# %% [markdown]
# # try getinfo

# %%
# import os
# from bs4 import BeautifulSoup as bs
# import re
# with open("./data/html/極幻燒肉弁当.html","r",encoding='utf8') as f:
#     dienhtml=f.read()
#     soup=bs(dienhtml, "lxml")
    
    
# int(re.findall("http:\/\/www\.ipeen\.com\.tw\/shop\/([0-9]+)\'",soup.text)[0])#id
# info=soup.select_one("#shop-header > div.info")
# info.find('span', attrs={'itemprop': 'name'}).text#name
# soup.find('a', attrs={'data-label': '詳細資訊_大分類'}).text#bigstyle
# info.find('a', attrs={'data-label': '上方小分類'}).text#smallstyle
# int(re.findall("本店均消 +([0-9]+) +元",info.select_one('p.cost.i').text)[0])#averagecost
# info.find('a', attrs={'data-label': '上方電話'}).text.replace("-","")#tele
# re.findall("..[市|縣].+[區|市].+[路|街|地段|巷][0-9]+[-|之]?[0-9]*?[號|巷|弄]?[0-9]*[號|巷|弄|樓]",
#            info.find('a', attrs={'data-label': '上方地址'}).text)[0]#add
# re.findall("\/c=([0-9]+\.[0-9]+)\,([0-9]+\.[0-9]+)\/z=",info.find('a', attrs={'data-label': '上方地址'})["href"])[0]#lat.lng
# int(re.findall("會員分享文 \(([0-9]+)\)",soup.text)[0])#Ncomment
# int(info.select_one("span.score-bar.large > meter")['value'])
# if "已歇業" in info.select_one("h1").text:
#     print("結束營業")
# else:
#     print("正常營業")#status
# re.findall("共([0-9]+)人瀏覽([0-9]+)人收藏",info.select_one("div.scalar").text.
#            replace(",","").replace("\n","").replace(" ",""))[0]#viewcount.collecount
# re.findall("更新時間(\d{4}\/\d{2}\/\d{2})",soup.select_one("div#shop-details").text.
#            replace("\n","").replace(" ",""))[0]#renewtime
# Out:
# 25.021057

# %% [markdown]
# # 第二版 須改邏輯為ID(唯一)

# %%
# import os
# from bs4 import BeautifulSoup as bs
# import json
# import re
# dienlist=[]
# print("共有"+str(len(os.listdir("./data/html")))+"筆資料")
# n=0


# if os.path.exists('./data/diendata.json'):
#     with open("./data/diendata.json","r") as d:
#         dienlist=json.load(d)
#         n=len(dienlist)
        
# finishdien=[dien['name'] for dien in dienlist]
        


# for file in os.listdir("./data/html"):
#     if n%50==0:
#         print(n)
#         with open("./data/diendata.json","w") as d:
#             json.dump(dienlist,d)
        
#     if file.split(".")[0].replace('"',"") not in finishdien:
#         n+=1
#         with open("./data/html/"+file,"r",encoding='utf8') as f:
#             diendata={}
#             dienhtml=f.read()
#             soup=bs(dienhtml,"lxml")
#             info=soup.select_one("#shop-header > div.info")

#             diendata["id"]=int(re.findall("http:\/\/www\.ipeen\.com\.tw\/shop\/([0-9]+)\'",soup.text)[0])#id
#             diendata["name"]=info.find('span', attrs={'itemprop': 'name'}).text.replace('"',"")
#             diendata["bigstyle"]=soup.find('a', attrs={'data-label': '詳細資訊_大分類'}).text
#             diendata["smallstyle"]=info.find('a', attrs={'data-label': '上方小分類'}).text

#             try:
#                 diendata["averagecost"]=int(re.findall("本店均消 +([0-9]+) +元",info.select_one('p.cost.i').text)[0])
#             except:
#                 diendata["averagecost"]=0
#             try:
#                 diendata["tele"]=info.find('a', attrs={'data-label': '上方電話'}).text.replace("-","")#tele
#             except:
#                 diendata["tele"]=0
#             try:
#                 diendata["address"]=re.findall("..[市|縣].+[區|市].+[路|街|地段|巷][0-9]+[-|之]?[0-9]*?[號|巷|弄]?[0-9]*[號|巷|弄|樓]",
#                        info.find('a', attrs={'data-label': '上方地址'}).text)[0]#add
#             except:
#                 diendata["address"]=0

#             try:
#                 diendata["lat"]=float(re.findall("\/c=([0-9]+\.[0-9]+)\,([0-9]+\.[0-9]+)\/z=",
#                                                info.find('a', attrs={'data-label': '上方地址'})["href"])[0][0])#lat.lng
#             except:
#                 diendata["lat"]=0
#             try:
#                 diendata["lng"]=float(re.findall("\/c=([0-9]+\.[0-9]+)\,([0-9]+\.[0-9]+)\/z=",
#                                                info.find('a', attrs={'data-label': '上方地址'})["href"])[0][1])#lat.lng
#             except:
#                 diendata["lng"]=0
#             try:
#                 diendata["Ncomment"]=int(re.findall("會員分享文 \(([0-9]+)\)",soup.text)[0])#Ncomment
#             except:
#                 diendata["Ncomment"]=0
#             diendata["ipeenscore"]=int(info.select_one("span.score-bar.large > meter")['value'])#ipeenscore
#             if "已歇業" in info.select_one("h1").text:
#                 diendata["status"]="結束營業"
#             else:
#                 diendata["status"]="正常營業"
#             diendata["viewcount"]=int(re.findall("共([0-9]+)人瀏覽([0-9]+)人收藏",info.select_one("div.scalar").text.
#                        replace(",","").replace("\n","").replace(" ",""))[0][0])#viewcount
#             diendata["collecount"]=int(re.findall("共([0-9]+)人瀏覽([0-9]+)人收藏",info.select_one("div.scalar").text.
#                        replace(",","").replace("\n","").replace(" ",""))[0][1])#collecount
#             diendata["reviewdate"]=re.findall("更新時間(\d{4}\/\d{2}\/\d{2})",soup.select_one("div#shop-details").text.
#                        replace("\n","").replace(" ",""))[0]#renewdate
#         dienlist.append(diendata)
#     else:
#         print("已有資料"+file)
    
# with open("./data/diendata.json","w") as d:
#     json.dump(dienlist,d)
# Out:
# 共有35491筆資料
# 800
# 已有資料007冰城.html
# 已有資料018咖啡甜品玩國.html
# 已有資料055龍蝦海鮮餐廳.html
# 已有資料086日式燒肉.html
# 已有資料1010湘.html
# 已有資料101日式小吃.html
# 已有資料101熱炒.html
# 已有資料101芒果冰團.html
# 已有資料103早午餐.html
# 已有資料108堂烘焙.html
# 已有資料108養生饅頭.html
# 已有資料10元吃到堡之鹹豬堡.html
# 已有資料10元滷味串燒.html
# 已有資料10元西瓜汁.html
# 已有資料10元豆花.html
# 已有資料10分之1海鮮燒烤.html
# 已有資料10號廚房.html
# 已有資料110泡芙銀行.html
# 已有資料111Bistro.html
# 已有資料119溫馨咖啡館.html
# 已有資料11號咖啡.html
# 已有資料11風谷拉麵.html
# 已有資料123冰城.html
# 已有資料123家常菜館.html
# 已有資料123手感烘焙坊.html
# 已有資料123簡餐.html
# 已有資料123養生雞湯.html
# 已有資料123饅頭店.html
# 已有資料127水餃.html
# 已有資料12次元巧克力魔法殿.html
# 已有資料1301中西餐飲坊.html
# 已有資料1314渡假村.html
# 已有資料1314碳烤三明治.html
# 已有資料133鮮果汁.html
# 已有資料1345BRUNCH.html
# 已有資料134巷內的女巫.html
# 已有資料136公路客家小館.html
# 已有資料139日式卡通雞蛋糕.html
# 已有資料139飲食小棧.html
# 已有資料13th.html
# 已有資料13個手感烘焙.html
# 已有資料13咖啡.html
# 已有資料14F手作甜點.html
# 已有資料14號咖啡館.html
# 已有資料1517手工冰品.html
# 已有資料151投幣火鍋.html
# 已有資料151食堂.html
# 已有資料152番地台式餐廳.html
# 已有資料15元大飯店.html
# 已有資料15區法式烘焙坊.html
# 已有資料161咖啡烘焙屋.html
# 已有資料161烘焙咖啡屋.html
# 已有資料168海鮮超市餐廳.html
# 已有資料168火鍋坊.html
# 已有資料168純鮮飲.html
# 已有資料168綠豆湯.html
# 已有資料168蔥油餅.html
# 已有資料169北平烤鴨店.html
# 已有資料16號酒館.html
# 已有資料179團購美食網.html
# 已有資料17番号-義式冰淇淋‧手工巧克力.html
# 已有資料17號鄉村廚房.html
# 已有資料17號雞排店.html
# 已有資料180韓定食.html
# 已有資料181烘焙屋.html
# 已有資料188炸雞店.html
# 已有資料18巷公園羊肉炒麵.html
# 已有資料18度C巧克力工坊.html
# 已有資料18番燒烤.html
# 已有資料18鍋.html
# 已有資料1915海洋咖啡館.html
# 已有資料1928燒肉總鋪.html
# 已有資料193咖啡館.html
# 已有資料1942餓棧廚房.html
# 已有資料1945東西美饌.html
# 已有資料1966牛肉麵.html
# 已有資料1978壹酒柒吧燒烤海鮮酒吧.html
# 已有資料1987廚房工作室.html
# 已有資料198美式炸雞.html
# 已有資料19號碼頭音樂餐廳.html
# 已有資料1加1.html
# 已有資料1加1午晚餐.html
# 850
# 已有資料2000萬壽司店.html
# 850
# 已有資料2010年月餅試吃.html
# 已有資料2011台北凱撒月餅禮盒.html
# 已有資料2014金格中秋調酒月餅禮盒.html
# 已有資料205巷紙火鍋.html
# 已有資料208音樂餐廳.html
# 已有資料20四6.html
# 已有資料20盎司牛排屋.html
# 已有資料216巷美食-非吃不可的泡菜香腸捲.html
# 已有資料218巷味蕾工房.html
# 已有資料21世紀櫻花蝦芋粿米糕.html
# 已有資料21金小火鍋臭臭鍋.html
# 已有資料21點港式點心茶飲專賣店.html
# 已有資料22部門專業碳烤吐司.html
# 已有資料22部門專業碳烤土司.html
# 已有資料2326炸雞.html
# 已有資料2326美食.html
# 已有資料233屋台燒烤.html
# 已有資料23度半鳳梨。福爾摩沙的熱帶金鑽.html
# 已有資料23燒烤.html
# 已有資料241橋頭鹹酥雞.html
# 已有資料2486辣脆腸.html
# 已有資料24小吃店.html
# 已有資料24臻穀.html
# 已有資料257咖啡.html
# 已有資料258水餃.html
# 已有資料25好好味.html
# 已有資料25巷複合式精緻餐飲.html
# 已有資料267飯店.html
# 已有資料26區鮮釀啤酒燒肉居食屋.html
# 已有資料26法式餐廳.html
# 已有資料26號飲品專賣店.html
# 已有資料27米粉湯.html
# 已有資料27街.html
# 已有資料27街迷你韓式火鍋.html
# 已有資料285大排檔.html
# 已有資料28巷早餐坊.html
# 已有資料28度C簡餐.html
# 已有資料28街排骨店.html
# 已有資料28豆腐店.html
# 已有資料2F食館.html
# 已有資料2派克脆皮雞排.html
# 已有資料2號出口海釣魚食料理.html
# 已有資料2里郎.html
# 900
# 已有資料301大道.html
# 已有資料301水餃滷味各式麵類.html
# 已有資料30年鵝肉老店.html
# 已有資料30年麵店.html
# 已有資料30幾年麵店.html
# 已有資料31活蝦小舖.html
# 已有資料32會館精鐉火鍋.html
# 已有資料32脆皮臭豆腐.html
# 已有資料32袋奶.html
# 已有資料32食坊.html
# 已有資料342巷Cafe.html
# 已有資料3517手作甜點。輕食.html
# 已有資料358精緻涮涮鍋.html
# 已有資料361義大利麵.html
# 已有資料36味咖啡館.html
# 已有資料37度茶微醺.html
# 已有資料37豆子手工粉圓.html
# 已有資料383冰果吧.html
# 已有資料38食光.html
# 已有資料3A同學會.html
# 已有資料3inch迷你燒烤堡.html
# 已有資料3Pig五花肉專賣店.html
# 已有資料3Q總舖手工關廟麵.html
# 已有資料3Q總鋪手工關麻乾麵.html
# 已有資料3Q脆皮雞排.html
# 已有資料3之小豬.html
# 已有資料3個10元紅豆餅.html
# 已有資料3個10元車輪餅攤.html
# 已有資料3各鍋火鍋料理.html
# 已有資料3樂鐡板燒.html
# 已有資料3茶館.html
# 已有資料3號咖啡.html
# 已有資料3頑子無煙燒烤.html
# 已有資料40元蒸餃.html
# 已有資料40年老店美香陽春麵.html
# 已有資料44號館浜焼き酒場.html
# 已有資料456蟹殼黃酥餅專賣店.html
# 已有資料48HOME.html
# 已有資料49元勁道烏龍麵.html
# 已有資料4C冰釀達人.html
# 已有資料4F小餐盒.html
# 已有資料4F料理生活家.html
# 已有資料4plus.html
# 已有資料500碗陽春麵.html
# 已有資料507高地美健農場.html
# 已有資料50pizza.html
# 已有資料50元爌肉飯.html
# 950
# 已有資料50嵐.html
# 已有資料50年古早味.html
# 已有資料50年杏仁茶.html
# 已有資料50樓cafe.html
# 已有資料50饡便當.html
# 已有資料513義式料理.html
# 已有資料51咖啡簡餐.html
# 已有資料51茶蓋.html
# 已有資料51號咖啡屋.html
# 已有資料534薇薇現打果汁.html
# 已有資料53咖啡.html
# 已有資料53林咖啡.html
# 已有資料5468美式原味碳烤牛排.html
# 已有資料555帝王食補薑母鴨.html
# 已有資料55號義大利麵.html
# 已有資料56巷口手工湯包.html
# 已有資料56芝麻球芋頭餅.html
# 已有資料56號藍色公路咖啡.html
# 已有資料586食堂.html
# 已有資料588包小奶.html
# 已有資料589奶酪工坊.html
# 已有資料58海鮮熱炒燒烤.html
# 已有資料58番蔥抓餅.html
# 已有資料58辣子雞.html
# 已有資料58鍋燒.html
# 已有資料5A招牌豬肉麵.html
# 已有資料5味臭臭鍋.html
# 已有資料5鄉地.html
# 已有資料6-1號現滷滷味.html
# 已有資料60號紅豆餅鋪.html
# 已有資料612號月光海洋咖啡館.html
# 已有資料61現烘咖啡餐酒館.html
# 1000
# 已有資料62藝廊咖啡館.html
# 1000
# 已有資料66義式燒烤手趴雞.html
# 已有資料676滷肉飯.html
# 已有資料687餐坊咖啡下午茶.html
# 已有資料68食堂.html
# 已有資料6956半線鏢局.html
# 已有資料6街義食屋.html
# 已有資料7-11-焗烤鮪魚三明治.html
# 已有資料7-11.html
# 已有資料7-11open玉子丸子飯團.html
# 已有資料7-11三鮮滑蛋燴飯.html
# 已有資料7-11主廚田園沙拉.html
# 已有資料7-11京都豆皮壽司.html
# 已有資料7-11光合三明治-厚蛋田園.html
# 已有資料7-11光合三明治-智利煙燻帝王鮭魚.html
# 已有資料7-11光合三明治-溫泉蛋沙拉.html
# 已有資料7-11光合沙拉-洋芋蛋沙拉佐生菜.html
# 已有資料7-11光合潛艇堡-法式紅酒肉丸堡.html
# 已有資料7-11北海道鮭魚親子極上夾心飯糰.html
# 已有資料7-11咖哩雞排.html
# 已有資料7-11大腸麵線.html
# 已有資料7-11大雞肉飯.html
# 已有資料7-11奶油鮭魚焗麵.html
# 已有資料7-11御壽司-壽司三明治.html
# 已有資料7-11御飯糰-嘉義火雞肉.html
# 已有資料7-11御飯糰-培根蛋沙拉.html
# 已有資料7-11御飯糰-干貝飯糰辣味.html
# 已有資料7-11御飯糰-泡菜鮪魚.html
# 已有資料7-11御飯糰-活力雙手捲.html
# 已有資料7-11御飯糰-海陸雙手捲.html
# 已有資料7-11御飯糰-糯米飯糰.html
# 已有資料7-11御飯糰-醬燒豬肉夾心.html
# 已有資料7-11御飯糰-雙餡飯糰美國龍蝦北海道鮭魚.html
# 已有資料7-11御飯糰-雙餡飯糰鮪魚肉鬆.html
# 已有資料7-11御飯糰-雞唐揚美乃滋.html
# 已有資料7-11御飯糰-韓式泡菜燒肉.html
# 已有資料7-11御飯糰-鮪魚夾心飯糰.html
# 已有資料7-11御飯糰.html
# 已有資料7-11桃木燻雞飯糰.html
# 已有資料7-11正宗台式肉燥乾麵.html
# 已有資料7-11比利時巧克力雙餡蛋糕.html
# 已有資料7-11比利時皇家岩石巧克力蛋糕.html
# 已有資料7-11炸雞腿便當.html
# 已有資料7-11焗烤奶油蝦仁義大利麵.html
# 已有資料7-11焦糖瑪奇朵軟法.html
# 已有資料7-11皮蛋瘦肉粥.html
# 已有資料7-11起酥香草布丁.html
# 已有資料7-11酷辣雞腿.html
# 已有資料7-11限定麻婆豆腐燴飯.html
# 已有資料7-11餛飩麵.html
# 已有資料7-11香草戚風蛋糕.html
# 已有資料7-11香辣雞翅洋芋片.html
# 已有資料7-11香雞排.html
# 已有資料7-ELEVEN義式烤雞番茄義大利麵.html
# 已有資料7-ELEVEN香蕉牛乳.html
# 已有資料7-SELECT切達起司爆米花.html
# 已有資料7-SELECT蕃茄乳酪手工披薩.html
# 已有資料7-SELECT蕃茄肉醬義大利麵.html
# 已有資料715森林園.html
# 已有資料72號鬆餅堡.html
# 已有資料737巷義麵屋.html
# 已有資料737滷味.html
# 已有資料77House手工烘焙坊.html
# 已有資料77乳加校車禮盒.html
# 已有資料77巧克力醬.html
# 已有資料77新貴派巧克力.html
# 已有資料77雷鬼巧克力.html
# 已有資料786李園清真小吃.html
# 已有資料7Linner.html
# 1050
# 已有資料7x7米平方.html
# 已有資料7分之7Brunch.html
# 已有資料7平方創新PIZZArestaurant.html
# 已有資料7年5班複合式餐飲.html
# 已有資料7號森林秘徑餐廳.html
# 已有資料806清粥自助餐.html
# 已有資料821麵食概念屋.html
# 已有資料82巷豬血糕.html
# 1100
# 已有資料85度C咖啡蛋糕烘焙專賣店.html
# 已有資料85度C鳳梨酥.html
# 已有資料86炭烤雞排.html
# 已有資料86號餐館.html
# 已有資料877手工咖啡.html
# 已有資料88牛肉麵.html
# 已有資料88花園咖啡無菜單創意料理.html
# 已有資料88麻辣鍋.html
# 已有資料89海鮮.html
# 已有資料89餐廳.html
# 已有資料8King港城飲食.html
# 已有資料8個娃娃鍋.html
# 已有資料8元紅豆餅.html
# 已有資料8克cafe.html
# 已有資料8分之1.html
# 已有資料8分之1無煙串燒.html
# 已有資料8加1番咖哩專賣.html
# 已有資料8号麵包創意工坊.html
# 已有資料8婆-水果專賣.html
# 已有資料8度洋食廚房.html
# 已有資料8度濃漿.html
# 已有資料8豆珈琲.html
# 已有資料90高地玉米花.html
# 已有資料90高地玉米花爆破工場.html
# 已有資料917攝影咖啡館.html
# 已有資料918咖啡.html
# 已有資料92夢咖啡豐原.html
# 已有資料92涮涮鍋.html
# 已有資料93。C加啡館.html
# 已有資料93巷人文空間.html
# 已有資料93巷馨香廚房.html
# 已有資料93複合式餐廳.html
# 已有資料93覓洋食.html
# 已有資料94i手感烘焙.html
# 已有資料95號煙燻滷味.html
# 已有資料988料理屋.html
# 已有資料988生猛海鮮餐廳.html
# 已有資料98日式拉麵.html
# 已有資料98燒烤屋.html
# 已有資料99泰式燒烤.html
# 已有資料9一郎活海鮮.html
# 已有資料9在ㄍㄡ甜心菓舖.html
# 已有資料9最定食拉麵.html
# 已有資料9號貓巷.html
# 已有資料A-bao.html
# 已有資料A-bao早餐店.html
# 已有資料A-Bull阿布食藝.html
# 1150
# 已有資料A-one泰.html
# 已有資料A-PLUS幸福窯烤.html
# 已有資料a-zone文化創意產業園區-香根名茶.html
# 已有資料ACE全素軟糖.html
# 已有資料ACE大蔓越莓乾.html
# 已有資料Addicition癮餐酒館.html
# 已有資料AFRICA.html
# 已有資料Agroworks蔬果工場.html
# 已有資料AGUGU阿咕咕.html
# 已有資料AIFYA常福螺旋藻酵素.html
# 1200
# 已有資料alemusichouse.html
# 已有資料All-in飽庫.html
# 已有資料ALLEY181.html
# 已有資料allin五青排空.html
# 已有資料allin金胎十勝原机.html
# 已有資料ALWAYS歐維氏-巧克力.html
# 已有資料ALWAYS歐維氏-杏仁蔓越莓巧克力.html
# 已有資料ALWAYS歐維氏-榛果夾心巧克力.html
# 已有資料ALWAYS歐維氏-跳跳糖巧克力.html
# 已有資料AMANA.html
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 2550
# 2600
# 2650
# 2700
# 2750
# 2800
# 2850
# 2900
# 2950
# 3000
# 3050
# 3100
# 3150
# 3200
# 3250
# 3300
# 3350
# 3400
# 3450
# 3500
# 3550
# 3600
# 3650
# 3700
# 3750
# 3800
# 3850
# 3900
# 3950
# 4000
# 4050
# 4100
# 4150
# 4200
# 4250
# 4300
# 4350
# 4400
# 4450
# 4500
# 4550
# 4600
# 4650
# 4700
# 4750
# 4800
# 4850
# 4900
# 4950
# 5000
# 5050
# 5100
# 5150
# 5200
# 5250
# 5300
# 5350
# 5400
# 5450
# 5500
# 5550
# 5600
# 5650
# 5700
# 5750
# 5800
# 5850
# 5900
# 5950
# 6000
# 6050
# 6100
# 6150
# 6200
# 6250
# 6300
# 6350
# 6400
# 6450
# 6500
# 6550
# 6600
# 6650
# 6700
# 6750
# 6800
# 6850
# 6900
# 6950
# 7000
# 7050
# 7100
# 7150
# 7200
# 7250
# 7300
# 7350
# 7400
# 7450
# 7500
# 7550
# 7600
# 7650
# 7700
# 7750
# 7800
# 7850
# 7900
# 7950
# 8000
# 8050
# 8100
# 8150
# 8200
# 8250
# 8300
# 8350
# 8400
# 8450
# 8500
# 8550
# 8600
# 8650
# 8700
# 8750
# 8800
# 8850
# 8900
# 8950
# 9000
# 9050
# 9100
# 9150
# 9200
# 9250
# 9300
# 9350
# 9400
# 9450
# 9500
# 9550
# 9600
# 9650
# 9700
# 9750
# 9800
# 9850
# 9900
# 9950
# 10000
# 10050
# 10100
# 10150
# 10200
# 10250
# 10300
# 10350
# 10400
# 10450
# 10500
# 10550
# 10600
# 10650
# 10700
# 10750
# 10800
# 10850
# 10900
# 10950
# 11000
# 11050
# 11100
# 11150
# 11200
# 11250
# 11300
# 11350
# 11400
# 11450
# 11500
# 11550
# 11600
# 11650
# 11700
# 11750
# 11800
# 11850
# 11900
# 11950
# 12000
# 12050
# 12100
# 12150
# 12200
# 12250
# 12300
# 12350
# 12400
# 12450
# 12500
# 12550
# 12600
# 12650
# 12700
# 12750
# 12800
# 12850
# 12900
# 12950
# 13000
# 13050
# 13100
# 13150
# 13200
# 13250
# 13300
# 13350
# 13400
# 13450
# 13500
# 13550
# 13600
# 13650
# 13700
# 13750
# 13800
# 13850
# 13900
# 13950
# 14000
# 14050
# 14100
# 14150
# 14200
# 14250
# 14300
# 14350
# 14400
# 14450
# 14500
# 14550
# 14600
# 14650
# 14700
# 14750
# 14800
# 14850
# 14900
# 14950
# 15000
# 15050
# 15100
# 15150
# 15200
# 15250
# 15300
# 15350
# 15400
# 15450
# 15500
# 15550
# 15600
# 15650
# 15700
# 15750
# 15800
# 15850
# 15900
# 15950
# 16000
# 16050
# 16100
# 16150
# 16200
# 16250
# 16300
# 16350
# 16400
# 16450
# 16500
# 16550
# 16600
# 16650
# 16700
# 16750
# 16800
# 16850
# 16900
# 16950
# 17000
# 17050
# 17100
# 17150
# 17200
# 17250
# 17300
# 17350
# 17400
# 17450
# 17500
# 17550
# 17600
# 17650
# 17700
# 17750
# 17800
# 17850
# 17900
# 17950
# 18000
# 18050
# 18100
# 18150
# 18200
# 18250
# 18300
# 18350
# 18400
# 18450
# 18500
# 18550
# 18600
# 18650
# 18700
# 18750
# 18800
# 18850
# 18900
# 18950
# 19000
# 19050
# 19100
# 19150
# 19200
# 19250
# 19300
# 19350
# 19400
# 19450
# 19500
# 19550
# 19600
# 19650
# 19700
# 19750
# 19800
# 19850
# 19900
# 19950
# 20000
# 20050
# 20100
# 20150
# 20200
# 20250
# 20300
# 20350
# 20400
# 20450
# 20500
# 20550
# 20600
# 20650
# 20700
# 20750
# 20800
# 20850
# 20900
# 20950
# 21000
# 21050
# 21100
# 21150
# 21200
# 21250
# 21300
# 21350
# 21400
# 21450
# 21500
# 21550
# 21600
# 21650
# 21700
# 21750
# 21800
# 21850
# 21900
# 21950
# 22000
# 22050
# 22100
# 22150
# 22200
# 22250
# 22300
# 22350
# 22400
# 22450
# 22500
# 22550
# 22600
# 22650
# 22700
# 22750
# 22800
# 22850
# 22900
# 22950
# 23000
# 23050
# 23100
# 23150
# 23200
# 23250
# 23300
# 23350
# 23400
# 23450
# 23500
# 23550
# 23600
# 23650
# 23700
# 23750
# 23800
# 23850
# 23900
# 23950
# 24000
# 24050
# 24100
# 24150
# 24200
# 24250
# 24300
# 24350
# 24400
# 24450
# 24500
# 24550
# 24600
# 24650
# 24700
# 24750
# 24800
# 24850
# 24900
# 24950
# 25000
# 25050
# 25100
# 25150
# 25200
# 25250
# 25300
# 25350
# 25400
# 25450
# 25500
# 25550
# 25600
# 25650
# 25700
# 25750
# 25800
# 25850
# 25900
# 25950
# 26000
# 26050
# 26100
# 26150
# 26200
# 26250
# 26300
# 26350
# 26400
# 26450
# 26500
# 26550
# 26600
# 26650
# 26700
# 26750
# 26800
# 26850
# 26900
# 26950
# 27000
# 27050
# 27100
# 27150
# 27200
# 27250
# 27300
# 27350
# 27400
# 27450
# 27500
# 27550
# 27600
# 27650
# 27700
# 27750
# 27800
# 27850
# 27900
# 27950
# 28000
# 28050
# 28100
# 28150
# 28200
# 28250
# 28300
# 28350
# 28400
# 28450
# 28500
# 28550
# 28600
# 28650
# 28700
# 28750
# 28800
# 28850
# 28900
# 28950
# 29000
# 29050
# 29100
# 29150
# 29200
# 29250
# 29300
# 29350
# 29400
# 29450
# 29500
# 29550
# 29600
# 29650
# 29700
# 29750
# 29800
# 29850
# 29900
# 29950
# 30000
# 30050
# 30100
# 30150
# 30200
# 30250
# 30300
# 30350
# 30400
# 30450
# 30500
# 30550
# 30600
# 30650
# 30700
# 30750
# 30800
# 30850
# 30900
# 30950
# 31000
# 31050
# 31100
# 31150
# 31200
# 31250
# 31300
# 31350
# 31400
# 31450
# 31500
# 31550
# 31600
# 31650
# 31700
# 31750
# 31800
# 31850
# 31900
# 31950
# 32000
# 32050
# 32100
# 32150
# 32200
# 32250
# 32300
# 32350
# 32400
# 32450
# 32500
# 32550
# 32600
# 32650
# 32700
# 32750
# 32800
# 32850
# 32900
# 32950
# 33000
# 33050
# 33100
# 33150
# 33200
# 33250
# 33300
# 33350
# 33400
# 33450
# 33500
# 33550
# 33600
# 33650
# 33700
# 33750
# 33800
# 33850
# 33900
# 33950
# 34000
# 34050
# 34100
# 34150
# 34200
# 34250
# 34300
# 34350
# 34400
# 34450
# 34500
# 34550
# 34600
# 34650
# 34700
# 34750
# 34800
# 34850
# 34900
# 34950
# 35000
# 35050
# 35100
# 35150
# 35200
# 35250
# 35300
# 35350
# 35400
# 35450
# 35500
# 35550
# 35600
# 35650
# 35700
# 35750
# 35800
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-121-00620e6fd9fd> in <module>()
#      25     if file.split(".")[0].replace('"',"") not in finishdien:
#      26         n+=1
# ---> 27         with open("./data/html/"+file,"r",encoding='utf8') as f:
#      28             diendata={}
#      29             dienhtml=f.read()
#
# D:\anaconda\lib\codecs.py in __init__(self, errors)
#     306     byte sequences.
#     307     """
# --> 308     def __init__(self, errors='strict'):
#     309         IncrementalDecoder.__init__(self, errors)
#     310         # undecoded input that is kept between calls to decode()
#
# KeyboardInterrupt:

# %% [markdown]
# # 第三版 唯一值為ID 不重複

# %%
import os
from bs4 import BeautifulSoup as bs
import json
import re
dienlist=[]
print("共有"+str(len(os.listdir("./data/html2")))+"筆資料")
n=0

finishdien=[]
if os.path.exists('./data/diendata.json'):
    with open("./data/diendata.json","r") as d:
        dienlist=json.load(d)
        n=len(dienlist)+1
        finishdien=[dien['id'] for dien in dienlist]

for file in os.listdir("./data/html2"):
    if int(file.split(".")[0]) not in finishdien:
        n+=1
        if n%50==0:
            print("已存%s筆資料"%n)
            with open("./data/diendata.json","w") as d:
                json.dump(dienlist,d)
                
        with open("./data/html2/"+file,"r",encoding='utf8') as f:
            diendata={}
            dienhtml=f.read()
            soup=bs(dienhtml,"lxml")
            info=soup.select_one("#shop-header > div.info")

            diendata["id"]=int(re.findall("http:\/\/www\.ipeen\.com\.tw\/shop\/([0-9]+)\'",soup.text)[0])#id
            diendata["name"]=info.find('span', attrs={'itemprop': 'name'}).text.replace('"',"")
            diendata["bigstyle"]=soup.find('a', attrs={'data-label': '詳細資訊_大分類'}).text
            diendata["smallstyle"]=info.find('a', attrs={'data-label': '上方小分類'}).text

            try:
                diendata["averagecost"]=int(re.findall("本店均消 +([0-9]+) +元",info.select_one('p.cost.i').text)[0])
            except:
                diendata["averagecost"]=0
            try:
                diendata["tele"]=info.find('a', attrs={'data-label': '上方電話'}).text.replace("-","")#tele
            except:
                diendata["tele"]=0
            try:
                diendata["address"]=re.findall("..[市|縣].+[區|市].+[路|街|地段|巷][0-9]+[-|之]?[0-9]*?[號|巷|弄]?[0-9]*[號|巷|弄|樓]",
                       info.find('a', attrs={'data-label': '上方地址'}).text)[0]#add
            except:
                diendata["address"]=0

            try:
                diendata["lat"]=float(re.findall("\/c=([0-9]+\.[0-9]+)\,([0-9]+\.[0-9]+)\/z=",
                                               info.find('a', attrs={'data-label': '上方地址'})["href"])[0][0])#lat.lng
            except:
                diendata["lat"]=0
            try:
                diendata["lng"]=float(re.findall("\/c=([0-9]+\.[0-9]+)\,([0-9]+\.[0-9]+)\/z=",
                                               info.find('a', attrs={'data-label': '上方地址'})["href"])[0][1])#lat.lng
            except:
                diendata["lng"]=0
            try:
                diendata["Ncomment"]=int(re.findall("會員分享文 \(([0-9]+)\)",soup.text)[0])#Ncomment
            except:
                diendata["Ncomment"]=0
            diendata["ipeenscore"]=int(info.select_one("span.score-bar.large > meter")['value'])#ipeenscore
            if "已歇業" in info.select_one("h1").text:
                diendata["status"]="結束營業"
            else:
                diendata["status"]="正常營業"
            diendata["viewcount"]=int(re.findall("共([0-9]+)人瀏覽([0-9]+)人收藏",info.select_one("div.scalar").text.
                       replace(",","").replace("\n","").replace(" ",""))[0][0])#viewcount
            diendata["collecount"]=int(re.findall("共([0-9]+)人瀏覽([0-9]+)人收藏",info.select_one("div.scalar").text.
                       replace(",","").replace("\n","").replace(" ",""))[0][1])#collecount
            diendata["reviewdate"]=re.findall("更新時間(\d{4}\/\d{2}\/\d{2})",soup.select_one("div#shop-details").text.
                       replace("\n","").replace(" ",""))[0]#renewdate
        dienlist.append(diendata)
    else:
        print("已有資料"+file)
    
with open("./data/diendata.json","w") as d:
    json.dump(dienlist,d)
# Out:
# 共有36688筆資料
# 已有資料100000.html
# 已有資料1000010.html
# 已有資料1000022.html
# 已有資料1000036.html
# 已有資料1000068.html
# 已有資料1000074.html
# 已有資料1000080.html
# 已有資料1000088.html
# 已有資料1000108.html
# 已有資料1000120.html
# 已有資料100013.html
# 已有資料1000158.html
# 已有資料1000166.html
# 已有資料1000170.html
# 已有資料1000180.html
# 已有資料1000192.html
# 已有資料1000204.html
# 已有資料1000222.html
# 已有資料1000228.html
# 已有資料1000242.html
# 已有資料1000250.html
# 已有資料1000266.html
# 已有資料1000294.html
# 已有資料1000326.html
# 已有資料1000334.html
# 已有資料1000336.html
# 已有資料1000340.html
# 已有資料1000368.html
# 已有資料1000370.html
# 已有資料1000424.html
# 已有資料1000426.html
# 已有資料1000430.html
# 已有資料1000432.html
# 已有資料1000434.html
# 已有資料1000436.html
# 已有資料1000460.html
# 已有資料1000468.html
# 已有資料1000494.html
# 已有資料100050.html
# 已有資料1000516.html
# 已有資料1000526.html
# 已有資料1000578.html
# 已有資料100065.html
# 已有資料1000654.html
# 已有資料1000704.html
# 已有資料1000732.html
# 已有資料1000738.html
# 已有資料100075.html
# 已有資料1000762.html
# 已有資料1000782.html
# 已有資料1000806.html
# 已有資料1000846.html
# 已有資料1000854.html
# 已有資料1000856.html
# 已有資料1000858.html
# 已有資料1000864.html
# 已有資料1000886.html
# 已有資料100089.html
# 已有資料1000898.html
# 已有資料100090.html
# 已有資料1000906.html
# 已有資料1000918.html
# 已有資料1000926.html
# 已有資料100093.html
# 已有資料1000934.html
# 已有資料100094.html
# 已有資料1000940.html
# 已有資料1000980.html
# 已有資料1001000.html
# 已有資料1001040.html
# 已有資料1001044.html
# 已有資料1001046.html
# 已有資料1001064.html
# 已有資料1001072.html
# 已有資料1001082.html
# 已有資料1001086.html
# 已有資料1001088.html
# 已有資料1001090.html
# 已有資料1001096.html
# 已有資料1001132.html
# 已有資料1001186.html
# 已有資料1001282.html
# 已有資料1001302.html
# 已有資料1001322.html
# 已有資料1001360.html
# 已有資料1001380.html
# 已有資料1001402.html
# 已有資料1001408.html
# 已有資料1001418.html
# 已有資料1001420.html
# 已有資料1001434.html
# 已有資料1001466.html
# 已有資料1001484.html
# 已有資料1001492.html
# 已有資料1001572.html
# 已有資料1001600.html
# 已有資料1001610.html
# 已有資料1001666.html
# 已有資料1001672.html
# 已有資料1001676.html
# 已有資料1001710.html
# 已有資料1001722.html
# 已有資料1001748.html
# 已有資料1001756.html
# 已有資料1001760.html
# 已有資料1001770.html
# 已有資料1001774.html
# 已有資料100178.html
# 已有資料1001816.html
# 已有資料1001842.html
# 已有資料1001858.html
# 已有資料1001864.html
# 已有資料100192.html
# 已有資料1001924.html
# 已有資料1001926.html
# 已有資料1001950.html
# 已有資料1001966.html
# 已有資料1001968.html
# 已有資料1001992.html
# 已有資料1002010.html
# 已有資料1002024.html
# 已有資料1002038.html
# 已有資料1002050.html
# 已有資料1002060.html
# 已有資料1002084.html
# 已有資料1002094.html
# 已有資料1002100.html
# 已有資料1002124.html
# 已有資料1002134.html
# 已有資料1002172.html
# 已有資料1002198.html
# 已有資料1002206.html
# 已有資料1002212.html
# 已有資料1002258.html
# 已有資料1002264.html
# 已有資料1002306.html
# 已有資料1002358.html
# 已有資料1002366.html
# 已有資料1002378.html
# 已有資料1002382.html
# 已有資料1002404.html
# 已有資料1002434.html
# 已有資料1002494.html
# 已有資料1002510.html
# 已有資料1002512.html
# 已有資料1002546.html
# 已有資料1002548.html
# 已有資料1002572.html
# 已有資料1002616.html
# 已有資料1002622.html
# 已有資料1002626.html
# 已有資料1002628.html
# 已有資料1002630.html
# 已有資料1002770.html
# 已有資料1002774.html
# 已有資料1002786.html
# 已有資料1002802.html
# 已有資料1002814.html
# 已有資料1002822.html
# 已有資料1002824.html
# 已有資料1002830.html
# 已有資料1002910.html
# 已有資料1002920.html
# 已有資料1002922.html
# 已有資料1002938.html
# 已有資料100295.html
# 已有資料100297.html
# 已有資料1003038.html
# 已有資料1003040.html
# 已有資料1003058.html
# 已有資料1003070.html
# 已有資料100309.html
# 已有資料100316.html
# 已有資料1003176.html
# 已有資料1003180.html
# 已有資料100319.html
# 已有資料1003190.html
# 已有資料100321.html
# 已有資料1003216.html
# 已有資料1003220.html
# 已有資料100324.html
# 已有資料1003334.html
# 已有資料1003346.html
# 已有資料1003362.html
# 已有資料100347.html
# 已有資料1003502.html
# 已有資料1003524.html
# 已有資料1003616.html
# 已有資料1003642.html
# 已有資料1003644.html
# 已有資料100365.html
# 已有資料100367.html
# 已有資料1003670.html
# 已有資料1003682.html
# 已有資料1003688.html
# 已有資料1003694.html
# 已有資料100372.html
# 已有資料1003738.html
# 已有資料100374.html
# 已有資料1003750.html
# 已有資料1003776.html
# 已有資料1003784.html
# 已有資料1003812.html
# 已有資料1003828.html
# 已有資料1003868.html
# 已有資料100387.html
# 已有資料1003910.html
# 已有資料1003916.html
# 已有資料1003928.html
# 已有資料1003930.html
# 已有資料1003954.html
# 已有資料1003966.html
# 已有資料1003998.html
# 已有資料1004014.html
# 已有資料1004018.html
# 已有資料1004040.html
# 已有資料1004056.html
# 已有資料1004060.html
# 已有資料1004094.html
# 已有資料1004112.html
# 已有資料1004128.html
# 已有資料1004136.html
# 已有資料1004146.html
# 已有資料1004198.html
# 已有資料1004208.html
# 已有資料1004212.html
# 已有資料1004228.html
# 已有資料1004234.html
# 已有資料100426.html
# 已有資料1004260.html
# 已有資料1004280.html
# 已有資料1004292.html
# 已有資料1004324.html
# 已有資料1004340.html
# 已有資料1004344.html
# 已有資料1004356.html
# 已有資料1004372.html
# 已有資料1004384.html
# 已有資料10044.html
# 已有資料1004406.html
# 已有資料1004424.html
# 已有資料1004426.html
# 已有資料1004444.html
# 已有資料1004446.html
# 已有資料1004456.html
# 已有資料1004478.html
# 已有資料1004518.html
# 已有資料1004534.html
# 已有資料1004542.html
# 已有資料1004558.html
# 已有資料10046.html
# 已有資料1004606.html
# 已有資料1004694.html
# 已有資料1004706.html
# 已有資料1004726.html
# 已有資料1004732.html
# 已有資料1004734.html
# 已有資料1004804.html
# 已有資料1004810.html
# 已有資料1004812.html
# 已有資料1004814.html
# 已有資料1004820.html
# 已有資料1004824.html
# 已有資料1004838.html
# 已有資料1004856.html
# 已有資料1004870.html
# 已有資料1004882.html
# 已有資料1004886.html
# 已有資料1004924.html
# 已有資料1004926.html
# 已有資料1004936.html
# 已有資料1004938.html
# 已有資料1004940.html
# 已有資料1004952.html
# 已有資料1004972.html
# 已有資料1004976.html
# 已有資料1004994.html
# 已有資料1004996.html
# 已有資料1005002.html
# 已有資料1005012.html
# 已有資料1005024.html
# 已有資料1005054.html
# 已有資料1005062.html
# 已有資料1005086.html
# 已有資料1005094.html
# 已有資料1005098.html
# 已有資料1005104.html
# 已有資料1005120.html
# 已有資料1005124.html
# 已有資料1005128.html
# 已有資料1005144.html
# 已有資料1005148.html
# 已有資料1005154.html
# 已有資料1005160.html
# 已有資料1005166.html
# 已有資料1005202.html
# 已有資料1005222.html
# 已有資料1005238.html
# 已有資料1005244.html
# 已有資料1005248.html
# 已有資料1005276.html
# 已有資料1005284.html
# 已有資料1005308.html
# 已有資料1005318.html
# 已有資料1005346.html
# 已有資料1005362.html
# 已有資料1005400.html
# 已有資料1005452.html
# 已有資料1005486.html
# 已有資料1005540.html
# 已有資料1005556.html
# 已有資料1005558.html
# 已有資料1005650.html
# 已有資料1005664.html
# 已有資料1005680.html
# 已有資料1005706.html
# 已有資料1005712.html
# 已有資料1005726.html
# 已有資料1005732.html
# 已有資料1005740.html
# 已有資料1005750.html
# 已有資料1005756.html
# 已有資料1005836.html
# 已有資料1005866.html
# 已有資料1005906.html
# 已有資料1005916.html
# 已有資料100592.html
# 已有資料1005922.html
# 已有資料1005924.html
# 已有資料100593.html
# 已有資料1005934.html
# 已有資料100594.html
# 已有資料1005974.html
# 已有資料1005978.html
# 已有資料10060.html
# 已有資料1006014.html
# 已有資料100603.html
# 已有資料1006034.html
# 已有資料1006060.html
# 已有資料1006062.html
# 已有資料1006064.html
# 已有資料100607.html
# 已有資料1006072.html
# 已有資料1006086.html
# 已有資料100609.html
# 已有資料1006094.html
# 已有資料1006096.html
# 已有資料1006108.html
# 已有資料1006116.html
# 已有資料1006138.html
# 已有資料100615.html
# 已有資料1006166.html
# 已有資料100618.html
# 已有資料1006198.html
# 已有資料1006230.html
# 已有資料1006238.html
# 已有資料1006240.html
# 已有資料1006272.html
# 已有資料1006286.html
# 已有資料1006324.html
# 已有資料1006326.html
# 已有資料1006354.html
# 已有資料1006386.html
# 已有資料1006452.html
# 已有資料1006464.html
# 已有資料1006490.html
# 已有資料1006564.html
# 已有資料1006568.html
# 已有資料1006572.html
# 已有資料1006578.html
# 已有資料100658.html
# 已有資料1006582.html
# 已有資料1006600.html
# 已有資料100662.html
# 已有資料1006652.html
# 已有資料1006666.html
# 已有資料100667.html
# 已有資料1006674.html
# 已有資料1006676.html
# 已有資料1006678.html
# 已有資料1006718.html
# 已有資料1006720.html
# 已有資料1006734.html
# 已有資料1006768.html
# 已有資料1006778.html
# 已有資料1006810.html
# 已有資料1006812.html
# 已有資料1006816.html
# 已有資料1006820.html
# 已有資料100689.html
# 已有資料1006900.html
# 已有資料1006904.html
# 已有資料1006926.html
# 已有資料1006930.html
# 已有資料1006948.html
# 已有資料1006956.html
# 已有資料1006962.html
# 已有資料1006968.html
# 已有資料1006974.html
# 已有資料1007016.html
# 已有資料1007022.html
# 已有資料1007026.html
# 已有資料1007040.html
# 已有資料1007050.html
# 已有資料1007058.html
# 已有資料1007066.html
# 已有資料1007068.html
# 已有資料1007098.html
# 已有資料1007104.html
# 已有資料1007120.html
# 已有資料1007122.html
# 已有資料1007134.html
# 已有資料1007140.html
# 已有資料100715.html
# 已有資料1007170.html
# 已有資料1007206.html
# 已有資料1007274.html
# 已有資料1007278.html
# 已有資料100734.html
# 已有資料1007370.html
# 已有資料1007410.html
# 已有資料1007474.html
# 已有資料1007476.html
# 已有資料1007480.html
# 已有資料10075.html
# 已有資料1007528.html
# 已有資料1007578.html
# 已有資料1007630.html
# 已有資料1007634.html
# 已有資料1007656.html
# 已有資料1007666.html
# 已有資料1007670.html
# 已有資料1007674.html
# 已有資料1007712.html
# 已有資料1007734.html
# 已有資料1007764.html
# 已有資料1007842.html
# 已有資料1007888.html
# 已有資料1007890.html
# 已有資料1007918.html
# 已有資料1007930.html
# 已有資料1007932.html
# 已有資料1007936.html
# 已有資料1007940.html
# 已有資料1007950.html
# 已有資料1007964.html
# 已有資料1007970.html
# 已有資料1007980.html
# 已有資料1008036.html
# 已有資料1008062.html
# 已有資料1008076.html
# 已有資料1008078.html
# 已有資料1008094.html
# 已有資料10081.html
# 已有資料1008110.html
# 已有資料1008126.html
# 已有資料1008128.html
# 已有資料1008184.html
# 已有資料10082.html
# 已有資料1008218.html
# 已有資料1008222.html
# 已有資料1008228.html
# 已有資料1008230.html
# 已有資料1008244.html
# 已有資料1008246.html
# 已有資料1008250.html
# 已有資料1008252.html
# 已有資料1008266.html
# 已有資料1008298.html
# 已有資料1008300.html
# 已有資料1008314.html
# 已有資料1008316.html
# 已有資料1008398.html
# 已有資料1008430.html
# 已有資料1008492.html
# 已有資料1008494.html
# 已有資料1008502.html
# 已有資料1008538.html
# 已有資料1008548.html
# 已有資料1008550.html
# 已有資料1008568.html
# 已有資料1008624.html
# 已有資料1008632.html
# 已有資料1008648.html
# 已有資料1008656.html
# 已有資料1008676.html
# 已有資料1008716.html
# 已有資料1008726.html
# 已有資料1008746.html
# 已有資料1008758.html
# 已有資料1008762.html
# 已有資料1008786.html
# 已有資料1008788.html
# 已有資料1008804.html
# 已有資料1008826.html
# 已有資料1008840.html
# 已有資料1008846.html
# 已有資料1008872.html
# 已有資料1008884.html
# 已有資料1008892.html
# 已有資料10089.html
# 已有資料1008902.html
# 已有資料1008934.html
# 已有資料1008938.html
# 已有資料1008948.html
# 已有資料100895.html
# 已有資料1008954.html
# 已有資料1008976.html
# 已有資料1008978.html
# 已有資料1008986.html
# 已有資料1009004.html
# 已有資料1009008.html
# 已有資料1009014.html
# 已存35600筆資料
# 已有資料1009038.html
# 已有資料1009040.html
# 已有資料1009080.html
# 已有資料1009090.html
# 已有資料1009096.html
# 已有資料1009124.html
# 已有資料1009128.html
# 已有資料1009130.html
# 已有資料1009132.html
# 已有資料1009140.html
# 已有資料1009180.html
# 已有資料1009184.html
# 已有資料1009188.html
# 已有資料1009190.html
# 已有資料1009194.html
# 已有資料1009200.html
# 已有資料1009206.html
# 已有資料100921.html
# 已有資料1009214.html
# 已有資料100922.html
# 已有資料1009228.html
# 已有資料100924.html
# 已有資料1009254.html
# 已有資料1009262.html
# 已有資料1009282.html
# 已有資料1009286.html
# 已有資料1009340.html
# 已有資料1009356.html
# 已有資料1009364.html
# 已有資料1009394.html
# 已有資料1009402.html
# 已有資料1009416.html
# 已有資料1009418.html
# 已有資料1009422.html
# 已有資料1009424.html
# 已有資料1009426.html
# 已有資料1009430.html
# 已有資料1009456.html
# 已有資料1009470.html
# 已有資料1009474.html
# 已有資料1009480.html
# 已有資料1009524.html
# 已有資料1009572.html
# 已有資料1009584.html
# 已有資料1009600.html
# 已有資料1009606.html
# 已有資料1009614.html
# 已有資料1009628.html
# 已有資料1009630.html
# 已有資料1009640.html
# 已有資料1009664.html
# 已有資料1009670.html
# 已有資料1009674.html
# 已有資料1009680.html
# 已有資料1009702.html
# 已有資料1009714.html
# 已有資料1009738.html
# 已有資料1009814.html
# 已有資料1009816.html
# 已有資料1009840.html
# 已有資料1009842.html
# 已有資料1009846.html
# 已有資料1009850.html
# 已有資料1009864.html
# 已有資料1009866.html
# 已有資料1009890.html
# 已有資料1009928.html
# 已有資料1010.html
# 已有資料1010010.html
# 已有資料1010030.html
# 已有資料1010032.html
# 已有資料1010040.html
# 已有資料1010044.html
# 已有資料1010052.html
# 已有資料1010074.html
# 已有資料1010088.html
# 已有資料1010112.html
# 已有資料1010132.html
# 已有資料1010160.html
# 已有資料1010164.html
# 已有資料1010188.html
# 已有資料1010206.html
# 已有資料1010216.html
# 已有資料1010228.html
# 已有資料1010230.html
# 已有資料1010232.html
# 已有資料1010244.html
# 已有資料1010246.html
# 已有資料1010250.html
# 已有資料1010252.html
# 已有資料1010264.html
# 已有資料1010266.html
# 已有資料1010268.html
# 已有資料1010270.html
# 已有資料1010274.html
# 已有資料1010294.html
# 已有資料10103.html
# 已有資料1010302.html
# 已有資料1010308.html
# 已有資料101031.html
# 已有資料1010312.html
# 已有資料1010322.html
# 已有資料1010328.html
# 已有資料1010348.html
# 已有資料1010350.html
# 已有資料1010370.html
# 已有資料1010374.html
# 已有資料1010380.html
# 已有資料1010384.html
# 已有資料1010388.html
# 已有資料1010394.html
# 已有資料1010396.html
# 已有資料1010398.html
# 已有資料1010402.html
# 已有資料1010404.html
# 已有資料1010408.html
# 已有資料1010412.html
# 已有資料1010418.html
# 已有資料1010428.html
# 已有資料101044.html
# 已有資料1010442.html
# 已有資料1010456.html
# 已有資料1010480.html
# 已有資料1010488.html
# 已有資料101050.html
# 已有資料1010508.html
# 已有資料1010516.html
# 已有資料101052.html
# 已有資料1010524.html
# 已有資料1010528.html
# 已有資料1010530.html
# 已有資料1010542.html
# 已有資料1010546.html
# 已有資料1010548.html
# 已有資料1010552.html
# 已有資料1010560.html
# 已有資料1010566.html
# 已有資料101057.html
# 已有資料10106.html
# 已有資料1010606.html
# 已有資料1010614.html
# 已有資料1010654.html
# 已有資料1010658.html
# 已有資料1010672.html
# 已有資料1010678.html
# 已有資料1010682.html
# 已有資料1010690.html
# 已有資料1010692.html
# 已有資料1010694.html
# 已有資料1010696.html
# 已有資料1010706.html
# 已有資料101072.html
# 已有資料1010728.html
# 已有資料1010748.html
# 已有資料1010750.html
# 已有資料1010770.html
# 已有資料1010800.html
# 已有資料1010824.html
# 已有資料1010840.html
# 已有資料1010866.html
# 已有資料1010884.html
# 已有資料1010910.html
# 已有資料1010920.html
# 已有資料1010930.html
# 已有資料1010950.html
# 已有資料1010956.html
# 已有資料101097.html
# 已有資料1010970.html
# 已有資料1010984.html
# 已有資料1010990.html
# 已有資料1010992.html
# 已有資料1010996.html
# 已有資料1011000.html
# 已有資料1011008.html
# 已有資料1011010.html
# 已有資料1011012.html
# 已有資料1011018.html
# 已有資料1011026.html
# 已有資料101103.html
# 已有資料1011040.html
# 已有資料1011044.html
# 已有資料101107.html
# 已有資料1011074.html
# 已有資料1011092.html
# 已有資料1011112.html
# 已有資料1011122.html
# 已有資料1011168.html
# 已有資料1011172.html
# 已有資料1011174.html
# 已有資料1011180.html
# 已有資料1011184.html
# 已有資料1011196.html
# 已有資料1011198.html
# 已有資料10112.html
# 已有資料1011206.html
# 已有資料1011216.html
# 已有資料1011230.html
# 已有資料1011258.html
# 已有資料1011264.html
# 已有資料1011272.html
# 已有資料1011274.html
# 已有資料101128.html
# 已有資料1011292.html
# 已有資料101131.html
# 已有資料1011334.html
# 已有資料101134.html
# 已有資料1011364.html
# 已有資料1011376.html
# 已有資料101138.html
# 已有資料1011384.html
# 已有資料1011386.html
# 已有資料1011388.html
# 已有資料10114.html
# 已有資料1011400.html
# 已有資料1011414.html
# 已有資料1011422.html
# 已有資料1011430.html
# 已有資料1011450.html
# 已有資料1011452.html
# 已有資料1011466.html
# 已有資料101148.html
# 已有資料1011480.html
# 已有資料1011494.html
# 已有資料1011496.html
# 已有資料1011542.html
# 已有資料1011558.html
# 已有資料1011560.html
# 已有資料1011564.html
# 已有資料1011578.html
# 已有資料10116.html
# 已有資料1011632.html
# 已有資料1011650.html
# 已有資料1011664.html
# 已有資料1011674.html
# 已有資料1011676.html
# 已有資料1011712.html
# 已有資料1011730.html
# 已有資料1011732.html
# 已有資料1011798.html
# 已有資料1011804.html
# 已有資料1011812.html
# 已有資料1011814.html
# 已有資料1011822.html
# 已有資料1011840.html
# 已有資料1011848.html
# 已有資料1011858.html
# 已有資料1011860.html
# 已有資料1011864.html
# 已有資料1011876.html
# 已有資料1011894.html
# 已有資料10119.html
# 已有資料1011910.html
# 已有資料1011916.html
# 已有資料1011930.html
# 已有資料1011934.html
# 已有資料1011944.html
# 已有資料1011950.html
# 已有資料1011962.html
# 已有資料1011964.html
# 已有資料1011966.html
# 已有資料10120.html
# 已有資料1012018.html
# 已有資料1012046.html
# 已有資料1012052.html
# 已有資料1012072.html
# 已有資料1012086.html
# 已有資料1012090.html
# 已有資料1012092.html
# 已有資料1012100.html
# 已有資料1012132.html
# 已有資料1012148.html
# 已有資料1012156.html
# 已有資料1012160.html
# 已有資料1012170.html
# 已有資料1012182.html
# 已有資料101219.html
# 已有資料1012214.html
# 已有資料101222.html
# 已有資料1012222.html
# 已有資料1012224.html
# 已有資料1012228.html
# 已有資料1012234.html
# 已有資料1012236.html
# 已有資料1012242.html
# 已有資料1012252.html
# 已有資料1012254.html
# 已有資料1012266.html
# 已有資料1012278.html
# 已有資料1012282.html
# 已有資料1012292.html
# 已有資料1012296.html
# 已有資料101231.html
# 已有資料1012316.html
# 已有資料1012338.html
# 已有資料101234.html
# 已有資料101235.html
# 已有資料1012370.html
# 已有資料1012384.html
# 已有資料1012388.html
# 已有資料1012390.html
# 已有資料1012402.html
# 已有資料1012404.html
# 已有資料1012420.html
# 已有資料1012436.html
# 已有資料1012446.html
# 已有資料1012452.html
# 已有資料1012462.html
# 已有資料1012466.html
# 已有資料1012474.html
# 已有資料101248.html
# 已有資料1012484.html
# 已有資料1012488.html
# 已有資料1012496.html
# 已有資料1012506.html
# 已有資料1012540.html
# 已有資料1012544.html
# 已有資料1012546.html
# 已有資料1012566.html
# 已有資料1012578.html
# 已有資料1012584.html
# 已有資料1012596.html
# 已有資料1012598.html
# 已有資料1012600.html
# 已有資料101261.html
# 已有資料1012610.html
# 已有資料1012640.html
# 已有資料1012654.html
# 已有資料101268.html
# 已有資料1012680.html
# 已有資料1012688.html
# 已有資料101269.html
# 已有資料1012692.html
# 已有資料1012706.html
# 已有資料1012724.html
# 已有資料101273.html
# 已有資料1012746.html
# 已有資料1012788.html
# 已有資料1012798.html
# 已有資料1012804.html
# 已有資料1012826.html
# 已有資料1012854.html
# 已有資料1012856.html
# 已有資料1012876.html
# 已有資料1012878.html
# 已有資料1012886.html
# 已有資料1012898.html
# 已有資料1012904.html
# 已有資料1012970.html
# 已有資料1012974.html
# 已有資料1012978.html
# 已有資料1012990.html
# 已有資料1013016.html
# 已有資料1013030.html
# 已有資料1013032.html
# 已有資料1013036.html
# 已有資料1013044.html
# 已有資料1013070.html
# 已有資料1013100.html
# 已有資料1013114.html
# 已有資料1013122.html
# 已有資料1013138.html
# 已有資料1013150.html
# 已有資料1013180.html
# 已有資料1013204.html
# 已有資料1013212.html
# 已有資料1013216.html
# 已有資料1013222.html
# 已有資料1013232.html
# 已有資料1013236.html
# 已有資料1013250.html
# 已有資料1013256.html
# 已有資料1013262.html
# 已有資料1013272.html
# 已有資料1013282.html
# 已有資料1013292.html
# 已有資料1013296.html
# 已有資料1013316.html
# 已有資料1013324.html
# 已有資料1013340.html
# 已有資料1013346.html
# 已有資料1013368.html
# 已有資料1013396.html
# 已有資料1013402.html
# 已有資料1013404.html
# 已有資料1013422.html
# 已有資料1013424.html
# 已有資料1013458.html
# 已有資料1013472.html
# 已有資料1013496.html
# 已有資料1013502.html
# 已有資料1013524.html
# 已有資料1013532.html
# 已有資料1013572.html
# 已有資料1013576.html
# 已有資料1013624.html
# 已有資料1013626.html
# 已有資料1013630.html
# 已有資料1013638.html
# 已有資料1013640.html
# 已有資料1013676.html
# 已有資料1013686.html
# 已有資料1013688.html
# 已有資料1013728.html
# 已有資料1013736.html
# 已有資料1013746.html
# 已有資料1013752.html
# 已有資料1013778.html
# 已有資料1013782.html
# 已有資料1013784.html
# 已有資料1013788.html
# 已有資料1013814.html
# 已有資料1013828.html
# 已有資料1013864.html
# 已有資料1013868.html
# 已有資料1013870.html
# 已有資料1013874.html
# 已有資料1013890.html
# 已有資料1013892.html
# 已有資料1013894.html
# 已有資料1013910.html
# 已有資料1013958.html
# 已有資料1013964.html
# 已有資料1013970.html
# 已有資料1014010.html
# 已有資料1014026.html
# 已有資料1014030.html
# 已有資料1014046.html
# 已有資料1014048.html
# 已有資料1014066.html
# 已有資料1014070.html
# 已有資料1014080.html
# 已有資料1014098.html
# 已有資料1014102.html
# 已有資料1014134.html
# 已有資料1014148.html
# 已有資料1014154.html
# 已有資料1014166.html
# 已有資料1014168.html
# 已有資料1014182.html
# 已有資料1014196.html
# 已有資料1014204.html
# 已有資料1014206.html
# 已有資料101421.html
# 已有資料1014210.html
# 已有資料1014214.html
# 已有資料1014218.html
# 已有資料1014228.html
# 已有資料1014238.html
# 已有資料1014244.html
# 已有資料1014258.html
# 已有資料1014314.html
# 已有資料1014320.html
# 已有資料1014330.html
# 已有資料1014344.html
# 已有資料101436.html
# 已有資料1014384.html
# 已有資料1014386.html
# 已有資料1014390.html
# 已有資料1014404.html
# 已有資料1014412.html
# 已有資料1014438.html
# 已有資料1014440.html
# 已有資料101445.html
# 已有資料101446.html
# 已有資料1014472.html
# 已有資料1014474.html
# 已有資料1014476.html
# 已有資料1014496.html
# 已有資料1014500.html
# 已有資料1014516.html
# 已有資料1014520.html
# 已有資料1014532.html
# 已有資料1014540.html
# 已有資料1014562.html
# 已有資料101458.html
# 已有資料1014582.html
# 已有資料101459.html
# 已有資料1014590.html
# 已有資料1014596.html
# 已有資料1014600.html
# 已有資料1014608.html
# 已有資料1014614.html
# 已有資料1014624.html
# 已有資料1014626.html
# 已有資料1014632.html
# 已有資料1014646.html
# 已有資料1014686.html
# 已有資料10147.html
# 已有資料1014700.html
# 已有資料1014702.html
# 已有資料1014712.html
# 已有資料1014718.html
# 已有資料1014728.html
# 已有資料1014732.html
# 已有資料1014734.html
# 已有資料1014738.html
# 已有資料1014744.html
# 已有資料1014746.html
# 已有資料1014758.html
# 已有資料1014760.html
# 已有資料1014766.html
# 已有資料1014778.html
# 已有資料1014788.html
# 已有資料1014800.html
# 已有資料1014810.html
# 已有資料1014814.html
# 已有資料1014824.html
# 已有資料1014830.html
# 已有資料1014836.html
# 已有資料1014860.html
# 已有資料1014892.html
# 已有資料1014894.html
# 已有資料1014898.html
# 已有資料1014910.html
# 已有資料1014934.html
# 已有資料1014948.html
# 已有資料1014960.html
# 已有資料1014964.html
# 已有資料1015002.html
# 已有資料1015008.html
# 已有資料1015026.html
# 已有資料1015032.html
# 已有資料1015078.html
# 已有資料1015086.html
# 已有資料1015116.html
# 已有資料1015132.html
# 已有資料1015152.html
# 已有資料1015158.html
# 已有資料1015174.html
# 已有資料1015182.html
# 已有資料1015184.html
# 已有資料1015196.html
# 已有資料1015238.html
# 已有資料1015304.html
# 已有資料1015312.html
# 已有資料1015320.html
# 已有資料1015326.html
# 已有資料1015340.html
# 已有資料1015370.html
# 已有資料1015374.html
# 已有資料1015388.html
# 已有資料10154.html
# 已有資料1015408.html
# 已有資料1015420.html
# 已有資料1015426.html
# 已有資料1015428.html
# 已有資料1015432.html
# 已有資料1015434.html
# 已有資料1015438.html
# 已有資料1015466.html
# 已有資料1015508.html
# 已有資料1015516.html
# 已有資料1015520.html
# 已有資料1015522.html
# 已有資料1015542.html
# 已有資料1015544.html
# 已有資料1015546.html
# 已有資料1015550.html
# 已有資料1015552.html
# 已有資料1015564.html
# 已有資料1015574.html
# 已有資料1015584.html
# 已有資料1015592.html
# 已有資料1015594.html
# 已有資料1015608.html
# 已有資料1015640.html
# 已有資料1015662.html
# 已有資料1015664.html
# 已有資料1015672.html
# 已有資料1015676.html
# 已有資料1015718.html
# 已有資料1015720.html
# 已有資料1015728.html
# 已有資料1015738.html
# 已有資料1015742.html
# 已有資料1015746.html
# 已有資料1015750.html
# 已有資料1015754.html
# 已有資料1015784.html
# 已有資料101579.html
# 已有資料1015794.html
# 已有資料1015806.html
# 已有資料1015822.html
# 已有資料1015832.html
# 已有資料1015862.html
# 已有資料1015880.html
# 已有資料1015888.html
# 已有資料1015898.html
# 已有資料1015902.html
# 已有資料1015920.html
# 已有資料1015922.html
# 已有資料1015932.html
# 已有資料1015936.html
# 已有資料1015968.html
# 已有資料101597.html
# 已有資料1015982.html
# 已有資料1016008.html
# 已有資料1016012.html
# 已有資料1016032.html
# 已有資料1016042.html
# 已有資料1016046.html
# 已有資料1016050.html
# 已有資料1016072.html
# 已有資料1016076.html
# 已有資料1016082.html
# 已有資料1016086.html
# 已有資料101609.html
# 已有資料1016098.html
# 已有資料1016110.html
# 已有資料1016114.html
# 已有資料1016122.html
# 已有資料1016128.html
# 已有資料1016134.html
# 已有資料1016136.html
# 已有資料1016146.html
# 已有資料1016160.html
# 已有資料1016170.html
# 已有資料1016184.html
# 已有資料1016186.html
# 已有資料1016200.html
# 已有資料1016204.html
# 已有資料1016226.html
# 已有資料1016230.html
# 已有資料1016236.html
# 已有資料1016242.html
# 已有資料1016260.html
# 已有資料1016274.html
# 已有資料1016278.html
# 已有資料1016288.html
# 已有資料1016292.html
# 已有資料1016310.html
# 已有資料1016312.html
# 已有資料1016324.html
# 已有資料1016328.html
# 已有資料1016334.html
# 已有資料1016350.html
# 已有資料1016356.html
# 已有資料1016362.html
# 已有資料1016374.html
# 已有資料1016400.html
# 已有資料1016408.html
# 已有資料101641.html
# 已有資料1016416.html
# 已有資料1016418.html
# 已有資料1016420.html
# 已有資料1016422.html
# 已有資料1016426.html
# 已有資料101643.html
# 已有資料1016444.html
# 已有資料1016450.html
# 已有資料1016452.html
# 已有資料1016458.html
# 已有資料1016470.html
# 已有資料1016472.html
# 已有資料1016498.html
# 已有資料1016500.html
# 已有資料1016502.html
# 已有資料1016518.html
# 已有資料1016530.html
# 已有資料1016540.html
# 已有資料1016570.html
# 已有資料1016586.html
# 已有資料101659.html
# 已有資料1016590.html
# 已有資料1016608.html
# 已有資料1016654.html
# 已有資料1016662.html
# 已有資料1016668.html
# 已有資料1016680.html
# 已有資料1016682.html
# 已有資料101671.html
# 已有資料1016714.html
# 已有資料1016728.html
# 已有資料1016730.html
# 已有資料1016752.html
# 已有資料1016754.html
# 已有資料1016758.html
# 已有資料101676.html
# 已有資料1016760.html
# 已有資料1016764.html
# 已有資料1016768.html
# 已有資料1016794.html
# 已有資料1016798.html
# 已有資料10168.html
# 已有資料1016808.html
# 已有資料101681.html
# 已有資料1016820.html
# 已有資料1016834.html
# 已有資料1016846.html
# 已有資料1016856.html
# 已有資料1016872.html
# 已有資料1016880.html
# 已有資料1016888.html
# 已有資料1016890.html
# 已有資料1016914.html
# 已有資料1016920.html
# 已有資料1016922.html
# 已有資料1016928.html
# 已有資料101693.html
# 已有資料1016938.html
# 已有資料1016944.html
# 已有資料101695.html
# 已有資料1016954.html
# 已有資料1016976.html
# 已有資料101699.html
# 已有資料1016990.html
# 已有資料1017.html
# 已有資料1017006.html
# 已有資料1017018.html
# 已有資料1017022.html
# 已有資料101703.html
# 已有資料1017042.html
# 已有資料1017048.html
# 已有資料1017054.html
# 已有資料1017060.html
# 已有資料1017064.html
# 已有資料10171.html
# 已有資料1017114.html
# 已有資料1017116.html
# 已有資料1017122.html
# 已有資料1017142.html
# 已有資料1017146.html
# 已有資料1017156.html
# 已有資料1017176.html
# 已有資料1017178.html
# 已有資料1017184.html
# 已有資料1017214.html
# 已有資料1017232.html
# 已有資料1017240.html
# 已有資料1017280.html
# 已有資料1017288.html
# 已有資料1017300.html
# 已有資料1017302.html
# 已有資料1017328.html
# 已有資料1017336.html
# 已有資料1017348.html
# 已有資料1017352.html
# 已有資料1017354.html
# 已有資料1017378.html
# 已有資料1017382.html
# 已有資料1017384.html
# 已有資料1017392.html
# 已有資料1017396.html
# 已有資料1017400.html
# 已有資料1017410.html
# 已有資料1017424.html
# 已有資料1017426.html
# 已有資料1017428.html
# 已有資料1017432.html
# 已有資料1017438.html
# 已有資料1017444.html
# 已有資料1017448.html
# 已有資料1017472.html
# 已有資料1017488.html
# 已有資料1017492.html
# 已有資料1017498.html
# 已有資料1017510.html
# 已有資料1017536.html
# 已有資料1017544.html
# 已有資料1017558.html
# 已有資料1017566.html
# 已有資料1017574.html
# 已有資料1017576.html
# 已有資料1017592.html
# 已有資料1017596.html
# 已有資料1017598.html
# 已有資料1017616.html
# 已有資料1017628.html
# 已有資料1017630.html
# 已有資料1017638.html
# 已有資料1017646.html
# 已有資料1017654.html
# 已有資料1017664.html
# 已有資料1017670.html
# 已有資料1017686.html
# 已有資料1017688.html
# 已有資料1017698.html
# 已有資料1017702.html
# 已有資料1017716.html
# 已有資料1017722.html
# 已有資料1017724.html
# 已有資料1017732.html
# 已有資料1017748.html
# 已有資料1017796.html
# 已有資料10178.html
# 已有資料1017806.html
# 已有資料1017820.html
# 已有資料1017822.html
# 已有資料1017826.html
# 已有資料1017862.html
# 已有資料10179.html
# 已有資料1017918.html
# 已有資料1017924.html
# 已有資料1017938.html
# 已有資料1017942.html
# 已有資料1017962.html
# 已有資料1017968.html
# 已有資料1017978.html
# 已有資料1017982.html
# 已有資料1017988.html
# 已有資料101800.html
# 已有資料1018004.html
# 已有資料1018016.html
# 已有資料1018022.html
# 已有資料1018024.html
# 已有資料101803.html
# 已有資料1018032.html
# 已有資料1018034.html
# 已有資料1018036.html
# 已有資料1018038.html
# 已有資料1018058.html
# 已有資料1018070.html
# 已有資料1018072.html
# 已有資料1018078.html
# 已有資料1018082.html
# 已有資料101809.html
# 已有資料1018122.html
# 已有資料1018128.html
# 已有資料101813.html
# 已有資料101814.html
# 已有資料1018144.html
# 已有資料1018202.html
# 已有資料1018226.html
# 已有資料1018230.html
# 已有資料1018240.html
# 已有資料1018260.html
# 已有資料1018272.html
# 已有資料1018300.html
# 已有資料1018312.html
# 已有資料1018316.html
# 已有資料1018320.html
# 已有資料101834.html
# 已有資料1018350.html
# 已有資料1018366.html
# 已有資料1018370.html
# 已有資料1018390.html
# 已有資料1018412.html
# 已有資料1018438.html
# 已有資料101844.html
# 已有資料1018444.html
# 已有資料1018450.html
# 已有資料1018452.html
# 已有資料1018454.html
# 已有資料1018480.html
# 已有資料1018482.html
# 已有資料101849.html
# 已有資料1018494.html
# 已有資料1018502.html
# 已有資料101851.html
# 已有資料1018516.html
# 已有資料1018518.html
# 已有資料1018524.html
# 已有資料1018538.html
# 已有資料101855.html
# 已有資料1018560.html
# 已有資料1018574.html
# 已有資料1018586.html
# 已有資料1018590.html
# 已有資料1018612.html
# 已有資料1018622.html
# 已有資料1018626.html
# 已有資料1018640.html
# 已有資料1018648.html
# 已有資料1018658.html
# 已有資料1018670.html
# 已有資料1018696.html
# 已有資料1018702.html
# 已有資料1018704.html
# 已有資料1018728.html
# 已有資料1018748.html
# 已有資料1018750.html
# 已有資料1018756.html
# 已有資料1018824.html
# 已有資料1018836.html
# 已有資料1018856.html
# 已有資料1018858.html
# 已有資料1018860.html
# 已有資料1018862.html
# 已有資料1018868.html
# 已有資料1018876.html
# 已有資料1018906.html
# 已有資料1018924.html
# 已有資料1018940.html
# 已有資料1018958.html
# 已有資料1018964.html
# 已有資料1018974.html
# 已有資料1018994.html
# 已有資料1018996.html
# 已有資料1019024.html
# 已有資料1019028.html
# 已有資料1019040.html
# 已有資料1019060.html
# 已有資料1019062.html
# 已有資料1019070.html
# 已有資料1019076.html
# 已有資料1019092.html
# 已有資料1019096.html
# 已有資料1019098.html
# 已有資料1019100.html
# 已有資料1019132.html
# 已有資料1019148.html
# 已有資料1019162.html
# 已有資料1019184.html
# 已有資料1019186.html
# 已有資料1019190.html
# 已有資料1019198.html
# 已有資料1019200.html
# 已有資料1019216.html
# 已有資料1019224.html
# 已有資料1019242.html
# 已有資料1019246.html
# 已有資料1019250.html
# 已有資料1019252.html
# 已有資料1019254.html
# 已有資料1019266.html
# 已有資料1019272.html
# 已有資料1019292.html
# 已有資料1019296.html
# 已有資料1019326.html
# 已有資料1019336.html
# 已有資料1019350.html
# 已有資料1019354.html
# 已有資料1019358.html
# 已有資料1019364.html
# 已有資料1019366.html
# 已有資料1019372.html
# 已有資料1019380.html
# 已有資料10194.html
# 已有資料1019430.html
# 已有資料1019446.html
# 已有資料1019452.html
# 已有資料1019456.html
# 已有資料1019460.html
# 已有資料1019480.html
# 已有資料1019490.html
# 已有資料1019496.html
# 已有資料10195.html
# 已有資料1019512.html
# 已有資料1019526.html
# 已有資料1019530.html
# 已有資料1019532.html
# 已有資料1019540.html
# 已有資料1019566.html
# 已有資料1019608.html
# 已有資料1019616.html
# 已有資料1019622.html
# 已有資料1019634.html
# 已有資料1019640.html
# 已有資料1019652.html
# 已有資料1019666.html
# 已有資料1019688.html
# 已有資料1019698.html
# 已有資料1019708.html
# 已有資料1019710.html
# 已有資料1019732.html
# 已有資料101978.html
# 已有資料1019780.html
# 已有資料1019790.html
# 已有資料1019792.html
# 已有資料1019804.html
# 已有資料101981.html
# 已有資料1019834.html
# 已有資料1019842.html
# 已有資料1019854.html
# 已有資料1019862.html
# 已有資料1019884.html
# 已有資料1019896.html
# 已有資料1019902.html
# 已有資料1019904.html
# 已有資料1019932.html
# 已有資料101994.html
# 已有資料1019946.html
# 已有資料101995.html
# 已有資料1019966.html
# 已有資料1019972.html
# 已有資料1019980.html
# 已有資料1019986.html
# 已有資料1019992.html
# 已有資料1020014.html
# 已有資料1020026.html
# 已有資料1020036.html
# 已有資料1020040.html
# 已有資料1020042.html
# 已有資料1020058.html
# 已有資料1020060.html
# 已有資料1020064.html
# 已有資料1020070.html
# 已有資料1020080.html
# 已有資料1020110.html
# 已有資料1020118.html
# 已有資料1020120.html
# 已有資料1020122.html
# 已有資料1020126.html
# 已有資料1020130.html
# 已有資料1020140.html
# 已有資料1020142.html
# 已有資料1020146.html
# 已有資料1020148.html
# 已有資料1020152.html
# 已有資料102017.html
# 已有資料1020172.html
# 已有資料1020182.html
# 已有資料1020192.html
# 已有資料1020194.html
# 已有資料1020198.html
# 已有資料1020200.html
# 已有資料1020208.html
# 已有資料102022.html
# 已有資料102023.html
# 已有資料102025.html
# 已有資料1020282.html
# 已有資料1020292.html
# 已有資料1020310.html
# 已有資料1020328.html
# 已有資料1020334.html
# 已有資料1020336.html
# 已有資料1020340.html
# 已有資料1020372.html
# 已有資料1020376.html
# 已有資料1020382.html
# 已有資料1020402.html
# 已有資料1020420.html
# 已有資料1020438.html
# 已有資料1020446.html
# 已有資料1020448.html
# 已有資料1020460.html
# 已有資料1020462.html
# 已有資料1020470.html
# 已有資料1020472.html
# 已有資料1020498.html
# 已有資料1020506.html
# 已有資料1020580.html
# 已有資料1020590.html
# 已有資料1020618.html
# 已有資料1020646.html
# 已有資料1020650.html
# 已有資料1020692.html
# 已有資料1020720.html
# 已有資料1020726.html
# 已有資料1020738.html
# 已有資料1020764.html
# 已有資料1020768.html
# 已有資料1020774.html
# 已有資料1020816.html
# 已有資料1020846.html
# 已有資料1020858.html
# 已有資料1020864.html
# 已有資料1020876.html
# 已有資料1020892.html
# 已有資料1020894.html
# 已有資料1020896.html
# 已有資料1020940.html
# 已有資料1020990.html
# 已有資料1020994.html
# 已有資料1020996.html
# 已有資料1021002.html
# 已有資料1021012.html
# 已有資料1021024.html
# 已有資料1021028.html
# 已有資料1021064.html
# 已有資料1021070.html
# 已有資料1021080.html
# 已有資料1021126.html
# 已有資料1021142.html
# 已有資料1021146.html
# 已有資料1021150.html
# 已有資料1021152.html
# 已有資料1021184.html
# 已有資料10212.html
# 已有資料1021220.html
# 已有資料1021224.html
# 已有資料1021252.html
# 已有資料1021260.html
# 已有資料1021268.html
# 已有資料1021274.html
# 已有資料1021276.html
# 已有資料1021278.html
# 已有資料1021302.html
# 已有資料1021306.html
# 已有資料1021310.html
# 已有資料102132.html
# 已有資料1021332.html
# 已有資料1021340.html
# 已有資料1021372.html
# 已有資料1021380.html
# 已有資料1021412.html
# 已有資料1021424.html
# 已有資料1021450.html
# 已有資料1021458.html
# 已有資料1021480.html
# 已有資料1021484.html
# 已有資料102150.html
# 已有資料1021500.html
# 已有資料1021508.html
# 已有資料1021510.html
# 已有資料1021538.html
# 已有資料1021544.html
# 已有資料1021578.html
# 已有資料102158.html
# 已有資料1021582.html
# 已有資料10216.html
# 已有資料1021604.html
# 已有資料102164.html
# 已有資料1021642.html
# 已有資料1021652.html
# 已有資料1021668.html
# 已有資料1021674.html
# 已有資料1021678.html
# 已有資料102168.html
# 已有資料1021684.html
# 已有資料1021696.html
# 已有資料1021726.html
# 已有資料1021736.html
# 已有資料1021740.html
# 已有資料1021748.html
# 已有資料1021750.html
# 已有資料1021752.html
# 已有資料1021754.html
# 已有資料1021764.html
# 已有資料1021794.html
# 已有資料1021800.html
# 已有資料1021802.html
# 已有資料1021810.html
# 已有資料1021816.html
# 已有資料1021830.html
# 已有資料1021840.html
# 已有資料1021848.html
# 已有資料102186.html
# 已有資料1021872.html
# 已有資料1021878.html
# 已有資料1021900.html
# 已有資料1021902.html
# 已有資料1021904.html
# 已有資料1021924.html
# 已有資料102195.html
# 已有資料1021966.html
# 已有資料1021972.html
# 已有資料1021990.html
# 已有資料1022006.html
# 已有資料1022050.html
# 已有資料1022052.html
# 已有資料1022054.html
# 已有資料1022066.html
# 已有資料1022072.html
# 已有資料1022074.html
# 已有資料1022094.html
# 已有資料1022100.html
# 已有資料1022106.html
# 已有資料1022112.html
# 已有資料1022122.html
# 已有資料1022130.html
# 已有資料1022170.html
# 已有資料1022172.html
# 已有資料1022184.html
# 已有資料1022190.html
# 已有資料1022192.html
# 已有資料1022212.html
# 已有資料1022218.html
# 已有資料1022234.html
# 已有資料1022260.html
# 已有資料1022264.html
# 已有資料1022270.html
# 已有資料1022278.html
# 已有資料1022282.html
# 已有資料1022300.html
# 已有資料1022306.html
# 已有資料1022320.html
# 已有資料1022328.html
# 已有資料1022334.html
# 已有資料1022340.html
# 已有資料1022342.html
# 已有資料1022352.html
# 已有資料1022356.html
# 已有資料1022364.html
# 已有資料1022408.html
# 已有資料1022414.html
# 已有資料1022416.html
# 已有資料1022422.html
# 已有資料1022442.html
# 已有資料1022460.html
# 已有資料1022486.html
# 已有資料1022504.html
# 已有資料1022530.html
# 已有資料1022536.html
# 已有資料1022546.html
# 已有資料1022552.html
# 已有資料1022554.html
# 已有資料1022558.html
# 已有資料1022566.html
# 已有資料1022576.html
# 已有資料1022588.html
# 已有資料1022604.html
# 已有資料1022626.html
# 已有資料1022646.html
# 已有資料1022670.html
# 已有資料102268.html
# 已有資料1022680.html
# 已有資料1022686.html
# 已有資料1022702.html
# 已有資料1022710.html
# 已有資料1022718.html
# 已有資料1022736.html
# 已有資料1022740.html
# 已有資料1022742.html
# 已有資料1022750.html
# 已有資料1022752.html
# 已有資料1022766.html
# 已有資料1022782.html
# 已有資料1022856.html
# 已有資料1022888.html
# 已有資料1022920.html
# 已有資料1022930.html
# 已有資料1022934.html
# 已有資料1022942.html
# 已有資料1022944.html
# 已有資料1022946.html
# 已有資料1022948.html
# 已有資料1022996.html
# 已有資料1022998.html
# 已有資料1023012.html
# 已有資料1023014.html
# 已有資料1023050.html
# 已有資料1023090.html
# 已有資料1023094.html
# 已有資料1023110.html
# 已有資料1023150.html
# 已有資料1023160.html
# 已有資料1023174.html
# 已有資料1023176.html
# 已有資料1023196.html
# 已有資料1023210.html
# 已有資料1023230.html
# 已有資料1023242.html
# 已有資料1023246.html
# 已有資料1023256.html
# 已有資料1023266.html
# 已有資料1023274.html
# 已有資料1023276.html
# 已有資料1023278.html
# 已有資料102328.html
# 已有資料1023324.html
# 已有資料1023326.html
# 已有資料1023328.html
# 已有資料102333.html
# 已有資料102334.html
# 已有資料1023340.html
# 已有資料1023348.html
# 已有資料102336.html
# 已有資料1023362.html
# 已存35650筆資料
# 已有資料1023406.html
# 已有資料1023434.html
# 已有資料1023456.html
# 已有資料1023458.html
# 已有資料1023462.html
# 已有資料1023470.html
# 已有資料102348.html
# 已有資料1023482.html
# 已有資料1023488.html
# 已有資料1023504.html
# 已有資料1023512.html
# 已有資料1023516.html
# 已有資料1023522.html
# 已有資料1023524.html
# 已有資料1023534.html
# 已有資料1023548.html
# 已有資料102356.html
# 已有資料1023562.html
# 已有資料1023570.html
# 已有資料1023572.html
# 已有資料1023602.html
# 已有資料1023604.html
# 已有資料1023610.html
# 已有資料1023618.html
# 已有資料1023622.html
# 已有資料1023640.html
# 已有資料1023642.html
# 已有資料1023654.html
# 已有資料1023658.html
# 已有資料1023662.html
# 已有資料1023680.html
# 已有資料1023688.html
# 已有資料1023714.html
# 已有資料1023720.html
# 已有資料1023732.html
# 已有資料1023740.html
# 已有資料1023770.html
# 已有資料1023778.html
# 已有資料1023780.html
# 已有資料1023792.html
# 已有資料1023804.html
# 已有資料1023806.html
# 已有資料1023810.html
# 已有資料1023820.html
# 已有資料1023838.html
# 已有資料1023840.html
# 已有資料1023842.html
# 已有資料1023846.html
# 已有資料1023882.html
# 已有資料1023892.html
# 已有資料1023900.html
# 已有資料1023928.html
# 已有資料1023936.html
# 已有資料1023948.html
# 已有資料1023958.html
# 已有資料1023978.html
# 已有資料1023980.html
# 已有資料1023988.html
# 已有資料1024000.html
# 已有資料1024008.html
# 已有資料1024022.html
# 已有資料1024040.html
# 已有資料1024076.html
# 已有資料1024080.html
# 已有資料1024096.html
# 已有資料1024114.html
# 已有資料1024174.html
# 已有資料1024176.html
# 已有資料1024178.html
# 已有資料1024190.html
# 已有資料1024212.html
# 已有資料1024220.html
# 已有資料1024252.html
# 已有資料1024254.html
# 已有資料1024266.html
# 已有資料1024276.html
# 已有資料1024278.html
# 已有資料1024286.html
# 已有資料1024294.html
# 已有資料1024302.html
# 已有資料1024310.html
# 已有資料1024318.html
# 已有資料1024322.html
# 已有資料1024344.html
# 已有資料1024352.html
# 已有資料1024372.html
# 已有資料1024380.html
# 已有資料1024382.html
# 已有資料1024398.html
# 已有資料1024404.html
# 已有資料1024406.html
# 已有資料1024412.html
# 已有資料1024420.html
# 已有資料1024426.html
# 已有資料1024428.html
# 已有資料1024440.html
# 已有資料1024446.html
# 已有資料1024486.html
# 已有資料102450.html
# 已有資料1024504.html
# 已有資料1024526.html
# 已有資料1024552.html
# 已有資料1024564.html
# 已有資料1024582.html
# 已有資料1024608.html
# 已有資料1024610.html
# 已有資料1024614.html
# 已有資料1024618.html
# 已有資料1024628.html
# 已有資料1024636.html
# 已有資料1024642.html
# 已有資料1024650.html
# 已有資料1024652.html
# 已有資料1024654.html
# 已有資料1024656.html
# 已有資料1024662.html
# 已有資料1024676.html
# 已有資料1024684.html
# 已有資料1024690.html
# 已有資料1024692.html
# 已有資料1024696.html
# 已有資料1024720.html
# 已有資料1024722.html
# 已有資料1024734.html
# 已有資料1024738.html
# 已有資料1024744.html
# 已有資料1024746.html
# 已有資料1024770.html
# 已有資料1024774.html
# 已有資料1024798.html
# 已有資料1024802.html
# 已有資料102481.html
# 已有資料1024830.html
# 已有資料1024842.html
# 已有資料1024882.html
# 已有資料1024898.html
# 已有資料1024920.html
# 已有資料1024924.html
# 已有資料1024948.html
# 已有資料1025026.html
# 已有資料1025036.html
# 已有資料1025042.html
# 已有資料1025050.html
# 已有資料1025066.html
# 已有資料1025072.html
# 已有資料1025074.html
# 已有資料1025076.html
# 已有資料1025078.html
# 已有資料1025104.html
# 已有資料1025126.html
# 已有資料1025128.html
# 已有資料1025138.html
# 已有資料1025142.html
# 已有資料1025146.html
# 已有資料1025148.html
# 已有資料1025154.html
# 已有資料1025162.html
# 已有資料1025180.html
# 已有資料1025196.html
# 已有資料1025202.html
# 已有資料102523.html
# 已有資料1025234.html
# 已有資料102524.html
# 已有資料1025258.html
# 已有資料1025272.html
# 已有資料1025288.html
# 已有資料1025298.html
# 已有資料1025308.html
# 已有資料1025310.html
# 已有資料1025318.html
# 已有資料1025366.html
# 已有資料1025400.html
# 已有資料1025402.html
# 已有資料1025406.html
# 已有資料1025408.html
# 已有資料1025416.html
# 已有資料1025420.html
# 已有資料1025440.html
# 已有資料1025442.html
# 已有資料102545.html
# 已有資料1025452.html
# 已有資料1025468.html
# 已有資料1025474.html
# 已有資料102549.html
# 已有資料1025496.html
# 已有資料102551.html
# 已有資料1025534.html
# 已有資料1025542.html
# 已有資料1025546.html
# 已有資料1025548.html
# 已有資料102556.html
# 已有資料1025564.html
# 已有資料1025570.html
# 已有資料1025580.html
# 已有資料1025588.html
# 已有資料1025592.html
# 已有資料1025640.html
# 已有資料1025684.html
# 已有資料1025690.html
# 已有資料1025698.html
# 已有資料1025712.html
# 已有資料1025738.html
# 已有資料1025758.html
# 已有資料1025760.html
# 已有資料1025762.html
# 已有資料1025778.html
# 已有資料1025780.html
# 已有資料1025784.html
# 已有資料1025796.html
# 已有資料1025806.html
# 已有資料1025808.html
# 已有資料1025812.html
# 已有資料1025816.html
# 已有資料102583.html
# 已有資料1025832.html
# 已有資料1025846.html
# 已有資料1025852.html
# 已有資料1025872.html
# 已有資料1025880.html
# 已有資料1025892.html
# 已有資料1025908.html
# 已有資料102592.html
# 已有資料1025938.html
# 已有資料1025946.html
# 已有資料1025996.html
# 已有資料102600.html
# 已有資料1026000.html
# 已有資料1026002.html
# 已有資料1026008.html
# 已有資料1026012.html
# 已有資料1026020.html
# 已有資料1026032.html
# 已有資料1026050.html
# 已有資料1026060.html
# 已有資料1026062.html
# 已有資料102607.html
# 已有資料1026072.html
# 已有資料1026080.html
# 已有資料1026088.html
# 已有資料102609.html
# 已有資料1026100.html
# 已有資料1026130.html
# 已有資料1026146.html
# 已有資料1026174.html
# 已有資料102618.html
# 已有資料1026184.html
# 已有資料10262.html
# 已有資料1026232.html
# 已有資料1026234.html
# 已有資料1026238.html
# 已有資料1026244.html
# 已有資料1026272.html
# 已有資料1026278.html
# 已有資料1026280.html
# 已有資料1026300.html
# 已有資料1026304.html
# 已有資料1026320.html
# 已有資料1026326.html
# 已有資料1026330.html
# 已有資料1026342.html
# 已有資料1026372.html
# 已有資料1026376.html
# 已有資料1026380.html
# 已有資料1026400.html
# 已有資料1026414.html
# 已有資料1026430.html
# 已有資料1026436.html
# 已有資料1026440.html
# 已有資料1026466.html
# 已有資料1026468.html
# 已有資料1026488.html
# 已有資料1026498.html
# 已有資料1026500.html
# 已有資料1026512.html
# 已有資料1026526.html
# 已有資料1026530.html
# 已有資料1026532.html
# 已有資料1026534.html
# 已有資料1026546.html
# 已有資料1026564.html
# 已有資料1026576.html
# 已有資料1026578.html
# 已有資料1026580.html
# 已有資料10266.html
# 已有資料1026602.html
# 已有資料1026658.html
# 已有資料1026690.html
# 已有資料1026694.html
# 已有資料1026698.html
# 已有資料1026704.html
# 已有資料1026716.html
# 已有資料1026726.html
# 已有資料1026772.html
# 已有資料102678.html
# 已有資料1026798.html
# 已有資料1026802.html
# 已有資料1026818.html
# 已有資料1026842.html
# 已有資料1026882.html
# 已有資料102689.html
# 已有資料1026890.html
# 已有資料1026910.html
# 已有資料1026916.html
# 已有資料102692.html
# 已有資料1026920.html
# 已有資料1026942.html
# 已有資料1026968.html
# 已有資料1026970.html
# 已有資料1026976.html
# 已有資料1026980.html
# 已有資料1026988.html
# 已有資料1026990.html
# 已有資料1026994.html
# 已有資料1027002.html
# 已有資料102701.html
# 已有資料1027024.html
# 已有資料1027030.html
# 已有資料1027048.html
# 已有資料1027064.html
# 已有資料1027070.html
# 已有資料1027102.html
# 已有資料1027104.html
# 已有資料1027108.html
# 已有資料1027112.html
# 已有資料1027122.html
# 已有資料1027124.html
# 已有資料1027144.html
# 已有資料1027148.html
# 已有資料102715.html
# 已有資料1027162.html
# 已有資料1027176.html
# 已有資料1027188.html
# 已有資料1027190.html
# 已有資料1027192.html
# 已有資料1027194.html
# 已有資料1027198.html
# 已有資料102721.html
# 已有資料102722.html
# 已有資料1027228.html
# 已有資料1027250.html
# 已有資料1027290.html
# 已有資料1027292.html
# 已有資料1027294.html
# 已有資料1027298.html
# 已有資料10273.html
# 已有資料1027306.html
# 已有資料1027308.html
# 已有資料1027310.html
# 已有資料1027320.html
# 已有資料1027338.html
# 已有資料1027344.html
# 已有資料1027346.html
# 已有資料1027350.html
# 已有資料1027352.html
# 已有資料1027354.html
# 已有資料1027370.html
# 已有資料1027408.html
# 已有資料1027412.html
# 已有資料1027426.html
# 已有資料1027436.html
# 已有資料1027454.html
# 已有資料1027464.html
# 已有資料1027470.html
# 已有資料1027478.html
# 已有資料1027482.html
# 已有資料1027496.html
# 已有資料1027514.html
# 已有資料1027518.html
# 已有資料1027522.html
# 已有資料1027528.html
# 已有資料1027550.html
# 已有資料1027552.html
# 已有資料1027564.html
# 已有資料1027588.html
# 已有資料1027600.html
# 已有資料1027602.html
# 已有資料1027610.html
# 已有資料1027620.html
# 已有資料1027686.html
# 已有資料1027702.html
# 已有資料1027706.html
# 已有資料1027708.html
# 已有資料1027714.html
# 已有資料1027732.html
# 已有資料1027742.html
# 已有資料1027766.html
# 已有資料1027778.html
# 已有資料1027818.html
# 已有資料1027828.html
# 已有資料1027832.html
# 已有資料1027836.html
# 已有資料1027860.html
# 已有資料1027862.html
# 已有資料1027872.html
# 已有資料1027882.html
# 已有資料1027912.html
# 已有資料1027920.html
# 已有資料1027932.html
# 已有資料1027936.html
# 已有資料1027942.html
# 已有資料1027950.html
# 已有資料1027970.html
# 已有資料1027980.html
# 已有資料1027982.html
# 已有資料1028002.html
# 已有資料1028008.html
# 已有資料1028010.html
# 已有資料1028036.html
# 已有資料1028044.html
# 已有資料1028054.html
# 已有資料1028056.html
# 已有資料1028060.html
# 已有資料1028090.html
# 已有資料1028096.html
# 已有資料1028100.html
# 已有資料1028114.html
# 已有資料1028130.html
# 已有資料1028150.html
# 已有資料1028164.html
# 已有資料1028168.html
# 已有資料1028170.html
# 已有資料1028176.html
# 已有資料1028192.html
# 已有資料1028214.html
# 已有資料1028280.html
# 已有資料1028284.html
# 已有資料1028314.html
# 已有資料1028316.html
# 已有資料102832.html
# 已有資料1028320.html
# 已有資料1028328.html
# 已有資料1028332.html
# 已有資料1028378.html
# 已有資料1028402.html
# 已有資料1028426.html
# 已有資料1028430.html
# 已有資料1028448.html
# 已有資料1028472.html
# 已有資料1028480.html
# 已有資料1028500.html
# 已有資料1028502.html
# 已有資料1028518.html
# 已有資料1028534.html
# 已有資料1028556.html
# 已有資料1028560.html
# 已有資料1028590.html
# 已有資料1028614.html
# 已有資料1028618.html
# 已有資料1028628.html
# 已有資料1028644.html
# 已有資料1028646.html
# 已有資料1028650.html
# 已有資料1028652.html
# 已有資料102866.html
# 已有資料1028668.html
# 已有資料1028694.html
# 已有資料1028696.html
# 已有資料1028706.html
# 已有資料1028714.html
# 已有資料1028720.html
# 已有資料1028728.html
# 已有資料1028734.html
# 已有資料1028756.html
# 已有資料1028760.html
# 已有資料1028838.html
# 已有資料102884.html
# 已有資料1028842.html
# 已有資料1028854.html
# 已有資料1028858.html
# 已有資料1028876.html
# 已有資料1028896.html
# 已有資料1028904.html
# 已有資料1028912.html
# 已有資料1028922.html
# 已有資料1028926.html
# 已有資料1028940.html
# 已有資料1028944.html
# 已有資料102897.html
# 已有資料1028980.html
# 已有資料1028990.html
# 已有資料1028998.html
# 已有資料1029002.html
# 已有資料1029016.html
# 已有資料1029018.html
# 已有資料102902.html
# 已有資料1029020.html
# 已有資料1029038.html
# 已有資料1029050.html
# 已有資料102907.html
# 已有資料1029082.html
# 已有資料1029086.html
# 已有資料1029096.html
# 已有資料1029100.html
# 已有資料1029102.html
# 已有資料1029128.html
# 已有資料1029146.html
# 已有資料1029170.html
# 已有資料1029172.html
# 已有資料1029176.html
# 已有資料1029178.html
# 已有資料1029188.html
# 已有資料1029212.html
# 已有資料1029214.html
# 已有資料1029228.html
# 已有資料1029230.html
# 已有資料1029238.html
# 已有資料1029240.html
# 已有資料1029246.html
# 已有資料1029252.html
# 已有資料1029276.html
# 已有資料1029298.html
# 已有資料1029304.html
# 已有資料1029306.html
# 已有資料1029328.html
# 已有資料1029336.html
# 已有資料1029354.html
# 已有資料1029378.html
# 已有資料1029394.html
# 已有資料1029400.html
# 已有資料1029418.html
# 已有資料1029420.html
# 已有資料1029426.html
# 已有資料1029438.html
# 已有資料1029486.html
# 已有資料1029494.html
# 已有資料1029504.html
# 已有資料1029508.html
# 已有資料1029516.html
# 已有資料1029522.html
# 已有資料1029524.html
# 已有資料1029536.html
# 已有資料1029540.html
# 已有資料1029544.html
# 已有資料1029558.html
# 已有資料1029576.html
# 已有資料1029580.html
# 已有資料1029582.html
# 已有資料1029600.html
# 已有資料1029602.html
# 已有資料1029622.html
# 已有資料1029624.html
# 已有資料1029644.html
# 已有資料1029650.html
# 已有資料1029656.html
# 已有資料1029664.html
# 已有資料1029666.html
# 已有資料1029672.html
# 已有資料1029696.html
# 已有資料1029700.html
# 已有資料1029708.html
# 已有資料1029736.html
# 已有資料1029742.html
# 已有資料1029758.html
# 已有資料1029768.html
# 已有資料1029772.html
# 已有資料1029784.html
# 已有資料1029786.html
# 已有資料1029790.html
# 已有資料1029822.html
# 已有資料1029838.html
# 已有資料1029842.html
# 已有資料1029848.html
# 已有資料1029858.html
# 已有資料1029868.html
# 已有資料1029880.html
# 已有資料1029882.html
# 已有資料1029884.html
# 已有資料1029886.html
# 已有資料1029904.html
# 已有資料1029918.html
# 已有資料1029932.html
# 已有資料1029936.html
# 已有資料1029940.html
# 已有資料1029942.html
# 已有資料1029956.html
# 已有資料1029958.html
# 已有資料102997.html
# 已有資料1029974.html
# 已有資料1029980.html
# 已有資料1030.html
# 已有資料1030004.html
# 已有資料1030026.html
# 已有資料1030062.html
# 已有資料10301.html
# 已有資料1030106.html
# 已有資料1030128.html
# 已有資料1030158.html
# 已有資料103016.html
# 已有資料1030168.html
# 已有資料1030170.html
# 已有資料1030200.html
# 已有資料1030216.html
# 已有資料1030226.html
# 已有資料1030234.html
# 已有資料1030242.html
# 已有資料1030258.html
# 已有資料1030286.html
# 已有資料1030294.html
# 已有資料1030300.html
# 已有資料1030312.html
# 已有資料1030332.html
# 已有資料1030340.html
# 已有資料1030344.html
# 已有資料1030346.html
# 已有資料1030380.html
# 已有資料1030382.html
# 已有資料1030424.html
# 已有資料103043.html
# 已有資料1030448.html
# 已有資料103046.html
# 已有資料1030470.html
# 已有資料1030476.html
# 已有資料1030478.html
# 已有資料1030484.html
# 已有資料1030492.html
# 已有資料1030500.html
# 已有資料103051.html
# 已有資料1030514.html
# 已有資料103052.html
# 已有資料1030520.html
# 已有資料1030522.html
# 已有資料1030524.html
# 已有資料1030544.html
# 已有資料1030552.html
# 已有資料1030568.html
# 已有資料103057.html
# 已有資料1030588.html
# 已有資料1030606.html
# 已有資料103062.html
# 已有資料1030622.html
# 已有資料1030640.html
# 已有資料1030694.html
# 已有資料10307.html
# 已有資料1030700.html
# 已有資料1030712.html
# 已有資料1030716.html
# 已有資料1030732.html
# 已有資料1030772.html
# 已有資料1030774.html
# 已有資料1030776.html
# 已有資料1030786.html
# 已有資料1030794.html
# 已有資料1030796.html
# 已有資料1030810.html
# 已有資料103086.html
# 已有資料1030862.html
# 已有資料1030870.html
# 已有資料1030872.html
# 已有資料1030876.html
# 已有資料1030878.html
# 已有資料103089.html
# 已有資料1030896.html
# 已有資料1030914.html
# 已有資料1030920.html
# 已有資料1030936.html
# 已有資料103094.html
# 已有資料1030960.html
# 已有資料1030970.html
# 已有資料1030974.html
# 已有資料1030982.html
# 已有資料103100.html
# 已有資料1031028.html
# 已有資料1031036.html
# 已有資料1031042.html
# 已有資料1031046.html
# 已有資料1031048.html
# 已有資料1031080.html
# 已有資料1031094.html
# 已有資料1031170.html
# 已有資料1031188.html
# 已有資料1031196.html
# 已有資料1031218.html
# 已有資料1031234.html
# 已有資料1031236.html
# 已有資料1031242.html
# 已有資料1031274.html
# 已有資料1031302.html
# 已有資料1031308.html
# 已有資料1031310.html
# 已有資料1031326.html
# 已有資料1031328.html
# 已有資料1031330.html
# 已有資料1031344.html
# 已有資料1031362.html
# 已有資料1031388.html
# 已有資料1031396.html
# 已有資料1031398.html
# 已有資料1031400.html
# 已有資料1031428.html
# 已有資料1031432.html
# 已有資料1031456.html
# 已有資料1031462.html
# 已有資料1031468.html
# 已有資料1031476.html
# 已有資料1031480.html
# 已有資料1031510.html
# 已有資料1031516.html
# 已有資料1031518.html
# 已有資料1031520.html
# 已有資料1031558.html
# 已有資料103156.html
# 已有資料1031562.html
# 已有資料1031564.html
# 已有資料1031570.html
# 已有資料1031574.html
# 已有資料1031588.html
# 已有資料1031592.html
# 已有資料1031594.html
# 已有資料1031602.html
# 已有資料1031630.html
# 已有資料1031654.html
# 已有資料1031658.html
# 已有資料1031660.html
# 已有資料1031662.html
# 已有資料1031686.html
# 已有資料1031736.html
# 已有資料1031746.html
# 已有資料1031752.html
# 已有資料1031756.html
# 已有資料1031760.html
# 已有資料1031762.html
# 已有資料1031786.html
# 已有資料103179.html
# 已有資料1031804.html
# 已有資料1031810.html
# 已有資料1031828.html
# 已有資料103183.html
# 已有資料1031838.html
# 已有資料103188.html
# 已有資料1031882.html
# 已有資料1031926.html
# 已有資料1031934.html
# 已有資料1031940.html
# 已有資料1031944.html
# 已有資料1031958.html
# 已有資料1031994.html
# 已有資料1032030.html
# 已有資料1032040.html
# 已有資料1032042.html
# 已有資料1032048.html
# 已有資料1032068.html
# 已有資料1032070.html
# 已有資料1032074.html
# 已有資料1032080.html
# 已有資料10321.html
# 已有資料103210.html
# 已有資料1032148.html
# 已有資料1032150.html
# 已有資料1032156.html
# 已有資料1032172.html
# 已有資料103218.html
# 已有資料1032194.html
# 已有資料1032198.html
# 已有資料10322.html
# 已有資料1032200.html
# 已有資料1032206.html
# 已有資料1032212.html
# 已有資料1032226.html
# 已有資料1032236.html
# 已有資料1032258.html
# 已有資料1032262.html
# 已有資料1032278.html
# 已有資料1032284.html
# 已有資料103229.html
# 已有資料1032294.html
# 已有資料1032308.html
# 已有資料1032314.html
# 已有資料1032330.html
# 已有資料1032334.html
# 已有資料1032338.html
# 已有資料1032342.html
# 已有資料1032348.html
# 已有資料1032350.html
# 已有資料1032376.html
# 已有資料1032402.html
# 已有資料1032404.html
# 已有資料1032410.html
# 已有資料1032420.html
# 已有資料1032456.html
# 已有資料1032462.html
# 已有資料1032480.html
# 已有資料1032488.html
# 已有資料10325.html
# 已有資料1032508.html
# 已有資料1032522.html
# 已有資料1032526.html
# 已有資料1032540.html
# 已有資料1032558.html
# 已有資料1032572.html
# 已有資料1032576.html
# 已有資料1032582.html
# 已有資料1032588.html
# 已有資料1032600.html
# 已有資料1032610.html
# 已有資料1032626.html
# 已有資料1032640.html
# 已有資料1032646.html
# 已有資料1032658.html
# 已有資料1032666.html
# 已有資料1032676.html
# 已有資料1032686.html
# 已有資料1032692.html
# 已有資料1032694.html
# 已有資料1032698.html
# 已有資料1032700.html
# 已有資料1032704.html
# 已有資料1032708.html
# 已有資料1032712.html
# 已有資料1032720.html
# 已有資料1032724.html
# 已有資料1032738.html
# 已有資料1032768.html
# 已有資料1032782.html
# 已有資料1032784.html
# 已有資料1032786.html
# 已有資料1032798.html
# 已有資料1032802.html
# 已有資料1032808.html
# 已有資料1032814.html
# 已有資料1032858.html
# 已有資料1032864.html
# 已有資料1032866.html
# 已有資料1032868.html
# 已有資料1032888.html
# 已有資料1032902.html
# 已有資料1032914.html
# 已有資料1032920.html
# 已有資料103293.html
# 已有資料1032996.html
# 已有資料10330.html
# 已有資料1033036.html
# 已有資料1033040.html
# 已有資料1033052.html
# 已有資料1033060.html
# 已有資料103307.html
# 已有資料1033082.html
# 已有資料1033088.html
# 已有資料1033094.html
# 已有資料1033122.html
# 已有資料1033150.html
# 已有資料1033158.html
# 已有資料1033162.html
# 已有資料1033176.html
# 已有資料1033184.html
# 已有資料1033196.html
# 已有資料1033210.html
# 已有資料1033214.html
# 已有資料1033228.html
# 已有資料1033236.html
# 已有資料1033238.html
# 已有資料1033246.html
# 已有資料1033250.html
# 已有資料1033256.html
# 已有資料1033278.html
# 已有資料1033290.html
# 已有資料1033294.html
# 已有資料1033318.html
# 已有資料1033324.html
# 已有資料1033328.html
# 已有資料1033344.html
# 已有資料1033350.html
# 已有資料1033362.html
# 已有資料1033368.html
# 已有資料1033380.html
# 已有資料1033394.html
# 已有資料1033406.html
# 已有資料1033420.html
# 已有資料1033454.html
# 已有資料1033458.html
# 已有資料1033478.html
# 已有資料1033480.html
# 已有資料1033482.html
# 已有資料103349.html
# 已有資料1033494.html
# 已有資料1033502.html
# 已有資料1033506.html
# 已有資料1033548.html
# 已有資料103355.html
# 已有資料1033570.html
# 已有資料1033586.html
# 已有資料1033602.html
# 已有資料1033608.html
# 已有資料1033610.html
# 已有資料1033642.html
# 已有資料1033644.html
# 已有資料1033648.html
# 已有資料1033654.html
# 已有資料1033658.html
# 已有資料1033660.html
# 已有資料1033662.html
# 已有資料103368.html
# 已有資料1033680.html
# 已有資料1033686.html
# 已有資料1033690.html
# 已有資料1033700.html
# 已有資料1033714.html
# 已有資料1033722.html
# 已有資料1033748.html
# 已有資料1033758.html
# 已有資料1033810.html
# 已有資料1033812.html
# 已有資料103382.html
# 已有資料1033832.html
# 已有資料1033858.html
# 已有資料1033878.html
# 已有資料1033888.html
# 已有資料1033890.html
# 已有資料1033900.html
# 已有資料1033918.html
# 已有資料1033936.html
# 已有資料1033938.html
# 已有資料1033948.html
# 已有資料1033970.html
# 已有資料1033982.html
# 已有資料1033994.html
# 已有資料1034030.html
# 已有資料1034036.html
# 已有資料1034044.html
# 已有資料1034058.html
# 已有資料1034076.html
# 已有資料1034092.html
# 已有資料1034104.html
# 已有資料1034110.html
# 已有資料1034132.html
# 已有資料1034140.html
# 已有資料1034142.html
# 已有資料1034152.html
# 已有資料1034156.html
# 已有資料103418.html
# 已有資料1034188.html
# 已有資料103422.html
# 已有資料1034250.html
# 已有資料1034258.html
# 已有資料1034262.html
# 已有資料1034272.html
# 已有資料103428.html
# 已有資料1034302.html
# 已有資料1034308.html
# 已有資料1034326.html
# 已有資料1034332.html
# 已有資料1034334.html
# 已有資料1034336.html
# 已有資料1034338.html
# 已有資料1034348.html
# 已有資料1034352.html
# 已有資料1034372.html
# 已有資料1034376.html
# 已有資料1034384.html
# 已有資料1034390.html
# 已有資料1034392.html
# 已有資料1034400.html
# 已有資料1034414.html
# 已有資料1034424.html
# 已有資料1034478.html
# 已有資料1034484.html
# 已有資料1034492.html
# 已有資料1034498.html
# 已有資料1034548.html
# 已有資料1034550.html
# 已有資料1034554.html
# 已有資料1034570.html
# 已有資料1034602.html
# 已有資料1034604.html
# 已有資料1034608.html
# 已有資料1034612.html
# 已有資料1034614.html
# 已有資料1034642.html
# 已有資料1034646.html
# 已有資料1034650.html
# 已有資料1034678.html
# 已有資料1034704.html
# 已有資料1034724.html
# 已有資料1034728.html
# 已有資料1034740.html
# 已有資料1034744.html
# 已有資料1034750.html
# 已有資料103477.html
# 已有資料1034772.html
# 已有資料1034808.html
# 已有資料1034838.html
# 已有資料1034858.html
# 已有資料1034868.html
# 已有資料1034898.html
# 已有資料1034908.html
# 已有資料1034918.html
# 已有資料1034936.html
# 已有資料1034938.html
# 已有資料1034976.html
# 已有資料1034990.html
# 已有資料1035012.html
# 已有資料1035026.html
# 已有資料1035056.html
# 已有資料1035058.html
# 已有資料1035062.html
# 已有資料1035066.html
# 已有資料10351.html
# 已有資料1035108.html
# 已有資料1035118.html
# 已有資料1035132.html
# 已有資料1035154.html
# 已有資料1035160.html
# 已有資料1035176.html
# 已有資料1035188.html
# 已有資料1035196.html
# 已有資料1035216.html
# 已有資料1035230.html
# 已有資料1035242.html
# 已有資料103525.html
# 已有資料1035264.html
# 已有資料1035266.html
# 已有資料10353.html
# 已有資料1035334.html
# 已有資料1035356.html
# 已有資料1035370.html
# 已有資料1035378.html
# 已有資料1035380.html
# 已有資料1035416.html
# 已有資料1035430.html
# 已有資料1035434.html
# 已有資料1035436.html
# 已有資料1035442.html
# 已有資料1035474.html
# 已有資料1035494.html
# 已有資料103550.html
# 已有資料1035502.html
# 已有資料1035522.html
# 已有資料1035536.html
# 已有資料1035540.html
# 已有資料103555.html
# 已有資料1035560.html
# 已有資料1035570.html
# 已有資料1035578.html
# 已有資料1035596.html
# 已有資料1035600.html
# 已有資料1035602.html
# 已有資料1035604.html
# 已有資料1035606.html
# 已有資料1035636.html
# 已有資料1035638.html
# 已有資料1035646.html
# 已有資料1035660.html
# 已有資料1035666.html
# 已有資料103567.html
# 已有資料1035680.html
# 已有資料1035696.html
# 已有資料1035702.html
# 已有資料1035708.html
# 已有資料1035724.html
# 已有資料1035740.html
# 已有資料1035742.html
# 已有資料1035758.html
# 已有資料1035764.html
# 已有資料1035766.html
# 已有資料1035772.html
# 已有資料103578.html
# 已有資料1035780.html
# 已存35700筆資料
# 已有資料1035784.html
# 已有資料1035790.html
# 已有資料1035798.html
# 已有資料103580.html
# 已有資料1035800.html
# 已有資料1035806.html
# 已有資料1035818.html
# 已有資料1035822.html
# 已有資料1035832.html
# 已有資料1035840.html
# 已有資料1035846.html
# 已有資料1035852.html
# 已有資料1035866.html
# 已有資料1035882.html
# 已有資料1035896.html
# 已有資料1035900.html
# 已有資料1035904.html
# 已有資料1035908.html
# ...
# 已有資料983544.html
# 已有資料983558.html
# 已有資料983576.html
# 已有資料983634.html
# 已有資料983638.html
# 已有資料983644.html
# 已有資料983716.html
# 已有資料983742.html
# 已有資料983748.html
# 已有資料983760.html
# 已有資料983764.html
# 已有資料983768.html
# 已有資料983784.html
# 已有資料983786.html
# 已有資料983822.html
# 已有資料983830.html
# 已有資料983832.html
# 已有資料983838.html
# 已有資料983844.html
# 已有資料983918.html
# 已有資料983932.html
# 已有資料983958.html
# 已有資料98397.html
# 已有資料983974.html
# 已存37250筆資料
# 已有資料983986.html
# 已有資料983990.html
# 已有資料983992.html
# 已有資料984002.html
# 已有資料984014.html
# 已有資料984028.html
# 已有資料984030.html
# 已有資料984060.html
# 已有資料984082.html
# 已有資料9841.html
# 已有資料984104.html
# 已有資料984106.html
# 已有資料984124.html
# 已有資料984138.html
# 已有資料984148.html
# 已有資料984156.html
# 已有資料984168.html
# 已有資料984182.html
# 已有資料984202.html
# 已有資料984204.html
# 已有資料984206.html
# 已有資料984220.html
# 已有資料984228.html
# 已有資料984232.html
# 已有資料984242.html
# 已有資料984244.html
# 已有資料984248.html
# 已有資料984256.html
# 已有資料984264.html
# 已有資料984276.html
# 已有資料984280.html
# 已有資料984286.html
# 已有資料984352.html
# 已有資料984370.html
# 已有資料984386.html
# 已有資料984456.html
# 已有資料984472.html
# 已有資料984488.html
# 已有資料984512.html
# 已有資料984514.html
# 已有資料984522.html
# 已有資料984528.html
# 已有資料984552.html
# 已有資料984554.html
# 已有資料984590.html
# 已有資料984632.html
# 已有資料984634.html
# 已有資料984638.html
# 已有資料98464.html
# 已有資料984644.html
# 已有資料984650.html
# 已有資料984656.html
# 已有資料984660.html
# 已有資料984670.html
# 已有資料984672.html
# 已有資料984678.html
# 已有資料984684.html
# 已有資料984690.html
# 已有資料984696.html
# 已有資料984702.html
# 已有資料984706.html
# 已有資料984722.html
# 已有資料98475.html
# 已有資料984752.html
# 已有資料984754.html
# 已有資料984760.html
# 已有資料984810.html
# 已有資料984832.html
# 已有資料984856.html
# 已有資料984918.html
# 已有資料984928.html
# 已有資料98493.html
# 已有資料984932.html
# 已有資料984934.html
# 已有資料98495.html
# 已有資料98498.html
# 已有資料984988.html
# 已有資料985004.html
# 已有資料98501.html
# 已有資料985026.html
# 已有資料985110.html
# 已有資料985112.html
# 已有資料98512.html
# 已有資料98514.html
# 已有資料985156.html
# 已有資料985168.html
# 已有資料985180.html
# 已有資料985206.html
# 已有資料985216.html
# 已有資料985244.html
# 已有資料985274.html
# 已有資料985276.html
# 已有資料985278.html
# 已有資料985280.html
# 已有資料985282.html
# 已有資料985370.html
# 已有資料985400.html
# 已有資料985402.html
# 已有資料985408.html
# 已有資料985414.html
# 已有資料985444.html
# 已有資料985446.html
# 已有資料985458.html
# 已有資料985460.html
# 已有資料98549.html
# 已有資料985500.html
# 已有資料985520.html
# 已有資料985544.html
# 已有資料985548.html
# 已有資料985564.html
# 已有資料985576.html
# 已有資料985580.html
# 已有資料985594.html
# 已有資料985596.html
# 已有資料985604.html
# 已有資料985606.html
# 已有資料985622.html
# 已有資料985632.html
# 已有資料985636.html
# 已有資料985638.html
# 已有資料985648.html
# 已有資料985658.html
# 已有資料985678.html
# 已有資料985686.html
# 已有資料985710.html
# 已有資料985736.html
# 已有資料985742.html
# 已有資料985746.html
# 已有資料985772.html
# 已有資料985776.html
# 已有資料98584.html
# 已有資料985844.html
# 已有資料985846.html
# 已有資料985862.html
# 已有資料985874.html
# 已有資料985880.html
# 已有資料985882.html
# 已有資料9859.html
# 已有資料985920.html
# 已有資料985930.html
# 已有資料985936.html
# 已有資料985938.html
# 已有資料985942.html
# 已有資料985948.html
# 已有資料985950.html
# 已有資料985964.html
# 已有資料986006.html
# 已有資料986018.html
# 已有資料986102.html
# 已有資料986106.html
# 已有資料986114.html
# 已有資料986134.html
# 已有資料986154.html
# 已有資料986156.html
# 已有資料986218.html
# 已有資料986264.html
# 已有資料986266.html
# 已有資料986286.html
# 已有資料986298.html
# 已有資料986324.html
# 已有資料986396.html
# 已有資料986408.html
# 已有資料986410.html
# 已有資料986430.html
# 已有資料986498.html
# 已有資料986508.html
# 已有資料986536.html
# 已有資料986544.html
# 已有資料986546.html
# 已有資料986556.html
# 已有資料986576.html
# 已有資料98661.html
# 已有資料986716.html
# 已有資料986730.html
# 已有資料986770.html
# 已有資料986784.html
# 已有資料986790.html
# 已有資料986794.html
# 已有資料986828.html
# 已有資料986832.html
# 已有資料986922.html
# 已有資料986926.html
# 已有資料986942.html
# 已有資料986946.html
# 已有資料986966.html
# 已有資料986970.html
# 已有資料986974.html
# 已有資料986984.html
# 已有資料986986.html
# 已有資料986988.html
# 已有資料987006.html
# 已有資料987010.html
# 已有資料987012.html
# 已有資料987118.html
# 已有資料987120.html
# 已有資料987142.html
# 已有資料987176.html
# 已有資料987188.html
# 已有資料987214.html
# 已有資料987216.html
# 已有資料987228.html
# 已有資料987258.html
# 已有資料987262.html
# 已有資料987272.html
# 已有資料987300.html
# 已有資料98731.html
# 已有資料987318.html
# 已有資料987328.html
# 已有資料987366.html
# 已有資料987368.html
# 已有資料987378.html
# 已有資料987388.html
# 已有資料987390.html
# 已有資料987404.html
# 已有資料987412.html
# 已有資料987416.html
# 已有資料987418.html
# 已有資料987426.html
# 已有資料987428.html
# 已有資料987430.html
# 已有資料987440.html
# 已有資料987444.html
# 已有資料987452.html
# 已有資料987466.html
# 已有資料987484.html
# 已有資料987504.html
# 已有資料987516.html
# 已有資料987558.html
# 已有資料98756.html
# 已有資料98757.html
# 已有資料987582.html
# 已有資料987606.html
# 已有資料98763.html
# 已有資料987630.html
# 已有資料987634.html
# 已有資料98764.html
# 已有資料987650.html
# 已有資料987654.html
# 已有資料987656.html
# 已有資料987666.html
# 已有資料987676.html
# 已有資料987706.html
# 已有資料987710.html
# 已有資料98773.html
# 已有資料987740.html
# 已有資料987774.html
# 已有資料987786.html
# 已有資料9878.html
# 已有資料98780.html
# 已有資料987810.html
# 已有資料987820.html
# 已有資料987824.html
# 已有資料987848.html
# 已有資料987852.html
# 已有資料987898.html
# 已有資料987904.html
# 已有資料987906.html
# 已有資料987918.html
# 已有資料987924.html
# 已有資料987938.html
# 已有資料987954.html
# 已有資料987984.html
# 已有資料987996.html
# 已有資料988004.html
# 已有資料98801.html
# 已有資料988022.html
# 已有資料988028.html
# 已有資料98804.html
# 已有資料988040.html
# 已有資料988058.html
# 已有資料988066.html
# 已有資料988076.html
# 已有資料988102.html
# 已有資料988106.html
# 已有資料988108.html
# 已有資料988126.html
# 已有資料988132.html
# 已有資料988138.html
# 已有資料988140.html
# 已有資料988160.html
# 已有資料988178.html
# 已有資料988180.html
# 已有資料988188.html
# 已有資料988214.html
# 已有資料988218.html
# 已有資料988232.html
# 已有資料988240.html
# 已有資料988242.html
# 已有資料988250.html
# 已有資料988276.html
# 已有資料988330.html
# 已有資料988372.html
# 已有資料988376.html
# 已有資料988394.html
# 已有資料988400.html
# 已有資料988406.html
# 已有資料988412.html
# 已有資料988444.html
# 已有資料988456.html
# 已有資料988468.html
# 已有資料988494.html
# 已有資料988500.html
# 已有資料988504.html
# 已有資料988510.html
# 已有資料988514.html
# 已有資料988516.html
# 已有資料988550.html
# 已有資料988582.html
# 已有資料988620.html
# 已有資料988632.html
# 已有資料988640.html
# 已有資料988648.html
# 已有資料988656.html
# 已有資料988668.html
# 已有資料988692.html
# 已有資料988694.html
# 已有資料988698.html
# 已有資料988706.html
# 已有資料988714.html
# 已有資料988720.html
# 已有資料988746.html
# 已有資料988748.html
# 已有資料988760.html
# 已有資料988770.html
# 已有資料988772.html
# 已有資料988778.html
# 已有資料988782.html
# 已有資料988786.html
# 已有資料9888.html
# 已有資料988804.html
# 已有資料988816.html
# 已有資料988822.html
# 已有資料988830.html
# 已有資料988854.html
# 已有資料988910.html
# 已有資料988918.html
# 已有資料988920.html
# 已有資料988964.html
# 已有資料988998.html
# 已有資料989002.html
# 已有資料989006.html
# 已有資料989028.html
# 已有資料989056.html
# 已有資料989062.html
# 已有資料989068.html
# 已有資料989070.html
# 已有資料989078.html
# 已有資料989080.html
# 已有資料989086.html
# 已有資料989094.html
# 已有資料989098.html
# 已有資料989118.html
# 已有資料989122.html
# 已有資料989130.html
# 已有資料989162.html
# 已有資料989182.html
# 已有資料989198.html
# 已有資料989254.html
# 已有資料989260.html
# 已有資料989282.html
# 已有資料989302.html
# 已有資料989304.html
# 已有資料989312.html
# 已有資料989320.html
# 已有資料989348.html
# 已有資料989424.html
# 已有資料989432.html
# 已有資料989440.html
# 已有資料989446.html
# 已有資料989448.html
# 已有資料989464.html
# 已有資料989470.html
# 已有資料9895.html
# 已有資料989512.html
# 已有資料989566.html
# 已有資料989572.html
# 已有資料989582.html
# 已有資料9896.html
# 已有資料989628.html
# 已有資料989634.html
# 已有資料989682.html
# 已有資料989696.html
# 已有資料989736.html
# 已有資料989762.html
# 已有資料989766.html
# 已有資料989778.html
# 已有資料98978.html
# 已有資料98979.html
# 已有資料989798.html
# 已有資料989800.html
# 已有資料989848.html
# 已有資料989850.html
# 已有資料989854.html
# 已有資料989862.html
# 已有資料989864.html
# 已有資料989900.html
# 已有資料989936.html
# 已有資料989938.html
# 已有資料989940.html
# 已有資料989948.html
# 已有資料989950.html
# 已有資料989978.html
# 已有資料99.html
# 已有資料99000.html
# 已有資料990034.html
# 已有資料990036.html
# 已有資料990054.html
# 已有資料99009.html
# 已有資料990114.html
# 已有資料990116.html
# 已有資料990118.html
# 已有資料990154.html
# 已有資料990172.html
# 已有資料990176.html
# 已有資料990194.html
# 已有資料990218.html
# 已有資料990220.html
# 已有資料99027.html
# 已有資料990274.html
# 已有資料990282.html
# 已有資料990304.html
# 已有資料99031.html
# 已有資料990312.html
# 已有資料990396.html
# 已有資料990398.html
# 已有資料990410.html
# 已有資料990442.html
# 已有資料990460.html
# 已有資料990472.html
# 已有資料990524.html
# 已有資料990526.html
# 已有資料990550.html
# 已有資料990554.html
# 已有資料990560.html
# 已有資料990562.html
# 已有資料99063.html
# 已有資料990668.html
# 已有資料990694.html
# 已有資料990716.html
# 已有資料990718.html
# 已有資料990720.html
# 已有資料990724.html
# 已有資料990732.html
# 已有資料990738.html
# 已有資料990744.html
# 已有資料990766.html
# 已有資料99080.html
# 已有資料990808.html
# 已有資料990826.html
# 已有資料990832.html
# 已有資料990834.html
# 已有資料990840.html
# 已有資料990850.html
# 已有資料990868.html
# 已有資料990874.html
# 已有資料99092.html
# 已有資料990944.html
# 已有資料990948.html
# 已有資料990982.html
# 已有資料990984.html
# 已有資料991004.html
# 已有資料991016.html
# 已有資料991022.html
# 已有資料991028.html
# 已有資料991086.html
# 已有資料991092.html
# 已有資料991100.html
# 已有資料991132.html
# 已有資料991134.html
# 已有資料991138.html
# 已有資料99114.html
# 已有資料991144.html
# 已有資料99116.html
# 已有資料991168.html
# 已有資料991170.html
# 已有資料991184.html
# 已有資料99121.html
# 已有資料991210.html
# 已有資料991216.html
# 已有資料991284.html
# 已有資料991294.html
# 已有資料991334.html
# 已有資料991340.html
# 已有資料991382.html
# 已有資料991418.html
# 已有資料991434.html
# 已有資料991448.html
# 已有資料991450.html
# 已有資料991452.html
# 已有資料991500.html
# 已有資料991502.html
# 已有資料991526.html
# 已有資料991532.html
# 已有資料991542.html
# 已有資料991578.html
# 已有資料991580.html
# 已有資料991584.html
# 已有資料99161.html
# 已有資料99162.html
# 已有資料99164.html
# 已有資料991640.html
# 已有資料991652.html
# 已有資料991658.html
# 已有資料991674.html
# 已有資料991714.html
# 已有資料991716.html
# 已有資料991734.html
# 已有資料991738.html
# 已有資料991786.html
# 已有資料991790.html
# 已有資料991794.html
# 已有資料991798.html
# 已有資料991808.html
# 已有資料991842.html
# 已有資料991898.html
# 已有資料991956.html
# 已有資料991978.html
# 已有資料991998.html
# 已有資料992052.html
# 已有資料99206.html
# 已有資料992080.html
# 已有資料992082.html
# 已有資料992084.html
# 已有資料992102.html
# 已有資料992118.html
# 已有資料992126.html
# 已有資料992164.html
# 已有資料992170.html
# 已有資料992172.html
# 已有資料992178.html
# 已有資料992184.html
# 已有資料992196.html
# 已有資料992204.html
# 已有資料992238.html
# 已有資料992264.html
# 已有資料992280.html
# 已有資料992284.html
# 已有資料992288.html
# 已有資料992300.html
# 已有資料992314.html
# 已有資料992322.html
# 已有資料992334.html
# 已有資料992422.html
# 已有資料992436.html
# 已有資料992442.html
# 已有資料992460.html
# 已有資料992468.html
# 已有資料992482.html
# 已有資料992486.html
# 已有資料992496.html
# 已有資料992500.html
# 已有資料992506.html
# 已有資料992508.html
# 已有資料992524.html
# 已有資料992546.html
# 已有資料992560.html
# 已有資料992568.html
# 已有資料992570.html
# 已有資料992580.html
# 已有資料992594.html
# 已有資料992598.html
# 已有資料992600.html
# 已有資料992610.html
# 已有資料992712.html
# 已有資料992714.html
# 已有資料992724.html
# 已有資料992734.html
# 已有資料992796.html
# 已有資料992806.html
# 已有資料992828.html
# 已有資料992856.html
# 已有資料992878.html
# 已有資料992900.html
# 已有資料992902.html
# 已有資料992904.html
# 已有資料992922.html
# 已有資料992926.html
# 已有資料992930.html
# 已有資料992944.html
# 已有資料992984.html
# 已有資料993038.html
# 已有資料993042.html
# 已有資料993152.html
# 已有資料993192.html
# 已有資料993234.html
# 已有資料993238.html
# 已有資料993240.html
# 已有資料993282.html
# 已有資料993336.html
# 已有資料993364.html
# 已有資料993396.html
# 已有資料993412.html
# 已有資料993414.html
# 已有資料993484.html
# 已有資料993552.html
# 已有資料993554.html
# 已有資料993588.html
# 已有資料993604.html
# 已有資料99361.html
# 已有資料993612.html
# 已有資料993624.html
# 已有資料993638.html
# 已有資料993640.html
# 已有資料993646.html
# 已有資料993648.html
# 已有資料993698.html
# 已有資料993700.html
# 已有資料993728.html
# 已有資料993736.html
# 已有資料993798.html
# 已有資料993826.html
# 已有資料993828.html
# 已有資料993834.html
# 已有資料993864.html
# 已有資料993920.html
# 已有資料993926.html
# 已有資料993936.html
# 已有資料993948.html
# 已有資料993984.html
# 已有資料993992.html
# 已有資料993996.html
# 已有資料994002.html
# 已有資料994012.html
# 已有資料994022.html
# 已有資料99404.html
# 已有資料994042.html
# 已有資料994050.html
# 已有資料994056.html
# 已有資料994062.html
# 已有資料994076.html
# 已有資料994088.html
# 已有資料994096.html
# 已有資料994098.html
# 已有資料994102.html
# 已有資料994116.html
# 已有資料994124.html
# 已有資料994130.html
# 已有資料994132.html
# 已有資料994138.html
# 已有資料994140.html
# 已有資料994178.html
# 已有資料994196.html
# 已有資料994200.html
# 已有資料994228.html
# 已有資料994268.html
# 已有資料994328.html
# 已有資料994334.html
# 已有資料994386.html
# 已有資料994392.html
# 已有資料9944.html
# 已有資料994402.html
# 已有資料994454.html
# 已有資料994478.html
# 已有資料994482.html
# 已有資料994546.html
# 已有資料994550.html
# 已有資料994554.html
# 已有資料994562.html
# 已有資料99459.html
# 已有資料994602.html
# 已有資料994638.html
# 已有資料994642.html
# 已有資料994658.html
# 已有資料994662.html
# 已有資料994710.html
# 已有資料994728.html
# 已有資料994734.html
# 已有資料99474.html
# 已有資料994764.html
# 已有資料994782.html
# 已有資料994804.html
# 已有資料994810.html
# 已有資料994820.html
# 已有資料994824.html
# 已有資料994838.html
# 已有資料994846.html
# 已有資料994856.html
# 已有資料994860.html
# 已有資料994890.html
# 已有資料9949.html
# 已有資料994908.html
# 已有資料994926.html
# 已有資料994932.html
# 已有資料994938.html
# 已有資料994946.html
# 已有資料994990.html
# 已有資料995020.html
# 已有資料995028.html
# 已有資料995042.html
# 已有資料995046.html
# 已有資料995052.html
# 已有資料995056.html
# 已有資料995088.html
# 已有資料995092.html
# 已有資料995112.html
# 已有資料995154.html
# 已有資料995166.html
# 已有資料995176.html
# 已有資料995182.html
# 已有資料995188.html
# 已有資料995196.html
# 已有資料995202.html
# 已有資料995212.html
# 已有資料995214.html
# 已有資料995226.html
# 已有資料995234.html
# 已有資料995334.html
# 已有資料995340.html
# 已有資料995386.html
# 已有資料995420.html
# 已有資料995428.html
# 已有資料995430.html
# 已有資料995434.html
# 已有資料995438.html
# 已有資料995478.html
# 已有資料995530.html
# 已有資料995550.html
# 已有資料995556.html
# 已有資料995570.html
# 已有資料995624.html
# 已有資料995646.html
# 已有資料995658.html
# 已有資料995674.html
# 已有資料995706.html
# 已有資料995746.html
# 已有資料995766.html
# 已有資料995788.html
# 已有資料995820.html
# 已有資料995822.html
# 已有資料995834.html
# 已有資料995844.html
# 已有資料995848.html
# 已有資料995856.html
# 已有資料995864.html
# 已有資料995876.html
# 已有資料995892.html
# 已有資料995894.html
# 已有資料995906.html
# 已有資料995926.html
# 已有資料995934.html
# 已有資料995954.html
# 已有資料99596.html
# 已有資料995972.html
# 已有資料996018.html
# 已有資料996026.html
# 已有資料996034.html
# 已有資料996052.html
# 已有資料996066.html
# 已有資料996072.html
# 已有資料996080.html
# 已有資料996122.html
# 已有資料996130.html
# 已有資料996134.html
# 已有資料99614.html
# 已有資料996142.html
# 已有資料996154.html
# 已有資料996168.html
# 已有資料99619.html
# 已有資料996190.html
# 已有資料996192.html
# 已有資料99620.html
# 已有資料996212.html
# 已有資料996218.html
# 已有資料996224.html
# 已有資料996226.html
# 已有資料996246.html
# 已有資料99625.html
# 已有資料996250.html
# 已有資料99629.html
# 已有資料996292.html
# 已有資料996324.html
# 已有資料996344.html
# 已有資料996402.html
# 已有資料996420.html
# 已有資料996438.html
# 已有資料996444.html
# 已有資料996456.html
# 已有資料996464.html
# 已有資料996488.html
# 已有資料996530.html
# 已有資料996566.html
# 已有資料996568.html
# 已有資料996572.html
# 已有資料996588.html
# 已有資料99660.html
# 已有資料996610.html
# 已有資料996612.html
# 已有資料996614.html
# 已有資料996648.html
# 已有資料996668.html
# 已有資料996704.html
# 已有資料996710.html
# 已有資料996714.html
# 已有資料996724.html
# 已有資料996728.html
# 已有資料996732.html
# 已有資料996742.html
# 已有資料996768.html
# 已有資料996770.html
# 已有資料996796.html
# 已有資料996798.html
# 已有資料996800.html
# 已有資料996820.html
# 已有資料996846.html
# 已有資料996848.html
# 已有資料996854.html
# 已有資料996860.html
# 已有資料996872.html
# 已有資料996924.html
# 已有資料996940.html
# 已有資料996942.html
# 已有資料996968.html
# 已有資料996984.html
# 已有資料996986.html
# 已有資料996992.html
# 已有資料997012.html
# 已有資料997016.html
# 已有資料997034.html
# 已有資料997036.html
# 已有資料997040.html
# 已有資料997050.html
# 已有資料9971.html
# 已有資料997110.html
# 已有資料997112.html
# 已有資料997140.html
# 已有資料997314.html
# 已有資料997360.html
# 已有資料997412.html
# 已有資料997416.html
# 已有資料997420.html
# 已有資料997466.html
# 已有資料997474.html
# 已有資料997476.html
# 已有資料997578.html
# 已有資料997588.html
# 已有資料997592.html
# 已有資料997606.html
# 已有資料997642.html
# 已有資料997646.html
# 已有資料997648.html
# 已有資料997658.html
# 已有資料997664.html
# 已有資料997666.html
# 已有資料997772.html
# 已有資料997784.html
# 已有資料997788.html
# 已有資料997804.html
# 已有資料997826.html
# 已有資料99784.html
# 已有資料9979.html
# 已有資料997978.html
# 已有資料997980.html
# 已有資料997982.html
# 已有資料997984.html
# 已有資料997996.html
# 已有資料997998.html
# 已有資料998002.html
# 已有資料998004.html
# 已有資料998016.html
# 已有資料998024.html
# 已有資料998028.html
# 已有資料998044.html
# 已有資料998048.html
# 已有資料998166.html
# 已有資料998170.html
# 已有資料998194.html
# 已有資料9982.html
# 已有資料998218.html
# 已有資料998228.html
# 已有資料998234.html
# 已有資料998236.html
# 已有資料998270.html
# 已有資料99828.html
# 已有資料998294.html
# 已有資料998312.html
# 已有資料998314.html
# 已有資料998316.html
# 已有資料998326.html
# 已有資料998346.html
# 已有資料998358.html
# 已有資料998380.html
# 已有資料998422.html
# 已有資料998476.html
# 已有資料998496.html
# 已有資料998536.html
# 已有資料998606.html
# 已有資料998614.html
# 已有資料998616.html
# 已有資料998624.html
# 已有資料998626.html
# 已有資料998640.html
# 已有資料998646.html
# 已有資料998664.html
# 已有資料998666.html
# 已有資料998672.html
# 已有資料998694.html
# 已有資料99870.html
# 已有資料998720.html
# 已有資料998738.html
# 已有資料99878.html
# 已有資料998782.html
# 已有資料998810.html
# 已有資料998816.html
# 已有資料998842.html
# 已有資料998902.html
# 已有資料998918.html
# 已有資料998938.html
# 已有資料998942.html
# 已有資料998994.html
# 已有資料999020.html
# 已有資料999030.html
# 已有資料999040.html
# 已有資料999044.html
# 已有資料999062.html
# 已有資料999070.html
# 已有資料999072.html
# 已有資料999082.html
# 已有資料99909.html
# 已有資料999090.html
# 已有資料999112.html
# 已有資料999114.html
# 已有資料999118.html
# 已有資料999128.html
# 已有資料999168.html
# 已有資料999188.html
# 已有資料999202.html
# 已有資料999206.html
# 已有資料999224.html
# 已有資料999226.html
# 已有資料999236.html
# 已有資料999238.html
# 已有資料999250.html
# 已有資料999272.html
# 已有資料999274.html
# 已有資料999284.html
# 已有資料999290.html
# 已有資料999328.html
# 已有資料999372.html
# 已有資料999376.html
# 已有資料999382.html
# 已有資料999384.html
# 已有資料999400.html
# 已有資料999418.html
# 已有資料999420.html
# 已有資料999480.html
# 已有資料99949.html
# 已有資料999520.html
# 已有資料999526.html
# 已有資料999530.html
# 已有資料999544.html
# 已有資料999550.html
# 已有資料999552.html
# 已有資料999558.html
# 已有資料99956.html
# 已有資料999560.html
# 已有資料999564.html
# 已有資料999572.html
# 已有資料999580.html
# 已有資料999620.html
# 已有資料999646.html
# 已有資料999650.html
# 已存37300筆資料
# 已有資料999686.html
# 已有資料999718.html
# 已有資料999722.html
# 已有資料999726.html
# 已有資料999752.html
# 已有資料999758.html
# 已有資料999818.html
# 已有資料999850.html
# 已有資料999852.html
# 已有資料999862.html
# 已有資料999872.html
# 已有資料999878.html
# 已有資料9999.html
# 已有資料99990.html
# 已有資料99994.html
# 已有資料999974.html
# 已有資料999978.html
# 已有資料999990.html

# %% [markdown]
# # 用來確認會造成BUG的店家名稱

# %%
for i in dienlist:
    print(i["name"])
    possible_json_string = '[{"a":"'+i["name"]+'","b":"2"},{"c":3.6,"d":""}]'
    js = json.loads(possible_json_string)

# %%
if os.path.exists('./data/diendata.json'):
    with open("./data/diendata.json","r") as d:
        dienlist=json.load(d)
        n=len(dienlist)
n
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-150-e7e3bc48307c> in <module>()
#       1 if os.path.exists('./data/diendata.json'):
#       2     with open("./data/diendata.json","r") as d:
# ----> 3         dienlist=json.load(d)
#       4         n=len(dienlist)
#       5 n
#
# D:\anaconda\lib\json\__init__.py in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     297         cls=cls, object_hook=object_hook,
#     298         parse_float=parse_float, parse_int=parse_int,
# --> 299         parse_constant=parse_constant, object_pairs_hook=object_pairs_hook, **kw)
#     300
#     301
#
# D:\anaconda\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     352             parse_int is None and parse_float is None and
#     353             parse_constant is None and object_pairs_hook is None and not kw):
# --> 354         return _default_decoder.decode(s)
#     355     if cls is None:
#     356         cls = JSONDecoder
#
# D:\anaconda\lib\json\decoder.py in decode(self, s, _w)
#     337
#     338         """
# --> 339         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     340         end = _w(s, end).end()
#     341         if end != len(s):
#
# D:\anaconda\lib\json\decoder.py in raw_decode(self, s, idx)
#     353         """
#     354         try:
# --> 355             obj, end = self.scan_once(s, idx)
#     356         except StopIteration as err:
#     357             raise JSONDecodeError("Expecting value", s, err.value) from None
#
# JSONDecodeError: Expecting ':' delimiter: line 1 column 525046 (char 525045)

# %% [markdown]
# # bs抓取某tag or tag群的方法
# soup.select("tag > tag > tag") 如:soup.select("#search > article > hgroup > h2 > b")
#
# soup.find_all('tag', attrs={'tag內的元素': '元素名稱'}) 如:soup.find_all('a', attrs={'data-label': '店名'})

# %%
#確認json是否可讀取的方法
possible_json_string = '[{"a":3,"b":"2"},{"c":3.6,"d":""}]'
print(None)
print(possible_json_string)
js = json.loads(possible_json_string)
# Out:
# None
# [{"a":3,"b":"2"},{"c":3.6,"d":""}]

# %%
len(set(finishdien))
# Out:
# 35349

# %%
# Out:
# '龍君兒的家'

# %%
with open("./data/diendata.json","r") as d:
    dienlist=json.load(d)

# %%
len(set([dien["id"] for dien in dienlist]))
# Out:
# 36629
