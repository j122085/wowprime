# %% [markdown]
# # try getinfo

# %%
import os
from bs4 import BeautifulSoup as bs
import re
with open("./data/html/極幻燒肉弁当.html","r",encoding='utf8') as f:
    dienhtml=f.read()
    soup=bs(dienhtml, "lxml")
    
    
int(re.findall("http:\/\/www\.ipeen\.com\.tw\/shop\/([0-9]+)\'",soup.text)[0])#id
info=soup.select_one("#shop-header > div.info")
info.find('span', attrs={'itemprop': 'name'}).text#name
soup.find('a', attrs={'data-label': '詳細資訊_大分類'}).text#bigstyle
info.find('a', attrs={'data-label': '上方小分類'}).text#smallstyle
int(re.findall("本店均消 +([0-9]+) +元",info.select_one('p.cost.i').text)[0])#averagecost
info.find('a', attrs={'data-label': '上方電話'}).text.replace("-","")#tele
re.findall("..[市|縣].+[區|市].+[路|街|地段|巷][0-9]+[-|之]?[0-9]*?[號|巷|弄]?[0-9]*[號|巷|弄|樓]",
           info.find('a', attrs={'data-label': '上方地址'}).text)[0]#add
re.findall("\/c=([0-9]+\.[0-9]+)\,([0-9]+\.[0-9]+)\/z=",info.find('a', attrs={'data-label': '上方地址'})["href"])[0]#lat.lng
int(re.findall("會員分享文 \(([0-9]+)\)",soup.text)[0])#Ncomment
int(info.select_one("span.score-bar.large > meter")['value'])
if "已歇業" in info.select_one("h1").text:
    print("結束營業")
else:
    print("正常營業")#status
re.findall("共([0-9]+)人瀏覽([0-9]+)人收藏",info.select_one("div.scalar").text.
           replace(",","").replace("\n","").replace(" ",""))[0]#viewcount.collecount
re.findall("更新時間(\d{4}\/\d{2}\/\d{2})",soup.select_one("div#shop-details").text.
           replace("\n","").replace(" ",""))[0]#renewtime
# Out:
# 25.021057

# %% [markdown]
# # 第二版

# %%
import os
from bs4 import BeautifulSoup as bs
import json
dienlist=[]
print("共有"+str(len(os.listdir("./data/html")))+"筆資料")
n=0


if os.path.exists('./data/diendata.json'):
    with open("./data/diendata.json","r") as d:
        dienlist=json.load(d)
        n=len(dienlist)
        
finishdien=[dien['name'] for dien in dienlist]
        


for file in os.listdir("./data/html"):
    if n%50==0:
        print(n)
        with open("./data/diendata.json","w") as d:
            json.dump(dienlist,d)
        
    if file.split(".")[0] not in finishdien:
        n+=1
        with open("./data/html/"+file,"r",encoding='utf8') as f:
            diendata={}
            dienhtml=f.read()
            soup=bs(dienhtml,"lxml")
            info=soup.select_one("#shop-header > div.info")

            diendata["id"]=int(re.findall("http:\/\/www\.ipeen\.com\.tw\/shop\/([0-9]+)\'",soup.text)[0])#id
            diendata["name"]=info.find('span', attrs={'itemprop': 'name'}).text
            diendata["bigstyle"]=soup.find('a', attrs={'data-label': '詳細資訊_大分類'}).text
            diendata["smallstyle"]=info.find('a', attrs={'data-label': '上方小分類'}).text

            try:
                diendata["averagecost"]=int(re.findall("本店均消 +([0-9]+) +元",info.select_one('p.cost.i').text)[0])
            except:
                diendata["averagecost"]=None
            try:
                diendata["tele"]=info.find('a', attrs={'data-label': '上方電話'}).text.replace("-","")#tele
            except:
                diendata["tele"]=None
            try:
                diendata["address"]=re.findall("..[市|縣].+[區|市].+[路|街|地段|巷][0-9]+[-|之]?[0-9]*?[號|巷|弄]?[0-9]*[號|巷|弄|樓]",
                       info.find('a', attrs={'data-label': '上方地址'}).text)[0]#add
            except:
                diendata["address"]=None

            try:
                diendata["lat"]=float(re.findall("\/c=([0-9]+\.[0-9]+)\,([0-9]+\.[0-9]+)\/z=",
                                               info.find('a', attrs={'data-label': '上方地址'})["href"])[0][0])#lat.lng
            except:
                diendata["lat"]=None
            try:
                diendata["lng"]=float(re.findall("\/c=([0-9]+\.[0-9]+)\,([0-9]+\.[0-9]+)\/z=",
                                               info.find('a', attrs={'data-label': '上方地址'})["href"])[0][1])#lat.lng
            except:
                diendata["lng"]=None
            try:
                diendata["Ncomment"]=int(re.findall("會員分享文 \(([0-9]+)\)",soup.text)[0])#Ncomment
            except:
                diendata["Ncomment"]=0
            diendata["ipeenscore"]=int(info.select_one("span.score-bar.large > meter")['value'])#ipeenscore
            if "已歇業" in info.select_one("h1").text:
                diendata["status"]="結束營業"
            else:
                diendata["status"]="正常營業"
            diendata["viewcount"]=int(re.findall("共([0-9]+)人瀏覽([0-9]+)人收藏",info.select_one("div.scalar").text.
                       replace(",","").replace("\n","").replace(" ",""))[0][0])#viewcount
            diendata["collecount"]=int(re.findall("共([0-9]+)人瀏覽([0-9]+)人收藏",info.select_one("div.scalar").text.
                       replace(",","").replace("\n","").replace(" ",""))[0][1])#collecount
            diendata["reviewdate"]=re.findall("更新時間(\d{4}\/\d{2}\/\d{2})",soup.select_one("div#shop-details").text.
                       replace("\n","").replace(" ",""))[0]#renewdate
        dienlist.append(diendata)
    
with open("./data/diendata.json","w") as d:
    json.dump(dienlist,d)
# Out:
# 共有28623筆資料
# 24700
# 24700
# 24750
# 24800
# 24850
# 24900
# 24950
# 25000
# 25050
# 25100
# 25150
# 25200
# 25250
# 25300
# 25350
# 25400
# 25450
# 25500
# 25550
# 25600
# 25650
# 25700
# 25750
# 25800
# 25850
# 25850
# 25900
# 25950
# 25950
# 25950
# 26000
# 26050
# 26100
# 26150
# 26150
# 26150
# 26150
# 26150
# 26150
# 26200
# 26250
# 26300
# 26350
# 26350
# 26400
# 26450
# 26500
# 26500
# 26550
# 26600
# 26650
# 26700
# 26750
# 26800
# 26850
# 26850
# 26900
# 26950
# 27000
# 27050
# 27100
# 27150
# 27200
# 27250
# 27300
# 27350
# 27400
# 27450
# 27500
# 27550
# 27600
# 27650
# 27700
# 27750
# 27800
# 27800
# 27800
# 27800
# 27800
# 27850
# 27900

# %%
with open("./data/diendata.json","r") as d:
    diendata=json.load(d)
[dien['name'] for dien in diendata]
# Out:
# ['0.618',
#  '018咖啡甜品玩國',
#  '0870 Australian Kitchen',
#  '1+1 Together Republic',
#  '1010湘(台中勤美店)',
#  '1010湘',
#  '101茶飲輕食(忠孝1店)',
#  '103早午餐',
#  '108堂烘焙',
#  '10元吃到堡之鹹豬堡',
#  '10元搖搖 茶飲連鎖店(青海店)',
#  '10元無名春捲．油餅',
#  '10元豆花',
#  '10分之1海鮮燒烤',
#  '11 Pasta 食義',
#  '110泡芙銀行',
#  '111Bistro',
#  '11號吐司 烘焙甜點 工作坊',
#  '11號咖啡',
#  '11風谷拉麵',
#  '12 Basekets Cafe',
#  '123冰城',
#  '123家常菜館',
#  '123炒螺肉(覺民店)',
#  '123簡餐',
#  '123養生雞湯',
#  '127 咖哩。燉飯',
#  '127水餃',
#  "129巷'咖啡館",
#  '12次元巧克力魔法殿',
#  '1314渡假村',
#  '1314碳烤三明治',
#  '133鮮果汁',
#  '136公路客家小館',
#  '137 Bookstore 咖啡館',
#  '139日式卡通雞蛋糕',
#  '13th',
#  '13個手感烘焙',
#  '13咖啡',
#  '14號咖啡館',
#  '151食堂',
#  '1525綠茶館(嘉義志昇店)',
#  '15元大飯店',
#  '15區法式烘焙坊',
#  '161咖啡烘焙屋',
#  '161烘焙咖啡屋',
#  '168海鮮超市餐廳',
#  '168火鍋坊',
#  '168綠豆湯',
#  '16號酒館',
#  '1789 Café, by Cyrille Courant',
#  '17番号-義式冰淇淋‧手工巧克力',
#  '17號鄉村廚房',
#  '17號雞排店',
#  '18%雞蛋糕',
#  '180韓定食',
#  '181烘焙屋',
#  '182 Pancake',
#  '1837 TWG TEA(台北101店)',
#  '1868咖啡烘培坊(忠孝店)',
#  '1868咖啡烘焙館(三峽北大店)',
#  '188炸雞店',
#  '18巷公園羊肉炒麵',
#  '18度C巧克力工坊',
#  '18番燒烤',
#  '18鍋',
#  '1915海洋咖啡館',
#  '1925 cafe',
#  '1928燒肉總鋪',
#  '1942餓棧廚房',
#  '1966牛肉麵',
#  '1972(興隆店)',
#  '1973 Music Space',
#  '1976(原香港廣東粥粉麵點心專家)',
#  '1978壹酒柒吧燒烤海鮮酒吧',
#  '198 藝術空間 ギャラリー CAFE',
#  '1984 Coffee Shop',
#  '1985窯烤披薩 Pizza Bar',
#  '1987廚房工作室',
#  '1996喫茶食譜(尊賢店)',
#  '1996喫茶食譜(德行店)',
#  '1Chio Pasta 義趣屋',
#  '1分鐘快煮麵(排骨雞汁)',
#  '1加1午晚餐',
#  '1點點(士林店)',
#  '2/100 Café',
#  '2 Daydreams 白日夢巧克力飲品',
#  '2 Two Princesses',
#  '2000萬壽司店',
#  '201 Cafe Restaurant',
#  '2011台北凱撒月餅禮盒',
#  '2014金格中秋調酒月餅禮盒',
#  '205巷紙火鍋',
#  '20四6',
#  '21%起司雞排',
#  '218巷味蕾工房',
#  '21世紀櫻花蝦芋粿米糕',
#  '21世紀風味館(信義三越A8門市)',
#  '21世紀風味館(內湖大潤發門市)',
#  '21世紀風味館(台南成大店)',
#  '21世紀風味館(台南西門三越)',
#  '21世紀風味館(屏東環球門市)',
#  '21世紀風味館(左營三越門市)',
#  '21世紀風味館(師大和平店)',
#  '21世紀風味館(平鎮大潤發店)',
#  '21世紀風味館(義大世界門市)',
#  '21工坊涼麵(華陰街店)',
#  '21工房chilled noodles',
#  '21金小火鍋臭臭鍋',
#  '22cafe 22號咖啡館',
#  '22部門專業碳烤土司',
#  '235巷Pasta(站前店)',
#  '23度半鳳梨。福爾摩沙的熱帶金鑽',
#  '23燒烤',
#  '241橋頭鹹酥雞',
#  '24小吃店',
#  '25好好味',
#  '25巷複合式精緻餐飲',
#  '267飯店',
#  '26區鮮釀啤酒燒肉居食屋',
#  '26法式餐廳',
#  '27 1/3 Cake house 伴手禮',
#  '2730 café 貳柒參零咖啡',
#  '27米粉湯',
#  '27街',
#  '285大排檔',
#  '28巷早餐坊',
#  '28度C簡餐',
#  '28街排骨店',
#  '2F Second Floor Night Club',
#  '2FISH Coffee - 荳荳魚咖啡',
#  '2F食館',
#  '2gether(晴光店)',
#  '2ㄌㄧㄤˇd水(新埔店)',
#  '2派克脆皮雞排(中壢龍東店)',
#  '2派克脆皮雞排(五股成泰店)',
#  '2派克脆皮雞排(公益店)',
#  '2派克脆皮雞排(北投奇岩店)',
#  '2派克脆皮雞排(北投店)',
#  '2派克脆皮雞排(台中東海店)',
#  '2派克脆皮雞排(新莊輔大店)',
#  '2派克脆皮雞排(永和永利店)',
#  '2派克脆皮雞排(迴龍店)',
#  '2派克脆皮雞排(逢甲店)',
#  '2派克脆皮雞排(陽明店)',
#  '2派克脆皮雞排(頭城店)',
#  '2派克脆皮雞排',
#  '2里郎',
#  '3 COWS 三隻牛',
#  '3 Idiots Toast& Curry',
#  '3 Wish',
#  '300%BAR',
#  '301水餃滷味各式麵類',
#  '30年鵝肉老店',
#  '30年麵店',
#  '30鮮the juice沙冰果汁',
#  '315 coffee',
#  '31Pizza(中壢老街溪的家)',
#  '31活蝦小舖',
#  '32脆皮臭豆腐',
#  '32袋奶',
#  '32食坊',
#  '333 Restaurant & Bar',
#  '336 豆花',
#  '34K coffee',
#  '3517手作甜點。輕食',
#  '35甕缸雞(紫南宮)',
#  '360°焗御坊(三重店)',
#  '361義大利麵',
#  '369牛肉麵(中山路二段)',
#  '36味咖啡館',
#  '38食光',
#  '39A Café',
#  '39比薩焗烤家族(高餐校區內)',
#  '3A同學會',
#  '3inch迷你燒烤堡(瑞豐夜市)',
#  '3inch迷你燒烤堡',
#  '3mins美式早午餐(精誠店)',
#  '3Pig五花肉專賣店',
#  '【3QMALL】老陳廚房黃金泡菜',
#  '3Q專業烘焙(原橙果烘焙菓子工坊)',
#  '3Q總舖手工關廟麵',
#  '3Q總鋪手工關麻乾麵',
#  '3Q脆皮雞排(內湖店)',
#  '3Q脆皮雞排(北平店)',
#  '3Q脆皮雞排(新莊天祥店)',
#  '3Q脆皮雞排(泰林店)',
#  '3Q脆皮雞排(竹東中興店)',
#  '3Q脆皮雞排',
#  '3個10元車輪餅攤',
#  '3各鍋火鍋料理',
#  '3品皇新鮮茶飲專賣店(復興店)',
#  '3樂鐡板燒',
#  '3皇3家(彰化店)',
#  '3號咖啡',
#  '3頑子無煙燒烤',
#  '4 MANO',
#  '40元蒸餃',
#  '40年老店美香陽春麵',
#  '44 Bit 拍拍咖啡 Cafe Lab(原：44 bit 拍拍 beverage)',
#  '44號館浜焼き酒場',
#  '456蟹殼黃酥餅專賣店',
#  '46番Mocoto承醬烤香雞排(大昌店)',
#  '48HOME',
#  '495巷小廚房 Soi 495 Homemade dessert',
#  '49元勁道烏龍麵',
#  "4C caf'e 冰釀達人",
#  '4F料理生活家',
#  '4plus',
#  '50 PIZZA(新營中正店)',
#  '500C.C鮮打果汁',
#  '501 darts cafe',
#  '507高地美健農場',
#  '50Pizza(新竹東門店)',
#  '50pizza',
#  '50元爌肉飯',
#  '50嵐(中興嶺店)',
#  '50嵐(南港園區店)',
#  '50嵐(台北中坡店)',
#  '50嵐(台北康定店)',
#  '50嵐(台北文德店)',
#  '50嵐(台北晴光店)',
#  '50嵐(台北東湖二店)',
#  '50嵐(台北林森店)',
#  '50嵐(台北重慶店)',
#  '50嵐(向上店)',
#  '50嵐(土城明德店)',
#  '50嵐(太平樹孝店)',
#  '50嵐(寧夏店)',
#  '50嵐(新北投店)',
#  '50嵐(新莊中正店)',
#  '50嵐(新莊富國店)',
#  '50嵐(昆陽遠東店)',
#  '50嵐(梧棲店)',
#  '50嵐(樹林博愛店)',
#  '50嵐(泰山明志店)',
#  '50嵐(淡水竹圍店)',
#  '50嵐(神岡豐州店)',
#  '50嵐(美村二店)',
#  '50嵐(美村店)',
#  '50嵐(青海店)',
#  '50嵐(鶯桃店)',
#  '50嵐',
#  '50年古早味',
#  '50饡便當',
#  '513義式料理',
#  '51咖啡簡餐',
#  '51茶蓋',
#  '51號咖啡屋',
#  '534薇薇現打果汁',
#  '53咖啡',
#  '53林咖啡',
#  '5468美式原味碳烤牛排',
#  '555帝王食補薑母鴨',
#  '-55度C沙西米 超低溫生魚片(敦北店)',
#  '55號義大利麵',
#  '56巷口手工湯包',
#  '56芝麻球芋頭餅',
#  '588包小奶',
#  '58海鮮熱炒燒烤',
#  '58鍋燒',
#  '5味臭臭鍋(公館店)',
#  '5鄉地',
#  '5餅2魚手工披薩(安樂店)',
#  '6-1號現滷滷味',
#  '6:35 吃早餐',
#  '601 PIZZERIA',
#  '609Tea Bar',
#  '60S瑞士烤起士 Raclette',
#  '60號紅豆餅鋪',
#  '620手作霜淇淋(鼎山店)',
#  '63 Brunch',
#  '66 pasta',
#  '66義式燒烤手趴雞',
#  '66號夾心豆干(胖姨夾心豆干)',
#  '676滷肉飯',
#  '687餐坊咖啡下午茶',
#  '68食堂',
#  '6956半線鏢局',
#  '6吋盤早午餐(鼎新店)(鼎新店)',
#  '6街義食屋',
#  '7-11 city cafe 咖啡年輪蛋糕',
#  '7-11 優遊卡',
#  '7-11 光合農場-田園番茄濃湯',
#  '7-11 全日優格',
#  '7-11 北海道霜淇淋',
#  '7-11 手打漢堡肉-辣味吉士',
#  '7-11 日本直送冷凍鍋物',
#  '7-11-焗烤鮪魚三明治',
#  '7-11 碗粿',
#  '7-11 紅燒牛肉燴飯',
#  '7- 11 統一水沙連風味紅茶(7-11統一超商(市捷門市))',
#  '7-11 肉捲飯糰',
#  '7-11--辣鮪魚貝果/鳳梨牛奶',
#  '7-11--醋勁窈窕--蜂蜜小麥草醋飲/ 蜂蜜梅棗醋飲',
#  '7-11',
#  '7-11open玉子丸子飯團',
#  '7-11主廚田園沙拉',
#  '7-11光合三明治-厚蛋田園',
#  '7-11光合三明治-智利煙燻帝王鮭魚',
#  '7-11光合沙拉-洋芋蛋沙拉佐生菜',
#  '7-11咖哩雞排',
#  '7-11大腸麵線',
#  '7-11大雞肉飯',
#  '7-11奶油鮭魚焗麵',
#  '7-11御料理 日式鹽烤五花燒肉便當',
#  '7-11御飯糰-嘉義火雞肉',
#  '7-11御飯糰-培根蛋沙拉',
#  '7-11御飯糰-干貝飯糰辣味',
#  '7-11御飯糰-泡菜鮪魚',
#  '7-11御飯糰-海陸雙手捲',
#  '7-11御飯糰-糯米飯糰',
#  '7-11御飯糰-醬燒豬肉夾心',
#  '7-11御飯糰-雙餡飯糰美國龍蝦北海道鮭魚',
#  '7-11御飯糰-雙餡飯糰鮪魚肉鬆',
#  '7-11御飯糰-雞唐揚美乃滋',
#  '7-11御飯糰-韓式泡菜燒肉',
#  '7-11御飯糰-鮪魚夾心飯糰',
#  '7-11比利時巧克力雙餡蛋糕',
#  '7-11涼麵(中華涼麵)',
#  '7-11涼麵(月見蕎麥涼麵)',
#  '7-11涼麵(韓國泡菜江原道燒肉極上涼麵)',
#  '7-11炸雞腿便當',
#  '7-11焗烤奶油蝦仁義大利麵',
#  '7-11焦糖瑪奇朵軟法',
#  '7-11貝果(起士)',
#  '7-11起酥香草布丁',
#  '7-11酷辣雞腿',
#  '7-11限定麻婆豆腐燴飯',
#  '7-11香辣雞翅洋芋片',
#  '7-11香雞排',
#  '7 DAY',
#  '7-Eleven 統一 Sweet Corner 雞蛋熟布丁',
#  '7-ELEVEN義式烤雞番茄義大利麵',
#  '7-SELECT～三鮮燒賣',
#  '7-SELECT 巧克力牛奶',
#  '7-SELECT 微波即時冷凍品',
#  '7-SELECT～黃金薯霸',
#  '7-SELECT切達起司爆米花',
#  '7-SELECT蕃茄乳酪手工披薩',
#  '7-SELECT蕃茄肉醬義大利麵',
#  '70-1 Sweet-to-Go',
#  '715森林園',
#  '71°N 庭園咖啡',
#  '72號鬆餅堡',
#  '737巷義麵屋',
#  '737滷味',
#  '747 巨無霸 炙燒牛排餐廳',
#  '77House手工烘焙坊',
#  '77乳加校車禮盒',
#  '77巧克力醬',
#  '77巧菲斯(牛奶)',
#  '77新貴派巧克力',
#  '77牛排館(中正店)',
#  '786李園清真小吃',
#  '79 Style(高雄裕誠店)',
#  '79 Style',
#  '79 時代',
#  '79義大利藝術冰淇淋專賣坊(南勢角)',
#  '79義大利藝術冰淇淋專賣坊(士林文林店)',
#  '7days away café+B&B 七天出走',
#  '7Linner',
#  '7th Japanese Bar',
#  '7x7米平方',
#  '7平方創新PIZZArestaurant',
#  '7年5班複合式餐飲',
#  '8%ice 食尚信義',
#  '806清粥自助餐',
#  '813芭依珊奶緹茶館(民權店)',
#  '821麵食概念屋',
#  '82mm Cafe',
#  '82巷豬血糕',
#  '84岩燒海苔飯捲-拔絲BAZ(新莊店)',
#  '85度C 咖啡蛋糕烘焙專賣店(萬華萬大店)',
#  '85度C咖啡蛋糕烘培專賣店(員林靜修店)',
#  '85度C咖啡蛋糕烘焙專賣店(三重中華店)',
#  '85度C咖啡蛋糕烘焙專賣店(三重仁政店)',
#  '85度C咖啡蛋糕烘焙專賣店(中壢民族店)',
#  '85度C咖啡蛋糕烘焙專賣店(中壢環中店)',
#  '85度C咖啡蛋糕烘焙專賣店(南崁南竹店)',
#  '85度C咖啡蛋糕烘焙專賣店(南投大同店)',
#  '85度C咖啡蛋糕烘焙專賣店(南投竹山店)',
#  '85度C咖啡蛋糕烘焙專賣店(台中復興店)',
#  '85度C咖啡蛋糕烘焙專賣店(台中東海店)',
#  '85度C咖啡蛋糕烘焙專賣店(台中潭子店)',
#  '85度C咖啡蛋糕烘焙專賣店(台中英才店)',
#  '85度C咖啡蛋糕烘焙專賣店(台中豐原店)',
#  '85度C咖啡蛋糕烘焙專賣店(台中逢甲店)',
#  '85度C咖啡蛋糕烘焙專賣店(台北京華店)',
#  '85度C咖啡蛋糕烘焙專賣店(台北吉林店)',
#  '85度C咖啡蛋糕烘焙專賣店(台北和平東店)',
#  '85度C咖啡蛋糕烘焙專賣店(台北西門店)',
#  '85度C咖啡蛋糕烘焙專賣店(台北饒河店)',
#  '85度C咖啡蛋糕烘焙專賣店(埔里中正店)',
#  '85度C咖啡蛋糕烘焙專賣店(基隆樂一店)',
#  '85度C咖啡蛋糕烘焙專賣店(大園中山店)',
#  '85度C咖啡蛋糕烘焙專賣店(大里成功店)',
#  '85度C咖啡蛋糕烘焙專賣店(天母德行店)',
#  '85度C咖啡蛋糕烘焙專賣店(嶺東店)',
#  '85度C咖啡蛋糕烘焙專賣店(板橋仁化店)',
#  '85度C咖啡蛋糕烘焙專賣店(桃園經國店)',
#  '85度C咖啡蛋糕烘焙專賣店(永和保平店)',
#  '85度C咖啡蛋糕烘焙專賣店(永康中華店)',
#  '85度C咖啡蛋糕烘焙專賣店(永康崑山店)',
#  '85度C咖啡蛋糕烘焙專賣店(汐止新台五店)',
#  '85度C咖啡蛋糕烘焙專賣店(泰山明志店)',
#  '85度C咖啡蛋糕烘焙專賣店(羅東民權店)',
#  '85度C咖啡蛋糕烘焙專賣店',
#  '85度C花蓮(海岸店)',
#  '85度C鳳梨酥',
#  '866 咖啡專賣店',
#  '86炭烤雞排',
#  '86號餐館',
#  '877手工咖啡',
#  '8818 披薩屋',
#  '888 chicken bar',
#  '8889倫倫&婷婷生炒花枝鮮蝦羹',
#  '888燻茶鵝(燻茶鵝·滷味·薑母鴨)',
#  '88嫩仙草(內壢店)',
#  '88花園咖啡無菜單創意料理',
#  '88麻辣鍋',
#  '89餐廳',
#  '8NaNa 八樂那咖啡複合店',
#  '8nana八樂那(台南佳里)',
#  '8元紅豆餅',
#  '8克cafe',
#  '8公仔(總店)',
#  '8分之1',
#  '8分之1無煙串燒',
#  '8加1番咖哩專賣',
#  '8号麵包創意工坊',
#  '8度洋食廚房',
#  '8度濃漿',
#  '8鍋臭臭鍋(北大店)',
#  '8鍋臭臭鍋(鶯歌建國店)',
#  '8鍋臭臭鍋連鎖餐飲(竹東北興店)',
#  '9 Darts&Cafe III',
#  "9 Darts&Cafe'",
#  '90後 JoHouLim(台北西門店)',
#  '90高地玉米花爆破工場',
#  '917攝影咖啡館',
#  "91手工餅乾 Joy's cookies",
#  '92夢咖啡豐原',
#  '92涮涮鍋',
#  '94i手感烘焙',
#  '98 Tea Café 高雄右昌店',
#  '988料理屋',
#  '988生猛海鮮餐廳',
#  '98日式拉麵',
#  '98燒烤屋',
#  '98義大利pasta(大雅店)',
#  '99咖啡蛋糕專賣店(大竹店)',
#  '99泰式燒烤',
#  '9一郎活海鮮',
#  '9在ㄍㄡ甜心菓舖',
#  'A-bao 龍井店',
#  'A-bao',
#  'A-bao早餐店',
#  'A-Bull阿布食藝',
#  'a cafe & bagel',
#  'a CHI 藝文空間',
#  'A day 日日村',
#  'A deal',
#  'A&E CREAM 義式手作冰淇淋',
#  'A-HA 阿哈西式排餐牛排',
#  'A-Hui 阿輝早午餐(北屯店)',
#  'A.I.T.烘培坊牛軋糖',
#  'A. K. 12美式小館',
#  'A Little More 多一點咖啡(新灣店)',
#  'A Moment一下子',
#  'A-one泰',
#  'A place',
#  'a poet',
#  'A-Point Express 都會慢食 南紡購物中心',
#  'a Room 房間',
#  'A.S.K.休閒餐廳',
#  'A-steak 牛排餐酒館',
#  'A story fushion 故事私房菜',
#  'A Way Cafe',
#  'a~We',
#  'ABC Cooking Studio(環球板橋教室)',
#  "Abi's 印度美食餐廳 & 酒吧",
#  'ABV Bar & Kitchen 啤酒餐廳',
#  'ABV% 加勒比海 精釀啤酒餐廳',
#  'ABVBar&Kitchen 加勒比海餐酒館',
#  'ACE全素軟糖',
#  'ACE咖啡3合1,2合1',
#  'ACE大蔓越莓乾',
#  'Across The Ocean環浪商號',
#  'Addicition癮餐酒館',
#  'ADE brunch&café 歐德義',
#  'ADM 頂級G98卵磷脂',
#  'Afternoon Tea(遠百台中門市)',
#  'aga burger',
#  'AGCT Apartment',
#  'Agene Cafe 阿嬸咖啡',
#  'agnès b. café',
#  'agnès b. Le Pain Grillé 法式小餐館(板橋大遠百)',
#  "AGRIOZ Cafe'",
#  'Agroworks蔬果工場',
#  'AGUGU阿咕咕',
#  'AI Dente若于義大利坊',
#  'AIFYA常福螺旋藻酵素',
#  'AIRWAVES(清涼薄荷)',
#  'AK PASTA',
#  'AK Restaurant',
#  'Aka Renga 紅磚',
#  'akuma caca  可可設計人文咖啡',
#  'Al Dente Pasta',
#  'al sorriso Ｈome Hotel',
#  "Alexander's Steakhouse 亞歷山大牛排館",
#  'ALL IN Coffee',
#  "Alleycat's 手工窯烤披薩(世博館)",
#  'allin五青排空',
#  'allin金胎十勝原机',
#  'Allson Kitchen三賀家',
#  'ALOHA 海洋餐廳',
#  'Alouette Cafe 雲雀 咖啡•輕食',
#  'Alouette Salon 雲雀沙龍',
#  'Always Bar',
#  'ALWAYS歐維氏-巧克力',
#  'ALWAYS歐維氏-杏仁蔓越莓巧克力',
#  'ALWAYS歐維氏-跳跳糖巧克力',
#  'AMANA',
#  'AMANDIER CAFÉ(京站店)',
#  'Amandier雅蒙蒂法式甜點(京站時尚廣場)',
#  'Amazing Amy神奇艾米美式麻辣海鮮',
#  'Amazing Cafe奇益咖啡',
#  'Amazing Thai 愛麵館',
#  'Amazing55餐酒館',
#  'amba Taipei Ximending 台北西門町意舍酒-甜吧tianba',
#  'AMBROSIA 俺不捨高級餐廳',
#  'Amigos早午餐',
#  'AMIGO咖啡',
#  "Amin's book & cafe",
#  'Amis Pasta',
#  'Amore 小酒吧',
#  'Amoureux 純愛甜心',
#  'AMOUR阿摩爾烘培坊',
#  'Amo阿默典藏蛋糕(台中文心門市)',
#  'Amo阿默典藏蛋糕(新光三越A4館)',
#  'AMUSE 阿慕斯茶飲',
#  'Amy me～艾米米手工果醬',
#  'AM田原',
#  'AN Burger',
#  "An-ka Ca'fe 安卡咖啡",
#  'An Studio 客製化手工禮品工作室',
#  'ANAIS香妍小館',
#  'Ancre Cafe安克黑咖啡',
#  'ANDES安迪士雙薄荷巧克力',
#  'Angel de la Placa',
#  'Angel House 天使屋',
#  'Angel La La天使拉娜',
#  'Angel Land 天使品味體內環保創意料理',
#  'Angel Louis 安捷路易咖啡館(台北館)',
#  'Angel Mini Caf’e 行動咖啡車',
#  'Angelato安爵拉朵義大利手工冰淇淋',
#  'ANGEL窯烤披薩',
#  'Angry Birds Juice & Tea(中壢元化店)',
#  'Angry Burger憤怒漢堡',
#  'Anko西園',
#  'Ann&Cake',
#  'Anoka 南極冰川水',
#  'APPLE 203(基隆深溪店)',
#  'APPLE 203 蘋果203早午餐(宜蘭復興店)',
#  'APPLE 203 蘋果203早午餐(歸緩店)',
#  'APPLE 203 蘋果203早午餐(花連國聯店)',
#  'APPLE 203 蘋果203早午餐(迪化店)',
#  'APPLE 203 蘋果203早餐店',
#  'Apple 咖哩',
#  'APPLE',
#  'Apple203 Cafe(復興咖啡館)',
#  "April's 花愛巧克力  (微風台北車站)",
#  'AQA 凍圓茶品奶酪',
#  'AQUA Collagen Night & Day PHQ10 純膠原蛋白美肌粉',
#  'Aqua kiss 水吻3.0(美術館店)',
#  'Aqua Kiss水吻1969',
#  'AQUA(旗艦店)',
#  'ARABICA阿拉比卡',
#  'Aranzi Aronzo Cafe 阿朗基阿龍佐(站前店)',
#  'Aranzi Aronzo Cafe 阿朗基阿龍佐',
#  'Arcobaieno Shaveice 阿巴諾',
#  'AREA-51 串燒。啤酒。飛鏢吧',
#  'Ariel 愛瑞兒咖啡‧燕窩‧生活館',
#  'Armin Brunch & Coffee 阿曼早午晚餐',
#  'Armin Brunch & Coffee',
#  'Aroma Corner 馥隅',
#  'Aroma Ice cream',
#  'Aroma 自家烘焙咖啡',
#  'AROMA義大利坊',
#  'ARROW TREE(花蓮店)',
#  'ART BOX B.T.S',
#  'Art Cafe & Pasta',
#  'Art Lynn 無己之凡生活空間',
#  'Artco.c6',
#  'Artiste de pain【徐國斌】（原小王子烘焙坊.新店）',
#  'Artist亞堤司創意廚房',
#  'ARTTREE',
#  'ARVORIG crêperie bar',
#  'Asado美式西餐廳',
#  'ASAHI調情聖手雞尾酒  鹹狗',
#  "Ashmore's草莓牛奶巧克力",
#  'ASIR more  拉麵',
#  'Asoka艾莎歐卡',
#  'ATC alcohol tea coffee',
#  'ATT4FUN亞洲最大夢幻甜點主題樂園',
#  'ATT筷食尚',
#  'AU BON PAIN(機場店)',
#  'Au Curry',
#  'Aug. 歐格小館',
#  "Aunt Stella's 詩特莉餅乾咖啡(SOGO元化館)",
#  "Aunt Stella's 詩特莉餅乾咖啡(SOGO復興店)",
#  "Aunt Stella's 詩特莉餅乾咖啡(中壢店)",
#  "Aunt Stella's 詩特莉餅乾咖啡",
#  'AUNT STELLA 詩特莉手工餅乾 台北大高島屋店',
#  'Aunt Strlla(天母sogo)',
#  'Auntie Angel 手工檸檬愛玉',
#  "Auntie Annie's 安蒂思蝴蝶餅專賣店",
#  'Aunties Café 安提詩咖啡早午餐',
#  'Aura 微光咖啡',
#  'Aux allées vertes 綠廊精品美食',
#  'Awake til Sleep 醒而眠手烘咖啡吧',
#  'Awhile 外兒小館',
#  'A咖cafe',
#  'A咖啡',
#  'A贏香雞排可愛冷飲車',
#  'B.B Brunch大口咬手作早午歺',
#  'B cuisine studio 相信私廚',
#  'b-fun家庭親子餐廳',
#  'B.G 工房アイスーたい焼き 鯛魚燒專門店',
#  'B&G 德國農莊德式精品餐廳(信義Bellavita店)',
#  'B.K 韓式年糕專賣店',
#  'B.M.W big mouth woman',
#  'B. Waffle 鬆餅。班(敦南誠品店)',
#  'B1 Cafe',
#  'Ba.ra 水果總匯',
#  'BABOQ 献作黑糖飲品(中港店)',
#  "Baby Caf'e",
#  'Babywalker Cafe & Stroller',
#  'Bacio gelatod  高品質霜淇淋',
#  'Badauyao鮮釀餐廳',
#  'Bake Cheese Tart(漢神巨蛋店)',
#  'Baking Place 烘焙所在',
#  'Bakku 2 ½',
#  'Bakku餐廳',
#  'Balcony 陽台咖啡 Cafe',
#  'Ballon 輕 甜點工坊',
#  'Ballon\xa0輕 甜點工坊',
#  'Balzac Coffee & Wine 巴爾扎克',
#  'Bambino義式冰淇淋',
#  'Bamboo cafe',
#  'BANCO',
#  'BANCO棒可 窯烤PIZZA',
#  'Bangles Bistro班格斯西式餐館',
#  'BAO法式可麗餅(旱溪夜市)',
#  'BARCODE(高雄店)',
#  'BARISTA COFFEE 西雅圖極品咖啡(台大店)',
#  'BARISTA COFFEE 西雅圖極品咖啡(崇聖店)',
#  'BARISTA COFFEE 西雅圖極品咖啡(忠孝倍利店)',
#  'BARISTA COFFEE 西雅圖極品咖啡(明基店)',
#  'Bark2 酒吧 輕餐食(公園店)',
#  'Barkers',
#  'Barokahtoko',
#  'Basil Le Bistro',
#  'Baskin-Robbins 31冰淇淋(台北101店)',
#  'Baskin Robbins 31冰淇淋(大統和平店)',
#  'bato tea遊艇下午茶',
#  'BBS早午餐專門店 bake&butter sandwich',
#  'Be: 咖啡 藝文展演空間',
#  'Beans Lab 豆系研究室',
#  'BEAR HOUSE 熊屋',
#  "Bear's Marsh",
#  'BEARD PAPA’S 日式泡芙工房(微風站前店)',
#  'beard papa 日式泡芙工房(SOGO天母店)',
#  'beardpapa日式泡芙工房(SOGO復興店)',
#  'beardpapa日式泡芙工房(中壢元化館)',
#  'Beata té',
#  'Beatnik Cafe',
#  'Beauty小舖',
#  'Beauty小舖購物網(華聯國際生技有限公司)',
#  'BED LOUNGE(五福店)',
#  'Bed Plus',
#  'BEE CAF`E(永吉店)',
#  'Bee Honey 蜂巢冰淇淋',
#  'Bee&Milk(台中站前店)',
#  'Beer Beef 比爾比夫和牛熟成館',
#  'Beer & Cheese Social House',
#  'BeeTouched蜜蜂工坊',
#  'BeeZin康萃美活雪白丸',
#  'BeeZin康萃諾麗美舒眠錠',
#  'Belinda SilverFrost',
#  'Bella&joye',
#  'BELLINI CAFFE(敦南店)',
#  'BELLINI Pasta Pasta 貝里尼(復興店)',
#  'BELLINI Pasta Pasta 貝里尼(忠孝店)',
#  "BELLY'S TIME 複合式料理",
#  'BeMos墨西哥捲',
#  'BENA Love Song',
#  'Bengodi(（原義麵屋）)',
#  'bento超味魷魚',
#  'BESO cafe',
#  'BEST bistro貝斯特餐酒館',
#  'Better Man蔬食披薩專賣',
#  'Betterman Pizza x Coffee(元：Companio 手作食事)',
#  "Betty's Kitchen 貝蒂廚房",
#  'BEVIL惡魔蛋糕手工巧克力禮盒',
#  'Bhava。巴瓦咖啡食研室',
#  'Big John Pizza 醬醬披薩',
#  'BIG MA MA牛排料理廚坊',
#  'BIG MAMA(大勇店)',
#  'Big Pancia 大肚皮義式餐坊',
#  'BIG 超大牛排專賣店',
#  'BIGTOM美國冰淇淋文化館(國父紀念館翠湖店)',
#  'Bigtom美國冰淇淋文化館(漢神巨蛋店)',
#  'BIKE De Koffie 鋤和日好',
#  "Billie's waffle",
#  'Bingo 賓果廚房',
#  'Birdeye Espresso / 被愛咖啡',
#  'Bison野牛原味炭烤牛排(中央店)',
#  'Bison野牛牛排館(南崁店)',
#  'Bistro27',
#  'bistro88 義法餐酒館',
#  'Black as Chocolate(統一阪急百貨)',
#  'Black as Chocolate 黃湘怡的蛋糕店(中山店)',
#  'Black Bull Farm',
#  'BLACK CHANNEL clothing x cafe´',
#  'black coffee 布樂客咖啡',
#  'Blackpages CAFÉ(高雄sogo店)',
#  'BLISS果凍酒',
#  'Blooming Ice Sweet 花果茶霜淇淋專門店',
#  'BLUBLU Kafe 不如咖啡',
#  'Blue Moon Institute Coffee',
#  'BLUE NOTE藍調',
#  'BLUE VILLA 藍舍',
#  'Blue磚塊義法廚房',
#  "Bo's Kitchen 波妞廚房",
#  'BO 雪球餅乾咖啡館(中友百貨)',
#  'Bobii Frutii 珍珠水果特調',
#  'BoBio波碧兒 鎂日輕暢液',
#  'Boboli 波波里創義廚房',
#  'bobosa波波薩休閒小館(中山店)',
#  'Bocca di royal 義大利餐廳',
#  'BOG TEA ROOM',
#  'Boite de bijou 珠寶盒法式點心坊',
#  "Bola's Cooking 寶拉料理廚坊",
#  'BOLERO 波麗路西餐廳(本店)',
#  'Bon Bon 鄉村慢食小餐館',
#  'Bon Voyage Patisserie 感官之旅',
#  'BONA BONA Pasta',
#  'BonBon Sweet Dessert&Coffee',
#  'BonBons de Chocolat',
#  "BoNEW Cafe'",
#  'Bonjour Maman',
#  'bonjour(敦化店)',
#  'Bonjour 朋廚',
#  'BONJOUR帕里尼 輕食',
#  "Bonnie Cafe'",
#  'BooGoo布咕 cafe',
#  'Boost Juice Bars(忠孝店)',
#  'BOOST 博世特 美的冒泡發泡錠',
#  'BOSK’E 咖啡麵包坊',
#  'BOSSA NOVA 巴沙諾瓦',
#  'BOSSA音樂餐廳',
#  'BOSS沙威瑪',
#  'Bosun Coffee(汐止店)',
#  'Botega del Vin Taipei',
#  'Bottega Italia 義宝坊',
#  'Bottoms Up Saloon',
#  'Boulangerie Shan Wei 山崴烘焙',
#  'BOX複合式茶館',
#  'BOZZ COFFEE懶人咖啡館',
#  'BRANDS 白蘭氏學進雞精',
#  'Brasserie Liz 麗緻巴賽麗(新光中港店)',
#  'Brasserie Liz 麗緻巴賽麗',
#  'Bravo Beer布娜飛比利時啤酒餐廳(公益店)',
#  'Bravo Beer布娜飛比利時啤酒餐廳(板橋環球店)',
#  'Bravo Burger',
#  'Bravo Burger發福廚房(台大店)',
#  'Bravo Burger發福廚房(景美店)',
#  'Bravo Burger發福廚房(林口店)',
#  "Bravo's pasta(原：Pizza Factory 披薩工廠-霧峰店)",
#  'BRAVO普拉伯義大利坊(苗栗頭份店)',
#  'Bread First 麵包優先(微風車站店)',
#  'BREAD MEAT & SWEET',
#  'bread show麵包秀手感烘焙(自由店)',
#  'BREAD\u3000\u3000ＰＡＮ',
#  'BREFIS手工點心烘培坊',
#  'Bric Cafe(吳興店)',
#  'BRICK WORKS樂高積木主題餐廳(新竹世博店)',
#  'BRICK WORKS樂高積木主題餐廳(花博店)',
#  'Brick Yard 33 1/3 -BY33 美軍俱樂部',
#  'BrickYard33',
#  'Bridge Bistro',
#  'Brightness生態廚房',
#  'BROWN TAFFY 咖啡糖二店',
#  'Brownie 布藍里烘焙工房(京站店)',
#  'Brunch &',
#  'Bruner Café',
#  'Bsb美式餐廳',
#  'Bu Bu法式吐司專門店',
#  'Bubble tea',
#  'Bubble+果醋氣泡飲',
#  'Bubble阿偉飲品專賣店(鹿港頂番店)',
#  'BUGEL Bagel Coffee(新板壹號店)',
#  'Buii Café 羊淘咖啡',
#  'Buka 這一隻熊咖啡',
#  'Bula 冷奶油咖椰吐司',
#  'Bungy Jump Korean BBQ 笨豬跳(京華城店)',
#  'Buonasera 波娜席菈歐式餐酒館',
#  'Buongiorno 班吉諾',
#  'Buonissimo義式正統提拉米蘇',
#  'Buono Italian Kitchen 好家義式餐廳坊',
#  'Buono Pizza布諾手工窯烤薄脆披薩',
#  'burgar ray個性漢堡',
#  'Burger Joint 7分So 漢堡 早午餐專賣(朝富店)',
#  'Burger Joint 7分So 漢堡早午餐專賣(崇德店)',
#  'Burger Ray(士林店)',
#  'Burger Ray',
#  'Burger Talks 淘客美式漢堡(台北三創園區店)',
#  'Burger Talks 淘客美式漢堡(新北市三重旗艦店)',
#  'Burnt Charcoal Korean Barbeque 精緻韓式料理燒肉',
#  'BURTY柏堤咖啡輕食義式料理',
#  "Butcher's Kitchen 肉舖廚房",
#  'BUXIBAN 補習班',
#  'BW HOUSE黑白嗆義大利美食',
#  'B仔弄 韓國起司豬肋排(逢甲店)',
#  'C.C.KISS Coffee&Cake',
#  "C'est Bon 手工燒烤Pizza",
#  "C'est La vie 五味瓶",
#  'C.H.Home 手作嚴選料理',
#  'C ice Sorriso西微廚房',
#  'C.W. Brunch House',
#  'C25 Plus',
#  'C25度咖啡館',
#  'ca va 小日和',
#  'CABY CAFE & Design',
#  'Cadeau可朵法式甜點',
#  "Caf'e De Aiffel 艾爾咖啡館",
#  "Caf'e est 易斯特咖啡",
#  'Cafe 702',
#  "Cafe' Arena",
#  'Cafe balcony 柏肯尼咖啡',
#  'Cafe Ballet 芭蕾咖啡館',
#  "Cafe' Coabana (古巴娜咖啡）",
#  "Cafe' de Corner",
#  'Cafe Hunter 獵咖啡',
#  'CAFE IE89',
#  'CAFE IN AUDIO',
#  'Cafe i呦喂呀',
#  'Cafe Lugo(101店)',
#  'CAFE LULU(總店)',
#  'Cafe Marche 咖啡瑪榭(忠孝店)',
#  'Cafe & Me',
#  'Cafe Rebecca小曼咖啡',
#  'Cafe RITIZZA',
#  'CAFE SLOW TRAIN小火車咖啡館',
#  'Cafe Smith(總店)',
#  'Cafe Trico',
#  'cafe wien',
#  'cafe主題館',
#  'Cafe食堂KenKen',
#  'caff&ice cream(新光三越A4店)',
#  'CAFF LATTE',
#  'Caffe bene(中正店)',
#  'Caffe bene(台中大遠百店)',
#  'Caffe Chat咖啡講',
#  'Caffe Ritazza(台中高鐵)',
#  'Caffe Vintage聞豆奇咖啡館',
#  'Caffè Quodlibet 咖啡樂覺',
#  'CAFÉ  Alfred  愛我的．咖啡',
#  "Café d'Amour",
#  'Café Lounge',
#  'Café Trip 咖啡旅行',
#  'Caldi Coffee 卡爾地自家烘焙咖啡館',
#  'CALL ME HOME 可米宏鍋物飲品',
#  'cama 現烘咖啡專門店(天津店)',
#  'cama 現烘咖啡專門店(忠孝敦化店)',
#  'cama 現烘咖啡專門店(新竹光復店)',
#  'cama 現烘咖啡專門店(永和店)',
#  'cama 現烘咖啡專門店(英才店)',
#  'cama 現烘咖啡專門店',
#  'Canopy卡諾比新鮮慢磨果汁',
#  'CAPATINA義式冰淇淋(漢神百貨)',
#  'Capricciosa卡布里喬莎((太平洋SOGO 新竹店站前館))',
#  'Captain India 印度隊長',
#  'Caramel Park 台南東區包心粉圓(台北忠孝店)',
#  'Caramel Park台南東區焦糖煉乳包心粉圓(台北忠孝店)',
#  'Caramel Park焦糖公園(光華店)',
#  "Carol's Gelato",
#  "Carrie's",
#  'Carzy Cart Cafe by TDS',
#  'CASA DELLA PASTA義麵坊(忠孝敦化店)',
#  'Casa Picasso',
#  'CASA',
#  'Casa咖薩 咖啡披薩手作坊',
#  'CAS優良水產品~東晟鱸魚',
#  'Cava 早安˙日安',
#  'CBD cafe',
#  'CCC咖啡早午餐',
#  'Cc老爹手作炸雞店',
#  'Cendy Caffe  仙笛咖啡',
#  'CHA CHA gelato',
#  'Cha Cha Thé 采采食茶文化',
#  "Chan'to Patisserie 香豆歐法手作甜點(微風廣場GF專櫃)",
#  'CHANG PEIYI 品貽乳酪蛋糕',
#  'Changex',
#  'Charco house手作廚房',
#  'Charmy 雪花冰(竹東店)',
#  'Chateau',
#  'Chateraise莎得徠茲(逢甲店)',
#  'Chatime Lounge',
#  'cheela 小屋',
#  'Cheers 茶爾斯(高雄旗艦店)',
#  'Cheers 起司工坊',
#  'Cheese bon',
#  'Cheese Cake 乳酪蛋糕 士林夜市',
#  'Cheese Way',
#  'CheeseCake1(新光三越A4館B2)',
#  'CheeseCake1頂級精品乳酪蛋糕',
#  'Chef HöKA荷卡廚坊義大利濃湯麵',
#  'CHEFFRESH',
#  'Cherii天然酵母麵包',
#  'CHERRY經典咖啡',
#  'Chess : Pizzeria & Bar 披薩餐酒館',
#  'CHEZ MOI。88-2',
#  'CHEZ PAPA',
#  "Chia's Time奇亞籽",
#  'ChiaoDuo House巧哚洋房餐飲坊',
#  'CHIC CAFÉ 奇可小廚',
#  'Chicking - 韓國歐爸呀炸雞',
#  'CHiC軟糖',
#  "Chili's Grill & Bar 美式休閒餐廳(信義店)",
#  "Chili's Grill & Bar 美式休閒餐廳 (台中店)",
#  "Chili's Grill & Bar 美式休閒餐廳 (民生店)",
#  'CHILI STEAK紅蕃牛排',
#  'Chill Art Center',
#  'Chill Bake',
#  'Chin Chin Cafe',
#  'CHINTA BAR(總店)',
#  'Chiyis齊益烘焙坊',
#  'CHIYODASUSHI千代田(大樂店)',
#  'Chiz UP 美式濃郁起司蛋糕',
#  'Choc for you',
#  'Chochoco(中港店)',
#  'choco choco手工巧克力',
#  'ChocoArt',
#  'CHOCOARTS 喬克亞司',
#  'Choir Cafe',
#  'ChoJung椒井天然氣泡礦泉水',
#  'Chop Chop 恰恰食堂親子餐廳',
#  'CHOW CHOW BAGEL',
#  'Chow Chow Brunch',
#  'Chu Coffee 啾咖啡(板橋環球店)',
#  'Chu Coffee 啾咖啡',
#  'ChuChu Pâtisserie 法式甜點',
#  'Chungci Bakery',
#  "Churro'K 啾拿棒專賣店",
#  'Ciao.O 敲我烘培工作室',
#  'Ciao巧義大利麵',
#  'CinCin 請請義大利餐廳',
#  'Cine Cafe',
#  'City Light 義大實習餐廳',
#  'City Linker',
#  'CITY MILK木瓜牛奶(一中店)',
#  'CITY MILK木瓜牛奶(新店大豐店)',
#  'CITY SUPER',
#  'Cité forêt',
#  'CJ bistro',
#  'CJSJ',
#  'classmate義大利麵',
#  "Cliff's Pizza 克里夫比薩",
#  "Clock Caf'e 小時鐘手工咖啡輕食",
#  'CLOUDY CUPCAKE 克勞蒂杯子蛋糕(信義誠品店)',
#  'CLOUDY CUPCAKE 克勞蒂杯子蛋糕(高雄明華店)',
#  'Clover Cafe 幸韻草咖非廚房',
#  'Club X',
#  'CMYK GALLERY',
#  'CM咖啡輕食',
#  'CNI人參金咖啡',
#  'CO2 CAFE & TEA',
#  'CoCa MaMa巧克力工坊',
#  'COCA泰式風味料理(中壢店)',
#  'Coco Brother 椰子冰淇淋',
#  'Coco brunch',
#  'CoCo Line異國館',
#  "CoCo's food 早午餐",
#  'COCO 元元美式炸雞',
#  'CoCo 都可(三芝)',
#  'CoCo 都可茶飲(老街)',
#  'Cocobear烘焙坊',
#  'cocoBrownies可可布朗尼',
#  'COCOMAKER 可可美克巧克力',
#  'COCOMAKER',
#  'coconia巧克力專賣店',
#  'COCO壱番屋(台南新天地)',
#  'CoCo壱番屋(徐匯店)',
#  'COCO壱番屋咖哩餐廳(松高路店)',
#  'coco壹番屋',
#  'CoCo壹番屋咖哩飯(大直美麗華店)',
#  'CoCo都可(內壢忠孝店)',
#  ...]

# %% [markdown]
# # bs抓取某tag or tag群的方法
# soup.select("tag > tag > tag") 如:soup.select("#search > article > hgroup > h2 > b")
#
# soup.find_all('tag', attrs={'tag內的元素': '元素名稱'}) 如:soup.find_all('a', attrs={'data-label': '店名'})
