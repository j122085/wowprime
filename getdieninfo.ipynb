# %% [markdown]
# # try getinfo

# %%
# import os
# from bs4 import BeautifulSoup as bs
# import re
# with open("./data/html/極幻燒肉弁当.html","r",encoding='utf8') as f:
#     dienhtml=f.read()
#     soup=bs(dienhtml, "lxml")
    
    
# int(re.findall("http:\/\/www\.ipeen\.com\.tw\/shop\/([0-9]+)\'",soup.text)[0])#id
# info=soup.select_one("#shop-header > div.info")
# info.find('span', attrs={'itemprop': 'name'}).text#name
# soup.find('a', attrs={'data-label': '詳細資訊_大分類'}).text#bigstyle
# info.find('a', attrs={'data-label': '上方小分類'}).text#smallstyle
# int(re.findall("本店均消 +([0-9]+) +元",info.select_one('p.cost.i').text)[0])#averagecost
# info.find('a', attrs={'data-label': '上方電話'}).text.replace("-","")#tele
# re.findall("..[市|縣].+[區|市].+[路|街|地段|巷][0-9]+[-|之]?[0-9]*?[號|巷|弄]?[0-9]*[號|巷|弄|樓]",
#            info.find('a', attrs={'data-label': '上方地址'}).text)[0]#add
# re.findall("\/c=([0-9]+\.[0-9]+)\,([0-9]+\.[0-9]+)\/z=",info.find('a', attrs={'data-label': '上方地址'})["href"])[0]#lat.lng
# int(re.findall("會員分享文 \(([0-9]+)\)",soup.text)[0])#Ncomment
# int(info.select_one("span.score-bar.large > meter")['value'])
# if "已歇業" in info.select_one("h1").text:
#     print("結束營業")
# else:
#     print("正常營業")#status
# re.findall("共([0-9]+)人瀏覽([0-9]+)人收藏",info.select_one("div.scalar").text.
#            replace(",","").replace("\n","").replace(" ",""))[0]#viewcount.collecount
# re.findall("更新時間(\d{4}\/\d{2}\/\d{2})",soup.select_one("div#shop-details").text.
#            replace("\n","").replace(" ",""))[0]#renewtime

# %% [markdown]
# # 第二版 須改邏輯為ID(唯一)

# %%
# import os
# from bs4 import BeautifulSoup as bs
# import json
# import re
# dienlist=[]
# print("共有"+str(len(os.listdir("./data/html")))+"筆資料")
# n=0


# if os.path.exists('./data/diendata.json'):
#     with open("./data/diendata.json","r") as d:
#         dienlist=json.load(d)
#         n=len(dienlist)
        
# finishdien=[dien['name'] for dien in dienlist]
        


# for file in os.listdir("./data/html"):
#     if n%50==0:
#         print(n)
#         with open("./data/diendata.json","w") as d:
#             json.dump(dienlist,d)
        
#     if file.split(".")[0].replace('"',"") not in finishdien:
#         n+=1
#         with open("./data/html/"+file,"r",encoding='utf8') as f:
#             diendata={}
#             dienhtml=f.read()
#             soup=bs(dienhtml,"lxml")
#             info=soup.select_one("#shop-header > div.info")

#             diendata["id"]=int(re.findall("http:\/\/www\.ipeen\.com\.tw\/shop\/([0-9]+)\'",soup.text)[0])#id
#             diendata["name"]=info.find('span', attrs={'itemprop': 'name'}).text.replace('"',"")
#             diendata["bigstyle"]=soup.find('a', attrs={'data-label': '詳細資訊_大分類'}).text
#             diendata["smallstyle"]=info.find('a', attrs={'data-label': '上方小分類'}).text

#             try:
#                 diendata["averagecost"]=int(re.findall("本店均消 +([0-9]+) +元",info.select_one('p.cost.i').text)[0])
#             except:
#                 diendata["averagecost"]=0
#             try:
#                 diendata["tele"]=info.find('a', attrs={'data-label': '上方電話'}).text.replace("-","")#tele
#             except:
#                 diendata["tele"]=0
#             try:
#                 diendata["address"]=re.findall("..[市|縣].+[區|市].+[路|街|地段|巷][0-9]+[-|之]?[0-9]*?[號|巷|弄]?[0-9]*[號|巷|弄|樓]",
#                        info.find('a', attrs={'data-label': '上方地址'}).text)[0]#add
#             except:
#                 diendata["address"]=0

#             try:
#                 diendata["lat"]=float(re.findall("\/c=([0-9]+\.[0-9]+)\,([0-9]+\.[0-9]+)\/z=",
#                                                info.find('a', attrs={'data-label': '上方地址'})["href"])[0][0])#lat.lng
#             except:
#                 diendata["lat"]=0
#             try:
#                 diendata["lng"]=float(re.findall("\/c=([0-9]+\.[0-9]+)\,([0-9]+\.[0-9]+)\/z=",
#                                                info.find('a', attrs={'data-label': '上方地址'})["href"])[0][1])#lat.lng
#             except:
#                 diendata["lng"]=0
#             try:
#                 diendata["Ncomment"]=int(re.findall("會員分享文 \(([0-9]+)\)",soup.text)[0])#Ncomment
#             except:
#                 diendata["Ncomment"]=0
#             diendata["ipeenscore"]=int(info.select_one("span.score-bar.large > meter")['value'])#ipeenscore
#             if "已歇業" in info.select_one("h1").text:
#                 diendata["status"]="結束營業"
#             else:
#                 diendata["status"]="正常營業"
#             diendata["viewcount"]=int(re.findall("共([0-9]+)人瀏覽([0-9]+)人收藏",info.select_one("div.scalar").text.
#                        replace(",","").replace("\n","").replace(" ",""))[0][0])#viewcount
#             diendata["collecount"]=int(re.findall("共([0-9]+)人瀏覽([0-9]+)人收藏",info.select_one("div.scalar").text.
#                        replace(",","").replace("\n","").replace(" ",""))[0][1])#collecount
#             diendata["reviewdate"]=re.findall("更新時間(\d{4}\/\d{2}\/\d{2})",soup.select_one("div#shop-details").text.
#                        replace("\n","").replace(" ",""))[0]#renewdate
#         dienlist.append(diendata)
#     else:
#         print("已有資料"+file)
    
# with open("./data/diendata.json","w") as d:
#     json.dump(dienlist,d)

# %% [markdown]
# # 第三版 唯一值為ID 不重複 考慮將資料存成好幾個檔案(每個檔案一家店?)
# # 目前資料約需2小整理
# 目前問題：儲存資料時，如遇到不可預期停止或手動停止，資料會只存一半，如果都存同一個檔案，會有壞掉的檔案蓋掉原始資料檔的問題

# %%
import os
from bs4 import BeautifulSoup as bs
import json
import re
dienlist=[]

#確認目前有多少網址的資料需要抓取
print("共有"+str(len(os.listdir("./data/html2")))+"筆資料")
n=0

#確認已完成資料抓取的店家id
finishdien=[]
if os.path.exists('./data/diendata.json'):
    with open("./data/diendata.json","r") as d:
        dienlist=json.load(d)
        n=len(dienlist)+1
        finishdien=set([dien['id'] for dien in dienlist])

#抓取不存在於finish的店家id資料
for file in os.listdir("./data/html2"):
    if int(file.split(".")[0]) not in finishdien:
        n+=1
        
        #每300筆資料儲存一次
        if n%300==0:
            with open("./data/diendata.json","w") as d:
                json.dump(dienlist,d)
            print("已存%s筆資料"%n)
           
        with open("./data/html2/"+file,"r",encoding='utf8') as f:
            diendata={}
            dienhtml=f.read()
            soup=bs(dienhtml,"lxml")
            info=soup.select_one("#shop-header > div.info")

            diendata["id"]=int(re.findall("http:\/\/www\.ipeen\.com\.tw\/shop\/([0-9]+)\'",soup.text)[0])#id
            diendata["name"]=info.find('span', attrs={'itemprop': 'name'}).text.replace('"',"")
            diendata["bigstyle"]=soup.find('a', attrs={'data-label': '詳細資訊_大分類'}).text
            diendata["smallstyle"]=info.find('a', attrs={'data-label': '上方小分類'}).text

            try:
                diendata["averagecost"]=int(re.findall("本店均消 +([0-9]+) +元",info.select_one('p.cost.i').text)[0])
            except:
                diendata["averagecost"]=0
            try:
                diendata["tele"]=info.find('a', attrs={'data-label': '上方電話'}).text.replace("-","")#tele
            except:
                diendata["tele"]=0
            try:
                diendata["address"]=re.findall("..[市|縣].+[區|市].+[路|街|地段|巷][0-9]+[-|之]?[0-9]*?[號|巷|弄]?[0-9]*[號|巷|弄|樓]",
                       info.find('a', attrs={'data-label': '上方地址'}).text)[0]#add
            except:
                diendata["address"]=0

            try:
                diendata["lat"]=float(re.findall("\/c=([0-9]+\.[0-9]+)\,([0-9]+\.[0-9]+)\/z=",
                                               info.find('a', attrs={'data-label': '上方地址'})["href"])[0][0])#lat.lng
            except:
                diendata["lat"]=0
            try:
                diendata["lng"]=float(re.findall("\/c=([0-9]+\.[0-9]+)\,([0-9]+\.[0-9]+)\/z=",
                                               info.find('a', attrs={'data-label': '上方地址'})["href"])[0][1])#lat.lng
            except:
                diendata["lng"]=0
            try:
                diendata["Ncomment"]=int(re.findall("會員分享文 \(([0-9]+)\)",soup.text)[0])#Ncomment
            except:
                diendata["Ncomment"]=0
            diendata["ipeenscore"]=int(info.select_one("span.score-bar.large > meter")['value'])#ipeenscore
            if "已歇業" in info.select_one("h1").text:
                diendata["status"]="結束營業"
            else:
                diendata["status"]="正常營業"
            diendata["viewcount"]=int(re.findall("共([0-9]+)人瀏覽([0-9]+)人收藏",info.select_one("div.scalar").text.
                       replace(",","").replace("\n","").replace(" ",""))[0][0])#viewcount
            diendata["collecount"]=int(re.findall("共([0-9]+)人瀏覽([0-9]+)人收藏",info.select_one("div.scalar").text.
                       replace(",","").replace("\n","").replace(" ",""))[0][1])#collecount
            diendata["reviewdate"]=re.findall("更新時間(\d{4}\/\d{2}\/\d{2})",soup.select_one("div#shop-details").text.
                       replace("\n","").replace(" ",""))[0]#renewdate
        dienlist.append(diendata)
    else:
#         print("已有資料"+file)
        pass
#抓取完畢後儲存資料
with open("./data/diendata.json","w") as d:
    json.dump(dienlist,d)
print("已完成，共存%s筆資料"%n)
# Out:
# 共有162364筆資料
# 已存162600筆資料
# 已存162900筆資料
# 已存163200筆資料
# 已存163500筆資料
# 已完成，共存163610筆資料

# %% [markdown]
# # 第四版，變更已搬遷 規則，新增commit連結、URL、加入爬蟲睡眠機制
# ## 資料內有LIST格式的資料，如要存進sql需要存兩個以上的表格

# %%
import os
from bs4 import BeautifulSoup as bs
import json
import re
import time
import requests
dienlist=[]

#確認目前有多少網址的資料需要抓取
print("共有"+str(len(os.listdir("./data/html2")))+"筆資料")

savePath='./data/diendataAddCommentUrl.json'
#k用以計算店家筆數
k=0
#確認已完成資料抓取的店家id
finishdien=[]
if os.path.exists(savePath):
    with open(savePath,"r") as d:
        dienlist=json.load(d)
        k=len(dienlist)
        finishdien=set([dien['id'] for dien in dienlist])
        
#n用以計算requests次數
n=0
#抓取不存在於finish的店家id資料
for file in os.listdir("./data/html2"):
    if int(file.split(".")[0]) not in finishdien:
        k+=1
        with open("./data/html2/"+file,"r",encoding='utf8') as f:
            diendata={}
            dienhtml=f.read()
            soup=bs(dienhtml,"lxml")
            info=soup.select_one("#shop-header > div.info")

            diendata["id"]=int(re.findall("http:\/\/www\.ipeen\.com\.tw\/shop\/([0-9]+)\'",soup.text)[0])#id
            diendata["name"]=info.find('span', attrs={'itemprop': 'name'}).text.replace('"',"")
            diendata["bigstyle"]=soup.find('a', attrs={'data-label': '詳細資訊_大分類'}).text
            diendata["smallstyle"]=info.find('a', attrs={'data-label': '上方小分類'}).text

            try:
                diendata["averagecost"]=int(re.findall("本店均消 +([0-9]+) +元",info.select_one('p.cost.i').text)[0])
            except:
                diendata["averagecost"]=0
            try:
                diendata["tele"]=info.find('a', attrs={'data-label': '上方電話'}).text.replace("-","")#tele
            except:
                diendata["tele"]=0
            try:
                diendata["address"]=re.findall("..[市|縣].+[區|市].+[路|街|地段|巷][0-9]+[-|之]?[0-9]*?[號|巷|弄]?[0-9]*[號|巷|弄|樓]",
                       info.find('a', attrs={'data-label': '上方地址'}).text)[0]#add
            except:
                diendata["address"]=0

            try:
                diendata["lat"]=float(re.findall("\/c=([0-9]+\.[0-9]+)\,([0-9]+\.[0-9]+)\/z=",
                                               info.find('a', attrs={'data-label': '上方地址'})["href"])[0][0])#lat.lng
            except:
                diendata["lat"]=0
            try:
                diendata["lng"]=float(re.findall("\/c=([0-9]+\.[0-9]+)\,([0-9]+\.[0-9]+)\/z=",
                                               info.find('a', attrs={'data-label': '上方地址'})["href"])[0][1])#lat.lng
            except:
                diendata["lng"]=0
            try:
                diendata["Ncomment"]=int(re.findall("會員分享文 \(([0-9]+)\)",soup.text)[0])#Ncomment
            except:
                diendata["Ncomment"]=0
                
            #第四版變更---------------------
            diendata["url"]="http://www.ipeen.com.tw/shop/"+file.split(".")[0]
            commentPage=int(diendata["Ncomment"]/5)+1
            peenlist=[]
            for i in range(1,commentPage+1):
                url2=diendata["url"]+'/comments?p='+str(i)
                res2=requests.get(url2)
                
                n+=1
                #每90筆requests資料儲存一次
                if n%90==0:
                    with open(savePath,"w") as d:
                        json.dump(dienlist,d)
                    print("已存%s筆店家資料"%k)
                #每45筆睡5秒，以防ban
                if n%45==0:
                    time.sleep(5)
                
                if res2.status_code == 200:
                    soup2=bs(res2.text,'lxml')
                    res2.close()
                    pagepeenlist=['http://www.ipeen.com.tw'+i['href'] for i in soup2.select("p.summary > a") if "checkin" not in i['href']]
                    peenlist+=pagepeenlist
            diendata["comments"]=peenlist
            #第四版變更---------------------  
            diendata["ipeenscore"]=int(info.select_one("span.score-bar.large > meter")['value'])#ipeenscore
            if "已歇業" in info.select_one("h1").text:
                diendata["status"]="結束營業"
            elif "已搬遷" in info.select_one("h1").text:
                continue
            else:
                diendata["status"]="正常營業"
            diendata["viewcount"]=int(re.findall("共([0-9]+)人瀏覽([0-9]+)人收藏",info.select_one("div.scalar").text.
                       replace(",","").replace("\n","").replace(" ",""))[0][0])#viewcount
            diendata["collecount"]=int(re.findall("共([0-9]+)人瀏覽([0-9]+)人收藏",info.select_one("div.scalar").text.
                       replace(",","").replace("\n","").replace(" ",""))[0][1])#collecount
            diendata["reviewdate"]=re.findall("更新時間(\d{4}\/\d{2}\/\d{2})",soup.select_one("div#shop-details").text.
                       replace("\n","").replace(" ",""))[0]#renewdate
        dienlist.append(diendata)
    else:
#         print("已有資料"+file)
        pass
#抓取完畢後儲存資料
with open(savePath,"w") as d:
    json.dump(dienlist,d)
# Out:
# 共有162042筆資料
# 已存68筆資料
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# D:\anaconda\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379             try:  # Python 2.7, use buffering of HTTP responses
# --> 380                 httplib_response = conn.getresponse(buffering=True)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-142-a4ed5837f4ff> in <module>()
#      73             for i in range(1,commentPage+1):
#      74                 url2=diendata["url"]+'/comments?p='+str(i)
# ---> 75                 res2=requests.get(url2)
#      76
#      77                 n+=1
#
# D:\anaconda\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# D:\anaconda\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# D:\anaconda\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# D:\anaconda\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     616
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#     620         # Total elapsed time of the request (approximately)
#
# D:\anaconda\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438                     decode_content=False,
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#     442
#
# D:\anaconda\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   timeout=timeout_obj,
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#     603             # If we're going to release the connection in ``finally:``, then
#
# D:\anaconda\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#     382                 try:
# --> 383                     httplib_response = conn.getresponse()
#     384                 except Exception as e:
#     385                     # Remove the TypeError from the exception chain in Python 3;
#
# D:\anaconda\lib\http\client.py in getresponse(self)
#    1329         try:
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#    1333                 self.close()
#
# D:\anaconda\lib\http\client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# D:\anaconda\lib\http\client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# D:\anaconda\lib\socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %% [markdown]
# # 用來確認會造成BUG的店家名稱

# %%
for i in dienlist:
    print(i["name"])
    possible_json_string = '[{"a":"'+i["name"]+'","b":"2"},{"c":3.6,"d":""}]'
    js = json.loads(possible_json_string)
    print(i['name'])
# Out:
# 麥當勞(新營家樂福店)
# 麥當勞(新營家樂福店)
# 岩谷新鐵板料理Rock Valley(台北信義總店)
# 岩谷新鐵板料理Rock Valley(台北信義總店)
# 阿宏日式料理
# 阿宏日式料理
# NU PASTA(台中向心店)
# NU PASTA(台中向心店)
# 包心粉圓 埔里點
# 包心粉圓 埔里點
# 清水王牌-筒仔米糕
# 清水王牌-筒仔米糕
# 凱恩斯岩燒餐廳(台北大安店)
# 凱恩斯岩燒餐廳(台北大安店)
# 梁媽媽麵線糊
# 梁媽媽麵線糊
# 98日式拉麵
# 98日式拉麵
# Qcar柴燒窯烤披薩
# Qcar柴燒窯烤披薩
# Aunt Stella's 詩特莉餅乾咖啡(中壢店)
# Aunt Stella's 詩特莉餅乾咖啡(中壢店)
# 沁香豆花
# 沁香豆花
# 日初食事
# 日初食事
# 天水玥秘境鍋物殿
# 天水玥秘境鍋物殿
# 吳記台灣小吃牛肉麵
# 吳記台灣小吃牛肉麵
# 川味小吃
# 川味小吃
# 三峽麵線阿峯
# 三峽麵線阿峯
# 桂格燕麥方脆
# 桂格燕麥方脆
# 蘇菠麵
# 蘇菠麵
# 艾薇恩工作室 Elvian Handmade
# 艾薇恩工作室 Elvian Handmade
# 酒鄉燒烤屋
# 酒鄉燒烤屋
# 呷尚宝複合式早餐
# 呷尚宝複合式早餐
# 黎家香港茶餐廳
# 黎家香港茶餐廳
# 六角工房
# 六角工房
# 白日夢
# 白日夢
# 實味香食品
# 實味香食品
# 小韓國雞蛋糕
# 小韓國雞蛋糕
# 寶哥爌肉飯
# 寶哥爌肉飯
# 辛咖哩
# 辛咖哩
# 歐森晨間廚房
# 歐森晨間廚房
# 小米義式廚房
# 小米義式廚房
# 樸儷花園Simply
# 樸儷花園Simply
# Art Cafe & Pasta
# Art Cafe & Pasta
# MIM CAFE
# MIM CAFE
# 古早味蚵嗲.剉冰
# 古早味蚵嗲.剉冰
# 韓牛村
# 韓牛村
# (好市多/大順店)新鮮草莓千層蛋糕
# (好市多/大順店)新鮮草莓千層蛋糕
# Fatty's 義式餐廳(瑞光店)
# Fatty's 義式餐廳(瑞光店)
# 金德春捲店
# 金德春捲店
# 于記杏仁豆腐專賣店(新光 A11 店)
# 于記杏仁豆腐專賣店(新光 A11 店)
# 韓宮 韓式料理
# 韓宮 韓式料理
# 西勢無名肉粿
# 西勢無名肉粿
# 清香小吃店
# 清香小吃店
# 九州鬆餅(台北富錦店)
# 九州鬆餅(台北富錦店)
# 順億鮪魚專賣店(漢口店)
# 順億鮪魚專賣店(漢口店)
# 嘉義粉條冰
# 嘉義粉條冰
# 川味麵館
# 川味麵館
# LATTEA綠蓋茶館(忠孝216店)
# LATTEA綠蓋茶館(忠孝216店)
# 五井拉麵(中壢中北店)
# 五井拉麵(中壢中北店)
# Alleycat's 手工窯烤披薩(東湖店)
# Alleycat's 手工窯烤披薩(東湖店)
# 首採茶水舖(台中東海店)
# 首採茶水舖(台中東海店)
# 大菜市鮮魚湯
# 大菜市鮮魚湯
# 泰拉瑪香蕉煎餅
# 泰拉瑪香蕉煎餅
# 粥遊天下(沙鹿店)
# 粥遊天下(沙鹿店)
# 淨光心香素食館
# 淨光心香素食館
# 兔兒咖啡 tour cafe
# 兔兒咖啡 tour cafe
# 雅園熱炒
# 雅園熱炒
# 開喜 梅嶺梅子茶
# 開喜 梅嶺梅子茶
# FUN4(高醫店)
# FUN4(高醫店)
# 「杜老爺」O'Black咖啡甜筒
# 「杜老爺」O'Black咖啡甜筒
# 手工包子
# 手工包子
# 橘村園
# 橘村園
# 府城體育公園杏仁豆腐冰(仁德德安店)
# 府城體育公園杏仁豆腐冰(仁德德安店)
# 歇腳亭(館前店)
# 歇腳亭(館前店)
# Texas Roadhouse德州鮮切牛排
# Texas Roadhouse德州鮮切牛排
# 阿仁福州包
# 阿仁福州包
# 魔術食品/奈'S菌乳酸菌粉
# 魔術食品/奈'S菌乳酸菌粉
# 台灣香蕉麵
# 台灣香蕉麵
# 品宴鍋物
# 品宴鍋物
# 雞大爺
# 雞大爺
# 東華166號
# 東華166號
# 虱目魚菲力脆片-海苔
# 虱目魚菲力脆片-海苔
# 古早滷味
# 古早滷味
# 蜜蜂小吧快餐車 bee bar
# 蜜蜂小吧快餐車 bee bar
# 麻姥姥手工餅舖
# 麻姥姥手工餅舖
# 芋泥餅
# 芋泥餅
# 義式意適
# 義式意適
# 樂樂小時光 Le Organic Babe Family Friendly Bistro
# 樂樂小時光 Le Organic Babe Family Friendly Bistro
# 你滋美得
# 你滋美得
# 第一家蒜味鴨賞麵線
# 第一家蒜味鴨賞麵線
# 御食鮮沙茶雞
# 御食鮮沙茶雞
# 玉佳珍肉圓
# 玉佳珍肉圓
# BELLAVITA CAFÉ
# BELLAVITA CAFÉ
# 梨園小吃店
# 梨園小吃店
# 廣豐燒臘
# 廣豐燒臘
# 黃家古早味美食
# 黃家古早味美食
# 祥鶴家南洋創意料理
# 祥鶴家南洋創意料理
# Mon cafe
# Mon cafe
# 伊豆食堂
# 伊豆食堂
# 啜飲室
# 啜飲室
# 江蘇 清水大閘蟹
# 江蘇 清水大閘蟹
# 泓谷餐廳
# 泓谷餐廳
# 小紅帽義式冰淇淋
# 小紅帽義式冰淇淋
# 元世祖火鍋店
# 元世祖火鍋店
# 太將鍋(太將鍋[頭份店])
# 太將鍋(太將鍋[頭份店])
# MuMu手作巧克力
# MuMu手作巧克力
# Costco好市多 全麥核桃葡萄麵包
# Costco好市多 全麥核桃葡萄麵包
# 領袖山莊 Leader(原嶺秀山莊)
# 領袖山莊 Leader(原嶺秀山莊)
# bread show麵包秀手感烘焙(自由店)
# bread show麵包秀手感烘焙(自由店)
# 南木町割烹料理
# 南木町割烹料理
# 30 Thirty 老酒館
# 30 Thirty 老酒館
# 鼎盛十里鍋の物
# 鼎盛十里鍋の物
# CITY MILK木瓜牛奶(新店大豐店)
# CITY MILK木瓜牛奶(新店大豐店)
# 大戶屋(南紡購物中心店)
# 大戶屋(南紡購物中心店)
# 炸蛋吐司
# 炸蛋吐司
# 心丼隱食堂(心丼隱食堂)
# 心丼隱食堂(心丼隱食堂)
# CITY MILK木瓜牛奶(一中店)
# CITY MILK木瓜牛奶(一中店)
# 團購大國民-一中金燒
# 團購大國民-一中金燒
# YUMMI HUB(大直店)
# YUMMI HUB(大直店)
# Think Cafe
# Think Cafe
# 卡麥哆
# 卡麥哆
# 台南旺海產店．鱔魚意麵
# 台南旺海產店．鱔魚意麵
# 餃子工坊(新市總店)
# 餃子工坊(新市總店)
# 90後 JoHouLim(台北西門店)
# 90後 JoHouLim(台北西門店)
# 好滋味蒸餃麵館
# 好滋味蒸餃麵館
# 彤心威眠胡椒餅
# 彤心威眠胡椒餅
# 山門咖啡
# 山門咖啡
# KP魔幻藝術咖啡屋
# KP魔幻藝術咖啡屋
# 德式香腸起司洋芋
# 德式香腸起司洋芋
# 家邊咖啡
# 家邊咖啡
# gou jia果家鮮果概念店
# gou jia果家鮮果概念店
# 水龍牛排
# 水龍牛排
# Bamboo cafe
# Bamboo cafe
# 松之露養生飲品
# 松之露養生飲品
# 炭根炭烤吐司俱樂部
# 炭根炭烤吐司俱樂部
# 邵師傅上海湯包
# 邵師傅上海湯包
# T.M手作米香菓
# T.M手作米香菓
# 阿桃烤玉米
# 阿桃烤玉米
# 八方雲集水餃鍋貼專賣店(台南佳里店)
# 八方雲集水餃鍋貼專賣店(台南佳里店)
# 品麵包
# 品麵包
# Helium Aurum 德里歐 鈣+酵素
# Helium Aurum 德里歐 鈣+酵素
# Q Burger饗樂早午餐(永平店)
# Q Burger饗樂早午餐(永平店)
# Lucid手作 南瓜鹹粿
# Lucid手作 南瓜鹹粿
# 北港元福麻油廠
# 北港元福麻油廠
# 九龍燒臘
# 九龍燒臘
# 魔力小樂
# 魔力小樂
# 法蕾熊手工經典舒芙蕾
# 法蕾熊手工經典舒芙蕾
# 一本日式咖哩專賣店
# 一本日式咖哩專賣店
# 勺子公爵手做烘焙
# 勺子公爵手做烘焙
# 澳門豆撈
# 澳門豆撈
# 豆米客soymilk
# 豆米客soymilk
# Pizza公主窯烤披薩
# Pizza公主窯烤披薩
# 虎記涼麵
# 虎記涼麵
# ALLEZ BISTRO 來酒館
# ALLEZ BISTRO 來酒館
# WO窩
# WO窩
# 纖Q好手藝-黑豆水
# 纖Q好手藝-黑豆水
# FULL PASTA 芙歐義式餐廳
# FULL PASTA 芙歐義式餐廳
# 禾家涮涮鍋
# 禾家涮涮鍋
# 文吉肉焿
# 文吉肉焿
# 樂作昭和料理
# 樂作昭和料理
# Hotea來找茶
# Hotea來找茶
# NOT ONLY CAFE
# NOT ONLY CAFE
# 旅人關東煮(高雄苓雅店)
# 旅人關東煮(高雄苓雅店)
# 丼吧！小野
# 丼吧！小野
# 夏弄早午餐專賣店
# 夏弄早午餐專賣店
# 天饌國際食品有限公司
# 天饌國際食品有限公司
# 高三孝碳烤吐司
# 高三孝碳烤吐司
# 全家草莓霜淇淋
# 全家草莓霜淇淋
# 雙連文花枝羹
# 雙連文花枝羹
# 烏龍派出所
# 烏龍派出所
# 金軒閣手工蛋捲
# 金軒閣手工蛋捲
# 炙牛食創堂Flaming Bull
# 炙牛食創堂Flaming Bull
# 上海點心
# 上海點心
# 錦霞樓
# 錦霞樓
# 珍鮮碳烤海鮮
# 珍鮮碳烤海鮮
# 塔木愛客廚坊
# 塔木愛客廚坊
# 小確幸關東煮
# 小確幸關東煮
# 同樂工地福利站
# 同樂工地福利站
# 奧莉維亞社區親子餐廳
# 奧莉維亞社區親子餐廳
# 爐鍋咖啡(小藝埕)
# 爐鍋咖啡(小藝埕)
# 陽光菓菓. Sunnygogo
# 陽光菓菓. Sunnygogo
# 小太陽義大利麵(東寧店)
# 小太陽義大利麵(東寧店)
# POP cafe
# POP cafe
# 這一鍋皇室祕藏鍋物(大興西殿)
# 這一鍋皇室祕藏鍋物(大興西殿)
# 家名稱
# 家名稱
# 阿強冰店
# 阿強冰店
# 小美布丁蛋糕專賣店
# 小美布丁蛋糕專賣店
# 原興鵪鶉
# 原興鵪鶉
# 無老鍋(台北市民店)
# 無老鍋(台北市民店)
# 雅啤川菜(竹北店)
# 雅啤川菜(竹北店)
# 莎菈媽媽的家庭廚房
# 莎菈媽媽的家庭廚房
# 宴江浙海鮮餐廳
# 宴江浙海鮮餐廳
# 滿鍋香
# 滿鍋香
# 樂活農場手作坊
# 樂活農場手作坊
# 蘭那泰式餐廳
# 蘭那泰式餐廳
# 潮SHIO鍋本家
# 潮SHIO鍋本家
# 明亮水煎包
# 明亮水煎包
# 屏東市迪化街老牌肉丸
# 屏東市迪化街老牌肉丸
# 名代富士蕎麥麵
# 名代富士蕎麥麵
# 梨好鳳梨冰
# 梨好鳳梨冰
# 黃金轟炸魷魚(一中街)
# 黃金轟炸魷魚(一中街)
# 宏佳火雞肉飯
# 宏佳火雞肉飯
# 沙里仙鱘龍魚餐廳
# 沙里仙鱘龍魚餐廳
# 寿豬日式咖哩專賣
# 寿豬日式咖哩專賣
# 大炒一番の店
# 大炒一番の店
# 微咖啡 V Cafe
# 微咖啡 V Cafe
# 洪敦耀的葡萄園
# 洪敦耀的葡萄園
# 北港張記古早味麵茶
# 北港張記古早味麵茶
# 高平海產小吃
# 高平海產小吃
# 鍋寶日式涮涮鍋
# 鍋寶日式涮涮鍋
# 客廳
# 客廳
# 香濃起司蛋糕
# 香濃起司蛋糕
# 義美_黑芝麻豆奶
# 義美_黑芝麻豆奶
# pmam bistro
# pmam bistro
# ohana的天空
# ohana的天空
# 福味石頭火鍋
# 福味石頭火鍋
# 麵處小林(高雄店)
# 麵處小林(高雄店)
# 八戶日式料理
# 八戶日式料理
# 北大洲鮮鋪
# 北大洲鮮鋪
# 一億香蕉冰淇淋
# 一億香蕉冰淇淋
# 定食8 爭鮮餐飲(松山店)
# 定食8 爭鮮餐飲(松山店)
# 好市多-KIRKLAND SIGNATURE 科克蘭 全脂鮮乳
# 好市多-KIRKLAND SIGNATURE 科克蘭 全脂鮮乳
# 汆堂鮮物火鍋
# 汆堂鮮物火鍋
# Le NINI 樂尼尼義式餐廳(林口國賓店)
# Le NINI 樂尼尼義式餐廳(林口國賓店)
# 橘屋餐酒館
# 橘屋餐酒館
# 富滿億冰品
# 富滿億冰品
# 甜樂園 Dulce Plaza
# 甜樂園 Dulce Plaza
# 白甘餘
# 白甘餘
# 時悅樂
# 時悅樂
# 3 Wish
# 3 Wish
# 司康小姐 Miss scone
# 司康小姐 Miss scone
# 藝素館素食
# 藝素館素食
# hot7 新鉄板料理(金山南店)
# hot7 新鉄板料理(金山南店)
# 雙色迷你泡芙(乳酸&草莓)
# 雙色迷你泡芙(乳酸&草莓)
# 雲品酒店-英式下午茶
# 雲品酒店-英式下午茶
# 好滋味手工包子店
# 好滋味手工包子店
# Wow.F 沃夫餐廚(駁二店)
# Wow.F 沃夫餐廚(駁二店)
# 123炒螺肉(覺民店)
# 123炒螺肉(覺民店)
# 藏苑日式創作料理
# 藏苑日式創作料理
# L'OCCITANE Café 歐舒丹咖啡(南紡夢時代)
# L'OCCITANE Café 歐舒丹咖啡(南紡夢時代)
# 咔嗞蔥油餅
# 咔嗞蔥油餅
# 牛角日式炭火燒肉(高島屋店)
# 牛角日式炭火燒肉(高島屋店)
# 21世紀風味館(台南仁德家福店)
# 21世紀風味館(台南仁德家福店)
# 文鳥公寓
# 文鳥公寓
# Cloud 9 Cafe
# Cloud 9 Cafe
# 路加咖啡館
# 路加咖啡館
# 祥益魚脯專賣店
# 祥益魚脯專賣店
# 生活早餐店
# 生活早餐店
# 野島家咖哩(華美店)
# 野島家咖哩(華美店)
# 小點
# 小點
# CHIC CAFÉ 奇可小廚
# CHIC CAFÉ 奇可小廚
# 漩茶舍(青年店)
# 漩茶舍(青年店)
# 台灣大鍋大涮涮鍋
# 台灣大鍋大涮涮鍋
# 綠豆椪
# 綠豆椪
# Zoo Zoo caFe(桃園復興店)
# Zoo Zoo caFe(桃園復興店)
# 九寨溝牛肉麵
# 九寨溝牛肉麵
# 如菓 Flambagel Cafe(信義永吉店)
# 如菓 Flambagel Cafe(信義永吉店)
# 莎莎莉
# 莎莎莉
# 廖土魠魚羹
# 廖土魠魚羹
# 牛老大涮牛肉(八德店)
# 牛老大涮牛肉(八德店)
# 老客馥粥品(新竹新埔店)
# 老客馥粥品(新竹新埔店)
# 家鄉客家麵食館
# 家鄉客家麵食館
# 竹仔園露天燒烤
# 竹仔園露天燒烤
# 哈根達斯 Häagen-Dazs(板橋遠百店)
# 哈根達斯 Häagen-Dazs(板橋遠百店)
# 全球食堂日式小火鍋
# 全球食堂日式小火鍋
# 千焙屋手作蛋糕
# 千焙屋手作蛋糕
# 二郭頭居酒屋
# 二郭頭居酒屋
# 小餐桌2F (預約制)
# 小餐桌2F (預約制)
# 沒有名字的咖啡館
# 沒有名字的咖啡館
# 仁武烤肉
# 仁武烤肉
# Apple 咖哩
# Apple 咖哩
# 大志軒
# 大志軒
# 協全餅舖
# 協全餅舖
# 玲月鐵板燒
# 玲月鐵板燒
# 謙津狀元四兩包
# 謙津狀元四兩包
# 瑜手創料理
# 瑜手創料理
# 頂家麵食風味館
# 頂家麵食風味館
# 晨間廚房(常德店)
# 晨間廚房(常德店)
# 鳴門和食料理
# 鳴門和食料理
# Bella Brunch 貝拉早午餐
# Bella Brunch 貝拉早午餐
# 37度茶微醺
# 37度茶微醺
# 福容大飯店-福粵樓
# 福容大飯店-福粵樓
# 李奶奶正北方麵點
# 李奶奶正北方麵點
# 松竹火鍋
# 松竹火鍋
# 饅頭福利社
# 饅頭福利社
# 牛魔王(高雄左營店)
# 牛魔王(高雄左營店)
# 菓風巧克力工坊
# 菓風巧克力工坊
# 巷里食麵茶
# 巷里食麵茶
# 貓居手作料理
# 貓居手作料理
# 北海道札幌キタリッシュ 奇塔里旭
# 北海道札幌キタリッシュ 奇塔里旭
# 山姆安娜SamAna
# 山姆安娜SamAna
# 糖九牛軋糖
# 糖九牛軋糖
# 榮座和食料理
# 榮座和食料理
# POP PIE
# POP PIE
# 著迷食間
# 著迷食間
# 獅子王商務旅館-香港豪記茶餐廳
# 獅子王商務旅館-香港豪記茶餐廳
# 蘇格蕾法式甜點 Le Sucré Pâtisserie
# 蘇格蕾法式甜點 Le Sucré Pâtisserie
# 鯊魚咬吐司
# 鯊魚咬吐司
# 新世紀漢方-上班族養生茶
# 新世紀漢方-上班族養生茶
# 元本鮮肉小湯包
# 元本鮮肉小湯包
# 阿嬤咖啡屋
# 阿嬤咖啡屋
# 老爺豆腐
# 老爺豆腐
# 福州林胡椒餅
# 福州林胡椒餅
# 美濃客家菜(鳳山名人店)
# 美濃客家菜(鳳山名人店)
# 上品苑鐵板燒(總店)
# 上品苑鐵板燒(總店)
# Botega del Vin Taipei
# Botega del Vin Taipei
# 紅花巷弄
# 紅花巷弄
# 曾記巧口滷味坊(熱河店)
# 曾記巧口滷味坊(熱河店)
# Shallot 紅蔥
# Shallot 紅蔥
# 一吅品
# 一吅品
# 番樂屋(民權店)
# 番樂屋(民權店)
# 木門朝午洋食 MOMENT
# 木門朝午洋食 MOMENT
# YAYOI(天母店)
# YAYOI(天母店)
# 榕樹下控土窯
# 榕樹下控土窯
# Dazzling Express 蜜堂飲品
# Dazzling Express 蜜堂飲品
# 帆船咖啡餐廳
# 帆船咖啡餐廳
# 海中金海產餐廳
# 海中金海產餐廳
# 里亞料理廚房
# 里亞料理廚房
# Royal house保師傅廚房
# Royal house保師傅廚房
# 澤喜手作洋食
# 澤喜手作洋食
# HOK House of Kuo
# HOK House of Kuo
# 沿海鮮魚湯
# 沿海鮮魚湯
# 火鍋世家(永和店)
# 火鍋世家(永和店)
# 達娜伊谷福味餐廳
# 達娜伊谷福味餐廳
# 菜香小廚
# 菜香小廚
# Mr.Onion 牛排餐廳(花蓮遠百店)
# Mr.Onion 牛排餐廳(花蓮遠百店)
# Starbucks Coffee 統一星巴克(彰化曉陽門市)
# Starbucks Coffee 統一星巴克(彰化曉陽門市)
# 好口福
# 好口福
# 香喜蛋糕麵包烘焙坊
# 香喜蛋糕麵包烘焙坊
# 嵐午咖啡 Lattӧӧ Café
# 嵐午咖啡 Lattӧӧ Café
# 黑豚麵屋
# 黑豚麵屋
# 威廉泰爾
# 威廉泰爾
# 耶濃搖滾豆漿
# 耶濃搖滾豆漿
# 新堂洞韓國料理
# 新堂洞韓國料理
# A WEEK PANCAKE&COFFEE
# A WEEK PANCAKE&COFFEE
# 松大沙茶爐(慶平店)
# 松大沙茶爐(慶平店)
# 日和屋日本料理
# 日和屋日本料理
# Bottega Italia 義宝坊
# Bottega Italia 義宝坊
# VINOZA葡萄酒專門店
# VINOZA葡萄酒專門店
# 鹿角吐司
# 鹿角吐司
# Pizza Hut 必勝客(台南金華店)
# Pizza Hut 必勝客(台南金華店)
# 空醬拉拉
# 空醬拉拉
# 馤咖啡
# 馤咖啡
# Pizza Hut 必勝客(台南安南店)
# Pizza Hut 必勝客(台南安南店)
# Amandier雅蒙蒂法式甜點(京站時尚廣場)
# Amandier雅蒙蒂法式甜點(京站時尚廣場)
# Pizza Hut 必勝客(台南新營店)
# Pizza Hut 必勝客(台南新營店)
# 第三元素 Luxoo(四平店)
# 第三元素 Luxoo(四平店)
# 朝日壽司
# 朝日壽司
# 品上品排翅盒餐
# 品上品排翅盒餐
# 陳記麵粉煎
# 陳記麵粉煎
# 鼎珍香小火鍋
# 鼎珍香小火鍋
# 八食巷
# 八食巷
# 美濃老牌板條
# 美濃老牌板條
# 老陳豆漿
# 老陳豆漿
# 土埆厝懷舊餐廳
# 土埆厝懷舊餐廳
# 香草 New 點子
# 香草 New 點子
# 品味甸複合式餐飲
# 品味甸複合式餐飲
# 莊ㄧ火雞肉飯
# 莊ㄧ火雞肉飯
# Tajin塔吉摩洛哥料理
# Tajin塔吉摩洛哥料理
# 拉麵一心
# 拉麵一心
# Armin Brunch & Coffee
# Armin Brunch & Coffee
# 第九站精緻鍋品
# 第九站精緻鍋品
# 德鑫廣東粥
# 德鑫廣東粥
# 閃shem小餐館
# 閃shem小餐館
# 黑松汽水 沁涼香檳口味
# 黑松汽水 沁涼香檳口味
# 里溪咖啡
# 里溪咖啡
# 陳記鴨肉麵
# 陳記鴨肉麵
# 大湯漁人料理海鮮餐廳
# 大湯漁人料理海鮮餐廳
# 新樂園美義餐館 Paradiso
# 新樂園美義餐館 Paradiso
# 侯夜擔仔麵
# 侯夜擔仔麵
# Miss DouDou cafe 荳荳咖啡屋
# Miss DouDou cafe 荳荳咖啡屋
# 佳佳農產品實業有限公司
# 佳佳農產品實業有限公司
# 鱷魚餐廳
# 鱷魚餐廳
# 雲上咖啡
# 雲上咖啡
# 紅寶石港式吃到飽
# 紅寶石港式吃到飽
# GB5 Cafe'
# GB5 Cafe'
# mars
# mars
# 巧仕佳西點麵包
# 巧仕佳西點麵包
# 好食自家烘焙
# 好食自家烘焙
# Coffee+ 咖啡家(苗栗店)
# Coffee+ 咖啡家(苗栗店)
# CHOCOARTS 喬克亞司
# CHOCOARTS 喬克亞司
# 美之味海產粥
# 美之味海產粥
# 欣品咖啡莊園
# 欣品咖啡莊園
# 鮨月手作壽司
# 鮨月手作壽司
# Pizza Hut 必勝客(高雄建工店)
# Pizza Hut 必勝客(高雄建工店)
# 八哥重慶酸辣粉銘傳店
# 八哥重慶酸辣粉銘傳店
# 願景軒
# 願景軒
# Pizza Hut 必勝客(高雄瑞隆店)
# Pizza Hut 必勝客(高雄瑞隆店)
# 米樂咖啡
# 米樂咖啡
# 文聖豆花專賣店
# 文聖豆花專賣店
# Pizza Hut 必勝客(高雄小港店)
# Pizza Hut 必勝客(高雄小港店)
# 晨花早午餐
# 晨花早午餐
# 維興米行
# 維興米行
# 鼎鍋牛肉麵
# 鼎鍋牛肉麵
# 享食風味麵館
# 享食風味麵館
# 集合咖啡數學館
# 集合咖啡數學館
# 魚禮食事處
# 魚禮食事處
# K.K. Banana
# K.K. Banana
# 無老鍋(中山店)
# 無老鍋(中山店)
# 天府之國巴蜀驛站
# 天府之國巴蜀驛站
# 駿茗茶葉
# 駿茗茶葉
# 樂華燒愛玉
# 樂華燒愛玉
# 透早日頭
# 透早日頭
# Pizza Hut 必勝客(高雄自由店)
# Pizza Hut 必勝客(高雄自由店)
# 特選餐廳
# 特選餐廳
# 如意泰式料理
# 如意泰式料理
# 騷咖啡
# 騷咖啡
# 誠實泡菜
# 誠實泡菜
# Home 湯粥館
# Home 湯粥館
# 亭仔腳古早味(寶山棧)
# 亭仔腳古早味(寶山棧)
# Okaeriお帰り 吃碗拉麵吧
# Okaeriお帰り 吃碗拉麵吧
# 花生奇蹟
# 花生奇蹟
# 德爾芙餐廳de reve cafe(台中民權店)
# 德爾芙餐廳de reve cafe(台中民權店)
# citta slow
# citta slow
# C.W. Brunch House
# C.W. Brunch House
# 歐森草本莊園乳果木身體乳系列
# 歐森草本莊園乳果木身體乳系列
# 林記麵疙瘩
# 林記麵疙瘩
# 歐米夏早午餐輕食館
# 歐米夏早午餐輕食館
# 泰棧鐵板燒
# 泰棧鐵板燒
# 鍋董日式涮涮鍋(大忠直營二店)
# 鍋董日式涮涮鍋(大忠直營二店)
# 小日和咖啡
# 小日和咖啡
# 鯊魚咬吐司(新營店)
# 鯊魚咬吐司(新營店)
# 中華一餅(新店店)
# 中華一餅(新店店)
# 普蕾納掛耳包濾泡咖啡
# 普蕾納掛耳包濾泡咖啡
# 上乘三家涮涮鍋共和國(淡水店)
# 上乘三家涮涮鍋共和國(淡水店)
# 66 pasta
# 66 pasta
# 冠捷黃金肉圓(0005攤位)
# 冠捷黃金肉圓(0005攤位)
# 富春食堂
# 富春食堂
# Pizza Hut 必勝客(高雄鳳山建國店)
# Pizza Hut 必勝客(高雄鳳山建國店)
# 泰廣城泰式料理
# 泰廣城泰式料理
# 麥面庄
# 麥面庄
# 阿榮麻辣鴨血
# 阿榮麻辣鴨血
# 白天使手作烘焙 Sweetsapp
# 白天使手作烘焙 Sweetsapp
# 老皮牛肉麵(湖口店)
# 老皮牛肉麵(湖口店)
# 瘋味好餃色麵食館
# 瘋味好餃色麵食館
# 大嗑西式餐館(信義店)
# 大嗑西式餐館(信義店)
# 米靈岸
# 米靈岸
# 木沐咖啡Mumu cafe
# 木沐咖啡Mumu cafe
# 路易莎咖啡 Louisa Coffee(逢甲福星店)
# 路易莎咖啡 Louisa Coffee(逢甲福星店)
# 源芳魚翅
# 源芳魚翅
# 日安食午
# 日安食午
# 心心甜心屋candy house
# 心心甜心屋candy house
# 皇冠冰城
# 皇冠冰城
# 飯樂丼 Fun Rice(南港店)
# 飯樂丼 Fun Rice(南港店)
# 和泰坊香腸專賣
# 和泰坊香腸專賣
# 信義小吃
# 信義小吃
# 三華
# 三華
# 阿全師無刺虱目魚
# 阿全師無刺虱目魚
# 藝 風巷 Art Alley Cafe
# 藝 風巷 Art Alley Cafe
# 客燒串烤酒場
# 客燒串烤酒場
# 宏廚pancake
# 宏廚pancake
# 藝奇新日本料理(耐斯松屋店)
# 藝奇新日本料理(耐斯松屋店)
# 麻膳堂(復北店)
# 麻膳堂(復北店)
# 海豊亭丼の專門店
# 海豊亭丼の專門店
# 寶島好味~美食館
# 寶島好味~美食館
# 3樂鐡板燒
# 3樂鐡板燒
# Kimmy淳朵坊
# Kimmy淳朵坊
# 桃花園飯店(蝴蝶谷自助百匯餐廳)
# 桃花園飯店(蝴蝶谷自助百匯餐廳)
# 韓老二韓國烤肉
# 韓老二韓國烤肉
# 義豐蔥油派
# 義豐蔥油派
# 香港88茶餐廳
# 香港88茶餐廳
# 鹿府 LU FU(二館)
# 鹿府 LU FU(二館)
# 選構 Piicoffee
# 選構 Piicoffee
# 順順堂
# 順順堂
# 參差 餘波未了 Remember Cafe
# 參差 餘波未了 Remember Cafe
# 一五一食時尚鮮鍋
# 一五一食時尚鮮鍋
# 泰邦泰式料理
# 泰邦泰式料理
# 橋頭滷味
# 橋頭滷味
# 皇膳魚翅餐廳
# 皇膳魚翅餐廳
# 富良野雪
# 富良野雪
# 布達爾咖啡館
# 布達爾咖啡館
# 大心吐司
# 大心吐司
# BRUNNER brunch&dinner
# BRUNNER brunch&dinner
# 清涼地
# 清涼地
# 阿里媽媽南洋料理
# 阿里媽媽南洋料理
# 賴公老滷
# 賴公老滷
# C.C.KISS Coffee&Cake
# C.C.KISS Coffee&Cake
# 甕大王甕仔雞萬里蟹(萬里店)
# 甕大王甕仔雞萬里蟹(萬里店)
# 朱 爆漿黑糖包
# 朱 爆漿黑糖包
# 建宏拉仔麵
# 建宏拉仔麵
# 三沙灣米苔目
# 三沙灣米苔目
# 劉家臭豆腐
# 劉家臭豆腐
# 蓁豆家
# 蓁豆家
# 赤鬼炙燒牛排(高雄店)
# 赤鬼炙燒牛排(高雄店)
# 牧穀禾牛麵食館
# 牧穀禾牛麵食館
# 正老林羊肉爐(台中分店)
# 正老林羊肉爐(台中分店)
# 勝丼日式蓋飯
# 勝丼日式蓋飯
# 廣東汕頭新鮮豆漿店
# 廣東汕頭新鮮豆漿店
# 豪記 台菜古早味
# 豪記 台菜古早味
# 楊記豬腳飯
# 楊記豬腳飯
# 艾搗蛋手工蛋餅
# 艾搗蛋手工蛋餅
# Peekaboo 麵包屋
# Peekaboo 麵包屋
# 東京銀座正統派和食
# 東京銀座正統派和食
# 誰啃果子(原：回香米蛋糕)
# 誰啃果子(原：回香米蛋糕)
# 鹿港麵線糊
# 鹿港麵線糊
# 櫻木町和風小館
# 櫻木町和風小館
# 赤鬼牛排(博愛店)
# 赤鬼牛排(博愛店)
# 幸福日式小火鍋
# 幸福日式小火鍋
# Muni 好食   miso鯛魚
# Muni 好食   miso鯛魚
# kimmy 淳朵甜點
# kimmy 淳朵甜點
# 甲仙小奇芋冰店
# 甲仙小奇芋冰店
# 漁聞樂
# 漁聞樂
# NEW SPARK
# NEW SPARK
# 甘味處 麻糬屋
# 甘味處 麻糬屋
# Yiamas Greeka Taverna 亞馬仕希臘餐廳
# Yiamas Greeka Taverna 亞馬仕希臘餐廳
# 幼葉林餐廳
# 幼葉林餐廳
# Amin's book & cafe
# Amin's book & cafe
# 高雄楠梓南豐滷肉飯(德賢店)
# 高雄楠梓南豐滷肉飯(德賢店)
# 羊立發羊肉創意料理(東港店)
# 羊立發羊肉創意料理(東港店)
# 薏蓮坊精緻養生甜品飲品專賣店(板橋店)
# 薏蓮坊精緻養生甜品飲品專賣店(板橋店)
# CABY CAFE & Design
# CABY CAFE & Design
# 龍景山莊
# 龍景山莊
# 高腳外省麵
# 高腳外省麵
# HI PIE 手工鹹派
# HI PIE 手工鹹派
# 花果漾花茶果汁概念店
# 花果漾花茶果汁概念店
# ICHI居酒屋
# ICHI居酒屋
# 181領袖莊園 Fashion Leader Manor
# 181領袖莊園 Fashion Leader Manor
# 威德in果凍
# 威德in果凍
# 仁之初手創壽司
# 仁之初手創壽司
# 三友町美食館
# 三友町美食館
# 林員肉圓(信義店)
# 林員肉圓(信義店)
# 茶古海鮮快炒
# 茶古海鮮快炒
# 豬血糕
# 豬血糕
# 純新牛奶棒、爆漿餐包
# 純新牛奶棒、爆漿餐包
# 瞭望台土雞城
# 瞭望台土雞城
# 麵線陳專業手工麵線
# 麵線陳專業手工麵線
# JJIM DAK
# JJIM DAK
# 胡言吳語私人咖啡
# 胡言吳語私人咖啡
# 兩批索靚鍋(三重溪尾店)
# 兩批索靚鍋(三重溪尾店)
# 溪堤cafe'
# 溪堤cafe'
# 鶴佳雞蛋糕
# 鶴佳雞蛋糕
# 正宗滬尾淡水手工阿給創始店
# 正宗滬尾淡水手工阿給創始店
# 李家裕民塩酥雞
# 李家裕民塩酥雞
# 楓鶴鐵板燒
# 楓鶴鐵板燒
# 回琉麵館
# 回琉麵館
# Hank coffee 漢克咖啡(西門店)
# Hank coffee 漢克咖啡(西門店)
# 貝邑軒干鍋海鮮
# 貝邑軒干鍋海鮮
# 香色 Xiang se
# 香色 Xiang se
# 韓集韓國料理
# 韓集韓國料理
# 卡路里早午餐(豐原店)
# 卡路里早午餐(豐原店)
# 施 豆花專賣店
# 施 豆花專賣店
# Sanpei cafe 三平咖啡
# Sanpei cafe 三平咖啡
# Hello Kitty Kitchen & Dining(南紡夢時代)
# Hello Kitty Kitchen & Dining(南紡夢時代)
# 後巷貓煮義
# 後巷貓煮義
# 十方串燒Bar
# 十方串燒Bar
# 麥當勞(台南遠百二店)
# 麥當勞(台南遠百二店)
# 青年路烤玉米
# 青年路烤玉米
# 麥當勞(台南大學店)
# 麥當勞(台南大學店)
# 廟口點心站
# 廟口點心站
# 麥當勞(台南東門店)
# 麥當勞(台南東門店)
# 後勁炸雞攤
# 後勁炸雞攤
# 七寶宅配滷味
# 七寶宅配滷味
# 老李蔥油餅
# 老李蔥油餅
# 旺昌冰舖
# 旺昌冰舖
# 2 Two Princesses
# 2 Two Princesses
# 蒙古草原
# 蒙古草原
# 宏定食品
# 宏定食品
# 宴川秋創意‧麻辣
# 宴川秋創意‧麻辣
# 菠蘿油王子
# 菠蘿油王子
# Mini私房點心
# Mini私房點心
# 林儀美食餐廳
# 林儀美食餐廳
# pie pie 澳洲肉派(環球板橋店)
# pie pie 澳洲肉派(環球板橋店)
# 南京胡同
# 南京胡同
# GODIVA 巧克力專賣店(臺北-信義威秀影城店)
# GODIVA 巧克力專賣店(臺北-信義威秀影城店)
# 海派餐廳
# 海派餐廳
# 富港海鮮
# 富港海鮮
# 米寓
# 米寓
# 曾家古早味挫冰
# 曾家古早味挫冰
# 桐花芽蔬食咖啡廚房
# 桐花芽蔬食咖啡廚房
# 名廚(竹子湖店)
# 名廚(竹子湖店)
# 早餐‧黃
# 早餐‧黃
# Bisous bisous
# Bisous bisous
# 一口甜不辣tenpura
# 一口甜不辣tenpura
# 普羅家族
# 普羅家族
# 粥道
# 粥道
# Coffee Please By Mastro
# Coffee Please By Mastro
# Space Cafe
# Space Cafe
# 名牌手工包子
# 名牌手工包子
# 元食cafe
# 元食cafe
# 大川本舖 古早味現烤蛋糕(高雄三民店)
# 大川本舖 古早味現烤蛋糕(高雄三民店)
# 【弘益傳香世家】南瓜子/五穀 海苔杏仁脆片(非油炸/全素可食)
# 【弘益傳香世家】南瓜子/五穀 海苔杏仁脆片(非油炸/全素可食)
# 象園咖啡 Elephant Garden(南港店)
# 象園咖啡 Elephant Garden(南港店)
# 艾隆義式麵食館(新光三越 A8店)
# 艾隆義式麵食館(新光三越 A8店)
# 直火人
# 直火人
# 青之森 手作霜淇淋
# 青之森 手作霜淇淋
# 陳家雞肉飯
# 陳家雞肉飯
# 鬍子叔叔義麵工坊 Beard Uncle(台北敦南店)
# 鬍子叔叔義麵工坊 Beard Uncle(台北敦南店)
# 伯爵紅茶餅乾泡芙
# 伯爵紅茶餅乾泡芙
# 不二堂茶所在(永康公園店)
# 不二堂茶所在(永康公園店)
# 灶王爺鐵板燒(大潤發二館)
# 灶王爺鐵板燒(大潤發二館)
# 257咖啡
# 257咖啡
# TA ● KO將(微風廣場)
# TA ● KO將(微風廣場)
# 阿松拉仔麵
# 阿松拉仔麵
# 御鼎燒物鍋物
# 御鼎燒物鍋物
# COCO 元元美式炸雞
# COCO 元元美式炸雞
# 台北永和豆漿大王
# 台北永和豆漿大王
# 簡單舊好
# 簡單舊好
# 炮咖啡
# 炮咖啡
# 太興活海鮮餐廳
# 太興活海鮮餐廳
# 樂透牛排
# 樂透牛排
# 無名鐵板麵
# 無名鐵板麵
# paco bear house
# paco bear house
# 內灣愛情故事館-景觀餐廳DH婚紗拍攝基地
# 內灣愛情故事館-景觀餐廳DH婚紗拍攝基地
# 泰之味(建功店)
# 泰之味(建功店)
# 醒而眠手烘咖啡吧
# 醒而眠手烘咖啡吧
# 大華牛排
# 大華牛排
# 紅茶幫(自由店)
# 紅茶幫(自由店)
# 炒不停(溪湖環中店)
# 炒不停(溪湖環中店)
# BIG MAMA(大勇店)
# BIG MAMA(大勇店)
# 御松甲殼素+藤黃果
# 御松甲殼素+藤黃果
# 義美彌月油飯
# 義美彌月油飯
# NU PASTA(桃園大有店)
# NU PASTA(桃園大有店)
# 運鮮企業山豬鱸鰻水餃
# 運鮮企業山豬鱸鰻水餃
# 順德土產牛肉
# 順德土產牛肉
# MORNI莫尼廚房-陽明店
# MORNI莫尼廚房-陽明店
# 研香所
# 研香所
# 邊田庄
# 邊田庄
# 劉記牛肉麵(正光美食街(七堵店))
# 劉記牛肉麵(正光美食街(七堵店))
# Magie du Levain 樂凡手感烘焙(【樂寶店】)
# Magie du Levain 樂凡手感烘焙(【樂寶店】)
# 韓34韓國料理(新時代店)
# 韓34韓國料理(新時代店)
# Bon Bon 鄉村慢食小餐館
# Bon Bon 鄉村慢食小餐館
# 鮮賣鍋貼(鮮賣鍋貼)
# 鮮賣鍋貼(鮮賣鍋貼)
# Cheese & Risotto
# Cheese & Risotto
# 品屋烘焙
# 品屋烘焙
# 鮮五丼Don Mono 丼飯專賣店(沙鹿店)
# 鮮五丼Don Mono 丼飯專賣店(沙鹿店)
# 小夫妻Q麵
# 小夫妻Q麵
# 米格手作甜食
# 米格手作甜食
# 豬八戒大腸包小腸
# 豬八戒大腸包小腸
# 金新鮮快炒王
# 金新鮮快炒王
# 丹路碳烤
# 丹路碳烤
# amba Taipei Ximending 台北西門町意舍酒-甜吧tianba
# amba Taipei Ximending 台北西門町意舍酒-甜吧tianba
# 輔皮牛軋糖
# 輔皮牛軋糖
# 北投麗禧溫泉酒店雍翠庭
# 北投麗禧溫泉酒店雍翠庭
# 馬德里義大利麵
# 馬德里義大利麵
# 寶豆豆漿
# 寶豆豆漿
# 紅門五號
# 紅門五號
# 阿彬炒麵屋
# 阿彬炒麵屋
# 冇冇有(ㄆㄚˇ)( ㄉ一ㄥˇ) (ㄨˇ)私房菜
# 冇冇有(ㄆㄚˇ)( ㄉ一ㄥˇ) (ㄨˇ)私房菜
# SHOW DOU 秀豆
# SHOW DOU 秀豆
# 誠品行旅The Chapter
# 誠品行旅The Chapter
# 玉水堂豆花
# 玉水堂豆花
# 人帥真好三明治輕食吧
# 人帥真好三明治輕食吧
# Bella&joye
# Bella&joye
# 八古文鬆餅義大利麵麵包餐
# 八古文鬆餅義大利麵麵包餐
# 喆發樂樂鍋(金華店)
# 喆發樂樂鍋(金華店)
# Pizza factory 披薩工廠-彰化員林店
# Pizza factory 披薩工廠-彰化員林店
# Pizza Factory 披薩工廠-豐原店
# Pizza Factory 披薩工廠-豐原店
# 張三桌百年小吃
# 張三桌百年小吃
# Pizza Factory 披薩工廠 - 中科店
# Pizza Factory 披薩工廠 - 中科店
# 99泰式燒烤
# 99泰式燒烤
# 阿月芒果冰
# 阿月芒果冰
# 麥當勞(屏東家樂福店)
# 麥當勞(屏東家樂福店)
# 丹丹漢堡(瀋陽店)
# 丹丹漢堡(瀋陽店)
# 楊家手工水餃
# 楊家手工水餃
# Zinc Food & Darts & Lounge 運動餐廳
# Zinc Food & Darts & Lounge 運動餐廳
# 李記刀削麵
# 李記刀削麵
# 麥當勞(屏東民生店)
# 麥當勞(屏東民生店)
# 金魚屋日式手作
# 金魚屋日式手作
# 貓鼻子複合式咖啡餐飲
# 貓鼻子複合式咖啡餐飲
# 麥當勞(屏東自由店)
# 麥當勞(屏東自由店)
# TAKO將(台北微風廣場店)
# TAKO將(台北微風廣場店)
# 水原天麵食館(鳳山店)
# 水原天麵食館(鳳山店)
# 香港燒臘快餐便當
# 香港燒臘快餐便當
# 青麥芋圓嫩仙草
# 青麥芋圓嫩仙草
# 小河馬手工帕里尼披薩專賣
# 小河馬手工帕里尼披薩專賣
# 依蘭 咖啡西食
# 依蘭 咖啡西食
# 沛芮瑅早午餐
# 沛芮瑅早午餐
# 明明德黑糖糕
# 明明德黑糖糕
# 蛋要酷手工蛋餅專賣店
# 蛋要酷手工蛋餅專賣店
# 麥當勞(屏東墾丁店)
# 麥當勞(屏東墾丁店)
# 喝一杯
# 喝一杯
# 鮮果舞juice
# 鮮果舞juice
# 南化區土雞閹雞
# 南化區土雞閹雞
# Jimolulu 美式夏威夷餐廳
# Jimolulu 美式夏威夷餐廳
# 格蘭傑12年PX雪莉桶風味威士忌
# 格蘭傑12年PX雪莉桶風味威士忌
# MAD EAT 怒吃一波!吐司.沙拉工場
# MAD EAT 怒吃一波!吐司.沙拉工場
# 好早 ohayo
# 好早 ohayo
# 紅螞蟻廚房餐廳
# 紅螞蟻廚房餐廳
# 啡堡創飲
# 啡堡創飲
# Tavola Plus
# Tavola Plus
# 三多利日本食堂
# 三多利日本食堂
# 中式早餐店
# 中式早餐店
# Mini Do - Brunch
# Mini Do - Brunch
# 麥當勞(高雄十全店)
# 麥當勞(高雄十全店)
# 一Ｏ八抹茶茶廊 108 MATCHA SARO(京站時尚廣場)
# 一Ｏ八抹茶茶廊 108 MATCHA SARO(京站時尚廣場)
# 喫麵趣
# 喫麵趣
# 愛斯漢堡 A'S BURGER
# 愛斯漢堡 A'S BURGER
# 天地人日式創意料理
# 天地人日式創意料理
# COFFEE SMITH(石牌店)
# COFFEE SMITH(石牌店)
# Small Ya 小Ya簡餐、焗烤、咖啡
# Small Ya 小Ya簡餐、焗烤、咖啡
# 宮原眼科 摘星樓沙龍
# 宮原眼科 摘星樓沙龍
# 趙咖Chao Cafe
# 趙咖Chao Cafe
# 青俠客
# 青俠客
# 金樽小曼咖啡
# 金樽小曼咖啡
# 森咖啡morikoohil
# 森咖啡morikoohil
# 呷懷念懷舊餐廳
# 呷懷念懷舊餐廳
# 心心手捲孝親糕
# 心心手捲孝親糕
# 壹兩雲吞
# 壹兩雲吞
# 麥當勞(高雄天祥店)
# 麥當勞(高雄天祥店)
# 小緹大作
# 小緹大作
# The Lin 林酒店 LV海鮮百匯餐廳Las Vegas Buffet
# The Lin 林酒店 LV海鮮百匯餐廳Las Vegas Buffet
# 福人街陽春麵
# 福人街陽春麵
# Mr.KIM 濟州韓式炸雞
# Mr.KIM 濟州韓式炸雞
# 阿得米糕
# 阿得米糕
# 戈再來
# 戈再來
# 王家水煎包蛋餅
# 王家水煎包蛋餅
# 真饌軒綠豆湯(北平店)
# 真饌軒綠豆湯(北平店)
# 輕品味 Qing Tasting
# 輕品味 Qing Tasting
# 早安！美芝城(景德店)
# 早安！美芝城(景德店)
# 樓梯腳
# 樓梯腳
# 麥當勞(高雄站前店)
# 麥當勞(高雄站前店)
# 自家用料理食堂
# 自家用料理食堂
# Mume
# Mume
# 龍記炒燴
# 龍記炒燴
# BING 繽
# BING 繽
# 跑飯店 the Paw Hotel-tutti cafe(新生店)
# 跑飯店 the Paw Hotel-tutti cafe(新生店)
# 香豪肉粽
# 香豪肉粽
# 阿桃越南小吃
# 阿桃越南小吃
# 良沐鍋物
# 良沐鍋物
# 港式威記燒臘
# 港式威記燒臘
# 開飯川食堂(南港中信店)
# 開飯川食堂(南港中信店)
# 原味食尚
# 原味食尚
# MICHA 米迦千層。乳酪蛋糕(板橋正隆店)
# MICHA 米迦千層。乳酪蛋糕(板橋正隆店)
# 轉角披薩 Corner Pizza
# 轉角披薩 Corner Pizza
# 愛評測試其他小吃
# 愛評測試其他小吃
# 女巫店
# 女巫店
# Moon Deer 慕朵
# Moon Deer 慕朵
# 東京時光
# 東京時光
# Neko_Cara(外帶專門店)
# Neko_Cara(外帶專門店)
# 韓二寶(徐匯廣場店)
# 韓二寶(徐匯廣場店)
# 棉朵花朵棉花糖手作坊
# 棉朵花朵棉花糖手作坊
# 郎 港式鮮肉包
# 郎 港式鮮肉包
# Mr.Onion 牛排餐廳(三重重新店)
# Mr.Onion 牛排餐廳(三重重新店)
# 麥當勞(高雄五福二店)
# 麥當勞(高雄五福二店)
# 麥方ㄆㄤˋ咖烘焙坊
# 麥方ㄆㄤˋ咖烘焙坊
# 麥當勞(高雄漢神店)
# 麥當勞(高雄漢神店)
# 開門茶堂
# 開門茶堂
# 麥當勞(高雄一心店)
# 麥當勞(高雄一心店)
# 豊好X天天都美好
# 豊好X天天都美好
# 貝肯庄Bake Culture
# 貝肯庄Bake Culture
# 麥當勞(高雄三越店)
# 麥當勞(高雄三越店)
# 隨行廚房
# 隨行廚房
# 超餡食泡芙(蜂蜜焙茶&伯爵巧克力)
# 超餡食泡芙(蜂蜜焙茶&伯爵巧克力)
# 菽 豆花豆乳飲品專賣
# 菽 豆花豆乳飲品專賣
# MOS TAIPEI MAFIA
# MOS TAIPEI MAFIA
# 自在軒健康茶飲(佳里店)
# 自在軒健康茶飲(佳里店)
# 萬里香蔥油餅
# 萬里香蔥油餅
# Leway樂の本味(善化店)
# Leway樂の本味(善化店)
# 飲酒駅
# 飲酒駅
# 羅丹薩咖啡(中正店)
# 羅丹薩咖啡(中正店)
# 炭火烤魷魚
# 炭火烤魷魚
# 挑tea茶飲專賣店(東興旗艦店)
# 挑tea茶飲專賣店(東興旗艦店)
# 麥當勞(高雄夢時代店)
# 麥當勞(高雄夢時代店)
# 品銘無油現烤蛋糕
# 品銘無油現烤蛋糕
# Princess juice&cafe
# Princess juice&cafe
# DeMo House
# DeMo House
# 午號出口Brunch
# 午號出口Brunch
# 佶園茶棧
# 佶園茶棧
# 帝王食補紅面薑母鴨(鳳山店)
# 帝王食補紅面薑母鴨(鳳山店)
# 峰記萬巒豬腳
# 峰記萬巒豬腳
# 醜比頭的祕密花園
# 醜比頭的祕密花園
# 台北音畫館
# 台北音畫館
# 阿育小吃店
# 阿育小吃店
# 台南傳統味小吃店
# 台南傳統味小吃店
# 龍門客棧
# 龍門客棧
# 找鹿Brunch
# 找鹿Brunch
# 鏊屋
# 鏊屋
# 惠記川味牛肉麵
# 惠記川味牛肉麵
# 吳越江浙菜館
# 吳越江浙菜館
# 火星小廚 Cuisine de Mars
# 火星小廚 Cuisine de Mars
# 和風牛肉專賣店
# 和風牛肉專賣店
# 星光碼頭
# 星光碼頭
# 大和屋國際日本料理
# 大和屋國際日本料理
# 家竹亭鍋燒部
# 家竹亭鍋燒部
# Loft 23.5
# Loft 23.5
# 喬英河粉鳝魚花枝麵
# 喬英河粉鳝魚花枝麵
# 米勒馬休法義創意料理
# 米勒馬休法義創意料理
# Mars Coffee
# Mars Coffee
# Easy te易特商務網
# Easy te易特商務網
# 呂媽媽手工豆花
# 呂媽媽手工豆花
# 抄(杪善美甲)
# 抄(杪善美甲)
# 永和四海豆漿
# 永和四海豆漿
# 悟饕花蓮(和平客來堡店)
# 悟饕花蓮(和平客來堡店)
# 五四燒烤牛排
# 五四燒烤牛排
# 1920 JAZZ CLUB &RESTAURANT
# 1920 JAZZ CLUB &RESTAURANT
# 玖街牛肉麵
# 玖街牛肉麵
# 珍馨滷味
# 珍馨滷味
# 伍角
# 伍角
# Captain India 印度隊長
# Captain India 印度隊長
# Queen Steak 皇后碳烤牛排館
# Queen Steak 皇后碳烤牛排館
# 加寶多早餐店
# 加寶多早餐店
# 一藤井茶菓鋪
# 一藤井茶菓鋪
# BRICK WORKS樂高積木主題餐廳(新竹世博店)
# BRICK WORKS樂高積木主題餐廳(新竹世博店)
# 匠takumi職人專門所
# 匠takumi職人專門所
# BLUE NOTE藍調
# BLUE NOTE藍調
# 光東养茶
# 光東养茶
# Chicking - 韓國歐爸呀炸雞
# Chicking - 韓國歐爸呀炸雞
# 慕緹妮烘焙工坊
# 慕緹妮烘焙工坊
# 福岡八女抹茶霜淇淋
# 福岡八女抹茶霜淇淋
# 囍圓咖啡茶飲
# 囍圓咖啡茶飲
# 囍圓咖啡茶飲(大林蒲店)
# 囍圓咖啡茶飲(大林蒲店)
# 三風麵館紅麴麵
# 三風麵館紅麴麵
# RUBY CAFE
# RUBY CAFE
# IS真香脆皮烤鴨
# IS真香脆皮烤鴨
# 一番地壽喜燒(台北古亭店)
# 一番地壽喜燒(台北古亭店)
# 雲南小館
# 雲南小館
# CoCo Line異國館
# CoCo Line異國館
# 捷克媽媽手工蜂蜜蛋糕
# 捷克媽媽手工蜂蜜蛋糕
# 那隻牛
# 那隻牛
# 四海遊龍鍋貼專賣店(台南西門店)
# 四海遊龍鍋貼專賣店(台南西門店)
# 郭家鍋野菜養生火鍋
# 郭家鍋野菜養生火鍋
# 上好林土魠魚羹
# 上好林土魠魚羹
# 食在好鍋精緻鍋物
# 食在好鍋精緻鍋物
# 焱燒
# 焱燒
# 貝's Home 手作料理小酒館
# 貝's Home 手作料理小酒館
# 月亮咬一口(台中林森店)
# 月亮咬一口(台中林森店)
# 信義牛肉麵
# 信義牛肉麵
# 三姨素食(崇德店)
# 三姨素食(崇德店)
# 嗝咖啡 gé cafe
# 嗝咖啡 gé cafe
# I Sweet Cafe
# I Sweet Cafe
# 愛茶棧
# 愛茶棧
# 918咖啡
# 918咖啡
# 明記燒臘
# 明記燒臘
# 小熊咖啡
# 小熊咖啡
# 夏米私房
# 夏米私房
# 連長小吃店
# 連長小吃店
# 太陽廚房 Sun's Kitchen
# 太陽廚房 Sun's Kitchen
# 喜得炭火燒三明治(台中重慶店)
# 喜得炭火燒三明治(台中重慶店)
# 上濱小吃店
# 上濱小吃店
# 老店客家菜
# 老店客家菜
# 嘉義黑香腸
# 嘉義黑香腸
# 巴布 BAMUHCAFETEA
# 巴布 BAMUHCAFETEA
# 蔡家麻糬(碧潭店)
# 蔡家麻糬(碧潭店)
# 鴦阿阿嬤的東港肉粿
# 鴦阿阿嬤的東港肉粿
# 通霄鐵臉盆燒酒雞
# 通霄鐵臉盆燒酒雞
# 班迪克咖啡
# 班迪克咖啡
# Q比廚房
# Q比廚房
# 可樂芙寵物手作烘焙坊
# 可樂芙寵物手作烘焙坊
# Awake til Sleep 醒而眠手烘咖啡吧
# Awake til Sleep 醒而眠手烘咖啡吧
# 古早味鹹湯圓
# 古早味鹹湯圓
# 白米咖啡早午餐工坊
# 白米咖啡早午餐工坊
# 雞蛋仔
# 雞蛋仔
# 清堤義大利麵
# 清堤義大利麵
# 沙貝葉咖啡
# 沙貝葉咖啡
# 炎術
# 炎術
# 久藏料亭
# 久藏料亭
# 開心農園
# 開心農園
# 餐廳日
# 餐廳日
# 萬丹紅豆餅(黎明市場)
# 萬丹紅豆餅(黎明市場)
# 【勇智企業】現榨100%純苦茶油
# 【勇智企業】現榨100%純苦茶油
# Cheers 乾杯吧
# Cheers 乾杯吧
# NU PASTA(高雄建國店)
# NU PASTA(高雄建國店)
# 本心咖啡自家烘焙館
# 本心咖啡自家烘焙館
# 豐仁冰創始店(三民分店)
# 豐仁冰創始店(三民分店)
# 法里斯法式經典起司蛋糕
# 法里斯法式經典起司蛋糕
# 129巷'咖啡館
# 129巷'咖啡館
# 哈美式三明治
# 哈美式三明治
# 美香牛肉麵
# 美香牛肉麵
# J‧E CAF'E 簡‧愛咖啡館
# J‧E CAF'E 簡‧愛咖啡館
# 鯊魚煙大王-桃園八德
# 鯊魚煙大王-桃園八德
# 猛嘎海鮮燒物
# 猛嘎海鮮燒物
# 岩燒鱈片
# 岩燒鱈片
# 晶冠食堂
# 晶冠食堂
# 咖啡工廠-台中西屯店
# 咖啡工廠-台中西屯店
# 波哥茶飲
# 波哥茶飲
# 幸福蜜語
# 幸福蜜語
# ICE 735(內壢店)
# ICE 735(內壢店)
# 王記菜頭粿米腸
# 王記菜頭粿米腸
# 林家麻豆文旦城
# 林家麻豆文旦城
# Atti咖啡研究工坊
# Atti咖啡研究工坊
# Angel Mini Caf’e 行動咖啡車
# Angel Mini Caf’e 行動咖啡車
# 士林廟口我豪蝦
# 士林廟口我豪蝦
# 嘉朋碳烤澎湖牡蠣
# 嘉朋碳烤澎湖牡蠣
# 食方味會館
# 食方味會館
# 巧意傳統鵝肉店
# 巧意傳統鵝肉店
# 東央貢。泰食堂
# 東央貢。泰食堂
# 洪家素食
# 洪家素食
# 果漾莊園
# 果漾莊園
# 花蓮無名早點
# 花蓮無名早點
# 米歐美食饗宴
# 米歐美食饗宴
# 時光森林TimeForest
# 時光森林TimeForest
# 大海呼麥(大海呼麥)
# 大海呼麥(大海呼麥)
# 竹間精緻鍋物(台北農安店)
# 竹間精緻鍋物(台北農安店)
# 倉崎 鮨‧割烹
# 倉崎 鮨‧割烹
# 漫高三明治
# 漫高三明治
# 阿娟早餐店
# 阿娟早餐店
# 月見町
# 月見町
# 問鼎麻辣鍋養生鍋(忠孝店)
# 問鼎麻辣鍋養生鍋(忠孝店)
# 產出The Food
# 產出The Food
# 鍋吤滿
# 鍋吤滿
# 葡京茶餐廳
# 葡京茶餐廳
# 阿咪米苔目
# 阿咪米苔目
# 宅倫灶咖
# 宅倫灶咖
# Kohimomento一瞬咖啡
# Kohimomento一瞬咖啡
# 波哥茶飲(台南勝利店)
# 波哥茶飲(台南勝利店)
# 馫品咖啡
# 馫品咖啡
# 春秋戰鍋
# 春秋戰鍋
# 稻稻來社區廚房
# 稻稻來社區廚房
# 天尊日本料理店
# 天尊日本料理店
# 微笑義大利麵
# 微笑義大利麵
# 微笑蛋餅
# 微笑蛋餅
# Mr.Onion洋蔥牛排餐廳(昕境廣場)
# Mr.Onion洋蔥牛排餐廳(昕境廣場)
# 香記脆皮烤鴨
# 香記脆皮烤鴨
# Sweet手作果物
# Sweet手作果物
# 民生公寓
# 民生公寓
# 賴桑壽司屋
# 賴桑壽司屋
# 小確幸串燒居酒屋(板橋店)
# 小確幸串燒居酒屋(板橋店)
# 美蔬館(東海店)
# 美蔬館(東海店)
# 築田日本式アイデアの料理
# 築田日本式アイデアの料理
# 早餐的家
# 早餐的家
# 岩森仙草(和美店)
# 岩森仙草(和美店)
# 大根立食亭
# 大根立食亭
# 皇老爺台灣溫體牛涮涮鍋專賣店
# 皇老爺台灣溫體牛涮涮鍋專賣店
# Salu 文創&七個醫師的咖啡
# Salu 文創&七個醫師的咖啡
# DolceVita多茄米拉創意甜點
# DolceVita多茄米拉創意甜點
# 波特多馬鈴薯
# 波特多馬鈴薯
# BIG 超大牛排專賣店
# BIG 超大牛排專賣店
# 第一碗滷肉飯(竹東分店)
# 第一碗滷肉飯(竹東分店)
# 傻師傅湯包(中山北店)
# 傻師傅湯包(中山北店)
# 米樂咖啡簡餐
# 米樂咖啡簡餐
# 小辛燙御品麻辣燙
# 小辛燙御品麻辣燙
# KANY BRUNCH
# KANY BRUNCH
# 可汗燒烤
# 可汗燒烤
# 早安！美芝城(大同路二段店)
# 早安！美芝城(大同路二段店)
# 和平虱目魚店
# 和平虱目魚店
# 水圳邊早點
# 水圳邊早點
# 阿財烤肉(永春店)
# 阿財烤肉(永春店)
# 路易·莎咖啡
# 路易·莎咖啡
# 都提咖啡屋
# 都提咖啡屋
# hMDC CAFE'
# hMDC CAFE'
# 彩虹糖輕食義大利麵館
# 彩虹糖輕食義大利麵館
# Daylight光合箱子(台北南京店)
# Daylight光合箱子(台北南京店)
# 客家小吃
# 客家小吃
# GREEN BAKERY 綠帶純植物烘焙
# GREEN BAKERY 綠帶純植物烘焙
# 甜蜜小屋 Sweet Home
# 甜蜜小屋 Sweet Home
# HOOD
# HOOD
# Corner 21
# Corner 21
# 漁都
# 漁都
# 上好吃鐵板燒(歸仁店)
# 上好吃鐵板燒(歸仁店)
# 老先覺麻辣窯燒鍋(台中潭子店)
# 老先覺麻辣窯燒鍋(台中潭子店)
# 123家常菜館
# 123家常菜館
# 貴哥小吃
# 貴哥小吃
# 粉愛配
# 粉愛配
# 無名阿婆飯糰
# 無名阿婆飯糰
# 三姐妹米苔目
# 三姐妹米苔目
# 艾倫廚房 Allen's daily kitchen
# 艾倫廚房 Allen's daily kitchen
# 紅滋滋美食鍋
# 紅滋滋美食鍋
# 日豐便當店
# 日豐便當店
# 可瑞安韓國美食
# 可瑞安韓國美食
# Input Music音鋪
# Input Music音鋪
# 老樹Tea Brunch
# 老樹Tea Brunch
# SOYoung 逗漾(裕民店)
# SOYoung 逗漾(裕民店)
# 思慕昔精緻早午餐店
# 思慕昔精緻早午餐店
# 超神鮮10元壽司連鎖專賣店(台中屋日店)
# 超神鮮10元壽司連鎖專賣店(台中屋日店)
# 歡喜紅蔥飯
# 歡喜紅蔥飯
# 開丼！いただきます 燒肉vs丼飯(忠孝東區店)
# 開丼！いただきます 燒肉vs丼飯(忠孝東區店)
# 冰博士冷飲工坊
# 冰博士冷飲工坊
# 洪十一擔仔麵(微風台大醫院)
# 洪十一擔仔麵(微風台大醫院)
# 喜羊羊羊肉鍋吃到飽
# 喜羊羊羊肉鍋吃到飽
# 鳳山黑輪
# 鳳山黑輪
# 起床號 早午餐
# 起床號 早午餐
# 楊家魯肉飯(三峽)
# 楊家魯肉飯(三峽)
# 葉家庄
# 葉家庄
# Basil Le Bistro
# Basil Le Bistro
# 搖一碗牛肉麵
# 搖一碗牛肉麵
# 台香麻辣麵線
# 台香麻辣麵線
# 十味觀食品
# 十味觀食品
# Lab146 Cafe and Kitchen
# Lab146 Cafe and Kitchen
# 台北文華東方酒店-大宴會廳
# 台北文華東方酒店-大宴會廳
# 寶達港式餐廳
# 寶達港式餐廳
# 海是甜的 Honey Ocean
# 海是甜的 Honey Ocean
# Homme Bistro
# Homme Bistro
# 東京精緻創意鐵板燒
# 東京精緻創意鐵板燒
# 佛爾諾窯烤披薩
# 佛爾諾窯烤披薩
# 總舵口上選復刻連鎖茶飲(旗楠總舵)
# 總舵口上選復刻連鎖茶飲(旗楠總舵)
# Saizeriya薩莉亞義大利料理(公館店)
# Saizeriya薩莉亞義大利料理(公館店)
# 优客咖啡館 U.can Cafe
# 优客咖啡館 U.can Cafe
# 樂餅屋
# 樂餅屋
# 大和宅
# 大和宅
# HAMI dessert studio
# HAMI dessert studio
# 日僑壽司
# 日僑壽司
# 北方村
# 北方村
# 聖寶羅專業炸食館
# 聖寶羅專業炸食館
# 蓋飯先生
# 蓋飯先生
# 正老牌草魚粥
# 正老牌草魚粥
# 西河灣熱炒
# 西河灣熱炒
# 素蔬美食
# 素蔬美食
# Hsin王子 早午餐
# Hsin王子 早午餐
# 衝記蔥油餅
# 衝記蔥油餅
# 舒果新米蘭蔬食(竹北光明店)
# 舒果新米蘭蔬食(竹北光明店)
# 米樂屋
# 米樂屋
# 久賀牛排
# 久賀牛排
# 好時光Brunch早午餐
# 好時光Brunch早午餐
# 冰BAR
# 冰BAR
# 榮星宮保雞丁飯
# 榮星宮保雞丁飯
# 劉媽媽手工坊
# 劉媽媽手工坊
# 青蚵嫂布袋烤鮮蚵
# 青蚵嫂布袋烤鮮蚵
# #LATTICE 拉堤斯比利時列日鬆餅(台北光復店)
# #LATTICE 拉堤斯比利時列日鬆餅(台北光復店)
# 駱師傅法式冰淇淋之家
# 駱師傅法式冰淇淋之家
# 阿Q包子
# 阿Q包子
# 帕瑪森乳酪蛋糕(原味/巧克力)
# 帕瑪森乳酪蛋糕(原味/巧克力)
# PK Caffè
# PK Caffè
# 康好早點豆漿
# 康好早點豆漿
# NoddleMix禮面作(BINGO館大同店)
# NoddleMix禮面作(BINGO館大同店)
# Sunny Bagel 太陽貝果
# Sunny Bagel 太陽貝果
# 單眼皮双眼皮早餐輕食
# 單眼皮双眼皮早餐輕食
# 麥味登&REAL 臻烘培坊(北市松德店)
# 麥味登&REAL 臻烘培坊(北市松德店)
# 麥味登&REAL 臻烘培坊(北市健康店)
# 麥味登&REAL 臻烘培坊(北市健康店)
# 阿米哥手工薄皮披薩Amigo Pizza
# 阿米哥手工薄皮披薩Amigo Pizza
# 餡老滿(晶冠店)
# 餡老滿(晶冠店)
# 瓦楞飲品專賣店
# 瓦楞飲品專賣店
# 船井醫朵-burner light輕快燃料輕食粥
# 船井醫朵-burner light輕快燃料輕食粥
# MR.Toast 吐司先生
# MR.Toast 吐司先生
# 大丸烤布丁
# 大丸烤布丁
# A place
# A place
# 莉莉媽水餃舖
# 莉莉媽水餃舖
# 微笑日日紅
# 微笑日日紅
# 黃師傅手工火烤披薩(斗六店)
# 黃師傅手工火烤披薩(斗六店)
# 享宴碳烤牛排
# 享宴碳烤牛排
# 獅子王親子烘培
# 獅子王親子烘培
# 多一點咖啡館-新灣館-品牌特許授權店
# 多一點咖啡館-新灣館-品牌特許授權店
# 歷穌窯麵包
# 歷穌窯麵包
# 蜂蜜核桃塔
# 蜂蜜核桃塔
# 帝王食補紅面薑母鴨(廣豐店)
# 帝王食補紅面薑母鴨(廣豐店)
# 湯世代溫泉餐廳
# 湯世代溫泉餐廳
# 拿披薩
# 拿披薩
# 屏東羊肉麵
# 屏東羊肉麵
# 5餅2魚手工披薩(安樂店)
# 5餅2魚手工披薩(安樂店)
# Amazing Thai 愛麵館
# Amazing Thai 愛麵館
# 喬治素漢堡
# 喬治素漢堡
# 豆語精品咖啡烘焙坊
# 豆語精品咖啡烘焙坊
# D2惡魔可可概念店(桃園南崁店)
# D2惡魔可可概念店(桃園南崁店)
# 泰滋味平價泰式料理
# 泰滋味平價泰式料理
# 杯杯炸雞CHICKEN CUP(高雄店)
# 杯杯炸雞CHICKEN CUP(高雄店)
# 宜蘭麥田現釀啤酒Beer(板橋店)
# 宜蘭麥田現釀啤酒Beer(板橋店)
# 阿婆鍋燒炸麵
# 阿婆鍋燒炸麵
# The V:F 舞蔬弄果(竹北店)
# The V:F 舞蔬弄果(竹北店)
# 木葉粗食 Mottainai Vegetarian Restaurant & Cafe’
# 木葉粗食 Mottainai Vegetarian Restaurant & Cafe’
# 窗口吐司
# 窗口吐司
# DOJA小仁泉極品豆漿
# DOJA小仁泉極品豆漿
# 日月酒莊(醋)
# 日月酒莊(醋)
# 素珠芋丸
# 素珠芋丸
# 鹿港鮮蚵捲
# 鹿港鮮蚵捲
# PETER BETTER CAFE'
# PETER BETTER CAFE'
# bonheur波納爾舒芙蕾
# bonheur波納爾舒芙蕾
# 家元手工豆花
# 家元手工豆花
# Icegood愛吃不可
# Icegood愛吃不可
# 貴族世家牛排(海洋大學店)
# 貴族世家牛排(海洋大學店)
# 找找我早午餐
# 找找我早午餐
# 劉家丸子舖
# 劉家丸子舖
# 薏蓮坊精緻養生甜品飲品專賣店(嘉義民雄店)
# 薏蓮坊精緻養生甜品飲品專賣店(嘉義民雄店)
# 遇見8號
# 遇見8號
# 海鮮平價
# 海鮮平價
# 妳有咖啡
# 妳有咖啡
# 法爾木咖啡 Firewood cafe
# 法爾木咖啡 Firewood cafe
# 荳桑
# 荳桑
# 楓香烤布蕾
# 楓香烤布蕾
# 幸福旅人
# 幸福旅人
# 布朗爵尼手作烘焙
# 布朗爵尼手作烘焙
# 蝸老闆風味餐廳
# 蝸老闆風味餐廳
# 原湘蔥抓餅
# 原湘蔥抓餅
# 石頭魚鐵道庭園咖啡
# 石頭魚鐵道庭園咖啡
# 泰味泰式料理
# 泰味泰式料理
# 僾果鮮
# 僾果鮮
# RUGO有機蔬食滷味
# RUGO有機蔬食滷味
# 富島翁 日式火鍋 輕食
# 富島翁 日式火鍋 輕食
# 喬口福風味小火鍋
# 喬口福風味小火鍋
# 東街日本料理(龍江店)
# 東街日本料理(龍江店)
# 庫亞斯咖啡烘焙屋 Cross Kafe
# 庫亞斯咖啡烘焙屋 Cross Kafe
# Campus Cafe(內湖店)
# Campus Cafe(內湖店)
# 香元港式茶餐廳
# 香元港式茶餐廳
# 羽翁生活飲食館
# 羽翁生活飲食館
# 醬菜三兄妹
# 醬菜三兄妹
# My MORE 天然酵母 烘培餐廳(中和中安店)
# My MORE 天然酵母 烘培餐廳(中和中安店)
# My MORE 天然酵母 烘培餐廳(台北天母店)
# My MORE 天然酵母 烘培餐廳(台北天母店)
# 穎川美食館
# 穎川美食館
# 排排饡(屏東店)
# 排排饡(屏東店)
# 登琪爾樂善莊-天母餐廳
# 登琪爾樂善莊-天母餐廳
# AM田原
# AM田原
# 六窟溫泉餐廳
# 六窟溫泉餐廳
# 鮮魚湯(台南佳里區)
# 鮮魚湯(台南佳里區)
# THE SANDRICH HOUSE
# THE SANDRICH HOUSE
# 綠香柚子
# 綠香柚子
# Mr.拉麵
# Mr.拉麵
# 日光角落 Coin de soleil
# 日光角落 Coin de soleil
# 嗆頂級麻辣鴛鴦火鍋(內湖店)
# 嗆頂級麻辣鴛鴦火鍋(內湖店)
# 六甲區媽祖廟麵茶冰店
# 六甲區媽祖廟麵茶冰店
# 日樂酒場(板橋)
# 日樂酒場(板橋)
# 阿吉媽湯滷味(總店)
# 阿吉媽湯滷味(總店)
# Double Soul coffee&bistro
# Double Soul coffee&bistro
# 富野香 - 鍋燒意麵 海鮮粥專賣店
# 富野香 - 鍋燒意麵 海鮮粥專賣店
# 招牌原汁紅燒牛肉麵+饗SO蒟蒻麵
# 招牌原汁紅燒牛肉麵+饗SO蒟蒻麵
# Siblings House 西菲斯法式精品甜點
# Siblings House 西菲斯法式精品甜點
# 胖叔叔專業肉羹咖哩飯
# 胖叔叔專業肉羹咖哩飯
# Madker live house&restaurant 美德客音樂餐酒館
# Madker live house&restaurant 美德客音樂餐酒館
# 熊二輕食
# 熊二輕食
# J.B Café 樂活廚房
# J.B Café 樂活廚房
# Wooso Caf 'e kitchen
# Wooso Caf 'e kitchen
# 阿坤炒飯
# 阿坤炒飯
# 30幾年麵店
# 30幾年麵店
# 東港現撈生魚片
# 東港現撈生魚片
# 棒棒屋
# 棒棒屋
# 王家筒仔米糕排骨酥湯
# 王家筒仔米糕排骨酥湯
# Weekend 餐酒館
# Weekend 餐酒館
# 總舵口上選復刻連鎖茶飲(後勁分舵)
# 總舵口上選復刻連鎖茶飲(後勁分舵)
# 艋舺雞排(台北士林店)
# 艋舺雞排(台北士林店)
# Burger Talks 淘客美式漢堡(台北三創園區店)
# Burger Talks 淘客美式漢堡(台北三創園區店)
# 四川牛肉麵館
# 四川牛肉麵館
# 野餐吧吐司
# 野餐吧吐司
# 人文工坊
# 人文工坊
# 阿娟咖哩飯
# 阿娟咖哩飯
# 在心田 Cafe&Bread
# 在心田 Cafe&Bread
# 開機咖啡 Rolling Café
# 開機咖啡 Rolling Café
# PIZZA桑
# PIZZA桑
# COOL N2 分子雪糕(台中逢甲店)
# COOL N2 分子雪糕(台中逢甲店)
# 克里特 CRETE TEA & COFFEE
# 克里特 CRETE TEA & COFFEE
# 普拉伯義大利坊
# 普拉伯義大利坊
# 朱記香港茶水灘
# 朱記香港茶水灘
# 法諾米義大利麵
# 法諾米義大利麵
# 閱築藝文咖啡館
# 閱築藝文咖啡館
# 品樂菓全日早午餐
# 品樂菓全日早午餐
# 天朝御饗---寒天燕窩飲
# 天朝御饗---寒天燕窩飲
# 乾杯(南港中信店)
# 乾杯(南港中信店)
# 五二食館
# 五二食館
# CAFE SLOW TRAIN小火車咖啡館
# CAFE SLOW TRAIN小火車咖啡館
# 九湯屋日本拉麵(東門店)
# 九湯屋日本拉麵(東門店)
# 食出韻-桃園龜山店
# 食出韻-桃園龜山店
# 陽光輕時-碳烤三明治
# 陽光輕時-碳烤三明治
# 威廉森茶在台灣  Williamson Tea in Taiwan
# 威廉森茶在台灣  Williamson Tea in Taiwan
# 英銓喜餅
# 英銓喜餅
# 吳家水晶餃
# 吳家水晶餃
# 星海之戀咖啡館
# 星海之戀咖啡館
# 作田串燒(忠孝支店)
# 作田串燒(忠孝支店)
# 家家久娃娃主題餐廳
# 家家久娃娃主題餐廳
# 竹北蒸鍋原味蒸籠涮涮鍋
# 竹北蒸鍋原味蒸籠涮涮鍋
# ㄇㄢˋㄇㄢˋ咖啡
# ㄇㄢˋㄇㄢˋ咖啡
# juicy 就是脆皮雞排 竹科店
# juicy 就是脆皮雞排 竹科店
# 亞米斯奎 小餐館
# 亞米斯奎 小餐館
# 元祖 銅鑼燒冰淇淋
# 元祖 銅鑼燒冰淇淋
# 好滋味麵館
# 好滋味麵館
# 高佐壽司
# 高佐壽司
# SF小花花咖啡
# SF小花花咖啡
# 我們 Our
# 我們 Our
# 與粽不同
# 與粽不同
# 檸檬草美食茶房(新莊輔大店)
# 檸檬草美食茶房(新莊輔大店)
# 跳格子鬆餅(民權店)
# 跳格子鬆餅(民權店)
# PM.WatCh 壓烤三明治
# PM.WatCh 壓烤三明治
# 好吉市平價生猛活海鮮
# 好吉市平價生猛活海鮮
# 明觀輕食咖啡館
# 明觀輕食咖啡館
# wow漢堡輕食專賣店
# wow漢堡輕食專賣店
# 重拾米糕點手作坊
# 重拾米糕點手作坊
# 天波露茶
# 天波露茶
# 鄭江號 - 緩食茶二店
# 鄭江號 - 緩食茶二店
# DR.GYM勁美膠原飲
# DR.GYM勁美膠原飲
# Cafe食堂KenKen
# Cafe食堂KenKen
# 鴻記水餃
# 鴻記水餃
# Tigertopoki 泰一格韓國年糕火鍋
# Tigertopoki 泰一格韓國年糕火鍋
# 蟹老闆精緻10元壽司
# 蟹老闆精緻10元壽司
# 橘子堡
# 橘子堡
# CLOUDY CUPCAKE 克勞蒂杯子蛋糕(高雄明華店)
# CLOUDY CUPCAKE 克勞蒂杯子蛋糕(高雄明華店)
# momi&toy's
# momi&toy's
# Colive tea house
# Colive tea house
# 路人咖啡Ruh Cafe
# 路人咖啡Ruh Cafe
# 好初北方麵
# 好初北方麵
# 台南福氣臭臭鍋(中華店)
# 台南福氣臭臭鍋(中華店)
# 山間小館(ATT店)
# 山間小館(ATT店)
# CCC咖啡早午餐
# CCC咖啡早午餐
# 壹錢洋食
# 壹錢洋食
# 林桑新加坡LAKSA麵
# 林桑新加坡LAKSA麵
# 紫蝶花影食茶餅舖
# 紫蝶花影食茶餅舖
# 快樂角天然酵母麵包坊
# 快樂角天然酵母麵包坊
# 上原燒肉
# 上原燒肉
# 樸樂咖啡
# 樸樂咖啡
# 金彩好茶
# 金彩好茶
# 專芳
# 專芳
# 斗新永氣鍋牛肉
# 斗新永氣鍋牛肉
# 竹南虱目魚大王
# 竹南虱目魚大王
# 粥公食堂(樹林店)
# 粥公食堂(樹林店)
# Asado美式西餐廳
# Asado美式西餐廳
# 白色小屋
# 白色小屋
# 明治胺基膠原食品
# 明治胺基膠原食品
# 嗑廳.COM
# 嗑廳.COM
# 金艾家手工冰淇淋
# 金艾家手工冰淇淋
# 胖卡鬆餅 Pan Car Waffle
# 胖卡鬆餅 Pan Car Waffle
# 李家韓國食堂
# 李家韓國食堂
# 木爾多養生飲品
# 木爾多養生飲品
# 元氣海苔飯捲
# 元氣海苔飯捲
# 欣海岸海鮮料理
# 欣海岸海鮮料理
# 劉江便當(劉江便當(三多店))
# 劉江便當(劉江便當(三多店))
# GENHAO日本玄米油
# GENHAO日本玄米油
# 猋師傅便當專賣店(屏東店)
# 猋師傅便當專賣店(屏東店)
# 布洛子手遊餐館
# 布洛子手遊餐館
# 拾肆番拉麵
# 拾肆番拉麵
# 麗媽四季鍋
# 麗媽四季鍋
# 福 麻糬豆花(藝文店)
# 福 麻糬豆花(藝文店)
# 米夏費德爾
# 米夏費德爾
# 無名素食煎包攤
# 無名素食煎包攤
# 牛肉友
# 牛肉友
# 明德素食園(誠品敦南店)
# 明德素食園(誠品敦南店)
# 吉豆有機工坊
# 吉豆有機工坊
# 尋早早餐
# 尋早早餐
# 萬暉名產 牛舌餅
# 萬暉名產 牛舌餅
# 咖你不可
# 咖你不可
# 小巷亭壽司
# 小巷亭壽司
# 太子美食餐廳
# 太子美食餐廳
# 6-1號現滷滷味
# 6-1號現滷滷味
# 手在比薩
# 手在比薩
# 建宏牛肉麵
# 建宏牛肉麵
# 義尤味勁
# 義尤味勁
# LATTEA綠蓋茶館(淡水店)
# LATTEA綠蓋茶館(淡水店)
# 三清閣
# 三清閣
# NUKI Coffee
# NUKI Coffee
# 紅音涮涮鍋
# 紅音涮涮鍋
# 花婆婆養生火鍋
# 花婆婆養生火鍋
# Sasha's Burger 啥漢堡
# Sasha's Burger 啥漢堡
# 烏日水煎包
# 烏日水煎包
# smith&hsu(南京東路店)
# smith&hsu(南京東路店)
# 義麵寶寶義大利麵餐館(五股成泰店)
# 義麵寶寶義大利麵餐館(五股成泰店)
# 阿展手工乾麵
# 阿展手工乾麵
# 野人手作串燒
# 野人手作串燒
# 愛麗莎美食屋
# 愛麗莎美食屋
# 夢東籬(文平店)
# 夢東籬(文平店)
# 紅館赫氏鍋餅店(師大店)
# 紅館赫氏鍋餅店(師大店)
# 元氣貓主題餐廳
# 元氣貓主題餐廳
# 海宴涮涮屋(林口長庚店)
# 海宴涮涮屋(林口長庚店)
# 奢草串燒
# 奢草串燒
# 彩饌中日便當行
# 彩饌中日便當行
# 吉拉朵先生義式冰淇淋專賣店
# 吉拉朵先生義式冰淇淋專賣店
# 佬地方牛排
# 佬地方牛排
# 豆腐安仔手工豆腐
# 豆腐安仔手工豆腐
# 汐止古早味
# 汐止古早味
# 老董牛肉麵 (公館捷運店)
# 老董牛肉麵 (公館捷運店)
# 林肯麵棧
# 林肯麵棧
# 巷子廚坊
# 巷子廚坊
# 劉家酸白菜火鍋(台北新莊直營店)
# 劉家酸白菜火鍋(台北新莊直營店)
# Mr.雪腐
# Mr.雪腐
# 月世界山頂土雞城
# 月世界山頂土雞城
# 無名抓餅及黑輪攤
# 無名抓餅及黑輪攤
# 烏醋麵黑白切
# 烏醋麵黑白切
# 0870 Australian Kitchen
# 0870 Australian Kitchen
# 玉陶園韓式料理
# 玉陶園韓式料理
# 文松代客料理
# 文松代客料理
# 極野宴燒肉專門店(遠雄購物中心汐止旗艦店)
# 極野宴燒肉專門店(遠雄購物中心汐止旗艦店)
# Ocean Blue 複合式餐廳
# Ocean Blue 複合式餐廳
# 麵包劇場 Alter Ego 1892
# 麵包劇場 Alter Ego 1892
# 英吉利活海產
# 英吉利活海產
# 雙連圓仔湯
# 雙連圓仔湯
# Starbucks Coffee 統一星巴克(city link)
# Starbucks Coffee 統一星巴克(city link)
# 南美村ㄚ狗ㄚ喵
# 南美村ㄚ狗ㄚ喵
# La Design Cafe
# La Design Cafe
# 九鼎鐵板燒
# 九鼎鐵板燒
# 恩龍小吃店
# 恩龍小吃店
# 海洋手工造型水餃
# 海洋手工造型水餃
# 饕鮮包子饅頭店
# 饕鮮包子饅頭店
# 橙色食品
# 橙色食品
# 誠記越南麵食館(永康二店)
# 誠記越南麵食館(永康二店)
# Lofa咖啡
# Lofa咖啡
# 繽豆咖啡
# 繽豆咖啡
# 溫室造咖
# 溫室造咖
# 客家鍾豬腳
# 客家鍾豬腳
# 美可食品工業股份有限公司
# 美可食品工業股份有限公司
# 綠茵咖啡
# 綠茵咖啡
# Nutella 能多益隨手杯
# Nutella 能多益隨手杯
# 台灣塩酥雞(新莊店)
# 台灣塩酥雞(新莊店)
# ‎小確幸手工水餃 推薦の好物天堂
# ‎小確幸手工水餃 推薦の好物天堂
# 半九十茶屋
# 半九十茶屋
# 韓饌韓式料理
# 韓饌韓式料理
# 多力可樂餅專賣(大里店)
# 多力可樂餅專賣(大里店)
# 日式拉麵
# 日式拉麵
# 統元豆花(漢口店)
# 統元豆花(漢口店)
# 饗贊石頭火鍋
# 饗贊石頭火鍋
# 免師傅肉品調理專賣
# 免師傅肉品調理專賣
# 手工臭豆腐、芋頭米粉湯
# 手工臭豆腐、芋頭米粉湯
# 金山七里香家味碳烤
# 金山七里香家味碳烤
# 叻沙麵館(南機場夜市)
# 叻沙麵館(南機場夜市)
# 北一綠豆沙
# 北一綠豆沙
# 全壽司
# 全壽司
# 泳富家
# 泳富家
# 御捲屋
# 御捲屋
# 健康路無名早點
# 健康路無名早點
# 綠葉 南洋風味料理
# 綠葉 南洋風味料理
# 香港豪記茶餐廳
# 香港豪記茶餐廳
# 紅豆湯、挫冰、燒仙草
# 紅豆湯、挫冰、燒仙草
# 樂禾烘焙手創坊(原幾之米菓子烘焙手創坊)
# 樂禾烘焙手創坊(原幾之米菓子烘焙手創坊)
# 台南味葉家小卷米粉(二店)
# 台南味葉家小卷米粉(二店)
# 崑崙養生莊園-輕食餐廳
# 崑崙養生莊園-輕食餐廳
# 呂媽麵飯館
# 呂媽麵飯館
# 三廠炸醬麵
# 三廠炸醬麵
# 裕榮燒番麥-原味(115g/包)
# 裕榮燒番麥-原味(115g/包)
# 斯諾客雪花冰品
# 斯諾客雪花冰品
# 兔兔窩家飾咖啡館
# 兔兔窩家飾咖啡館
# Moi café
# Moi café
# 218巷味蕾工房
# 218巷味蕾工房
# 曾家涼麵
# 曾家涼麵
# 日出-宮原眼科-摘星樓
# 日出-宮原眼科-摘星樓
# 米淇淋手作霜淇淋
# 米淇淋手作霜淇淋
# 51號咖啡屋
# 51號咖啡屋
# Yummy Pancake
# Yummy Pancake
# 日月潭紅茶廠
# 日月潭紅茶廠
# Hsun style 勳料理
# Hsun style 勳料理
# 麵屋一龍拉麵專門店
# 麵屋一龍拉麵專門店
# 北海岸海鮮樓
# 北海岸海鮮樓
# 有FU社區文化飲食空間
# 有FU社區文化飲食空間
# Chop Chop 恰恰食堂親子餐廳
# Chop Chop 恰恰食堂親子餐廳
# 韓風堂手作韓食
# 韓風堂手作韓食
# 遇貴人家庭式餐館
# 遇貴人家庭式餐館
# CoCo壹番屋咖哩飯(大直美麗華店)
# CoCo壹番屋咖哩飯(大直美麗華店)
# chez nous
# chez nous
# ABV Bar & Kitchen 啤酒餐廳
# ABV Bar & Kitchen 啤酒餐廳
# 德也精緻涮涮鍋
# 德也精緻涮涮鍋
# 巷弄廚房 S.N. Kitchen
# 巷弄廚房 S.N. Kitchen
# 可麗露手作烘焙
# 可麗露手作烘焙
# 鬆歪歪鬆餅
# 鬆歪歪鬆餅
# 愛倫手感烘焙
# 愛倫手感烘焙
# 浮基仔香腸
# 浮基仔香腸
# 加栗諾
# 加栗諾
# 薔薇蘿拉咖啡館
# 薔薇蘿拉咖啡館
# 古典玫瑰園(新竹遠百店)
# 古典玫瑰園(新竹遠百店)
# 古典玫瑰園(宜蘭美術館食堂)
# 古典玫瑰園(宜蘭美術館食堂)
# 三方六 日式食堂
# 三方六 日式食堂
# 一也本舖 豆乳雞翅
# 一也本舖 豆乳雞翅
# 艾旦香雞排
# 艾旦香雞排
# 饅頭人創意饅頭
# 饅頭人創意饅頭
# 皇豆豆花
# 皇豆豆花
# 林奶奶手作果乾
# 林奶奶手作果乾
# 皇后複合式餐飲
# 皇后複合式餐飲
# 四哥的店(二店)
# 四哥的店(二店)
# 中央畜牧場-家香豬
# 中央畜牧場-家香豬
# Yami亞米鬆餅鋪(楠梓德賢店)
# Yami亞米鬆餅鋪(楠梓德賢店)
# 樹林大鈺門燒烤火鍋店
# 樹林大鈺門燒烤火鍋店
# B.G 工房アイスーたい焼き 鯛魚燒專門店
# B.G 工房アイスーたい焼き 鯛魚燒專門店
# ZEST三五會館觀景餐廳(天母東山店)
# ZEST三五會館觀景餐廳(天母東山店)
# 茶米涼品
# 茶米涼品
# 南大門
# 南大門
# 滋養製菓
# 滋養製菓
# 福站牛肉麵
# 福站牛肉麵
# 台南東區焦糖煉乳包心粉圓(屏東復興店)
# 台南東區焦糖煉乳包心粉圓(屏東復興店)
# FLORA
# FLORA
# 創義麵(士林捷運站分店)
# 創義麵(士林捷運站分店)
# PappaRich 金爸爸(市民店)
# PappaRich 金爸爸(市民店)
# 即食享樂
# 即食享樂
# 老林記愛玉冰
# 老林記愛玉冰
# 食本味
# 食本味
# FUN Tower 日式可麗餅-高雄旗艦店
# FUN Tower 日式可麗餅-高雄旗艦店
# UDON讚岐烏龍麵
# UDON讚岐烏龍麵
# 溫馨小廚
# 溫馨小廚
# 三商巧福(高雄明誠店)
# 三商巧福(高雄明誠店)
# 波波廚房
# 波波廚房
# 銘記煎粿
# 銘記煎粿
# 禾家鄉麵線糊
# 禾家鄉麵線糊
# 泡菜醬吃
# 泡菜醬吃
# 走廊倉廚-Zaolong 貳號倉
# 走廊倉廚-Zaolong 貳號倉
# Winnie Love 布蕾專賣
# Winnie Love 布蕾專賣
# A-bao早餐店
# A-bao早餐店
# Spot Taipei
# Spot Taipei
# 萬州烤魚
# 萬州烤魚
# Pizza Hut 必勝客(南投南崗)
# Pizza Hut 必勝客(南投南崗)
# 三牛牛肉麵(新光店)
# 三牛牛肉麵(新光店)
# 直式咖啡 Direct Cafe
# 直式咖啡 Direct Cafe
# 卡隆義式焗烤披薩(南投)
# 卡隆義式焗烤披薩(南投)
# 味蕾居酒屋
# 味蕾居酒屋
# 綠光咖啡2號館
# 綠光咖啡2號館
# 一吉鐵板燒
# 一吉鐵板燒
# 來客平價牛排-潭子
# 來客平價牛排-潭子
# 野餐計畫
# 野餐計畫
# 小巷花園
# 小巷花園
# 幸福燒
# 幸福燒
# 良泉豆花豆漿
# 良泉豆花豆漿
# 小亞鐵板燒
# 小亞鐵板燒
# 桑尼咖啡
# 桑尼咖啡
# 古早亭仙草甘茶專賣(大甲店)
# 古早亭仙草甘茶專賣(大甲店)
# 荳荳ちゃん磨菇爆米花
# 荳荳ちゃん磨菇爆米花
# 醉翁漁港海鮮
# 醉翁漁港海鮮
# Megumi 甜蜜屋
# Megumi 甜蜜屋
# 維吾爾新疆碳烤
# 維吾爾新疆碳烤
# 木門咖啡Wooden Door
# 木門咖啡Wooden Door
# Starbucks星巴克 檸檬塔
# Starbucks星巴克 檸檬塔
# 山井大肥鵝日式料理
# 山井大肥鵝日式料理
# Q比美食
# Q比美食
# 地中海冰館
# 地中海冰館
# 樹種子大地蔬食
# 樹種子大地蔬食
# 桐聚 平價料理
# 桐聚 平價料理
# 轉角小麵店
# 轉角小麵店
# 泰鄉館
# 泰鄉館
# HEYDAY
# HEYDAY
# 剛好冰果室
# 剛好冰果室
# 健康時刻-巧克力脆片
# 健康時刻-巧克力脆片
# 阿玉麵館-豬頭肉麵
# 阿玉麵館-豬頭肉麵
# 台灣維根鳳梨
# 台灣維根鳳梨
# 均記 水解珍珠粉
# 均記 水解珍珠粉
# 康喜軒金牛角(西湖休息站門市)
# 康喜軒金牛角(西湖休息站門市)
# 布丁寶貝手工烤布丁烘焙屋
# 布丁寶貝手工烤布丁烘焙屋
# Muse Café
# Muse Café
# 麥仕佳專業烘培坊(大墩店)
# 麥仕佳專業烘培坊(大墩店)
# 王記麻辣火鍋
# 王記麻辣火鍋
# Senfoni wine house土耳其餐廳
# Senfoni wine house土耳其餐廳
# 南京陳嘉興板鴨店
# 南京陳嘉興板鴨店
# 庶民滷三寳
# 庶民滷三寳
# 凱蒂冰果室
# 凱蒂冰果室
# 四季庭中式料理台菜餐廳
# 四季庭中式料理台菜餐廳
# 市場手工鹹湯圓
# 市場手工鹹湯圓
# 北斗大菜市場紅豆餅
# 北斗大菜市場紅豆餅
# 國王烘焙
# 國王烘焙
# 國王烘焙roidupain
# 國王烘焙roidupain
# 7-11大雞肉飯
# 7-11大雞肉飯
# 東街日式料理(鶯歌店)
# 東街日式料理(鶯歌店)
# 羅勒小館
# 羅勒小館
# SUNNY義式廚房
# SUNNY義式廚房
# 紅燈籠古早味拉仔麵
# 紅燈籠古早味拉仔麵
# 雲珍小館
# 雲珍小館
# 文化養生豆花
# 文化養生豆花
# 東方食府
# 東方食府
# 精誠牛肉麵豬腳麵
# 精誠牛肉麵豬腳麵
# 富隆莊餐廳
# 富隆莊餐廳
# 蒔蔬元素 素食餐館
# 蒔蔬元素 素食餐館
# 路易先生早午餐
# 路易先生早午餐
# Donutes 多那之蛋糕咖啡烘焙(和美店)
# Donutes 多那之蛋糕咖啡烘焙(和美店)
# 小草冰吧
# 小草冰吧
# 日森製藥 之 紅豆水 & 舒密野莓 & 水嫩基底
# 日森製藥 之 紅豆水 & 舒密野莓 & 水嫩基底
# 延三海鮮碳烤日本料理
# 延三海鮮碳烤日本料理
# 甜屋菓子坊
# 甜屋菓子坊
# 大埔平價鐵板燒(三重店)
# 大埔平價鐵板燒(三重店)
# 紅茶臭豆腐
# 紅茶臭豆腐
# 新錡麥芽餅
# 新錡麥芽餅
# 阿伯鬆餅
# 阿伯鬆餅
# CW巧克力主題餐廳
# CW巧克力主題餐廳
# 三喜蛋餅((原阿Q蛋餅))
# 三喜蛋餅((原阿Q蛋餅))
# 圓光素食
# 圓光素食
# Aster 愛思特的點心罐
# Aster 愛思特的點心罐
# 家鄉味客家菜
# 家鄉味客家菜
# 新疆界(新春店)
# 新疆界(新春店)
# 台灣磚窰雞
# 台灣磚窰雞
# 飯饌韓式料理(台北站前店(HOYII北車站))
# 飯饌韓式料理(台北站前店(HOYII北車站))
# 翁林林 Café
# 翁林林 Café
# 河南砂鍋手工扔麵
# 河南砂鍋手工扔麵
# 藝境空間 x 虎咖啡
# 藝境空間 x 虎咖啡
# 福岡漁場 庶民日式食堂
# 福岡漁場 庶民日式食堂
# 徐古早味魷魚羹
# 徐古早味魷魚羹
# 佰佳BIOGOOD 天然果乾
# 佰佳BIOGOOD 天然果乾
# 潮味
# 潮味
# 品川蘭(桃園分店)
# 品川蘭(桃園分店)
# Bravo Burger發福廚房(林口店)
# Bravo Burger發福廚房(林口店)
# Bengodi(（原義麵屋）)
# Bengodi(（原義麵屋）)
# 小太陽義大利麵
# 小太陽義大利麵
# 胖子咖哩
# 胖子咖哩
# 工匠咖啡
# 工匠咖啡
# 花蓮一品香扁食
# 花蓮一品香扁食
# 千之壽
# 千之壽
# 光泉薏仁飲
# 光泉薏仁飲
# 葱大爺
# 葱大爺
# 石上川鍋物
# 石上川鍋物
# 禾家酸菜白肉鍋
# 禾家酸菜白肉鍋
# 元手壽司(台中漢口店)
# 元手壽司(台中漢口店)
# 傳螃蟹薑母鴨(旗艦店)
# 傳螃蟹薑母鴨(旗艦店)
# 李媽媽手工泡菜
# 李媽媽手工泡菜
# 北港香菇赤肉焿 六味香店
# 北港香菇赤肉焿 六味香店
# 北港香菇赤肉焿
# 北港香菇赤肉焿
# Gayo Cafe'
# Gayo Cafe'
# 日安朝食
# 日安朝食
# FUN Tower 日式可麗餅
# FUN Tower 日式可麗餅
# 明日咖啡店
# 明日咖啡店
# 小家文創咖啡Home Cafe
# 小家文創咖啡Home Cafe
# 老先覺麻辣窯燒鍋(台中東興店)
# 老先覺麻辣窯燒鍋(台中東興店)
# 北成香腸伯
# 北成香腸伯
# 鱻仔店
# 鱻仔店
# 舞月雪
# 舞月雪
# 麵堂拉麵專賣店
# 麵堂拉麵專賣店
# 粽點阿忠
# 粽點阿忠
# 芸料理食堂
# 芸料理食堂
# 鋤頭伯果園
# 鋤頭伯果園
# 樂烘焙手作甜點 Love Baking Hand Made
# 樂烘焙手作甜點 Love Baking Hand Made
# 庫克山上的阿卡
# 庫克山上的阿卡
# 太郎自產自銷荔枝芒果
# 太郎自產自銷荔枝芒果
# 胡家醬爆車輪餅
# 胡家醬爆車輪餅
# Lin氏素王
# Lin氏素王
# 毒家冰窖
# 毒家冰窖
# 浪花屋
# 浪花屋
# 三佰斤連鎖茶飲(松山民生店)
# 三佰斤連鎖茶飲(松山民生店)
# 東東芋圓(市府店)
# 東東芋圓(市府店)
# 閱築藝文咖啡廳
# 閱築藝文咖啡廳
# 本仕
# 本仕
# 飛去澳洲Brekkie 早午餐
# 飛去澳洲Brekkie 早午餐
# 恆鼎食品
# 恆鼎食品
# Smith酒藏
# Smith酒藏
# 初米咖啡 Choose me Cafe&Meals(錦州店)
# 初米咖啡 Choose me Cafe&Meals(錦州店)
# 唯鮮水晶石板燒肉(台北復興店)
# 唯鮮水晶石板燒肉(台北復興店)
# 聚北海道昆布鍋(桃園台茂中心)
# 聚北海道昆布鍋(桃園台茂中心)
# 開燈咖啡 Dawn Surf
# 開燈咖啡 Dawn Surf
# 玉琦日本料理(原：走走咖啡 Walking Cafe)
# 玉琦日本料理(原：走走咖啡 Walking Cafe)
# 趣品茶
# 趣品茶
# 麥味登 Cafe&Brunch(楠梓土庫二店)
# 麥味登 Cafe&Brunch(楠梓土庫二店)
# 哥倫布咖啡
# 哥倫布咖啡
# BBS早午餐專門店 bake&butter sandwich
# BBS早午餐專門店 bake&butter sandwich
# 艋舺阿義麵線
# 艋舺阿義麵線
# Red Fox 紅狐狸 台灣烏龍麵專賣店(原：沙場老醬趙子龍烏龍麵)
# Red Fox 紅狐狸 台灣烏龍麵專賣店(原：沙場老醬趙子龍烏龍麵)
# Petit Cakes and Café 貝帝烘焙店
# Petit Cakes and Café 貝帝烘焙店
# 三代喜日式自助食堂
# 三代喜日式自助食堂
# 大埔大腸香腸
# 大埔大腸香腸
# 米稼日本咖喱飯
# 米稼日本咖喱飯
# 名屋蒟蒻燕麥綠豆湯
# 名屋蒟蒻燕麥綠豆湯
# 窯烤披薩
# 窯烤披薩
# 天府宮前土魠魚羹
# 天府宮前土魠魚羹
# 車酷汽車主題餐廳
# 車酷汽車主題餐廳
# 樂禾田
# 樂禾田
# 鄭家孔雀蛤
# 鄭家孔雀蛤
# 吳氏養生飲
# 吳氏養生飲
# SKY 觀景西餐
# SKY 觀景西餐
# 鈊砌潗手調茶
# 鈊砌潗手調茶
# 金格彌月蛋糕-長崎本鋪
# 金格彌月蛋糕-長崎本鋪
# 馬克斯Marcus(士林店)
# 馬克斯Marcus(士林店)
# 幸福這裡 Happiness Here(新莊中港店)
# 幸福這裡 Happiness Here(新莊中港店)
# 哥在賣牛排
# 哥在賣牛排
# 清香燉露專賣店
# 清香燉露專賣店
# 紳士帽英式主題餐廳
# 紳士帽英式主題餐廳
# 爭鮮迴轉壽司 SUSHI EXPRESS(台南高鐵店)
# 爭鮮迴轉壽司 SUSHI EXPRESS(台南高鐵店)
# 炭樵日式串燒居酒屋(二店)
# 炭樵日式串燒居酒屋(二店)
# 伊莎貝爾月餅
# 伊莎貝爾月餅
# 侯家滷味鹽水鴨
# 侯家滷味鹽水鴨
# 勝昌蔬食
# 勝昌蔬食
# 和風飯糰本舖
# 和風飯糰本舖
# 野貓中途咖啡
# 野貓中途咖啡
# 草山食府
# 草山食府
# 微淇甜蜜屋- Weichi Sweets 板橋
# 微淇甜蜜屋- Weichi Sweets 板橋
# 大滷桶(花蓮店)
# 大滷桶(花蓮店)
# 靴子咖啡 Share's Cafe
# 靴子咖啡 Share's Cafe
# 梁家麵館
# 梁家麵館
# 奮發泰式料理
# 奮發泰式料理
# 越廚
# 越廚
# 上海邵師傅湯包店
# 上海邵師傅湯包店
# 正港芋圓
# 正港芋圓
# 大社今井拉麵
# 大社今井拉麵
# 阿義的腿庫飯
# 阿義的腿庫飯
# Buger&Co
# Buger&Co
# 夢想樹咖啡館 Dream Tree Cafe
# 夢想樹咖啡館 Dream Tree Cafe
# 樸食山坊
# 樸食山坊
# 輕醒咖啡。AWAKEN CAFE
# 輕醒咖啡。AWAKEN CAFE
# 茗時序茶飲(西門店)
# 茗時序茶飲(西門店)
# 火焰山
# 火焰山
# 憶香許烘焙工坊
# 憶香許烘焙工坊
# 三福路邊小吃店
# 三福路邊小吃店
# BEAST Bar & Grill 野獸美式餐廳
# BEAST Bar & Grill 野獸美式餐廳
# Morning MAN
# Morning MAN
# 原味海產粥 生魚片丼飯
# 原味海產粥 生魚片丼飯
# 牛角棒
# 牛角棒
# 淞葳日式料理
# 淞葳日式料理
# 饗泰多 Siam More  泰式風格餐廳(桃園店)
# 饗泰多 Siam More  泰式風格餐廳(桃園店)
# 茶壺蝦炭烤海鮮
# 茶壺蝦炭烤海鮮
# WAKE n' BAKE
# WAKE n' BAKE
# 我們的大邱咖啡館
# 我們的大邱咖啡館
# 三峽阿萬師黑珍珠飯糰
# 三峽阿萬師黑珍珠飯糰
# 喬伊 咖啡簡餐 Miss Joy Cafe
# 喬伊 咖啡簡餐 Miss Joy Cafe
# 鬍子叔叔義式廚房(府中店)
# 鬍子叔叔義式廚房(府中店)
# 逢甲埔里春捲潤餅割包
# 逢甲埔里春捲潤餅割包
# 信維市場米粉湯
# 信維市場米粉湯
# 花月嵐拉麵(新店家樂福店)
# 花月嵐拉麵(新店家樂福店)
# 天生牌金門高粱佐醃豬肉/香腸
# 天生牌金門高粱佐醃豬肉/香腸
# 彩虹屋手工蛋捲
# 彩虹屋手工蛋捲
# 順口麵食館
# 順口麵食館
# 瓦法奇朵Waffogato(忠孝松菸店)
# 瓦法奇朵Waffogato(忠孝松菸店)
# Místo Caf'e
# Místo Caf'e
# 禾記嫩骨飯(善化店)
# 禾記嫩骨飯(善化店)
# 海豐亭(海豐亭（台南 府前店）)
# 海豐亭(海豐亭（台南 府前店）)
# 伍師傅車輪餅
# 伍師傅車輪餅
# 香之味烤鴨
# 香之味烤鴨
# 艾思頓 Ice Cotton((彰化店）)
# 艾思頓 Ice Cotton((彰化店）)
# Casa Picasso
# Casa Picasso
# 隨心沖咖啡
# 隨心沖咖啡
# Coffee+ 咖啡家(彰化辭修店)
# Coffee+ 咖啡家(彰化辭修店)
# 235巷Pasta(站前店)
# 235巷Pasta(站前店)
# 十七街 鵝肉海產 日本料理
# 十七街 鵝肉海產 日本料理
# Texas Roadhouse
# Texas Roadhouse
# 味千館鍋物定食
# 味千館鍋物定食
# 三風麵館
# 三風麵館
# 鴻金食堂
# 鴻金食堂
# 早餐優選(永和安樂店)
# 早餐優選(永和安樂店)
# 開 心魚舖
# 開 心魚舖
# Gasann#19
# Gasann#19
# 紀どり燒鳥居酒屋
# 紀どり燒鳥居酒屋
# 世田谷拉麵(站前店)
# 世田谷拉麵(站前店)
# 筑亭燒き鳥Bar居酒屋
# 筑亭燒き鳥Bar居酒屋
# Venture&Caff'e
# Venture&Caff'e
# B cuisine studio 相信私廚
# B cuisine studio 相信私廚
# 九九炸烤
# 九九炸烤
# 竹村庭園茶藝
# 竹村庭園茶藝
# 朱記餡餅粥店(中信南港店)
# 朱記餡餅粥店(中信南港店)
# 咖哩高潮Curry Orgasmo
# 咖哩高潮Curry Orgasmo
# 真川味牛肉麵
# 真川味牛肉麵
# 芋頭師傅
# 芋頭師傅
# 艾斯机膜 ESGM cafe'3.0(羅東店)
# 艾斯机膜 ESGM cafe'3.0(羅東店)
# 棲すむ
# 棲すむ
# 鏟子義大利廚房
# 鏟子義大利廚房
# HOKA 日式家庭餐廳
# HOKA 日式家庭餐廳
# 鑫康黑蒜醋
# 鑫康黑蒜醋
# 傳統手工阿婆粉圓
# 傳統手工阿婆粉圓
# 老厝1933 燒烤
# 老厝1933 燒烤
# 松滿緣手作美食
# 松滿緣手作美食
# 1942餓棧廚房
# 1942餓棧廚房
# 康萃美活膠原蛋白粉
# 康萃美活膠原蛋白粉
# 黑呱呱炸雞
# 黑呱呱炸雞
# J&J cafe
# J&J cafe
# 蜀漢之都麻辣燙臭豆腐煲(鴨血臭豆腐煲大腸旺)
# 蜀漢之都麻辣燙臭豆腐煲(鴨血臭豆腐煲大腸旺)
# Jacobs雅柯氏 金帶皇冠咖啡研磨粉
# Jacobs雅柯氏 金帶皇冠咖啡研磨粉
# 大方香魚
# 大方香魚
# Dano's Pasta Wine
# Dano's Pasta Wine
# 神秘豆塔
# 神秘豆塔
# 津味小館
# 津味小館
# 傳遞幸福手作坊
# 傳遞幸福手作坊
# 波米咖啡pomme
# 波米咖啡pomme
# Japoli義大利餐酒館(忠孝店)
# Japoli義大利餐酒館(忠孝店)
# 吃麵吧Jai Mi Ba
# 吃麵吧Jai Mi Ba
# 浙江俞記
# 浙江俞記
# 劉漣麵
# 劉漣麵
# Love Toast i 吐司
# Love Toast i 吐司
# 峇里村印尼料理
# 峇里村印尼料理
# 勝麻辣牛肉拉麵(政大店)
# 勝麻辣牛肉拉麵(政大店)
# 果乾達人 Super Dryfruit
# 果乾達人 Super Dryfruit
# 山林香 泰國辛香小吃
# 山林香 泰國辛香小吃
# Love at First Bite Bakery Café
# Love at First Bite Bakery Café
# 五街客家美食
# 五街客家美食
# 豆腐35  TOFU thirty five(公益店)
# 豆腐35  TOFU thirty five(公益店)
# 悅來咖啡館
# 悅來咖啡館
# 第一味古早麵
# 第一味古早麵
# 7-11皮蛋瘦肉粥
# 7-11皮蛋瘦肉粥
# K-BOOM K棒韓式料理
# K-BOOM K棒韓式料理
# 美美客家麻糬(敦南店)
# 美美客家麻糬(敦南店)
# 肯德基/高雄大順二餐廳
# 肯德基/高雄大順二餐廳
# No.9 咖啡館
# No.9 咖啡館
# 丸童鍋物
# 丸童鍋物
# 須盡歡
# 須盡歡
# 海賊日式料理(桃園南平店)
# 海賊日式料理(桃園南平店)
# 甜洋蔥平價鐵板燒
# 甜洋蔥平價鐵板燒
# 楷將Q皮湯包
# 楷將Q皮湯包
# 翌食堂
# 翌食堂
# 臻皇港式餐廳
# 臻皇港式餐廳
# 珈琍琍職人烘焙
# 珈琍琍職人烘焙
# 異人館(清豐店)
# 異人館(清豐店)
# K's Cafe'(復興店)
# K's Cafe'(復興店)
# 原味堂天然養生包子饅頭
# 原味堂天然養生包子饅頭
# 棗子樹健康素食料理(經國店)
# 棗子樹健康素食料理(經國店)
# 不錯吃鹹酥雞
# 不錯吃鹹酥雞
# 犇牛園
# 犇牛園
# 野飼崎雞
# 野飼崎雞
# Miga Kitchen Pasta 米家廚房
# Miga Kitchen Pasta 米家廚房
# 方正谷地方菜
# 方正谷地方菜
# 幸福和食堂
# 幸福和食堂
# 清真昆明園(復興北路店)
# 清真昆明園(復興北路店)
# 寶島菠蘿團
# 寶島菠蘿團
# 水里羊肉王山產餐廳
# 水里羊肉王山產餐廳
# 松哥拉仔麵
# 松哥拉仔麵
# 中平路香菇肉粥
# 中平路香菇肉粥
# 饗壽司
# 饗壽司
# Leonana 藝廊咖啡
# Leonana 藝廊咖啡
# 鉄人麵倉
# 鉄人麵倉
# ISABELLE 伊莎貝爾(永和店)
# ISABELLE 伊莎貝爾(永和店)
# 老先覺麻辣窯燒鍋(基隆義二店)
# 老先覺麻辣窯燒鍋(基隆義二店)
# 樂。野食
# 樂。野食
# 標達生醫
# 標達生醫
# 周家手作 花生捲冰淇淋
# 周家手作 花生捲冰淇淋
# 馬可的店(屏東店)
# 馬可的店(屏東店)
# Pain Perdu 邦'咖啡館
# Pain Perdu 邦'咖啡館
# 來了
# 來了
# 68食堂
# 68食堂
# Hello!Jazz!
# Hello!Jazz!
# 歐嘉樂蝦餅
# 歐嘉樂蝦餅
# 卓家鵝肉
# 卓家鵝肉
# 1928燒肉總鋪
# 1928燒肉總鋪
# 東東粵菜小館
# 東東粵菜小館
# 金花子韓國料理 김화자 한식당
# 金花子韓國料理 김화자 한식당
# 佐竹日本料理
# 佐竹日本料理
# 瑪夏廚房 Marsha's kitchen Välkommen
# 瑪夏廚房 Marsha's kitchen Välkommen
# 蘇澳菜市場汽水甘蔗汁
# 蘇澳菜市場汽水甘蔗汁
# 亞都麗緻坊(微風松高)
# 亞都麗緻坊(微風松高)
# 全家--黑松香檳汽水
# 全家--黑松香檳汽水
# MilkShop 迷客夏 - 板橋店
# MilkShop 迷客夏 - 板橋店
# 合掌屋日式料理
# 合掌屋日式料理
# DoDidDone Coffee Research
# DoDidDone Coffee Research
# Sa Sa House烘焙點心
# Sa Sa House烘焙點心
# 橡木銅 restaurant&bar
# 橡木銅 restaurant&bar
# On the Road
# On the Road
# 正原味鹽水雞
# 正原味鹽水雞
# 禾家精緻鍋物
# 禾家精緻鍋物
# 西河堂炸物專賣店
# 西河堂炸物專賣店
# 樂口福手工烘焙
# 樂口福手工烘焙
# 瑪沙肉圓
# 瑪沙肉圓
# 可以醬
# 可以醬
# 森浦日式居酒屋
# 森浦日式居酒屋
# 黑殿飯店
# 黑殿飯店
# 五九香碳烤玉米
# 五九香碳烤玉米
# 酒巷一弄炭火串燒
# 酒巷一弄炭火串燒
# 溫野菜信義誠品店
# 溫野菜信義誠品店
# 拾陌 Shihmo
# 拾陌 Shihmo
# 雅米奇
# 雅米奇
# 哦咿禧
# 哦咿禧
# 安平劍獅假日夜市
# 安平劍獅假日夜市
# 友間食堂有機自然涮涮鍋(yuan :友間食堂天然生機)
# 友間食堂有機自然涮涮鍋(yuan :友間食堂天然生機)
# 極品鹽水雞
# 極品鹽水雞
# 遠洋深海花枝燒
# 遠洋深海花枝燒
# 芙力糖紅茶
# 芙力糖紅茶
# 秋玉滷味
# 秋玉滷味
# 阿官火鍋專家(天母新光三越)
# 阿官火鍋專家(天母新光三越)
# 晨間廚房西式早午餐(頭份永和店)
# 晨間廚房西式早午餐(頭份永和店)
# 宜蘭調查站紅豆餅
# 宜蘭調查站紅豆餅
# 黑色磨菇
# 黑色磨菇
# 光東養茶
# 光東養茶
# 赫氏韓味食坊
# 赫氏韓味食坊
# 加賀日式涮涮鍋
# 加賀日式涮涮鍋
# 菲林咖啡
# 菲林咖啡
# apple 203(彰化華山店)
# apple 203(彰化華山店)
# 營養師輕食
# 營養師輕食
# 亞芳茶坊
# 亞芳茶坊
# 少爺冰
# 少爺冰
# Osaka 日式炭火燒肉、壽司、吟釀料理
# Osaka 日式炭火燒肉、壽司、吟釀料理
# 23度半鳳梨。福爾摩沙的熱帶金鑽
# 23度半鳳梨。福爾摩沙的熱帶金鑽
# MORE WORLD
# MORE WORLD
# 韓媽咪滴雞精
# 韓媽咪滴雞精
# 惡燒肉便當專賣店
# 惡燒肉便當專賣店
# 鳳山無名蛋餅飯
# 鳳山無名蛋餅飯
# 哲食創意甜點工作室
# 哲食創意甜點工作室
# 家食堂(南昌路)
# 家食堂(南昌路)
# 雞肉亮黑白切
# 雞肉亮黑白切
# 阿浚師魯麵
# 阿浚師魯麵
# 飯湯肉粿
# 飯湯肉粿
# 阿潘肉包
# 阿潘肉包
# 焱麻堂
# 焱麻堂
# 鮮霸王海產城
# 鮮霸王海產城
# 布萊恩紅茶(十全店)
# 布萊恩紅茶(十全店)
# 葉妹妹乳酪蛋糕
# 葉妹妹乳酪蛋糕
# POP JUICE juice & fruit bar
# POP JUICE juice & fruit bar
# 典藏家咖啡館
# 典藏家咖啡館
# 小不點複合茶飲海苔飯捲(竹北店)
# 小不點複合茶飲海苔飯捲(竹北店)
# The X. dessert
# The X. dessert
# 阿平咖啡館
# 阿平咖啡館
# 英國紅 茶館
# 英國紅 茶館
# 食記居酒屋
# 食記居酒屋
# 4C caf'e 冰釀達人
# 4C caf'e 冰釀達人
# 頭城蚵仔煎
# 頭城蚵仔煎
# 親元滴雞精
# 親元滴雞精
# 心程咖啡
# 心程咖啡
# 香格里拉台北遠東國際大飯店-怡東園
# 香格里拉台北遠東國際大飯店-怡東園
# 香師傅
# 香師傅
# YOKU MOKU 原味蛋捲
# YOKU MOKU 原味蛋捲
# 嘉義李雞肉飯
# 嘉義李雞肉飯
# 2 Daydreams 白日夢巧克力飲品
# 2 Daydreams 白日夢巧克力飲品
# 白色方塊咖啡
# 白色方塊咖啡
# Myron cafe
# Myron cafe
# 先麥收涎餅
# 先麥收涎餅
# 爭纖健康涮涮鍋
# 爭纖健康涮涮鍋
# 本東手作弁当
# 本東手作弁当
# 隨便CHIN TSAI
# 隨便CHIN TSAI
# 蒸鍋蒸煮健康鍋
# 蒸鍋蒸煮健康鍋
# 蒂兒Deer
# 蒂兒Deer
# Mr.Garden
# Mr.Garden
# Rabbito
# Rabbito
# 大門咖啡BIG DOOR COFFEE
# 大門咖啡BIG DOOR COFFEE
# FM PASTA
# FM PASTA
# 快樂地水果吧 Happy Inn Juice Bar(信義A11店)
# 快樂地水果吧 Happy Inn Juice Bar(信義A11店)
# 豐山蔥油餅
# 豐山蔥油餅
# KIRIN一番搾(統一阪急百貨)
# KIRIN一番搾(統一阪急百貨)
# 歌麿日本料理
# 歌麿日本料理
# 鴻智茶莊
# 鴻智茶莊
# 愷洋地寶天食 紫御地瓜花式刀削麵+養生意麵+香菇香椿醬~
# 愷洋地寶天食 紫御地瓜花式刀削麵+養生意麵+香菇香椿醬~
# Dig Angel  迪克天使
# Dig Angel  迪克天使
# 鳳姊小館
# 鳳姊小館
# 古哥咖啡烘焙坊
# 古哥咖啡烘焙坊
# 上海素食食尚館
# 上海素食食尚館
# 拉麵吧 Raman Bar
# 拉麵吧 Raman Bar
# 三國饌鴛鴦麻辣鍋(虎尾店)
# 三國饌鴛鴦麻辣鍋(虎尾店)
# 海竹臺灣味料理
# 海竹臺灣味料理
# 禾麥烘培麵包 (文二店)
# 禾麥烘培麵包 (文二店)
# Carol's Gelato
# Carol's Gelato
# 原燒優質原味燒肉(板橋館前東店)
# 原燒優質原味燒肉(板橋館前東店)
# 十八辣紅油抄手
# 十八辣紅油抄手
# 高師傅海鮮麵高原烏龍麵
# 高師傅海鮮麵高原烏龍麵
# 誠記蝦仁羹
# 誠記蝦仁羹
# 三顧茅廬麻辣滷味(板橋仁化旗艦店)
# 三顧茅廬麻辣滷味(板橋仁化旗艦店)
# 來來鴨肉
# 來來鴨肉
# 竹香園甕仔雞
# 竹香園甕仔雞
# 香草工坊(光華家樂福店)
# 香草工坊(光華家樂福店)
# 沁采現代生活餐飲
# 沁采現代生活餐飲
# 林口媽媽家義式餐廳 Mom Cafe
# 林口媽媽家義式餐廳 Mom Cafe
# 貓星柒咖啡
# 貓星柒咖啡
# 品田牧場(台北家樂福重慶店)
# 品田牧場(台北家樂福重慶店)
# 福記香滷鴨肉飯
# 福記香滷鴨肉飯
# 羅絲朵晴天(站前店)
# 羅絲朵晴天(站前店)
# Lucas的店
# Lucas的店
# 緹克廚房
# 緹克廚房
# 鮪魚王
# 鮪魚王
# 閣樓上的烤布蕾
# 閣樓上的烤布蕾
# 阿信水餃牛肉麵
# 阿信水餃牛肉麵
# 峰古早味傳統美食
# 峰古早味傳統美食
# 幸運草素包坊
# 幸運草素包坊
# 好角子may ga 料理廚房
# 好角子may ga 料理廚房
# 世唯烘培坊(斗六店)
# 世唯烘培坊(斗六店)
# 美人秀秀檸檬水
# 美人秀秀檸檬水
# 鶴茶 ho tea
# 鶴茶 ho tea
# The Artful Dodge 亞芙
# The Artful Dodge 亞芙
# 南門市場
# 南門市場
# 018咖啡甜品玩國
# 018咖啡甜品玩國
# 雅朵午后飲
# 雅朵午后飲
# 一點甜豆塔喜餅
# 一點甜豆塔喜餅
# 大呼過癮臭臭鍋(台南新營店)
# 大呼過癮臭臭鍋(台南新營店)
# 三禾手打烏龍麵(太平店)
# 三禾手打烏龍麵(太平店)
# 悠茗仙草、冷凍芋、芋圓
# 悠茗仙草、冷凍芋、芋圓
# 鬍鬚林滷味雞腳凍
# 鬍鬚林滷味雞腳凍
# 紐約牛排
# 紐約牛排
# 武當家魷魚王(蘆洲加盟店)
# 武當家魷魚王(蘆洲加盟店)
# 王者之蚵
# 王者之蚵
# 王功台生蚵仔煎
# 王功台生蚵仔煎
# 普羅旺斯玫瑰莊園
# 普羅旺斯玫瑰莊園
# 野菜園素食館
# 野菜園素食館
# 凱洛黃金多藻
# 凱洛黃金多藻
# 亮點咖啡
# 亮點咖啡
# NICE GREEN美蔬菜廚房(BELLAVITA)
# NICE GREEN美蔬菜廚房(BELLAVITA)
# 雅閣
# 雅閣
# 寶德里洋樓
# 寶德里洋樓
# classmate義大利麵
# classmate義大利麵
# 春囍冰品
# 春囍冰品
# 尚享
# 尚享
# 查理布朗烘培：流淚芋泥捲
# 查理布朗烘培：流淚芋泥捲
# 曼舒清雅咖啡會舘
# 曼舒清雅咖啡會舘
# 丹提早午餐
# 丹提早午餐
# 坂元麵疙瘩
# 坂元麵疙瘩
# 紙盒子桌遊休閒館
# 紙盒子桌遊休閒館
# 阿部仔烘焙坊(阿部烘焙坊中山店)
# 阿部仔烘焙坊(阿部烘焙坊中山店)
# 弘記豆漿店
# 弘記豆漿店
# 帝薇莎頂級稀有精品咖啡
# 帝薇莎頂級稀有精品咖啡
# 鯨吞燒-精肉食堂(海安店)
# 鯨吞燒-精肉食堂(海安店)
# 樂凡手感烘培麵包
# 樂凡手感烘培麵包
# 哈克大師菓子工坊
# 哈克大師菓子工坊
# 釧路日本海鮮餐廳
# 釧路日本海鮮餐廳
# 夾子園熱壓吐司輕食
# 夾子園熱壓吐司輕食
# 新華園港式燒臘
# 新華園港式燒臘
# 鈺鮮創意日式料理
# 鈺鮮創意日式料理
# 芬園手工包子饅頭
# 芬園手工包子饅頭
# 東門茶樓
# 東門茶樓
# 蝦博士
# 蝦博士
# RYNO GELATO 里諾工房義式冰淇淋專門店
# RYNO GELATO 里諾工房義式冰淇淋專門店
# 台中一碗拉麵
# 台中一碗拉麵
# 人之初手作咖啡
# 人之初手作咖啡
# 松菓-橡實堤岸
# 松菓-橡實堤岸
# KIRIN ICHIBAN GARDEN台北阪急店
# KIRIN ICHIBAN GARDEN台北阪急店
# 金湖大飯店湖光餐廳
# 金湖大飯店湖光餐廳
# 過嶺早點
# 過嶺早點
# 雲林虎尾Viola薇若拉 親子音樂餐廳
# 雲林虎尾Viola薇若拉 親子音樂餐廳
# 美鳳油飯
# 美鳳油飯
# 泰和源芋仔冰
# 泰和源芋仔冰
# 信德股份有限公司
# 信德股份有限公司
# 豆之味有機嫰豆花
# 豆之味有機嫰豆花
# 皇家傳承牛肉麵(重慶店)
# 皇家傳承牛肉麵(重慶店)
# 後港碳烤排
# 後港碳烤排
# 哈樂事美食
# 哈樂事美食
# 銅盤嚴選韓式烤肉
# 銅盤嚴選韓式烤肉
# 角屋
# 角屋
# 拖車甜點
# 拖車甜點
# 鏢準食間
# 鏢準食間
# 瑞發藥膳排骨
# 瑞發藥膳排骨
# 雙木林壹號店
# 雙木林壹號店
# 龍鮨处 職人すし 日本料理
# 龍鮨处 職人すし 日本料理
# 陳記甕缸雞
# 陳記甕缸雞
# 梅乃之小棧
# 梅乃之小棧
# 美濃妙香粄條
# 美濃妙香粄條
# 天香樓(Sogo忠孝店)
# 天香樓(Sogo忠孝店)
# 小晴空
# 小晴空
# TASTy 西堤牛排
# TASTy 西堤牛排
# 目目 MùMù 咖啡廳
# 目目 MùMù 咖啡廳
# 樵驛KTV啤酒屋 燒烤
# 樵驛KTV啤酒屋 燒烤
# 後龍廟口-蒸餃
# 後龍廟口-蒸餃
# 後龍慈雲宮-臭豆腐
# 後龍慈雲宮-臭豆腐
# 小南便當(小南老蘇鼎中店)
# 小南便當(小南老蘇鼎中店)
# 悅喀手工甜點
# 悅喀手工甜點
# 亞緹義廚(板橋文化店)
# 亞緹義廚(板橋文化店)
# 笑福庵
# 笑福庵
# 酸豆義式小館
# 酸豆義式小館
# 鐵板MAN
# 鐵板MAN
# 老虎醬溫州大餛飩(南京東路四段)
# 老虎醬溫州大餛飩(南京東路四段)
# 京盛宇
# 京盛宇
# Pontus-限量手作甜點
# Pontus-限量手作甜點
# Curry+ Kitchen 誠欣廚房
# Curry+ Kitchen 誠欣廚房
# 可愛家便當店
# 可愛家便當店
# 阿尼雞無骨鹹酥雞
# 阿尼雞無骨鹹酥雞
# 吳家芝麻粉.白芝麻醬,黑麻醬.黑芝麻油
# 吳家芝麻粉.白芝麻醬,黑麻醬.黑芝麻油
# 丸龜製麵
# 丸龜製麵
# 穗馨花生酥
# 穗馨花生酥
# 四季糖sweetseason港式甜品
# 四季糖sweetseason港式甜品
# 如意坊海鮮干貝醬
# 如意坊海鮮干貝醬
# 菜鳥居酒屋 ルーキー
# 菜鳥居酒屋 ルーキー
# 蘭英坊
# 蘭英坊
# 小圓圓
# 小圓圓
# 清湘小館
# 清湘小館
# 販奇網
# 販奇網
# 美心茶藝行
# 美心茶藝行
# 仙草鮮贏竹炭仙草茶
# 仙草鮮贏竹炭仙草茶
# 紫金堂八味芝麻糕
# 紫金堂八味芝麻糕
# 縣爺mini
# 縣爺mini
# 旺旺快餐
# 旺旺快餐
# JusCleanse
# JusCleanse
# Bula冷奶油咖椰吐司
# Bula冷奶油咖椰吐司
# LeJoyau樂珈歐
# LeJoyau樂珈歐
# Supercut塑魔纖代謝膠囊
# Supercut塑魔纖代謝膠囊
# 輕點嚐沁心薄荷糖
# 輕點嚐沁心薄荷糖
# 阿基伯燒冷冰
# 阿基伯燒冷冰
# 林媽媽黑白切
# 林媽媽黑白切
# BONJOUR帕里尼 輕食
# BONJOUR帕里尼 輕食
# 千翔創意鐵板料理
# 千翔創意鐵板料理
# 來樂 活力美雞精
# 來樂 活力美雞精
# 即嗑饗樂食舖
# 即嗑饗樂食舖
# 黃金牛牛肉麵
# 黃金牛牛肉麵
# Black Sugar 黑糖先生 原味黑糖冰
# Black Sugar 黑糖先生 原味黑糖冰
# VILLA LOHERB 樂健活日光綠築
# VILLA LOHERB 樂健活日光綠築
# 香蔥車輪餅
# 香蔥車輪餅
# 亨蕾咖啡HolyCafe
# 亨蕾咖啡HolyCafe
# 巴克斯BARKIS飲料調酒
# 巴克斯BARKIS飲料調酒
# 高野家愛寶諾滴雞精(烏骨雞)
# 高野家愛寶諾滴雞精(烏骨雞)
# 93複合式餐廳
# 93複合式餐廳
# 滿意堂
# 滿意堂
# 藏甜手作廚房
# 藏甜手作廚房
# 無名粉圓冰
# 無名粉圓冰
# Hello Kitty 人形燒
# Hello Kitty 人形燒
# 峰田小町
# 峰田小町
# 錦城石頭火鍋
# 錦城石頭火鍋
# 雪涼冰品
# 雪涼冰品
# U-Day健康手作優格
# U-Day健康手作優格
# 泡麵王國(新北市總店)
# 泡麵王國(新北市總店)
# 超越原味炭烤牛排
# 超越原味炭烤牛排
# 黃金營養三明治
# 黃金營養三明治
# 植物奶機
# 植物奶機
# 萬代福快餐
# 萬代福快餐
# NU PASTA(新店中正店)
# NU PASTA(新店中正店)
# 恆春素食麵
# 恆春素食麵
# 禾宴海魚
# 禾宴海魚
# 甜絲姬Chenski Sweets乳酪蛋糕＆手作甜點
# 甜絲姬Chenski Sweets乳酪蛋糕＆手作甜點
# Ten Ba Ba鐵板燒料理
# Ten Ba Ba鐵板燒料理
# 翁記滷肉飯(城隍廟正戲台下方)
# 翁記滷肉飯(城隍廟正戲台下方)
# 大埔肉燥粿
# 大埔肉燥粿
# 小斗笠彈牙米
# 小斗笠彈牙米
# Nook餐桌
# Nook餐桌
# 品安豆花(家樂福夜市店)
# 品安豆花(家樂福夜市店)
# 寬心園精緻蔬食
# 寬心園精緻蔬食
# 众 餐酒館
# 众 餐酒館
# 起士公爵
# 起士公爵
# 五花馬水餃館(淡水中山北店)
# 五花馬水餃館(淡水中山北店)
# 古早味早點
# 古早味早點
# KUKO比利時鬆餅(4號店)
# KUKO比利時鬆餅(4號店)
# 桂田酒店櫻桃鴨
# 桂田酒店櫻桃鴨
# Hello Kitty Shabu Shabu
# Hello Kitty Shabu Shabu
# 大龍棧餐飲
# 大龍棧餐飲
# 客臨廣東粥(民生店)
# 客臨廣東粥(民生店)
# NISORO熱量調控餐
# NISORO熱量調控餐
# 古早黑砂糖剉冰
# 古早黑砂糖剉冰
# 周小福鐵路便當
# 周小福鐵路便當
# 靜岡勝政日式豬排(天母sogo店)
# 靜岡勝政日式豬排(天母sogo店)
# 好客音樂燒烤(市府店)
# 好客音樂燒烤(市府店)
# 麥當勞(南京五店)
# 麥當勞(南京五店)
# 欣來便當自助餐
# 欣來便當自助餐
# HOT手工窯烤披薩
# HOT手工窯烤披薩
# 吉鋒愛玉檸檬
# 吉鋒愛玉檸檬
# 米鳳梨酥
# 米鳳梨酥
# JouJouX Cafe玩具咖啡
# JouJouX Cafe玩具咖啡
# 山水便當
# 山水便當
# 太陽蕃茄麵
# 太陽蕃茄麵
# 東呷牛肉麵((板橋二店))
# 東呷牛肉麵((板橋二店))
# 愛蜜手作烘焙坊 amier doux
# 愛蜜手作烘焙坊 amier doux
# Chia's Time奇亞籽
# Chia's Time奇亞籽
# 鳥苑地雞燒 Yakitori&wine
# 鳥苑地雞燒 Yakitori&wine
# 鼎吉大腸蚵仔麵線
# 鼎吉大腸蚵仔麵線
# 美崙海鮮
# 美崙海鮮
# 食驛
# 食驛
# Light House 燈塔美式酒館
# Light House 燈塔美式酒館
# 宜蘭178早午餐民宿
# 宜蘭178早午餐民宿
# 台北寒舍艾美酒店北緯25
# 台北寒舍艾美酒店北緯25
# 泰閣 tiger.house
# 泰閣 tiger.house
# 享日子日式餐館
# 享日子日式餐館
# 8分之1無煙串燒
# 8分之1無煙串燒
# ＴＯＰ王子洋公館
# ＴＯＰ王子洋公館
# 安樂市場口台灣第一家鹽酥雞
# 安樂市場口台灣第一家鹽酥雞
# 極香BBQ
# 極香BBQ
# DLC 現烘咖啡
# DLC 現烘咖啡
# 歐鄉牛排館(花蓮中正店)
# 歐鄉牛排館(花蓮中正店)
# 五甲麻油腰子
# 五甲麻油腰子
# 哈古小館 au petit cochon
# 哈古小館 au petit cochon
# 好好 good days(友愛店)
# 好好 good days(友愛店)
# Fun-s 芳茲生技Chia's Time 奇亞籽
# Fun-s 芳茲生技Chia's Time 奇亞籽
# 瓦法奇朵Waffogato(敦南店)
# 瓦法奇朵Waffogato(敦南店)
# 長春健康素食(開元店)
# 長春健康素食(開元店)
# 光和鹽平價義大利麵專賣 Light&Salt Pasta
# 光和鹽平價義大利麵專賣 Light&Salt Pasta
# 橙果園果汁茶品專門店
# 橙果園果汁茶品專門店
# 源味本鋪-古早味現烤蛋糕(淡水站前店)
# 源味本鋪-古早味現烤蛋糕(淡水站前店)
# 達揚農場 巨峰葡萄
# 達揚農場 巨峰葡萄
# 愛披薩 ipizza
# 愛披薩 ipizza
# 瞞著爹(內湖店)
# 瞞著爹(內湖店)
# ISABELLE 伊莎貝爾(台北士林門市)
# ISABELLE 伊莎貝爾(台北士林門市)
# Stable Fly 穩定飛行
# Stable Fly 穩定飛行
# 統一陽光低糖豆漿
# 統一陽光低糖豆漿
# 弘大炸雞
# 弘大炸雞
# 阿秀小吃部牛肉麵
# 阿秀小吃部牛肉麵
# 宅配美食 東港氛饗鮮食網
# 宅配美食 東港氛饗鮮食網
# 鴻富麵食館
# 鴻富麵食館
# 虎町(東海店)
# 虎町(東海店)
# 爭鮮迴轉壽司 SUSHI EXPRESS(淡新店)
# 爭鮮迴轉壽司 SUSHI EXPRESS(淡新店)
# 台北阿郎鹹酥雞(德惠分店)
# 台北阿郎鹹酥雞(德惠分店)
# 壹鼎
# 壹鼎
# 喜喜多多
# 喜喜多多
# 肥仔港式茶餐廳
# 肥仔港式茶餐廳
# 鴻達臭豆腐
# 鴻達臭豆腐
# 美人秀秀新一代檸檬水
# 美人秀秀新一代檸檬水
# 利昌食品行
# 利昌食品行
# 歐可茶葉科技有限公司
# 歐可茶葉科技有限公司
# 橙館
# 橙館
# 可可莉可 歐式小餐館
# 可可莉可 歐式小餐館
# 私家手作廚房
# 私家手作廚房
# Kocano可卡諾鬆餅
# Kocano可卡諾鬆餅
# 餘味
# 餘味
# 爭鮮外帶 SUSHI TAKE - OUT(淡水店)
# 爭鮮外帶 SUSHI TAKE - OUT(淡水店)
# 富盛號
# 富盛號
# 龍師父黃金泡菜坊
# 龍師父黃金泡菜坊
# 尚品坊素食
# 尚品坊素食
# 燻雞總匯握沙拉
# 燻雞總匯握沙拉
# 夢東籬(永華店)
# 夢東籬(永華店)
# 港邊小屋現烤生蠔(梧棲店)
# 港邊小屋現烤生蠔(梧棲店)
# 桶好口甲(永和分店)
# 桶好口甲(永和分店)
# 海益行
# 海益行
# BREAD MEAT & SWEET
# BREAD MEAT & SWEET
# Peach&Plum桃李手作烘焙
# Peach&Plum桃李手作烘焙
# 法布甜 法式伴手禮專賣店(中友店)
# 法布甜 法式伴手禮專賣店(中友店)
# 小綿羊藥膳的鍋(健康店)
# 小綿羊藥膳的鍋(健康店)
# 屋台拉麵
# 屋台拉麵
# 麥當勞(鶯歌鶯桃店)
# 麥當勞(鶯歌鶯桃店)
# SUNDAY
# SUNDAY
# 恆香小廚
# 恆香小廚
# 桶好呷(永和仁愛店)
# 桶好呷(永和仁愛店)
# 萬豐醬油
# 萬豐醬油
# 鮮丼食事處
# 鮮丼食事處
# 東海紅豆餅
# 東海紅豆餅
# 真味饌
# 真味饌
# 一魂拉麵
# 一魂拉麵
# 弗卡夏手工披薩屋
# 弗卡夏手工披薩屋
# 麵公子
# 麵公子
# 逐鹿御膳房
# 逐鹿御膳房
# 逗點燒烤
# 逗點燒烤
# 蜜蜂工坊
# 蜜蜂工坊
# 西馬拉雅印度餐廳
# 西馬拉雅印度餐廳
# 逢甲番薯哥
# 逢甲番薯哥
# 紅門大腸麵線
# 紅門大腸麵線
# 越蘭香
# 越蘭香
# 靖咖啡 Jing Coffee
# 靖咖啡 Jing Coffee
# 黑白切
# 黑白切
# 金捷發煎盤粿
# 金捷發煎盤粿
# 檸檬果廚房
# 檸檬果廚房
# 藍象廷泰式火鍋
# 藍象廷泰式火鍋
# 六甲國中前黑輪伯
# 六甲國中前黑輪伯
# 酒肉German Garden德國花園手工啤酒專賣店
# 酒肉German Garden德國花園手工啤酒專賣店
# 安記食府
# 安記食府
# 阿水嫂自助刨冰
# 阿水嫂自助刨冰
# 那瑪卡西なまかし
# 那瑪卡西なまかし
# 味衛門日式手創料理
# 味衛門日式手創料理
# 蜜蜂來了
# 蜜蜂來了
# Miin妙音手工果醬
# Miin妙音手工果醬
# 原野牧場
# 原野牧場
# twotwotogo
# twotwotogo
# 品茶集 Pinchajii Tea House
# 品茶集 Pinchajii Tea House
# Five Ounces小富豪鐵板燒
# Five Ounces小富豪鐵板燒
# 黛安莊園Diane's Garden
# 黛安莊園Diane's Garden
# 鬆餅小姐の格子鬆餅
# 鬆餅小姐の格子鬆餅
# 明月豆腐店‬
# 明月豆腐店‬
# 老戴豆漿大王
# 老戴豆漿大王
# PrinXure x 與手工甜點對話的Susan聯名
# PrinXure x 與手工甜點對話的Susan聯名
# 十勝川鍋物(大里店二店)
# 十勝川鍋物(大里店二店)
# 財伯無煙串烤
# 財伯無煙串烤
# 小酒食堂 Shochu
# 小酒食堂 Shochu
# 伍零壹
# 伍零壹
# 老地方小籠包
# 老地方小籠包
# 菠蘿油王子mini茶餐廳(高雄中華店)
# 菠蘿油王子mini茶餐廳(高雄中華店)
# Picnic Fun 野餐趣
# Picnic Fun 野餐趣
# Murphy cafe
# Murphy cafe
# 下午3點的甜點
# 下午3點的甜點
# 茶本味
# 茶本味
# LOVE ONE樂昂咖啡信義誠品店
# LOVE ONE樂昂咖啡信義誠品店
# 火雞肉飯
# 火雞肉飯
# 香料屋餐廳
# 香料屋餐廳
# 全國寶
# 全國寶
# 小南人燒烤廚房
# 小南人燒烤廚房
# 古灶蝦捲
# 古灶蝦捲
# 熊先生魚舖
# 熊先生魚舖
# 300%BAR
# 300%BAR
# 貓頭鷹日式拉麵 フクロウ
# 貓頭鷹日式拉麵 フクロウ
# 名流水岸慢食藝術館
# 名流水岸慢食藝術館
# 即享咖啡 濾泡式 掛耳咖啡
# 即享咖啡 濾泡式 掛耳咖啡
# Love u u 樂悠悠
# Love u u 樂悠悠
# 野台獅
# 野台獅
# 餐廳日 RESTAURANT DAY
# 餐廳日 RESTAURANT DAY
# 司麥Smile
# 司麥Smile
# Burger Ray
# Burger Ray
# 青草茶
# 青草茶
# 花の漾早餐
# 花の漾早餐
# 勇原住民石板烤肉
# 勇原住民石板烤肉
# 仁隆咖啡館
# 仁隆咖啡館
# 新竹雞場鹽水雞城隍店
# 新竹雞場鹽水雞城隍店
# 亓家蒸餃專賣店
# 亓家蒸餃專賣店
# Baskin Robbins 31冰淇淋(大統和平店)
# Baskin Robbins 31冰淇淋(大統和平店)
# 波莉與喬治親子空間
# 波莉與喬治親子空間
# 魚海戀
# 魚海戀
# 海綸泰式小吃
# 海綸泰式小吃
# 阿成小吃店
# 阿成小吃店
# 蜜龍-紅龍蜜果
# 蜜龍-紅龍蜜果
# 關西仙草茶、燒仙草
# 關西仙草茶、燒仙草
# 朱朱豬腳
# 朱朱豬腳
# PALM PASTA 棕櫚樹義大利麵(信義店)
# PALM PASTA 棕櫚樹義大利麵(信義店)
# 許甜記
# 許甜記
# 佳味鮮食品
# 佳味鮮食品
# 上品芒果冰
# 上品芒果冰
# 礁溪大師兄雪花冰
# 礁溪大師兄雪花冰
# 好運土司商行(富國店)
# 好運土司商行(富國店)
# 竹地小舖(大連店)
# 竹地小舖(大連店)
# 迦南地 Canaan Café
# 迦南地 Canaan Café
# 東陽鵝肉
# 東陽鵝肉
# 茶本味(大甲鎮瀾店)
# 茶本味(大甲鎮瀾店)
# BBX DIETARY - 清暢馥纖錠+女神彈力帶
# BBX DIETARY - 清暢馥纖錠+女神彈力帶
# 三坑老街餐廳
# 三坑老街餐廳
# 源松客家餐廳(榕樹下)
# 源松客家餐廳(榕樹下)
# 雞舍鹹水雞(元：雞婆鹽水雞)
# 雞舍鹹水雞(元：雞婆鹽水雞)
# 一江橋飯糰
# 一江橋飯糰
# 漁來生魚片專賣店(內湖店)
# 漁來生魚片專賣店(內湖店)
# 找地方坐Have a Seat
# 找地方坐Have a Seat
# 飯島屋
# 飯島屋
# 北風蒸餃(環球購物中心-新左營店)
# 北風蒸餃(環球購物中心-新左營店)
# 台灣魯肉飯
# 台灣魯肉飯
# STOP新美食主義
# STOP新美食主義
# 老練牛肉麵
# 老練牛肉麵
# 賴阿婆芋園之家
# 賴阿婆芋園之家
# 春水堂人文茶館
# 春水堂人文茶館
# すき家 SUKIYA(站前店)
# すき家 SUKIYA(站前店)
# 食君團餐廳
# 食君團餐廳
# 台灣好料館
# 台灣好料館
# 慢生活咖啡
# 慢生活咖啡
# 香聚
# 香聚
# 小湯匙越式料理 Little Spoon(高雄夢時代店)
# 小湯匙越式料理 Little Spoon(高雄夢時代店)
# TU PANG地坊餐廳
# TU PANG地坊餐廳
# 金心盈福法義式手工甜點Cuore Doro
# 金心盈福法義式手工甜點Cuore Doro
# 轆轆Lu Lu早午餐
# 轆轆Lu Lu早午餐
# 阿里巴巴的廚房(台北總店)
# 阿里巴巴的廚房(台北總店)
# Green Bakery 綠帶純植物烘培
# Green Bakery 綠帶純植物烘培
# 老郭餛飩
# 老郭餛飩
# 嵩岳咖啡
# 嵩岳咖啡
# 清玉手調原味茶(台北杭州店)
# 清玉手調原味茶(台北杭州店)
# 朵爾自家手烘咖啡
# 朵爾自家手烘咖啡
# 模範街8巷23號
# 模範街8巷23號
# 十七號串烤町
# 十七號串烤町
# 寳德里洋樓
# 寳德里洋樓
# Mr. Deer
# Mr. Deer
# 就摮夯燒烤
# 就摮夯燒烤
# Malt Share咖啡餐酒館
# Malt Share咖啡餐酒館
# 冰果甜心 Bingirl(台中公益店)
# 冰果甜心 Bingirl(台中公益店)
# 原始仁烤物
# 原始仁烤物
# 通勝果園
# 通勝果園
# 花樂鐵板燒餐廳
# 花樂鐵板燒餐廳
# 百八魚場(青海店)
# 百八魚場(青海店)
# 寶達香瓜子
# 寶達香瓜子
# 王嫂手工坊
# 王嫂手工坊
# 亨記海鮮麻辣火鍋
# 亨記海鮮麻辣火鍋
# 純粹Pure Coffee
# 純粹Pure Coffee
# Winnie Drinker葳林爵閣彰化店
# Winnie Drinker葳林爵閣彰化店
# 江家餛飩
# 江家餛飩
# 巷仔內麵線焿
# 巷仔內麵線焿
# 二丁靚鍋(三重店)
# 二丁靚鍋(三重店)
# 台灣大排擋
# 台灣大排擋
# Z cafe 景觀民宿咖啡餐廳
# Z cafe 景觀民宿咖啡餐廳
# 富哥小吃
# 富哥小吃
# 一起呵呵開心茶飲 一ㄑㄏㄏ
# 一起呵呵開心茶飲 一ㄑㄏㄏ
# 夏部Shabu壽喜燒(林口國賓店)
# 夏部Shabu壽喜燒(林口國賓店)
# Jump搖滾炫飲
# Jump搖滾炫飲
# Deely Kitchen迪利樂廚
# Deely Kitchen迪利樂廚
# Feuille food Lab
# Feuille food Lab
# 味味香麵食店
# 味味香麵食店
# 大溪賴祖傳豆花店
# 大溪賴祖傳豆花店
# 品軒日式拉麵
# 品軒日式拉麵
# 饕饕
# 饕饕
# 山莊林食品行
# 山莊林食品行
# 禾燒方塊土司盒子
# 禾燒方塊土司盒子
# 順億鮪魚專賣店(忠明店)
# 順億鮪魚專賣店(忠明店)
# 紅色榖倉美式餐廳
# 紅色榖倉美式餐廳
# 食在養生
# 食在養生
# 愛不是手
# 愛不是手
# YANA cafe 人拿咖啡吧
# YANA cafe 人拿咖啡吧
# 銅鈴美食坊 Tone Bistro
# 銅鈴美食坊 Tone Bistro
# 中美街無名麵攤
# 中美街無名麵攤
# DOSE CAFE
# DOSE CAFE
# 台灣最後一家鹽酥雞
# 台灣最後一家鹽酥雞
# 黑美豆豆
# 黑美豆豆
# 赫曼咖啡(新竹市世博台灣館)
# 赫曼咖啡(新竹市世博台灣館)
# 壺川居酒屋
# 壺川居酒屋
# 鷹流東京豚骨拉麵-極匠gokujoh
# 鷹流東京豚骨拉麵-極匠gokujoh
# 石妹風味屋
# 石妹風味屋
# 神仙草-柴燒嫩仙草專賣店
# 神仙草-柴燒嫩仙草專賣店
# 全醫輕健速
# 全醫輕健速
# 岐夫部屋
# 岐夫部屋
# Solo Pizza Napoletana
# Solo Pizza Napoletana
# 圓仔花手工湯圓
# 圓仔花手工湯圓
# 樹巢Tree Nest
# 樹巢Tree Nest
# (良)古早味黑砂糖挫冰
# (良)古早味黑砂糖挫冰
# 大佬咖啡冰廳
# 大佬咖啡冰廳
# mini nook角落
# mini nook角落
# 愛屋吉屋
# 愛屋吉屋
# 高雄周燒肉飯(漢口店)
# 高雄周燒肉飯(漢口店)
# 人情味餐館
# 人情味餐館
# 17號鄉村廚房
# 17號鄉村廚房
# BO 雪球餅乾咖啡館(中友百貨)
# BO 雪球餅乾咖啡館(中友百貨)
# 工寓咖啡
# 工寓咖啡
# 南岭精緻麵館
# 南岭精緻麵館
# 咕嚕咕嚕貓咖啡 旗艦店
# 咕嚕咕嚕貓咖啡 旗艦店
# 貝瑞斯塔市集─西雅圖極品咖啡
# 貝瑞斯塔市集─西雅圖極品咖啡
# 露臺咖啡
# 露臺咖啡
# 東發號蚵仔麵線
# 東發號蚵仔麵線
# 史丹利家車輪餅
# 史丹利家車輪餅
# 182 Pancake
# 182 Pancake
# 川之流精緻涮涮鍋(北投店)
# 川之流精緻涮涮鍋(北投店)
# 玩麥趣麵包工坊
# 玩麥趣麵包工坊
# 布丁阿嬤
# 布丁阿嬤
# 香月美食
# 香月美食
# 可果美一番咖哩醬
# 可果美一番咖哩醬
# my味兒寶貝脆皮紅豆餅
# my味兒寶貝脆皮紅豆餅
# 老八風居酒屋(板橋店)
# 老八風居酒屋(板橋店)
# 東京雜貨樂園
# 東京雜貨樂園
# Happy Bar
# Happy Bar
# 木子家八寶冰
# 木子家八寶冰
# 波龍那食品-波妹方便麵
# 波龍那食品-波妹方便麵
# 阿慶師碳烤海鮮
# 阿慶師碳烤海鮮
# 小蔬苑
# 小蔬苑
# 二番町
# 二番町
# 中和包子
# 中和包子
# 茉斯手工甜點Partagez
# 茉斯手工甜點Partagez
# 老街茶房
# 老街茶房
# 鼎昌號
# 鼎昌號
# 超大模 9吋8切鹹派+9吋10切蘋菓派
# 超大模 9吋8切鹹派+9吋10切蘋菓派
# 勝面(成大店)
# 勝面(成大店)
# 漢家園迷你火鍋
# 漢家園迷你火鍋
# OVEN COFFEE 烤香咖啡
# OVEN COFFEE 烤香咖啡
# O ROSE 法式天然高品質冰淇淋
# O ROSE 法式天然高品質冰淇淋
# 3Pig五花肉專賣店
# 3Pig五花肉專賣店
# 麻神招待所
# 麻神招待所
# 5cent 五分錢快餐車古巴三明治輕食
# 5cent 五分錢快餐車古巴三明治輕食
# 喜得炭火燒三明治(板橋實踐店)
# 喜得炭火燒三明治(板橋實踐店)
# 饗四季-Vegetable Diet
# 饗四季-Vegetable Diet
# 紀家烘焙坊
# 紀家烘焙坊
# 滙景屋
# 滙景屋
# 米可微館 mini.co
# 米可微館 mini.co
# 森兜風咖啡館
# 森兜風咖啡館
# 草港飲食店
# 草港飲食店
# 波雷克堤
# 波雷克堤
# 台南 秘氏咖啡
# 台南 秘氏咖啡
# 波波莉可 洋菓子-boborico
# 波波莉可 洋菓子-boborico
# 田宜美食家
# 田宜美食家
# 福天津水餃
# 福天津水餃
# 松江8號廚房
# 松江8號廚房
# 諾瑪義大利麵
# 諾瑪義大利麵
# 烙印精緻早餐
# 烙印精緻早餐
# 張媽媽私房小廚
# 張媽媽私房小廚
# 一心豚骨拉麵(左營店)
# 一心豚骨拉麵(左營店)
# 棗食堂
# 棗食堂
# 牛爸爸牛肉麵店
# 牛爸爸牛肉麵店
# See U 手作披薩&氣泡調飲
# See U 手作披薩&氣泡調飲
# 蔡家米苔目冰
# 蔡家米苔目冰
# 鴨鄉寶煙燻冰滷味
# 鴨鄉寶煙燻冰滷味
# 鮮友火鍋(新竹-經國店)
# 鮮友火鍋(新竹-經國店)
# Double Times x2 呈予貳
# Double Times x2 呈予貳
# 伊凡的花園
# 伊凡的花園
# 正源萬巒豬腳
# 正源萬巒豬腳
# NU PASTA(新竹光華店)
# NU PASTA(新竹光華店)
# 山菜
# 山菜
# 8度濃漿
# 8度濃漿
# 馬克斯Marcus茶飲(合江店)
# 馬克斯Marcus茶飲(合江店)
# 艾德堡德國城堡民宿-德屋餐廳
# 艾德堡德國城堡民宿-德屋餐廳
# 四海豆漿大王
# 四海豆漿大王
# 牛喀牛排(大溪埔頂店)
# 牛喀牛排(大溪埔頂店)
# 阿翔珍味泰式
# 阿翔珍味泰式
# 順路來紅燒肉羹
# 順路來紅燒肉羹
# Fun Tower日式可麗餅
# Fun Tower日式可麗餅
# 阿川涼麵
# 阿川涼麵
# 34K coffee
# 34K coffee
# 阿巧肉粽碗粿
# 阿巧肉粽碗粿
# Feista Cafeteria
# Feista Cafeteria
# 黔香坊貴州料理
# 黔香坊貴州料理
# 方塊豆腐冰
# 方塊豆腐冰
# 潮粥府
# 潮粥府
# 赤肉胡椒餅
# 赤肉胡椒餅
# 桌上賓中式快餐便當達人(大裕店)
# 桌上賓中式快餐便當達人(大裕店)
# 茶自點複合式餐飲
# 茶自點複合式餐飲
# 吉野家 Yoshinoya(建國店)
# 吉野家 Yoshinoya(建國店)
# 小室涼麵
# 小室涼麵
# 家傳牛肉麵
# 家傳牛肉麵
# 竹東圳綿綿冰
# 竹東圳綿綿冰
# Journey Kaffe 覺旅咖啡(陽光店)
# Journey Kaffe 覺旅咖啡(陽光店)
# 扶旺號鐵板吐司(通化店)
# 扶旺號鐵板吐司(通化店)
# 茉香白玉銀耳
# 茉香白玉銀耳
# 高鼎丼料理(世貿店)
# 高鼎丼料理(世貿店)
# 巧味園餐廳(劉家香豬腳)
# 巧味園餐廳(劉家香豬腳)
# 維力食品-大乾麵系列
# 維力食品-大乾麵系列
# 優諾麗SOD-LIKE酵素飲
# 優諾麗SOD-LIKE酵素飲
# 弥味壽司 YUMMY SUSHI(原:平田壽司)
# 弥味壽司 YUMMY SUSHI(原:平田壽司)
# 台鹽優青素
# 台鹽優青素
# 大埔肉圓
# 大埔肉圓
# 饗饌牛肉麵
# 饗饌牛肉麵
# 王子鬆餅早午餐義大利麵
# 王子鬆餅早午餐義大利麵
# 心耕甜園
# 心耕甜園
# 161烘焙咖啡屋
# 161烘焙咖啡屋
# 點心小站
# 點心小站
# O by Locofood
# O by Locofood
# Eagle義來藝去
# Eagle義來藝去
# 感覺咖啡
# 感覺咖啡
# 鮮乳坊
# 鮮乳坊
# 夯達人創意串燒
# 夯達人創意串燒
# 天然素材富士
# 天然素材富士
# 烤北平價碳烤(桃園夜市)
# 烤北平價碳烤(桃園夜市)
# Jia 創意廚房
# Jia 創意廚房
# i。Choco巧克力專賣店
# i。Choco巧克力專賣店
# 幸福果舖
# 幸福果舖
# 蔥肉燒
# 蔥肉燒
# 翹宇宙Fun Space
# 翹宇宙Fun Space
# Pan Rico 手作烘焙
# Pan Rico 手作烘焙
# Start Boulangerie
# Start Boulangerie
# 大家好麵店
# 大家好麵店
# 祥記台北大橋頭麻糬冰
# 祥記台北大橋頭麻糬冰
# 小鮮鹹水雞
# 小鮮鹹水雞
# 跳格子義式廚房
# 跳格子義式廚房
# 匠 蝦料理餐廳
# 匠 蝦料理餐廳
# 嘉賀嫩仙草
# 嘉賀嫩仙草
# 乾泰豐蔬食咖啡
# 乾泰豐蔬食咖啡
# ...
# 胖虎帕尼尼
# 胖虎帕尼尼
# momo廚房
# momo廚房
# 新化排骨麵
# 新化排骨麵
# 江山海
# 江山海
# 魔棒咖哩
# 魔棒咖哩
# 尚品咖啡(高雄民權店)
# 尚品咖啡(高雄民權店)
# 天涯海餃
# 天涯海餃
# 肥龍一品鍋
# 肥龍一品鍋
# 五花馬水餃館
# 五花馬水餃館
# 麵飯店
# 麵飯店
# 想喝咖啡蔬食養生館
# 想喝咖啡蔬食養生館
# 光河咖啡坊
# 光河咖啡坊
# 佳多利餐廳
# 佳多利餐廳
# 玉蘭米糕食品專賣店
# 玉蘭米糕食品專賣店
# 花蓮糖廠冰品
# 花蓮糖廠冰品
# 竹野日本料理
# 竹野日本料理
# 王醬軍師魏三國
# 王醬軍師魏三國
# 基隆廟口阿民炒麵
# 基隆廟口阿民炒麵
# 馬卡龍和蛋糕
# 馬卡龍和蛋糕
# 北平烤鴨
# 北平烤鴨
# 摩多咖啡
# 摩多咖啡
# 六張犁饅頭店
# 六張犁饅頭店
# 饕客美食燒烤店
# 饕客美食燒烤店
# 鵝肉榮
# 鵝肉榮
# 點中王脆皮水煎包
# 點中王脆皮水煎包
# 董師傅手工麻糬
# 董師傅手工麻糬
# 美食甘仔店
# 美食甘仔店
# 澤鮨屋和食
# 澤鮨屋和食
# 漢坊食品有限公司
# 漢坊食品有限公司
# 九州新風堂日式拉麵店
# 九州新風堂日式拉麵店
# 咖啡語
# 咖啡語
# 老上海臭臭鍋
# 老上海臭臭鍋
# 北回木瓜牛奶(中壢元化店)
# 北回木瓜牛奶(中壢元化店)
# 林家涼麵
# 林家涼麵
# 澎湖御品家黑糖糕
# 澎湖御品家黑糖糕
# 姊弟客家菜
# 姊弟客家菜
# 四海遊龍鍋貼專賣店(龍井店)
# 四海遊龍鍋貼專賣店(龍井店)
# 台東羊哥現宰全羊料理
# 台東羊哥現宰全羊料理
# WORTHY活西美式餐飲
# WORTHY活西美式餐飲
# 貴族世家牛排
# 貴族世家牛排
# 蔚藍海岸
# 蔚藍海岸
# 湘誼小館
# 湘誼小館
# 蔡家鵝肉莊
# 蔡家鵝肉莊
# TIN MEN
# TIN MEN
# 秋料理精緻和食
# 秋料理精緻和食
# NO.63飛行公路
# NO.63飛行公路
# 福客來港式燒臘店
# 福客來港式燒臘店
# 上班族冷飲店
# 上班族冷飲店
# 井川的靚鍋
# 井川的靚鍋
# Pizza Hut 必勝客(新竹林森店)
# Pizza Hut 必勝客(新竹林森店)
# Bellavita 豆腐村
# Bellavita 豆腐村
# 饕食館
# 饕食館
# 山東饅頭
# 山東饅頭
# 南投意麵
# 南投意麵
# 豐原排骨麵
# 豐原排骨麵
# Cafe Trico
# Cafe Trico
# 主播貢丸
# 主播貢丸
# mini one
# mini one
# 大陸牛肉麵
# 大陸牛肉麵
# 1Bite2Go Caf'e & Deli
# 1Bite2Go Caf'e & Deli
# 福源
# 福源
# 巧味
# 巧味
# 幸福の餅舖
# 幸福の餅舖
# 豐原排骨酥麵
# 豐原排骨酥麵
# 河南水餃
# 河南水餃
# 雄出沒岩燒生蠔
# 雄出沒岩燒生蠔
# D2惡魔蛋糕
# D2惡魔蛋糕
# 一龍拉麵
# 一龍拉麵
# 巧味美食
# 巧味美食
# 香記烤鴨
# 香記烤鴨
# 二哥的店黃牛肉麵
# 二哥的店黃牛肉麵
# 懶人披薩雞排 起司薯薯
# 懶人披薩雞排 起司薯薯
# 蒼阜日本料亭
# 蒼阜日本料亭
# 洪記腸粉
# 洪記腸粉
# 無名水煎包
# 無名水煎包
# 就是淳咖啡
# 就是淳咖啡
# 恬甜豆坊
# 恬甜豆坊
# 卡璐佶咖啡館
# 卡璐佶咖啡館
# 杏仁豆腐冰
# 杏仁豆腐冰
# 紗舞縭
# 紗舞縭
# 三界公廟口米腸包香腸
# 三界公廟口米腸包香腸
# 好品味純手工鮮肉湯包
# 好品味純手工鮮肉湯包
# Finger COCO
# Finger COCO
# 三味鍋物(向上店)
# 三味鍋物(向上店)
# 中興素食
# 中興素食
# 霸味薑母鴨(安樂店)
# 霸味薑母鴨(安樂店)
# 十三番咖啡
# 十三番咖啡
# Pizza Hut 必勝客
# Pizza Hut 必勝客
# 福昌餐廳
# 福昌餐廳
# GULU's House 咕嚕好吃法式廚坊
# GULU's House 咕嚕好吃法式廚坊
# 東龍港式燒臘
# 東龍港式燒臘
# 本味日本料理
# 本味日本料理
# 鬥牛士(德安店)
# 鬥牛士(德安店)
# 動動嘴牛排館
# 動動嘴牛排館
# 貴族世家牛排
# 貴族世家牛排
# WeWell健康の白咖啡
# WeWell健康の白咖啡
# 想巷咖啡PÜKY’S CAFĒ
# 想巷咖啡PÜKY’S CAFĒ
# 秘密雞地
# 秘密雞地
# 黃記筒仔米糕排骨酥湯
# 黃記筒仔米糕排骨酥湯
# 鄭家拉麵廚房
# 鄭家拉麵廚房
# 土匪烘焙事務所
# 土匪烘焙事務所
# 原味海鮮餐廳
# 原味海鮮餐廳
# 好世界平價海鮮
# 好世界平價海鮮
# 白毫素食(石牌店)
# 白毫素食(石牌店)
# 天然素食
# 天然素食
# 鳳城燒臘粵菜
# 鳳城燒臘粵菜
# 牛魔王牛排館
# 牛魔王牛排館
# 開心吃喝巴士餐廳(師大店)
# 開心吃喝巴士餐廳(師大店)
# 塔拉多羅餐飲
# 塔拉多羅餐飲
# 紅牛屋
# 紅牛屋
# 港督燒臘
# 港督燒臘
# 普羅珈琲 PURO COFFEE & TEA
# 普羅珈琲 PURO COFFEE & TEA
# 大八平價海產
# 大八平價海產
# 奇緣咖啡坊
# 奇緣咖啡坊
# 咖啡的廚坊
# 咖啡的廚坊
# 馥蘭聚餐小品咖啡館
# 馥蘭聚餐小品咖啡館
# 向日葵咖啡館
# 向日葵咖啡館
# 千富川菜
# 千富川菜
# 大排檔
# 大排檔
# 小憩荼亭
# 小憩荼亭
# 檸檬草美食茶房(板橋館西店)
# 檸檬草美食茶房(板橋館西店)
# 羽翁羅德利(新莊店)
# 羽翁羅德利(新莊店)
# 改造人間餐廳
# 改造人間餐廳
# Starbucks Coffee 統一星巴克
# Starbucks Coffee 統一星巴克
# 三味朝鮮烤肉飯 豆腐鍋
# 三味朝鮮烤肉飯 豆腐鍋
# 石碇公臭臭鍋
# 石碇公臭臭鍋
# 三媽臭臭鍋(重陽店)
# 三媽臭臭鍋(重陽店)
# 典華飯店
# 典華飯店
# 光明公共食堂
# 光明公共食堂
# 光復饅頭店
# 光復饅頭店
# 帝臨舍餃子工房
# 帝臨舍餃子工房
# 姊妹雙胞胎
# 姊妹雙胞胎
# 劉家牛肉麵
# 劉家牛肉麵
# 仙人掌冰淇淋
# 仙人掌冰淇淋
# 名廚鐵板燒
# 名廚鐵板燒
# 欣味屋日式料理
# 欣味屋日式料理
# 牢鍋
# 牢鍋
# 錢都日式涮涮鍋
# 錢都日式涮涮鍋
# 錢多日式涮涮鍋
# 錢多日式涮涮鍋
# 薑母鴨
# 薑母鴨
# 印路品嚐咖啡
# 印路品嚐咖啡
# 大杉林小吃店
# 大杉林小吃店
# 金谷餐廳
# 金谷餐廳
# 台味珍餐廳
# 台味珍餐廳
# 廣達素食自助餐
# 廣達素食自助餐
# 港味燒臘
# 港味燒臘
# 劉記涼麵
# 劉記涼麵
# 陳家涼麵
# 陳家涼麵
# 哈拉里咖啡專櫃
# 哈拉里咖啡專櫃
# 香料廚房
# 香料廚房
# 山東餃子館
# 山東餃子館
# 老陳牛肉麵
# 老陳牛肉麵
# 劉備水煎包
# 劉備水煎包
# 小南門福州傻瓜乾麵
# 小南門福州傻瓜乾麵
# 福得泰
# 福得泰
# 八方雲集水餃鍋貼專賣店
# 八方雲集水餃鍋貼專賣店
# 御品川味牛肉麵
# 御品川味牛肉麵
# 湘帝牛肉麵
# 湘帝牛肉麵
# 富爸爸豬腳麵線
# 富爸爸豬腳麵線
# 奇味麵食(八德店)
# 奇味麵食(八德店)
# 蘭花亭涼麵
# 蘭花亭涼麵
# 山東切麵店
# 山東切麵店
# 全國府城
# 全國府城
# 劉師傅
# 劉師傅
# 西門老媽蒸餃
# 西門老媽蒸餃
# MY COFFEE
# MY COFFEE
# 政益食品
# 政益食品
# 竹野燒肉飯
# 竹野燒肉飯
# 貴族世家牛排
# 貴族世家牛排
# 客居食堂
# 客居食堂
# 喜多屋日本料理(風城店)
# 喜多屋日本料理(風城店)
# 莊園咖啡
# 莊園咖啡
# 素食
# 素食
# 京都鐵板燒
# 京都鐵板燒
# 品味生活家卡拉OK附設咖啡簡餐
# 品味生活家卡拉OK附設咖啡簡餐
# 錢源日式涮涮鍋
# 錢源日式涮涮鍋
# 紅洋蔥
# 紅洋蔥
# 喃邦府泰式料理
# 喃邦府泰式料理
# 素食坊
# 素食坊
# 民生素食
# 民生素食
# 錢城涮涮鍋(彰化店)
# 錢城涮涮鍋(彰化店)
# 鴻運燒臘
# 鴻運燒臘
# 樂竹壽司和風料理
# 樂竹壽司和風料理
# 貴族世家牛排(龍潭店)
# 貴族世家牛排(龍潭店)
# 我家牛排
# 我家牛排
# 漁樓深海鮮
# 漁樓深海鮮
# 霸味薑母鴨
# 霸味薑母鴨
# 湯匙咖啡屋
# 湯匙咖啡屋
# 鍋神涮涮鍋
# 鍋神涮涮鍋
# 鍋神日式涮涮鍋
# 鍋神日式涮涮鍋
# 鍋神日式涮涮鍋
# 鍋神日式涮涮鍋
# 極品迷你涮涮鍋
# 極品迷你涮涮鍋
# 采苑燒肉
# 采苑燒肉
# 家園川味小館
# 家園川味小館
# 多柏思麵包
# 多柏思麵包
# 川味
# 川味
# 謝阿姨餐飲
# 謝阿姨餐飲
# 佳佳香鍋貼專賣店
# 佳佳香鍋貼專賣店
# 新荷風茶居
# 新荷風茶居
# 嘟嘟美食館
# 嘟嘟美食館
# 真口味餐廳
# 真口味餐廳
# 專業蚵仔大腸麵線
# 專業蚵仔大腸麵線
# 成都麵食館
# 成都麵食館
# 真川味
# 真川味
# 重慶森林
# 重慶森林
# 銘記牛肉麵
# 銘記牛肉麵
# 柑仔店
# 柑仔店
# 海岸風情
# 海岸風情
# 南台灣土魠魚羹
# 南台灣土魠魚羹
# 莎莉屋
# 莎莉屋
# Small 萱
# Small 萱
# 樂蕃天
# 樂蕃天
# 黑雞牌雞絲麵
# 黑雞牌雞絲麵
# 大丸靚鍋
# 大丸靚鍋
# 海新鱻(原：台糖白甘蔗養生涮涮鍋)
# 海新鱻(原：台糖白甘蔗養生涮涮鍋)
# 魚河岸海鮮料理
# 魚河岸海鮮料理
# 香雞排
# 香雞排
# 3Q脆皮雞排
# 3Q脆皮雞排
# 哈拉里咖啡(台中中港店)
# 哈拉里咖啡(台中中港店)
# 巴瓦朵Bravo餐廳
# 巴瓦朵Bravo餐廳
# 鮮味屋迴轉涮涮鍋
# 鮮味屋迴轉涮涮鍋
# 干城米干
# 干城米干
# 郭元益(愛國門市)
# 郭元益(愛國門市)
# 摩斯漢堡 MOS BURGER(瑞光店)
# 摩斯漢堡 MOS BURGER(瑞光店)
# 嘉義火雞肉飯
# 嘉義火雞肉飯
# ROYAL HOST樂雅樂家庭餐廳(台中高鐵店)
# ROYAL HOST樂雅樂家庭餐廳(台中高鐵店)
# 壹咖啡 ecoffee(草屯虎山店)
# 壹咖啡 ecoffee(草屯虎山店)
# 清心福全冷飲站(復興店)
# 清心福全冷飲站(復興店)
# 東港漁村
# 東港漁村
# 拿坡里披薩‧炸雞(內湖店)
# 拿坡里披薩‧炸雞(內湖店)
# 布朗咖啡小館
# 布朗咖啡小館
# 85度C咖啡蛋糕烘焙專賣店(桃園大業店)
# 85度C咖啡蛋糕烘焙專賣店(桃園大業店)
# 85度C咖啡蛋糕烘焙專賣店(中壢元化店)
# 85度C咖啡蛋糕烘焙專賣店(中壢元化店)
# 85度C咖啡蛋糕烘焙專賣店(湖口忠孝店)
# 85度C咖啡蛋糕烘焙專賣店(湖口忠孝店)
# 麥當勞(台北中山店)
# 麥當勞(台北中山店)
# 有雞料理
# 有雞料理
# 萬里飄香美食餐館
# 萬里飄香美食餐館
# 雷門豆花
# 雷門豆花
# 廣合涼麵
# 廣合涼麵
# 公館蚵仔麵線
# 公館蚵仔麵線
# 柳家韓式料理 Yu Ga Ne(現為：哈魯邦)
# 柳家韓式料理 Yu Ga Ne(現為：哈魯邦)
# 阿仁小吃店
# 阿仁小吃店
# 丹野牧場
# 丹野牧場
# 三角骨鹽酥雞專賣店
# 三角骨鹽酥雞專賣店
# 泡菜王(崑山店)
# 泡菜王(崑山店)
# 紅太陽(高雄文化店)
# 紅太陽(高雄文化店)
# 南洋風尚茶館
# 南洋風尚茶館
# 老蔡牛肉麵
# 老蔡牛肉麵
# 爆米香
# 爆米香
# 和田日本料理
# 和田日本料理
# 小南米糕
# 小南米糕
# 老莊牛肉麵
# 老莊牛肉麵
# 金三峽牛角精緻西點烘培(新莊門市)
# 金三峽牛角精緻西點烘培(新莊門市)
# 小春日和涮涮鍋
# 小春日和涮涮鍋
# 彰化肉圓
# 彰化肉圓
# 員林肉圓
# 員林肉圓
# 三寶麵線
# 三寶麵線
# 劉家肉粽菜粽專賣(西門店)
# 劉家肉粽菜粽專賣(西門店)
# 楓炭火燒肉(昆明店)
# 楓炭火燒肉(昆明店)
# 鬍鬚張(台北寧夏店)
# 鬍鬚張(台北寧夏店)
# 大台北永和豆漿大王
# 大台北永和豆漿大王
# HAPA燒肉居酒屋
# HAPA燒肉居酒屋
# 我家涼麵(延吉店)
# 我家涼麵(延吉店)
# 康福精緻全自助餐(莊敬店)
# 康福精緻全自助餐(莊敬店)
# 京都浪漫明治館(雙十店)
# 京都浪漫明治館(雙十店)
# 擔仔麵意麵
# 擔仔麵意麵
# 賴記蚵仔煎
# 賴記蚵仔煎
# 陶林涮涮鍋(鳳山店)
# 陶林涮涮鍋(鳳山店)
# 潮州牛雜湯
# 潮州牛雜湯
# 新珍香餅行
# 新珍香餅行
# 上好肉粽
# 上好肉粽
# 湯皇東山排骨酥
# 湯皇東山排骨酥
# 品香當歸土虱.藥燉排骨.肉圓.肉燥飯.米糕
# 品香當歸土虱.藥燉排骨.肉圓.肉燥飯.米糕
# 劉家楊桃湯
# 劉家楊桃湯
# 吉品屋美食館
# 吉品屋美食館
# 黑吧煎焙咖啡專賣店
# 黑吧煎焙咖啡專賣店
# 圓環魯肉飯肉羹
# 圓環魯肉飯肉羹
# 比利小雞(永和店)
# 比利小雞(永和店)
# 東京和風豬排專門店(內湖店)
# 東京和風豬排專門店(內湖店)
# 三品鱻涮涮鍋
# 三品鱻涮涮鍋
# 洛貝茲城藝文咖啡館
# 洛貝茲城藝文咖啡館
# 笑顏亭
# 笑顏亭
# 丹堤咖啡(信義一店)
# 丹堤咖啡(信義一店)
# 踏雪貓
# 踏雪貓
# 2097   那豆咖啡
# 2097   那豆咖啡
# 瀧之家和風料理
# 瀧之家和風料理
# 肯德基 KFC(崇光店)
# 肯德基 KFC(崇光店)
# 蚵仔麵線
# 蚵仔麵線
# 肯德基 KFC(中壢中正店)
# 肯德基 KFC(中壢中正店)
# 可愛冷飲車 澎湖小男孩
# 可愛冷飲車 澎湖小男孩
# 王記府城肉粽(西寧店)
# 王記府城肉粽(西寧店)
# 得利食品
# 得利食品
# 一口小肉圓
# 一口小肉圓
# 靠屘改泰式海南雞飯專門店
# 靠屘改泰式海南雞飯專門店
# 新港廟口鴨肉羹
# 新港廟口鴨肉羹
# 食堂屋
# 食堂屋
# QK咖啡(虎林店)
# QK咖啡(虎林店)
# 秀姑巒溪
# 秀姑巒溪
# 岩義大利麵
# 岩義大利麵
# IS COFFEE/伊是咖啡(安和伊是店)
# IS COFFEE/伊是咖啡(安和伊是店)
# 好男人生活坊
# 好男人生活坊
# 水巷茶弄(屏東林森店)
# 水巷茶弄(屏東林森店)
# 二師兄古早味魯味
# 二師兄古早味魯味
# 榭歐陸美食餐飲
# 榭歐陸美食餐飲
# QK咖啡(永康店)
# QK咖啡(永康店)
# 聖加南洋小品(南昌店)
# 聖加南洋小品(南昌店)
# 將軍蔥抓餅
# 將軍蔥抓餅
# 泰世紀
# 泰世紀
# 珍香海產店
# 珍香海產店
# 永和四海豆漿大王(塗城店)
# 永和四海豆漿大王(塗城店)
# 上田屋
# 上田屋
# cafe'8(內湖店)
# cafe'8(內湖店)
# 杏花村
# 杏花村
# Uncle Pan麵包叔叔烘培坊(中正店)
# Uncle Pan麵包叔叔烘培坊(中正店)
# 阿達海產店
# 阿達海產店
# 客滿堂
# 客滿堂
# 隨豐餐廳
# 隨豐餐廳
# 魷魚王
# 魷魚王
# 阿堤米糕
# 阿堤米糕
# 高馡咖啡
# 高馡咖啡
# 北觀食館
# 北觀食館
# 方亭咖啡
# 方亭咖啡
# 光華小毛牛肉麵
# 光華小毛牛肉麵
# 西大發
# 西大發
# 滿滿炭火燒肉
# 滿滿炭火燒肉
# 歐霸醬的灶腳
# 歐霸醬的灶腳
# 斗南米糕甲
# 斗南米糕甲
# 永和保福路無名大腸麵線
# 永和保福路無名大腸麵線
# 阿珠手工現做芋圓
# 阿珠手工現做芋圓
# 古早味
# 古早味
# 愛之味紅豆燕麥
# 愛之味紅豆燕麥
# 帝王食補紅面薑母鴨(公道五店)
# 帝王食補紅面薑母鴨(公道五店)
# 關山便當
# 關山便當
# 長壽長崎蜂蜜蛋糕
# 長壽長崎蜂蜜蛋糕
# 正常鮮肉小籠湯包
# 正常鮮肉小籠湯包
# 離塵山莊
# 離塵山莊
# 古早味蚵嗲
# 古早味蚵嗲
# 水林蔡氏農產行
# 水林蔡氏農產行
# 小籠包
# 小籠包
# 明倫蛋餅
# 明倫蛋餅
# 上海小籠湯包
# 上海小籠湯包
# 丼亭(原：和膳亭)
# 丼亭(原：和膳亭)
# 魯肉昌
# 魯肉昌
# 豆花
# 豆花
# 章成麥芽餅
# 章成麥芽餅
# 巧味溫州大餛飩
# 巧味溫州大餛飩
# 古早味豆花
# 古早味豆花
# Vincent's Foods&Drinks歐陸餐廳
# Vincent's Foods&Drinks歐陸餐廳
# 王元吉炸粿
# 王元吉炸粿
# 潮州大廟口旗魚黑輪
# 潮州大廟口旗魚黑輪
# 食上日燒
# 食上日燒
# 蕭家庄涼麵專賣店
# 蕭家庄涼麵專賣店
# 米蘭咖啡
# 米蘭咖啡
# 85度C咖啡蛋糕烘焙專賣店(高雄岡山店)
# 85度C咖啡蛋糕烘焙專賣店(高雄岡山店)
# 港墘蚵嗲
# 港墘蚵嗲
# Aroma House II
# Aroma House II
# 真味香快餐店
# 真味香快餐店
# 歐風義大利麵館
# 歐風義大利麵館
# 富嵐迪咖啡
# 富嵐迪咖啡
# 天仁茗茶(武昌店)
# 天仁茗茶(武昌店)
# 蔡清豐手工麵線
# 蔡清豐手工麵線
# 店小二
# 店小二
# 西蜀饌牛肉麵
# 西蜀饌牛肉麵
# 巧園咖啡館
# 巧園咖啡館
# 25twenty-five 順暢99
# 25twenty-five 順暢99
# 肯德基
# 肯德基
# 火鍋世家(中和南華店)
# 火鍋世家(中和南華店)
# 老頭擺客家菜
# 老頭擺客家菜
# 繼光香香雞(鳳山店)
# 繼光香香雞(鳳山店)
# 老朋友平價美食坊
# 老朋友平價美食坊
# 花園白咖啡
# 花園白咖啡
# 漁師物語安心食材專賣店
# 漁師物語安心食材專賣店
# 天天見麵
# 天天見麵
# June 六月美式音樂餐廳(吳鳳店)
# June 六月美式音樂餐廳(吳鳳店)
# 銘記麻辣涼麵
# 銘記麻辣涼麵
# 蜜蜂咖啡
# 蜜蜂咖啡
# 慈慧素食
# 慈慧素食
# 咱兜灶腳
# 咱兜灶腳
# 丹丹漢堡
# 丹丹漢堡
# 鮮辣(原：樂道麻辣鍋)
# 鮮辣(原：樂道麻辣鍋)
# 冰家之地
# 冰家之地
# 宜蘭土包仔
# 宜蘭土包仔
# 奶油 飛
# 奶油 飛
# 迪化街紅麵線
# 迪化街紅麵線
# 陳記蔥油餅
# 陳記蔥油餅
# 轉角花園咖啡美食館
# 轉角花園咖啡美食館
# 幸福可樂餅
# 幸福可樂餅
# 喜粵樓
# 喜粵樓
# 曾公子2012聖誕月貴賓劵
# 曾公子2012聖誕月貴賓劵
# Coffee+ 咖啡家
# Coffee+ 咖啡家
# 甘喜茶(南崁店)
# 甘喜茶(南崁店)
# 無老鍋
# 無老鍋
# getmore lab 精品咖啡
# getmore lab 精品咖啡
# 8弄5焗烤廚房
# 8弄5焗烤廚房
# 于烤魚創意家常料理
# 于烤魚創意家常料理
# 台酒肉紙 [海苔口味 芝麻口味]
# 台酒肉紙 [海苔口味 芝麻口味]
# 品客牛排
# 品客牛排
# 宜品福州乾拌麵
# 宜品福州乾拌麵
# coco都可
# coco都可
# 大口咬串燒
# 大口咬串燒
# 易式小豬窯烤披薩
# 易式小豬窯烤披薩
# 餃餃者(興大店)
# 餃餃者(興大店)
# 田媽媽鄉土美食坊
# 田媽媽鄉土美食坊
# 武藏甜甜圈專賣店
# 武藏甜甜圈專賣店
# 濰濰泡沫紅茶
# 濰濰泡沫紅茶
# 阿ㄆㄧㄚˋ滷味
# 阿ㄆㄧㄚˋ滷味
# DOM動美式餐廳
# DOM動美式餐廳
# Jellybird
# Jellybird
# JOYCE巧克力工房
# JOYCE巧克力工房
# 甜在心甜點冰品專賣店
# 甜在心甜點冰品專賣店
# 鼎記臭豆腐
# 鼎記臭豆腐
# 南興米粉
# 南興米粉
# 尚品咖啡
# 尚品咖啡
# 米迪亞 coffee media
# 米迪亞 coffee media
# 徐家手工蛋捲
# 徐家手工蛋捲
# 紫南宮複合式餐飲
# 紫南宮複合式餐飲
# 五七廚房
# 五七廚房
# ELITE CONCEPT
# ELITE CONCEPT
# 美式早餐屋(羅東公正店)
# 美式早餐屋(羅東公正店)
# 東北麵食館
# 東北麵食館
# 大腸包小腸
# 大腸包小腸
# 炸鮮奶
# 炸鮮奶
# TINA COFFEE
# TINA COFFEE
# 早安！美芝城(廣權店)
# 早安！美芝城(廣權店)
# 鈺品園
# 鈺品園
# 空中的魚乳酪蛋糕
# 空中的魚乳酪蛋糕
# 臭豆腐
# 臭豆腐
# coco都可
# coco都可
# 珍葆活海鮮批發零售賣場
# 珍葆活海鮮批發零售賣場
# 原炭燒
# 原炭燒
# 鮮二鍋吃飽小火鍋
# 鮮二鍋吃飽小火鍋
# 歐登咖啡專賣店
# 歐登咖啡專賣店
# 悟饕池上飯包(台東關山店)
# 悟饕池上飯包(台東關山店)
# 清粥小菜
# 清粥小菜
# 50嵐
# 50嵐
# Joyce Sport Club & Live Band
# Joyce Sport Club & Live Band
# 清心福全冷飲店
# 清心福全冷飲店
# 瘋巢複合式餐飲
# 瘋巢複合式餐飲
# 古都台南擔仔麵
# 古都台南擔仔麵
# 鴨天下食補薑母鴨烏蔘雞
# 鴨天下食補薑母鴨烏蔘雞
# 東山鴨頭
# 東山鴨頭
# 中南海早餐店
# 中南海早餐店
# 明洞一隻雞(中山店)
# 明洞一隻雞(中山店)
# 定食8 爭鮮餐飲
# 定食8 爭鮮餐飲
# 微熱山丘
# 微熱山丘
# 媽媽廚房
# 媽媽廚房
# 青蛙黑蛋奶(中山店)
# 青蛙黑蛋奶(中山店)
# 邵師父上海湯包
# 邵師父上海湯包
# 丹堤咖啡研磨專賣店 Dante Coffee(龜山萬壽店)
# 丹堤咖啡研磨專賣店 Dante Coffee(龜山萬壽店)
# 魯山人和風壽喜鍋物
# 魯山人和風壽喜鍋物
# 阿貴風味鄒餐廳
# 阿貴風味鄒餐廳
# 愛斯基摩複合餐飲
# 愛斯基摩複合餐飲
# 角子虎
# 角子虎
# 天橋下美食自助餐
# 天橋下美食自助餐
# Myron cafe
# Myron cafe
# 瑞穗生活購物網
# 瑞穗生活購物網
# 復興大腸蚵仔麵線
# 復興大腸蚵仔麵線
# 香港鍋巴港式燒臘快餐
# 香港鍋巴港式燒臘快餐
# 阿聰師芋頭酥的糕餅主意(台中秋紅谷館)
# 阿聰師芋頭酥的糕餅主意(台中秋紅谷館)
# O!Bao 柴燒手感天然酵母麵包
# O!Bao 柴燒手感天然酵母麵包
# 抹醬仙。原味廚房
# 抹醬仙。原味廚房
# 蘿蔔園
# 蘿蔔園
# 基隆連珍－芋泥雪露
# 基隆連珍－芋泥雪露
# 一直是晴天
# 一直是晴天
# 逸園包子
# 逸園包子
# Gayo Cafe'
# Gayo Cafe'
# 嘉義雞肉飯
# 嘉義雞肉飯
# 阿婆蔥油餅
# 阿婆蔥油餅
# ㄙㄨㄚˋ嘴鹽水雞
# ㄙㄨㄚˋ嘴鹽水雞
# 楊家將過橋米線
# 楊家將過橋米線
# 新林鐵板燒
# 新林鐵板燒
# 魚鮮會社
# 魚鮮會社
# 品鱻鍋物
# 品鱻鍋物
# 五華魷魚羹
# 五華魷魚羹
# Long Bar
# Long Bar
# double L
# double L
# 喜利廉餅店(清水總店)
# 喜利廉餅店(清水總店)
# 陸品川浙名菜
# 陸品川浙名菜
# Trio
# Trio
# 德記東山鴨頭
# 德記東山鴨頭
# Come
# Come
# 鵝媽媽鵝肉料理
# 鵝媽媽鵝肉料理
# 麥當勞(林森一店)
# 麥當勞(林森一店)
# Machikaka WaCafe
# Machikaka WaCafe
# 四海遊龍鍋貼專賣店
# 四海遊龍鍋貼專賣店
# 綠蓋茶館
# 綠蓋茶館
# 北方早點
# 北方早點
# 歐可茶葉_真奶茶
# 歐可茶葉_真奶茶
# 戴記麵食中興炒飯
# 戴記麵食中興炒飯
# Fun king
# Fun king
# i豆咖啡(林森店)
# i豆咖啡(林森店)
# 竹東邱排骨酥麵(竹北店)
# 竹東邱排骨酥麵(竹北店)
# PiNNCafe 品．咖啡
# PiNNCafe 品．咖啡
# 黑肉麵
# 黑肉麵
# 高雄木瓜牛乳(一心店)
# 高雄木瓜牛乳(一心店)
# 八角8茶飲
# 八角8茶飲
# 飄香麵館
# 飄香麵館
# MÖVENPICK café 莫凡彼咖啡館
# MÖVENPICK café 莫凡彼咖啡館
# Fun Tower日式可麗餅
# Fun Tower日式可麗餅
# 老窩咖啡館
# 老窩咖啡館
# 85度C咖啡蛋糕烘焙專賣店
# 85度C咖啡蛋糕烘焙專賣店
# 侏儸紀 - 醬汁魷魚、啤酒螺專賣店(原羅記醬之坊)
# 侏儸紀 - 醬汁魷魚、啤酒螺專賣店(原羅記醬之坊)
# 巧食雞碳烤香雞排
# 巧食雞碳烤香雞排
# 黑丸嫩仙草(板橋莊敬店)
# 黑丸嫩仙草(板橋莊敬店)
# 北港東陽香菇肉羹
# 北港東陽香菇肉羹
# 松井日本料理自助百匯
# 松井日本料理自助百匯
# 罔市手工粉圓
# 罔市手工粉圓
# 麻豆驢子廚房(原麻豆PASA廚房)
# 麻豆驢子廚房(原麻豆PASA廚房)
# 艾隆義式麵食館(彰化店)
# 艾隆義式麵食館(彰化店)
# 延齡堂
# 延齡堂
# 全羅道韓式拌飯(松山店)
# 全羅道韓式拌飯(松山店)
# 鏞記烤鴨
# 鏞記烤鴨
# 紫竹萱
# 紫竹萱
# 熊野食彩酒坊
# 熊野食彩酒坊
# 良食究好市集
# 良食究好市集
# 留乃堂烘焙坊(慶城店)
# 留乃堂烘焙坊(慶城店)
# CoCo 都可茶飲(北新)
# CoCo 都可茶飲(北新)
# 純發糕點廚
# 純發糕點廚
# 三媽臭臭鍋
# 三媽臭臭鍋
# 水煎包
# 水煎包
# 衣淇鮮奶麻糬
# 衣淇鮮奶麻糬
# 高雄金鑽夜市泡菜蝦蛋
# 高雄金鑽夜市泡菜蝦蛋
# 小琉球麻花捲
# 小琉球麻花捲
# 黑羊咖啡
# 黑羊咖啡
# 康樂街無名水餃店
# 康樂街無名水餃店
# 烤堂
# 烤堂
# Mr.Smile 微笑先生
# Mr.Smile 微笑先生
# 79 Style
# 79 Style
# 郭家雞肉飯
# 郭家雞肉飯
# 麻糬
# 麻糬
# 台灣蔡虱目魚專賣店
# 台灣蔡虱目魚專賣店
# 阿一鐵板
# 阿一鐵板
# 泓星園餐館
# 泓星園餐館
# 大眾套餐便當
# 大眾套餐便當
# 韓國烤肉捲(公館總店)
# 韓國烤肉捲(公館總店)
# 猴腮擂大腸包小腸(宜蘭店)
# 猴腮擂大腸包小腸(宜蘭店)
# 草包店(台北101店)
# 草包店(台北101店)
# 青瓷泰式料理
# 青瓷泰式料理
# 無名飯糰
# 無名飯糰
# 九如營養香酥三明治(新莊分店)
# 九如營養香酥三明治(新莊分店)
# 蛋黃麵
# 蛋黃麵
# 鱔魚麵
# 鱔魚麵
# 八珍饌
# 八珍饌
# 韓楓館
# 韓楓館
# 饗厚牛排
# 饗厚牛排
# 彩椒廚房
# 彩椒廚房
# 飲客INK創意飲品(飲客INK海華門市)
# 飲客INK創意飲品(飲客INK海華門市)
# 日出茶太
# 日出茶太
# 大滷桶魯味
# 大滷桶魯味
# Beauty小舖
# Beauty小舖
# 和風食堂
# 和風食堂
# 光泉優酪乳(原味低脂)
# 光泉優酪乳(原味低脂)
# 瑪迪滋專業烘焙
# 瑪迪滋專業烘焙
# 八方雲集水餃鍋貼專賣店(新莊化成店)
# 八方雲集水餃鍋貼專賣店(新莊化成店)
# 康師傅 港式 干燒海鮮炒麵
# 康師傅 港式 干燒海鮮炒麵
# 港台燒臘美食
# 港台燒臘美食
# TFYOGURT《圖圖果》霜‧優格(MegaCity 板橋大遠百)
# TFYOGURT《圖圖果》霜‧優格(MegaCity 板橋大遠百)
# 陳員外抓餅店
# 陳員外抓餅店
# 冰菓店
# 冰菓店
# 金都餐廳
# 金都餐廳
# 新台客
# 新台客
# 阿公店麵店
# 阿公店麵店
# 捲麵
# 捲麵
# 天津蔥抓餅
# 天津蔥抓餅
# 家鄉牛肉麵
# 家鄉牛肉麵
# 米粉湯
# 米粉湯
# ㄚ好嬸古早味紅茶冰(南勢角夜市)
# ㄚ好嬸古早味紅茶冰(南勢角夜市)
# 布丁牛焦糖奶香手工布丁
# 布丁牛焦糖奶香手工布丁
# 珍記北平烤鴨(鳳山分店)
# 珍記北平烤鴨(鳳山分店)
# 圓夢茶葉蛋
# 圓夢茶葉蛋
# 彰化肉丸
# 彰化肉丸
# 糜家莊潮式砂鍋粥
# 糜家莊潮式砂鍋粥
# 清井澤
# 清井澤
# 宜蘭山寨村
# 宜蘭山寨村
# 乾杯BAR
# 乾杯BAR
# 麵癡
# 麵癡
# 飯館兒韓式專門店
# 飯館兒韓式專門店
# 寶珠蛋黃麵(重信分店)
# 寶珠蛋黃麵(重信分店)
# ｐｉｎ品奶酪
# ｐｉｎ品奶酪
# kapi fish
# kapi fish
# 韓鶴亭(木新店)
# 韓鶴亭(木新店)
# 清蒸一口小肉圓
# 清蒸一口小肉圓
# 3Q脆皮雞排複合式餐飲
# 3Q脆皮雞排複合式餐飲
# 南投阿霞手工蛋捲
# 南投阿霞手工蛋捲
# 尚豐美食
# 尚豐美食
# 台灣古早味 黑糖四物
# 台灣古早味 黑糖四物
# 又一村
# 又一村
# kimo義大利創意料理
# kimo義大利創意料理
# 韓豚豬龍骨包
# 韓豚豬龍骨包
# 平價自助火鍋城
# 平價自助火鍋城
# 和記豆漿店
# 和記豆漿店
# 福利麵包
# 福利麵包
# 福提豬腳
# 福提豬腳
# 小辣椒(石牌店)
# 小辣椒(石牌店)
# 廟口紅糟魷魚
# 廟口紅糟魷魚
# 內巷甕缸雞
# 內巷甕缸雞
# 得倫食品~小魚花生海苔酥
# 得倫食品~小魚花生海苔酥
# ROCK SAUCE味子餐廳
# ROCK SAUCE味子餐廳
# 幾分甜(板中店)
# 幾分甜(板中店)
# 洛神麻糬餅
# 洛神麻糬餅
# 饅頭與我
# 饅頭與我
# 熊菓子煎餅(焦糖腰果)
# 熊菓子煎餅(焦糖腰果)
# 李銘記烤鴨(中壢店)
# 李銘記烤鴨(中壢店)
# 鐵道咖啡景觀台
# 鐵道咖啡景觀台
# 怖麻怖辣(京華場)
# 怖麻怖辣(京華場)
# 喜兒咖啡坊(Here Caf'e)
# 喜兒咖啡坊(Here Caf'e)
# 北海漁村
# 北海漁村
# 綠峰大飯店
# 綠峰大飯店
# 郭家蔥油餅
# 郭家蔥油餅
# 加味屋
# 加味屋
# 阿弘潤餅
# 阿弘潤餅
# 手信坊
# 手信坊
# 喫飯食堂
# 喫飯食堂
# 全麥王子
# 全麥王子
# 川本岡手製工坊
# 川本岡手製工坊
# 頂廚國宴
# 頂廚國宴
# 爭鮮迴轉壽司 SUSHI EXPRESS(嘉義店)
# 爭鮮迴轉壽司 SUSHI EXPRESS(嘉義店)
# 起思味工房
# 起思味工房
# 米菓子活力早餐
# 米菓子活力早餐
# 曾記麻糬
# 曾記麻糬
# 西北麻吉燒
# 西北麻吉燒
# 運動速燃 飲料
# 運動速燃 飲料
# 玉膳實業
# 玉膳實業
# 蚯蚓龍山麵線糊
# 蚯蚓龍山麵線糊
# 好年年豬腳
# 好年年豬腳
# 牛喀牛排
# 牛喀牛排
# 意樂
# 意樂
# 品豐軒
# 品豐軒
# 無名米粉湯
# 無名米粉湯
# 三好便當
# 三好便當
# FISH IN魚游進來
# FISH IN魚游進來
# 古典玫瑰園(台中廣三SOGO店)
# 古典玫瑰園(台中廣三SOGO店)
# PONPIE
# PONPIE
# 純萃喝咖啡(重焙曼特寧)
# 純萃喝咖啡(重焙曼特寧)
# 金食堂
# 金食堂
# Bric Cafe(吳興店)
# Bric Cafe(吳興店)
# 古味
# 古味
# 甜客廳(中壢店)
# 甜客廳(中壢店)
# 辣匠
# 辣匠
# 土魠魚羹
# 土魠魚羹
# I'm Pasta
# I'm Pasta
# 永和豆漿大王
# 永和豆漿大王
# 七里香甕仔雞
# 七里香甕仔雞
# 合口味餐廳
# 合口味餐廳
# 阿婆麵店
# 阿婆麵店
# 礁溪老爺大酒店-岩波亭新潮流料理
# 礁溪老爺大酒店-岩波亭新潮流料理
# 開開看飯店
# 開開看飯店
# 巴布爾尼乳酪蛋糕專賣店
# 巴布爾尼乳酪蛋糕專賣店
# 糖水公園(一心店)
# 糖水公園(一心店)
# 上海王餐廳
# 上海王餐廳
# 津正越南小吃
# 津正越南小吃
# 好易網。醬燒豆腐烹飪包
# 好易網。醬燒豆腐烹飪包
# 川味紅燒牛肉麵
# 川味紅燒牛肉麵
# 龍緣麻辣鴛鴦火鍋
# 龍緣麻辣鴛鴦火鍋
# 爆漿雞蛋糕
# 爆漿雞蛋糕
# 中大水餃鍋貼館
# 中大水餃鍋貼館
# 弘爺漢堡
# 弘爺漢堡
# 古早厝
# 古早厝
# 葉記休閒食品厚豬肉乾
# 葉記休閒食品厚豬肉乾
# 大勝銅鑼燒
# 大勝銅鑼燒
# 石牌甜蜜蜜
# 石牌甜蜜蜜
# 溪邊的樹老羊與海
# 溪邊的樹老羊與海
# 宗和黑糖桂圓糕
# 宗和黑糖桂圓糕
# CHUBBY喜樂餐廳
# CHUBBY喜樂餐廳
# 尊品原汁牛肉麵
# 尊品原汁牛肉麵
# 好味珍現炒
# 好味珍現炒
# AL CICCHETTO 義麵坊小酒館
# AL CICCHETTO 義麵坊小酒館
# 豆花薏仁湯
# 豆花薏仁湯
# 客滿樓(蘆洲長榮店)
# 客滿樓(蘆洲長榮店)
# 無名麵攤
# 無名麵攤
# 嘟柏林鐵板燒餐廳
# 嘟柏林鐵板燒餐廳
# 松芝岡日式料理(台中中港店)
# 松芝岡日式料理(台中中港店)
# 鐵板王
# 鐵板王
# MOCHI烘坊工坊
# MOCHI烘坊工坊
# 甜椒食堂
# 甜椒食堂
# 宏林鐵板燒餐廳
# 宏林鐵板燒餐廳
# 大嘜鐵板燒
# 大嘜鐵板燒
# Let's Six
# Let's Six
# 富瑤鐵板燒
# 富瑤鐵板燒
# 莉庭古早味(青山店)
# 莉庭古早味(青山店)
# 郎港式鮮肉包
# 郎港式鮮肉包
# 米花鍋燒麵關東煮
# 米花鍋燒麵關東煮
# 台北米粉湯
# 台北米粉湯
# 愛之味－妞妞蒟蒻紅豆粉粿
# 愛之味－妞妞蒟蒻紅豆粉粿
# 詠晟蛋糕實業有限公司
# 詠晟蛋糕實業有限公司
# 大澤壽喜燒燒肉(大澤店)
# 大澤壽喜燒燒肉(大澤店)
# 瑪莉精緻點心
# 瑪莉精緻點心
# 全家便利商店
# 全家便利商店
# 高雄曾記巧口滷味
# 高雄曾記巧口滷味
# 紅龍雞腿排
# 紅龍雞腿排
# 大庭素食(原：安和小館)
# 大庭素食(原：安和小館)
# 吼牛排
# 吼牛排
# 烘培媽媽
# 烘培媽媽
# 澤本壽司
# 澤本壽司
# 香草氣球 Vanilla Balloon之起司檸檬派
# 香草氣球 Vanilla Balloon之起司檸檬派
# 辣媽燒烤
# 辣媽燒烤
# 一桶鮮
# 一桶鮮
# 川食真四川麻辣火鍋
# 川食真四川麻辣火鍋
# 民安街口無名牛舌餅
# 民安街口無名牛舌餅
# 1/2 Sofa 星空餐廳
# 1/2 Sofa 星空餐廳
# 百八魚場(士林店)
# 百八魚場(士林店)
# 北芳金贊麵食館
# 北芳金贊麵食館
# 日本小吃
# 日本小吃
# 溫記豆花
# 溫記豆花
# 一鍋饗涮鮮涮
# 一鍋饗涮鮮涮
# 丸子手工坊-桂花醉雞
# 丸子手工坊-桂花醉雞
# Let's Six六吋蛋糕專店
# Let's Six六吋蛋糕專店
# 黑米CAFÉ BISTRO
# 黑米CAFÉ BISTRO
# 曾記餡餅
# 曾記餡餅
# 百胜廚 新加坡咖哩
# 百胜廚 新加坡咖哩
# 酥炸魷魚
# 酥炸魷魚
# Ms. Jennifer's 25.27 Cafe'
# Ms. Jennifer's 25.27 Cafe'
# 北方大陸餅(辛亥路店)
# 北方大陸餅(辛亥路店)
# 德川新日式料理
# 德川新日式料理
# 好味屋餐廳
# 好味屋餐廳
# 漢景設計中心-窯咖啡
# 漢景設計中心-窯咖啡
# BALLADE咖啡敘事曲
# BALLADE咖啡敘事曲
# Best Roti Coffee Bun(龍山店)
# Best Roti Coffee Bun(龍山店)
# 太元日本料理店
# 太元日本料理店
# Starbucks Coffee 統一星巴克(東門門市)
# Starbucks Coffee 統一星巴克(東門門市)
# 好口味小吃店
# 好口味小吃店
# 艾瑞兒義式鮮奶酪
# 艾瑞兒義式鮮奶酪
# 古早味
# 古早味
# 布袋鮮蚵
# 布袋鮮蚵
# 印度風
# 印度風
# Louvier 法式西點
# Louvier 法式西點
# 糯米炸
# 糯米炸
# 聖保羅烘焙花園
# 聖保羅烘焙花園
# 阿賢麵館(台糖店)
# 阿賢麵館(台糖店)
# 林家豬腸冬粉
# 林家豬腸冬粉
# 小珍園拉麵(撫順店)
# 小珍園拉麵(撫順店)
# 來福海鮮餐廳
# 來福海鮮餐廳
# Fleur Lis 芙洛麗大飯店--ocean bar
# Fleur Lis 芙洛麗大飯店--ocean bar
# 蔬店
# 蔬店
# 檜溪彰化肉圓
# 檜溪彰化肉圓
# NU PASTA(台南崇德店)
# NU PASTA(台南崇德店)
# 傳鮮網路生鮮宅配
# 傳鮮網路生鮮宅配
# 天山豆花芋圓(民雄總店)
# 天山豆花芋圓(民雄總店)
# 金豐八寶冬粉
# 金豐八寶冬粉
# 脆皮鮮奶甜甜圈
# 脆皮鮮奶甜甜圈
# 百年傳奇
# 百年傳奇
# PLAN B Café
# PLAN B Café
# 萬歲牌麻辣腰果
# 萬歲牌麻辣腰果
# 機場手工蛋捲
# 機場手工蛋捲
# PASTA 達人料理廚房(光復店)
# PASTA 達人料理廚房(光復店)
# 城市咖啡
# 城市咖啡
# Starbucks Coffee 統一星巴克(北醫門市)
# Starbucks Coffee 統一星巴克(北醫門市)
# 老拓
# 老拓
# 萬春小龍
# 萬春小龍
# 牛蛙遇上蝦
# 牛蛙遇上蝦
# 源士林粥品
# 源士林粥品
# 凱旋加油讚
# 凱旋加油讚
# 小雞客棧鬆餅
# 小雞客棧鬆餅
# 鬼屋咖啡
# 鬼屋咖啡
# 凱米比利時列日鬆餅專賣店
# 凱米比利時列日鬆餅專賣店
# 榮飛正宗蒙古麻辣鍋
# 榮飛正宗蒙古麻辣鍋
# 便宜坊北平烤鴨
# 便宜坊北平烤鴨
# Cafe' la moon
# Cafe' la moon
# 羅記民雄肉包
# 羅記民雄肉包
# 阿星鹹粥
# 阿星鹹粥
# 艾莉斯藝術精緻餐坊
# 艾莉斯藝術精緻餐坊
# 【Cakeone 1號蛋糕】輕乳酪蛋糕
# 【Cakeone 1號蛋糕】輕乳酪蛋糕
# 手在披薩 Hand on the pizza
# 手在披薩 Hand on the pizza
# PAN手感的店
# PAN手感的店
# PRONTO PASTA CAFE 波拉諾義麵咖啡坊
# PRONTO PASTA CAFE 波拉諾義麵咖啡坊
# 和美圓環素食麵
# 和美圓環素食麵
# 江豪記臭豆腐王
# 江豪記臭豆腐王
# 九鱻奶油酥條
# 九鱻奶油酥條
# 2派克脆皮雞排
# 2派克脆皮雞排
# 石神養生石頭火鍋
# 石神養生石頭火鍋
# 太將鍋
# 太將鍋
# 大手燒(新光小西門)
# 大手燒(新光小西門)
# 佳福雞肉飯
# 佳福雞肉飯
# 月亮奇司起司烘焙專賣店(台南店)
# 月亮奇司起司烘焙專賣店(台南店)
# 元記小舖
# 元記小舖
# Picturesque 塗鴉空間書店
# Picturesque 塗鴉空間書店
# 古早味這一家糯米炸
# 古早味這一家糯米炸
# Charco house手作廚房
# Charco house手作廚房
# 吉圓品伴手禮鮮餅鋪
# 吉圓品伴手禮鮮餅鋪
# 愛維根素食餐廳(新店店)
# 愛維根素食餐廳(新店店)
# Dining Room
# Dining Room
# 阿明師老店太陽堂
# 阿明師老店太陽堂
# 總督西餐廳
# 總督西餐廳
# 蔥油餅
# 蔥油餅
# 摩多居酒屋
# 摩多居酒屋
# YOZAI悠哉美健
# YOZAI悠哉美健
# Q丸 QMaru和洋食堂(台北站前店)
# Q丸 QMaru和洋食堂(台北站前店)
# 台糖台北會館-甜心餐廳
# 台糖台北會館-甜心餐廳
# 大娘羹大王
# 大娘羹大王
# O2 BRUNCH & CAFE 歐圖咖啡廚房
# O2 BRUNCH & CAFE 歐圖咖啡廚房
# Tudo bom
# Tudo bom
# 台南意麵
# 台南意麵
# 卡迪納超濃起司
# 卡迪納超濃起司
# 神座日本拉麵(至聖巨蛋店)
# 神座日本拉麵(至聖巨蛋店)
# 鎌奈鍋(站前店)
# 鎌奈鍋(站前店)
# Tina廚房(大溪店)
# Tina廚房(大溪店)
# 南客仙草原汁
# 南客仙草原汁
# 古媽炒飯
# 古媽炒飯
# 無双串燒居酒屋
# 無双串燒居酒屋
# 禾丰烤炭火燒肉
# 禾丰烤炭火燒肉
# 建誼滷味
# 建誼滷味
# 儂may泰國料理
# 儂may泰國料理
# 文岩文岩燒蜀辣鴛鴦鍋
# 文岩文岩燒蜀辣鴛鴦鍋
# 正宗古早味粉圓
# 正宗古早味粉圓
# 仁川韓國炸雞
# 仁川韓國炸雞
# 歐若拉義式小廚
# 歐若拉義式小廚
# 台南無刺虱目魚粥
# 台南無刺虱目魚粥
# 蔥蔬餅
# 蔥蔬餅
# 甲量古早味枝仔冰
# 甲量古早味枝仔冰
# OPPA! 韓式炸雞
# OPPA! 韓式炸雞
# 建弘雞肉飯
# 建弘雞肉飯
# 大可茶樓
# 大可茶樓
# 惠家蔥油餅
# 惠家蔥油餅
# 波天久BOTEJYU元祖摩登燒(京站時尚廣場店)
# 波天久BOTEJYU元祖摩登燒(京站時尚廣場店)
# 太鮮屋
# 太鮮屋
# 延三飯糰蛋餅早餐
# 延三飯糰蛋餅早餐
# 大漢草原新疆羊肉串
# 大漢草原新疆羊肉串
# 騎士布朗尼
# 騎士布朗尼
# 中華一餅(北車微風店)
# 中華一餅(北車微風店)
# 天使美手作甜點
# 天使美手作甜點
# 林家麵館
# 林家麵館
# 陶米納生活咖啡簡餐
# 陶米納生活咖啡簡餐
# 大東北韭菜盒子
# 大東北韭菜盒子
# 韓國先生(OBBA店)
# 韓國先生(OBBA店)
# 黃媽媽麵店
# 黃媽媽麵店
# 胡椒餅
# 胡椒餅
# 九御亭泰式料理
# 九御亭泰式料理
# 定食8 爭鮮餐飲
# 定食8 爭鮮餐飲
# 江媽媽香酥雞
# 江媽媽香酥雞
# 林娘炸醬麵
# 林娘炸醬麵
# 光泉 果茶物語
# 光泉 果茶物語
# 莎嗑蘭女士 Lady Succulents
# 莎嗑蘭女士 Lady Succulents
# 紅豆餅
# 紅豆餅
# 樂田麵包屋(長庚店)
# 樂田麵包屋(長庚店)
# 桔士廚房
# 桔士廚房
# 瘋kara
# 瘋kara
# 知點新時尚料理餐廳
# 知點新時尚料理餐廳
# 樂丘廚房 Leo Chiu
# 樂丘廚房 Leo Chiu
# Yellow Lemon 黃檸檬
# Yellow Lemon 黃檸檬
# 均鎂糕餅公司
# 均鎂糕餅公司
# 頂盛牛老媽
# 頂盛牛老媽
# RÊVE Café 黑浮咖啡
# RÊVE Café 黑浮咖啡
# 晶圓包心粉圓
# 晶圓包心粉圓
# 福樂自然零青木瓜優酪(零脂鮮奶優酪 )
# 福樂自然零青木瓜優酪(零脂鮮奶優酪 )
# 協力旺雞排(東海店)
# 協力旺雞排(東海店)
# 一品滷味(建興店)
# 一品滷味(建興店)
# 柴窯火腿製造所
# 柴窯火腿製造所
# 36號轉角咖啡
# 36號轉角咖啡
# choco choco手工巧克力
# choco choco手工巧克力
# 北投紅茶冰
# 北投紅茶冰
# 竹南布洛瓦烘焙餐坊(酒酷)
# 竹南布洛瓦烘焙餐坊(酒酷)
# 松竹涮涮鍋
# 松竹涮涮鍋
# 巧佳涼麵
# 巧佳涼麵
# Gelateria Cosi O Cosi 闊喜窩
# Gelateria Cosi O Cosi 闊喜窩
# 豬血湯
# 豬血湯
# 竹屋休閒農莊
# 竹屋休閒農莊
# 天然葉
# 天然葉
# 麵黨 現桿刀切麵
# 麵黨 現桿刀切麵
# 私房小廚
# 私房小廚
# 木匠手作(輔大店)
# 木匠手作(輔大店)
# Buono Pizza布諾手工窯烤披薩
# Buono Pizza布諾手工窯烤披薩
# 阿月紅茶冰
# 阿月紅茶冰
# 圓石禪飲
# 圓石禪飲
# 詠茶
# 詠茶
# 屏東郭家碗粿
# 屏東郭家碗粿
# 泰式雲南小吃
# 泰式雲南小吃
# 鮮道鍋日式涮涮鍋(承德店)
# 鮮道鍋日式涮涮鍋(承德店)
# OKey Dokey
# OKey Dokey
# 7-11花生米漿
# 7-11花生米漿
# 橋壽司
# 橋壽司
# 翅包飯雞翅包炒飯(凱旋夜市店)
# 翅包飯雞翅包炒飯(凱旋夜市店)
# 世欣甲仙芋頭冰
# 世欣甲仙芋頭冰
# 多那之(鳳山青年門市)
# 多那之(鳳山青年門市)
# 好吃雞肉飯
# 好吃雞肉飯
# 鍋醬平價小火鍋
# 鍋醬平價小火鍋
# 芝香涼麵
# 芝香涼麵
# Le petit pâtissier 雷斯理
# Le petit pâtissier 雷斯理
# 小鬆鼠cafe
# 小鬆鼠cafe
# 燒仙草
# 燒仙草
# 番仔明古早味什菜
# 番仔明古早味什菜
# 斜角巷(Big City遠東巨城購物中心)
# 斜角巷(Big City遠東巨城購物中心)
# 維尼造型手工餅乾屋
# 維尼造型手工餅乾屋
# 大王麻辣乾麵
# 大王麻辣乾麵
# 好了啦紅茶冰
# 好了啦紅茶冰
# 明佳真味涮涮鍋~阿剛湯頭(景美店)
# 明佳真味涮涮鍋~阿剛湯頭(景美店)
# 水澤鮮活調飲(宜蘭站前店)
# 水澤鮮活調飲(宜蘭站前店)
# 台南米糕
# 台南米糕
# 丸八酢飯店
# 丸八酢飯店
# 幸福廚房
# 幸福廚房
# 阿根廷金蕉異國料理
# 阿根廷金蕉異國料理
# 鮮味香蚌麵(台北誠品信義店)
# 鮮味香蚌麵(台北誠品信義店)
# 嘉昌雞肉飯
# 嘉昌雞肉飯
# 米亞蜜現烤蛋糕
# 米亞蜜現烤蛋糕
# 焦糖牛奶軟法
# 焦糖牛奶軟法
# 高品味無煙串烤
# 高品味無煙串烤
# Kaffa咖法義式廚房
# Kaffa咖法義式廚房
# 太將鍋日式涮涮鍋(內湖江南店)
# 太將鍋日式涮涮鍋(內湖江南店)
# 怡客咖啡 Ikari Coffee
# 怡客咖啡 Ikari Coffee
# 品嚐生活咖啡館 C'est La Vie
# 品嚐生活咖啡館 C'est La Vie
# 越南河粉
# 越南河粉
# 藝人塘 ‧ 薏仁豬腳
# 藝人塘 ‧ 薏仁豬腳
# 台中大莊園尾牙餐聽
# 台中大莊園尾牙餐聽
# 蔥花千層大餅
# 蔥花千層大餅
# 鬼椒一番鍋 竹北店
# 鬼椒一番鍋 竹北店
# 涓豆腐(台南)
# 涓豆腐(台南)
# 豆豆天冰
# 豆豆天冰
# 舞尼棉花冰(瑞豐店)
# 舞尼棉花冰(瑞豐店)
# 兔子兔子 Rabbit Rabbit
# 兔子兔子 Rabbit Rabbit
# 太祖魷魚羹
# 太祖魷魚羹
# 阿Q粉圓(世貿店)
# 阿Q粉圓(世貿店)
# 八野爺土鳳梨酥
# 八野爺土鳳梨酥
# 咖啡深藏(五甲門市)
# 咖啡深藏(五甲門市)
# NEWTON'S 優格 輕食 冰淇淋
# NEWTON'S 優格 輕食 冰淇淋
# 金格食品(三重店)
# 金格食品(三重店)

# %%
import os
import json
import pprint
if os.path.exists('./data/diendata2.json'):
    with open("./data/diendata2.json","r") as d:
        dienlist=json.load(d)
        n=len(dienlist)
n
pprint.pprint(dienlist)
# Out:
# [{'Ncomment': 0,
#   'address': '台東縣台東市安慶街16號',
#   'averagecost': 0,
#   'bigstyle': '咖啡、簡餐、茶',
#   'collecount': 0,
#   'comments': [],
#   'id': 10,
#   'ipeenscore': 0,
#   'lat': 22.749409424335585,
#   'lng': 121.14442065867614,
#   'name': '蔡文益',
#   'reviewdate': '2006/12/13',
#   'smallstyle': '咖啡專賣',
#   'status': '正常營業',
#   'tele': '089325593',
#   'url': 'http://www.ipeen.com.tw/shop/10',
#   'viewcount': 5391},
#  {'Ncomment': 0,
#   'address': 0,
#   'averagecost': 0,
#   'bigstyle': '咖啡、簡餐、茶',
#   'collecount': 1,
#   'comments': [],
#   'id': 100,
#   'ipeenscore': 0,
#   'lat': 24.984029968789226,
#   'lng': 121.95639507263282,
#   'name': '擁舞湛藍',
#   'reviewdate': '2006/12/13',
#   'smallstyle': '咖啡專賣',
#   'status': '正常營業',
#   'tele': '039780920',
#   'url': 'http://www.ipeen.com.tw/shop/100',
#   'viewcount': 4461},
#  {'Ncomment': 0,
#   'address': '台北市松山區敦化北路244巷34號',
#   'averagecost': 0,
#   'bigstyle': '鍋類',
#   'collecount': 0,
#   'comments': [],
#   'id': 10000,
#   'ipeenscore': 0,
#   'lat': 25.060937124634002,
#   'lng': 121.54777199532225,
#   'name': '京都日式涮涮鍋',
#   'reviewdate': '2016/03/27',
#   'smallstyle': '涮涮鍋',
#   'status': '結束營業',
#   'tele': 0,
#   'url': 'http://www.ipeen.com.tw/shop/10000',
#   'viewcount': 3491},
#  {'Ncomment': 0,
#   'address': '台南市新營區健康路251號',
#   'averagecost': 0,
#   'bigstyle': '速食料理',
#   'collecount': 0,
#   'comments': [],
#   'id': 100000,
#   'ipeenscore': 0,
#   'lat': 23.319379010490003,
#   'lng': 120.31197500804001,
#   'name': '麥當勞(新營家樂福店)',
#   'reviewdate': '2011/07/14',
#   'smallstyle': '漢堡、炸雞',
#   'status': '正常營業',
#   'tele': '066571158',
#   'url': 'http://www.ipeen.com.tw/shop/100000',
#   'viewcount': 2949},
#  {'Ncomment': 5,
#   'address': '台北市大安區信義路三段166巷2號',
#   'averagecost': 383,
#   'bigstyle': '燒烤類',
#   'collecount': 19,
#   'comments': ['http://www.ipeen.com.tw/comment/1024552',
#                'http://www.ipeen.com.tw/comment/996750',
#                'http://www.ipeen.com.tw/comment/982096',
#                'http://www.ipeen.com.tw/comment/960782',
#                'http://www.ipeen.com.tw/comment/866316'],
#   'id': 1000010,
#   'ipeenscore': 45,
#   'lat': 25.03301900787,
#   'lng': 121.54191500375,
#   'name': '岩谷新鐵板料理Rock Valley(台北信義總店)',
#   'reviewdate': '2017/08/23',
#   'smallstyle': '鐵板燒',
#   'status': '正常營業',
#   'tele': '0227071968',
#   'url': 'http://www.ipeen.com.tw/shop/1000010',
#   'viewcount': 12926},
#  {'Ncomment': 0,
#   'address': '台南市佳里區延平路380號',
#   'averagecost': 30,
#   'bigstyle': '中式料理',
#   'collecount': 1,
#   'comments': [],
#   'id': 1000014,
#   'ipeenscore': 35,
#   'lat': 23.16267400948,
#   'lng': 120.17833900001,
#   'name': '朱員外拉麵店(台南佳里鎮)',
#   'reviewdate': '2015/12/08',
#   'smallstyle': '麵食點心',
#   'status': '正常營業',
#   'tele': '067211329',
#   'url': 'http://www.ipeen.com.tw/shop/1000014',
#   'viewcount': 3594},
#  {'Ncomment': 0,
#   'address': '新北市板橋區文化路一段360號',
#   'averagecost': 155,
#   'bigstyle': '咖啡、簡餐、茶',
#   'collecount': 0,
#   'comments': [],
#   'id': 1000016,
#   'ipeenscore': 40,
#   'lat': 25.023534008370003,
#   'lng': 121.46863500736,
#   'name': 'Starbucks Coffee 統一星巴克',
#   'reviewdate': '2016/04/04',
#   'smallstyle': '咖啡專賣',
#   'status': '正常營業',
#   'tele': 0,
#   'url': 'http://www.ipeen.com.tw/shop/1000016',
#   'viewcount': 2046},
#  {'Ncomment': 3,
#   'address': '台北市內湖區內湖路一段689-1號',
#   'averagecost': 314,
#   'bigstyle': '日式料理',
#   'collecount': 29,
#   'comments': ['http://www.ipeen.com.tw/comment/1099586',
#                'http://www.ipeen.com.tw/comment/826808',
#                'http://www.ipeen.com.tw/comment/799874'],
#   'id': 1000022,
#   'ipeenscore': 45,
#   'lat': 25.08003220642,
#   'lng': 121.57675520955,
#   'name': '阿宏日式料理',
#   'reviewdate': '2015/01/23',
#   'smallstyle': '生魚片、壽司專賣',
#   'status': '正常營業',
#   'tele': 0,
#   'url': 'http://www.ipeen.com.tw/shop/1000022',
#   'viewcount': 6083},
#  {'Ncomment': 1,
#   'address': '屏東縣屏東市民生路2-12號',
#   'averagecost': 0,
#   'bigstyle': '早餐',
#   'collecount': 7,
#   'comments': ['http://www.ipeen.com.tw/comment/799898'],
#   'id': 1000032,
#   'ipeenscore': 40,
#   'lat': 22.667284003579997,
#   'lng': 120.4987000195,
#   'name': '城香角落香草早午餐',
#   'reviewdate': '2015/01/23',
#   'smallstyle': '西式早餐',
#   'status': '正常營業',
#   'tele': '087216769',
#   'url': 'http://www.ipeen.com.tw/shop/1000032',
#   'viewcount': 4769},
#  {'Ncomment': 0,
#   'address': '台中市神岡區中山路842-1號',
#   'averagecost': 0,
#   'bigstyle': '鍋類',
#   'collecount': 0,
#   'comments': [],
#   'id': 1000034,
#   'ipeenscore': 0,
#   'lat': 24.24992000637,
#   'lng': 120.67820141942,
#   'name': '讚不絕口(神岡社口店)',
#   'reviewdate': '2015/01/23',
#   'smallstyle': '其他鍋類',
#   'status': '正常營業',
#   'tele': '0425624001',
#   'url': 'http://www.ipeen.com.tw/shop/1000034',
#   'viewcount': 2287},
#  {'Ncomment': 2,
#   'address': '台中市南屯區文心南一路62-1號',
#   'averagecost': 0,
#   'bigstyle': '異國料理',
#   'collecount': 2,
#   'comments': ['http://www.ipeen.com.tw/comment/823424',
#                'http://www.ipeen.com.tw/comment/799900'],
#   'id': 1000036,
#   'ipeenscore': 45,
#   'lat': 24.13717430887,
#   'lng': 120.6442107136,
#   'name': 'NU PASTA(台中向心店)',
#   'reviewdate': '2016/04/03',
#   'smallstyle': '義式料理',
#   'status': '正常營業',
#   'tele': '0424737440',
#   'url': 'http://www.ipeen.com.tw/shop/1000036',
#   'viewcount': 4106},
#  {'Ncomment': 0,
#   'address': '台中市豐原區成功路193號',
#   'averagecost': 0,
#   'bigstyle': '鍋類',
#   'collecount': 0,
#   'comments': [],
#   'id': 1000038,
#   'ipeenscore': 0,
#   'lat': 24.2512090112,
#   'lng': 120.70649400356001,
#   'name': '讚不絕口(豐原成功店)',
#   'reviewdate': '2015/01/23',
#   'smallstyle': '其他鍋類',
#   'status': '正常營業',
#   'tele': '0982991478',
#   'url': 'http://www.ipeen.com.tw/shop/1000038',
#   'viewcount': 2746},
#  {'Ncomment': 0,
#   'address': '台中市豐原區南陽路232號',
#   'averagecost': 0,
#   'bigstyle': '鍋類',
#   'collecount': 0,
#   'comments': [],
#   'id': 1000040,
#   'ipeenscore': 0,
#   'lat': 24.24550701298,
#   'lng': 120.72717600532,
#   'name': '讚不絕口小火鍋(豐原南陽旗艦店)',
#   'reviewdate': '2015/01/23',
#   'smallstyle': '其他鍋類',
#   'status': '正常營業',
#   'tele': '0425235358',
#   'url': 'http://www.ipeen.com.tw/shop/1000040',
#   'viewcount': 3742},
#  {'Ncomment': 6,
#   'address': '新北市板橋區文化路二段357號',
#   'averagecost': 562,
#   'bigstyle': '燒烤類',
#   'collecount': 42,
#   'comments': ['http://www.ipeen.com.tw/comment/812126',
#                'http://www.ipeen.com.tw/comment/800372',
#                'http://www.ipeen.com.tw/comment/800286',
#                'http://www.ipeen.com.tw/comment/920230',
#                'http://www.ipeen.com.tw/comment/917738',
#                'http://www.ipeen.com.tw/comment/885444'],
#   'id': 1000042,
#   'ipeenscore': 45,
#   'lat': 25.03079640581,
#   'lng': 121.47286930895,
#   'name': '9%酒趴串燒Bar',
#   'reviewdate': '2016/04/05',
#   'smallstyle': '炭烤串燒',
#   'status': '正常營業',
#   'tele': 0,
#   'url': 'http://www.ipeen.com.tw/shop/1000042',
#   'viewcount': 17839},
#  {'Ncomment': 1,
#   'address': 0,
#   'averagecost': 40,
#   'bigstyle': '小吃',
#   'collecount': 2,
#   'comments': ['http://www.ipeen.com.tw/comment/799976'],
#   'id': 1000048,
#   'ipeenscore': 45,
#   'lat': 22.66771821809,
#   'lng': 120.29917430743001,
#   'name': '排灣族美食',
#   'reviewdate': '2016/06/04',
#   'smallstyle': '其他小吃',
#   'status': '正常營業',
#   'tele': 0,
#   'url': 'http://www.ipeen.com.tw/shop/1000048',
#   'viewcount': 10831},
#  {'Ncomment': 0,
#   'address': '新北市烏來區溪羅岸路46號',
#   'averagecost': 0,
#   'bigstyle': '其他美食',
#   'collecount': 0,
#   'comments': [],
#   'id': 1000052,
#   'ipeenscore': 0,
#   'lat': 24.86637210344,
#   'lng': 121.54978010867,
#   'name': '土雞王',
#   'reviewdate': '2015/01/27',
#   'smallstyle': '其他美食',
#   'status': '正常營業',
#   'tele': '0916608571',
#   'url': 'http://www.ipeen.com.tw/shop/1000052',
#   'viewcount': 745},
#  {'Ncomment': 0,
#   'address': 0,
#   'averagecost': 0,
#   'bigstyle': '冰品、飲料、甜湯',
#   'collecount': 1,
#   'comments': [],
#   'id': 1000066,
#   'ipeenscore': 0,
#   'lat': 23.966432913560002,
#   'lng': 120.96818701459,
#   'name': '嘟嘟冷熱冰',
#   'reviewdate': '2016/01/28',
#   'smallstyle': '剉冰、豆花',
#   'status': '正常營業',
#   'tele': '0492900299',
#   'url': 'http://www.ipeen.com.tw/shop/1000066',
#   'viewcount': 826},
#  {'Ncomment': 0,
#   'address': 0,
#   'averagecost': 0,
#   'bigstyle': '冰品、飲料、甜湯',
#   'collecount': 0,
#   'comments': [],
#   'id': 1000068,
#   'ipeenscore': 0,
#   'lat': 23.96643291955,
#   'lng': 120.96818700405,
#   'name': '包心粉圓 埔里點',
#   'reviewdate': '2016/01/28',
#   'smallstyle': '甜品、甜湯',
#   'status': '正常營業',
#   'tele': '0921706833',
#   'url': 'http://www.ipeen.com.tw/shop/1000068',
#   'viewcount': 928},
#  {'Ncomment': 1,
#   'address': 0,
#   'averagecost': 80,
#   'bigstyle': '小吃',
#   'collecount': 4,
#   'comments': ['http://www.ipeen.com.tw/comment/800504'],
#   'id': 1000070,
#   'ipeenscore': 40,
#   'lat': 24.17745130942,
#   'lng': 120.64515290562,
#   'name': '橋頭香菇油飯',
#   'reviewdate': '2016/01/28',
#   'smallstyle': '其他小吃',
#   'status': '正常營業',
#   'tele': 0,
#   'url': 'http://www.ipeen.com.tw/shop/1000070',
#   'viewcount': 6880},
#  {'Ncomment': 1,
#   'address': '台中市梧棲區中央路一段681號',
#   'averagecost': 110,
#   'bigstyle': '中式料理',
#   'collecount': 5,
#   'comments': ['http://www.ipeen.com.tw/comment/800042'],
#   'id': 1000074,
#   'ipeenscore': 45,
#   'lat': 24.24537030303,
#   'lng': 120.53754541026,
#   'name': '清水王牌-筒仔米糕',
#   'reviewdate': '2015/01/24',
#   'smallstyle': '其它中式料理',
#   'status': '正常營業',
#   'tele': '0426579768',
#   'url': 'http://www.ipeen.com.tw/shop/1000074',
#   'viewcount': 4369},
#  {'Ncomment': 21,
#   'address': '台北市大安區四維路14巷6-1號',
#   'averagecost': 933,
#   'bigstyle': '異國料理',
#   'collecount': 301,
#   'comments': ['http://www.ipeen.com.tw/comment/1377797',
#                'http://www.ipeen.com.tw/comment/1020088',
#                'http://www.ipeen.com.tw/comment/1007106',
#                'http://www.ipeen.com.tw/comment/971440',
#                'http://www.ipeen.com.tw/comment/940316',
#                'http://www.ipeen.com.tw/comment/910954',
#                'http://www.ipeen.com.tw/comment/893198',
#                'http://www.ipeen.com.tw/comment/883792',
#                'http://www.ipeen.com.tw/comment/875878',
#                'http://www.ipeen.com.tw/comment/830804',
#                'http://www.ipeen.com.tw/comment/824356',
#                'http://www.ipeen.com.tw/comment/824188',
#                'http://www.ipeen.com.tw/comment/812266',
#                'http://www.ipeen.com.tw/comment/1298633',
#                'http://www.ipeen.com.tw/comment/1278530',
#                'http://www.ipeen.com.tw/comment/1205741',
#                'http://www.ipeen.com.tw/comment/1030142',
#                'http://www.ipeen.com.tw/comment/918670',
#                'http://www.ipeen.com.tw/comment/910096',
#                'http://www.ipeen.com.tw/comment/810766',
#                'http://www.ipeen.com.tw/comment/807408'],
#   'id': 1000080,
#   'ipeenscore': 45,
#   'lat': 25.03678902433351,
#   'lng': 121.54740865359874,
#   'name': '凱恩斯岩燒餐廳(台北大安店)',
#   'reviewdate': '2015/03/02',
#   'smallstyle': '美式料理',
#   'status': '正常營業',
#   'tele': '0227018513',
#   'url': 'http://www.ipeen.com.tw/shop/1000080',
#   'viewcount': 1134186},
#  {'Ncomment': 3,
#   'address': '台北市松山區南京東路五段154-156號',
#   'averagecost': 793,
#   'bigstyle': '中式料理',
#   'collecount': 31,
#   'comments': ['http://www.ipeen.com.tw/comment/1325012',
#                'http://www.ipeen.com.tw/comment/800148',
#                'http://www.ipeen.com.tw/comment/930964'],
#   'id': 1000082,
#   'ipeenscore': 45,
#   'lat': 25.05145810495,
#   'lng': 121.56506021768,
#   'name': '鳥窩窩私房菜(南京店)',
#   'reviewdate': '2016/04/05',
#   'smallstyle': '其它中式料理',
#   'status': '正常營業',
#   'tele': '0227460788',
#   'url': 'http://www.ipeen.com.tw/shop/1000082',
#   'viewcount': 13556},
#  {'Ncomment': 0,
#   'address': '高雄市鳳山區平等路47號',
#   'averagecost': 0,
#   'bigstyle': '小吃',
#   'collecount': 1,
#   'comments': [],
#   'id': 1000084,
#   'ipeenscore': 40,
#   'lat': 22.62454400375,
#   'lng': 120.35237601172005,
#   'name': '池鳳山手工包子饅頭',
#   'reviewdate': '2015/01/24',
#   'smallstyle': '其他小吃',
#   'status': '正常營業',
#   'tele': '077108910',
#   'url': 'http://www.ipeen.com.tw/shop/1000084',
#   'viewcount': 2263},
#  {'Ncomment': 1,
#   'address': '桃園市龍潭區五福街193號',
#   'averagecost': 320,
#   'bigstyle': '主題特色餐廳',
#   'collecount': 1,
#   'comments': ['http://www.ipeen.com.tw/comment/979930'],
#   'id': 1000086,
#   'ipeenscore': 40,
#   'lat': 24.86523300664,
#   'lng': 121.22198600358,
#   'name': '寒舍客家原風人文餐館',
#   'reviewdate': '2015/01/24',
#   'smallstyle': '懷舊主題',
#   'status': '正常營業',
#   'tele': '034707311',
#   'url': 'http://www.ipeen.com.tw/shop/1000086',
#   'viewcount': 9187},
#  {'Ncomment': 0,
#   'address': 0,
#   'averagecost': 0,
#   'bigstyle': '小吃',
#   'collecount': 3,
#   'comments': [],
#   'id': 1000088,
#   'ipeenscore': 45,
#   'lat': 23.96305301239,
#   'lng': 120.56877900246,
#   'name': '梁媽媽麵線糊',
#   'reviewdate': '2016/04/05',
#   'smallstyle': '麵線',
#   'status': '正常營業',
#   'tele': '0911093312',
#   'url': 'http://www.ipeen.com.tw/shop/1000088',
#   'viewcount': 2150},
#  {'Ncomment': 0,
#   'address': '新北市永和區得和路111號',
#   'averagecost': 65,
#   'bigstyle': '小吃',
#   'collecount': 2,
#   'comments': [],
#   'id': 1000094,
#   'ipeenscore': 45,
#   'lat': 25.000115007850003,
#   'lng': 121.51873801502,
#   'name': '滿溢肉焿',
#   'reviewdate': '2016/01/28',
#   'smallstyle': '滷肉飯',
#   'status': '正常營業',
#   'tele': '0229207535',
#   'url': 'http://www.ipeen.com.tw/shop/1000094',
#   'viewcount': 2222},
#  {'Ncomment': 0,
#   'address': 0,
#   'averagecost': 0,
#   'bigstyle': '日式料理',
#   'collecount': 0,
#   'comments': [],
#   'id': 1000096,
#   'ipeenscore': 0,
#   'lat': 23.9781614073,
#   'lng': 121.60679711416999,
#   'name': '本壽司料理亭',
#   'reviewdate': '2015/01/24',
#   'smallstyle': '綜合日式料理',
#   'status': '正常營業',
#   'tele': '038321328',
#   'url': 'http://www.ipeen.com.tw/shop/1000096',
#   'viewcount': 979},
#  {'Ncomment': 10,
#   'address': '台南市東區中華東路一段366號',
#   'averagecost': 257,
#   'bigstyle': '日式料理',
#   'collecount': 5,
#   'comments': ['http://www.ipeen.com.tw/comment/1059104',
#                'http://www.ipeen.com.tw/comment/900118',
#                'http://www.ipeen.com.tw/comment/858360',
#                'http://www.ipeen.com.tw/comment/830110',
#                'http://www.ipeen.com.tw/comment/1276352',
#                'http://www.ipeen.com.tw/comment/1030516',
#                'http://www.ipeen.com.tw/comment/917144',
#                'http://www.ipeen.com.tw/comment/851476',
#                'http://www.ipeen.com.tw/comment/812674',
#                'http://www.ipeen.com.tw/comment/800196'],
#   'id': 1000098,
#   'ipeenscore': 40,
#   'lat': 22.98912820806,
#   'lng': 120.23305821399,
#   'name': '三田製麵所(南紡夢時代店)',
#   'reviewdate': '2016/01/28',
#   'smallstyle': '日式麵食專賣',
#   'status': '正常營業',
#   'tele': 0,
#   'url': 'http://www.ipeen.com.tw/shop/1000098',
#   'viewcount': 9124},
#  {'Ncomment': 0,
#   'address': '台北市大安區復興南路二段148巷37號',
#   'averagecost': 0,
#   'bigstyle': '鍋類',
#   'collecount': 0,
#   'comments': [],
#   'id': 10001,
#   'ipeenscore': 0,
#   'lat': 25.028370323872807,
#   'lng': 121.54167494046881,
#   'name': '大將涮涮鍋',
#   'reviewdate': '2011/11/22',
#   'smallstyle': '涮涮鍋',
#   'status': '結束營業',
#   'tele': 0,
#   'url': 'http://www.ipeen.com.tw/shop/10001',
#   'viewcount': 6596}]

# %% [markdown]
# # list(dict,dict)去重

# %%
from functools import reduce
# a=[{"a":3,"vv":1},{"a":3,"vv":1},{"a":2,"vv":4}] #測試用


f = lambda x,y:x if y in x else x + [y]
dienlist = reduce(f, [[], ] + dienlist)

print(len(dienlist))
with open("./data/diendata.json","w") as d:
    json.dump(dienlist,d)


# def reduce(function, iterable, initializer=None):
#     it = iter(iterable)
#     if initializer is None:
#         try:
#             initializer = next(it)
#         except StopIteration:
#             raise TypeError('reduce() of empty sequence with no initial value')
#     accum_value = initializer
#     for x in it:
#         accum_value = function(accum_value, x)
#     return accum_value
# Out:
# 45740

# %%
[[], ] + a
# Out:
# [[], {'a': 3, 'vv': 1}, {'a': 3, 'vv': 1}, {'a': 2, 'vv': 4}]

# %% [markdown]
# # bs抓取某tag or tag群的方法
# soup.select("tag > tag > tag") 如:soup.select("#search > article > hgroup > h2 > b")
#
# soup.find_all('tag', attrs={'tag內的元素': '元素名稱'}) 如:soup.find_all('a', attrs={'data-label': '店名'})

# %% [markdown]
# # 確認json是否可讀取的方法
# possible_json_string = '[{"a":3,"b":"2"},{"c":3.6,"d":""}]'
#
# print(None)
#
# print(possible_json_string)
#
# js = json.loads(possible_json_string)

# %%
with open("./data/diendata.json","r") as d:
    dienlist=json.load(d)

# %%
file
# Out:
# '86142.html'

# %%
if os.path.exists('./data/diendata.json'):
    with open("./data/diendata.json","r") as d:
        dienlist=json.load(d)
        n=len(dienlist)+1
        finishdien=set([dien['id'] for dien in dienlist])
len(finishdien)
# Out:
# 45739

# %%
al=[int(file.split(".")[0]) for file in os.listdir("./data/html2")]
len(al)
# Out:
# 47306

# %%
gap=[dien for dien in al if dien not in finishdien]
len(gap)
# Out:
# 2043
