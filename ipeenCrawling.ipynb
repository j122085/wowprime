# %%
import json
import os
import requests
from bs4 import BeautifulSoup as bs
import logging

# %% [markdown]
# # 待將set改成id 不抓取搬遷 抓取關店

# %%
if not os.path.exists('./data'):
    os.makedirs('./data')
URL="http://www.ipeen.com.tw/search/taiwan/000/1-100-0-0/?baragain=1"

res=requests.get(URL+"&p=1")
soup=bs(res.text,"lxml")
res.close()
page=int(soup.select("#search > article > hgroup > h2 > b")[0].text)//15
print(str(page)+"pages(all)")

#初始set、頁
WebsiteSet=set()
pagebegin=1

#如果已抓取，由中途開始繼續抓取 (抓取的資料set及頁面)
if os.path.exists('./data/WebsiteSet.json'):
    with open("./data/WebsiteSet.json") as f:
        x=json.load(f)
        WebsiteSet=set(x[dien]+"-"+dien for dien in x)
        pagebegin=int(len(WebsiteSet)/15)

if os.path.exists('./data/beginpage.txt'):
    with open("./data/beginpage.txt") as p:
        pagebegin=int(p.read())
        
print("開始頁%s"%pagebegin)
        
# headers = {"User-Agent":"Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/62.0.3202.94 Safari/537.36"}

#會累積的變數>>i WebsiteSet
for i in range(pagebegin,page+1):
    res=requests.get(URL+"&p="+str(i))
    if res.status_code==200:
        soup=bs(res.text,'lxml')
        dienlist=soup.select("article.serMain > div.result > section > article.serItem > div > h3")
        dienlist=[dien for dien in dienlist  if not dien.select_one("span.status")]#去除搬遷或關店狀態的店家
        dienlist=["http://www.ipeen.com.tw"+dien.select_one("a")["href"] for dien in dienlist 
                  if dien.select_one("a")["data-action"]!="ad_shop"]#去除廣告店家，並留下網址
        WebsiteSet.update(dienlist)
        if i%10==0:
            print("-----\n已抓取第%s頁"%i)
            print(len(WebsiteSet))
            websitedict={Website.split("-",1)[1]:Website.split("-",1)[0] for Website in WebsiteSet}
            print("實際剩餘%s，店名重複%s"%(len(websitedict),len(WebsiteSet)-len(websitedict)))
            with open("./data/WebsiteSet.json","w") as f:
                json.dump(websitedict,f)
            with open("./data/beginpage.txt","w") as p:
                p.write(str(i))
    else:
        print("status_code"+str(res.status_code))
        print(len(WebsiteSet))
        websitedict={Website.split("-",1)[1]:Website.split("-",1)[0] for Website in WebsiteSet}
        with open("./data/WebsiteSet.json","w") as f:
            json.dump(websitedict,f)
        with open("./data/beginpage.txt","w") as p:
            p.write(str(i))
            
websitedict={Website.split("-",1)[1]:Website.split("-",1)[0] for Website in WebsiteSet}
with open("./data/WebsiteSet.json","w") as f:
    json.dump(websitedict,f)
with open("./data/beginpage.txt","w") as p:
    p.write(str(i))
# Out:
# 11170pages(all)
# 開始頁6670
# -----
# 已抓取第6670頁
# 94131
# 實際剩餘94131，店名重複0
# -----
# 已抓取第6680頁
# 94281
# 實際剩餘94268，店名重複13
# -----
# 已抓取第6690頁
# 94431
# 實際剩餘94409，店名重複22
# -----
# 已抓取第6700頁
# 94581
# 實際剩餘94550，店名重複31
# -----
# 已抓取第6710頁
# 94731
# 實際剩餘94691，店名重複40
# -----
# 已抓取第6720頁
# 94881
# 實際剩餘94831，店名重複50
# -----
# 已抓取第6730頁
# 95031
# 實際剩餘94978，店名重複53
# -----
# 已抓取第6740頁
# 95181
# 實際剩餘95123，店名重複58
# -----
# 已抓取第6750頁
# 95331
# 實際剩餘95262，店名重複69
# -----
# 已抓取第6760頁
# 95481
# 實際剩餘95407，店名重複74
# -----
# 已抓取第6770頁
# 95631
# 實際剩餘95548，店名重複83
# -----
# 已抓取第6780頁
# 95781
# 實際剩餘95694，店名重複87
# -----
# 已抓取第6790頁
# 95931
# 實際剩餘95836，店名重複95
# -----
# 已抓取第6800頁
# 96081
# 實際剩餘95974，店名重複107
# -----
# 已抓取第6810頁
# 96231
# 實際剩餘96113，店名重複118
# -----
# 已抓取第6820頁
# 96381
# 實際剩餘96254，店名重複127
# -----
# 已抓取第6830頁
# 96531
# 實際剩餘96397，店名重複134
# -----
# 已抓取第6840頁
# 96681
# 實際剩餘96536，店名重複145
# -----
# 已抓取第6850頁
# 96831
# 實際剩餘96677，店名重複154
# -----
# 已抓取第6860頁
# 96981
# 實際剩餘96815，店名重複166
# -----
# 已抓取第6870頁
# 97131
# 實際剩餘96955，店名重複176
# -----
# 已抓取第6880頁
# 97281
# 實際剩餘97099，店名重複182
# -----
# 已抓取第6890頁
# 97431
# 實際剩餘97242，店名重複189
# -----
# 已抓取第6900頁
# 97581
# 實際剩餘97383，店名重複198
# -----
# 已抓取第6910頁
# 97731
# 實際剩餘97521，店名重複210
# -----
# 已抓取第6920頁
# 97881
# 實際剩餘97662，店名重複219
# -----
# 已抓取第6930頁
# 98031
# 實際剩餘97800，店名重複231
# -----
# 已抓取第6940頁
# 98181
# 實際剩餘97941，店名重複240
# -----
# 已抓取第6950頁
# 98331
# 實際剩餘98084，店名重複247
# -----
# 已抓取第6960頁
# 98481
# 實際剩餘98227，店名重複254
# -----
# 已抓取第6970頁
# 98631
# 實際剩餘98363，店名重複268
# -----
# 已抓取第6980頁
# 98781
# 實際剩餘98502，店名重複279
# -----
# 已抓取第6990頁
# 98931
# 實際剩餘98642，店名重複289
# -----
# 已抓取第7000頁
# 99081
# 實際剩餘98776，店名重複305
# -----
# 已抓取第7010頁
# 99231
# 實際剩餘98915，店名重複316
# -----
# 已抓取第7020頁
# 99381
# 實際剩餘99057，店名重複324
# -----
# 已抓取第7030頁
# 99531
# 實際剩餘99194，店名重複337
# -----
# 已抓取第7040頁
# 99681
# 實際剩餘99334，店名重複347
# -----
# 已抓取第7050頁
# 99831
# 實際剩餘99474，店名重複357
# -----
# 已抓取第7060頁
# 99981
# 實際剩餘99611，店名重複370
# -----
# 已抓取第7070頁
# 100131
# 實際剩餘99748，店名重複383
# -----
# 已抓取第7080頁
# 100281
# 實際剩餘99891，店名重複390
# -----
# 已抓取第7090頁
# 100431
# 實際剩餘100025，店名重複406
# -----
# 已抓取第7100頁
# 100581
# 實際剩餘100165，店名重複416
# -----
# 已抓取第7110頁
# 100731
# 實際剩餘100304，店名重複427
# -----
# 已抓取第7120頁
# 100881
# 實際剩餘100439，店名重複442
# -----
# 已抓取第7130頁
# 101031
# 實際剩餘100579，店名重複452
# -----
# 已抓取第7140頁
# 101181
# 實際剩餘100719，店名重複462
# -----
# 已抓取第7150頁
# 101331
# 實際剩餘100858，店名重複473
# -----
# 已抓取第7160頁
# 101481
# 實際剩餘100993，店名重複488
# -----
# 已抓取第7170頁
# 101631
# 實際剩餘101133，店名重複498
# -----
# 已抓取第7180頁
# 101781
# 實際剩餘101276，店名重複505
# -----
# 已抓取第7190頁
# 101931
# 實際剩餘101415，店名重複516
# -----
# 已抓取第7200頁
# 102081
# 實際剩餘101553，店名重複528
# -----
# 已抓取第7210頁
# 102231
# 實際剩餘101692，店名重複539
# -----
# 已抓取第7220頁
# 102381
# 實際剩餘101832，店名重複549
# -----
# 已抓取第7230頁
# 102531
# 實際剩餘101964，店名重複567
# -----
# 已抓取第7240頁
# 102681
# 實際剩餘102109，店名重複572
# -----
# 已抓取第7250頁
# 102831
# 實際剩餘102248，店名重複583
# -----
# 已抓取第7260頁
# 102981
# 實際剩餘102390，店名重複591
# -----
# 已抓取第7270頁
# 103131
# 實際剩餘102530，店名重複601
# -----
# 已抓取第7280頁
# 103281
# 實際剩餘102667，店名重複614
# -----
# 已抓取第7290頁
# 103431
# 實際剩餘102808，店名重複623
# -----
# 已抓取第7300頁
# 103581
# 實際剩餘102942，店名重複639
# -----
# 已抓取第7310頁
# 103731
# 實際剩餘103079，店名重複652
# -----
# 已抓取第7320頁
# 103881
# 實際剩餘103212，店名重複669
# -----
# 已抓取第7330頁
# 104031
# 實際剩餘103348，店名重複683
# -----
# 已抓取第7340頁
# 104181
# 實際剩餘103483，店名重複698
# -----
# 已抓取第7350頁
# 104331
# 實際剩餘103629，店名重複702
# -----
# 已抓取第7360頁
# 104481
# 實際剩餘103769，店名重複712
# -----
# 已抓取第7370頁
# 104631
# 實際剩餘103911，店名重複720
# -----
# 已抓取第7380頁
# 104781
# 實際剩餘104055，店名重複726
# -----
# 已抓取第7390頁
# 104931
# 實際剩餘104187，店名重複744
# -----
# 已抓取第7400頁
# 105081
# 實際剩餘104328，店名重複753
# -----
# 已抓取第7410頁
# 105231
# 實際剩餘104468，店名重複763
# -----
# 已抓取第7420頁
# 105381
# 實際剩餘104604，店名重複777
# -----
# 已抓取第7430頁
# 105531
# 實際剩餘104741，店名重複790
# -----
# 已抓取第7440頁
# 105681
# 實際剩餘104879，店名重複802
# -----
# 已抓取第7450頁
# 105831
# 實際剩餘105014，店名重複817
# -----
# 已抓取第7460頁
# 105981
# 實際剩餘105152，店名重複829
# -----
# 已抓取第7470頁
# 106131
# 實際剩餘105294，店名重複837
# -----
# 已抓取第7480頁
# 106281
# 實際剩餘105435，店名重複846
# -----
# 已抓取第7490頁
# 106431
# 實際剩餘105572，店名重複859
# -----
# 已抓取第7500頁
# 106581
# 實際剩餘105713，店名重複868
# -----
# 已抓取第7510頁
# 106731
# 實際剩餘105851，店名重複880
# -----
# 已抓取第7520頁
# 106881
# 實際剩餘105987，店名重複894
# -----
# 已抓取第7530頁
# 107031
# 實際剩餘106129，店名重複902
# -----
# 已抓取第7540頁
# 107181
# 實際剩餘106265，店名重複916
# -----
# 已抓取第7550頁
# 107331
# 實際剩餘106387，店名重複944
# -----
# 已抓取第7560頁
# 107481
# 實際剩餘106522，店名重複959
# -----
# 已抓取第7570頁
# 107631
# 實際剩餘106663，店名重複968
# -----
# 已抓取第7580頁
# 107781
# 實際剩餘106804，店名重複977
# -----
# 已抓取第7590頁
# 107931
# 實際剩餘106939，店名重複992
# -----
# 已抓取第7600頁
# 108081
# 實際剩餘107075，店名重複1006
# -----
# 已抓取第7610頁
# 108231
# 實際剩餘107214，店名重複1017
# -----
# 已抓取第7620頁
# 108381
# 實際剩餘107351，店名重複1030
# -----
# 已抓取第7630頁
# 108531
# 實際剩餘107492，店名重複1039
# -----
# 已抓取第7640頁
# 108681
# 實際剩餘107606，店名重複1075
# -----
# 已抓取第7650頁
# 108831
# 實際剩餘107749，店名重複1082
# -----
# 已抓取第7660頁
# 108981
# 實際剩餘107886，店名重複1095
# -----
# 已抓取第7670頁
# 109131
# 實際剩餘108014，店名重複1117
# -----
# 已抓取第7680頁
# 109281
# 實際剩餘108154，店名重複1127
# -----
# 已抓取第7690頁
# 109431
# 實際剩餘108299，店名重複1132
# -----
# 已抓取第7700頁
# 109581
# 實際剩餘108436，店名重複1145
# -----
# 已抓取第7710頁
# 109731
# 實際剩餘108575，店名重複1156
# -----
# 已抓取第7720頁
# 109881
# 實際剩餘108706，店名重複1175
# -----
# 已抓取第7730頁
# 110031
# 實際剩餘108850，店名重複1181
# -----
# 已抓取第7740頁
# 110181
# 實際剩餘108991，店名重複1190
# -----
# 已抓取第7750頁
# 110331
# 實際剩餘109128，店名重複1203
# -----
# 已抓取第7760頁
# 110481
# 實際剩餘109261，店名重複1220
# -----
# 已抓取第7770頁
# 110631
# 實際剩餘109391，店名重複1240
# -----
# 已抓取第7780頁
# 110781
# 實際剩餘109518，店名重複1263
# -----
# 已抓取第7790頁
# 110931
# 實際剩餘109654，店名重複1277
# -----
# 已抓取第7800頁
# 111081
# 實際剩餘109795，店名重複1286
# -----
# 已抓取第7810頁
# 111231
# 實際剩餘109938，店名重複1293
# -----
# 已抓取第7820頁
# 111381
# 實際剩餘110071，店名重複1310
# -----
# 已抓取第7830頁
# 111531
# 實際剩餘110201，店名重複1330
# -----
# 已抓取第7840頁
# 111681
# 實際剩餘110324，店名重複1357
# -----
# 已抓取第7850頁
# 111831
# 實際剩餘110449，店名重複1382
# -----
# 已抓取第7860頁
# 111981
# 實際剩餘110582，店名重複1399
# -----
# 已抓取第7870頁
# 112131
# 實際剩餘110706，店名重複1425
# -----
# 已抓取第7880頁
# 112281
# 實際剩餘110835，店名重複1446
# -----
# 已抓取第7890頁
# 112431
# 實際剩餘110971，店名重複1460
# -----
# 已抓取第7900頁
# 112581
# 實際剩餘111109，店名重複1472
# -----
# 已抓取第7910頁
# 112731
# 實際剩餘111250，店名重複1481
# -----
# 已抓取第7920頁
# 112881
# 實際剩餘111385，店名重複1496
# -----
# 已抓取第7930頁
# 113031
# 實際剩餘111516，店名重複1515
# -----
# 已抓取第7940頁
# 113181
# 實際剩餘111655，店名重複1526
# -----
# 已抓取第7950頁
# 113331
# 實際剩餘111789，店名重複1542
# -----
# 已抓取第7960頁
# 113481
# 實際剩餘111925，店名重複1556
# -----
# 已抓取第7970頁
# 113631
# 實際剩餘112067，店名重複1564
# -----
# 已抓取第7980頁
# 113781
# 實際剩餘112208，店名重複1573
# -----
# 已抓取第7990頁
# 113931
# 實際剩餘112345，店名重複1586
# -----
# 已抓取第8000頁
# 114081
# 實際剩餘112475，店名重複1606
# -----
# 已抓取第8010頁
# 114231
# 實際剩餘112591，店名重複1640
# -----
# 已抓取第8020頁
# 114381
# 實際剩餘112720，店名重複1661
# -----
# 已抓取第8030頁
# 114531
# 實際剩餘112846，店名重複1685
# -----
# 已抓取第8040頁
# 114681
# 實際剩餘112968，店名重複1713
# -----
# 已抓取第8050頁
# 114831
# 實際剩餘113096，店名重複1735
# -----
# 已抓取第8060頁
# 114981
# 實際剩餘113228，店名重複1753
# -----
# 已抓取第8070頁
# 115131
# 實際剩餘113368，店名重複1763
# -----
# 已抓取第8080頁
# 115281
# 實際剩餘113515，店名重複1766
# -----
# 已抓取第8090頁
# 115431
# 實際剩餘113656，店名重複1775
# -----
# 已抓取第8100頁
# 115581
# 實際剩餘113797，店名重複1784
# -----
# 已抓取第8110頁
# 115731
# 實際剩餘113928，店名重複1803
# -----
# 已抓取第8120頁
# 115881
# 實際剩餘114068，店名重複1813
# -----
# 已抓取第8130頁
# 116031
# 實際剩餘114205，店名重複1826
# -----
# 已抓取第8140頁
# 116181
# 實際剩餘114338，店名重複1843
# -----
# 已抓取第8150頁
# 116331
# 實際剩餘114463，店名重複1868
# -----
# 已抓取第8160頁
# 116481
# 實際剩餘114594，店名重複1887
# -----
# 已抓取第8170頁
# 116631
# 實際剩餘114726，店名重複1905
# -----
# 已抓取第8180頁
# 116781
# 實際剩餘114863，店名重複1918
# -----
# 已抓取第8190頁
# 116931
# 實際剩餘114976，店名重複1955
# -----
# 已抓取第8200頁
# 117081
# 實際剩餘115108，店名重複1973
# -----
# 已抓取第8210頁
# 117231
# 實際剩餘115233，店名重複1998
# -----
# 已抓取第8220頁
# 117381
# 實際剩餘115354，店名重複2027
# -----
# 已抓取第8230頁
# 117531
# 實際剩餘115485，店名重複2046
# -----
# 已抓取第8240頁
# 117681
# 實際剩餘115624，店名重複2057
# -----
# 已抓取第8250頁
# 117831
# 實際剩餘115761，店名重複2070
# -----
# 已抓取第8260頁
# 117981
# 實際剩餘115901，店名重複2080
# -----
# 已抓取第8270頁
# 118131
# 實際剩餘116030，店名重複2101
# -----
# 已抓取第8280頁
# 118281
# 實際剩餘116169，店名重複2112
# -----
# 已抓取第8290頁
# 118431
# 實際剩餘116309，店名重複2122
# -----
# 已抓取第8300頁
# 118581
# 實際剩餘116446，店名重複2135
# -----
# 已抓取第8310頁
# 118731
# 實際剩餘116583，店名重複2148
# -----
# 已抓取第8320頁
# 118881
# 實際剩餘116705，店名重複2176
# -----
# 已抓取第8330頁
# 119031
# 實際剩餘116838，店名重複2193
# -----
# 已抓取第8340頁
# 119181
# 實際剩餘116974，店名重複2207
# -----
# 已抓取第8350頁
# 119331
# 實際剩餘117111，店名重複2220
# -----
# 已抓取第8360頁
# 119481
# 實際剩餘117256，店名重複2225
# -----
# 已抓取第8370頁
# 119631
# 實際剩餘117398，店名重複2233
# -----
# 已抓取第8380頁
# 119781
# 實際剩餘117540，店名重複2241
# -----
# 已抓取第8390頁
# 119931
# 實際剩餘117679，店名重複2252
# -----
# 已抓取第8400頁
# 120081
# 實際剩餘117808，店名重複2273
# -----
# 已抓取第8410頁
# 120231
# 實際剩餘117936，店名重複2295
# -----
# 已抓取第8420頁
# 120381
# 實際剩餘118067，店名重複2314
# -----
# 已抓取第8430頁
# 120531
# 實際剩餘118200，店名重複2331
# -----
# 已抓取第8440頁
# 120681
# 實際剩餘118333，店名重複2348
# -----
# 已抓取第8450頁
# 120831
# 實際剩餘118467，店名重複2364
# -----
# 已抓取第8460頁
# 120981
# 實際剩餘118601，店名重複2380
# -----
# 已抓取第8470頁
# 121131
# 實際剩餘118740，店名重複2391
# -----
# 已抓取第8480頁
# 121281
# 實際剩餘118875，店名重複2406
# -----
# 已抓取第8490頁
# 121431
# 實際剩餘119007，店名重複2424
# -----
# 已抓取第8500頁
# 121581
# 實際剩餘119148，店名重複2433
# -----
# 已抓取第8510頁
# 121731
# 實際剩餘119285，店名重複2446
# -----
# 已抓取第8520頁
# 121881
# 實際剩餘119420，店名重複2461
# -----
# 已抓取第8530頁
# 122031
# 實際剩餘119556，店名重複2475
# -----
# 已抓取第8540頁
# 122181
# 實際剩餘119697，店名重複2484
# -----
# 已抓取第8550頁
# 122331
# 實際剩餘119840，店名重複2491
# -----
# 已抓取第8560頁
# 122481
# 實際剩餘119981，店名重複2500
# -----
# 已抓取第8570頁
# 122631
# 實際剩餘120125，店名重複2506
# -----
# 已抓取第8580頁
# 122781
# 實際剩餘120264，店名重複2517
# -----
# 已抓取第8590頁
# 122931
# 實際剩餘120400，店名重複2531
# -----
# 已抓取第8600頁
# 123081
# 實際剩餘120539，店名重複2542
# -----
# 已抓取第8610頁
# 123231
# 實際剩餘120677，店名重複2554
# -----
# 已抓取第8620頁
# 123381
# 實際剩餘120818，店名重複2563
# -----
# 已抓取第8630頁
# 123531
# 實際剩餘120958，店名重複2573
# -----
# 已抓取第8640頁
# 123681
# 實際剩餘121095，店名重複2586
# -----
# 已抓取第8650頁
# 123831
# 實際剩餘121231，店名重複2600
# -----
# 已抓取第8660頁
# 123981
# 實際剩餘121374，店名重複2607
# -----
# 已抓取第8670頁
# 124131
# 實際剩餘121514，店名重複2617
# -----
# 已抓取第8680頁
# 124281
# 實際剩餘121656，店名重複2625
# -----
# 已抓取第8690頁
# 124431
# 實際剩餘121799，店名重複2632
# -----
# 已抓取第8700頁
# 124581
# 實際剩餘121937，店名重複2644
# -----
# 已抓取第8710頁
# 124731
# 實際剩餘122075，店名重複2656
# -----
# 已抓取第8720頁
# 124881
# 實際剩餘122212，店名重複2669
# -----
# 已抓取第8730頁
# 125031
# 實際剩餘122350，店名重複2681
# -----
# 已抓取第8740頁
# 125181
# 實際剩餘122486，店名重複2695
# -----
# 已抓取第8750頁
# 125331
# 實際剩餘122617，店名重複2714
# -----
# 已抓取第8760頁
# 125481
# 實際剩餘122755，店名重複2726
# -----
# 已抓取第8770頁
# 125631
# 實際剩餘122898，店名重複2733
# -----
# 已抓取第8780頁
# 125781
# 實際剩餘123025，店名重複2756
# -----
# 已抓取第8790頁
# 125931
# 實際剩餘123158，店名重複2773
# -----
# 已抓取第8800頁
# 126081
# 實際剩餘123302，店名重複2779
# -----
# 已抓取第8810頁
# 126231
# 實際剩餘123445，店名重複2786
# -----
# 已抓取第8820頁
# 126381
# 實際剩餘123585，店名重複2796
# -----
# 已抓取第8830頁
# 126531
# 實際剩餘123715，店名重複2816
# -----
# 已抓取第8840頁
# 126681
# 實際剩餘123853，店名重複2828
# -----
# 已抓取第8850頁
# 126831
# 實際剩餘123984，店名重複2847
# -----
# 已抓取第8860頁
# 126981
# 實際剩餘124109，店名重複2872
# -----
# 已抓取第8870頁
# 127131
# 實際剩餘124243，店名重複2888
# -----
# 已抓取第8880頁
# 127281
# 實際剩餘124375，店名重複2906
# -----
# 已抓取第8890頁
# 127431
# 實際剩餘124508，店名重複2923
# -----
# 已抓取第8900頁
# 127581
# 實際剩餘124634，店名重複2947
# -----
# 已抓取第8910頁
# 127731
# 實際剩餘124770，店名重複2961
# -----
# 已抓取第8920頁
# 127881
# 實際剩餘124912，店名重複2969
# -----
# 已抓取第8930頁
# 128031
# 實際剩餘125043，店名重複2988
# -----
# 已抓取第8940頁
# 128181
# 實際剩餘125184，店名重複2997
# -----
# 已抓取第8950頁
# 128331
# 實際剩餘125317，店名重複3014
# -----
# 已抓取第8960頁
# 128481
# 實際剩餘125454，店名重複3027
# -----
# 已抓取第8970頁
# 128631
# 實際剩餘125579，店名重複3052
# -----
# 已抓取第8980頁
# 128781
# 實際剩餘125697，店名重複3084
# -----
# 已抓取第8990頁
# 128931
# 實際剩餘125824，店名重複3107
# -----
# 已抓取第9000頁
# 129081
# 實際剩餘125965，店名重複3116
# -----
# 已抓取第9010頁
# 129231
# 實際剩餘126102，店名重複3129
# -----
# 已抓取第9020頁
# 129381
# 實際剩餘126243，店名重複3138
# -----
# 已抓取第9030頁
# 129531
# 實際剩餘126379，店名重複3152
# -----
# 已抓取第9040頁
# 129681
# 實際剩餘126515，店名重複3166
# -----
# 已抓取第9050頁
# 129831
# 實際剩餘126653，店名重複3178
# -----
# 已抓取第9060頁
# 129981
# 實際剩餘126787，店名重複3194
# -----
# 已抓取第9070頁
# 130131
# 實際剩餘126927，店名重複3204
# -----
# 已抓取第9080頁
# 130281
# 實際剩餘127067，店名重複3214
# -----
# 已抓取第9090頁
# 130431
# 實際剩餘127208，店名重複3223
# -----
# 已抓取第9100頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9110頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9120頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9130頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9140頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9150頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9160頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9170頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9180頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9190頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9200頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9210頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9220頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9230頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9240頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9250頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9260頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9270頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9280頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9290頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9300頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9310頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9320頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9330頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9340頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9350頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9360頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9370頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9380頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9390頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9400頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9410頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9420頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9430頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9440頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9450頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9460頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9470頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9480頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9490頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9500頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9510頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9520頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9530頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9540頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9550頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9560頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9570頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9580頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9590頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9600頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9610頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9620頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9630頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9640頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9650頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9660頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9670頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9680頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9690頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9700頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9710頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9720頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9730頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9740頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9750頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9760頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9770頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9780頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9790頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9800頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9810頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9820頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9830頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9840頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9850頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9860頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9870頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9880頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9890頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9900頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9910頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9920頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9930頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9940頁
# 130562
# 實際剩餘127333，店名重複3229
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# D:\anaconda\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379             try:  # Python 2.7, use buffering of HTTP responses
# --> 380                 httplib_response = conn.getresponse(buffering=True)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-37-cc1600783608> in <module>()
#      30 #會累積的變數>>i WebsiteSet
#      31 for i in range(pagebegin,page+1):
# ---> 32     res=requests.get(URL+"&p="+str(i))
#      33     if res.status_code==200:
#      34         soup=bs(res.text,'lxml')
#
# D:\anaconda\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# D:\anaconda\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# D:\anaconda\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# D:\anaconda\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     616
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#     620         # Total elapsed time of the request (approximately)
#
# D:\anaconda\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438                     decode_content=False,
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#     442
#
# D:\anaconda\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   timeout=timeout_obj,
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#     603             # If we're going to release the connection in ``finally:``, then
#
# D:\anaconda\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#     382                 try:
# --> 383                     httplib_response = conn.getresponse()
#     384                 except Exception as e:
#     385                     # Remove the TypeError from the exception chain in Python 3;
#
# D:\anaconda\lib\http\client.py in getresponse(self)
#    1329         try:
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#    1333                 self.close()
#
# D:\anaconda\lib\http\client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# D:\anaconda\lib\http\client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# D:\anaconda\lib\socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
with open("./data/WebsiteSet.json") as f:
    x=json.load(f)

# %%
x
# Out:
# {'IN墅館': 'http://www.ipeen.com.tw/shop/1082',
#  '高雄爆漿雞排': 'http://www.ipeen.com.tw/shop/56749',
#  '沁采現代生活餐飲': 'http://www.ipeen.com.tw/shop/1023246',
#  '二丁靚鍋-三重店': 'http://www.ipeen.com.tw/shop/1027518',
#  '逢甲港式燒臘快餐現炒店-埤頭店': 'http://www.ipeen.com.tw/shop/25944',
#  '達美樂披薩-DOMINO-S-PIZZA-大甲店': 'http://www.ipeen.com.tw/shop/106646',
#  '佳珍小館': 'http://www.ipeen.com.tw/shop/120623',
#  '福和生鮮農場有限公司-信義鄉巨峰葡萄': 'http://www.ipeen.com.tw/shop/68840',
#  '京屋拉麵': 'http://www.ipeen.com.tw/shop/1054634',
#  '泰蕉手工泰式茶-香蕉煎餅': 'http://www.ipeen.com.tw/shop/1127192',
#  '傅媽媽干貝長年菜-雞肉': 'http://www.ipeen.com.tw/shop/91749',
#  '阿英小吃': 'http://www.ipeen.com.tw/shop/92823',
#  '85度C咖啡蛋糕烘焙專賣店-埔里中正店': 'http://www.ipeen.com.tw/shop/33524',
#  'La-Mia-義式料理餐廳': 'http://www.ipeen.com.tw/shop/48878',
#  '花生糖': 'http://www.ipeen.com.tw/shop/625162',
#  '基隆全家福海鮮餐廳': 'http://www.ipeen.com.tw/shop/78267',
#  '龍門海產': 'http://www.ipeen.com.tw/shop/21687',
#  '五花馬水餃館-新竹竹科店': 'http://www.ipeen.com.tw/shop/942478',
#  '百分之二咖啡': 'http://www.ipeen.com.tw/shop/993698',
#  '東東快炒': 'http://www.ipeen.com.tw/shop/603060',
#  '宏明XO小管醬': 'http://www.ipeen.com.tw/shop/113890',
#  '泰凱實業有限公司': 'http://www.ipeen.com.tw/shop/1065234',
#  '阿水嫂自助刨冰': 'http://www.ipeen.com.tw/shop/1026326',
#  '旺梨小鎮': 'http://www.ipeen.com.tw/shop/88332',
#  '菇菇熊美食': 'http://www.ipeen.com.tw/shop/77315',
#  '赤鬼牛排-博愛店': 'http://www.ipeen.com.tw/shop/1008624',
#  '呷味亭專業滷味': 'http://www.ipeen.com.tw/shop/108055',
#  '辛很守辣': 'http://www.ipeen.com.tw/shop/1151210',
#  'Starbucks-Coffee-統一星巴克-中港門市': 'http://www.ipeen.com.tw/shop/2483',
#  '樂の屋日式豬排丼飯專門': 'http://www.ipeen.com.tw/shop/1068426',
#  '百家香香雞排炸雞': 'http://www.ipeen.com.tw/shop/40519',
#  'Hyphen-Cuisine-Brunch-Cafe': 'http://www.ipeen.com.tw/shop/634420',
#  '嘉義粉條冰': 'http://www.ipeen.com.tw/shop/1000732',
#  '火考-イ香イ香-烤香香': 'http://www.ipeen.com.tw/shop/582561',
#  '湯廚房-內湖科學園區': 'http://www.ipeen.com.tw/shop/27691',
#  '拉亞漢堡-Laya-Burger-內湖江南店': 'http://www.ipeen.com.tw/shop/47715',
#  '松山活海鮮': 'http://www.ipeen.com.tw/shop/383888',
#  '五麥壽喜燒鍋物': 'http://www.ipeen.com.tw/shop/1184579',
#  '明觀輕食咖啡館': 'http://www.ipeen.com.tw/shop/1016122',
#  '小廚川味牛肉麵': 'http://www.ipeen.com.tw/shop/42213',
#  '啾司愛手工冰淇淋': 'http://www.ipeen.com.tw/shop/96115',
#  '纖女酥': 'http://www.ipeen.com.tw/shop/83265',
#  '丸太拉麵-工學店': 'http://www.ipeen.com.tw/shop/750584',
#  'BLISS果凍酒': 'http://www.ipeen.com.tw/shop/1054626',
#  '勁饗食手工刀切麵-熱河店': 'http://www.ipeen.com.tw/shop/587834',
#  '普羅旺斯庭園餐應': 'http://www.ipeen.com.tw/shop/637106',
#  '赤肉粥': 'http://www.ipeen.com.tw/shop/579990',
#  '滷大王-桃園中正店': 'http://www.ipeen.com.tw/shop/829264',
#  '大創-takara-巧克力棒': 'http://www.ipeen.com.tw/shop/84908',
#  '蓮慈香素食盒餐': 'http://www.ipeen.com.tw/shop/16502',
#  '蜜思波緹-魔力比基尼纖暢飲': 'http://www.ipeen.com.tw/shop/139643',
#  '協全餅舖': 'http://www.ipeen.com.tw/shop/1004810',
#  '靓品香港茶餐廳': 'http://www.ipeen.com.tw/shop/40264',
#  'Da-SacE-重乳酪專門店': 'http://www.ipeen.com.tw/shop/1115681',
#  'Alouette-Salon-雲雀沙龍': 'http://www.ipeen.com.tw/shop/1079933',
#  '嚐嚐九九-桃園中壢店': 'http://www.ipeen.com.tw/shop/57925',
#  '新滋城藝術蛋糕': 'http://www.ipeen.com.tw/shop/88307',
#  '翔賀蔥油餅': 'http://www.ipeen.com.tw/shop/348294',
#  '幸福廚房': 'http://www.ipeen.com.tw/shop/99141',
#  '晶品北海婚宴會館-集賢店': 'http://www.ipeen.com.tw/shop/1188380',
#  '貴族世家牛排-沙鹿店': 'http://www.ipeen.com.tw/shop/22098',
#  '泰鮮館': 'http://www.ipeen.com.tw/shop/986106',
#  '寶山黑糖爆漿饅頭': 'http://www.ipeen.com.tw/shop/610730',
#  '華興芋仔冰': 'http://www.ipeen.com.tw/shop/1165457',
#  '蜜旺果-愛文芒果干': 'http://www.ipeen.com.tw/shop/55412',
#  '7-11-肉捲飯糰': 'http://www.ipeen.com.tw/shop/115318',
#  '慕夏咖啡MUCHA-COFFEE': 'http://www.ipeen.com.tw/shop/33069',
#  'IKEA-宜家家居餐廳-高雄店': 'http://www.ipeen.com.tw/shop/35533',
#  '查某人的味': 'http://www.ipeen.com.tw/shop/49480',
#  '澤村餐廳': 'http://www.ipeen.com.tw/shop/14925',
#  'Brownie-布藍里烘焙工房-京站店': 'http://www.ipeen.com.tw/shop/628932',
#  '殷商涮涮鍋': 'http://www.ipeen.com.tw/shop/42507',
#  '悅喀手工甜點': 'http://www.ipeen.com.tw/shop/1024276',
#  '韓國不倒翁OTTOG辛辣拉麵': 'http://www.ipeen.com.tw/shop/143095',
#  '港籠腸粉': 'http://www.ipeen.com.tw/shop/51062',
#  '風林火山日式爐燒碳烤專門店': 'http://www.ipeen.com.tw/shop/8581',
#  'Cherii天然酵母麵包': 'http://www.ipeen.com.tw/shop/596254',
#  '牛鼎牛肉火鍋': 'http://www.ipeen.com.tw/shop/1225481',
#  '滿客鍋貼專賣店': 'http://www.ipeen.com.tw/shop/23810',
#  '宏嘉食品行': 'http://www.ipeen.com.tw/shop/149855',
#  '鍋爸愛鍋媽小火鍋專賣店-沙鹿店': 'http://www.ipeen.com.tw/shop/940646',
#  '浙江餛飩大王': 'http://www.ipeen.com.tw/shop/39912',
#  '北斗素圓祝': 'http://www.ipeen.com.tw/shop/46782',
#  '新順成餅舖': 'http://www.ipeen.com.tw/shop/37279',
#  'Mr-Taco-章魚先生品味小館': 'http://www.ipeen.com.tw/shop/1087730',
#  '郭元益-公館門市': 'http://www.ipeen.com.tw/shop/32170',
#  '芳典軒餐廳': 'http://www.ipeen.com.tw/shop/7540',
#  '蜂之饗宴': 'http://www.ipeen.com.tw/shop/1041314',
#  '美麗信花園酒店-雨林': 'http://www.ipeen.com.tw/shop/86341',
#  '日月潭哲園中餐廳': 'http://www.ipeen.com.tw/shop/116576',
#  '寶島燒創意食堂': 'http://www.ipeen.com.tw/shop/742850',
#  '烘人院': 'http://www.ipeen.com.tw/shop/936234',
#  '三媽臭臭鍋-台北農安店': 'http://www.ipeen.com.tw/shop/7217',
#  '伊豆燒板屋': 'http://www.ipeen.com.tw/shop/26300',
#  '糖麻栗': 'http://www.ipeen.com.tw/shop/978128',
#  '阿部平價日本料理': 'http://www.ipeen.com.tw/shop/51576',
#  '中華鍋貼': 'http://www.ipeen.com.tw/shop/59426',
#  '梅婆茶葉蛋': 'http://www.ipeen.com.tw/shop/938032',
#  '日出乳酪蛋糕': 'http://www.ipeen.com.tw/shop/903000',
#  '晴天廚房': 'http://www.ipeen.com.tw/shop/1054348',
#  '歌麿日本料理': 'http://www.ipeen.com.tw/shop/1022942',
#  '壹咖啡-ecoffee-蘆洲長樂店': 'http://www.ipeen.com.tw/shop/121987',
#  '菠蘿油王子mini茶餐廳-高雄中華店': 'http://www.ipeen.com.tw/shop/1026532',
#  '維力素食炸醬': 'http://www.ipeen.com.tw/shop/56399',
#  '蒝紅綵手作飲冰館': 'http://www.ipeen.com.tw/shop/984934',
#  'SlimDay全日纖-排空酵素': 'http://www.ipeen.com.tw/shop/1147046',
#  '疆毒串烤-花博店': 'http://www.ipeen.com.tw/shop/807922',
#  '祥園燒鴨大王': 'http://www.ipeen.com.tw/shop/25482',
#  '大埔平價鐵板燒-文山店': 'http://www.ipeen.com.tw/shop/80092',
#  '莫內咖啡坊': 'http://www.ipeen.com.tw/shop/65514',
#  '古早香碳烤胡椒餅': 'http://www.ipeen.com.tw/shop/924732',
#  '27街': 'http://www.ipeen.com.tw/shop/27647',
#  '茶芝飲-仁雄店': 'http://www.ipeen.com.tw/shop/618982',
#  '基隆港活海鮮': 'http://www.ipeen.com.tw/shop/15895',
#  '金草莓': 'http://www.ipeen.com.tw/shop/147323',
#  '紅廚排骨': 'http://www.ipeen.com.tw/shop/1142855',
#  '東門御園坊': 'http://www.ipeen.com.tw/shop/1059460',
#  '趴趴亞木瓜牛奶': 'http://www.ipeen.com.tw/shop/1061886',
#  '海洋之家爆漿起司豬排': 'http://www.ipeen.com.tw/shop/67664',
#  '幸福Feliz-1號店': 'http://www.ipeen.com.tw/shop/115228',
#  '許家雞鵝-汐止分店': 'http://www.ipeen.com.tw/shop/584527',
#  '鴨肉興': 'http://www.ipeen.com.tw/shop/597912',
#  '拉法頌時尚喜餅': 'http://www.ipeen.com.tw/shop/579822',
#  '紅頭嶼蒸氣海鮮-高雄店': 'http://www.ipeen.com.tw/shop/1116377',
#  'Texas-Roadhouse德州鮮切牛排': 'http://www.ipeen.com.tw/shop/1000934',
#  '李家韓國食堂': 'http://www.ipeen.com.tw/shop/1016422',
#  '饌師傅水煎餃': 'http://www.ipeen.com.tw/shop/97745',
#  '同枝粿仔店': 'http://www.ipeen.com.tw/shop/131333',
#  '桔磨坊義式麵屋-民權店': 'http://www.ipeen.com.tw/shop/50532',
#  '印尼爪哇美食站': 'http://www.ipeen.com.tw/shop/988004',
#  '麥盧卡蜂蜜': 'http://www.ipeen.com.tw/shop/88085',
#  '顏記一口清蒸肉圓': 'http://www.ipeen.com.tw/shop/957210',
#  '包心粉圓-埔里點': 'http://www.ipeen.com.tw/shop/1000068',
#  '阿梅師義式料理': 'http://www.ipeen.com.tw/shop/1113947',
#  '食‧金湯精典麵食館': 'http://www.ipeen.com.tw/shop/43193',
#  '老夫子牛排屋': 'http://www.ipeen.com.tw/shop/592574',
#  'Teaˊs-原味-南崁店': 'http://www.ipeen.com.tw/shop/762698',
#  '大井烤茶': 'http://www.ipeen.com.tw/shop/58318',
#  '喵姨蛋餅Cindy-s-Pancake': 'http://www.ipeen.com.tw/shop/1194458',
#  '龍興海鮮城': 'http://www.ipeen.com.tw/shop/17561',
#  '博和軒日式拉麵': 'http://www.ipeen.com.tw/shop/1079774',
#  '藻遍海餃': 'http://www.ipeen.com.tw/shop/156469',
#  '拉亞漢堡-Laya-Burger-瀋陽店': 'http://www.ipeen.com.tw/shop/75316',
#  '大眾滷味': 'http://www.ipeen.com.tw/shop/41596',
#  '丹堤咖啡研磨專賣店-Dante-Coffee-寶慶店': 'http://www.ipeen.com.tw/shop/32124',
#  '麻吉飯糰': 'http://www.ipeen.com.tw/shop/116659',
#  '小餘家食堂': 'http://www.ipeen.com.tw/shop/983014',
#  '紅洋蔥創義廚房': 'http://www.ipeen.com.tw/shop/107100',
#  '寬緹宴會館': 'http://www.ipeen.com.tw/shop/1213244',
#  '翰林茶棧-台北新光信義A8店': 'http://www.ipeen.com.tw/shop/1229843',
#  '林肯香雞排-沙鹿成功店': 'http://www.ipeen.com.tw/shop/72487',
#  '錢都日式涮涮鍋-桃園永安店': 'http://www.ipeen.com.tw/shop/27143',
#  '光復饅頭-民族西店': 'http://www.ipeen.com.tw/shop/23953',
#  '麥當勞-屏東民生店': 'http://www.ipeen.com.tw/shop/101050',
#  '經典食尚': 'http://www.ipeen.com.tw/shop/1058822',
#  '笠原麵食館': 'http://www.ipeen.com.tw/shop/23072',
#  'Local-Bar-在地酒館': 'http://www.ipeen.com.tw/shop/1074292',
#  '鮮賣鍋貼-鮮賣鍋貼': 'http://www.ipeen.com.tw/shop/1010264',
#  '大埔硫磺泉浴室': 'http://www.ipeen.com.tw/shop/19952',
#  '帝鈞碳烤胡椒餅-慶和直營店': 'http://www.ipeen.com.tw/shop/763918',
#  '洪媽飯糰': 'http://www.ipeen.com.tw/shop/965360',
#  '北平金宴餐廳': 'http://www.ipeen.com.tw/shop/47934',
#  '台雞店-烏來店': 'http://www.ipeen.com.tw/shop/52861',
#  '泰閣-tiger-house': 'http://www.ipeen.com.tw/shop/1025420',
#  '老上海臭豆腐-東海店': 'http://www.ipeen.com.tw/shop/1067662',
#  '逢甲碳烤': 'http://www.ipeen.com.tw/shop/994196',
#  '頂好現炒沙威瑪': 'http://www.ipeen.com.tw/shop/37867',
#  '靜岡勝政日式豬排-台北統一時代店': 'http://www.ipeen.com.tw/shop/1129160',
#  '餐飲集團美食廣場': 'http://www.ipeen.com.tw/shop/612404',
#  '磨啡糕點鋪-Bummel-Café': 'http://www.ipeen.com.tw/shop/1064910',
#  '京兔子幸守燒-手作菓子': 'http://www.ipeen.com.tw/shop/51619',
#  '順龍餐廳': 'http://www.ipeen.com.tw/shop/24403',
#  '東京鐵板燒': 'http://www.ipeen.com.tw/shop/12680',
#  '康家阿媽ㄟ粉腸': 'http://www.ipeen.com.tw/shop/32272',
#  '宜蘭古早味料理': 'http://www.ipeen.com.tw/shop/58396',
#  '貴族世家牛排-嘉義友愛店': 'http://www.ipeen.com.tw/shop/107235',
#  '豐滿咖啡早午餐-三重正義店': 'http://www.ipeen.com.tw/shop/1083971',
#  '日芳珍饌北極貝米雞': 'http://www.ipeen.com.tw/shop/928386',
#  'Feel-藝術的饗宴': 'http://www.ipeen.com.tw/shop/83452',
#  '富屋泡芙': 'http://www.ipeen.com.tw/shop/73872',
#  '巴麼漾生活咖啡館': 'http://www.ipeen.com.tw/shop/12228',
#  '麵': 'http://www.ipeen.com.tw/shop/610336',
#  '正原味鹽水雞': 'http://www.ipeen.com.tw/shop/102195',
#  '總監工坊': 'http://www.ipeen.com.tw/shop/84980',
#  '一品香火鍋-屏東店': 'http://www.ipeen.com.tw/shop/1042460',
#  '伊莎貝爾沙式喜餅': 'http://www.ipeen.com.tw/shop/88531',
#  '鮮芋仙-新明店': 'http://www.ipeen.com.tw/shop/43168',
#  '四葉關東煮': 'http://www.ipeen.com.tw/shop/105996',
#  '果爾市優格': 'http://www.ipeen.com.tw/shop/1038480',
#  '長崎拉麵': 'http://www.ipeen.com.tw/shop/8228',
#  '神祕便當': 'http://www.ipeen.com.tw/shop/1093904',
#  '米克森咖啡輕食': 'http://www.ipeen.com.tw/shop/997360',
#  '正功夫港式煨湯': 'http://www.ipeen.com.tw/shop/629776',
#  '疆毒串烤-敦北店': 'http://www.ipeen.com.tw/shop/808662',
#  '龍都冰果店': 'http://www.ipeen.com.tw/shop/38668',
#  '無名阿婆飯糰': 'http://www.ipeen.com.tw/shop/1013788',
#  '51號咖啡屋': 'http://www.ipeen.com.tw/shop/1017510',
#  '大個子饅頭包子專賣店': 'http://www.ipeen.com.tw/shop/78155',
#  '福友山土雞城': 'http://www.ipeen.com.tw/shop/950300',
#  '發現越越式時尚料理-信義店A4': 'http://www.ipeen.com.tw/shop/28276',
#  'Niko-Niko可樂餅專賣': 'http://www.ipeen.com.tw/shop/61447',
#  '常新美式沙拉': 'http://www.ipeen.com.tw/shop/56595',
#  '清新福全冷飲店': 'http://www.ipeen.com.tw/shop/1144676',
#  '老山東餃子館': 'http://www.ipeen.com.tw/shop/947500',
#  '鴨喜露滷味': 'http://www.ipeen.com.tw/shop/596038',
#  '港式燒臘': 'http://www.ipeen.com.tw/shop/17310',
#  '中壢後站四果冰': 'http://www.ipeen.com.tw/shop/138317',
#  'First-Colony進口有機咖啡豆': 'http://www.ipeen.com.tw/shop/82619',
#  '猋太師傅中式餐館-大發店': 'http://www.ipeen.com.tw/shop/82874',
#  'らあめん花月嵐拉麵-誠品敦南店': 'http://www.ipeen.com.tw/shop/60962',
#  '潘師傅黃金甘醇雞': 'http://www.ipeen.com.tw/shop/91083',
#  '泰山大腸蚵仔麵線': 'http://www.ipeen.com.tw/shop/54299',
#  '新疆界-新春店': 'http://www.ipeen.com.tw/shop/1018996',
#  '星野銅鑼燒-站前店': 'http://www.ipeen.com.tw/shop/930182',
#  '蒜蓉辣椒': 'http://www.ipeen.com.tw/shop/52687',
#  '板橋國小雞蛋糕': 'http://www.ipeen.com.tw/shop/607492',
#  '老賴牛肉麵館': 'http://www.ipeen.com.tw/shop/1032172',
#  '桔葉茶舍-太平店': 'http://www.ipeen.com.tw/shop/600570',
#  '老傳統滷肉飯': 'http://www.ipeen.com.tw/shop/938468',
#  '十味觀食品': 'http://www.ipeen.com.tw/shop/1014098',
#  '三竹園客家小館': 'http://www.ipeen.com.tw/shop/819700',
#  'BoNEW-Cafe': 'http://www.ipeen.com.tw/shop/957428',
#  '茶花大師-英式香草紅茶專賣店-中壢中央店': 'http://www.ipeen.com.tw/shop/1077152',
#  '岩葉拉麵-大仁店': 'http://www.ipeen.com.tw/shop/945178',
#  '湖畔99露天庭園餐廳': 'http://www.ipeen.com.tw/shop/578882',
#  '逢甲脆皮烤鴨': 'http://www.ipeen.com.tw/shop/14900',
#  'SUBWAY-大潤發2館店': 'http://www.ipeen.com.tw/shop/27959',
#  '台西港大腸蚵仔麵線': 'http://www.ipeen.com.tw/shop/63590',
#  '卡不里吃到飽': 'http://www.ipeen.com.tw/shop/73173',
#  '台灣味-中興店': 'http://www.ipeen.com.tw/shop/135229',
#  '延三海鮮碳烤日本料理': 'http://www.ipeen.com.tw/shop/1018862',
#  '冬瓜幫': 'http://www.ipeen.com.tw/shop/884614',
#  '新市農會超市': 'http://www.ipeen.com.tw/shop/1078342',
#  '魚你在一起親子屋-員林店': 'http://www.ipeen.com.tw/shop/933354',
#  '花神咖啡私房小廚': 'http://www.ipeen.com.tw/shop/1146071',
#  '西市鱔魚麵': 'http://www.ipeen.com.tw/shop/592688',
#  '溝邊生猛海鮮': 'http://www.ipeen.com.tw/shop/961152',
#  '奉茶來恁兜-台中青海': 'http://www.ipeen.com.tw/shop/32648',
#  '田園日式美食亭': 'http://www.ipeen.com.tw/shop/9290',
#  '三方六-日式食堂': 'http://www.ipeen.com.tw/shop/1017716',
#  'Angel-Land-天使品味體內環保創意料理': 'http://www.ipeen.com.tw/shop/67936',
#  '三省齋': 'http://www.ipeen.com.tw/shop/16472',
#  '一江蓋飯': 'http://www.ipeen.com.tw/shop/965370',
#  '端端美食': 'http://www.ipeen.com.tw/shop/71556',
#  '上好鍋燒麵': 'http://www.ipeen.com.tw/shop/14637',
#  '泰好水餃館': 'http://www.ipeen.com.tw/shop/95418',
#  'N2恩菟樂活輕食': 'http://www.ipeen.com.tw/shop/153263',
#  '綠爵輕食館': 'http://www.ipeen.com.tw/shop/1052580',
#  '大順手工牛軋糖': 'http://www.ipeen.com.tw/shop/81307',
#  '唯鮮水晶石板燒肉-台北復興店': 'http://www.ipeen.com.tw/shop/1019540',
#  '統一晨光奶油土司': 'http://www.ipeen.com.tw/shop/930712',
#  'WaPizza瓦比薩-原義磚義瓦': 'http://www.ipeen.com.tw/shop/88965',
#  '花蓮老牌炸蛋蔥油餅-台南店': 'http://www.ipeen.com.tw/shop/116252',
#  '華芳利布朗尼': 'http://www.ipeen.com.tw/shop/66400',
#  '饗食天堂-中壢SOGO店': 'http://www.ipeen.com.tw/shop/940844',
#  '富貴屋': 'http://www.ipeen.com.tw/shop/56683',
#  '北海道美食展': 'http://www.ipeen.com.tw/shop/603864',
#  '高田食堂-蘆洲店': 'http://www.ipeen.com.tw/shop/51151',
#  '春水堂人文茶館': 'http://www.ipeen.com.tw/shop/1027194',
#  '仙草匯': 'http://www.ipeen.com.tw/shop/1146389',
#  '哈根達斯-Haagen-Dazs-玲瓏心意': 'http://www.ipeen.com.tw/shop/107496',
#  '福井日本料理台菜海鮮餐廳': 'http://www.ipeen.com.tw/shop/26948',
#  '曾記鍋貼': 'http://www.ipeen.com.tw/shop/20414',
#  '麻辣一哥養生麻辣鍋': 'http://www.ipeen.com.tw/shop/1212533',
#  '大自然印尼料理屋': 'http://www.ipeen.com.tw/shop/1045746',
#  '米香屋廣東粥': 'http://www.ipeen.com.tw/shop/1213433',
#  'Arcobaieno-Shaveice-阿巴諾': 'http://www.ipeen.com.tw/shop/1077384',
#  '一町目': 'http://www.ipeen.com.tw/shop/600838',
#  '兔子先生手做餅乾': 'http://www.ipeen.com.tw/shop/614772',
#  '胖逗咖啡': 'http://www.ipeen.com.tw/shop/1040632',
#  '元之氣早午餐輕食-臥龍店': 'http://www.ipeen.com.tw/shop/622868',
#  '外灘1號-私房料理餐盒': 'http://www.ipeen.com.tw/shop/1173086',
#  '秉瀚食品': 'http://www.ipeen.com.tw/shop/85446',
#  '津Q麵疙瘩': 'http://www.ipeen.com.tw/shop/920714',
#  '東門路雞蛋糕': 'http://www.ipeen.com.tw/shop/1234733',
#  '領袖山莊-Leader-原嶺秀山莊': 'http://www.ipeen.com.tw/shop/1001666',
#  '北橫之星原味餐廳': 'http://www.ipeen.com.tw/shop/26976',
#  '春風飲食堂': 'http://www.ipeen.com.tw/shop/39195',
#  '正港臭豆腐': 'http://www.ipeen.com.tw/shop/631956',
#  '舞鶴甲熱炒': 'http://www.ipeen.com.tw/shop/1107719',
#  '南化區土雞閹雞': 'http://www.ipeen.com.tw/shop/1010614',
#  '御品一番炸': 'http://www.ipeen.com.tw/shop/604744',
#  '叫花麵館': 'http://www.ipeen.com.tw/shop/24022',
#  '默砌Galle餐廳': 'http://www.ipeen.com.tw/shop/1102199',
#  'ㄨ子餐廳': 'http://www.ipeen.com.tw/shop/1074038',
#  '唐都紅舍': 'http://www.ipeen.com.tw/shop/610760',
#  '山荷苑': 'http://www.ipeen.com.tw/shop/109030',
#  '本場流專業麵店-北上休息站': 'http://www.ipeen.com.tw/shop/11749',
#  'mis-yakitori': 'http://www.ipeen.com.tw/shop/587298',
#  'Mississippi-Burgers-密西西比完美漢堡': 'http://www.ipeen.com.tw/shop/1201259',
#  '水車': 'http://www.ipeen.com.tw/shop/5428',
#  '竹圍山豬城土雞海鮮餐廳': 'http://www.ipeen.com.tw/shop/1168124',
#  '葡吉小廚-天母SOGO店': 'http://www.ipeen.com.tw/shop/87627',
#  '椿萱雅集': 'http://www.ipeen.com.tw/shop/1205624',
#  'OPEN將夏日盒餐組': 'http://www.ipeen.com.tw/shop/59052',
#  '好記食品號': 'http://www.ipeen.com.tw/shop/47189',
#  '東坡鐵板燒': 'http://www.ipeen.com.tw/shop/8550',
#  '壹咖啡-ecoffee-泰山泰林店': 'http://www.ipeen.com.tw/shop/18165',
#  '貴婦級超值餐盒': 'http://www.ipeen.com.tw/shop/109368',
#  '奇芋大地': 'http://www.ipeen.com.tw/shop/1035058',
#  '三汴頭早餐店': 'http://www.ipeen.com.tw/shop/151933',
#  '小葉覓蜜SECRETEA': 'http://www.ipeen.com.tw/shop/1073488',
#  '極鮮饌-創意料理': 'http://www.ipeen.com.tw/shop/1127810',
#  '七七乳加巧克力': 'http://www.ipeen.com.tw/shop/53438',
#  '大普美蛋糕': 'http://www.ipeen.com.tw/shop/70301',
#  '瑪丹廚房': 'http://www.ipeen.com.tw/shop/994130',
#  '碳德美式牛排館': 'http://www.ipeen.com.tw/shop/1123016',
#  '上乘三家涮涮鍋共合國-台北西園店': 'http://www.ipeen.com.tw/shop/37381',
#  'Starbucks-Coffee-統一星巴克-十全店': 'http://www.ipeen.com.tw/shop/12085',
#  '森八佰-原-森800': 'http://www.ipeen.com.tw/shop/1066266',
#  '悟饕花蓮-和平客來堡店': 'http://www.ipeen.com.tw/shop/1011876',
#  '歐咖啡自家烘焙館': 'http://www.ipeen.com.tw/shop/1162211',
#  '晨間廚房': 'http://www.ipeen.com.tw/shop/983844',
#  '可果美早健康-加': 'http://www.ipeen.com.tw/shop/106733',
#  '三商巧福-愛買店': 'http://www.ipeen.com.tw/shop/20359',
#  '當歸豬腳': 'http://www.ipeen.com.tw/shop/27430',
#  '施子韓國烤肉-韓式泡菜': 'http://www.ipeen.com.tw/shop/616554',
#  '献騰膳': 'http://www.ipeen.com.tw/shop/114223',
#  '梨子咖啡-崇德店': 'http://www.ipeen.com.tw/shop/621074',
#  '雲火日式燒肉': 'http://www.ipeen.com.tw/shop/1074904',
#  '飯飯': 'http://www.ipeen.com.tw/shop/1035780',
#  '家樂福日式大福': 'http://www.ipeen.com.tw/shop/74539',
#  '燕巢水果妹': 'http://www.ipeen.com.tw/shop/950036',
#  '虎屋-憨吉糕點1號店': 'http://www.ipeen.com.tw/shop/1069112',
#  '西雅圖極品咖啡': 'http://www.ipeen.com.tw/shop/88296',
#  '京宴小館': 'http://www.ipeen.com.tw/shop/45533',
#  '澎湖御品家黑糖糕': 'http://www.ipeen.com.tw/shop/136143',
#  '炳叔烤玉米-一中店': 'http://www.ipeen.com.tw/shop/1050746',
#  '廣東鴨莊': 'http://www.ipeen.com.tw/shop/11349',
#  '阿憲冰店': 'http://www.ipeen.com.tw/shop/1032692',
#  '瓦城泰國料理-台中新時代店': 'http://www.ipeen.com.tw/shop/94412',
#  'DH咖啡屋': 'http://www.ipeen.com.tw/shop/136855',
#  '英讚美食館': 'http://www.ipeen.com.tw/shop/1056886',
#  '公園號酸梅湯-忠孝分店': 'http://www.ipeen.com.tw/shop/630474',
#  '肉夾饃-大古堡': 'http://www.ipeen.com.tw/shop/1108367',
#  '春亭園': 'http://www.ipeen.com.tw/shop/962080',
#  '韓鮮韓國料理': 'http://www.ipeen.com.tw/shop/1067254',
#  '鍋之舞麻辣火鍋': 'http://www.ipeen.com.tw/shop/1102928',
#  '宏季鮮味料理': 'http://www.ipeen.com.tw/shop/68107',
#  '味王京御滿堂精燉爌肉麵': 'http://www.ipeen.com.tw/shop/51766',
#  '御品堂中式料理': 'http://www.ipeen.com.tw/shop/1164626',
#  '錢都日式涮涮鍋-新竹中正店': 'http://www.ipeen.com.tw/shop/1187030',
#  '沙鹿肉圓福': 'http://www.ipeen.com.tw/shop/34055',
#  '老紀牛肉土產現宰黃牛肉專賣店': 'http://www.ipeen.com.tw/shop/153189',
#  '健康時刻-巧克力脆片': 'http://www.ipeen.com.tw/shop/101849',
#  '水都活海鮮': 'http://www.ipeen.com.tw/shop/146',
#  '維大力汽水': 'http://www.ipeen.com.tw/shop/65007',
#  '翔雲西餐廳': 'http://www.ipeen.com.tw/shop/123817',
#  '照咖雅品': 'http://www.ipeen.com.tw/shop/1157036',
#  '雙連肉包饅頭食品店': 'http://www.ipeen.com.tw/shop/23086',
#  '46番Mocoto承醬烤香雞排-大昌店': 'http://www.ipeen.com.tw/shop/138033',
#  '宏茂刀削麵專賣店': 'http://www.ipeen.com.tw/shop/20380',
#  '貳樓餐廳SECOND-FLOOR-CAFE-新竹店': 'http://www.ipeen.com.tw/shop/1129412',
#  'Bobii-Frutii-珍珠水果特調': 'http://www.ipeen.com.tw/shop/1071292',
#  '917攝影咖啡館': 'http://www.ipeen.com.tw/shop/116272',
#  'ORIGIN歐芮橘': 'http://www.ipeen.com.tw/shop/927760',
#  '儂特利-仁愛路': 'http://www.ipeen.com.tw/shop/64520',
#  '大上海酥雞': 'http://www.ipeen.com.tw/shop/134419',
#  '統一楓糖蜜雪蛋糕': 'http://www.ipeen.com.tw/shop/41463',
#  '摩啡館': 'http://www.ipeen.com.tw/shop/1070468',
#  '肯尼西點工作室': 'http://www.ipeen.com.tw/shop/63208',
#  '阿得米糕': 'http://www.ipeen.com.tw/shop/1010996',
#  '可爾妃咖啡': 'http://www.ipeen.com.tw/shop/135347',
#  'Bubble-tea': 'http://www.ipeen.com.tw/shop/1128899',
#  '曾家古早味挫冰': 'http://www.ipeen.com.tw/shop/1009474',
#  '國民雞肉妹手工滴雞精': 'http://www.ipeen.com.tw/shop/926386',
#  '老牌牛肉麵': 'http://www.ipeen.com.tw/shop/599150',
#  'MICHA-米迦千層。乳酪蛋糕-板橋正隆店': 'http://www.ipeen.com.tw/shop/1011184',
#  'ROYAL-HOST樂雅樂家庭餐廳-松江店': 'http://www.ipeen.com.tw/shop/16694',
#  '香港回春堂十全大補帖': 'http://www.ipeen.com.tw/shop/16178',
#  '款待': 'http://www.ipeen.com.tw/shop/1143497',
#  '爭鮮迴轉壽司-SUSHI-EXPRESS-漢神店': 'http://www.ipeen.com.tw/shop/103057',
#  '木易師傅壞饅頭': 'http://www.ipeen.com.tw/shop/31675',
#  '段純貞牛肉麵-廣三SOGO分店': 'http://www.ipeen.com.tw/shop/1099115',
#  '台南蜜餞食鋪': 'http://www.ipeen.com.tw/shop/113279',
#  '好吃餡餅': 'http://www.ipeen.com.tw/shop/927590',
#  '鈺鮮創意日式料理': 'http://www.ipeen.com.tw/shop/1023780',
#  'Läbu-Café': 'http://www.ipeen.com.tw/shop/580483',
#  '美達寶美茶': 'http://www.ipeen.com.tw/shop/1235243',
#  '香草鹿Vanilla-Deer': 'http://www.ipeen.com.tw/shop/1056854',
#  '點心魔法師': 'http://www.ipeen.com.tw/shop/42478',
#  'De廚坊酥炸大魷魚': 'http://www.ipeen.com.tw/shop/946078',
#  '大稻埕魯肉飯': 'http://www.ipeen.com.tw/shop/1218803',
#  '孫媽媽手工蛋捲': 'http://www.ipeen.com.tw/shop/58970',
#  '高雄義大皇家酒店-皇樓-原皇冠假日飯店': 'http://www.ipeen.com.tw/shop/92472',
#  '美養莊園': 'http://www.ipeen.com.tw/shop/961238',
#  '大禹貳義式冰淇淋': 'http://www.ipeen.com.tw/shop/1154315',
#  '麥格問格のQ-蘆洲得勝店': 'http://www.ipeen.com.tw/shop/140831',
#  '梅鴻亭客家餐館': 'http://www.ipeen.com.tw/shop/89983',
#  '斜坑庭園咖啡': 'http://www.ipeen.com.tw/shop/1042154',
#  '永亨無骨炸雞': 'http://www.ipeen.com.tw/shop/99114',
#  '御三家備長炭串料理': 'http://www.ipeen.com.tw/shop/1070366',
#  '恬圓布丁豆花': 'http://www.ipeen.com.tw/shop/978546',
#  '排骨酥麵': 'http://www.ipeen.com.tw/shop/85005',
#  '茶窯複合式餐飲': 'http://www.ipeen.com.tw/shop/25304',
#  '圓環牛排': 'http://www.ipeen.com.tw/shop/121637',
#  '右舍咖啡': 'http://www.ipeen.com.tw/shop/65554',
#  '慢調子咖啡館': 'http://www.ipeen.com.tw/shop/961540',
#  '竹間精緻鍋物-三民店': 'http://www.ipeen.com.tw/shop/930986',
#  '無名爆漿奶油紅豆餅': 'http://www.ipeen.com.tw/shop/139995',
#  '丘山小間茶店': 'http://www.ipeen.com.tw/shop/945262',
#  '一之軒-旗艦店': 'http://www.ipeen.com.tw/shop/1213853',
#  '上島珈琲店-誠品站前店': 'http://www.ipeen.com.tw/shop/1224812',
#  '艾麗咖啡檔車': 'http://www.ipeen.com.tw/shop/999480',
#  '極幻燒肉便當': 'http://www.ipeen.com.tw/shop/1190360',
#  'Lacuz-新泰食餐廳-台大公館店': 'http://www.ipeen.com.tw/shop/712070',
#  '鄉野鱒魚餐廳': 'http://www.ipeen.com.tw/shop/37471',
#  '立瑞畜產滴雞精': 'http://www.ipeen.com.tw/shop/1165685',
#  '咖博館-內科店': 'http://www.ipeen.com.tw/shop/82487',
#  '方王媽媽堅果饅頭': 'http://www.ipeen.com.tw/shop/32888',
#  '華國大飯店-甜點遊戲外帶櫃': 'http://www.ipeen.com.tw/shop/41084',
#  '大社今井拉麵': 'http://www.ipeen.com.tw/shop/1020070',
#  '大玉食堂-二館': 'http://www.ipeen.com.tw/shop/944260',
#  '竹村庭園茶藝': 'http://www.ipeen.com.tw/shop/1020738',
#  '蔥抓餅': 'http://www.ipeen.com.tw/shop/64750',
#  '戰鬥口糧': 'http://www.ipeen.com.tw/shop/86395',
#  '里亞料理廚房': 'http://www.ipeen.com.tw/shop/1005318',
#  '揚揚現作茶飲專賣店': 'http://www.ipeen.com.tw/shop/961588',
#  '郭老師養生滴雞精': 'http://www.ipeen.com.tw/shop/970348',
#  'Cha-Cha-Thé-采采食茶文化': 'http://www.ipeen.com.tw/shop/117310',
#  'ANGEL窯烤披薩': 'http://www.ipeen.com.tw/shop/978388',
#  '隨客意臭臭鍋': 'http://www.ipeen.com.tw/shop/964772',
#  '花樂-Flower-Brunch': 'http://www.ipeen.com.tw/shop/1125296',
#  '原味屋日式平價料理-板橋中山店': 'http://www.ipeen.com.tw/shop/941662',
#  '學府路飯糰': 'http://www.ipeen.com.tw/shop/1058758',
#  '吉川日式料理': 'http://www.ipeen.com.tw/shop/635002',
#  '武騰-日式平價料理': 'http://www.ipeen.com.tw/shop/619640',
#  '可果美-一番咖哩-甜味': 'http://www.ipeen.com.tw/shop/84608',
#  '酒庄麵食館': 'http://www.ipeen.com.tw/shop/944698',
#  '巷內義大利廚房': 'http://www.ipeen.com.tw/shop/92624',
#  '玉膳坊月子餐': 'http://www.ipeen.com.tw/shop/926218',
#  '炸雙胞胎': 'http://www.ipeen.com.tw/shop/117341',
#  '嘉禾美食坊': 'http://www.ipeen.com.tw/shop/7901',
#  '生活咖啡小站-旅順': 'http://www.ipeen.com.tw/shop/2616',
#  '蒙兀兒達巴兒印度餐廳': 'http://www.ipeen.com.tw/shop/625042',
#  '福利麵包店': 'http://www.ipeen.com.tw/shop/27368',
#  '阿婆扁食': 'http://www.ipeen.com.tw/shop/580367',
#  '太極韓國烤肉': 'http://www.ipeen.com.tw/shop/1104248',
#  '波奇餐坊-bochibochi-bar': 'http://www.ipeen.com.tw/shop/66494',
#  '魂麵': 'http://www.ipeen.com.tw/shop/9107',
#  '鍋董日式涮涮鍋-大忠直營二店': 'http://www.ipeen.com.tw/shop/1007058',
#  '船來雪淇淋-永和樂華店': 'http://www.ipeen.com.tw/shop/1068766',
#  '幸福提食': 'http://www.ipeen.com.tw/shop/990472',
#  '全好小吃-李記蔥抓餅': 'http://www.ipeen.com.tw/shop/623992',
#  '大湖草莓麵包': 'http://www.ipeen.com.tw/shop/72474',
#  '大紅田麻辣鴛鴦火鍋': 'http://www.ipeen.com.tw/shop/86191',
#  '香蒂咖啡': 'http://www.ipeen.com.tw/shop/3940',
#  '皇樓-乾清之月-中秋月餅': 'http://www.ipeen.com.tw/shop/83522',
#  '基隆廟口大腸蚵仔麵線': 'http://www.ipeen.com.tw/shop/611968',
#  '添好運-統一時代百貨': 'http://www.ipeen.com.tw/shop/1136069',
#  '三商巧福-博愛路': 'http://www.ipeen.com.tw/shop/23391',
#  '太和風涮涮鍋': 'http://www.ipeen.com.tw/shop/28512',
#  '美地有機農園有機蔬菜箱': 'http://www.ipeen.com.tw/shop/991022',
#  '鬼匠拉麵-新莊店': 'http://www.ipeen.com.tw/shop/1141589',
#  '養生食補薑母鴨': 'http://www.ipeen.com.tw/shop/114815',
#  '綠園道石頭飯館': 'http://www.ipeen.com.tw/shop/2514',
#  '小野小町': 'http://www.ipeen.com.tw/shop/1051406',
#  'JIKA時花商行': 'http://www.ipeen.com.tw/shop/619046',
#  '台灣清香冷泡茶': 'http://www.ipeen.com.tw/shop/71428',
#  '米淇淋ic飲料專賣店': 'http://www.ipeen.com.tw/shop/610824',
#  '金饌脆皮烤鴨': 'http://www.ipeen.com.tw/shop/976524',
#  '奇華-鳳凰捲': 'http://www.ipeen.com.tw/shop/601252',
#  '泉日本料理': 'http://www.ipeen.com.tw/shop/9043',
#  '巧多火鍋': 'http://www.ipeen.com.tw/shop/11597',
#  '獨一蒸氣鍋物-桃園店-獨一蒸氣鍋物-中壢店-獨一蒸氣鍋物-新竹店': 'http://www.ipeen.com.tw/shop/1221371',
#  '真柏園': 'http://www.ipeen.com.tw/shop/29685',
#  'Las樂不思蜀': 'http://www.ipeen.com.tw/shop/1077338',
#  '西雅圖極品拿鐵咖啡': 'http://www.ipeen.com.tw/shop/57652',
#  '陳家剉冰': 'http://www.ipeen.com.tw/shop/144333',
#  'Fun-Breeze放風親子餐廳': 'http://www.ipeen.com.tw/shop/1107284',
#  '馬可先生': 'http://www.ipeen.com.tw/shop/599626',
#  '南城泰式料理': 'http://www.ipeen.com.tw/shop/625642',
#  '德芙S新曲線-絲滑般的享受': 'http://www.ipeen.com.tw/shop/593178',
#  '樂錢嘟涮涮鍋-168泰林店': 'http://www.ipeen.com.tw/shop/702258',
#  '碗公': 'http://www.ipeen.com.tw/shop/629740',
#  '黑糖小舖': 'http://www.ipeen.com.tw/shop/578984',
#  '澳氏咖啡Aussie-Cafe': 'http://www.ipeen.com.tw/shop/1029858',
#  'Dunkin-Donuts-和平店': 'http://www.ipeen.com.tw/shop/105905',
#  '好吃麵攤': 'http://www.ipeen.com.tw/shop/28847',
#  '住家快餐店': 'http://www.ipeen.com.tw/shop/36725',
#  '豬寶店': 'http://www.ipeen.com.tw/shop/995822',
#  '甲量古早味枝仔冰': 'http://www.ipeen.com.tw/shop/953638',
#  '有一腿真功夫雞腿卷-桃園觀光夜市': 'http://www.ipeen.com.tw/shop/1215980',
#  '中大鲁肉飯': 'http://www.ipeen.com.tw/shop/52593',
#  '木柵水煎包': 'http://www.ipeen.com.tw/shop/54735',
#  '老先覺麻辣窯燒鍋-高雄仁武店': 'http://www.ipeen.com.tw/shop/1053096',
#  '新馨小籠湯包專賣店': 'http://www.ipeen.com.tw/shop/20332',
#  'Gusta-Pasta-古斯塔義大利麵': 'http://www.ipeen.com.tw/shop/1212479',
#  '福隆簡便當': 'http://www.ipeen.com.tw/shop/106315',
#  '冰火宴燒冰': 'http://www.ipeen.com.tw/shop/64153',
#  '辣媽豬血糕': 'http://www.ipeen.com.tw/shop/48535',
#  '江戶前-秀壽司-無': 'http://www.ipeen.com.tw/shop/49318',
#  '瑞穗生活購物網': 'http://www.ipeen.com.tw/shop/614990',
#  '吳家紅茶冰-高雄海洋店': 'http://www.ipeen.com.tw/shop/625146',
#  '8克cafe': 'http://www.ipeen.com.tw/shop/32718',
#  '早安兔寶堡Good-morning-Tobo': 'http://www.ipeen.com.tw/shop/932318',
#  '小蒙牛頂級麻辣養生鍋-仁德店': 'http://www.ipeen.com.tw/shop/991382',
#  '芷鼎滷味': 'http://www.ipeen.com.tw/shop/800664',
#  '中和包子': 'http://www.ipeen.com.tw/shop/1028378',
#  '旺旺快餐': 'http://www.ipeen.com.tw/shop/1024526',
#  '恆春綠豆饌': 'http://www.ipeen.com.tw/shop/41278',
#  '日和旅-Veggie-Cafe': 'http://www.ipeen.com.tw/shop/1139618',
#  '多多清粥小菜': 'http://www.ipeen.com.tw/shop/64880',
#  '揪厚工茶葉蛋': 'http://www.ipeen.com.tw/shop/105369',
#  '蔡技食品': 'http://www.ipeen.com.tw/shop/1215728',
#  '福泉花生豆腐': 'http://www.ipeen.com.tw/shop/118645',
#  '馥臨港式火鍋-市民店': 'http://www.ipeen.com.tw/shop/7234',
#  '新鮮芒果冰': 'http://www.ipeen.com.tw/shop/623148',
#  '老丁家': 'http://www.ipeen.com.tw/shop/111143',
#  '日札小店': 'http://www.ipeen.com.tw/shop/1062430',
#  '阿場ㄔ豆腐': 'http://www.ipeen.com.tw/shop/987666',
#  'niko-and-TAIPEI': 'http://www.ipeen.com.tw/shop/1227971',
#  '火鍋世家-中壢中原店': 'http://www.ipeen.com.tw/shop/79674',
#  '金龍鳳餐廳': 'http://www.ipeen.com.tw/shop/19901',
#  '三一宅-藝空間': 'http://www.ipeen.com.tw/shop/1177109',
#  '丹鳳肉羹': 'http://www.ipeen.com.tw/shop/979632',
#  '福哥石窯雞': 'http://www.ipeen.com.tw/shop/116443',
#  '三商巧福-中平店': 'http://www.ipeen.com.tw/shop/106346',
#  '阿奇排骨麵': 'http://www.ipeen.com.tw/shop/22950',
#  '友邦冰果室': 'http://www.ipeen.com.tw/shop/26376',
#  'CoCo-s-food-早午餐': 'http://www.ipeen.com.tw/shop/96001',
#  '馨藝庭園咖啡': 'http://www.ipeen.com.tw/shop/943862',
#  'AK-PASTA': 'http://www.ipeen.com.tw/shop/1053234',
#  '霸王紅面': 'http://www.ipeen.com.tw/shop/21323',
#  '7-11香辣雞翅洋芋片': 'http://www.ipeen.com.tw/shop/85994',
#  '安樂市場口台灣第一家鹽酥雞': 'http://www.ipeen.com.tw/shop/1025452',
#  '龐德羅莎-內湖店': 'http://www.ipeen.com.tw/shop/16705',
#  '米其三明治專賣店': 'http://www.ipeen.com.tw/shop/49365',
#  '慶周青果行': 'http://www.ipeen.com.tw/shop/52592',
#  '燒酒窩': 'http://www.ipeen.com.tw/shop/620336',
#  '稻香村懷舊料理': 'http://www.ipeen.com.tw/shop/1215716',
#  '祥好喝': 'http://www.ipeen.com.tw/shop/35167',
#  '鍋神日式涮涮鍋-埔心永美店': 'http://www.ipeen.com.tw/shop/27181',
#  '黃金左腿': 'http://www.ipeen.com.tw/shop/586902',
#  'daily-deli西式盒餐登場': 'http://www.ipeen.com.tw/shop/1042774',
#  '18番燒烤': 'http://www.ipeen.com.tw/shop/620384',
#  '黃金麥芽糖': 'http://www.ipeen.com.tw/shop/64369',
#  '1加1午晚餐': 'http://www.ipeen.com.tw/shop/1157072',
#  '北方小館': 'http://www.ipeen.com.tw/shop/17680',
#  '鮮五丼Don-Mono-丼飯專賣店-沙鹿店': 'http://www.ipeen.com.tw/shop/1010270',
#  '銘鄉鐵板燒': 'http://www.ipeen.com.tw/shop/20619',
#  '百樂廚房BlanceKitchen': 'http://www.ipeen.com.tw/shop/150709',
#  '黃毛ㄚ頭': 'http://www.ipeen.com.tw/shop/67622',
#  '肯德基-台中中港餐廳': 'http://www.ipeen.com.tw/shop/106586',
#  '統帥餐廳': 'http://www.ipeen.com.tw/shop/13557',
#  '茶芝飲-萬丹店': 'http://www.ipeen.com.tw/shop/618990',
#  '盧卡斯炭烤牛排': 'http://www.ipeen.com.tw/shop/1055254',
#  'Starbucks-Coffee-統一星巴克-南園門市': 'http://www.ipeen.com.tw/shop/34208',
#  '天香廚': 'http://www.ipeen.com.tw/shop/593984',
#  '京皇食品': 'http://www.ipeen.com.tw/shop/1050980',
#  '美而美': 'http://www.ipeen.com.tw/shop/51015',
#  '關東日式涮涮鍋': 'http://www.ipeen.com.tw/shop/150337',
#  '沐沐咖啡': 'http://www.ipeen.com.tw/shop/470488',
#  '白面東極品楊桃汁-健行店': 'http://www.ipeen.com.tw/shop/615424',
#  '好豆味豆花-北埔店': 'http://www.ipeen.com.tw/shop/1208771',
#  'Jamling-CAFE-高雄店': 'http://www.ipeen.com.tw/shop/1043060',
#  '聖保羅烘焙花園-新營店': 'http://www.ipeen.com.tw/shop/95757',
#  '宏泰汕頭麵': 'http://www.ipeen.com.tw/shop/998646',
#  '滿願健康蔬食館': 'http://www.ipeen.com.tw/shop/125705',
#  '賴家油飯': 'http://www.ipeen.com.tw/shop/70264',
#  '吳記肉圓-高雄分號': 'http://www.ipeen.com.tw/shop/1050204',
#  '義見鍾情': 'http://www.ipeen.com.tw/shop/52132',
#  '鹿港傳統粉粿冰': 'http://www.ipeen.com.tw/shop/98231',
#  '牛宮頂級牛肉麵': 'http://www.ipeen.com.tw/shop/999382',
#  '鬆餅一番': 'http://www.ipeen.com.tw/shop/587730',
#  '金園滿漢餐廳-代表號': 'http://www.ipeen.com.tw/shop/11617',
#  '水舞饌-大直店': 'http://www.ipeen.com.tw/shop/58381',
#  '墾丁凱撒大飯店-大廰酒吧': 'http://www.ipeen.com.tw/shop/97529',
#  '港點大師港式點心專門店-桃園南崁誠品店': 'http://www.ipeen.com.tw/shop/1031926',
#  '樂活鮮瓶': 'http://www.ipeen.com.tw/shop/613378',
#  '阿宏臭豆腐': 'http://www.ipeen.com.tw/shop/1095467',
#  '甘泉魚麵-鶯歌店': 'http://www.ipeen.com.tw/shop/1034104',
#  '台中河南鄧家道口燒雞': 'http://www.ipeen.com.tw/shop/89865',
#  '不二': 'http://www.ipeen.com.tw/shop/1215125',
#  '九華農業科技股份有限公司': 'http://www.ipeen.com.tw/shop/64579',
#  '泰閣老虎餐廳': 'http://www.ipeen.com.tw/shop/1073556',
#  '蘭陽派雞排-龍泉街店': 'http://www.ipeen.com.tw/shop/30700',
#  '愛儷仕廚坊': 'http://www.ipeen.com.tw/shop/1073298',
#  '河邊海景餐廳-香蕉碼頭': 'http://www.ipeen.com.tw/shop/995478',
#  '崇軒粵式茶點-中壢崇光店': 'http://www.ipeen.com.tw/shop/26544',
#  '喀比食尚館CABI': 'http://www.ipeen.com.tw/shop/835266',
#  '千野麵包-屬於-奧瑪烘焙': 'http://www.ipeen.com.tw/shop/40088',
#  '義大利小鎮-IL-Borgo': 'http://www.ipeen.com.tw/shop/1236626',
#  '初志。日式炸物': 'http://www.ipeen.com.tw/shop/1211966',
#  '手作鮮奶饅頭': 'http://www.ipeen.com.tw/shop/613748',
#  '角子虎水餃館-台北吉林店': 'http://www.ipeen.com.tw/shop/813824',
#  'MR-TOM頂級牛排': 'http://www.ipeen.com.tw/shop/151103',
#  '千鶴日式炒烏龍': 'http://www.ipeen.com.tw/shop/82241',
#  '石二鍋-台南中華東店': 'http://www.ipeen.com.tw/shop/592622',
#  'Katsu勝日式丼物達人': 'http://www.ipeen.com.tw/shop/994946',
#  '印度風': 'http://www.ipeen.com.tw/shop/92487',
#  '興目童紅芭樂蔬果汁': 'http://www.ipeen.com.tw/shop/588854',
#  '劉記大腸蚵仔麵線': 'http://www.ipeen.com.tw/shop/591648',
#  '旭日料理': 'http://www.ipeen.com.tw/shop/980112',
#  '迷你沱': 'http://www.ipeen.com.tw/shop/623876',
#  '徐記醬鴨': 'http://www.ipeen.com.tw/shop/43803',
#  '種子咖啡館-Caff-e-Seme': 'http://www.ipeen.com.tw/shop/606922',
#  '松江庭-博愛旗艦店': 'http://www.ipeen.com.tw/shop/70407',
#  '春谷餐廳': 'http://www.ipeen.com.tw/shop/19844',
#  '紅橘子-光復': 'http://www.ipeen.com.tw/shop/1079400',
#  '洪記阿公麻糬': 'http://www.ipeen.com.tw/shop/911814',
#  '佶佳日式涮涮鍋': 'http://www.ipeen.com.tw/shop/126049',
#  '南田火雞肉飯': 'http://www.ipeen.com.tw/shop/637692',
#  'Mini-Izzy-Cafe-台中店': 'http://www.ipeen.com.tw/shop/1063982',
#  '王義雞肉飯-文信店': 'http://www.ipeen.com.tw/shop/935802',
#  'Artco-c6': 'http://www.ipeen.com.tw/shop/1078032',
#  '和津壽司日本料理': 'http://www.ipeen.com.tw/shop/637098',
#  '翔賀采牛排館': 'http://www.ipeen.com.tw/shop/107754',
#  '大家健康素食': 'http://www.ipeen.com.tw/shop/27087',
#  '新方海產': 'http://www.ipeen.com.tw/shop/145741',
#  '秋吉日本料理': 'http://www.ipeen.com.tw/shop/580963',
#  '亞尼活力': 'http://www.ipeen.com.tw/shop/1062160',
#  '卓家鵝肉': 'http://www.ipeen.com.tw/shop/1021794',
#  '福圓號真功夫養生饅頭-信義店': 'http://www.ipeen.com.tw/shop/985402',
#  'mars': 'http://www.ipeen.com.tw/shop/1006386',
#  '客家小吃': 'http://www.ipeen.com.tw/shop/1013640',
#  '辣典': 'http://www.ipeen.com.tw/shop/578914',
#  '龍辰鑫小健牛': 'http://www.ipeen.com.tw/shop/936598',
#  '蜀川担担麵-牛肉麵': 'http://www.ipeen.com.tw/shop/1147010',
#  '吸tea茶飲': 'http://www.ipeen.com.tw/shop/138539',
#  '鼎泰豐網路便利購': 'http://www.ipeen.com.tw/shop/83719',
#  '休閒小站-台北敦南店': 'http://www.ipeen.com.tw/shop/920478',
#  '燄鐵板燒-西屯總店': 'http://www.ipeen.com.tw/shop/945056',
#  '丹式食堂': 'http://www.ipeen.com.tw/shop/1079264',
#  '飛碟紅豆餅': 'http://www.ipeen.com.tw/shop/91373',
#  '美侯王石頭麻辣火鍋-新竹殿': 'http://www.ipeen.com.tw/shop/1157642',
#  '麥當勞-中壢環中東店': 'http://www.ipeen.com.tw/shop/44603',
#  '小順豐義式焗烤-大業大昌店': 'http://www.ipeen.com.tw/shop/50083',
#  '好香海鮮店': 'http://www.ipeen.com.tw/shop/61',
#  '樂祈洋廚': 'http://www.ipeen.com.tw/shop/1114637',
#  '山珍飯店': 'http://www.ipeen.com.tw/shop/21208',
#  '台北組羊肉羹-和美中正店': 'http://www.ipeen.com.tw/shop/966008',
#  '川邑雞湯拉麵-內湖成功店': 'http://www.ipeen.com.tw/shop/85785',
#  '三輪車關東煮-青海店': 'http://www.ipeen.com.tw/shop/1053122',
#  '拾貳食': 'http://www.ipeen.com.tw/shop/1165004',
#  '廟口點心旗艦店': 'http://www.ipeen.com.tw/shop/1118204',
#  '小熊與熊糕點': 'http://www.ipeen.com.tw/shop/138485',
#  '日鴻蔥抓餅': 'http://www.ipeen.com.tw/shop/117295',
#  '御品園海鮮樓': 'http://www.ipeen.com.tw/shop/21698',
#  '爆爆谷爆米花-蘑菇牛奶巧克力球': 'http://www.ipeen.com.tw/shop/81208',
#  '這一鍋皇室秘藏鍋物-圍爐年菜禮盒': 'http://www.ipeen.com.tw/shop/1055290',
#  '東東豆乳雞': 'http://www.ipeen.com.tw/shop/598752',
#  '明齋素食館': 'http://www.ipeen.com.tw/shop/138507',
#  'COFFEE-館': 'http://www.ipeen.com.tw/shop/5402',
#  '路易莎咖啡-Louisa-Coffee': 'http://www.ipeen.com.tw/shop/1064074',
#  '朝和餅舖': 'http://www.ipeen.com.tw/shop/42775',
#  '益得-玄米土鳳梨酥': 'http://www.ipeen.com.tw/shop/465842',
#  '奶-蜜複合式餐飲': 'http://www.ipeen.com.tw/shop/1225268',
#  '水工鳥人文咖啡館': 'http://www.ipeen.com.tw/shop/1095611',
#  '東京食堂': 'http://www.ipeen.com.tw/shop/77368',
#  '陽明山遊客中心': 'http://www.ipeen.com.tw/shop/943128',
#  '楓壽司': 'http://www.ipeen.com.tw/shop/15026',
#  '食Q牛肉麵食館': 'http://www.ipeen.com.tw/shop/89316',
#  '小南人燒烤廚房': 'http://www.ipeen.com.tw/shop/1026658',
#  '瓦城泰國料理-新光三越台南中山店': 'http://www.ipeen.com.tw/shop/247049',
#  '林記燒餅': 'http://www.ipeen.com.tw/shop/151583',
#  '富鼎旺豬腳餐廳-中正店': 'http://www.ipeen.com.tw/shop/136651',
#  '亞熱帶': 'http://www.ipeen.com.tw/shop/5740',
#  '月琴日式料理': 'http://www.ipeen.com.tw/shop/14938',
#  '福勝亭日式豬排專賣': 'http://www.ipeen.com.tw/shop/753072',
#  '可爾達美食團購': 'http://www.ipeen.com.tw/shop/103368',
#  '品安豆花-家樂福夜市店': 'http://www.ipeen.com.tw/shop/1025050',
#  '315-coffee': 'http://www.ipeen.com.tw/shop/965266',
#  'e世家': 'http://www.ipeen.com.tw/shop/117118',
#  '醬燒天婦羅': 'http://www.ipeen.com.tw/shop/1051230',
#  'Mr-Wheat-小麥先生創意料理-文平義式館': 'http://www.ipeen.com.tw/shop/1036308',
#  '郭老師養生月子餐-南區': 'http://www.ipeen.com.tw/shop/584633',
#  '信哥飯擔': 'http://www.ipeen.com.tw/shop/604018',
#  '洪家回春堂鹽酥雞-水湳分堂': 'http://www.ipeen.com.tw/shop/1231994',
#  '拿坡里披薩‧炸雞-三重店': 'http://www.ipeen.com.tw/shop/18393',
#  '台南仁波霸火龍果': 'http://www.ipeen.com.tw/shop/1069432',
#  '緹克廚房': 'http://www.ipeen.com.tw/shop/1023324',
#  'OMAYA春川炒雞-嘉義民雄店': 'http://www.ipeen.com.tw/shop/1064780',
#  '廣安階-新光三越站前店': 'http://www.ipeen.com.tw/shop/949718',
#  '宜蘭-無骨鳳爪': 'http://www.ipeen.com.tw/shop/126855',
#  'J的鍋物': 'http://www.ipeen.com.tw/shop/1042844',
#  '韓大發': 'http://www.ipeen.com.tw/shop/949898',
#  '阿宗蚵仔煎': 'http://www.ipeen.com.tw/shop/47838',
#  'io-design-studio': 'http://www.ipeen.com.tw/shop/983838',
#  '東門市場興記水餃': 'http://www.ipeen.com.tw/shop/127219',
#  '半夜三點10元清粥小菜瓜仔肉飯': 'http://www.ipeen.com.tw/shop/1044718',
#  '草本荼集-大安森林公園店': 'http://www.ipeen.com.tw/shop/1215302',
#  '松之露養生飲品': 'http://www.ipeen.com.tw/shop/1002060',
#  '仁獻堂': 'http://www.ipeen.com.tw/shop/1043308',
#  '亞都麗緻坊-微風松高': 'http://www.ipeen.com.tw/shop/1021848',
#  '扭轉乾坤-原-合浦刀切麵-永福店': 'http://www.ipeen.com.tw/shop/82040',
#  '福記小廚': 'http://www.ipeen.com.tw/shop/82642',
#  '南京胡同': 'http://www.ipeen.com.tw/shop/1009424',
#  '老北方蒸餃麵食專賣店': 'http://www.ipeen.com.tw/shop/1096775',
#  '光復市場無名燒餅': 'http://www.ipeen.com.tw/shop/1059548',
#  '蓓緹巧克力': 'http://www.ipeen.com.tw/shop/81831',
#  '阿村鵝肉店': 'http://www.ipeen.com.tw/shop/46527',
#  '好嚐烘焙工作室-Tastygooood': 'http://www.ipeen.com.tw/shop/1167818',
#  '大基隆如意花枝羹蚵仔煎': 'http://www.ipeen.com.tw/shop/990554',
#  '阿儒師古早味麵線糊': 'http://www.ipeen.com.tw/shop/109825',
#  '臺灣咖哩店': 'http://www.ipeen.com.tw/shop/1072020',
#  '董娘的糖餅屋-大南店': 'http://www.ipeen.com.tw/shop/611904',
#  '斯麥爾咖啡-smile-cafe-板橋店': 'http://www.ipeen.com.tw/shop/1047894',
#  '沐風複合式餐廳': 'http://www.ipeen.com.tw/shop/992598',
#  '海水屋海鮮快炒': 'http://www.ipeen.com.tw/shop/586888',
#  'HOWTHAI': 'http://www.ipeen.com.tw/shop/782096',
#  '小林香筍茸': 'http://www.ipeen.com.tw/shop/74375',
#  'Nán-19西式廚房': 'http://www.ipeen.com.tw/shop/1055470',
#  '首塢爾韓式料理-文心店': 'http://www.ipeen.com.tw/shop/990524',
#  '廟口厚切牛排': 'http://www.ipeen.com.tw/shop/1176896',
#  'SUNDAY': 'http://www.ipeen.com.tw/shop/1026060',
#  '柯記蚵仔煎': 'http://www.ipeen.com.tw/shop/55591',
#  '福井蓋飯': 'http://www.ipeen.com.tw/shop/986730',
#  '菊田食堂': 'http://www.ipeen.com.tw/shop/10579',
#  '找地方坐Have-a-Seat': 'http://www.ipeen.com.tw/shop/1027148',
#  'Eagle義來藝去': 'http://www.ipeen.com.tw/shop/1029252',
#  '一Ｏ八抹茶茶廊-108-MATCHA-SARO-SOGO復興館': 'http://www.ipeen.com.tw/shop/1061678',
#  '阿吉牛肉麵': 'http://www.ipeen.com.tw/shop/1062716',
#  'Mr-Mrs-O-口氣清新噴霧': 'http://www.ipeen.com.tw/shop/1031994',
#  'RicercaMemoria': 'http://www.ipeen.com.tw/shop/1215887',
#  '五目坊蛋包飯-華夏店': 'http://www.ipeen.com.tw/shop/628800',
#  '緩慢咖啡庭園': 'http://www.ipeen.com.tw/shop/925446',
#  '尊爵大飯店-桃苑': 'http://www.ipeen.com.tw/shop/1390',
#  '張老師水煎包': 'http://www.ipeen.com.tw/shop/59178',
#  '禾馬烘焙': 'http://www.ipeen.com.tw/shop/152549',
#  '珍寶甜不辣專賣店-師大店': 'http://www.ipeen.com.tw/shop/52076',
#  '寶茶': 'http://www.ipeen.com.tw/shop/582917',
#  '壹輪鯛燒': 'http://www.ipeen.com.tw/shop/1133570',
#  '烤香-OVEN-COFFEE': 'http://www.ipeen.com.tw/shop/582945',
#  '第9號乳酪蛋糕-美麗島店': 'http://www.ipeen.com.tw/shop/149001',
#  '焦糖太妃布朗尼-85度C甜點': 'http://www.ipeen.com.tw/shop/1127363',
#  '摩斯漢堡-MOS-BURGER-雙和醫院店': 'http://www.ipeen.com.tw/shop/90943',
#  '烤の胖日式烤土司': 'http://www.ipeen.com.tw/shop/1077718',
#  '柳榮標': 'http://www.ipeen.com.tw/shop/24589',
#  '阿木蛋包麵': 'http://www.ipeen.com.tw/shop/940082',
#  'Kiwi-奇異茶飲': 'http://www.ipeen.com.tw/shop/1032558',
#  '小鮮鹹水雞': 'http://www.ipeen.com.tw/shop/1029486',
#  '牛肉傳奇': 'http://www.ipeen.com.tw/shop/44515',
#  '青青吧-MM-juice-garden': 'http://www.ipeen.com.tw/shop/1092536',
#  'CNI人參金咖啡': 'http://www.ipeen.com.tw/shop/78721',
#  '楊家東山鴨頭': 'http://www.ipeen.com.tw/shop/67597',
#  '華新汕頭細麵': 'http://www.ipeen.com.tw/shop/152363',
#  '香港角港式茶餐廳-東豐店': 'http://www.ipeen.com.tw/shop/1083206',
#  '正老林羊肉爐-中壢店': 'http://www.ipeen.com.tw/shop/29911',
#  '品佳現做鮮奶饅頭': 'http://www.ipeen.com.tw/shop/43694',
#  '優鮮果甜檸檬芭樂-輔大店': 'http://www.ipeen.com.tw/shop/114565',
#  '都布韓式嫩豆腐煲專門店DUBUDUBU-TOFU-HOUSE': 'http://www.ipeen.com.tw/shop/75518',
#  '鐵板雅客平價鐵板燒': 'http://www.ipeen.com.tw/shop/27209',
#  '侑機會活海鮮餐廳': 'http://www.ipeen.com.tw/shop/26087',
#  '滌塵園': 'http://www.ipeen.com.tw/shop/41680',
#  '鼓豆咖啡-Great-Bean-Company': 'http://www.ipeen.com.tw/shop/926474',
#  'Daddy-s-美式餐廳': 'http://www.ipeen.com.tw/shop/926412',
#  '綵宸小吃': 'http://www.ipeen.com.tw/shop/1090412',
#  '翔記廣東煲仔飯': 'http://www.ipeen.com.tw/shop/937770',
#  '海傳文化空間': 'http://www.ipeen.com.tw/shop/197',
#  '藏湘居酒屋': 'http://www.ipeen.com.tw/shop/1048466',
#  '浪漫一生': 'http://www.ipeen.com.tw/shop/16720',
#  '鰻屋日式燒烤便當': 'http://www.ipeen.com.tw/shop/8660',
#  '兩披索靚鍋新莊中平店': 'http://www.ipeen.com.tw/shop/1136228',
#  '廣鮨日本料理': 'http://www.ipeen.com.tw/shop/157141',
#  '三商巧福-南港店': 'http://www.ipeen.com.tw/shop/23169',
#  '法朵手工巧克力-板橋遠百': 'http://www.ipeen.com.tw/shop/622532',
#  '繕魚麵': 'http://www.ipeen.com.tw/shop/13050',
#  '大庄原生美食': 'http://www.ipeen.com.tw/shop/19886',
#  '癡豆咖啡聚所': 'http://www.ipeen.com.tw/shop/1093181',
#  '天香台灣料理': 'http://www.ipeen.com.tw/shop/30401',
#  '不同麵食館': 'http://www.ipeen.com.tw/shop/13144',
#  '米湘園廣式料理': 'http://www.ipeen.com.tw/shop/1147631',
#  '幸福素食館': 'http://www.ipeen.com.tw/shop/17047',
#  'Kevin主廚乳酪塔專賣店': 'http://www.ipeen.com.tw/shop/37606',
#  '壹咖啡-ecoffee-台北昌吉店': 'http://www.ipeen.com.tw/shop/5684',
#  '鮑伯叔叔日本料理餐廳-漢神店': 'http://www.ipeen.com.tw/shop/13214',
#  '85度C鳳梨酥': 'http://www.ipeen.com.tw/shop/77027',
#  '呈信傳統鵝肉店-興隆店': 'http://www.ipeen.com.tw/shop/936478',
#  '雪記粥品': 'http://www.ipeen.com.tw/shop/924726',
#  '義美鮮奶雞蛋布丁': 'http://www.ipeen.com.tw/shop/1140689',
#  '凱蒂冰菓室': 'http://www.ipeen.com.tw/shop/968874',
#  'WOW-哇嗚手工烘焙坊': 'http://www.ipeen.com.tw/shop/150911',
#  '義美小泡芙-超濃-巧克力布朗尼': 'http://www.ipeen.com.tw/shop/481154',
#  '冷鍋寶養生涮涮鍋': 'http://www.ipeen.com.tw/shop/21165',
#  'Better-Man蔬食披薩專賣': 'http://www.ipeen.com.tw/shop/1060700',
#  '遼寧街甜不辣': 'http://www.ipeen.com.tw/shop/66242',
#  'CALL-ME-HOME-可米宏鍋物飲品': 'http://www.ipeen.com.tw/shop/1099757',
#  'LATTICE-拉堤斯比利時列日鬆餅-台北光復店': 'http://www.ipeen.com.tw/shop/1014440',
#  '這一家北方麵食小館-新營店': 'http://www.ipeen.com.tw/shop/11705',
#  '原鍋食堂': 'http://www.ipeen.com.tw/shop/9971',
#  '尚林鐵板燒餐廳': 'http://www.ipeen.com.tw/shop/8485',
#  '陳記大灣粿仔': 'http://www.ipeen.com.tw/shop/1193726',
#  '喬英河粉鳝魚花枝麵': 'http://www.ipeen.com.tw/shop/1011814',
#  '游爸爸蕃薯椪-白糖粿': 'http://www.ipeen.com.tw/shop/56351',
#  '檸檬乳酪可鬆': 'http://www.ipeen.com.tw/shop/63301',
#  '二月咖啡February-coffee-埔里店': 'http://www.ipeen.com.tw/shop/924764',
#  '香巴佬千層大蔥餅王': 'http://www.ipeen.com.tw/shop/771662',
#  '暖暖義式蔬食': 'http://www.ipeen.com.tw/shop/1191077',
#  '三時福利社': 'http://www.ipeen.com.tw/shop/1151099',
#  '曠馬咖啡': 'http://www.ipeen.com.tw/shop/99',
#  '老師傅手工蛋捲': 'http://www.ipeen.com.tw/shop/115806',
#  '青草茶': 'http://www.ipeen.com.tw/shop/1026842',
#  '金門麵店': 'http://www.ipeen.com.tw/shop/95925',
#  '貝奴力咖啡簡餐': 'http://www.ipeen.com.tw/shop/12048',
#  '微笑恬蛋塔': 'http://www.ipeen.com.tw/shop/1032526',
#  '茶的魔手': 'http://www.ipeen.com.tw/shop/37275',
#  '極品珍饌-極品鍋貼': 'http://www.ipeen.com.tw/shop/32119',
#  'BeeZin康萃諾麗美舒眠錠': 'http://www.ipeen.com.tw/shop/1048452',
#  '惠康百貨': 'http://www.ipeen.com.tw/shop/123999',
#  '花旗坊八仙果': 'http://www.ipeen.com.tw/shop/1046110',
#  '大廣味燒臘': 'http://www.ipeen.com.tw/shop/105609',
#  'Money-Jump-親食餐廳親子餐廳': 'http://www.ipeen.com.tw/shop/1072614',
#  '六腳田媽媽QQ米香屋': 'http://www.ipeen.com.tw/shop/34070',
#  '夏可里朵-SOGO復興店': 'http://www.ipeen.com.tw/shop/99116',
#  'Fleur-Lis-芙洛麗大飯店-山日本料理': 'http://www.ipeen.com.tw/shop/935662',
#  '蒸Q手作麵包-有機桑甚-黑糖全麥-紅麴地瓜-香蔥-蘋果肉桂-蜂蜜胡蘿蔔-焦糖地瓜': 'http://www.ipeen.com.tw/shop/54634',
#  '經濟宅急便': 'http://www.ipeen.com.tw/shop/69371',
#  '夯的桶仔雞-中和直營店': 'http://www.ipeen.com.tw/shop/1173881',
#  'Leway-樂の本味-台北合江店': 'http://www.ipeen.com.tw/shop/1159667',
#  '七堵家傳營養三明治': 'http://www.ipeen.com.tw/shop/989260',
#  '青年路烤玉米': 'http://www.ipeen.com.tw/shop/1009214',
#  '磨牙坊': 'http://www.ipeen.com.tw/shop/4995',
#  '田中小廚-恬逸品牌系列館': 'http://www.ipeen.com.tw/shop/1125545',
#  'Ice-Robot': 'http://www.ipeen.com.tw/shop/1133255',
#  '簡實新村-板橋店': 'http://www.ipeen.com.tw/shop/1171685',
#  '永信美研益生錠': 'http://www.ipeen.com.tw/shop/65017',
#  '黑鳶': 'http://www.ipeen.com.tw/shop/1123346',
#  '2派克脆皮雞排-永和永利店': 'http://www.ipeen.com.tw/shop/115701',
#  '露易莎咖啡': 'http://www.ipeen.com.tw/shop/993728',
#  '雪壩豐仁冰': 'http://www.ipeen.com.tw/shop/942810',
#  '壽桃專賣店': 'http://www.ipeen.com.tw/shop/1156304',
#  '真順冰城': 'http://www.ipeen.com.tw/shop/60068',
#  '惡魔雞排-旱溪夜市': 'http://www.ipeen.com.tw/shop/975824',
#  '高佐壽司': 'http://www.ipeen.com.tw/shop/1016072',
#  '東石蚵仔煎回嘉第一味': 'http://www.ipeen.com.tw/shop/590080',
#  '亞米亞米法式現烤泡芙專賣': 'http://www.ipeen.com.tw/shop/96661',
#  '廟口鐹魚湯': 'http://www.ipeen.com.tw/shop/1056136',
#  '大雅牛肉麵': 'http://www.ipeen.com.tw/shop/43811',
#  '三媽臭臭鍋-昆明': 'http://www.ipeen.com.tw/shop/7170',
#  '胖叔叔專業肉羹-城中店': 'http://www.ipeen.com.tw/shop/629094',
#  '光復一元行水餃': 'http://www.ipeen.com.tw/shop/994482',
#  '品紀日本料理': 'http://www.ipeen.com.tw/shop/91613',
#  'CABY-CAFE-Design': 'http://www.ipeen.com.tw/shop/1008840',
#  '阿香早餐古早味蛋餅': 'http://www.ipeen.com.tw/shop/935634',
#  'Cafe-Ballet-芭蕾咖啡館': 'http://www.ipeen.com.tw/shop/48959',
#  '好客-酒吧燒烤-忠孝店': 'http://www.ipeen.com.tw/shop/600598',
#  '馥琳精緻盒餐': 'http://www.ipeen.com.tw/shop/33405',
#  '一寸一杯Cyotto-Ippai': 'http://www.ipeen.com.tw/shop/953086',
#  '上島紅茶咖啡器具批發': 'http://www.ipeen.com.tw/shop/2089',
#  '楊記一品園': 'http://www.ipeen.com.tw/shop/997578',
#  '賀野和風家庭料理': 'http://www.ipeen.com.tw/shop/1034744',
#  'Ming-s-Coffee-Playroom-瞇瞇眼自家烘焙咖啡館': 'http://www.ipeen.com.tw/shop/1033608',
#  '茗穀屋烘焙工作坊': 'http://www.ipeen.com.tw/shop/59020',
#  '大禹街龍鳳腿-阿中店': 'http://www.ipeen.com.tw/shop/53066',
#  '得意中華-高捷左營門市': 'http://www.ipeen.com.tw/shop/119034',
#  '參壹工坊': 'http://www.ipeen.com.tw/shop/1042968',
#  'Uncle-Sam-s-Kitchen-山姆大叔廚房': 'http://www.ipeen.com.tw/shop/1070946',
#  '通豪大飯店-通豪點心坊': 'http://www.ipeen.com.tw/shop/69444',
#  '菜根香飲食店': 'http://www.ipeen.com.tw/shop/38348',
#  '耘華居': 'http://www.ipeen.com.tw/shop/16433',
#  'Rainbow-Snow半月銅鑼燒': 'http://www.ipeen.com.tw/shop/40149',
#  '清海美食城': 'http://www.ipeen.com.tw/shop/1123262',
#  '敘舊偶劇團': 'http://www.ipeen.com.tw/shop/1041244',
#  '詹家水餃店': 'http://www.ipeen.com.tw/shop/11668',
#  '金園美食館': 'http://www.ipeen.com.tw/shop/965710',
#  '十勝川鍋物-大里店二店': 'http://www.ipeen.com.tw/shop/1026498',
#  '米卡希達': 'http://www.ipeen.com.tw/shop/1136288',
#  '鮮奶茶': 'http://www.ipeen.com.tw/shop/67692',
#  'Coffee-House-客廳-The-Living-Room': 'http://www.ipeen.com.tw/shop/985026',
#  '金彩紅豆湯': 'http://www.ipeen.com.tw/shop/115890',
#  '家門口': 'http://www.ipeen.com.tw/shop/144569',
#  '珈琲館': 'http://www.ipeen.com.tw/shop/2561',
#  '雷門豆花仙草專賣店-桃園中華店': 'http://www.ipeen.com.tw/shop/38706',
#  '三發點心總匯': 'http://www.ipeen.com.tw/shop/50102',
#  '華仔菠蘿油': 'http://www.ipeen.com.tw/shop/958298',
#  '江浙順利園餐廳': 'http://www.ipeen.com.tw/shop/8092',
#  '肯得利香雞排': 'http://www.ipeen.com.tw/shop/1165886',
#  '蜜月館餐廳': 'http://www.ipeen.com.tw/shop/984104',
#  '一Ｏ八抹茶茶廊-108-MATCHA-SARO': 'http://www.ipeen.com.tw/shop/985950',
#  '百湯王拉麵專賣店': 'http://www.ipeen.com.tw/shop/632168',
#  '雲南傣族小吃店': 'http://www.ipeen.com.tw/shop/38122',
#  '壽司-源': 'http://www.ipeen.com.tw/shop/73262',
#  'ORO咖啡屋': 'http://www.ipeen.com.tw/shop/10439',
#  '以耳傳耳': 'http://www.ipeen.com.tw/shop/443426',
#  '東海蓮心冰‧雞爪凍-逢甲店': 'http://www.ipeen.com.tw/shop/40857',
#  '元吉屋': 'http://www.ipeen.com.tw/shop/108171',
#  '懷舊小棧': 'http://www.ipeen.com.tw/shop/44465',
#  '不二家日式拉麵': 'http://www.ipeen.com.tw/shop/6023',
#  '隨食烤吧': 'http://www.ipeen.com.tw/shop/54526',
#  '亞緹': 'http://www.ipeen.com.tw/shop/978502',
#  '錢堡涮涮鍋': 'http://www.ipeen.com.tw/shop/21097',
#  '東昇溫泉羊肉爐': 'http://www.ipeen.com.tw/shop/978768',
#  'Corner-Coffee': 'http://www.ipeen.com.tw/shop/61861',
#  '大陸飲食店': 'http://www.ipeen.com.tw/shop/105946',
#  '山東麵食': 'http://www.ipeen.com.tw/shop/70442',
#  '迦拿庭園餐廳': 'http://www.ipeen.com.tw/shop/615264',
#  '大鼻南包子饅頭專賣店': 'http://www.ipeen.com.tw/shop/920612',
#  '日和食堂Biyori': 'http://www.ipeen.com.tw/shop/1075704',
#  '香港全球美食美式餐廳': 'http://www.ipeen.com.tw/shop/1068114',
#  '石堂-極和牛石頭燒': 'http://www.ipeen.com.tw/shop/1110164',
#  '澳洲特級燕麥片': 'http://www.ipeen.com.tw/shop/76645',
#  '山東徐老爹韭菜盒': 'http://www.ipeen.com.tw/shop/125675',
#  '貴族世家牛排-嘉義博愛': 'http://www.ipeen.com.tw/shop/1219463',
#  '寶泉-12入天皇賞': 'http://www.ipeen.com.tw/shop/149035',
#  '齊力乳酪蛋糕': 'http://www.ipeen.com.tw/shop/66131',
#  '仁香素食專賣坊': 'http://www.ipeen.com.tw/shop/17122',
#  'Sweet-tea-惡魔茶飲-屏東民生店': 'http://www.ipeen.com.tw/shop/1079486',
#  '明日咖啡店': 'http://www.ipeen.com.tw/shop/1019292',
#  '金客來小吃店-信貳分店': 'http://www.ipeen.com.tw/shop/107539',
#  '艾薇時尚烘焙麵包坊': 'http://www.ipeen.com.tw/shop/975396',
#  '淳茗雪霜冰': 'http://www.ipeen.com.tw/shop/97636',
#  'Yes-Juice-是的果汁工作室': 'http://www.ipeen.com.tw/shop/1051210',
#  '小黑豆豆手感烘焙-中央店': 'http://www.ipeen.com.tw/shop/592568',
#  '新鮮市集樂活鮮美家-挪威青飛片': 'http://www.ipeen.com.tw/shop/55479',
#  '輝華早餐店': 'http://www.ipeen.com.tw/shop/1034132',
#  '北歐先生Mr-Nordic-奶香薄捲': 'http://www.ipeen.com.tw/shop/94196',
#  '3mins美式早午餐-精誠店': 'http://www.ipeen.com.tw/shop/34874',
#  '德芳素食': 'http://www.ipeen.com.tw/shop/15367',
#  'Starbucks-Coffee-統一星巴克-三重門市': 'http://www.ipeen.com.tw/shop/929094',
#  '這個鍋-潭子店': 'http://www.ipeen.com.tw/shop/1059596',
#  '健安雞肉飯': 'http://www.ipeen.com.tw/shop/122747',
#  '海洋生成水': 'http://www.ipeen.com.tw/shop/988668',
#  '冰棒': 'http://www.ipeen.com.tw/shop/1183907',
#  '大漢酵素D-tox-Enzyme蔬果植物醱酵粉': 'http://www.ipeen.com.tw/shop/939508',
#  'Bula-冷奶油咖椰吐司': 'http://www.ipeen.com.tw/shop/1076156',
#  '御宴坊': 'http://www.ipeen.com.tw/shop/597600',
#  '范記便當': 'http://www.ipeen.com.tw/shop/985746',
#  '丹堤咖啡研磨專賣店-Dante-Coffee-信義二店': 'http://www.ipeen.com.tw/shop/4094',
#  '樂芙廚坊': 'http://www.ipeen.com.tw/shop/999118',
#  '伍饌道車輪餅': 'http://www.ipeen.com.tw/shop/992796',
#  '詠晴黃金泡菜': 'http://www.ipeen.com.tw/shop/1184306',
#  '台中爆漿燒烤杏鮑菇': 'http://www.ipeen.com.tw/shop/1058070',
#  'Starbucks-Coffee-統一星巴克-佛陀館': 'http://www.ipeen.com.tw/shop/118900',
#  'CAFE-IN-AUDIO': 'http://www.ipeen.com.tw/shop/4778',
#  '國光饅頭': 'http://www.ipeen.com.tw/shop/20258',
#  'New-Cal': 'http://www.ipeen.com.tw/shop/1172405',
#  '廣海食堂': 'http://www.ipeen.com.tw/shop/602762',
#  '巫雲雲南菜': 'http://www.ipeen.com.tw/shop/41555',
#  '福樂麵店': 'http://www.ipeen.com.tw/shop/39422',
#  '巧克力蛋糕': 'http://www.ipeen.com.tw/shop/599166',
#  '丹寧象咖啡館': 'http://www.ipeen.com.tw/shop/578468',
#  '錢溏': 'http://www.ipeen.com.tw/shop/1033162',
#  '提摩太咖啡': 'http://www.ipeen.com.tw/shop/634682',
#  '蘇杭餐廳-濟南店': 'http://www.ipeen.com.tw/shop/22553',
#  '丁香魚達人': 'http://www.ipeen.com.tw/shop/1037892',
#  '九斗桑海田園': 'http://www.ipeen.com.tw/shop/1179',
#  '鍋太炫': 'http://www.ipeen.com.tw/shop/1114679',
#  '先喝道-原-古典玫瑰園': 'http://www.ipeen.com.tw/shop/49604',
#  '麗芬肉粽': 'http://www.ipeen.com.tw/shop/41034',
#  '東池便當': 'http://www.ipeen.com.tw/shop/626004',
#  '彩虹廚房': 'http://www.ipeen.com.tw/shop/962138',
#  '日瀠壽司便當': 'http://www.ipeen.com.tw/shop/530534',
#  'CASA': 'http://www.ipeen.com.tw/shop/1070736',
#  '微甜幸福菓舖': 'http://www.ipeen.com.tw/shop/122387',
#  '味丹-Q10-美顏活飲': 'http://www.ipeen.com.tw/shop/85898',
#  '吉野家-Yoshinoya-古亭店': 'http://www.ipeen.com.tw/shop/593610',
#  '平價小館': 'http://www.ipeen.com.tw/shop/95122',
#  '汆堂鮮物火鍋': 'http://www.ipeen.com.tw/shop/1003928',
#  '萬歲牌松子野菇麥飲-新口味-鹹的': 'http://www.ipeen.com.tw/shop/594438',
#  '台南度小月擔仔麵': 'http://www.ipeen.com.tw/shop/1205126',
#  '糖村蛋糕-竹北自強店': 'http://www.ipeen.com.tw/shop/108069',
#  '珍品石鍋': 'http://www.ipeen.com.tw/shop/1105433',
#  '杉原夜食': 'http://www.ipeen.com.tw/shop/1218593',
#  '宏宇農產': 'http://www.ipeen.com.tw/shop/1121282',
#  '何首烏養生雞湯': 'http://www.ipeen.com.tw/shop/1065018',
#  '快倒閉的咖啡廳': 'http://www.ipeen.com.tw/shop/33382',
#  '強羊肉爐牛肉鍋': 'http://www.ipeen.com.tw/shop/583009',
#  '來客豆腐': 'http://www.ipeen.com.tw/shop/1127186',
#  '卡迪那mini-脆薯鹽味': 'http://www.ipeen.com.tw/shop/1112951',
#  '林家莊-鮮味賞': 'http://www.ipeen.com.tw/shop/933010',
#  '下營鵝肉店': 'http://www.ipeen.com.tw/shop/141085',
#  '冰河時期複合式冰品店': 'http://www.ipeen.com.tw/shop/25163',
#  '十三張紅油炒手': 'http://www.ipeen.com.tw/shop/1099379',
#  '小象廚房': 'http://www.ipeen.com.tw/shop/1228238',
#  'Starbucks-Coffee-統一星巴克-大甲': 'http://www.ipeen.com.tw/shop/1032802',
#  '鄭記扁食': 'http://www.ipeen.com.tw/shop/152033',
#  '承德餐廳': 'http://www.ipeen.com.tw/shop/7880',
#  '滷大王麻辣燙': 'http://www.ipeen.com.tw/shop/945754',
#  '梁記嘉義雞肉飯': 'http://www.ipeen.com.tw/shop/49280',
#  'Muse-Café': 'http://www.ipeen.com.tw/shop/1018524',
#  '銅猴子餐廳': 'http://www.ipeen.com.tw/shop/6914',
#  '無招牌小吃店': 'http://www.ipeen.com.tw/shop/66134',
#  '六福精食館-春日店': 'http://www.ipeen.com.tw/shop/30341',
#  '大長金韓式料理': 'http://www.ipeen.com.tw/shop/963844',
#  '文德路22巷無名早餐': 'http://www.ipeen.com.tw/shop/85541',
#  '台灣水牛城': 'http://www.ipeen.com.tw/shop/47905',
#  '阿勝咖哩': 'http://www.ipeen.com.tw/shop/1164782',
#  '合家廚房': 'http://www.ipeen.com.tw/shop/1104641',
#  '魔力小樂': 'http://www.ipeen.com.tw/shop/1002258',
#  '滿意阿滿姨鹽地蕃茄': 'http://www.ipeen.com.tw/shop/615082',
#  '幸福80號美味早餐': 'http://www.ipeen.com.tw/shop/968424',
#  '壬之初': 'http://www.ipeen.com.tw/shop/926582',
#  '啡比尋嚐-GAIA-Vegan-Cafe': 'http://www.ipeen.com.tw/shop/1048454',
#  '小山記日式方塊燒': 'http://www.ipeen.com.tw/shop/1059074',
#  '郭媽媽蔥油餅': 'http://www.ipeen.com.tw/shop/621028',
#  '阿棉麻糬-鹽埕店': 'http://www.ipeen.com.tw/shop/586281',
#  '莎巴克咖啡': 'http://www.ipeen.com.tw/shop/128309',
#  '壺八拉麵屋': 'http://www.ipeen.com.tw/shop/12926',
#  '金福隆-華貴絲襪': 'http://www.ipeen.com.tw/shop/980202',
#  'Dining-Akio-明男の廚房': 'http://www.ipeen.com.tw/shop/118748',
#  '傻愛莊咖啡館': 'http://www.ipeen.com.tw/shop/2260',
#  'WaWa樂園-永和保平店': 'http://www.ipeen.com.tw/shop/1077972',
#  '好運土司': 'http://www.ipeen.com.tw/shop/1072682',
#  '中壢老牌牛肉麵': 'http://www.ipeen.com.tw/shop/1150304',
#  '台中金典酒店-高第鐵板燒': 'http://www.ipeen.com.tw/shop/74109',
#  '全家-巧克力布朗尼': 'http://www.ipeen.com.tw/shop/588890',
#  '永豐年菜': 'http://www.ipeen.com.tw/shop/75128',
#  '洪記燒腊食品': 'http://www.ipeen.com.tw/shop/26565',
#  '品福夢想世界': 'http://www.ipeen.com.tw/shop/114644',
#  ...}

# %%
i
# Out:
# 6546

# %% [markdown]
# # try to concurrent.futures 無法跑到一半存檔、會被BAN

# %%
import concurrent.futures
import json
import os
import requests
from bs4 import BeautifulSoup as bs
import logging
import time

# %%
if not os.path.exists('./data'):
    os.makedirs('./data')

# %%
def getlink(page,linkset,):
    headers = {"User-Agent":"Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/62.0.3202.94 Safari/537.36"}
    res=requests.get("http://www.ipeen.com.tw/search/taiwan/000/1-100-0-0/?baragain=1&p=1&p="+str(page),headers=headers)
    if res.status_code==200:
        soup=bs(res.text,'lxml')
        res.close()
        dienlist=soup.select("article.serMain > div.result > section > article.serItem > div > h3")#找尋店家資訊
        dienlist=[dien for dien in dienlist  if not dien.select_one("span.status")]#去除搬遷或關店狀態的店家
        dienlist=["http://www.ipeen.com.tw"+dien.select_one("a")["href"] for dien in dienlist 
                  if dien.select_one("a")["data-action"]!="ad_shop"]#去除廣告店家，留下網址
        linkset.update(dienlist)#將該頁的店list加入set中(順便去除重複)
#         if i%10==0:#每十頁存一次
#             print(len(linkset))
#             websitedict={Website.split("-",1)[1]:Website.split("-",1)[0] for Website in linkset}
#             with open("./data/linkset.json","w") as f:
#                 json.dump(websitedict,f)
    else:#沒連線成功也存
        print("status_code="+str(res.status_code))
        res.close()
        print(len(linkset))
#         websitedict={Website.split("-",1)[1]:Website.split("-",1)[0] for Website in linkset}
#         with open("./data/linkset.json","w") as f:
#             json.dump(websitedict,f)
#     websitedict={Website.split("-",1)[1]:Website.split("-",1)[0] for Website in linkset}
    return dienlist

# %%
res=requests.get("http://www.ipeen.com.tw/search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=1")
soup=bs(res.text,"lxml")
res.close()
page=int(soup.select("#search > article > hgroup > h2 > b")[0].text)//15
print(str(page)+"pages")

WebsiteSet=set()
start = time.time()
i=0
with concurrent.futures.ThreadPoolExecutor(max_workers=20) as executor:
    jobInfo = [executor.submit(getlink, page, WebsiteSet) for page in range(1,page+1)]
    for future in concurrent.futures.as_completed(jobInfo):
        try:
            data = future.result()
            WebsiteSet.update(data)
        except Exception as e:
            print(e)
            print("zzz")
            pass
        
end = time.time()  
print("-----------------")
print(end-start)

websitedict={Website.split("-",1)[1]:Website.split("-",1)[0] for Website in WebsiteSet}
with open("./data/linkset.json","w") as f:
    json.dump(websitedict,f)
# Out:
# 11168pages
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=411 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000000AB9C048>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=413 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000000C41BC18>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=414 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000001267AEF0>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=415 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x0000000011DBE550>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=416 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000001069F9E8>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=417 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x0000000010689860>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=418 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x0000000009D4C320>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=419 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000000F7CF6A0>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=423 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000000FE39320>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=425 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000000CA7FA20>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=426 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000000F6DD198>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=428 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000001003C5C0>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=429 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000001003C978>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=434 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x00000000129CF550>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=436 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000000C4329B0>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=437 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000000C432630>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=441 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000001067C898>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=444 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000000BEA28D0>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=445 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x0000000010447518>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=446 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000000BEA2828>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=451 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000000FAFE128>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=452 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000000FAFEDD8>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=453 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000000BEA2390>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=455 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000001214FDA0>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=457 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x00000000107ADD30>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=459 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000000FAE8D68>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=460 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000000F625710>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=462 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000000F993CF8>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=463 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000000F9784E0>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=466 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000001214F7B8>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=468 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000000BE94EB8>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=469 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000000C45CB38>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=472 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000000FAE8A58>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=474 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000000F84A748>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=476 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000000FBF6E10>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=477 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000000FBF56D8>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=479 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000000FBF59B0>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=485 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000000B309D68>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=487 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000000F794C18>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=488 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x00000000107DDF60>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=491 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000000FBF5518>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=492 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000000AB68FD0>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=494 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000000AB744E0>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=495 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000000A256438>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=496 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000000BE3E0F0>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=497 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x00000000107D7780>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=502 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x00000000107C3470>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=503 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000000F5DB630>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=507 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000000FB1FA20>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=508 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000000FB1FD30>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=510 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000000FB1FDA0>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=512 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000000A616BA8>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=519 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000000A4B37F0>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=520 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000000C9F32E8>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=521 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000000C4934E0>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=522 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000000C172E10>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=523 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000000C16F630>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=524 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000000C16FE10>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=525 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000000C164588>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=529 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000001033C2B0>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=533 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000000F49B5F8>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=536 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000000F305080>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=540 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000000C47C1D0>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=541 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000000B95DC88>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=542 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x00000000129BF390>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=549 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000000A503F60>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=551 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000000C499668>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=554 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000000F822668>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=558 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x0000000011D0B550>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz

# %%
with open("./data/linkSet.json") as f:
    x=json.load(f)

# %%
len(x)

# %% [markdown]
# # try to change proxy 失敗

# %%
import concurrent.futures
import json
import os
import requests
from bs4 import BeautifulSoup as bs
import logging
import time
import re
if not os.path.exists('./data'):
    os.makedirs('./data')

# %%
def getlink(page,linkset,proxylist):
    res=requests.get("http://www.ipeen.com.tw/search/taiwan/000/1-0-0-0/?baragain=1&p="+str(page))
    if res.status_code==200:
        soup=bs(res.text,'lxml')
        res.close()
        dienlist=soup.select("article.serMain > div.result > section > article.serItem > div > h3")#找尋店家資訊
        dienlist=[dien for dien in dienlist  if not dien.select_one("span.status")]#去除搬遷或關店狀態的店家
        dienlist=["http://www.ipeen.com.tw"+dien.select_one("a")["href"] for dien in dienlist 
                  if dien.select_one("a")["data-action"]!="ad_shop"]#去除廣告店家，留下網址
#         linkset.update(dienlist)#將該頁的店list加入set中(順便去除重複)
#         if i%10==0:#每十頁存一次
#             print(len(linkset))
#             websitedict={Website.split("-",1)[1]:Website.split("-",1)[0] for Website in linkset}
#             with open("./data/linkset.json","w") as f:
#                 json.dump(websitedict,f)
    else:#沒連線成功也存
        res.close()
        n=0
        res=requests.get("http://www.ipeen.com.tw/search/taiwan/000/1-0-0-0/?baragain=1&p="+str(page),proxies=proxylist[n])
        while res.status_code!=200:
            n+=1
            res.close()
            res=requests.get("http://www.ipeen.com.tw/search/taiwan/000/1-0-0-0/?baragain=1&p="+str(page),proxies=proxylist[n])
        dienlist=soup.select("article.serMain > div.result > section > article.serItem > div > h3")#找尋店家資訊
        dienlist=[dien for dien in dienlist  if not dien.select_one("span.status")]#去除搬遷或關店狀態的店家
        dienlist=["http://www.ipeen.com.tw"+dien.select_one("a")["href"] for dien in dienlist 
                  if dien.select_one("a")["data-action"]!="ad_shop"]#去除廣告店家，留下網址
#         websitedict={Website.split("-",1)[1]:Website.split("-",1)[0] for Website in linkset}
#         with open("./data/linkset.json","w") as f:
#             json.dump(websitedict,f)
#     websitedict={Website.split("-",1)[1]:Website.split("-",1)[0] for Website in linkset}
    return dienlist

# %%
url="https://free-proxy-list.net/"
res=requests.get(url)
soup=bs(res.text,"lxml")
proxylist=re.findall("([0-2]?[0-9]?[0-9]\.[0-2]?[0-9]?[0-9]\.[0-2]?[0-9]?[0-9]\.[0-2]?[0-9]?[0-9])(80)",soup.text)
proxylist=[{'http':'http://'+proxy[0]+':'+proxy[1]} for proxy in proxylist]
proxylist
# Out:
# [{'http': 'http://145.239.93.189:80'},
#  {'http': 'http://58.229.253.103:80'},
#  {'http': 'http://217.18.142.29:80'},
#  {'http': 'http://210.212.73.61:80'},
#  {'http': 'http://217.65.217.68:80'},
#  {'http': 'http://37.187.120.123:80'},
#  {'http': 'http://112.201.89.228:80'},
#  {'http': 'http://62.182.25.38:80'},
#  {'http': 'http://185.34.20.82:80'},
#  {'http': 'http://47.89.41.164:80'},
#  {'http': 'http://80.234.41.140:80'},
#  {'http': 'http://203.58.117.34:80'},
#  {'http': 'http://37.29.48.78:80'},
#  {'http': 'http://78.25.98.114:80'},
#  {'http': 'http://62.161.11.21:80'},
#  {'http': 'http://95.188.161.39:80'},
#  {'http': 'http://213.136.77.246:80'},
#  {'http': 'http://201.16.197.16:80'},
#  {'http': 'http://80.83.20.14:80'},
#  {'http': 'http://178.49.136.82:80'},
#  {'http': 'http://175.126.38.224:80'},
#  {'http': 'http://13.78.125.167:80'},
#  {'http': 'http://104.199.40.49:80'},
#  {'http': 'http://203.74.4.4:80'},
#  {'http': 'http://89.22.175.43:80'},
#  {'http': 'http://212.83.164.85:80'},
#  {'http': 'http://218.50.2.102:80'},
#  {'http': 'http://62.161.11.20:80'},
#  {'http': 'http://203.74.4.2:80'},
#  {'http': 'http://52.76.214.252:80'},
#  {'http': 'http://52.163.62.13:80'},
#  {'http': 'http://50.245.168.108:80'},
#  {'http': 'http://5.189.133.231:80'},
#  {'http': 'http://203.177.151.24:80'},
#  {'http': 'http://200.109.236.60:80'},
#  {'http': 'http://95.85.50.218:80'},
#  {'http': 'http://191.102.85.234:80'},
#  {'http': 'http://189.206.107.6:80'},
#  {'http': 'http://45.77.124.178:80'},
#  {'http': 'http://183.91.23.194:80'},
#  {'http': 'http://170.246.114.196:80'},
#  {'http': 'http://89.188.229.14:80'},
#  {'http': 'http://91.191.173.37:80'},
#  {'http': 'http://203.74.4.6:80'},
#  {'http': 'http://52.15.116.121:80'},
#  {'http': 'http://213.136.89.121:80'},
#  {'http': 'http://139.255.55.146:80'},
#  {'http': 'http://52.164.244.34:80'},
#  {'http': 'http://94.232.55.100:80'},
#  {'http': 'http://78.36.43.79:80'},
#  {'http': 'http://80.211.166.20:80'},
#  {'http': 'http://202.9.104.10:80'},
#  {'http': 'http://52.57.95.123:80'},
#  {'http': 'http://143.0.188.213:80'},
#  {'http': 'http://203.74.4.0:80'},
#  {'http': 'http://203.74.4.5:80'},
#  {'http': 'http://89.98.94.50:80'},
#  {'http': 'http://5.196.189.50:80'},
#  {'http': 'http://81.21.75.142:80'},
#  {'http': 'http://47.52.117.173:80'},
#  {'http': 'http://46.218.73.162:80'},
#  {'http': 'http://203.74.4.7:80'},
#  {'http': 'http://145.239.4.43:80'},
#  {'http': 'http://64.34.21.84:80'},
#  {'http': 'http://92.62.79.187:80'},
#  {'http': 'http://211.127.160.240:80'},
#  {'http': 'http://203.74.4.1:80'},
#  {'http': 'http://31.173.33.140:80'},
#  {'http': 'http://37.182.212.118:80'},
#  {'http': 'http://61.90.105.123:80'},
#  {'http': 'http://118.172.116.53:80'},
#  {'http': 'http://177.207.92.74:80'},
#  {'http': 'http://36.74.35.204:80'},
#  {'http': 'http://95.71.0.215:80'},
#  {'http': 'http://223.206.22.220:80'},
#  {'http': 'http://118.97.191.203:80'},
#  {'http': 'http://180.246.149.11:80'},
#  {'http': 'http://202.138.254.18:80'},
#  {'http': 'http://128.73.128.64:80'},
#  {'http': 'http://190.137.124.160:80'},
#  {'http': 'http://179.179.87.177:80'},
#  {'http': 'http://180.254.117.16:80'},
#  {'http': 'http://182.253.42.10:80'},
#  {'http': 'http://125.24.102.129:80'},
#  {'http': 'http://37.237.242.17:80'},
#  {'http': 'http://46.101.255.137:80'},
#  {'http': 'http://197.245.70.47:80'},
#  {'http': 'http://46.61.39.119:80'},
#  {'http': 'http://125.161.140.143:80'},
#  {'http': 'http://125.25.33.209:80'},
#  {'http': 'http://101.109.222.161:80'},
#  {'http': 'http://36.66.217.179:80'},
#  {'http': 'http://36.73.156.84:80'},
#  {'http': 'http://170.233.149.107:80'},
#  {'http': 'http://180.183.88.52:80'},
#  {'http': 'http://94.37.74.23:80'},
#  {'http': 'http://36.73.78.33:80'},
#  {'http': 'http://128.75.82.61:80'},
#  {'http': 'http://178.164.237.72:80'},
#  {'http': 'http://125.166.15.229:80'},
#  {'http': 'http://118.96.187.196:80'},
#  {'http': 'http://187.79.9.253:80'},
#  {'http': 'http://196.202.194.85:80'},
#  {'http': 'http://52.178.68.67:80'},
#  {'http': 'http://124.122.184.11:80'},
#  {'http': 'http://183.88.51.30:80'},
#  {'http': 'http://159.255.167.131:80'},
#  {'http': 'http://36.83.25.71:80'},
#  {'http': 'http://203.74.4.3:80'},
#  {'http': 'http://83.169.244.38:80'},
#  {'http': 'http://217.79.54.68:80'},
#  {'http': 'http://113.190.244.106:80'},
#  {'http': 'http://128.199.234.64:80'},
#  {'http': 'http://181.65.131.102:80'},
#  {'http': 'http://45.32.51.175:80'},
#  {'http': 'http://141.101.5.155:80'},
#  {'http': 'http://43.230.145.176:80'},
#  {'http': 'http://106.201.230.227:80'},
#  {'http': 'http://103.217.104.74:80'},
#  {'http': 'http://69.144.49.11:80'},
#  {'http': 'http://177.5.28.3:80'},
#  {'http': 'http://190.248.158.194:80'},
#  {'http': 'http://124.13.235.11:80'},
#  {'http': 'http://31.173.209.111:80'},
#  {'http': 'http://201.209.239.131:80'},
#  {'http': 'http://103.54.25.253:80'},
#  {'http': 'http://5.1.32.38:80'},
#  {'http': 'http://203.177.162.154:80'},
#  {'http': 'http://5.188.155.243:80'},
#  {'http': 'http://180.211.94.170:80'},
#  {'http': 'http://179.189.248.174:80'},
#  {'http': 'http://189.221.102.190:80'},
#  {'http': 'http://110.170.150.166:80'},
#  {'http': 'http://217.13.222.161:80'},
#  {'http': 'http://50.245.168.106:80'},
#  {'http': 'http://167.114.196.153:80'},
#  {'http': 'http://84.204.83.178:80'},
#  {'http': 'http://148.251.211.123:80'},
#  {'http': 'http://125.165.91.64:80'},
#  {'http': 'http://83.169.38.204:80'},
#  {'http': 'http://202.159.36.70:80'},
#  {'http': 'http://139.195.35.48:80'},
#  {'http': 'http://95.159.69.161:80'},
#  {'http': 'http://176.235.99.166:80'},
#  {'http': 'http://124.41.240.105:80'},
#  {'http': 'http://181.65.84.97:80'},
#  {'http': 'http://200.54.45.170:80'},
#  {'http': 'http://103.76.45.185:80'},
#  {'http': 'http://180.183.108.243:80'},
#  {'http': 'http://139.59.118.118:80'},
#  {'http': 'http://200.203.144.98:80'},
#  {'http': 'http://110.77.199.219:80'},
#  {'http': 'http://202.153.228.130:80'}]

# %%
res=requests.get("http://www.ipeen.com.tw/search/taiwan/000/1-0-0-0/?baragain=1&p=1")
soup=bs(res.text,"lxml")
res.close()
page=int(soup.select("#search > article > hgroup > h2 > b")[0].text)//15
print(str(page)+"pages")

WebsiteSet=set()
start = time.time()
with concurrent.futures.ThreadPoolExecutor(max_workers=20) as executor:
    jobInfo = [executor.submit(getlink, page, WebsiteSet,proxylist) for page in range(1,page+1)]
    for future in concurrent.futures.as_completed(jobInfo):
        try:
            data = future.result()
            WebsiteSet.update(data)
        except Exception as e:
            print(e)
            print("zzz")
            pass
        
end = time.time()  
print("-----------------")
print(end-start)

websitedict={Website.split("-",1)[1]:Website.split("-",1)[0] for Website in WebsiteSet}
with open("./data/linkset.json","w") as f:
    json.dump(websitedict,f)

# %%
with open("./data/linkSet.json") as f:
    x=json.load(f)

# %% [markdown]
# # 變更proxy的兩種方法
# import requests
# s = requests.Session()
# s.proxies = {"http": "http://61.233.25.166:80"}
# r = s.get("http://www.google.com")
# print(r.text)
#
# import requests
# r = requests.get("http://www.google.com", proxies={"http": "http://61.233.25.166:80"})
# print(r.text)

# %% [markdown]
# # 變更user agent的方法
# headers = {
#     'User-Agent': 'My User Agent 1.0',
#     'From': 'youremail@domain.com'  # This is another valid field
# }
# response = requests.get(url, headers=headers)

# %% [markdown]
# # bs抓取某tag or tag群的方法
# soup.select("tag > tag > tag")
# 如:soup.select("#search > article > hgroup > h2 > b")
#
# soup.find_all('tag', attrs={'tag內的元素': '元素名稱'})
# 如:soup.find_all('a', attrs={'data-label': '店名'})
