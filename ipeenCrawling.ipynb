# %%
import json
import os
import requests
from bs4 import BeautifulSoup as bs
import logging

# %% [markdown]
# #  第一版-待將set改成id 不抓取搬遷 抓取關店

# %%
# if not os.path.exists('./data'):
#     os.makedirs('./data')
# URL="http://www.ipeen.com.tw/search/taiwan/000/1-100-0-0/?baragain=1"

# res=requests.get(URL+"&p=1")
# soup=bs(res.text,"lxml")
# res.close()
# page=int(soup.select("#search > article > hgroup > h2 > b")[0].text)//15
# print(str(page)+"pages(all)")

# #初始set、頁
# WebsiteSet=set()
# pagebegin=1

# #如果已抓取，由中途開始繼續抓取 (抓取的資料set及頁面)
# if os.path.exists('./data/WebsiteSet.json'):
#     with open("./data/WebsiteSet.json") as f:
#         x=json.load(f)
#         WebsiteSet=set(x[dien]+"-"+dien for dien in x)
#         pagebegin=int(len(WebsiteSet)/15)

# if os.path.exists('./data/beginpage.txt'):
#     with open("./data/beginpage.txt") as p:
#         pagebegin=int(p.read())
        
# print("開始頁%s"%pagebegin)
        
# # headers = {"User-Agent":"Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/62.0.3202.94 Safari/537.36"}

# #會累積的變數>>i WebsiteSet
# for i in range(pagebegin,page+1):
#     res=requests.get(URL+"&p="+str(i))
#     if res.status_code==200:
#         soup=bs(res.text,'lxml')
#         dienlist=soup.select("article.serMain > div.result > section > article.serItem > div > h3")
#         dienlist=[dien for dien in dienlist  if not dien.select_one("span.status")]#去除搬遷或關店狀態的店家
#         dienlist=["http://www.ipeen.com.tw"+dien.select_one("a")["href"] for dien in dienlist 
#                   if dien.select_one("a")["data-action"]!="ad_shop"]#去除廣告店家，並留下網址
#         WebsiteSet.update(dienlist)
#         if i%10==0:
#             print("-----\n已抓取第%s頁"%i)
#             print(len(WebsiteSet))
#             websitedict={Website.split("-",1)[1]:Website.split("-",1)[0] for Website in WebsiteSet}
#             print("實際剩餘%s，店名重複%s"%(len(websitedict),len(WebsiteSet)-len(websitedict)))
#             with open("./data/WebsiteSet.json","w") as f:
#                 json.dump(websitedict,f)
#             with open("./data/beginpage.txt","w") as p:
#                 p.write(str(i))
#     else:
#         print("status_code"+str(res.status_code))
#         print(len(WebsiteSet))
#         websitedict={Website.split("-",1)[1]:Website.split("-",1)[0] for Website in WebsiteSet}
#         with open("./data/WebsiteSet.json","w") as f:
#             json.dump(websitedict,f)
#         with open("./data/beginpage.txt","w") as p:
#             p.write(str(i))
            
# websitedict={Website.split("-",1)[1]:Website.split("-",1)[0] for Website in WebsiteSet}
# with open("./data/WebsiteSet.json","w") as f:
#     json.dump(websitedict,f)
# with open("./data/beginpage.txt","w") as p:
#     p.write(str(i))
# Out:
# 11170pages(all)
# 開始頁6670
# -----
# 已抓取第6670頁
# 94131
# 實際剩餘94131，店名重複0
# -----
# 已抓取第6680頁
# 94281
# 實際剩餘94268，店名重複13
# -----
# 已抓取第6690頁
# 94431
# 實際剩餘94409，店名重複22
# -----
# 已抓取第6700頁
# 94581
# 實際剩餘94550，店名重複31
# -----
# 已抓取第6710頁
# 94731
# 實際剩餘94691，店名重複40
# -----
# 已抓取第6720頁
# 94881
# 實際剩餘94831，店名重複50
# -----
# 已抓取第6730頁
# 95031
# 實際剩餘94978，店名重複53
# -----
# 已抓取第6740頁
# 95181
# 實際剩餘95123，店名重複58
# -----
# 已抓取第6750頁
# 95331
# 實際剩餘95262，店名重複69
# -----
# 已抓取第6760頁
# 95481
# 實際剩餘95407，店名重複74
# -----
# 已抓取第6770頁
# 95631
# 實際剩餘95548，店名重複83
# -----
# 已抓取第6780頁
# 95781
# 實際剩餘95694，店名重複87
# -----
# 已抓取第6790頁
# 95931
# 實際剩餘95836，店名重複95
# -----
# 已抓取第6800頁
# 96081
# 實際剩餘95974，店名重複107
# -----
# 已抓取第6810頁
# 96231
# 實際剩餘96113，店名重複118
# -----
# 已抓取第6820頁
# 96381
# 實際剩餘96254，店名重複127
# -----
# 已抓取第6830頁
# 96531
# 實際剩餘96397，店名重複134
# -----
# 已抓取第6840頁
# 96681
# 實際剩餘96536，店名重複145
# -----
# 已抓取第6850頁
# 96831
# 實際剩餘96677，店名重複154
# -----
# 已抓取第6860頁
# 96981
# 實際剩餘96815，店名重複166
# -----
# 已抓取第6870頁
# 97131
# 實際剩餘96955，店名重複176
# -----
# 已抓取第6880頁
# 97281
# 實際剩餘97099，店名重複182
# -----
# 已抓取第6890頁
# 97431
# 實際剩餘97242，店名重複189
# -----
# 已抓取第6900頁
# 97581
# 實際剩餘97383，店名重複198
# -----
# 已抓取第6910頁
# 97731
# 實際剩餘97521，店名重複210
# -----
# 已抓取第6920頁
# 97881
# 實際剩餘97662，店名重複219
# -----
# 已抓取第6930頁
# 98031
# 實際剩餘97800，店名重複231
# -----
# 已抓取第6940頁
# 98181
# 實際剩餘97941，店名重複240
# -----
# 已抓取第6950頁
# 98331
# 實際剩餘98084，店名重複247
# -----
# 已抓取第6960頁
# 98481
# 實際剩餘98227，店名重複254
# -----
# 已抓取第6970頁
# 98631
# 實際剩餘98363，店名重複268
# -----
# 已抓取第6980頁
# 98781
# 實際剩餘98502，店名重複279
# -----
# 已抓取第6990頁
# 98931
# 實際剩餘98642，店名重複289
# -----
# 已抓取第7000頁
# 99081
# 實際剩餘98776，店名重複305
# -----
# 已抓取第7010頁
# 99231
# 實際剩餘98915，店名重複316
# -----
# 已抓取第7020頁
# 99381
# 實際剩餘99057，店名重複324
# -----
# 已抓取第7030頁
# 99531
# 實際剩餘99194，店名重複337
# -----
# 已抓取第7040頁
# 99681
# 實際剩餘99334，店名重複347
# -----
# 已抓取第7050頁
# 99831
# 實際剩餘99474，店名重複357
# -----
# 已抓取第7060頁
# 99981
# 實際剩餘99611，店名重複370
# -----
# 已抓取第7070頁
# 100131
# 實際剩餘99748，店名重複383
# -----
# 已抓取第7080頁
# 100281
# 實際剩餘99891，店名重複390
# -----
# 已抓取第7090頁
# 100431
# 實際剩餘100025，店名重複406
# -----
# 已抓取第7100頁
# 100581
# 實際剩餘100165，店名重複416
# -----
# 已抓取第7110頁
# 100731
# 實際剩餘100304，店名重複427
# -----
# 已抓取第7120頁
# 100881
# 實際剩餘100439，店名重複442
# -----
# 已抓取第7130頁
# 101031
# 實際剩餘100579，店名重複452
# -----
# 已抓取第7140頁
# 101181
# 實際剩餘100719，店名重複462
# -----
# 已抓取第7150頁
# 101331
# 實際剩餘100858，店名重複473
# -----
# 已抓取第7160頁
# 101481
# 實際剩餘100993，店名重複488
# -----
# 已抓取第7170頁
# 101631
# 實際剩餘101133，店名重複498
# -----
# 已抓取第7180頁
# 101781
# 實際剩餘101276，店名重複505
# -----
# 已抓取第7190頁
# 101931
# 實際剩餘101415，店名重複516
# -----
# 已抓取第7200頁
# 102081
# 實際剩餘101553，店名重複528
# -----
# 已抓取第7210頁
# 102231
# 實際剩餘101692，店名重複539
# -----
# 已抓取第7220頁
# 102381
# 實際剩餘101832，店名重複549
# -----
# 已抓取第7230頁
# 102531
# 實際剩餘101964，店名重複567
# -----
# 已抓取第7240頁
# 102681
# 實際剩餘102109，店名重複572
# -----
# 已抓取第7250頁
# 102831
# 實際剩餘102248，店名重複583
# -----
# 已抓取第7260頁
# 102981
# 實際剩餘102390，店名重複591
# -----
# 已抓取第7270頁
# 103131
# 實際剩餘102530，店名重複601
# -----
# 已抓取第7280頁
# 103281
# 實際剩餘102667，店名重複614
# -----
# 已抓取第7290頁
# 103431
# 實際剩餘102808，店名重複623
# -----
# 已抓取第7300頁
# 103581
# 實際剩餘102942，店名重複639
# -----
# 已抓取第7310頁
# 103731
# 實際剩餘103079，店名重複652
# -----
# 已抓取第7320頁
# 103881
# 實際剩餘103212，店名重複669
# -----
# 已抓取第7330頁
# 104031
# 實際剩餘103348，店名重複683
# -----
# 已抓取第7340頁
# 104181
# 實際剩餘103483，店名重複698
# -----
# 已抓取第7350頁
# 104331
# 實際剩餘103629，店名重複702
# -----
# 已抓取第7360頁
# 104481
# 實際剩餘103769，店名重複712
# -----
# 已抓取第7370頁
# 104631
# 實際剩餘103911，店名重複720
# -----
# 已抓取第7380頁
# 104781
# 實際剩餘104055，店名重複726
# -----
# 已抓取第7390頁
# 104931
# 實際剩餘104187，店名重複744
# -----
# 已抓取第7400頁
# 105081
# 實際剩餘104328，店名重複753
# -----
# 已抓取第7410頁
# 105231
# 實際剩餘104468，店名重複763
# -----
# 已抓取第7420頁
# 105381
# 實際剩餘104604，店名重複777
# -----
# 已抓取第7430頁
# 105531
# 實際剩餘104741，店名重複790
# -----
# 已抓取第7440頁
# 105681
# 實際剩餘104879，店名重複802
# -----
# 已抓取第7450頁
# 105831
# 實際剩餘105014，店名重複817
# -----
# 已抓取第7460頁
# 105981
# 實際剩餘105152，店名重複829
# -----
# 已抓取第7470頁
# 106131
# 實際剩餘105294，店名重複837
# -----
# 已抓取第7480頁
# 106281
# 實際剩餘105435，店名重複846
# -----
# 已抓取第7490頁
# 106431
# 實際剩餘105572，店名重複859
# -----
# 已抓取第7500頁
# 106581
# 實際剩餘105713，店名重複868
# -----
# 已抓取第7510頁
# 106731
# 實際剩餘105851，店名重複880
# -----
# 已抓取第7520頁
# 106881
# 實際剩餘105987，店名重複894
# -----
# 已抓取第7530頁
# 107031
# 實際剩餘106129，店名重複902
# -----
# 已抓取第7540頁
# 107181
# 實際剩餘106265，店名重複916
# -----
# 已抓取第7550頁
# 107331
# 實際剩餘106387，店名重複944
# -----
# 已抓取第7560頁
# 107481
# 實際剩餘106522，店名重複959
# -----
# 已抓取第7570頁
# 107631
# 實際剩餘106663，店名重複968
# -----
# 已抓取第7580頁
# 107781
# 實際剩餘106804，店名重複977
# -----
# 已抓取第7590頁
# 107931
# 實際剩餘106939，店名重複992
# -----
# 已抓取第7600頁
# 108081
# 實際剩餘107075，店名重複1006
# -----
# 已抓取第7610頁
# 108231
# 實際剩餘107214，店名重複1017
# -----
# 已抓取第7620頁
# 108381
# 實際剩餘107351，店名重複1030
# -----
# 已抓取第7630頁
# 108531
# 實際剩餘107492，店名重複1039
# -----
# 已抓取第7640頁
# 108681
# 實際剩餘107606，店名重複1075
# -----
# 已抓取第7650頁
# 108831
# 實際剩餘107749，店名重複1082
# -----
# 已抓取第7660頁
# 108981
# 實際剩餘107886，店名重複1095
# -----
# 已抓取第7670頁
# 109131
# 實際剩餘108014，店名重複1117
# -----
# 已抓取第7680頁
# 109281
# 實際剩餘108154，店名重複1127
# -----
# 已抓取第7690頁
# 109431
# 實際剩餘108299，店名重複1132
# -----
# 已抓取第7700頁
# 109581
# 實際剩餘108436，店名重複1145
# -----
# 已抓取第7710頁
# 109731
# 實際剩餘108575，店名重複1156
# -----
# 已抓取第7720頁
# 109881
# 實際剩餘108706，店名重複1175
# -----
# 已抓取第7730頁
# 110031
# 實際剩餘108850，店名重複1181
# -----
# 已抓取第7740頁
# 110181
# 實際剩餘108991，店名重複1190
# -----
# 已抓取第7750頁
# 110331
# 實際剩餘109128，店名重複1203
# -----
# 已抓取第7760頁
# 110481
# 實際剩餘109261，店名重複1220
# -----
# 已抓取第7770頁
# 110631
# 實際剩餘109391，店名重複1240
# -----
# 已抓取第7780頁
# 110781
# 實際剩餘109518，店名重複1263
# -----
# 已抓取第7790頁
# 110931
# 實際剩餘109654，店名重複1277
# -----
# 已抓取第7800頁
# 111081
# 實際剩餘109795，店名重複1286
# -----
# 已抓取第7810頁
# 111231
# 實際剩餘109938，店名重複1293
# -----
# 已抓取第7820頁
# 111381
# 實際剩餘110071，店名重複1310
# -----
# 已抓取第7830頁
# 111531
# 實際剩餘110201，店名重複1330
# -----
# 已抓取第7840頁
# 111681
# 實際剩餘110324，店名重複1357
# -----
# 已抓取第7850頁
# 111831
# 實際剩餘110449，店名重複1382
# -----
# 已抓取第7860頁
# 111981
# 實際剩餘110582，店名重複1399
# -----
# 已抓取第7870頁
# 112131
# 實際剩餘110706，店名重複1425
# -----
# 已抓取第7880頁
# 112281
# 實際剩餘110835，店名重複1446
# -----
# 已抓取第7890頁
# 112431
# 實際剩餘110971，店名重複1460
# -----
# 已抓取第7900頁
# 112581
# 實際剩餘111109，店名重複1472
# -----
# 已抓取第7910頁
# 112731
# 實際剩餘111250，店名重複1481
# -----
# 已抓取第7920頁
# 112881
# 實際剩餘111385，店名重複1496
# -----
# 已抓取第7930頁
# 113031
# 實際剩餘111516，店名重複1515
# -----
# 已抓取第7940頁
# 113181
# 實際剩餘111655，店名重複1526
# -----
# 已抓取第7950頁
# 113331
# 實際剩餘111789，店名重複1542
# -----
# 已抓取第7960頁
# 113481
# 實際剩餘111925，店名重複1556
# -----
# 已抓取第7970頁
# 113631
# 實際剩餘112067，店名重複1564
# -----
# 已抓取第7980頁
# 113781
# 實際剩餘112208，店名重複1573
# -----
# 已抓取第7990頁
# 113931
# 實際剩餘112345，店名重複1586
# -----
# 已抓取第8000頁
# 114081
# 實際剩餘112475，店名重複1606
# -----
# 已抓取第8010頁
# 114231
# 實際剩餘112591，店名重複1640
# -----
# 已抓取第8020頁
# 114381
# 實際剩餘112720，店名重複1661
# -----
# 已抓取第8030頁
# 114531
# 實際剩餘112846，店名重複1685
# -----
# 已抓取第8040頁
# 114681
# 實際剩餘112968，店名重複1713
# -----
# 已抓取第8050頁
# 114831
# 實際剩餘113096，店名重複1735
# -----
# 已抓取第8060頁
# 114981
# 實際剩餘113228，店名重複1753
# -----
# 已抓取第8070頁
# 115131
# 實際剩餘113368，店名重複1763
# -----
# 已抓取第8080頁
# 115281
# 實際剩餘113515，店名重複1766
# -----
# 已抓取第8090頁
# 115431
# 實際剩餘113656，店名重複1775
# -----
# 已抓取第8100頁
# 115581
# 實際剩餘113797，店名重複1784
# -----
# 已抓取第8110頁
# 115731
# 實際剩餘113928，店名重複1803
# -----
# 已抓取第8120頁
# 115881
# 實際剩餘114068，店名重複1813
# -----
# 已抓取第8130頁
# 116031
# 實際剩餘114205，店名重複1826
# -----
# 已抓取第8140頁
# 116181
# 實際剩餘114338，店名重複1843
# -----
# 已抓取第8150頁
# 116331
# 實際剩餘114463，店名重複1868
# -----
# 已抓取第8160頁
# 116481
# 實際剩餘114594，店名重複1887
# -----
# 已抓取第8170頁
# 116631
# 實際剩餘114726，店名重複1905
# -----
# 已抓取第8180頁
# 116781
# 實際剩餘114863，店名重複1918
# -----
# 已抓取第8190頁
# 116931
# 實際剩餘114976，店名重複1955
# -----
# 已抓取第8200頁
# 117081
# 實際剩餘115108，店名重複1973
# -----
# 已抓取第8210頁
# 117231
# 實際剩餘115233，店名重複1998
# -----
# 已抓取第8220頁
# 117381
# 實際剩餘115354，店名重複2027
# -----
# 已抓取第8230頁
# 117531
# 實際剩餘115485，店名重複2046
# -----
# 已抓取第8240頁
# 117681
# 實際剩餘115624，店名重複2057
# -----
# 已抓取第8250頁
# 117831
# 實際剩餘115761，店名重複2070
# -----
# 已抓取第8260頁
# 117981
# 實際剩餘115901，店名重複2080
# -----
# 已抓取第8270頁
# 118131
# 實際剩餘116030，店名重複2101
# -----
# 已抓取第8280頁
# 118281
# 實際剩餘116169，店名重複2112
# -----
# 已抓取第8290頁
# 118431
# 實際剩餘116309，店名重複2122
# -----
# 已抓取第8300頁
# 118581
# 實際剩餘116446，店名重複2135
# -----
# 已抓取第8310頁
# 118731
# 實際剩餘116583，店名重複2148
# -----
# 已抓取第8320頁
# 118881
# 實際剩餘116705，店名重複2176
# -----
# 已抓取第8330頁
# 119031
# 實際剩餘116838，店名重複2193
# -----
# 已抓取第8340頁
# 119181
# 實際剩餘116974，店名重複2207
# -----
# 已抓取第8350頁
# 119331
# 實際剩餘117111，店名重複2220
# -----
# 已抓取第8360頁
# 119481
# 實際剩餘117256，店名重複2225
# -----
# 已抓取第8370頁
# 119631
# 實際剩餘117398，店名重複2233
# -----
# 已抓取第8380頁
# 119781
# 實際剩餘117540，店名重複2241
# -----
# 已抓取第8390頁
# 119931
# 實際剩餘117679，店名重複2252
# -----
# 已抓取第8400頁
# 120081
# 實際剩餘117808，店名重複2273
# -----
# 已抓取第8410頁
# 120231
# 實際剩餘117936，店名重複2295
# -----
# 已抓取第8420頁
# 120381
# 實際剩餘118067，店名重複2314
# -----
# 已抓取第8430頁
# 120531
# 實際剩餘118200，店名重複2331
# -----
# 已抓取第8440頁
# 120681
# 實際剩餘118333，店名重複2348
# -----
# 已抓取第8450頁
# 120831
# 實際剩餘118467，店名重複2364
# -----
# 已抓取第8460頁
# 120981
# 實際剩餘118601，店名重複2380
# -----
# 已抓取第8470頁
# 121131
# 實際剩餘118740，店名重複2391
# -----
# 已抓取第8480頁
# 121281
# 實際剩餘118875，店名重複2406
# -----
# 已抓取第8490頁
# 121431
# 實際剩餘119007，店名重複2424
# -----
# 已抓取第8500頁
# 121581
# 實際剩餘119148，店名重複2433
# -----
# 已抓取第8510頁
# 121731
# 實際剩餘119285，店名重複2446
# -----
# 已抓取第8520頁
# 121881
# 實際剩餘119420，店名重複2461
# -----
# 已抓取第8530頁
# 122031
# 實際剩餘119556，店名重複2475
# -----
# 已抓取第8540頁
# 122181
# 實際剩餘119697，店名重複2484
# -----
# 已抓取第8550頁
# 122331
# 實際剩餘119840，店名重複2491
# -----
# 已抓取第8560頁
# 122481
# 實際剩餘119981，店名重複2500
# -----
# 已抓取第8570頁
# 122631
# 實際剩餘120125，店名重複2506
# -----
# 已抓取第8580頁
# 122781
# 實際剩餘120264，店名重複2517
# -----
# 已抓取第8590頁
# 122931
# 實際剩餘120400，店名重複2531
# -----
# 已抓取第8600頁
# 123081
# 實際剩餘120539，店名重複2542
# -----
# 已抓取第8610頁
# 123231
# 實際剩餘120677，店名重複2554
# -----
# 已抓取第8620頁
# 123381
# 實際剩餘120818，店名重複2563
# -----
# 已抓取第8630頁
# 123531
# 實際剩餘120958，店名重複2573
# -----
# 已抓取第8640頁
# 123681
# 實際剩餘121095，店名重複2586
# -----
# 已抓取第8650頁
# 123831
# 實際剩餘121231，店名重複2600
# -----
# 已抓取第8660頁
# 123981
# 實際剩餘121374，店名重複2607
# -----
# 已抓取第8670頁
# 124131
# 實際剩餘121514，店名重複2617
# -----
# 已抓取第8680頁
# 124281
# 實際剩餘121656，店名重複2625
# -----
# 已抓取第8690頁
# 124431
# 實際剩餘121799，店名重複2632
# -----
# 已抓取第8700頁
# 124581
# 實際剩餘121937，店名重複2644
# -----
# 已抓取第8710頁
# 124731
# 實際剩餘122075，店名重複2656
# -----
# 已抓取第8720頁
# 124881
# 實際剩餘122212，店名重複2669
# -----
# 已抓取第8730頁
# 125031
# 實際剩餘122350，店名重複2681
# -----
# 已抓取第8740頁
# 125181
# 實際剩餘122486，店名重複2695
# -----
# 已抓取第8750頁
# 125331
# 實際剩餘122617，店名重複2714
# -----
# 已抓取第8760頁
# 125481
# 實際剩餘122755，店名重複2726
# -----
# 已抓取第8770頁
# 125631
# 實際剩餘122898，店名重複2733
# -----
# 已抓取第8780頁
# 125781
# 實際剩餘123025，店名重複2756
# -----
# 已抓取第8790頁
# 125931
# 實際剩餘123158，店名重複2773
# -----
# 已抓取第8800頁
# 126081
# 實際剩餘123302，店名重複2779
# -----
# 已抓取第8810頁
# 126231
# 實際剩餘123445，店名重複2786
# -----
# 已抓取第8820頁
# 126381
# 實際剩餘123585，店名重複2796
# -----
# 已抓取第8830頁
# 126531
# 實際剩餘123715，店名重複2816
# -----
# 已抓取第8840頁
# 126681
# 實際剩餘123853，店名重複2828
# -----
# 已抓取第8850頁
# 126831
# 實際剩餘123984，店名重複2847
# -----
# 已抓取第8860頁
# 126981
# 實際剩餘124109，店名重複2872
# -----
# 已抓取第8870頁
# 127131
# 實際剩餘124243，店名重複2888
# -----
# 已抓取第8880頁
# 127281
# 實際剩餘124375，店名重複2906
# -----
# 已抓取第8890頁
# 127431
# 實際剩餘124508，店名重複2923
# -----
# 已抓取第8900頁
# 127581
# 實際剩餘124634，店名重複2947
# -----
# 已抓取第8910頁
# 127731
# 實際剩餘124770，店名重複2961
# -----
# 已抓取第8920頁
# 127881
# 實際剩餘124912，店名重複2969
# -----
# 已抓取第8930頁
# 128031
# 實際剩餘125043，店名重複2988
# -----
# 已抓取第8940頁
# 128181
# 實際剩餘125184，店名重複2997
# -----
# 已抓取第8950頁
# 128331
# 實際剩餘125317，店名重複3014
# -----
# 已抓取第8960頁
# 128481
# 實際剩餘125454，店名重複3027
# -----
# 已抓取第8970頁
# 128631
# 實際剩餘125579，店名重複3052
# -----
# 已抓取第8980頁
# 128781
# 實際剩餘125697，店名重複3084
# -----
# 已抓取第8990頁
# 128931
# 實際剩餘125824，店名重複3107
# -----
# 已抓取第9000頁
# 129081
# 實際剩餘125965，店名重複3116
# -----
# 已抓取第9010頁
# 129231
# 實際剩餘126102，店名重複3129
# -----
# 已抓取第9020頁
# 129381
# 實際剩餘126243，店名重複3138
# -----
# 已抓取第9030頁
# 129531
# 實際剩餘126379，店名重複3152
# -----
# 已抓取第9040頁
# 129681
# 實際剩餘126515，店名重複3166
# -----
# 已抓取第9050頁
# 129831
# 實際剩餘126653，店名重複3178
# -----
# 已抓取第9060頁
# 129981
# 實際剩餘126787，店名重複3194
# -----
# 已抓取第9070頁
# 130131
# 實際剩餘126927，店名重複3204
# -----
# 已抓取第9080頁
# 130281
# 實際剩餘127067，店名重複3214
# -----
# 已抓取第9090頁
# 130431
# 實際剩餘127208，店名重複3223
# -----
# 已抓取第9100頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9110頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9120頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9130頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9140頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9150頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9160頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9170頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9180頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9190頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9200頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9210頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9220頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9230頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9240頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9250頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9260頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9270頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9280頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9290頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9300頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9310頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9320頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9330頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9340頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9350頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9360頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9370頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9380頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9390頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9400頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9410頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9420頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9430頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9440頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9450頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9460頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9470頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9480頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9490頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9500頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9510頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9520頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9530頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9540頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9550頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9560頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9570頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9580頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9590頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9600頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9610頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9620頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9630頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9640頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9650頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9660頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9670頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9680頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9690頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9700頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9710頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9720頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9730頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9740頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9750頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9760頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9770頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9780頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9790頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9800頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9810頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9820頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9830頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9840頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9850頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9860頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9870頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9880頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9890頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9900頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9910頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9920頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9930頁
# 130562
# 實際剩餘127333，店名重複3229
# -----
# 已抓取第9940頁
# 130562
# 實際剩餘127333，店名重複3229
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# D:\anaconda\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379             try:  # Python 2.7, use buffering of HTTP responses
# --> 380                 httplib_response = conn.getresponse(buffering=True)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-37-cc1600783608> in <module>()
#      30 #會累積的變數>>i WebsiteSet
#      31 for i in range(pagebegin,page+1):
# ---> 32     res=requests.get(URL+"&p="+str(i))
#      33     if res.status_code==200:
#      34         soup=bs(res.text,'lxml')
#
# D:\anaconda\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# D:\anaconda\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# D:\anaconda\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# D:\anaconda\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     616
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#     620         # Total elapsed time of the request (approximately)
#
# D:\anaconda\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438                     decode_content=False,
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#     442
#
# D:\anaconda\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   timeout=timeout_obj,
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#     603             # If we're going to release the connection in ``finally:``, then
#
# D:\anaconda\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#     382                 try:
# --> 383                     httplib_response = conn.getresponse()
#     384                 except Exception as e:
#     385                     # Remove the TypeError from the exception chain in Python 3;
#
# D:\anaconda\lib\http\client.py in getresponse(self)
#    1329         try:
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#    1333                 self.close()
#
# D:\anaconda\lib\http\client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# D:\anaconda\lib\http\client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# D:\anaconda\lib\socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
#將{店名：網址}格式的json改成{ID:網址}
# if os.path.exists('./data/WebsiteSet.json'):
#     with open("./data/WebsiteSet.json") as f:
#         x=json.load(f)
# y={x[dien].split("/")[-1]:x[dien] for dien in x}
# with open("./data/WebsiteSet.json","w") as f:
#     json.dump(y,f)

# %% [markdown]
# # 第二版 -存取資料改為 id:網址

# %%
import json
import os
import requests
from bs4 import BeautifulSoup as bs
import logging

if not os.path.exists('./data'):
    os.makedirs('./data')
URL="http://www.ipeen.com.tw/search/taiwan/000/1-100-0-0/?baragain=1"

res=requests.get(URL+"&p=1")
soup=bs(res.text,"lxml")
res.close()
page=int(soup.select("#search > article > hgroup > h2 > b")[0].text)//15
print(str(page)+"pages(all)")

#初始網址set、頁
WebsiteSet=set()
pagebegin=1

#如果已抓取，由中途開始繼續抓取 (抓取的資料set及頁面)
if os.path.exists('./data/WebsiteSet.json'):
    with open("./data/WebsiteSet.json") as f:
        x=json.load(f)
        WebsiteSet=set(x[dien] for dien in x)
if os.path.exists('./data/beginpage.txt'):
    with open("./data/beginpage.txt") as p:
        pagebegin=int(p.read())
        
print("開始頁%s"%pagebegin)
        
# headers = {"User-Agent":"Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/62.0.3202.94 Safari/537.36"}

#會累積的變數>>i WebsiteSet
for i in range(pagebegin,page+1):
    res=requests.get(URL+"&p="+str(i))
    if res.status_code==200:
        soup=bs(res.text,'lxml')
        dienlist=soup.select("article.serMain > div.result > section > article.serItem > div > h3")
#         dienlist=[dien for dien in dienlist  if not dien.select_one("span.status")]#去除搬遷或關店狀態的店家>改全抓
        dienlist=["http://www.ipeen.com.tw"+dien.select_one("a")["href"].split("-")[0] for dien in dienlist 
                  if dien.select_one("a")["data-action"]!="ad_shop"]#去除廣告店家，並留下網址>改不留店名
        WebsiteSet.update(dienlist)
        if i%10==0:
            print("-----\n抓取第%s頁"%i)
            print(len(WebsiteSet))
            
            websitedict={Website.split("/")[-1]:Website for Website in WebsiteSet}#改存{id:網址}格式
            print("實際剩餘%s，id重複%s"%(len(websitedict),len(WebsiteSet)-len(websitedict)))
            with open("./data/WebsiteSet.json","w") as f:
                json.dump(websitedict,f)
            with open("./data/beginpage.txt","w") as p:
                p.write(str(i))
    else:
        print("status_code"+str(res.status_code))
        print(len(WebsiteSet))
        websitedict={Website.split("/")[-1]:Website for Website in WebsiteSet}#改存{id:網址}格式
        with open("./data/WebsiteSet.json","w") as f:
            json.dump(websitedict,f)
        with open("./data/beginpage.txt","w") as p:
            p.write(str(i))
            
websitedict={Website.split("/")[-1]:Website for Website in WebsiteSet}#改存{id:網址}格式
with open("./data/WebsiteSet.json","w") as f:
    json.dump(websitedict,f)
with open("./data/beginpage.txt","w") as p:
    p.write(str(i))
# Out:
# 11172pages(all)
# 開始頁890
# -----
# 抓取第890頁
# 127992
# 實際剩餘127992，id重複0
# -----
# 抓取第900頁
# 128000
# 實際剩餘128000，id重複0
# -----
# 抓取第910頁
# 128013
# 實際剩餘128013，id重複0
# -----
# 抓取第920頁
# 128018
# 實際剩餘128018，id重複0
# -----
# 抓取第930頁
# 128028
# 實際剩餘128028，id重複0
# -----
# 抓取第940頁
# 128033
# 實際剩餘128033，id重複0
# -----
# 抓取第950頁
# 128043
# 實際剩餘128043，id重複0
# -----
# 抓取第960頁
# 128053
# 實際剩餘128053，id重複0
# -----
# 抓取第970頁
# 128063
# 實際剩餘128063，id重複0
# -----
# 抓取第980頁
# 128069
# 實際剩餘128069，id重複0
# -----
# 抓取第990頁
# 128073
# 實際剩餘128073，id重複0
# -----
# 抓取第1000頁
# 128078
# 實際剩餘128078，id重複0
# -----
# 抓取第1010頁
# 128085
# 實際剩餘128085，id重複0
# -----
# 抓取第1020頁
# 128087
# 實際剩餘128087，id重複0
# -----
# 抓取第1030頁
# 128094
# 實際剩餘128094，id重複0
# -----
# 抓取第1040頁
# 128097
# 實際剩餘128097，id重複0
# -----
# 抓取第1050頁
# 128103
# 實際剩餘128103，id重複0
# -----
# 抓取第1060頁
# 128110
# 實際剩餘128110，id重複0
# -----
# 抓取第1070頁
# 128117
# 實際剩餘128117，id重複0
# -----
# 抓取第1080頁
# 128125
# 實際剩餘128125，id重複0
# -----
# 抓取第1090頁
# 128135
# 實際剩餘128135，id重複0
# -----
# 抓取第1100頁
# 128146
# 實際剩餘128146，id重複0
# -----
# 抓取第1110頁
# 128151
# 實際剩餘128151，id重複0
# -----
# 抓取第1120頁
# 128165
# 實際剩餘128165，id重複0
# -----
# 抓取第1130頁
# 128175
# 實際剩餘128175，id重複0
# -----
# 抓取第1140頁
# 128181
# 實際剩餘128181，id重複0
# -----
# 抓取第1150頁
# 128190
# 實際剩餘128190，id重複0
# -----
# 抓取第1160頁
# 128199
# 實際剩餘128199，id重複0
# -----
# 抓取第1170頁
# 128205
# 實際剩餘128205，id重複0
# -----
# 抓取第1180頁
# 128218
# 實際剩餘128218，id重複0
# -----
# 抓取第1190頁
# 128226
# 實際剩餘128226，id重複0
# -----
# 抓取第1200頁
# 128232
# 實際剩餘128232，id重複0
# -----
# 抓取第1210頁
# 128241
# 實際剩餘128241，id重複0
# -----
# 抓取第1220頁
# 128253
# 實際剩餘128253，id重複0
# -----
# 抓取第1230頁
# 128265
# 實際剩餘128265，id重複0
# -----
# 抓取第1240頁
# 128271
# 實際剩餘128271，id重複0
# -----
# 抓取第1250頁
# 128276
# 實際剩餘128276，id重複0
# -----
# 抓取第1260頁
# 128283
# 實際剩餘128283，id重複0
# -----
# 抓取第1270頁
# 128289
# 實際剩餘128289，id重複0
# -----
# 抓取第1280頁
# 128297
# 實際剩餘128297，id重複0
# -----
# 抓取第1290頁
# 128304
# 實際剩餘128304，id重複0
# -----
# 抓取第1300頁
# 128316
# 實際剩餘128316，id重複0
# -----
# 抓取第1310頁
# 128317
# 實際剩餘128317，id重複0
# -----
# 抓取第1320頁
# 128326
# 實際剩餘128326，id重複0
# -----
# 抓取第1330頁
# 128335
# 實際剩餘128335，id重複0
# -----
# 抓取第1340頁
# 128342
# 實際剩餘128342，id重複0
# -----
# 抓取第1350頁
# 128349
# 實際剩餘128349，id重複0
# -----
# 抓取第1360頁
# 128354
# 實際剩餘128354，id重複0
# -----
# 抓取第1370頁
# 128363
# 實際剩餘128363，id重複0
# -----
# 抓取第1380頁
# 128370
# 實際剩餘128370，id重複0
# -----
# 抓取第1390頁
# 128382
# 實際剩餘128382，id重複0
# -----
# 抓取第1400頁
# 128391
# 實際剩餘128391，id重複0
# -----
# 抓取第1410頁
# 128395
# 實際剩餘128395，id重複0
# -----
# 抓取第1420頁
# 128399
# 實際剩餘128399，id重複0
# -----
# 抓取第1430頁
# 128410
# 實際剩餘128410，id重複0
# -----
# 抓取第1440頁
# 128419
# 實際剩餘128419，id重複0
# -----
# 抓取第1450頁
# 128426
# 實際剩餘128426，id重複0
# -----
# 抓取第1460頁
# 128436
# 實際剩餘128436，id重複0
# -----
# 抓取第1470頁
# 128442
# 實際剩餘128442，id重複0
# -----
# 抓取第1480頁
# 128452
# 實際剩餘128452，id重複0
# -----
# 抓取第1490頁
# 128460
# 實際剩餘128460，id重複0
# -----
# 抓取第1500頁
# 128467
# 實際剩餘128467，id重複0
# -----
# 抓取第1510頁
# 128476
# 實際剩餘128476，id重複0
# -----
# 抓取第1520頁
# 128486
# 實際剩餘128486，id重複0
# -----
# 抓取第1530頁
# 128498
# 實際剩餘128498，id重複0
# -----
# 抓取第1540頁
# 128507
# 實際剩餘128507，id重複0
# -----
# 抓取第1550頁
# 128516
# 實際剩餘128516，id重複0
# -----
# 抓取第1560頁
# 128523
# 實際剩餘128523，id重複0
# -----
# 抓取第1570頁
# 128528
# 實際剩餘128528，id重複0
# -----
# 抓取第1580頁
# 128535
# 實際剩餘128535，id重複0
# -----
# 抓取第1590頁
# 128548
# 實際剩餘128548，id重複0
# -----
# 抓取第1600頁
# 128556
# 實際剩餘128556，id重複0
# -----
# 抓取第1610頁
# 128562
# 實際剩餘128562，id重複0
# -----
# 抓取第1620頁
# 128570
# 實際剩餘128570，id重複0
# -----
# 抓取第1630頁
# 128574
# 實際剩餘128574，id重複0
# -----
# 抓取第1640頁
# 128582
# 實際剩餘128582，id重複0
# -----
# 抓取第1650頁
# 128591
# 實際剩餘128591，id重複0
# -----
# 抓取第1660頁
# 128599
# 實際剩餘128599，id重複0
# -----
# 抓取第1670頁
# 128605
# 實際剩餘128605，id重複0
# -----
# 抓取第1680頁
# 128614
# 實際剩餘128614，id重複0
# -----
# 抓取第1690頁
# 128628
# 實際剩餘128628，id重複0
# -----
# 抓取第1700頁
# 128643
# 實際剩餘128643，id重複0
# -----
# 抓取第1710頁
# 128650
# 實際剩餘128650，id重複0
# -----
# 抓取第1720頁
# 128660
# 實際剩餘128660，id重複0
# -----
# 抓取第1730頁
# 128672
# 實際剩餘128672，id重複0
# -----
# 抓取第1740頁
# 128683
# 實際剩餘128683，id重複0
# -----
# 抓取第1750頁
# 128692
# 實際剩餘128692，id重複0
# -----
# 抓取第1760頁
# 128702
# 實際剩餘128702，id重複0
# -----
# 抓取第1770頁
# 128707
# 實際剩餘128707，id重複0
# -----
# 抓取第1780頁
# 128713
# 實際剩餘128713，id重複0
# -----
# 抓取第1790頁
# 128716
# 實際剩餘128716，id重複0
# -----
# 抓取第1800頁
# 128724
# 實際剩餘128724，id重複0
# -----
# 抓取第1810頁
# 128738
# 實際剩餘128738，id重複0
# -----
# 抓取第1820頁
# 128744
# 實際剩餘128744，id重複0
# -----
# 抓取第1830頁
# 128753
# 實際剩餘128753，id重複0
# -----
# 抓取第1840頁
# 128765
# 實際剩餘128765，id重複0
# -----
# 抓取第1850頁
# 128773
# 實際剩餘128773，id重複0
# -----
# 抓取第1860頁
# 128783
# 實際剩餘128783，id重複0
# -----
# 抓取第1870頁
# 128793
# 實際剩餘128793，id重複0
# -----
# 抓取第1880頁
# 128802
# 實際剩餘128802，id重複0
# -----
# 抓取第1890頁
# 128811
# 實際剩餘128811，id重複0
# -----
# 抓取第1900頁
# 128818
# 實際剩餘128818，id重複0
# -----
# 抓取第1910頁
# 128824
# 實際剩餘128824，id重複0
# -----
# 抓取第1920頁
# 128833
# 實際剩餘128833，id重複0
# -----
# 抓取第1930頁
# 128848
# 實際剩餘128848，id重複0
# -----
# 抓取第1940頁
# 128860
# 實際剩餘128860，id重複0
# -----
# 抓取第1950頁
# 128866
# 實際剩餘128866，id重複0
# -----
# 抓取第1960頁
# 128873
# 實際剩餘128873，id重複0
# -----
# 抓取第1970頁
# 128884
# 實際剩餘128884，id重複0
# -----
# 抓取第1980頁
# 128894
# 實際剩餘128894，id重複0
# -----
# 抓取第1990頁
# 128902
# 實際剩餘128902，id重複0
# -----
# 抓取第2000頁
# 128903
# 實際剩餘128903，id重複0
# -----
# 抓取第2010頁
# 128908
# 實際剩餘128908，id重複0
# -----
# 抓取第2020頁
# 128914
# 實際剩餘128914，id重複0
# -----
# 抓取第2030頁
# 128919
# 實際剩餘128919，id重複0
# -----
# 抓取第2040頁
# 128929
# 實際剩餘128929，id重複0
# -----
# 抓取第2050頁
# 128941
# 實際剩餘128941，id重複0
# -----
# 抓取第2060頁
# 128951
# 實際剩餘128951，id重複0
# -----
# 抓取第2070頁
# 128962
# 實際剩餘128962，id重複0
# -----
# 抓取第2080頁
# 128972
# 實際剩餘128972，id重複0
# -----
# 抓取第2090頁
# 128975
# 實際剩餘128975，id重複0
# -----
# 抓取第2100頁
# 128983
# 實際剩餘128983，id重複0
# -----
# 抓取第2110頁
# 128988
# 實際剩餘128988，id重複0
# -----
# 抓取第2120頁
# 128995
# 實際剩餘128995，id重複0
# -----
# 抓取第2130頁
# 129000
# 實際剩餘129000，id重複0
# -----
# 抓取第2140頁
# 129008
# 實際剩餘129008，id重複0
# -----
# 抓取第2150頁
# 129014
# 實際剩餘129014，id重複0
# -----
# 抓取第2160頁
# 129020
# 實際剩餘129020，id重複0
# -----
# 抓取第2170頁
# 129025
# 實際剩餘129025，id重複0
# -----
# 抓取第2180頁
# 129032
# 實際剩餘129032，id重複0
# -----
# 抓取第2190頁
# 129035
# 實際剩餘129035，id重複0
# -----
# 抓取第2200頁
# 129044
# 實際剩餘129044，id重複0
# -----
# 抓取第2210頁
# 129053
# 實際剩餘129053，id重複0
# -----
# 抓取第2220頁
# 129057
# 實際剩餘129057，id重複0
# -----
# 抓取第2230頁
# 129068
# 實際剩餘129068，id重複0
# -----
# 抓取第2240頁
# 129082
# 實際剩餘129082，id重複0
# -----
# 抓取第2250頁
# 129091
# 實際剩餘129091，id重複0

# %% [markdown]
# # try to concurrent.futures 無法跑到一半存檔、會被BAN

# %%
import concurrent.futures
import json
import os
import requests
from bs4 import BeautifulSoup as bs
import logging
import time

# %%
if not os.path.exists('./data'):
    os.makedirs('./data')

# %%
def getlink(page,linkset,):
    headers = {"User-Agent":"Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/62.0.3202.94 Safari/537.36"}
    res=requests.get("http://www.ipeen.com.tw/search/taiwan/000/1-100-0-0/?baragain=1&p=1&p="+str(page),headers=headers)
    if res.status_code==200:
        soup=bs(res.text,'lxml')
        res.close()
        dienlist=soup.select("article.serMain > div.result > section > article.serItem > div > h3")#找尋店家資訊
        dienlist=[dien for dien in dienlist  if not dien.select_one("span.status")]#去除搬遷或關店狀態的店家
        dienlist=["http://www.ipeen.com.tw"+dien.select_one("a")["href"] for dien in dienlist 
                  if dien.select_one("a")["data-action"]!="ad_shop"]#去除廣告店家，留下網址
        linkset.update(dienlist)#將該頁的店list加入set中(順便去除重複)
#         if i%10==0:#每十頁存一次
#             print(len(linkset))
#             websitedict={Website.split("-",1)[1]:Website.split("-",1)[0] for Website in linkset}
#             with open("./data/linkset.json","w") as f:
#                 json.dump(websitedict,f)
    else:#沒連線成功也存
        print("status_code="+str(res.status_code))
        res.close()
        print(len(linkset))
#         websitedict={Website.split("-",1)[1]:Website.split("-",1)[0] for Website in linkset}
#         with open("./data/linkset.json","w") as f:
#             json.dump(websitedict,f)
#     websitedict={Website.split("-",1)[1]:Website.split("-",1)[0] for Website in linkset}
    return dienlist

# %%
res=requests.get("http://www.ipeen.com.tw/search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=1")
soup=bs(res.text,"lxml")
res.close()
page=int(soup.select("#search > article > hgroup > h2 > b")[0].text)//15
print(str(page)+"pages")

WebsiteSet=set()
start = time.time()
i=0
with concurrent.futures.ThreadPoolExecutor(max_workers=20) as executor:
    jobInfo = [executor.submit(getlink, page, WebsiteSet) for page in range(1,page+1)]
    for future in concurrent.futures.as_completed(jobInfo):
        try:
            data = future.result()
            WebsiteSet.update(data)
        except Exception as e:
            print(e)
            print("zzz")
            pass
        
end = time.time()  
print("-----------------")
print(end-start)

websitedict={Website.split("-",1)[1]:Website.split("-",1)[0] for Website in WebsiteSet}
with open("./data/linkset.json","w") as f:
    json.dump(websitedict,f)
# Out:
# 11168pages
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=411 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000000AB9C048>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=413 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000000C41BC18>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=414 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000001267AEF0>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=415 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x0000000011DBE550>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=416 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000001069F9E8>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=417 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x0000000010689860>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=418 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x0000000009D4C320>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=419 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000000F7CF6A0>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=423 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000000FE39320>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=425 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000000CA7FA20>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=426 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000000F6DD198>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=428 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000001003C5C0>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=429 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000001003C978>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=434 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x00000000129CF550>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=436 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000000C4329B0>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=437 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000000C432630>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=441 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000001067C898>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=444 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000000BEA28D0>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=445 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x0000000010447518>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=446 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000000BEA2828>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=451 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000000FAFE128>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=452 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000000FAFEDD8>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=453 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000000BEA2390>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=455 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000001214FDA0>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=457 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x00000000107ADD30>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=459 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000000FAE8D68>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=460 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000000F625710>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=462 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000000F993CF8>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=463 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000000F9784E0>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=466 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000001214F7B8>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=468 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000000BE94EB8>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=469 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000000C45CB38>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=472 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000000FAE8A58>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=474 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000000F84A748>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=476 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000000FBF6E10>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=477 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000000FBF56D8>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=479 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000000FBF59B0>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=485 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000000B309D68>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=487 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000000F794C18>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=488 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x00000000107DDF60>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=491 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000000FBF5518>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=492 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000000AB68FD0>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=494 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000000AB744E0>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=495 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000000A256438>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=496 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000000BE3E0F0>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=497 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x00000000107D7780>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=502 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x00000000107C3470>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=503 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000000F5DB630>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=507 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000000FB1FA20>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=508 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000000FB1FD30>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=510 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000000FB1FDA0>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=512 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000000A616BA8>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=519 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000000A4B37F0>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=520 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000000C9F32E8>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=521 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000000C4934E0>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=522 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000000C172E10>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=523 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000000C16F630>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=524 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000000C16FE10>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=525 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000000C164588>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=529 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000001033C2B0>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=533 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000000F49B5F8>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=536 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000000F305080>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=540 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000000C47C1D0>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=541 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000000B95DC88>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=542 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x00000000129BF390>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=549 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000000A503F60>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=551 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000000C499668>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=554 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000000F822668>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz
# HTTPConnectionPool(host='www.ipeen.com.tw', port=80): Max retries exceeded with url: /search/taiwan/000/1-100-0-0/?baragain=1&p=1&p=558 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x0000000011D0B550>: Failed to establish a new connection: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。',))
# zzz

# %%
with open("./data/linkSet.json") as f:
    x=json.load(f)

# %%
len(x)

# %% [markdown]
# # try to change proxy 失敗

# %%
import concurrent.futures
import json
import os
import requests
from bs4 import BeautifulSoup as bs
import logging
import time
import re
if not os.path.exists('./data'):
    os.makedirs('./data')

# %%
def getlink(page,linkset,proxylist):
    res=requests.get("http://www.ipeen.com.tw/search/taiwan/000/1-0-0-0/?baragain=1&p="+str(page))
    if res.status_code==200:
        soup=bs(res.text,'lxml')
        res.close()
        dienlist=soup.select("article.serMain > div.result > section > article.serItem > div > h3")#找尋店家資訊
        dienlist=[dien for dien in dienlist  if not dien.select_one("span.status")]#去除搬遷或關店狀態的店家
        dienlist=["http://www.ipeen.com.tw"+dien.select_one("a")["href"] for dien in dienlist 
                  if dien.select_one("a")["data-action"]!="ad_shop"]#去除廣告店家，留下網址
#         linkset.update(dienlist)#將該頁的店list加入set中(順便去除重複)
#         if i%10==0:#每十頁存一次
#             print(len(linkset))
#             websitedict={Website.split("-",1)[1]:Website.split("-",1)[0] for Website in linkset}
#             with open("./data/linkset.json","w") as f:
#                 json.dump(websitedict,f)
    else:#沒連線成功也存
        res.close()
        n=0
        res=requests.get("http://www.ipeen.com.tw/search/taiwan/000/1-0-0-0/?baragain=1&p="+str(page),proxies=proxylist[n])
        while res.status_code!=200:
            n+=1
            res.close()
            res=requests.get("http://www.ipeen.com.tw/search/taiwan/000/1-0-0-0/?baragain=1&p="+str(page),proxies=proxylist[n])
        dienlist=soup.select("article.serMain > div.result > section > article.serItem > div > h3")#找尋店家資訊
        dienlist=[dien for dien in dienlist  if not dien.select_one("span.status")]#去除搬遷或關店狀態的店家
        dienlist=["http://www.ipeen.com.tw"+dien.select_one("a")["href"] for dien in dienlist 
                  if dien.select_one("a")["data-action"]!="ad_shop"]#去除廣告店家，留下網址
#         websitedict={Website.split("-",1)[1]:Website.split("-",1)[0] for Website in linkset}
#         with open("./data/linkset.json","w") as f:
#             json.dump(websitedict,f)
#     websitedict={Website.split("-",1)[1]:Website.split("-",1)[0] for Website in linkset}
    return dienlist

# %%
url="https://free-proxy-list.net/"
res=requests.get(url)
soup=bs(res.text,"lxml")
proxylist=re.findall("([0-2]?[0-9]?[0-9]\.[0-2]?[0-9]?[0-9]\.[0-2]?[0-9]?[0-9]\.[0-2]?[0-9]?[0-9])(80)",soup.text)
proxylist=[{'http':'http://'+proxy[0]+':'+proxy[1]} for proxy in proxylist]
proxylist
# Out:
# [{'http': 'http://145.239.93.189:80'},
#  {'http': 'http://58.229.253.103:80'},
#  {'http': 'http://217.18.142.29:80'},
#  {'http': 'http://210.212.73.61:80'},
#  {'http': 'http://217.65.217.68:80'},
#  {'http': 'http://37.187.120.123:80'},
#  {'http': 'http://112.201.89.228:80'},
#  {'http': 'http://62.182.25.38:80'},
#  {'http': 'http://185.34.20.82:80'},
#  {'http': 'http://47.89.41.164:80'},
#  {'http': 'http://80.234.41.140:80'},
#  {'http': 'http://203.58.117.34:80'},
#  {'http': 'http://37.29.48.78:80'},
#  {'http': 'http://78.25.98.114:80'},
#  {'http': 'http://62.161.11.21:80'},
#  {'http': 'http://95.188.161.39:80'},
#  {'http': 'http://213.136.77.246:80'},
#  {'http': 'http://201.16.197.16:80'},
#  {'http': 'http://80.83.20.14:80'},
#  {'http': 'http://178.49.136.82:80'},
#  {'http': 'http://175.126.38.224:80'},
#  {'http': 'http://13.78.125.167:80'},
#  {'http': 'http://104.199.40.49:80'},
#  {'http': 'http://203.74.4.4:80'},
#  {'http': 'http://89.22.175.43:80'},
#  {'http': 'http://212.83.164.85:80'},
#  {'http': 'http://218.50.2.102:80'},
#  {'http': 'http://62.161.11.20:80'},
#  {'http': 'http://203.74.4.2:80'},
#  {'http': 'http://52.76.214.252:80'},
#  {'http': 'http://52.163.62.13:80'},
#  {'http': 'http://50.245.168.108:80'},
#  {'http': 'http://5.189.133.231:80'},
#  {'http': 'http://203.177.151.24:80'},
#  {'http': 'http://200.109.236.60:80'},
#  {'http': 'http://95.85.50.218:80'},
#  {'http': 'http://191.102.85.234:80'},
#  {'http': 'http://189.206.107.6:80'},
#  {'http': 'http://45.77.124.178:80'},
#  {'http': 'http://183.91.23.194:80'},
#  {'http': 'http://170.246.114.196:80'},
#  {'http': 'http://89.188.229.14:80'},
#  {'http': 'http://91.191.173.37:80'},
#  {'http': 'http://203.74.4.6:80'},
#  {'http': 'http://52.15.116.121:80'},
#  {'http': 'http://213.136.89.121:80'},
#  {'http': 'http://139.255.55.146:80'},
#  {'http': 'http://52.164.244.34:80'},
#  {'http': 'http://94.232.55.100:80'},
#  {'http': 'http://78.36.43.79:80'},
#  {'http': 'http://80.211.166.20:80'},
#  {'http': 'http://202.9.104.10:80'},
#  {'http': 'http://52.57.95.123:80'},
#  {'http': 'http://143.0.188.213:80'},
#  {'http': 'http://203.74.4.0:80'},
#  {'http': 'http://203.74.4.5:80'},
#  {'http': 'http://89.98.94.50:80'},
#  {'http': 'http://5.196.189.50:80'},
#  {'http': 'http://81.21.75.142:80'},
#  {'http': 'http://47.52.117.173:80'},
#  {'http': 'http://46.218.73.162:80'},
#  {'http': 'http://203.74.4.7:80'},
#  {'http': 'http://145.239.4.43:80'},
#  {'http': 'http://64.34.21.84:80'},
#  {'http': 'http://92.62.79.187:80'},
#  {'http': 'http://211.127.160.240:80'},
#  {'http': 'http://203.74.4.1:80'},
#  {'http': 'http://31.173.33.140:80'},
#  {'http': 'http://37.182.212.118:80'},
#  {'http': 'http://61.90.105.123:80'},
#  {'http': 'http://118.172.116.53:80'},
#  {'http': 'http://177.207.92.74:80'},
#  {'http': 'http://36.74.35.204:80'},
#  {'http': 'http://95.71.0.215:80'},
#  {'http': 'http://223.206.22.220:80'},
#  {'http': 'http://118.97.191.203:80'},
#  {'http': 'http://180.246.149.11:80'},
#  {'http': 'http://202.138.254.18:80'},
#  {'http': 'http://128.73.128.64:80'},
#  {'http': 'http://190.137.124.160:80'},
#  {'http': 'http://179.179.87.177:80'},
#  {'http': 'http://180.254.117.16:80'},
#  {'http': 'http://182.253.42.10:80'},
#  {'http': 'http://125.24.102.129:80'},
#  {'http': 'http://37.237.242.17:80'},
#  {'http': 'http://46.101.255.137:80'},
#  {'http': 'http://197.245.70.47:80'},
#  {'http': 'http://46.61.39.119:80'},
#  {'http': 'http://125.161.140.143:80'},
#  {'http': 'http://125.25.33.209:80'},
#  {'http': 'http://101.109.222.161:80'},
#  {'http': 'http://36.66.217.179:80'},
#  {'http': 'http://36.73.156.84:80'},
#  {'http': 'http://170.233.149.107:80'},
#  {'http': 'http://180.183.88.52:80'},
#  {'http': 'http://94.37.74.23:80'},
#  {'http': 'http://36.73.78.33:80'},
#  {'http': 'http://128.75.82.61:80'},
#  {'http': 'http://178.164.237.72:80'},
#  {'http': 'http://125.166.15.229:80'},
#  {'http': 'http://118.96.187.196:80'},
#  {'http': 'http://187.79.9.253:80'},
#  {'http': 'http://196.202.194.85:80'},
#  {'http': 'http://52.178.68.67:80'},
#  {'http': 'http://124.122.184.11:80'},
#  {'http': 'http://183.88.51.30:80'},
#  {'http': 'http://159.255.167.131:80'},
#  {'http': 'http://36.83.25.71:80'},
#  {'http': 'http://203.74.4.3:80'},
#  {'http': 'http://83.169.244.38:80'},
#  {'http': 'http://217.79.54.68:80'},
#  {'http': 'http://113.190.244.106:80'},
#  {'http': 'http://128.199.234.64:80'},
#  {'http': 'http://181.65.131.102:80'},
#  {'http': 'http://45.32.51.175:80'},
#  {'http': 'http://141.101.5.155:80'},
#  {'http': 'http://43.230.145.176:80'},
#  {'http': 'http://106.201.230.227:80'},
#  {'http': 'http://103.217.104.74:80'},
#  {'http': 'http://69.144.49.11:80'},
#  {'http': 'http://177.5.28.3:80'},
#  {'http': 'http://190.248.158.194:80'},
#  {'http': 'http://124.13.235.11:80'},
#  {'http': 'http://31.173.209.111:80'},
#  {'http': 'http://201.209.239.131:80'},
#  {'http': 'http://103.54.25.253:80'},
#  {'http': 'http://5.1.32.38:80'},
#  {'http': 'http://203.177.162.154:80'},
#  {'http': 'http://5.188.155.243:80'},
#  {'http': 'http://180.211.94.170:80'},
#  {'http': 'http://179.189.248.174:80'},
#  {'http': 'http://189.221.102.190:80'},
#  {'http': 'http://110.170.150.166:80'},
#  {'http': 'http://217.13.222.161:80'},
#  {'http': 'http://50.245.168.106:80'},
#  {'http': 'http://167.114.196.153:80'},
#  {'http': 'http://84.204.83.178:80'},
#  {'http': 'http://148.251.211.123:80'},
#  {'http': 'http://125.165.91.64:80'},
#  {'http': 'http://83.169.38.204:80'},
#  {'http': 'http://202.159.36.70:80'},
#  {'http': 'http://139.195.35.48:80'},
#  {'http': 'http://95.159.69.161:80'},
#  {'http': 'http://176.235.99.166:80'},
#  {'http': 'http://124.41.240.105:80'},
#  {'http': 'http://181.65.84.97:80'},
#  {'http': 'http://200.54.45.170:80'},
#  {'http': 'http://103.76.45.185:80'},
#  {'http': 'http://180.183.108.243:80'},
#  {'http': 'http://139.59.118.118:80'},
#  {'http': 'http://200.203.144.98:80'},
#  {'http': 'http://110.77.199.219:80'},
#  {'http': 'http://202.153.228.130:80'}]

# %%
res=requests.get("http://www.ipeen.com.tw/search/taiwan/000/1-0-0-0/?baragain=1&p=1")
soup=bs(res.text,"lxml")
res.close()
page=int(soup.select("#search > article > hgroup > h2 > b")[0].text)//15
print(str(page)+"pages")

WebsiteSet=set()
start = time.time()
with concurrent.futures.ThreadPoolExecutor(max_workers=20) as executor:
    jobInfo = [executor.submit(getlink, page, WebsiteSet,proxylist) for page in range(1,page+1)]
    for future in concurrent.futures.as_completed(jobInfo):
        try:
            data = future.result()
            WebsiteSet.update(data)
        except Exception as e:
            print(e)
            print("zzz")
            pass
        
end = time.time()  
print("-----------------")
print(end-start)

websitedict={Website.split("-",1)[1]:Website.split("-",1)[0] for Website in WebsiteSet}
with open("./data/linkset.json","w") as f:
    json.dump(websitedict,f)

# %%
with open("./data/linkSet.json") as f:
    x=json.load(f)

# %% [markdown]
# # 變更proxy的兩種方法
# import requests
# s = requests.Session()
# s.proxies = {"http": "http://61.233.25.166:80"}
# r = s.get("http://www.google.com")
# print(r.text)
#
# import requests
# r = requests.get("http://www.google.com", proxies={"http": "http://61.233.25.166:80"})
# print(r.text)

# %% [markdown]
# # 變更user agent的方法
# headers = {
#     'User-Agent': 'My User Agent 1.0',
#     'From': 'youremail@domain.com'  # This is another valid field
# }
# response = requests.get(url, headers=headers)

# %% [markdown]
# # bs抓取某tag or tag群的方法
# soup.select("tag > tag > tag")
# 如:soup.select("#search > article > hgroup > h2 > b")
#
# soup.find_all('tag', attrs={'tag內的元素': '元素名稱'})
# 如:soup.find_all('a', attrs={'data-label': '店名'})
