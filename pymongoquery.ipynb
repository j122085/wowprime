# %%
import pymongo
from pymongo import MongoClient

# %%
client = MongoClient()

# %%
client = MongoClient('172.20.26.39', 27017)

# %%
db=client['rawData']
db.collection_names()
# Out:
# ['wowprimeipeen']

# %%
collection = db.wowprimeipeen

# %%
list(collection.find({}))
# Out:
# [{'Ncomment': 0,
#   '_id': ObjectId('5a17c44780b11018380251e0'),
#   'address': '台南市新營區健康路251號',
#   'averagecost': 0,
#   'bigstyle': '速食料理',
#   'collecount': 0,
#   'id': 100000,
#   'ipeenscore': 0,
#   'lat': 23.319379010490003,
#   'lng': 120.31197500804001,
#   'name': '麥當勞(新營家樂福店)',
#   'reviewdate': '2011/07/14',
#   'smallstyle': '漢堡、炸雞',
#   'status': '正常營業',
#   'tele': '066571158',
#   'viewcount': 2949},
#  {'Ncomment': 5,
#   '_id': ObjectId('5a17c44780b11018380251e1'),
#   'address': '台北市大安區信義路三段166巷2號',
#   'averagecost': 383,
#   'bigstyle': '燒烤類',
#   'collecount': 19,
#   'id': 1000010,
#   'ipeenscore': 45,
#   'lat': 25.03301900787,
#   'lng': 121.54191500375,
#   'name': '岩谷新鐵板料理Rock Valley(台北信義總店)',
#   'reviewdate': '2017/08/23',
#   'smallstyle': '鐵板燒',
#   'status': '正常營業',
#   'tele': '0227071968',
#   'viewcount': 12926},
#  {'Ncomment': 3,
#   '_id': ObjectId('5a17c44780b11018380251e2'),
#   'address': '台北市內湖區內湖路一段689-1號',
#   'averagecost': 314,
#   'bigstyle': '日式料理',
#   'collecount': 29,
#   'id': 1000022,
#   'ipeenscore': 45,
#   'lat': 25.08003220642,
#   'lng': 121.57675520955,
#   'name': '阿宏日式料理',
#   'reviewdate': '2015/01/23',
#   'smallstyle': '生魚片、壽司專賣',
#   'status': '正常營業',
#   'tele': 0,
#   'viewcount': 6083},
#  {'Ncomment': 2,
#   '_id': ObjectId('5a17c44780b11018380251e3'),
#   'address': '台中市南屯區文心南一路62-1號',
#   'averagecost': 0,
#   'bigstyle': '異國料理',
#   'collecount': 2,
#   'id': 1000036,
#   'ipeenscore': 45,
#   'lat': 24.13717430887,
#   'lng': 120.6442107136,
#   'name': 'NU PASTA(台中向心店)',
#   'reviewdate': '2016/04/03',
#   'smallstyle': '義式料理',
#   'status': '正常營業',
#   'tele': '0424737440',
#   'viewcount': 4106},
#  {'Ncomment': 0,
#   '_id': ObjectId('5a17c44780b11018380251e4'),
#   'address': 0,
#   'averagecost': 0,
#   'bigstyle': '冰品、飲料、甜湯',
#   'collecount': 0,
#   'id': 1000068,
#   'ipeenscore': 0,
#   'lat': 23.96643291955,
#   'lng': 120.96818700405,
#   'name': '包心粉圓 埔里點',
#   'reviewdate': '2016/01/28',
#   'smallstyle': '甜品、甜湯',
#   'status': '正常營業',
#   'tele': '0921706833',
#   'viewcount': 928},
#  {'Ncomment': 1,
#   '_id': ObjectId('5a17c44780b11018380251e5'),
#   'address': '台中市梧棲區中央路一段681號',
#   'averagecost': 110,
#   'bigstyle': '中式料理',
#   'collecount': 5,
#   'id': 1000074,
#   'ipeenscore': 45,
#   'lat': 24.24537030303,
#   'lng': 120.53754541026,
#   'name': '清水王牌-筒仔米糕',
#   'reviewdate': '2015/01/24',
#   'smallstyle': '其它中式料理',
#   'status': '正常營業',
#   'tele': '0426579768',
#   'viewcount': 4369},
#  {'Ncomment': 21,
#   '_id': ObjectId('5a17c44780b11018380251e6'),
#   'address': '台北市大安區四維路14巷6-1號',
#   'averagecost': 933,
#   'bigstyle': '異國料理',
#   'collecount': 301,
#   'id': 1000080,
#   'ipeenscore': 45,
#   'lat': 25.03678902433351,
#   'lng': 121.54740865359874,
#   'name': '凱恩斯岩燒餐廳(台北大安店)',
#   'reviewdate': '2015/03/02',
#   'smallstyle': '美式料理',
#   'status': '正常營業',
#   'tele': '0227018513',
#   'viewcount': 1134186},
#  {'Ncomment': 0,
#   '_id': ObjectId('5a17c44780b11018380251e7'),
#   'address': 0,
#   'averagecost': 0,
#   'bigstyle': '小吃',
#   'collecount': 3,
#   'id': 1000088,
#   'ipeenscore': 45,
#   'lat': 23.96305301239,
#   'lng': 120.56877900246,
#   'name': '梁媽媽麵線糊',
#   'reviewdate': '2016/04/05',
#   'smallstyle': '麵線',
#   'status': '正常營業',
#   'tele': '0911093312',
#   'viewcount': 2150},
#  {'Ncomment': 1,
#   '_id': ObjectId('5a17c44780b11018380251e8'),
#   'address': '新北市永和區永和路二段35號',
#   'averagecost': 150,
#   'bigstyle': '日式料理',
#   'collecount': 2,
#   'id': 1000108,
#   'ipeenscore': 0,
#   'lat': 25.0104568086,
#   'lng': 121.51446400877,
#   'name': '98日式拉麵',
#   'reviewdate': '2015/01/24',
#   'smallstyle': '日式麵食專賣',
#   'status': '正常營業',
#   'tele': '0229227272',
#   'viewcount': 7386},
#  {'Ncomment': 1,
#   '_id': ObjectId('5a17c44780b11018380251e9'),
#   'address': '台中市北屯區台中市北屯區中清路二段165號',
#   'averagecost': 0,
#   'bigstyle': '速食料理',
#   'collecount': 2,
#   'id': 1000120,
#   'ipeenscore': 40,
#   'lat': 24.17649251448,
#   'lng': 120.66989220951001,
#   'name': 'Qcar柴燒窯烤披薩',
#   'reviewdate': '2016/04/05',
#   'smallstyle': '披薩',
#   'status': '正常營業',
#   'tele': '0931409866',
#   'viewcount': 3980},
#  {'Ncomment': 11,
#   '_id': ObjectId('5a17c44780b11018380251ea'),
#   'address': '桃園市中壢區元化路357號2樓',
#   'averagecost': 353,
#   'bigstyle': '烘焙、甜點、零食',
#   'collecount': 51,
#   'id': 100013,
#   'ipeenscore': 45,
#   'lat': 24.96244001226,
#   'lng': 121.22388401293,
#   'name': "Aunt Stella's 詩特莉餅乾咖啡(中壢店)",
#   'reviewdate': '2016/04/05',
#   'smallstyle': '西點烘焙、麵包',
#   'status': '正常營業',
#   'tele': '032711919',
#   'viewcount': 40487},
#  {'Ncomment': 0,
#   '_id': ObjectId('5a17c44780b11018380251eb'),
#   'address': '高雄市三民區建武路185號',
#   'averagecost': 25,
#   'bigstyle': '冰品、飲料、甜湯',
#   'collecount': 1,
#   'id': 1000158,
#   'ipeenscore': 40,
#   'lat': 22.64449300147,
#   'lng': 120.33061800774,
#   'name': '沁香豆花',
#   'reviewdate': '2015/01/24',
#   'smallstyle': '剉冰、豆花',
#   'status': '正常營業',
#   'tele': 0,
#   'viewcount': 1902},
#  {'Ncomment': 6,
#   '_id': ObjectId('5a17c44780b11018380251ec'),
#   'address': '新北市永和區文化路128號',
#   'averagecost': 198,
#   'bigstyle': '日式料理',
#   'collecount': 69,
#   'id': 1000166,
#   'ipeenscore': 40,
#   'lat': 25.01540491226,
#   'lng': 121.51294800779999,
#   'name': '日初食事',
#   'reviewdate': '2015/01/24',
#   'smallstyle': '日式豬排專賣',
#   'status': '正常營業',
#   'tele': '0286606876',
#   'viewcount': 77456},
#  {'Ncomment': 25,
#   '_id': ObjectId('5a17c44780b11018380251ed'),
#   'address': '高雄市左營區曾子路105號',
#   'averagecost': 481,
#   'bigstyle': '鍋類',
#   'collecount': 267,
#   'id': 1000170,
#   'ipeenscore': 45,
#   'lat': 22.67799341331,
#   'lng': 120.30909361036,
#   'name': '天水玥秘境鍋物殿',
#   'reviewdate': '2015/07/07',
#   'smallstyle': '涮涮鍋',
#   'status': '正常營業',
#   'tele': '073438188',
#   'viewcount': 206681},
#  {'Ncomment': 0,
#   '_id': ObjectId('5a17c44780b11018380251ee'),
#   'address': '桃園市大園區中正東路51號',
#   'averagecost': 0,
#   'bigstyle': '中式料理',
#   'collecount': 0,
#   'id': 1000180,
#   'ipeenscore': 0,
#   'lat': 25.03868521699,
#   'lng': 121.13627621044999,
#   'name': '吳記台灣小吃牛肉麵',
#   'reviewdate': '2015/01/25',
#   'smallstyle': '麵食點心',
#   'status': '正常營業',
#   'tele': '033868967',
#   'viewcount': 815},
#  {'Ncomment': 1,
#   '_id': ObjectId('5a17c44780b11018380251ef'),
#   'address': '高雄市鹽埕區大勇路155號',
#   'averagecost': 0,
#   'bigstyle': '中式料理',
#   'collecount': 7,
#   'id': 1000192,
#   'ipeenscore': 0,
#   'lat': 22.62708121888,
#   'lng': 120.28556191211,
#   'name': '川味小吃',
#   'reviewdate': '2015/01/24',
#   'smallstyle': '海鮮餐廳',
#   'status': '正常營業',
#   'tele': '075612436',
#   'viewcount': 5632},
#  {'Ncomment': 0,
#   '_id': ObjectId('5a17c44780b11018380251f0'),
#   'address': '新北市三峽區民生街186號2樓',
#   'averagecost': 0,
#   'bigstyle': '小吃',
#   'collecount': 3,
#   'id': 1000204,
#   'ipeenscore': 0,
#   'lat': 24.934952000139997,
#   'lng': 121.37104881838992,
#   'name': '三峽麵線阿峯',
#   'reviewdate': '2016/04/03',
#   'smallstyle': '麵線',
#   'status': '正常營業',
#   'tele': '0973371006',
#   'viewcount': 801466},
#  {'Ncomment': 1,
#   '_id': ObjectId('5a17c44780b11018380251f1'),
#   'address': 0,
#   'averagecost': 0,
#   'bigstyle': '常溫包裝食品',
#   'collecount': 0,
#   'id': 1000222,
#   'ipeenscore': 45,
#   'lat': 0,
#   'lng': 0,
#   'name': '桂格燕麥方脆',
#   'reviewdate': '2015/01/25',
#   'smallstyle': '餅乾、零食',
#   'status': '正常營業',
#   'tele': 0,
#   'viewcount': 4214},
#  {'Ncomment': 0,
#   '_id': ObjectId('5a17c44780b11018380251f2'),
#   'address': 0,
#   'averagecost': 0,
#   'bigstyle': '中式料理',
#   'collecount': 2,
#   'id': 1000228,
#   'ipeenscore': 0,
#   'lat': 24.0716583022,
#   'lng': 120.56244740202,
#   'name': '蘇菠麵',
#   'reviewdate': '2016/04/05',
#   'smallstyle': '麵食點心',
#   'status': '正常營業',
#   'tele': '047275777',
#   'viewcount': 857},
#  {'Ncomment': 3,
#   '_id': ObjectId('5a17c44780b11018380251f3'),
#   'address': 0,
#   'averagecost': 200,
#   'bigstyle': '網購包裝食品',
#   'collecount': 10,
#   'id': 1000242,
#   'ipeenscore': 0,
#   'lat': 0,
#   'lng': 0,
#   'name': '艾薇恩工作室 Elvian Handmade',
#   'reviewdate': '2015/01/25',
#   'smallstyle': '甜點、蛋糕',
#   'status': '正常營業',
#   'tele': '033530364',
#   'viewcount': 5935},
#  {'Ncomment': 1,
#   '_id': ObjectId('5a17c44780b11018380251f4'),
#   'address': '新北市新莊區公園路16號',
#   'averagecost': 498,
#   'bigstyle': '燒烤類',
#   'collecount': 2,
#   'id': 1000250,
#   'ipeenscore': 40,
#   'lat': 25.03915911732,
#   'lng': 121.44849750213,
#   'name': '酒鄉燒烤屋',
#   'reviewdate': '2016/04/03',
#   'smallstyle': '炭烤串燒',
#   'status': '正常營業',
#   'tele': '0229917199',
#   'viewcount': 3571},
#  {'Ncomment': 0,
#   '_id': ObjectId('5a17c44780b11018380251f5'),
#   'address': 0,
#   'averagecost': 0,
#   'bigstyle': '早餐',
#   'collecount': 0,
#   'id': 1000266,
#   'ipeenscore': 0,
#   'lat': 22.550921203490002,
#   'lng': 120.5428841033,
#   'name': '呷尚宝複合式早餐',
#   'reviewdate': '2015/01/25',
#   'smallstyle': '西式早餐',
#   'status': '正常營業',
#   'tele': 0,
#   'viewcount': 883},
#  {'Ncomment': 0,
#   '_id': ObjectId('5a17c44780b11018380251f6'),
#   'address': '高雄市左營區明華ㄧ路221號',
#   'averagecost': 255,
#   'bigstyle': '中式料理',
#   'collecount': 5,
#   'id': 1000294,
#   'ipeenscore': 45,
#   'lat': 22.66489300575,
#   'lng': 120.31303500343999,
#   'name': '黎家香港茶餐廳',
#   'reviewdate': '2016/04/05',
#   'smallstyle': '粵菜 港式飲茶',
#   'status': '正常營業',
#   'tele': '075509218',
#   'viewcount': 2622},
#  {'Ncomment': 0,
#   '_id': ObjectId('5a17c44780b11018380251f7'),
#   'address': 0,
#   'averagecost': 0,
#   'bigstyle': '日式料理',
#   'collecount': 2,
#   'id': 1000326,
#   'ipeenscore': 0,
#   'lat': 24.71487841273,
#   'lng': 120.921360217,
#   'name': '六角工房',
#   'reviewdate': '2015/01/25',
#   'smallstyle': '綜合日式料理',
#   'status': '正常營業',
#   'tele': '037661870',
#   'viewcount': 1407},
#  {'Ncomment': 1,
#   '_id': ObjectId('5a17c44780b11018380251f8'),
#   'address': '屏東縣屏東市和生路二段96巷21號',
#   'averagecost': 157,
#   'bigstyle': '燒烤類',
#   'collecount': 10,
#   'id': 1000334,
#   'ipeenscore': 35,
#   'lat': 22.557807623557917,
#   'lng': 120.463965248901,
#   'name': '白日夢',
#   'reviewdate': '2015/01/25',
#   'smallstyle': '炭烤串燒',
#   'status': '正常營業',
#   'tele': '0916035553',
#   'viewcount': 7780},
#  {'Ncomment': 0,
#   '_id': ObjectId('5a17c44780b11018380251f9'),
#   'address': '桃園市中壢區中山路8號',
#   'averagecost': 250,
#   'bigstyle': '烘焙、甜點、零食',
#   'collecount': 0,
#   'id': 1000336,
#   'ipeenscore': 45,
#   'lat': 24.9629130106,
#   'lng': 121.22328801831999,
#   'name': '實味香食品',
#   'reviewdate': '2016/01/28',
#   'smallstyle': '休閒零食',
#   'status': '正常營業',
#   'tele': '034223309',
#   'viewcount': 1615},
#  {'Ncomment': 2,
#   '_id': ObjectId('5a17c44780b11018380251fa'),
#   'address': 0,
#   'averagecost': 30,
#   'bigstyle': '小吃',
#   'collecount': 14,
#   'id': 1000340,
#   'ipeenscore': 40,
#   'lat': 24.13576741844,
#   'lng': 120.70099951805,
#   'name': '小韓國雞蛋糕',
#   'reviewdate': '2016/01/28',
#   'smallstyle': '其他小吃',
#   'status': '正常營業',
#   'tele': 0,
#   'viewcount': 18032},
#  {'Ncomment': 1,
#   '_id': ObjectId('5a17c44780b11018380251fb'),
#   'address': 0,
#   'averagecost': 41,
#   'bigstyle': '小吃',
#   'collecount': 0,
#   'id': 1000368,
#   'ipeenscore': 45,
#   'lat': 23.95351350791,
#   'lng': 120.48041051849,
#   'name': '寶哥爌肉飯',
#   'reviewdate': '2016/01/28',
#   'smallstyle': '焢肉飯',
#   'status': '正常營業',
#   'tele': '048828951',
#   'viewcount': 3769},
#  {'Ncomment': 1,
#   '_id': ObjectId('5a17c44780b11018380251fc'),
#   'address': '台中市南區美村路二段180-1號',
#   'averagecost': 95,
#   'bigstyle': '日式料理',
#   'collecount': 2,
#   'id': 1000370,
#   'ipeenscore': 40,
#   'lat': 24.125500016729998,
#   'lng': 120.66304900409,
#   'name': '辛咖哩',
#   'reviewdate': '2015/01/26',
#   'smallstyle': '綜合日式料理',
#   'status': '正常營業',
#   'tele': '0422612999',
#   'viewcount': 4749},
#  {'Ncomment': 1,
#   '_id': ObjectId('5a17c44780b11018380251fd'),
#   'address': '台中市大里區國光路二段145號',
#   'averagecost': 60,
#   'bigstyle': '咖啡、簡餐、茶',
#   'collecount': 1,
#   'id': 1000424,
#   'ipeenscore': 40,
#   'lat': 24.10240690133,
#   'lng': 120.68163221306,
#   'name': '歐森晨間廚房',
#   'reviewdate': '2015/01/26',
#   'smallstyle': '複合式',
#   'status': '正常營業',
#   'tele': '0424073122',
#   'viewcount': 3799},
#  {'Ncomment': 0,
#   '_id': ObjectId('5a17c44780b11018380251fe'),
#   'address': '桃園市中壢區弘揚路84號2樓',
#   'averagecost': 0,
#   'bigstyle': '異國料理',
#   'collecount': 0,
#   'id': 1000426,
#   'ipeenscore': 0,
#   'lat': 24.95366101344,
#   'lng': 121.24154800749,
#   'name': '小米義式廚房',
#   'reviewdate': '2015/01/26',
#   'smallstyle': '義式料理',
#   'status': '正常營業',
#   'tele': '034665502',
#   'viewcount': 785},
#  {'Ncomment': 1,
#   '_id': ObjectId('5a17c44780b11018380251ff'),
#   'address': '台中市西區存中街22-1號',
#   'averagecost': 0,
#   'bigstyle': '異國料理',
#   'collecount': 16,
#   'id': 1000430,
#   'ipeenscore': 0,
#   'lat': 24.14168110268,
#   'lng': 120.66030020254,
#   'name': '樸儷花園Simply',
#   'reviewdate': '2015/01/26',
#   'smallstyle': '法式料理',
#   'status': '正常營業',
#   'tele': 0,
#   'viewcount': 3030},
#  {'Ncomment': 2,
#   '_id': ObjectId('5a17c44780b1101838025200'),
#   'address': '台中市西區公益路89號',
#   'averagecost': 0,
#   'bigstyle': '異國料理',
#   'collecount': 3,
#   'id': 1000432,
#   'ipeenscore': 0,
#   'lat': 24.15064100074,
#   'lng': 120.66700700575,
#   'name': 'Art Cafe & Pasta',
#   'reviewdate': '2016/04/05',
#   'smallstyle': '其他異國料理',
#   'status': '正常營業',
#   'tele': 0,
#   'viewcount': 1980},
#  {'Ncomment': 1,
#   '_id': ObjectId('5a17c44780b1101838025201'),
#   'address': '台中市西區民生路370-2號',
#   'averagecost': 0,
#   'bigstyle': '咖啡、簡餐、茶',
#   'collecount': 1,
#   'id': 1000434,
#   'ipeenscore': 0,
#   'lat': 24.14443820995,
#   'lng': 120.66205820643,
#   'name': 'MIM CAFE',
#   'reviewdate': '2015/06/18',
#   'smallstyle': '複合式',
#   'status': '正常營業',
#   'tele': '0423026857',
#   'viewcount': 1864},
#  {'Ncomment': 1,
#   '_id': ObjectId('5a17c44780b1101838025202'),
#   'address': 0,
#   'averagecost': 0,
#   'bigstyle': '小吃',
#   'collecount': 0,
#   'id': 1000436,
#   'ipeenscore': 0,
#   'lat': 24.02398870245,
#   'lng': 120.69635011046,
#   'name': '古早味蚵嗲.剉冰',
#   'reviewdate': '2016/04/05',
#   'smallstyle': '其他小吃',
#   'status': '正常營業',
#   'tele': 0,
#   'viewcount': 2091},
#  {'Ncomment': 2,
#   '_id': ObjectId('5a17c44780b1101838025203'),
#   'address': '宜蘭縣宜蘭市民權路二段38巷6號',
#   'averagecost': 305,
#   'bigstyle': '亞洲料理',
#   'collecount': 0,
#   'id': 1000460,
#   'ipeenscore': 0,
#   'lat': 24.754852402210002,
#   'lng': 121.75071101801,
#   'name': '韓牛村',
#   'reviewdate': '2015/01/26',
#   'smallstyle': '韓式料理',
#   'status': '正常營業',
#   'tele': 0,
#   'viewcount': 3899},
#  {'Ncomment': 1,
#   '_id': ObjectId('5a17c44780b1101838025204'),
#   'address': 0,
#   'averagecost': 0,
#   'bigstyle': '冷凍/冷藏包裝食品',
#   'collecount': 0,
#   'id': 1000468,
#   'ipeenscore': 45,
#   'lat': 0,
#   'lng': 0,
#   'name': '(好市多/大順店)新鮮草莓千層蛋糕',
#   'reviewdate': '2015/01/26',
#   'smallstyle': '甜點、蛋糕',
#   'status': '正常營業',
#   'tele': '0800885889',
#   'viewcount': 4908},
#  {'Ncomment': 5,
#   '_id': ObjectId('5a17c44780b1101838025205'),
#   'address': '台北市內湖區瑞光路407號',
#   'averagecost': 445,
#   'bigstyle': '異國料理',
#   'collecount': 48,
#   'id': 1000494,
#   'ipeenscore': 45,
#   'lat': 25.078305115510002,
#   'lng': 121.57124500792,
#   'name': "Fatty's 義式餐廳(瑞光店)",
#   'reviewdate': '2016/04/05',
#   'smallstyle': '義式料理',
#   'status': '正常營業',
#   'tele': '0287972688',
#   'viewcount': 17049},
#  {'Ncomment': 2,
#   '_id': ObjectId('5a17c44780b1101838025206'),
#   'address': '台南市中西區民族路三段19號',
#   'averagecost': 35,
#   'bigstyle': '小吃',
#   'collecount': 18,
#   'id': 100050,
#   'ipeenscore': 40,
#   'lat': 22.99901901859,
#   'lng': 120.19857301255999,
#   'name': '金德春捲店',
#   'reviewdate': '2011/08/04',
#   'smallstyle': '其他小吃',
#   'status': '正常營業',
#   'tele': '062285397',
#   'viewcount': 6000},
#  {'Ncomment': 2,
#   '_id': ObjectId('5a17c44780b1101838025207'),
#   'address': '台北市信義區松壽路11號',
#   'averagecost': 70,
#   'bigstyle': '冰品、飲料、甜湯',
#   'collecount': 3,
#   'id': 1000516,
#   'ipeenscore': 40,
#   'lat': 25.03654461386,
#   'lng': 121.56723691004,
#   'name': '于記杏仁豆腐專賣店(新光 A11 店)',
#   'reviewdate': '2016/04/05',
#   'smallstyle': '剉冰、豆花',
#   'status': '正常營業',
#   'tele': '0985380630',
#   'viewcount': 427296},
#  {'Ncomment': 1,
#   '_id': ObjectId('5a17c44780b1101838025208'),
#   'address': '桃園市桃園區中山路837號',
#   'averagecost': 150,
#   'bigstyle': '燒烤類',
#   'collecount': 7,
#   'id': 1000526,
#   'ipeenscore': 45,
#   'lat': 24.989336911720002,
#   'lng': 121.28802900788,
#   'name': '韓宮 韓式料理',
#   'reviewdate': '2015/01/26',
#   'smallstyle': '韓式燒肉',
#   'status': '正常營業',
#   'tele': '0337943',
#   'viewcount': 6337},
#  {'Ncomment': 1,
#   '_id': ObjectId('5a17c44780b1101838025209'),
#   'address': '台南市永康區西勢里廣盛街167號',
#   'averagecost': 0,
#   'bigstyle': '早餐',
#   'collecount': 11,
#   'id': 1000578,
#   'ipeenscore': 40,
#   'lat': 23.02053721271,
#   'lng': 120.27876740249,
#   'name': '西勢無名肉粿',
#   'reviewdate': '2015/01/26',
#   'smallstyle': '中式早餐',
#   'status': '正常營業',
#   'tele': 0,
#   'viewcount': 3746},
#  {'Ncomment': 0,
#   '_id': ObjectId('5a17c44780b110183802520a'),
#   'address': '台南市中西區民族路二段251號',
#   'averagecost': 0,
#   'bigstyle': '小吃',
#   'collecount': 0,
#   'id': 100065,
#   'ipeenscore': 0,
#   'lat': 22.996135005899998,
#   'lng': 120.20437600996,
#   'name': '清香小吃店',
#   'reviewdate': '2011/08/04',
#   'smallstyle': '其他小吃',
#   'status': '正常營業',
#   'tele': '062251540',
#   'viewcount': 1381},
#  {'Ncomment': 38,
#   '_id': ObjectId('5a17c44780b110183802520b'),
#   'address': '台北市松山區富錦街413號',
#   'averagecost': 352,
#   'bigstyle': '咖啡、簡餐、茶',
#   'collecount': 874,
#   'id': 1000654,
#   'ipeenscore': 45,
#   'lat': 25.06092760605,
#   'lng': 121.56070351905005,
#   'name': '九州鬆餅(台北富錦店)',
#   'reviewdate': '2016/01/05',
#   'smallstyle': '咖啡專賣',
#   'status': '正常營業',
#   'tele': '0227495253',
#   'viewcount': 140549},
#  {'Ncomment': 1,
#   '_id': ObjectId('5a17c44780b110183802520c'),
#   'address': '台中市北區永興街358號',
#   'averagecost': 280,
#   'bigstyle': '日式料理',
#   'collecount': 4,
#   'id': 1000704,
#   'ipeenscore': 40,
#   'lat': 24.1679475126,
#   'lng': 120.68289431976,
#   'name': '順億鮪魚專賣店(漢口店)',
#   'reviewdate': '2016/04/03',
#   'smallstyle': '生魚片、壽司專賣',
#   'status': '正常營業',
#   'tele': '0422310328',
#   'viewcount': 6722},
#  {'Ncomment': 1,
#   '_id': ObjectId('5a17c44780b110183802520d'),
#   'address': 0,
#   'averagecost': 40,
#   'bigstyle': '中式料理',
#   'collecount': 0,
#   'id': 1000732,
#   'ipeenscore': 0,
#   'lat': 24.98879300871,
#   'lng': 121.42447040753001,
#   'name': '嘉義粉條冰',
#   'reviewdate': '2016/04/03',
#   'smallstyle': '麵食點心',
#   'status': '正常營業',
#   'tele': 0,
#   'viewcount': 1849},
#  {'Ncomment': 0,
#   '_id': ObjectId('5a17c44780b110183802520e'),
#   'address': 0,
#   'averagecost': 0,
#   'bigstyle': '中式料理',
#   'collecount': 1,
#   'id': 1000738,
#   'ipeenscore': 0,
#   'lat': 23.9702469156,
#   'lng': 120.96613431029999,
#   'name': '川味麵館',
#   'reviewdate': '2015/01/27',
#   'smallstyle': '麵食點心',
#   'status': '正常營業',
#   'tele': '0492420152',
#   'viewcount': 999},
#  {'Ncomment': 4,
#   '_id': ObjectId('5a17c44780b110183802520f'),
#   'address': '台北市大安區忠孝東路四段216巷11弄16號',
#   'averagecost': 95,
#   'bigstyle': '冰品、飲料、甜湯',
#   'collecount': 33,
#   'id': 100075,
#   'ipeenscore': 40,
#   'lat': 25.04070101874,
#   'lng': 121.55374800272,
#   'name': 'LATTEA綠蓋茶館(忠孝216店)',
#   'reviewdate': '2012/09/08',
#   'smallstyle': '果汁',
#   'status': '正常營業',
#   'tele': '0227219909',
#   'viewcount': 38129},
#  {'Ncomment': 1,
#   '_id': ObjectId('5a17c44780b1101838025210'),
#   'address': '桃園市中壢區中北路44號',
#   'averagecost': 0,
#   'bigstyle': '日式料理',
#   'collecount': 0,
#   'id': 1000762,
#   'ipeenscore': 40,
#   'lat': 24.95579801562,
#   'lng': 121.23680001194,
#   'name': '五井拉麵(中壢中北店)',
#   'reviewdate': '2015/01/27',
#   'smallstyle': '綜合日式料理',
#   'status': '正常營業',
#   'tele': '034371980',
#   'viewcount': 3261},
#  {'Ncomment': 1,
#   '_id': ObjectId('5a17c44780b1101838025211'),
#   'address': '台北市內湖區成功路五段67-1號',
#   'averagecost': 600,
#   'bigstyle': '異國料理',
#   'collecount': 4,
#   'id': 1000782,
#   'ipeenscore': 0,
#   'lat': 25.07411600493,
#   'lng': 121.60596100106,
#   'name': "Alleycat's 手工窯烤披薩(東湖店)",
#   'reviewdate': '2016/04/05',
#   'smallstyle': '義式料理',
#   'status': '正常營業',
#   'tele': '0226306278',
#   'viewcount': 1738},
#  {'Ncomment': 2,
#   '_id': ObjectId('5a17c44780b1101838025212'),
#   'address': '台中市龍井區台中港路東園巷56號',
#   'averagecost': 0,
#   'bigstyle': '冰品、飲料、甜湯',
#   'collecount': 2,
#   'id': 1000806,
#   'ipeenscore': 45,
#   'lat': 24.181729214409998,
#   'lng': 120.59255401379001,
#   'name': '首採茶水舖(台中東海店)',
#   'reviewdate': '2016/04/03',
#   'smallstyle': '飲料專賣店',
#   'status': '正常營業',
#   'tele': '0426520161',
#   'viewcount': 3781},
#  {'Ncomment': 3,
#   '_id': ObjectId('5a17c44780b1101838025213'),
#   'address': '台南市中西區國華街三段20巷9號',
#   'averagecost': 95,
#   'bigstyle': '小吃',
#   'collecount': 6,
#   'id': 1000846,
#   'ipeenscore': 45,
#   'lat': 22.993505007539998,
#   'lng': 120.19723700455,
#   'name': '大菜市鮮魚湯',
#   'reviewdate': '2016/04/03',
#   'smallstyle': '其他小吃',
#   'status': '正常營業',
#   'tele': 0,
#   'viewcount': 12466},
#  {'Ncomment': 0,
#   '_id': ObjectId('5a17c44780b1101838025214'),
#   'address': '台南市中西區國華街三段26號',
#   'averagecost': 0,
#   'bigstyle': '小吃',
#   'collecount': 1,
#   'id': 1000854,
#   'ipeenscore': 0,
#   'lat': 22.99379300576,
#   'lng': 120.19761611373,
#   'name': '泰拉瑪香蕉煎餅',
#   'reviewdate': '2016/04/05',
#   'smallstyle': '其他小吃',
#   'status': '正常營業',
#   'tele': 0,
#   'viewcount': 811},
#  {'Ncomment': 1,
#   '_id': ObjectId('5a17c44780b1101838025215'),
#   'address': '台中市沙鹿區沙田路60-2號',
#   'averagecost': 0,
#   'bigstyle': '中式料理',
#   'collecount': 1,
#   'id': 1000856,
#   'ipeenscore': 45,
#   'lat': 24.232656000739997,
#   'lng': 120.55909600759999,
#   'name': '粥遊天下(沙鹿店)',
#   'reviewdate': '2015/01/27',
#   'smallstyle': '其它中式料理',
#   'status': '正常營業',
#   'tele': '0426355626',
#   'viewcount': 3473},
#  {'Ncomment': 1,
#   '_id': ObjectId('5a17c44780b1101838025216'),
#   'address': '台中市清水區光明路35-3號',
#   'averagecost': 0,
#   'bigstyle': '素食',
#   'collecount': 2,
#   'id': 1000858,
#   'ipeenscore': 40,
#   'lat': 24.27119200229,
#   'lng': 120.5785060009,
#   'name': '淨光心香素食館',
#   'reviewdate': '2015/01/27',
#   'smallstyle': '中式',
#   'status': '正常營業',
#   'tele': '0426225688',
#   'viewcount': 4178},
#  {'Ncomment': 1,
#   '_id': ObjectId('5a17c44780b1101838025217'),
#   'address': 0,
#   'averagecost': 155,
#   'bigstyle': '咖啡、簡餐、茶',
#   'collecount': 3,
#   'id': 1000864,
#   'ipeenscore': 0,
#   'lat': 23.97072521214,
#   'lng': 120.95865170656,
#   'name': '兔兒咖啡 tour cafe',
#   'reviewdate': '2016/03/16',
#   'smallstyle': '咖啡專賣',
#   'status': '正常營業',
#   'tele': '0492918550',
#   'viewcount': 2050},
#  {'Ncomment': 1,
#   '_id': ObjectId('5a17c44780b1101838025218'),
#   'address': '高雄市梓官區蚵仔寮鄉中正路218號',
#   'averagecost': 0,
#   'bigstyle': '中式料理',
#   'collecount': 1,
#   'id': 1000886,
#   'ipeenscore': 45,
#   'lat': 22.73105800087,
#   'lng': 120.2498290022,
#   'name': '雅園熱炒',
#   'reviewdate': '2015/01/28',
#   'smallstyle': '海鮮餐廳',
#   'status': '正常營業',
#   'tele': '0977029252',
#   'viewcount': 2801},
#  {'Ncomment': 1,
#   '_id': ObjectId('5a17c44780b1101838025219'),
#   'address': 0,
#   'averagecost': 25,
#   'bigstyle': '冷凍/冷藏包裝食品',
#   'collecount': 0,
#   'id': 100089,
#   'ipeenscore': 45,
#   'lat': 0,
#   'lng': 0,
#   'name': '開喜 梅嶺梅子茶',
#   'reviewdate': '2011/07/15',
#   'smallstyle': '飲料、冰品',
#   'status': '正常營業',
#   'tele': 0,
#   'viewcount': 4747},
#  {'Ncomment': 0,
#   '_id': ObjectId('5a17c44780b110183802521a'),
#   'address': '高雄市三民區熱河一街145號',
#   'averagecost': 0,
#   'bigstyle': '主題特色餐廳',
#   'collecount': 0,
#   'id': 1000898,
#   'ipeenscore': 0,
#   'lat': 22.643418718680003,
#   'lng': 120.30962061461,
#   'name': 'FUN4(高醫店)',
#   'reviewdate': '2016/04/05',
#   'smallstyle': '其它主題餐廳',
#   'status': '正常營業',
#   'tele': '0928978199',
#   'viewcount': 1057},
#  {'Ncomment': 1,
#   '_id': ObjectId('5a17c44780b110183802521b'),
#   'address': 0,
#   'averagecost': 30,
#   'bigstyle': '冷凍/冷藏包裝食品',
#   'collecount': 0,
#   'id': 100090,
#   'ipeenscore': 45,
#   'lat': 0,
#   'lng': 0,
#   'name': "「杜老爺」O'Black咖啡甜筒",
#   'reviewdate': '2011/07/15',
#   'smallstyle': '飲料、冰品',
#   'status': '正常營業',
#   'tele': 0,
#   'viewcount': 6768},
#  {'Ncomment': 1,
#   '_id': ObjectId('5a17c44780b110183802521c'),
#   'address': 0,
#   'averagecost': 0,
#   'bigstyle': '冷凍/冷藏包裝食品',
#   'collecount': 0,
#   'id': 1000906,
#   'ipeenscore': 45,
#   'lat': 0,
#   'lng': 0,
#   'name': '手工包子',
#   'reviewdate': '2015/01/28',
#   'smallstyle': '小吃特產',
#   'status': '正常營業',
#   'tele': 0,
#   'viewcount': 2240},
#  {'Ncomment': 1,
#   '_id': ObjectId('5a17c44780b110183802521d'),
#   'address': 0,
#   'averagecost': 0,
#   'bigstyle': '烘焙、甜點、零食',
#   'collecount': 0,
#   'id': 1000918,
#   'ipeenscore': 40,
#   'lat': 25.01463790752,
#   'lng': 121.46462670564,
#   'name': '橘村園',
#   'reviewdate': '2016/04/05',
#   'smallstyle': '西點烘焙、麵包',
#   'status': '正常營業',
#   'tele': 0,
#   'viewcount': 3870},
#  {'Ncomment': 0,
#   '_id': ObjectId('5a17c44780b110183802521e'),
#   'address': '台南市仁德區德安路159號',
#   'averagecost': 0,
#   'bigstyle': '冰品、飲料、甜湯',
#   'collecount': 1,
#   'id': 1000926,
#   'ipeenscore': 0,
#   'lat': 22.951023216560003,
#   'lng': 120.25398941649999,
#   'name': '府城體育公園杏仁豆腐冰(仁德德安店)',
#   'reviewdate': '2015/01/28',
#   'smallstyle': '剉冰、豆花',
#   'status': '正常營業',
#   'tele': '062496658',
#   'viewcount': 1625},
#  {'Ncomment': 0,
#   '_id': ObjectId('5a17c44780b110183802521f'),
#   'address': '台北市中正區館前路22號',
#   'averagecost': 0,
#   'bigstyle': '冰品、飲料、甜湯',
#   'collecount': 0,
#   'id': 100093,
#   'ipeenscore': 40,
#   'lat': 25.04511901272,
#   'lng': 121.51486701844999,
#   'name': '歇腳亭(館前店)',
#   'reviewdate': '2011/07/15',
#   'smallstyle': '飲料專賣店',
#   'status': '正常營業',
#   'tele': '0223617222',
#   'viewcount': 1670},
#  {'Ncomment': 0,
#   '_id': ObjectId('5a17c44780b1101838025220'),
#   'address': '台北市信義區松高路16號3樓',
#   'averagecost': 0,
#   'bigstyle': '異國料理',
#   'collecount': 3,
#   'id': 1000934,
#   'ipeenscore': 0,
#   'lat': 25.038983417009998,
#   'lng': 121.56727300199,
#   'name': 'Texas Roadhouse德州鮮切牛排',
#   'reviewdate': '2015/03/02',
#   'smallstyle': '美式料理',
#   'status': '正常營業',
#   'tele': '0227251030',
#   'viewcount': 825},
#  {'Ncomment': 5,
#   '_id': ObjectId('5a17c44780b1101838025221'),
#   'address': '台北市中正區許昌街26-1號',
#   'averagecost': 37,
#   'bigstyle': '小吃',
#   'collecount': 68,
#   'id': 100094,
#   'ipeenscore': 40,
#   'lat': 25.04549200297,
#   'lng': 121.51628800822,
#   'name': '阿仁福州包',
#   'reviewdate': '2011/07/15',
#   'smallstyle': '其他小吃',
#   'status': '正常營業',
#   'tele': '0223888565',
#   'viewcount': 231278},
#  {'Ncomment': 1,
#   '_id': ObjectId('5a17c44780b1101838025222'),
#   'address': 0,
#   'averagecost': 0,
#   'bigstyle': '網購包裝食品',
#   'collecount': 0,
#   'id': 1000940,
#   'ipeenscore': 0,
#   'lat': 0,
#   'lng': 0,
#   'name': "魔術食品/奈'S菌乳酸菌粉",
#   'reviewdate': '2015/01/28',
#   'smallstyle': '其他網購包裝食品',
#   'status': '正常營業',
#   'tele': 0,
#   'viewcount': 948},
#  {'Ncomment': 1,
#   '_id': ObjectId('5a17c44780b1101838025223'),
#   'address': 0,
#   'averagecost': 0,
#   'bigstyle': '網購包裝食品',
#   'collecount': 0,
#   'id': 1000980,
#   'ipeenscore': 45,
#   'lat': 0,
#   'lng': 0,
#   'name': '台灣香蕉麵',
#   'reviewdate': '2015/01/28',
#   'smallstyle': '其他網購包裝食品',
#   'status': '正常營業',
#   'tele': 0,
#   'viewcount': 2184},
#  {'Ncomment': 1,
#   '_id': ObjectId('5a17c44780b1101838025224'),
#   'address': '高雄市三民區褒陽東街170號',
#   'averagecost': 0,
#   'bigstyle': '鍋類',
#   'collecount': 5,
#   'id': 1001000,
#   'ipeenscore': 45,
#   'lat': 22.64044600374,
#   'lng': 120.34574730142,
#   'name': '品宴鍋物',
#   'reviewdate': '2015/01/29',
#   'smallstyle': '其他鍋類',
#   'status': '正常營業',
#   'tele': '077678318',
#   'viewcount': 4749},
#  {'Ncomment': 1,
#   '_id': ObjectId('5a17c44780b1101838025225'),
#   'address': '新北市三重區五華街49號',
#   'averagecost': 0,
#   'bigstyle': '速食料理',
#   'collecount': 0,
#   'id': 1001040,
#   'ipeenscore': 40,
#   'lat': 25.08127311288,
#   'lng': 121.49426581952,
#   'name': '雞大爺',
#   'reviewdate': '2015/01/28',
#   'smallstyle': '其他速食',
#   'status': '正常營業',
#   'tele': 0,
#   'viewcount': 9106},
#  {'Ncomment': 1,
#   '_id': ObjectId('5a17c44780b1101838025226'),
#   'address': '台北市北投區東華街166號',
#   'averagecost': 210,
#   'bigstyle': '中式料理',
#   'collecount': 1,
#   'id': 1001044,
#   'ipeenscore': 45,
#   'lat': 25.11991340646,
#   'lng': 121.51158811568,
#   'name': '東華166號',
#   'reviewdate': '2016/04/05',
#   'smallstyle': '麵食點心',
#   'status': '正常營業',
#   'tele': 0,
#   'viewcount': 6237},
#  {'Ncomment': 1,
#   '_id': ObjectId('5a17c44780b1101838025227'),
#   'address': 0,
#   'averagecost': 0,
#   'bigstyle': '常溫包裝食品',
#   'collecount': 0,
#   'id': 1001046,
#   'ipeenscore': 40,
#   'lat': 0,
#   'lng': 0,
#   'name': '虱目魚菲力脆片-海苔',
#   'reviewdate': '2015/01/29',
#   'smallstyle': '餅乾、零食',
#   'status': '正常營業',
#   'tele': 0,
#   'viewcount': 1613},
#  {'Ncomment': 1,
#   '_id': ObjectId('5a17c44780b1101838025228'),
#   'address': 0,
#   'averagecost': 20,
#   'bigstyle': '常溫包裝食品',
#   'collecount': 0,
#   'id': 1001064,
#   'ipeenscore': 0,
#   'lat': 0,
#   'lng': 0,
#   'name': '古早滷味',
#   'reviewdate': '2015/01/29',
#   'smallstyle': '小吃特產',
#   'status': '正常營業',
#   'tele': '0228937121',
#   'viewcount': 746},
#  {'Ncomment': 3,
#   '_id': ObjectId('5a17c44780b1101838025229'),
#   'address': '桃園市中壢區慈惠三街110號',
#   'averagecost': 70,
#   'bigstyle': '早餐',
#   'collecount': 15,
#   'id': 1001072,
#   'ipeenscore': 40,
#   'lat': 24.96323650186,
#   'lng': 121.22566801226,
#   'name': '蜜蜂小吧快餐車 bee bar',
#   'reviewdate': '2015/01/29',
#   'smallstyle': '西式早餐',
#   'status': '正常營業',
#   'tele': '0972820555',
#   'viewcount': 10114},
#  {'Ncomment': 2,
#   '_id': ObjectId('5a17c44780b110183802522a'),
#   'address': '台中市外埔區水美路8-15號',
#   'averagecost': 0,
#   'bigstyle': '烘焙、甜點、零食',
#   'collecount': 4,
#   'id': 1001082,
#   'ipeenscore': 45,
#   'lat': 24.33090710246,
#   'lng': 120.63460871201,
#   'name': '麻姥姥手工餅舖',
#   'reviewdate': '2016/02/17',
#   'smallstyle': '中式糕餅',
#   'status': '正常營業',
#   'tele': '0426836847',
#   'viewcount': 784567},
#  {'Ncomment': 1,
#   '_id': ObjectId('5a17c44780b110183802522b'),
#   'address': 0,
#   'averagecost': 150,
#   'bigstyle': '常溫包裝食品',
#   'collecount': 0,
#   'id': 1001086,
#   'ipeenscore': 45,
#   'lat': 0,
#   'lng': 0,
#   'name': '芋泥餅',
#   'reviewdate': '2015/01/29',
#   'smallstyle': '小吃特產',
#   'status': '正常營業',
#   'tele': '088714890',
#   'viewcount': 7699},
#  {'Ncomment': 1,
#   '_id': ObjectId('5a17c44780b110183802522c'),
#   'address': '台南市中西區五妃街270號',
#   'averagecost': 0,
#   'bigstyle': '異國料理',
#   'collecount': 0,
#   'id': 1001088,
#   'ipeenscore': 45,
#   'lat': 22.982592102490003,
#   'lng': 120.20198430085,
#   'name': '義式意適',
#   'reviewdate': '2015/01/29',
#   'smallstyle': '義式料理',
#   'status': '正常營業',
#   'tele': '062143969',
#   'viewcount': 3411},
#  {'Ncomment': 6,
#   '_id': ObjectId('5a17c44780b110183802522d'),
#   'address': '高雄市苓雅區青年一路1-10號',
#   'averagecost': 338,
#   'bigstyle': '主題特色餐廳',
#   'collecount': 75,
#   'id': 1001090,
#   'ipeenscore': 45,
#   'lat': 22.62188880205,
#   'lng': 120.30828790990999,
#   'name': '樂樂小時光 Le Organic Babe Family Friendly Bistro',
#   'reviewdate': '2016/04/03',
#   'smallstyle': '其它主題餐廳',
#   'status': '正常營業',
#   'tele': 0,
#   'viewcount': 16754},
#  {'Ncomment': 3,
#   '_id': ObjectId('5a17c44780b110183802522e'),
#   'address': 0,
#   'averagecost': 0,
#   'bigstyle': '常溫包裝食品',
#   'collecount': 0,
#   'id': 1001096,
#   'ipeenscore': 45,
#   'lat': 0,
#   'lng': 0,
#   'name': '你滋美得',
#   'reviewdate': '2015/01/29',
#   'smallstyle': '保健食品',
#   'status': '正常營業',
#   'tele': 0,
#   'viewcount': 4902},
#  {'Ncomment': 0,
#   '_id': ObjectId('5a17c44780b110183802522f'),
#   'address': '宜蘭縣宜蘭市新民路182號',
#   'averagecost': 0,
#   'bigstyle': '小吃',
#   'collecount': 3,
#   'id': 1001132,
#   'ipeenscore': 0,
#   'lat': 24.75789890279,
#   'lng': 121.75292171242,
#   'name': '第一家蒜味鴨賞麵線',
#   'reviewdate': '2015/01/29',
#   'smallstyle': '麵線',
#   'status': '正常營業',
#   'tele': '0970772746',
#   'viewcount': 1328},
#  {'Ncomment': 0,
#   '_id': ObjectId('5a17c44780b1101838025230'),
#   'address': 0,
#   'averagecost': 0,
#   'bigstyle': '冷凍/冷藏包裝食品',
#   'collecount': 0,
#   'id': 1001186,
#   'ipeenscore': 0,
#   'lat': 0,
#   'lng': 0,
#   'name': '御食鮮沙茶雞',
#   'reviewdate': '2015/01/29',
#   'smallstyle': '其他冷凍/冷藏包裝食品',
#   'status': '正常營業',
#   'tele': '0956838888',
#   'viewcount': 576},
#  {'Ncomment': 0,
#   '_id': ObjectId('5a17c44780b1101838025231'),
#   'address': 0,
#   'averagecost': 0,
#   'bigstyle': '小吃',
#   'collecount': 1,
#   'id': 1001282,
#   'ipeenscore': 0,
#   'lat': 23.97589901452,
#   'lng': 120.68296001325,
#   'name': '玉佳珍肉圓',
#   'reviewdate': '2015/01/29',
#   'smallstyle': '肉圓',
#   'status': '正常營業',
#   'tele': '0492305679',
#   'viewcount': 1018},
#  {'Ncomment': 1,
#   '_id': ObjectId('5a17c44780b1101838025232'),
#   'address': '台北市信義區松仁路28號',
#   'averagecost': 0,
#   'bigstyle': '咖啡、簡餐、茶',
#   'collecount': 10,
#   'id': 1001302,
#   'ipeenscore': 45,
#   'lat': 25.039244109840002,
#   'lng': 121.56818311461,
#   'name': 'BELLAVITA CAFÉ',
#   'reviewdate': '2016/04/05',
#   'smallstyle': '複合式',
#   'status': '正常營業',
#   'tele': 0,
#   'viewcount': 3515},
#  {'Ncomment': 2,
#   '_id': ObjectId('5a17c44780b1101838025233'),
#   'address': '台北市萬華區 中華路一段114巷2號',
#   'averagecost': 123,
#   'bigstyle': '小吃',
#   'collecount': 1,
#   'id': 1001322,
#   'ipeenscore': 40,
#   'lat': 25.043792911609998,
#   'lng': 121.50813500913,
#   'name': '梨園小吃店',
#   'reviewdate': '2015/01/29',
#   'smallstyle': '其他小吃',
#   'status': '正常營業',
#   'tele': 0,
#   'viewcount': 4735},
#  {'Ncomment': 2,
#   '_id': ObjectId('5a17c44780b1101838025234'),
#   'address': '台中市西屯區太原路一段68號',
#   'averagecost': 80,
#   'bigstyle': '中式料理',
#   'collecount': 10,
#   'id': 1001360,
#   'ipeenscore': 40,
#   'lat': 24.1596543193,
#   'lng': 120.65892291214999,
#   'name': '廣豐燒臘',
#   'reviewdate': '2015/01/29',
#   'smallstyle': '其它中式料理',
#   'status': '正常營業',
#   'tele': '0423169522',
#   'viewcount': 7016},
#  {'Ncomment': 1,
#   '_id': ObjectId('5a17c44780b1101838025235'),
#   'address': '高雄市岡山區維仁路73號',
#   'averagecost': 60,
#   'bigstyle': '小吃',
#   'collecount': 2,
#   'id': 1001380,
#   'ipeenscore': 40,
#   'lat': 22.79332230574,
#   'lng': 120.29218250049999,
#   'name': '黃家古早味美食',
#   'reviewdate': '2015/01/30',
#   'smallstyle': '其他小吃',
#   'status': '正常營業',
#   'tele': '076216500',
#   'viewcount': 7700},
#  {'Ncomment': 0,
#   '_id': ObjectId('5a17c44780b1101838025236'),
#   'address': '高雄市三民區泰安街50號',
#   'averagecost': 0,
#   'bigstyle': '亞洲料理',
#   'collecount': 1,
#   'id': 1001402,
#   'ipeenscore': 0,
#   'lat': 22.64430961954,
#   'lng': 120.31067920850998,
#   'name': '祥鶴家南洋創意料理',
#   'reviewdate': '2015/01/30',
#   'smallstyle': '綜合南洋料理',
#   'status': '正常營業',
#   'tele': '073212525',
#   'viewcount': 1132},
#  {'Ncomment': 0,
#   '_id': ObjectId('5a17c44780b1101838025237'),
#   'address': '台中市北區健行路958號',
#   'averagecost': 0,
#   'bigstyle': '異國料理',
#   'collecount': 0,
#   'id': 1001408,
#   'ipeenscore': 0,
#   'lat': 24.159278813729998,
#   'lng': 120.66545500632999,
#   'name': 'Mon cafe',
#   'reviewdate': '2015/01/30',
#   'smallstyle': '其他異國料理',
#   'status': '正常營業',
#   'tele': '0423262393',
#   'viewcount': 596},
#  {'Ncomment': 3,
#   '_id': ObjectId('5a17c44780b1101838025238'),
#   'address': '基隆市信義區信一路177號17樓',
#   'averagecost': 0,
#   'bigstyle': '咖啡、簡餐、茶',
#   'collecount': 7,
#   'id': 1001418,
#   'ipeenscore': 40,
#   'lat': 25.13074130798,
#   'lng': 121.74470041492,
#   'name': '伊豆食堂',
#   'reviewdate': '2016/07/20',
#   'smallstyle': '複合式',
#   'status': '正常營業',
#   'tele': '0224251122',
#   'viewcount': 16877},
#  {'Ncomment': 4,
#   '_id': ObjectId('5a17c44780b1101838025239'),
#   'address': '台北市大安區復興南路一段107巷5弄14號',
#   'averagecost': 274,
#   'bigstyle': '主題特色餐廳',
#   'collecount': 191,
#   'id': 1001420,
#   'ipeenscore': 40,
#   'lat': 25.044126111609998,
#   'lng': 121.54499741511,
#   'name': '啜飲室',
#   'reviewdate': '2015/01/30',
#   'smallstyle': '酒吧 Lounge Bar',
#   'status': '正常營業',
#   'tele': '0287739001',
#   'viewcount': 32485},
#  {'Ncomment': 1,
#   '_id': ObjectId('5a17c44780b110183802523a'),
#   'address': 0,
#   'averagecost': 0,
#   'bigstyle': '網購包裝食品',
#   'collecount': 0,
#   'id': 1001434,
#   'ipeenscore': 45,
#   'lat': 0,
#   'lng': 0,
#   'name': '江蘇 清水大閘蟹',
#   'reviewdate': '2015/01/30',
#   'smallstyle': '其他網購包裝食品',
#   'status': '正常營業',
#   'tele': 0,
#   'viewcount': 1576},
#  {'Ncomment': 0,
#   '_id': ObjectId('5a17c44780b110183802523b'),
#   'address': '台北市北投區大業路448號',
#   'averagecost': 0,
#   'bigstyle': '中式料理',
#   'collecount': 0,
#   'id': 1001466,
#   'ipeenscore': 0,
#   'lat': 25.13125401033,
#   'lng': 121.4965950046,
#   'name': '泓谷餐廳',
#   'reviewdate': '2015/01/30',
#   'smallstyle': '台菜餐廳',
#   'status': '正常營業',
#   'tele': '0228964848',
#   'viewcount': 2713},
#  {'Ncomment': 1,
#   '_id': ObjectId('5a17c44780b110183802523c'),
#   'address': 0,
#   'averagecost': 36,
#   'bigstyle': '冰品、飲料、甜湯',
#   'collecount': 4,
#   'id': 1001484,
#   'ipeenscore': 40,
#   'lat': 23.449674308970003,
#   'lng': 120.43366301215002,
#   'name': '小紅帽義式冰淇淋',
#   'reviewdate': '2015/01/30',
#   'smallstyle': '冰淇淋',
#   'status': '正常營業',
#   'tele': '052354813',
#   'viewcount': 432644},
#  {'Ncomment': 6,
#   '_id': ObjectId('5a17c44780b110183802523d'),
#   'address': '新竹縣竹北市莊敬南路91號',
#   'averagecost': 0,
#   'bigstyle': '鍋類',
#   'collecount': 10,
#   'id': 1001492,
#   'ipeenscore': 45,
#   'lat': 24.81723771666,
#   'lng': 121.02059121961,
#   'name': '元世祖火鍋店',
#   'reviewdate': '2015/01/30',
#   'smallstyle': '其他鍋類',
#   'status': '正常營業',
#   'tele': '036583133',
#   'viewcount': 8468},
#  {'Ncomment': 1,
#   '_id': ObjectId('5a17c44780b110183802523e'),
#   'address': 0,
#   'averagecost': 218,
#   'bigstyle': '鍋類',
#   'collecount': 1,
#   'id': 1001572,
#   'ipeenscore': 35,
#   'lat': 24.68719871957,
#   'lng': 120.90146041327,
#   'name': '太將鍋(太將鍋[頭份店])',
#   'reviewdate': '2015/01/30',
#   'smallstyle': '其他鍋類',
#   'status': '正常營業',
#   'tele': '037590026',
#   'viewcount': 4698},
#  {'Ncomment': 1,
#   '_id': ObjectId('5a17c44780b110183802523f'),
#   'address': 0,
#   'averagecost': 0,
#   'bigstyle': '網購包裝食品',
#   'collecount': 0,
#   'id': 1001600,
#   'ipeenscore': 45,
#   'lat': 0,
#   'lng': 0,
#   'name': 'MuMu手作巧克力',
#   'reviewdate': '2015/01/31',
#   'smallstyle': '甜點、蛋糕',
#   'status': '正常營業',
#   'tele': '0961324770',
#   'viewcount': 1165},
#  {'Ncomment': 1,
#   '_id': ObjectId('5a17c44780b1101838025240'),
#   'address': 0,
#   'averagecost': 134,
#   'bigstyle': '常溫包裝食品',
#   'collecount': 0,
#   'id': 1001610,
#   'ipeenscore': 45,
#   'lat': 0,
#   'lng': 0,
#   'name': 'Costco好市多 全麥核桃葡萄麵包',
#   'reviewdate': '2015/01/31',
#   'smallstyle': '麵包、西點',
#   'status': '正常營業',
#   'tele': 0,
#   'viewcount': 3107},
#  {'Ncomment': 4,
#   '_id': ObjectId('5a17c44780b1101838025241'),
#   'address': '台中市潭子區潭興路一段17巷35之8號',
#   'averagecost': 284,
#   'bigstyle': '主題特色餐廳',
#   'collecount': 95,
#   'id': 1001666,
#   'ipeenscore': 45,
#   'lat': 24.2039686171,
#   'lng': 120.72488640524,
#   'name': '領袖山莊 Leader(原嶺秀山莊)',
#   'reviewdate': '2015/05/04',
#   'smallstyle': '景觀餐廳',
#   'status': '正常營業',
#   'tele': '0425391099',
#   'viewcount': 230867},
#  {'Ncomment': 2,
#   '_id': ObjectId('5a17c44780b1101838025242'),
#   'address': '高雄市三民區青年路二段626號',
#   'averagecost': 0,
#   'bigstyle': '烘焙、甜點、零食',
#   'collecount': 2,
#   'id': 1001672,
#   'ipeenscore': 45,
#   'lat': 22.64712430998,
#   'lng': 120.34764851696,
#   'name': 'bread show麵包秀手感烘焙(自由店)',
#   'reviewdate': '2015/01/31',
#   'smallstyle': '西點烘焙、麵包',
#   'status': '正常營業',
#   'tele': 0,
#   'viewcount': 6032},
#  {'Ncomment': 11,
#   '_id': ObjectId('5a17c44780b1101838025243'),
#   'address': '桃園市桃園區中寧街17號',
#   'averagecost': 1515,
#   'bigstyle': '日式料理',
#   'collecount': 36,
#   'id': 1001676,
#   'ipeenscore': 45,
#   'lat': 24.99048380504,
#   'lng': 121.30591081899,
#   'name': '南木町割烹料理',
#   'reviewdate': '2016/02/05',
#   'smallstyle': '綜合日式料理',
#   'status': '正常營業',
#   'tele': '033465280',
#   'viewcount': 17509},
#  {'Ncomment': 12,
#   '_id': ObjectId('5a17c44780b1101838025244'),
#   'address': '台北市信義區逸仙路26巷17號',
#   'averagecost': 765,
#   'bigstyle': '異國料理',
#   'collecount': 359,
#   'id': 1001710,
#   'ipeenscore': 45,
#   'lat': 25.03967551589,
#   'lng': 121.56244601163999,
#   'name': '30 Thirty 老酒館',
#   'reviewdate': '2016/03/27',
#   'smallstyle': '義式料理',
#   'status': '正常營業',
#   'tele': '0287892663',
#   'viewcount': 55836},
#  {'Ncomment': 14,
#   '_id': ObjectId('5a17c44780b1101838025245'),
#   'address': '新竹市東區關新東路199號',
#   'averagecost': 339,
#   'bigstyle': '鍋類',
#   'collecount': 33,
#   'id': 1001722,
#   'ipeenscore': 45,
#   'lat': 24.78540860671,
#   'lng': 121.01993950266001,
#   'name': '鼎盛十里鍋の物',
#   'reviewdate': '2016/04/05',
#   'smallstyle': '涮涮鍋',
#   'status': '正常營業',
#   'tele': '035785959',
#   'viewcount': 29095},
#  {'Ncomment': 0,
#   '_id': ObjectId('5a17c44780b1101838025246'),
#   'address': '新北市新店區大豐路2號',
#   'averagecost': 0,
#   'bigstyle': '冰品、飲料、甜湯',
#   'collecount': 1,
#   'id': 1001748,
#   'ipeenscore': 0,
#   'lat': 24.98054630354,
#   'lng': 121.54155001322,
#   'name': 'CITY MILK木瓜牛奶(新店大豐店)',
#   'reviewdate': '2016/04/12',
#   'smallstyle': '飲料專賣店',
#   'status': '正常營業',
#   'tele': '0229111194',
#   'viewcount': 1510},
#  {'Ncomment': 3,
#   '_id': ObjectId('5a17c44780b1101838025247'),
#   'address': '台南市東區中華東路一段366號',
#   'averagecost': 344,
#   'bigstyle': '日式料理',
#   'collecount': 5,
#   'id': 1001756,
#   'ipeenscore': 40,
#   'lat': 22.98988370235,
#   'lng': 120.23359180058,
#   'name': '大戶屋(南紡購物中心店)',
#   'reviewdate': '2017/03/04',
#   'smallstyle': '綜合日式料理',
#   'status': '正常營業',
#   'tele': '062377887',
#   'viewcount': 7141},
#  {'Ncomment': 1,
#   '_id': ObjectId('5a17c44780b1101838025248'),
#   'address': '南投縣南投市中學西路181號',
#   'averagecost': 105,
#   'bigstyle': '早餐',
#   'collecount': 3,
#   'id': 1001760,
#   'ipeenscore': 0,
#   'lat': 23.944670315009997,
#   'lng': 120.68901980477,
#   'name': '炸蛋吐司',
#   'reviewdate': '2015/02/02',
#   'smallstyle': '西式早餐',
#   'status': '正常營業',
#   'tele': '0492351455',
#   'viewcount': 2486},
#  {'Ncomment': 2,
#   '_id': ObjectId('5a17c44780b1101838025249'),
#   'address': '新竹縣竹北市縣政十街75號',
#   'averagecost': 308,
#   'bigstyle': '日式料理',
#   'collecount': 3,
#   'id': 1001770,
#   'ipeenscore': 45,
#   'lat': 24.84117200641,
#   'lng': 120.98925500141,
#   'name': '心丼隱食堂(心丼隱食堂)',
#   'reviewdate': '2015/02/01',
#   'smallstyle': '其他日式料理',
#   'status': '正常營業',
#   'tele': '036570882',
#   'viewcount': 11093},
#  {'Ncomment': 0,
#   '_id': ObjectId('5a17c44780b110183802524a'),
#   'address': '台中市北區一中街25號',
#   'averagecost': 0,
#   'bigstyle': '冰品、飲料、甜湯',
#   'collecount': 0,
#   'id': 1001774,
#   'ipeenscore': 0,
#   'lat': 24.147407119769998,
#   'lng': 120.6841005078,
#   'name': 'CITY MILK木瓜牛奶(一中店)',
#   'reviewdate': '2016/04/12',
#   'smallstyle': '飲料專賣店',
#   'status': '正常營業',
#   'tele': '0422256658',
#   'viewcount': 796},
#  {'Ncomment': 5,
#   '_id': ObjectId('5a17c44780b110183802524b'),
#   'address': 0,
#   'averagecost': 285,
#   'bigstyle': '網購包裝食品',
#   'collecount': 2,
#   'id': 100178,
#   'ipeenscore': 45,
#   'lat': 0,
#   'lng': 0,
#   'name': '團購大國民-一中金燒',
#   'reviewdate': '2011/07/15',
#   'smallstyle': '甜點、蛋糕',
#   'status': '正常營業',
#   'tele': 0,
#   'viewcount': 17774},
#  {'Ncomment': 2,
#   '_id': ObjectId('5a17c44780b110183802524c'),
#   'address': '台北市中山區樂群三路218號',
#   'averagecost': 0,
#   'bigstyle': '異國料理',
#   'collecount': 6,
#   'id': 1001816,
#   'ipeenscore': 45,
#   'lat': 25.08248791486,
#   'lng': 121.55809351855,
#   'name': 'YUMMI HUB(大直店)',
#   'reviewdate': '2015/02/01',
#   'smallstyle': '墨西哥料理',
#   'status': '正常營業',
#   'tele': 0,
#   'viewcount': 4805},
#  {'Ncomment': 1,
#   '_id': ObjectId('5a17c44780b110183802524d'),
#   'address': '台北市信義區安東街18號',
#   'averagecost': 260,
#   'bigstyle': '咖啡、簡餐、茶',
#   'collecount': 16,
#   'id': 1001842,
#   'ipeenscore': 45,
#   'lat': 25.045343004219998,
#   'lng': 121.54210500546,
#   'name': 'Think Cafe',
#   'reviewdate': '2015/02/01',
#   'smallstyle': '複合式',
#   'status': '正常營業',
#   'tele': 0,
#   'viewcount': 6481},
#  {'Ncomment': 0,
#   '_id': ObjectId('5a17c44780b110183802524e'),
#   'address': '高雄市大社區自由路54號',
#   'averagecost': 50,
#   'bigstyle': '早餐',
#   'collecount': 0,
#   'id': 1001858,
#   'ipeenscore': 45,
#   'lat': 22.70681001573,
#   'lng': 120.33640700276999,
#   'name': '卡麥哆',
#   'reviewdate': '2016/01/28',
#   'smallstyle': '西式早餐',
#   'status': '正常營業',
#   'tele': 0,
#   'viewcount': 2143},
#  {'Ncomment': 0,
#   '_id': ObjectId('5a17c44780b110183802524f'),
#   'address': '高雄市新興區六合二路187號',
#   'averagecost': 0,
#   'bigstyle': '中式料理',
#   'collecount': 1,
#   'id': 1001864,
#   'ipeenscore': 0,
#   'lat': 22.630208404450002,
#   'lng': 120.29384051033,
#   'name': '台南旺海產店．鱔魚意麵',
#   'reviewdate': '2016/04/05',
#   'smallstyle': '熱炒、快炒',
#   'status': '正常營業',
#   'tele': '072720999',
#   'viewcount': 1230},
#  {'Ncomment': 0,
#   '_id': ObjectId('5a17c44780b1101838025250'),
#   'address': '新北市淡水區新市一路三段121號',
#   'averagecost': 110,
#   'bigstyle': '中式料理',
#   'collecount': 3,
#   'id': 100192,
#   'ipeenscore': 40,
#   'lat': 25.183660799029635,
#   'lng': 121.44692660977051,
#   'name': '餃子工坊(新市總店)',
#   'reviewdate': '2011/07/27',
#   'smallstyle': '麵食點心',
#   'status': '正常營業',
#   'tele': 0,
#   'viewcount': 2943},
#  {'Ncomment': 9,
#   '_id': ObjectId('5a17c44780b1101838025251'),
#   'address': '台北市萬華區中華路59-1號',
#   'averagecost': 99,
#   'bigstyle': '小吃',
#   'collecount': 14,
#   'id': 1001924,
#   'ipeenscore': 45,
#   'lat': 25.062270319880003,
#   'lng': 121.48358591639,
#   'name': '90後 JoHouLim(台北西門店)',
#   'reviewdate': '2015/02/01',
#   'smallstyle': '刈包',
#   'status': '正常營業',
#   'tele': '0223318357',
#   'viewcount': 20189},
#  {'Ncomment': 2,
#   '_id': ObjectId('5a17c44780b1101838025252'),
#   'address': '新北市淡水區大忠街40號',
#   'averagecost': 69,
#   'bigstyle': '中式料理',
#   'collecount': 11,
#   'id': 1001926,
#   'ipeenscore': 40,
#   'lat': 25.17592471155,
#   'lng': 121.44365291024,
#   'name': '好滋味蒸餃麵館',
#   'reviewdate': '2015/02/01',
#   'smallstyle': '麵食點心',
#   'status': '正常營業',
#   'tele': '0226209370',
#   'viewcount': 5678},
#  {'Ncomment': 0,
#   '_id': ObjectId('5a17c44780b1101838025253'),
#   'address': 0,
#   'averagecost': 35,
#   'bigstyle': '小吃',
#   'collecount': 1,
#   'id': 1001950,
#   'ipeenscore': 45,
#   'lat': 25.00829005391323,
#   'lng': 121.5116788517461,
#   'name': '彤心威眠胡椒餅',
#   'reviewdate': '2016/01/28',
#   'smallstyle': '胡椒餅',
#   'status': '正常營業',
#   'tele': '0926724319',
#   'viewcount': 2367},
#  {'Ncomment': 5,
#   '_id': ObjectId('5a17c44780b1101838025254'),
#   'address': 0,
#   'averagecost': 100,
#   'bigstyle': '咖啡、簡餐、茶',
#   'collecount': 8,
#   'id': 1001966,
#   'ipeenscore': 45,
#   'lat': 23.506740404170003,
#   'lng': 120.51351610504005,
#   'name': '山門咖啡',
#   'reviewdate': '2015/02/02',
#   'smallstyle': '複合式',
#   'status': '正常營業',
#   'tele': '052111828',
#   'viewcount': 6598},
#  {'Ncomment': 0,
#   '_id': ObjectId('5a17c44780b1101838025255'),
#   'address': '台中市沙鹿區北勢東路352號',
#   'averagecost': 0,
#   'bigstyle': '咖啡、簡餐、茶',
#   'collecount': 0,
#   'id': 1001968,
#   'ipeenscore': 0,
#   'lat': 24.21649551599,
#   'lng': 120.57977000570006,
#   'name': 'KP魔幻藝術咖啡屋',
#   'reviewdate': '2015/02/02',
#   'smallstyle': '複合式',
#   'status': '正常營業',
#   'tele': '0983956026',
#   'viewcount': 941},
#  {'Ncomment': 1,
#   '_id': ObjectId('5a17c44780b1101838025256'),
#   'address': 0,
#   'averagecost': 13,
#   'bigstyle': '冷凍/冷藏包裝食品',
#   'collecount': 0,
#   'id': 1001992,
#   'ipeenscore': 45,
#   'lat': 0,
#   'lng': 0,
#   'name': '德式香腸起司洋芋',
#   'reviewdate': '2015/02/02',
#   'smallstyle': '微波食品',
#   'status': '正常營業',
#   'tele': 0,
#   'viewcount': 2437},
#  {'Ncomment': 2,
#   '_id': ObjectId('5a17c44780b1101838025257'),
#   'address': '桃園市龜山區茶專路175號',
#   'averagecost': 218,
#   'bigstyle': '咖啡、簡餐、茶',
#   'collecount': 6,
#   'id': 1002010,
#   'ipeenscore': 45,
#   'lat': 25.019909210330002,
#   'lng': 121.36559891057001,
#   'name': '家邊咖啡',
#   'reviewdate': '2016/07/20',
#   'smallstyle': '複合式',
#   'status': '正常營業',
#   'tele': '0936960776',
#   'viewcount': 3902},
#  {'Ncomment': 1,
#   '_id': ObjectId('5a17c44780b1101838025258'),
#   'address': '桃園市大園區航站南路9號',
#   'averagecost': 199,
#   'bigstyle': '咖啡、簡餐、茶',
#   'collecount': 5,
#   'id': 1002024,
#   'ipeenscore': 45,
#   'lat': 25.0770120104,
#   'lng': 121.23197600723003,
#   'name': 'gou jia果家鮮果概念店',
#   'reviewdate': '2015/02/02',
#   'smallstyle': '複合式',
#   'status': '正常營業',
#   'tele': 0,
#   'viewcount': 4092},
#  {'Ncomment': 1,
#   '_id': ObjectId('5a17c44780b1101838025259'),
#   'address': '嘉義市東區東義路76號',
#   'averagecost': 0,
#   'bigstyle': '異國料理',
#   'collecount': 0,
#   'id': 1002038,
#   'ipeenscore': 0,
#   'lat': 23.493096302210002,
#   'lng': 120.46851660327992,
#   'name': '水龍牛排',
#   'reviewdate': '2015/02/02',
#   'smallstyle': '法式料理',
#   'status': '正常營業',
#   'tele': '052774557',
#   'viewcount': 3136},
#  {'Ncomment': 0,
#   '_id': ObjectId('5a17c44780b110183802525a'),
#   'address': '台北市中山區民生東路二段115巷24號1樓',
#   'averagecost': 0,
#   'bigstyle': '咖啡、簡餐、茶',
#   'collecount': 1,
#   'id': 1002050,
#   'ipeenscore': 0,
#   'lat': 25.05939860715,
#   'lng': 121.53156621302004,
#   'name': 'Bamboo cafe',
#   'reviewdate': '2015/02/02',
#   'smallstyle': '咖啡專賣',
#   'status': '正常營業',
#   'tele': '0225365512',
#   'viewcount': 507},
#  {'Ncomment': 0,
#   '_id': ObjectId('5a17c44780b110183802525b'),
#   'address': 0,
#   'averagecost': 0,
#   'bigstyle': '冰品、飲料、甜湯',
#   'collecount': 0,
#   'id': 1002060,
#   'ipeenscore': 0,
#   'lat': 22.693620002579998,
#   'lng': 120.54872901892998,
#   'name': '松之露養生飲品',
#   'reviewdate': '2015/02/02',
#   'smallstyle': '甜品、甜湯',
#   'status': '正常營業',
#   'tele': '087624588',
#   'viewcount': 863},
#  {'Ncomment': 1,
#   '_id': ObjectId('5a17c44780b110183802525c'),
#   'address': '高雄市旗山區平和街12號',
#   'averagecost': 83,
#   'bigstyle': '早餐',
#   'collecount': 113,
#   'id': 1002084,
#   'ipeenscore': 40,
#   'lat': 23.908496204019997,
#   'lng': 120.69120981663002,
#   'name': '炭根炭烤吐司俱樂部',
#   'reviewdate': '2015/02/02',
#   'smallstyle': '其他類型早餐',
#   'status': '正常營業',
#   'tele': '076627770',
#   'viewcount': 8184},
#  {'Ncomment': 3,
#   '_id': ObjectId('5a17c44780b110183802525d'),
#   'address': 0,
#   'averagecost': 74,
#   'bigstyle': '中式料理',
#   'collecount': 199,
#   'id': 147791,
#   'ipeenscore': 45,
#   'lat': 22.6659570167,
#   'lng': 120.29919901691,
#   'name': '邵師傅上海湯包',
#   'reviewdate': '2016/01/28',
#   'smallstyle': '麵食點心',
#   'status': '正常營業',
#   'tele': 0,
#   'viewcount': 20933},
#  {'Ncomment': 1,
#   '_id': ObjectId('5a17c44780b110183802525e'),
#   'address': 0,
#   'averagecost': 0,
#   'bigstyle': '網購包裝食品',
#   'collecount': 0,
# ...
#   'name': '台北文華東方酒店-大宴會廳',
#   'reviewdate': '2016/04/05',
#   'smallstyle': '台菜餐廳',
#   'status': '正常營業',
#   'tele': '0227156888',
#   'viewcount': 4742},
#  {'Ncomment': 3,
#   '_id': ObjectId('5a17c44780b110183802559f'),
#   'address': '台中市西屯區中港路二段71號',
#   'averagecost': 376,
#   'bigstyle': '中式料理',
#   'collecount': 13,
#   'id': 1014148,
#   'ipeenscore': 45,
#   'lat': 24.16233981926,
#   'lng': 120.65060111470001,
#   'name': '寶達港式餐廳',
#   'reviewdate': '2015/04/20',
#   'smallstyle': '粵菜 港式飲茶',
#   'status': '正常營業',
#   'tele': 0,
#   'viewcount': 4993},
#  {'Ncomment': 25,
#   '_id': ObjectId('5a17c44780b11018380255a0'),
#   'address': '新北市永和區中正路385號1樓',
#   'averagecost': 243,
#   'bigstyle': '烘焙、甜點、零食',
#   'collecount': 537,
#   'id': 1014154,
#   'ipeenscore': 50,
#   'lat': 25.00387341589,
#   'lng': 121.51718761975,
#   'name': '海是甜的 Honey Ocean',
#   'reviewdate': '2016/09/13',
#   'smallstyle': '西點烘焙、麵包',
#   'status': '正常營業',
#   'tele': '0289236969',
#   'viewcount': 755840},
#  {'Ncomment': 0,
#   '_id': ObjectId('5a17c44780b11018380255a1'),
#   'address': '台中市北區陜西路23號',
#   'averagecost': 0,
#   'bigstyle': '咖啡、簡餐、茶',
#   'collecount': 1,
#   'id': 1014166,
#   'ipeenscore': 0,
#   'lat': 24.167566019080002,
#   'lng': 120.66811601833,
#   'name': 'Homme Bistro',
#   'reviewdate': '2015/05/26',
#   'smallstyle': '複合式',
#   'status': '正常營業',
#   'tele': '0422961599',
#   'viewcount': 2901},
#  {'Ncomment': 4,
#   '_id': ObjectId('5a17c44780b11018380255a2'),
#   'address': '新竹市東區中華路二段736號',
#   'averagecost': 388,
#   'bigstyle': '燒烤類',
#   'collecount': 8,
#   'id': 1014168,
#   'ipeenscore': 45,
#   'lat': 24.79745200483,
#   'lng': 120.96399470041,
#   'name': '東京精緻創意鐵板燒',
#   'reviewdate': '2015/04/20',
#   'smallstyle': '鐵板燒',
#   'status': '正常營業',
#   'tele': '035278969',
#   'viewcount': 11096},
#  {'Ncomment': 0,
#   '_id': ObjectId('5a17c44780b11018380255a3'),
#   'address': '台南市東區前鋒路210號',
#   'averagecost': 0,
#   'bigstyle': '咖啡、簡餐、茶',
#   'collecount': 0,
#   'id': 1014182,
#   'ipeenscore': 0,
#   'lat': 22.99637191118,
#   'lng': 120.21388611257,
#   'name': '佛爾諾窯烤披薩',
#   'reviewdate': '2015/04/20',
#   'smallstyle': '複合式',
#   'status': '正常營業',
#   'tele': '0905121342',
#   'viewcount': 1626},
#  {'Ncomment': 0,
#   '_id': ObjectId('5a17c44780b11018380255a4'),
#   'address': '高雄市楠梓區旗楠路895號',
#   'averagecost': 0,
#   'bigstyle': '咖啡、簡餐、茶',
#   'collecount': 0,
#   'id': 1014196,
#   'ipeenscore': 0,
#   'lat': 22.7422089046,
#   'lng': 120.33877600129999,
#   'name': '總舵口上選復刻連鎖茶飲(旗楠總舵)',
#   'reviewdate': '2015/04/20',
#   'smallstyle': '茶專賣',
#   'status': '正常營業',
#   'tele': '073550739',
#   'viewcount': 1021},
#  {'Ncomment': 5,
#   '_id': ObjectId('5a17c44780b11018380255a5'),
#   'address': '台北市中正區羅斯福路四段68號2樓',
#   'averagecost': 236,
#   'bigstyle': '異國料理',
#   'collecount': 4,
#   'id': 1014204,
#   'ipeenscore': 40,
#   'lat': 25.01461600657,
#   'lng': 121.53423001782,
#   'name': 'Saizeriya薩莉亞義大利料理(公館店)',
#   'reviewdate': '2016/03/27',
#   'smallstyle': '義式料理',
#   'status': '正常營業',
#   'tele': '0223683277',
#   'viewcount': 23551},
#  {'Ncomment': 0,
#   '_id': ObjectId('5a17c44780b11018380255a6'),
#   'address': '台南市安平區文平路347號',
#   'averagecost': 0,
#   'bigstyle': '咖啡、簡餐、茶',
#   'collecount': 0,
#   'id': 1014206,
#   'ipeenscore': 0,
#   'lat': 22.99180411727,
#   'lng': 120.1784409194,
#   'name': '优客咖啡館 U.can Cafe',
#   'reviewdate': '2016/04/05',
#   'smallstyle': '複合式',
#   'status': '正常營業',
#   'tele': '062980596',
#   'viewcount': 1156},
#  {'Ncomment': 2,
#   '_id': ObjectId('5a17c44780b11018380255a7'),
#   'address': '台北市中正區汀州路二段200號',
#   'averagecost': 40,
#   'bigstyle': '咖啡、簡餐、茶',
#   'collecount': 5,
#   'id': 101421,
#   'ipeenscore': 0,
#   'lat': 25.02267101319,
#   'lng': 121.5233750112,
#   'name': '樂餅屋',
#   'reviewdate': '2016/03/27',
#   'smallstyle': '複合式',
#   'status': '正常營業',
#   'tele': '0223682138',
#   'viewcount': 5894},
#  {'Ncomment': 1,
#   '_id': ObjectId('5a17c44780b11018380255a8'),
#   'address': '台中市西區民權路229巷20號',
#   'averagecost': 80,
#   'bigstyle': '中式料理',
#   'collecount': 4,
#   'id': 1014210,
#   'ipeenscore': 45,
#   'lat': 24.14918471683,
#   'lng': 120.66848620081001,
#   'name': '大和宅',
#   'reviewdate': '2015/05/16',
#   'smallstyle': '麵食點心',
#   'status': '正常營業',
#   'tele': '0423058958',
#   'viewcount': 5340},
#  {'Ncomment': 0,
#   '_id': ObjectId('5a17c44780b11018380255a9'),
#   'address': '台南市永康區永康區中山路99號',
#   'averagecost': 0,
#   'bigstyle': '咖啡、簡餐、茶',
#   'collecount': 1,
#   'id': 1014214,
#   'ipeenscore': 0,
#   'lat': 23.01910841819,
#   'lng': 120.23218150174,
#   'name': 'HAMI dessert studio',
#   'reviewdate': '2015/04/20',
#   'smallstyle': '茶專賣',
#   'status': '正常營業',
#   'tele': '062329553',
#   'viewcount': 820},
#  {'Ncomment': 0,
#   '_id': ObjectId('5a17c44780b11018380255aa'),
#   'address': '高雄市左營區南屏路205號',
#   'averagecost': 0,
#   'bigstyle': '日式料理',
#   'collecount': 2,
#   'id': 1014218,
#   'ipeenscore': 0,
#   'lat': 22.67048700298,
#   'lng': 120.29712001302,
#   'name': '日僑壽司',
#   'reviewdate': '2015/04/20',
#   'smallstyle': '生魚片、壽司專賣',
#   'status': '正常營業',
#   'tele': '075528822',
#   'viewcount': 3758},
#  {'Ncomment': 0,
#   '_id': ObjectId('5a17c44780b11018380255ab'),
#   'address': '台中市南屯區東興路二段71號',
#   'averagecost': 0,
#   'bigstyle': '冰品、飲料、甜湯',
#   'collecount': 0,
#   'id': 1014228,
#   'ipeenscore': 0,
#   'lat': 24.13834700601,
#   'lng': 120.65276601485,
#   'name': '北方村',
#   'reviewdate': '2015/04/20',
#   'smallstyle': '剉冰、豆花',
#   'status': '正常營業',
#   'tele': '0424710008',
#   'viewcount': 604},
#  {'Ncomment': 0,
#   '_id': ObjectId('5a17c44780b11018380255ac'),
#   'address': '台中市豐原區三民路101號',
#   'averagecost': 0,
#   'bigstyle': '速食料理',
#   'collecount': 0,
#   'id': 1014238,
#   'ipeenscore': 0,
#   'lat': 24.253310008699998,
#   'lng': 120.71966801327,
#   'name': '聖寶羅專業炸食館',
#   'reviewdate': '2015/04/20',
#   'smallstyle': '漢堡、炸雞',
#   'status': '正常營業',
#   'tele': 0,
#   'viewcount': 1538},
#  {'Ncomment': 1,
#   '_id': ObjectId('5a17c44780b11018380255ad'),
#   'address': '高雄市楠梓區藍昌路398-15號',
#   'averagecost': 65,
#   'bigstyle': '日式料理',
#   'collecount': 1,
#   'id': 1014244,
#   'ipeenscore': 45,
#   'lat': 22.72525901694,
#   'lng': 120.29244500306,
#   'name': '蓋飯先生',
#   'reviewdate': '2015/04/20',
#   'smallstyle': '日式豬排專賣',
#   'status': '正常營業',
#   'tele': '075913223',
#   'viewcount': 8776},
#  {'Ncomment': 1,
#   '_id': ObjectId('5a17c44780b11018380255ae'),
#   'address': '嘉義市西區嘉義市西區西榮街91-1號',
#   'averagecost': 50,
#   'bigstyle': '小吃',
#   'collecount': 3,
#   'id': 1014258,
#   'ipeenscore': 0,
#   'lat': 23.47626330551,
#   'lng': 120.44544291303,
#   'name': '正老牌草魚粥',
#   'reviewdate': '2015/06/06',
#   'smallstyle': '其他小吃',
#   'status': '正常營業',
#   'tele': '052282326',
#   'viewcount': 4605},
#  {'Ncomment': 1,
#   '_id': ObjectId('5a17c44780b11018380255af'),
#   'address': 0,
#   'averagecost': 0,
#   'bigstyle': '中式料理',
#   'collecount': 8,
#   'id': 1014314,
#   'ipeenscore': 0,
#   'lat': 24.70168021472,
#   'lng': 121.75646850611,
#   'name': '西河灣熱炒',
#   'reviewdate': '2015/04/21',
#   'smallstyle': '熱炒、快炒',
#   'status': '正常營業',
#   'tele': '039658285',
#   'viewcount': 3725},
#  {'Ncomment': 0,
#   '_id': ObjectId('5a17c44780b11018380255b0'),
#   'address': '桃園市中壢區中華路一段619巷11號',
#   'averagecost': 0,
#   'bigstyle': '中式料理',
#   'collecount': 0,
#   'id': 1014320,
#   'ipeenscore': 0,
#   'lat': 24.969038911160002,
#   'lng': 121.25101100963,
#   'name': '素蔬美食',
#   'reviewdate': '2015/04/21',
#   'smallstyle': '其它中式料理',
#   'status': '正常營業',
#   'tele': '0926834671',
#   'viewcount': 749},
#  {'Ncomment': 0,
#   '_id': ObjectId('5a17c44780b11018380255b1'),
#   'address': '高雄市三民區正忠路380號',
#   'averagecost': 0,
#   'bigstyle': '早餐',
#   'collecount': 0,
#   'id': 1014330,
#   'ipeenscore': 0,
#   'lat': 22.64874461505,
#   'lng': 120.33018441978999,
#   'name': 'Hsin王子 早午餐',
#   'reviewdate': '2015/04/21',
#   'smallstyle': '西式早餐',
#   'status': '正常營業',
#   'tele': 0,
#   'viewcount': 1592},
#  {'Ncomment': 1,
#   '_id': ObjectId('5a17c44780b11018380255b2'),
#   'address': '台南市東區前峰路122號',
#   'averagecost': 30,
#   'bigstyle': '中式料理',
#   'collecount': 5,
#   'id': 1014344,
#   'ipeenscore': 40,
#   'lat': 22.99503301903,
#   'lng': 120.21340541348,
#   'name': '衝記蔥油餅',
#   'reviewdate': '2015/04/21',
#   'smallstyle': '麵食點心',
#   'status': '正常營業',
#   'tele': 0,
#   'viewcount': 6239},
#  {'Ncomment': 13,
#   '_id': ObjectId('5a17c44780b11018380255b3'),
#   'address': '新竹縣竹北市光明一路106號2樓',
#   'averagecost': 430,
#   'bigstyle': '素食',
#   'collecount': 27,
#   'id': 101436,
#   'ipeenscore': 45,
#   'lat': 24.829997000859997,
#   'lng': 121.01779700779001,
#   'name': '舒果新米蘭蔬食(竹北光明店)',
#   'reviewdate': '2012/02/22',
#   'smallstyle': '中式',
#   'status': '正常營業',
#   'tele': '036571611',
#   'viewcount': 82063},
#  {'Ncomment': 0,
#   '_id': ObjectId('5a17c44780b11018380255b4'),
#   'address': '高雄市三民區明哲路33-2號',
#   'averagecost': 0,
#   'bigstyle': '異國料理',
#   'collecount': 0,
#   'id': 1014384,
#   'ipeenscore': 0,
#   'lat': 22.66135680945,
#   'lng': 120.31266300252,
#   'name': '米樂屋',
#   'reviewdate': '2015/04/21',
#   'smallstyle': '其他異國料理',
#   'status': '正常營業',
#   'tele': '073411711',
#   'viewcount': 4185},
#  {'Ncomment': 14,
#   '_id': ObjectId('5a17c44780b11018380255b5'),
#   'address': '宜蘭縣宜蘭市環市東路二段786號',
#   'averagecost': 512,
#   'bigstyle': '其他美食',
#   'collecount': 6,
#   'id': 1014386,
#   'ipeenscore': 40,
#   'lat': 24.756339610090002,
#   'lng': 121.77126351969001,
#   'name': '久賀牛排',
#   'reviewdate': '2015/04/21',
#   'smallstyle': '其他美食',
#   'status': '正常營業',
#   'tele': '039386262',
#   'viewcount': 14834},
#  {'Ncomment': 2,
#   '_id': ObjectId('5a17c44780b11018380255b6'),
#   'address': '高雄市鼓山區篤敬路35號',
#   'averagecost': 150,
#   'bigstyle': '早餐',
#   'collecount': 14,
#   'id': 1014390,
#   'ipeenscore': 40,
#   'lat': 22.664274017049998,
#   'lng': 120.30224731945,
#   'name': '好時光Brunch早午餐',
#   'reviewdate': '2015/04/21',
#   'smallstyle': '西式早餐',
#   'status': '正常營業',
#   'tele': '075500352',
#   'viewcount': 5527},
#  {'Ncomment': 3,
#   '_id': ObjectId('5a17c44780b11018380255b7'),
#   'address': '台北市士林區基河路106號',
#   'averagecost': 49,
#   'bigstyle': '冰品、飲料、甜湯',
#   'collecount': 9,
#   'id': 107625,
#   'ipeenscore': 45,
#   'lat': 25.08813201805,
#   'lng': 121.52350501015,
#   'name': '冰BAR',
#   'reviewdate': '2011/09/26',
#   'smallstyle': '剉冰、豆花',
#   'status': '正常營業',
#   'tele': 0,
#   'viewcount': 11645},
#  {'Ncomment': 1,
#   '_id': ObjectId('5a17c44780b11018380255b8'),
#   'address': '高雄市楠梓區新路190巷57號',
#   'averagecost': 70,
#   'bigstyle': '中式料理',
#   'collecount': 0,
#   'id': 1014404,
#   'ipeenscore': 40,
#   'lat': 22.72639281736,
#   'lng': 120.32691130314001,
#   'name': '榮星宮保雞丁飯',
#   'reviewdate': '2015/04/21',
#   'smallstyle': '其它中式料理',
#   'status': '正常營業',
#   'tele': '073559207',
#   'viewcount': 4711},
#  {'Ncomment': 18,
#   '_id': ObjectId('5a17c44780b11018380255b9'),
#   'address': 0,
#   'averagecost': 250,
#   'bigstyle': '常溫包裝食品',
#   'collecount': 1,
#   'id': 1014412,
#   'ipeenscore': 45,
#   'lat': 0,
#   'lng': 0,
#   'name': '劉媽媽手工坊',
#   'reviewdate': '2015/11/10',
#   'smallstyle': '餅乾、零食',
#   'status': '正常營業',
#   'tele': '0423785511',
#   'viewcount': 12593},
#  {'Ncomment': 1,
#   '_id': ObjectId('5a17c44780b11018380255ba'),
#   'address': '台中市西屯區中平路12號',
#   'averagecost': 200,
#   'bigstyle': '燒烤類',
#   'collecount': 5,
#   'id': 1014438,
#   'ipeenscore': 0,
#   'lat': 24.176330201,
#   'lng': 120.65984470074,
#   'name': '青蚵嫂布袋烤鮮蚵',
#   'reviewdate': '2015/04/22',
#   'smallstyle': '炭烤串燒',
#   'status': '正常營業',
#   'tele': '0935685268',
#   'viewcount': 4931},
#  {'Ncomment': 15,
#   '_id': ObjectId('5a17c44780b11018380255bb'),
#   'address': '台北市信義區光復南路200巷11號',
#   'averagecost': 63,
#   'bigstyle': '咖啡、簡餐、茶',
#   'collecount': 21,
#   'id': 1014440,
#   'ipeenscore': 45,
#   'lat': 25.041891311009998,
#   'lng': 121.55564820279999,
#   'name': '#LATTICE 拉堤斯比利時列日鬆餅(台北光復店)',
#   'reviewdate': '2016/04/05',
#   'smallstyle': '複合式',
#   'status': '正常營業',
#   'tele': '0227753660',
#   'viewcount': 951958},
#  {'Ncomment': 2,
#   '_id': ObjectId('5a17c44780b11018380255bc'),
#   'address': '台北市信義區永吉路30巷101弄10號',
#   'averagecost': 75,
#   'bigstyle': '冰品、飲料、甜湯',
#   'collecount': 1,
#   'id': 1079444,
#   'ipeenscore': 45,
#   'lat': 25.04342990596,
#   'lng': 121.56926200462,
#   'name': '駱師傅法式冰淇淋之家',
#   'reviewdate': '2016/07/19',
#   'smallstyle': '冰淇淋',
#   'status': '正常營業',
#   'tele': '0227660108',
#   'viewcount': 2235},
#  {'Ncomment': 2,
#   '_id': ObjectId('5a17c44780b11018380255bd'),
#   'address': 0,
#   'averagecost': 75,
#   'bigstyle': '網購包裝食品',
#   'collecount': 1,
#   'id': 101445,
#   'ipeenscore': 45,
#   'lat': 0,
#   'lng': 0,
#   'name': '阿Q包子',
#   'reviewdate': '2011/07/21',
#   'smallstyle': '其他網購包裝食品',
#   'status': '正常營業',
#   'tele': 0,
#   'viewcount': 10896},
#  {'Ncomment': 1,
#   '_id': ObjectId('5a17c44780b11018380255be'),
#   'address': 0,
#   'averagecost': 0,
#   'bigstyle': '網購包裝食品',
#   'collecount': 0,
#   'id': 101446,
#   'ipeenscore': 40,
#   'lat': 0,
#   'lng': 0,
#   'name': '帕瑪森乳酪蛋糕(原味/巧克力)',
#   'reviewdate': '2011/07/21',
#   'smallstyle': '甜點、蛋糕',
#   'status': '正常營業',
#   'tele': '0225215959',
#   'viewcount': 3863},
#  {'Ncomment': 0,
#   '_id': ObjectId('5a17c44780b11018380255bf'),
#   'address': '台北市松山區南京東路五段123巷8弄2號',
#   'averagecost': 0,
#   'bigstyle': '咖啡、簡餐、茶',
#   'collecount': 1,
#   'id': 1014472,
#   'ipeenscore': 0,
#   'lat': 25.053410502139997,
#   'lng': 121.56095131102,
#   'name': 'PK Caffè',
#   'reviewdate': '2016/04/05',
#   'smallstyle': '複合式',
#   'status': '正常營業',
#   'tele': '0227609838',
#   'viewcount': 623},
#  {'Ncomment': 1,
#   '_id': ObjectId('5a17c44780b11018380255c0'),
#   'address': '高雄市前鎮區鎮榮街7號',
#   'averagecost': 46,
#   'bigstyle': '早餐',
#   'collecount': 3,
#   'id': 1014474,
#   'ipeenscore': 40,
#   'lat': 22.59117110174,
#   'lng': 120.31253071763,
#   'name': '康好早點豆漿',
#   'reviewdate': '2015/04/22',
#   'smallstyle': '中式早餐',
#   'status': '正常營業',
#   'tele': 0,
#   'viewcount': 4657},
#  {'Ncomment': 3,
#   '_id': ObjectId('5a17c44780b11018380255c1'),
#   'address': '台南市東區大同路1段111號',
#   'averagecost': 120,
#   'bigstyle': '中式料理',
#   'collecount': 3,
#   'id': 1014476,
#   'ipeenscore': 45,
#   'lat': 22.98616521383,
#   'lng': 120.21132471581001,
#   'name': 'NoddleMix禮面作(BINGO館大同店)',
#   'reviewdate': '2015/04/22',
#   'smallstyle': '其它中式料理',
#   'status': '正常營業',
#   'tele': 0,
#   'viewcount': 4568},
#  {'Ncomment': 22,
#   '_id': ObjectId('5a17c44780b11018380255c2'),
#   'address': '台中市北區五常街45號',
#   'averagecost': 115,
#   'bigstyle': '早餐',
#   'collecount': 20,
#   'id': 1014496,
#   'ipeenscore': 45,
#   'lat': 24.15377690198,
#   'lng': 120.68069300424,
#   'name': 'Sunny Bagel 太陽貝果',
#   'reviewdate': '2015/12/21',
#   'smallstyle': '西式早餐',
#   'status': '正常營業',
#   'tele': '0905599733',
#   'viewcount': 5152838},
#  {'Ncomment': 4,
#   '_id': ObjectId('5a17c44780b11018380255c3'),
#   'address': '台北市萬華區德昌街2號',
#   'averagecost': 101,
#   'bigstyle': '早餐',
#   'collecount': 28,
#   'id': 1014500,
#   'ipeenscore': 40,
#   'lat': 25.02547691979,
#   'lng': 121.50002050788001,
#   'name': '單眼皮双眼皮早餐輕食',
#   'reviewdate': '2016/04/03',
#   'smallstyle': '西式早餐',
#   'status': '正常營業',
#   'tele': '0223079296',
#   'viewcount': 9115},
#  {'Ncomment': 0,
#   '_id': ObjectId('5a17c44780b11018380255c4'),
#   'address': 0,
#   'averagecost': 0,
#   'bigstyle': '烘焙、甜點、零食',
#   'collecount': 1,
#   'id': 1014516,
#   'ipeenscore': 0,
#   'lat': 25.03653500102,
#   'lng': 121.57487600772001,
#   'name': '麥味登&REAL 臻烘培坊(北市松德店)',
#   'reviewdate': '2016/04/05',
#   'smallstyle': '西點烘焙、麵包',
#   'status': '正常營業',
#   'tele': '0277294270',
#   'viewcount': 1457},
#  {'Ncomment': 3,
#   '_id': ObjectId('5a17c44780b11018380255c5'),
#   'address': '台北市松山區健康路15巷13號',
#   'averagecost': 90,
#   'bigstyle': '烘焙、甜點、零食',
#   'collecount': 1,
#   'id': 1014520,
#   'ipeenscore': 40,
#   'lat': 25.05348301695,
#   'lng': 121.55321800737,
#   'name': '麥味登&REAL 臻烘培坊(北市健康店)',
#   'reviewdate': '2016/04/05',
#   'smallstyle': '西點烘焙、麵包',
#   'status': '正常營業',
#   'tele': '0225148117',
#   'viewcount': 5695},
#  {'Ncomment': 1,
#   '_id': ObjectId('5a17c44780b11018380255c6'),
#   'address': 0,
#   'averagecost': 0,
#   'bigstyle': '速食料理',
#   'collecount': 3,
#   'id': 1014532,
#   'ipeenscore': 35,
#   'lat': 23.98782931346,
#   'lng': 121.5860166059,
#   'name': '阿米哥手工薄皮披薩Amigo Pizza',
#   'reviewdate': '2015/04/22',
#   'smallstyle': '披薩',
#   'status': '正常營業',
#   'tele': '038565722',
#   'viewcount': 6020},
#  {'Ncomment': 13,
#   '_id': ObjectId('5a17c44780b11018380255c7'),
#   'address': '新北市新莊區五工路66號2樓',
#   'averagecost': 319,
#   'bigstyle': '中式料理',
#   'collecount': 93,
#   'id': 1014540,
#   'ipeenscore': 45,
#   'lat': 25.063465004570002,
#   'lng': 121.45816090951999,
#   'name': '餡老滿(晶冠店)',
#   'reviewdate': '2015/12/22',
#   'smallstyle': '北京菜',
#   'status': '正常營業',
#   'tele': '0285212059',
#   'viewcount': 4811269},
#  ...]
