# %%
import requests
res=requests.get("https://sip.einvoice.nat.gov.tw/ods-main/ODS308E/download/691C0280-CEFB-488F-9E71-6AA4F39A41CD/1/48544764-8D2F-4A71-B9E1-4C16AA5B2797/0/?fileType=csv")
if res.status_code==200:
    csv=res.text.replace("\ufeff","").replace("\r","").replace("\u3000","")
    res.close()
    with open("../data/invoice1.csv","w") as f:
        f.write(csv)

# %%
import csv
with open("../data/invoice1.csv") as f:
    invoicedata=list(csv.DictReader(f))

# %%
invoicedata[5:8]
# Out:
# [OrderedDict([('年度', '2017'),
#               ('縣市', '臺北市'),
#               ('縣市代碼', 'A'),
#               ('鄉鎮市區', '松山區'),
#               ('鄉鎮市區代碼', '01'),
#               ('主行業別', '零售業'),
#               ('主行業別代碼', '47'),
#               ('外來生活圈', '留在生活圈'),
#               ('客源區域維度', '鄉鎮市區'),
#               ('客源縣市', '臺北市'),
#               ('客源縣市代碼', 'A'),
#               ('客源鄉鎮市區', '大同區'),
#               ('客源鄉鎮市區代碼', '09'),
#               ('消費金額', '24478'),
#               ('載具人次', '6619')]),
#  OrderedDict([('年度', '2017'),
#               ('縣市', '臺北市'),
#               ('縣市代碼', 'A'),
#               ('鄉鎮市區', '松山區'),
#               ('鄉鎮市區代碼', '01'),
#               ('主行業別', '零售業'),
#               ('主行業別代碼', '47'),
#               ('外來生活圈', '留在生活圈'),
#               ('客源區域維度', '鄉鎮市區'),
#               ('客源縣市', '臺北市'),
#               ('客源縣市代碼', 'A'),
#               ('客源鄉鎮市區', '中山區'),
#               ('客源鄉鎮市區代碼', '10'),
#               ('消費金額', '165401'),
# ...

# %%
comsumption={}
for area in invoicedata:
    area['鄉鎮市區']=area['鄉鎮市區'].replace("\u3000","")
    if area['縣市']+area['鄉鎮市區'] not in comsumption:
        comsumption[area['縣市']+area['鄉鎮市區']]={}
        comsumption[area['縣市']+area['鄉鎮市區']]['消費金額']=0
        comsumption[area['縣市']+area['鄉鎮市區']]['載具人次']=0
    comsumption[area['縣市']+area['鄉鎮市區']]['消費金額']+=int(area['消費金額'])
    comsumption[area['縣市']+area['鄉鎮市區']]['載具人次']+=int(area['載具人次'])

# %%
comsumptionData=[{"地區":area,"總消費":comsumption[area]['消費金額'],
                  "消費人數":comsumption[area]['載具人次'],
                  "人均消":int(comsumption[area]['消費金額']/comsumption[area]['載具人次'])}
                 for area in comsumption if len(area)>3]

# %%
comsumptionData[0]
# Out:
# {'人均消': 4, '地區': '臺北市松山區', '消費人數': 3690930, '總消費': 17102403}

# %%
len(comsumptionData)
# Out:
# 347

# %%
import googlemaps
import json
gmaps = googlemaps.Client(key='AIzaSyAF9GKxqgmgDEW_h7M4TtM5CbkK03xnS0E')

for area in comsumptionData:
    geocode_result = gmaps.geocode(area['地區'])
    area["lat"]=geocode_result[0]['geometry']['location']['lat']
    area["lng"]=geocode_result[0]['geometry']['location']['lng']
    print(area['地區']+"完成")
# Out:
# 臺北市松山區完成
# 雲林縣四湖鄉完成
# 雲林縣口湖鄉完成
# 雲林縣水林鄉完成
# 嘉義縣朴子市完成
# 嘉義縣布袋鎮完成
# 嘉義縣大林鎮完成
# 嘉義縣民雄鄉完成
# 嘉義縣溪口鄉完成
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# D:\anaconda\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379             try:  # Python 2.7, use buffering of HTTP responses
# --> 380                 httplib_response = conn.getresponse(buffering=True)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-0f6ba2cf4af7> in <module>()
#       4
#       5 for area in comsumptionData:
# ...

# %%
comsumptionData[0]

# %%
import gc
gc.collect()

# %%
import json
with open("../data/comsumptionData.json","w",encoding="utf8") as f:
    json.dump(comsumptionData,f)

# %%
import json
with open("../data/comsumptionData.json","r",encoding="utf8") as f:
    comsumptionData1=json.load(f)

# %%
areaDict={area['地區']:(area['lat'],area['lng']) for area in comsumptionData1}
areaDict
# Out:
# {'南投縣': (23.9609981, 120.9718638),
#  '南投縣中寮鄉': (23.9058666, 120.7809676),
#  '南投縣仁愛鄉': (24.0213745, 121.1252135),
#  '南投縣信義鄉': (23.6679756, 120.9876321),
#  '南投縣南投市': (23.9179637, 120.6775054),
#  '南投縣名間鄉': (23.8537843, 120.6775054),
#  '南投縣國姓鄉': (23.980824, 120.876645),
#  '南投縣埔里鎮': (23.9932872, 120.9646866),
#  '南投縣水里鄉': (23.7919524, 120.8613785),
#  '南投縣竹山鎮': (23.712201, 120.6890055),
#  '南投縣草屯鎮': (23.9933816, 120.7234992),
#  '南投縣集集鎮': (23.8279876, 120.7925043),
#  '南投縣魚池鄉': (23.8753852, 120.9187827),
#  '南投縣鹿谷鄉': (23.7348372, 120.7809676),
#  '嘉義市': (23.4800751, 120.4491113),
#  '嘉義市東區': (23.4853348, 120.4760853),
#  '嘉義市西區': (23.4803964, 120.4242401),
#  '嘉義縣': (23.4518428, 120.2554615),
#  '嘉義縣中埔鄉': (23.3995944, 120.5509358),
#  '嘉義縣六腳鄉': (23.5149489, 120.2628111),
#  '嘉義縣大埔鄉': (23.3040182, 120.5969758),
#  '嘉義縣大林鎮': (23.6040709, 120.4542004),
#  '嘉義縣太保市': (23.4964492, 120.3837086),
#  '嘉義縣布袋鎮': (23.3733555, 120.1868038),
#  '嘉義縣新港鄉': (23.538123, 120.3550808),
# ...

# %%
len(areaDict)
# Out:
# 369

# %%
import requests
res=requests.get("https://sip.einvoice.nat.gov.tw/ods-main/ODS308E/download/3886F055-EB77-4DF9-98E2-F3F49A7D3434/1/E265F67E-6CDA-4FB2-B4E9-ACF40ECA3476/0/?fileType=csv")
if res.status_code==200:
    csv=res.text.replace("\ufeff","").replace("\r","").replace("\u3000","")
    res.close()
    with open("../data/invoice2.csv","w") as f:
        f.write(csv)

# %%
import csv
with open("../data/invoice2.csv") as f:
    invoicedata=list(csv.DictReader(f))

# %%
len(invoicedata)
# Out:
# 31758

# %%
invoicedata=[dict(area) for area in invoicedata if area['發票年月']=="2017-09-01" and area['行業名稱']=='餐飲業']
len(invoicedata)
# Out:
# 179

# %%
for area in invoicedata:
    area['平均客單價']=int(area['平均客單價'])
    area['開立張數']=int(area['平均開立張數'])
    area['總消費']=int(area['平均開立金額'])
    area['area']=area['縣市名稱']+area['鄉鎮市區名稱']
    area['lat']=areaDict[area['area']][0]
    area['lng']=areaDict[area['area']][1]
    del area['發票年月']
    del area['縣市代碼']
    del area['縣市名稱']
    del area['鄉鎮市區代碼']
    del area['鄉鎮市區名稱']
    del area['行業名稱']
    del area['平均開立張數']
    del area['平均開立金額']

# %%
invoicedata[0]
# Out:
# {'area': '臺北市松山區',
#  'lat': 25.0541591,
#  'lng': 121.5638621,
#  '平均客單價': 237,
#  '總消費': 1122504,
#  '開立張數': 4729}

# %%
import json
with open("../data/comsumptionData2.json","w",encoding="utf8") as f:
    json.dump(invoicedata,f)

# %%
invoicedata[0]
# Out:
# {'area': '臺北市松山區',
#  'lat': 25.0541591,
#  'lng': 121.5638621,
#  '平均客單價': 237,
#  '總消費': 1122504,
#  '開立張數': 4729}

# %%
invoiceDict={area['area']:area['總消費'] for area in invoicedata}
invoiceDict
# Out:
# {'南投縣南投市': 847346,
#  '南投縣埔里鎮': 1131299,
#  '南投縣竹山鎮': 752971,
#  '南投縣草屯鎮': 926806,
#  '南投縣魚池鄉': 611736,
#  '嘉義市東區': 856956,
#  '嘉義市西區': 2067941,
#  '嘉義縣中埔鄉': 642559,
#  '嘉義縣太保市': 1263848,
#  '嘉義縣布袋鎮': 316431,
#  '嘉義縣朴子市': 634527,
#  '嘉義縣民雄鄉': 748870,
#  '嘉義縣水上鄉': 524978,
#  '嘉義縣竹崎鄉': 513706,
#  '基隆市中正區': 1727520,
#  '基隆市仁愛區': 1334972,
#  '基隆市信義區': 900320,
#  '基隆市安樂區': 1571349,
#  '宜蘭縣五結鄉': 1237359,
#  '宜蘭縣宜蘭市': 1427761,
#  '宜蘭縣礁溪鄉': 2406684,
#  '宜蘭縣羅東鎮': 1001420,
#  '屏東縣內埔鄉': 392147,
#  '屏東縣屏東市': 1088158,
#  '屏東縣恆春鎮': 1340976,
#  '屏東縣東港鎮': 782630,
#  '屏東縣潮州鎮': 1148383,
#  '屏東縣萬丹鄉': 561776,
#  '彰化縣二林鎮': 801444,
#  '彰化縣伸港鄉': 386215,
#  '彰化縣北斗鎮': 949997,
#  '彰化縣和美鎮': 1140961,
#  '彰化縣員林市': 1083870,
#  '彰化縣埔心鄉': 1400282,
#  '彰化縣大村鄉': 546049,
#  '彰化縣彰化市': 1171638,
#  '彰化縣溪湖鎮': 993749,
#  '彰化縣田中鎮': 897076,
#  '彰化縣社頭鄉': 505952,
#  '彰化縣福興鄉': 551453,
#  '彰化縣花壇鄉': 1074161,
#  '彰化縣鹿港鎮': 895945,
#  '新北市三峽區': 1593583,
#  '新北市三重區': 1492630,
#  '新北市中和區': 1073617,
#  '新北市五股區': 1325067,
# ...

# %%
import requests
res=requests.get("https://quality.data.gov.tw/dq_download_json.php?nid=8410&md5_url=4bda00c25490e8c83a23913e30e0dc3d")

# %%
import json
x=res.json()

# %%
humanDensity=x[1:-7]

# %%
for area in humanDensity:
    area["population_density"]=int(area["population_density"])
    try:
        area["lat"]=areaDict[area['site_id']][0]
        area["lng"]=areaDict[area['site_id']][1]
    except:
        pass

# %%
humanDensity=[area for area in humanDensity if "lat" in area]

# %%
with open("../data/humanDensity.json","w") as f:
    json.dump(humanDensity,f)

# %%
with open("../data/humanDensity.json") as f:
    humanDensity=json.load(f)
humanDensity[0]
# Out:
# {'area': '23.1373',
#  'lat': 25.0114095,
#  'lng': 121.4618415,
#  'people_total': '552285',
#  'population_density': 23870,
#  'site_id': '新北市板橋區',
#  'statistic_yyy': '105'}

# %%
humanDensityDict={area['site_id']:area['population_density'] for area in humanDensity}
humanDensityDict
# Out:
# {'南投縣中寮鄉': 103,
#  '南投縣仁愛鄉': 12,
#  '南投縣信義鄉': 12,
#  '南投縣南投市': 1410,
#  '南投縣名間鄉': 472,
#  '南投縣國姓鄉': 109,
#  '南投縣埔里鎮': 503,
#  '南投縣水里鄉': 169,
#  '南投縣竹山鎮': 224,
#  '南投縣草屯鎮': 946,
#  '南投縣集集鎮': 222,
#  '南投縣魚池鄉': 133,
#  '南投縣鹿谷鄉': 127,
#  '嘉義市東區': 4061,
#  '嘉義市西區': 4935,
#  '嘉義縣中埔鄉': 351,
#  '嘉義縣六腳鄉': 382,
#  '嘉義縣大埔鄉': 27,
#  '嘉義縣大林鎮': 489,
#  '嘉義縣太保市': 561,
#  '嘉義縣布袋鎮': 446,
#  '嘉義縣新港鄉': 490,
#  '嘉義縣朴子市': 859,
#  '嘉義縣東石鄉': 310,
#  '嘉義縣梅山鄉': 165,
#  '嘉義縣民雄鄉': 840,
#  '嘉義縣水上鄉': 725,
#  '嘉義縣溪口鄉': 452,
#  '嘉義縣番路鄉': 100,
#  '嘉義縣竹崎鄉': 223,
#  '嘉義縣義竹鄉': 237,
#  '嘉義縣阿里山鄉': 13,
#  '嘉義縣鹿草鄉': 291,
#  '基隆市七堵區': 962,
#  '基隆市中山區': 4572,
#  '基隆市中正區': 5148,
#  '基隆市仁愛區': 10634,
#  '基隆市信義區': 4861,
#  '基隆市安樂區': 4550,
#  '基隆市暖暖區': 1682,
#  '宜蘭縣三星鄉': 149,
#  '宜蘭縣五結鄉': 1020,
#  '宜蘭縣冬山鄉': 668,
#  '宜蘭縣南澳鄉': 8,
#  '宜蘭縣員山鄉': 289,
#  '宜蘭縣壯圍鄉': 630,
#  '宜蘭縣大同鄉': 9,
#  '宜蘭縣宜蘭市': 3261,
#  '宜蘭縣礁溪鄉': 354,
#  '宜蘭縣羅東鎮': 6389,
#  '宜蘭縣蘇澳鎮': 455,
#  '宜蘭縣頭城鎮': 294,
#  '屏東縣三地門鄉': 39,
#  '屏東縣九如鄉': 526,
#  '屏東縣佳冬鄉': 635,
# ...

# %%
cityData={"臺北市" : {"中正區":"100","大同區":"103","中山區":"104","松山區":"105","大安區":"106","萬華區":"108","信義區":"110","士林區":"111","北投區":"112","內湖區":"114","南港區":"115","文山區":"116"},
"新北市" : {"萬里區":"207","金山區":"208","板橋區":"220","汐止區":"221","深坑區":"222","石碇區":"223","瑞芳區":"224","平溪區":"226","雙溪區":"227","貢寮區":"228","新店區":"231","坪林區":"232","烏來區":"233","永和區":"234","中和區":"235","土城區":"236","三峽區":"237","樹林區":"238","鶯歌區":"239","三重區":"241","新莊區":"242","泰山區":"243","林口區":"244","蘆洲區":"247","五股區":"248","八里區":"249","淡水區":"251","三芝區":"252","石門區":"253"},
"基隆市" : {"仁愛區":"200","信義區":"201","中正區":"202","中山區":"203","安樂區":"204","暖暖區":"205","七堵區":"206"},
"宜蘭縣" : {"宜蘭市":"260","頭城鎮":"261","礁溪鄉":"262","壯圍鄉":"263","員山鄉":"264","羅東鎮":"265","三星鄉":"266","大同鄉":"267","五結鄉":"268","冬山鄉":"269","蘇澳鎮":"270","南澳鄉":"272"},
"新竹市" : {"東區":"300", "北區":"300", "香山區":"300"},
"新竹縣": {"湖口鄉":"303","新豐鄉":"304","新埔鎮":"305","關西鎮":"306","芎林鄉":"307","寶山鄉":"308","竹東鎮":"310","五峰鄉":"311","橫山鄉":"312","尖石鄉":"313","北埔鄉":"314","峨眉鄉":"315"},
"桃園市" : {"中壢區":"320","平鎮區":"324","龍潭區":"325","楊梅區":"326","新屋區":"327","觀音區":"328","桃園區":"330","龜山區":"333","八德區":"334","大溪區":"335","復興區":"336","大園區":"337","蘆竹區":"338"},
"苗栗縣": {"竹南鎮":"350","頭份鎮":"351","三灣鄉":"352","南庄鄉":"353","獅潭鄉":"354","後龍鎮":"356","通霄鎮":"357","苑裡鎮":"358","苗栗市":"360","造橋鄉":"361","頭屋鄉":"362","公館鄉":"363","大湖鄉":"364","泰安鄉":"365","銅鑼鄉":"366","三義鄉":"367","西湖鄉":"368","卓蘭鎮":"369"},
"臺中市" : {"中區":"400","東區":"401","南區":"402","西區":"403","北區":"404","北屯區":"406","西屯區":"407","南屯區":"408","太平區":"411","大里區":"412","霧峰區":"413","烏日區":"414","豐原區":"420","后里區":"421","石岡區":"422","東勢區":"423","和平區":"424","新社區":"426","潭子區":"427","大雅區":"428","神岡區":"429","大肚區":"432","沙鹿區":"433","龍井區":"434","梧棲區":"435","清水區":"436","大甲區":"437","外埔區":"438","大安區":"439"},
"彰化縣" : {"彰化市":"500","芬園鄉":"502","花壇鄉":"503","秀水鄉":"504","鹿港鎮":"505","福興鄉":"506","線西鄉":"507","和美鎮":"508","伸港鄉":"509","員林鎮":"510","社頭鄉":"511","永靖鄉":"512","埔心鄉":"513","溪湖鎮":"514","大村鄉":"515","埔鹽鄉":"516","田中鎮":"520","北斗鎮":"521","田尾鄉":"522","埤頭鄉":"523","溪州鄉":"524","竹塘鄉":"525","二林鎮":"526","大城鄉":"527","芳苑鄉":"528","二水鄉":"530"},
"南投縣" : {"南投市":"540","中寮鄉":"541","草屯鎮":"542","國姓鄉":"544","埔里鎮":"545","仁愛鄉":"546","名間鄉":"551","集集鎮":"552","水里鄉":"553","魚池鄉":"555","信義鄉":"556","竹山鎮":"557","鹿谷鄉":"558"},
"雲林縣" : {"斗南鎮":"630","大埤鄉":"631","虎尾鎮":"632","土庫鎮":"633","褒忠鄉":"634","東勢鄉":"635","臺西鄉":"636","崙背鄉":"637","麥寮鄉":"638","斗六市":"640","林內鄉":"643","古坑鄉":"646","莿桐鄉":"647","西螺鎮":"648","二崙鄉":"649","北港鎮":"651","水林鄉":"652","口湖鄉":"653","四湖鄉":"654","元長鄉":"655"},
"嘉義市" : {"東區":"600", "西區":"600"},
"嘉義縣" : {"番路鄉":"602","梅山鄉":"603","竹崎鄉":"604","阿里山":"605","中埔鄉":"606","大埔鄉":"607","水上鄉":"608","鹿草鄉":"611","太保市":"612","朴子市":"613","東石鄉":"614","六腳鄉":"615","新港鄉":"616","民雄鄉":"621","大林鎮":"622","溪口鄉":"623","義竹鄉":"624","布袋鎮":"625"},
"臺南市" : {"永康區":"710","歸仁區":"711","新化區":"712","左鎮區":"713","玉井區":"714","楠西區":"715","南化區":"716","仁德區":"717","關廟區":"718","龍崎區":"719","官田區":"720","麻豆區":"721","佳里區":"722","西港區":"723","七股區":"724","將軍區":"725","學甲區":"726","北門區":"727","新營區":"730","後壁區":"731","白河區":"732","東山區":"733","六甲區":"734","下營區":"735","柳營區":"736","鹽水區":"737","善化區":"741","大內區":"742","山上區":"743","新市區":"744","安定區":"745"},
"高雄市" : {"新興區":"800","前金區":"801","苓雅區":"802","鹽埕區":"803","鼓山區":"804","旗津區":"805","前鎮區":"806","三民區":"807","楠梓區":"811","小港區":"812","左營區":"813","仁武區":"814","大社區":"815","岡山區":"820","路竹區":"821","阿蓮區":"822","田寮區":"823","燕巢區":"824","橋頭區":"825","梓官區":"826","彌陀區":"827","永安區":"828","湖內區":"829","鳳山區":"830","大寮區":"831","林園區":"832","鳥松區":"833","大樹區":"840","旗山區":"842","美濃區":"843","六龜區":"844","內門區":"845","杉林區":"846","甲仙區":"847","桃源區":"848","那瑪夏":"849","茂林區":"851","茄萣區":"852"},
"屏東縣" : {"屏東市":"900","三地門":"901","霧臺鄉":"902","瑪家鄉":"903","九如鄉":"904","里港鄉":"905","高樹鄉":"906","鹽埔鄉":"907","長治鄉":"908","麟洛鄉":"909","竹田鄉":"911","內埔鄉":"912","萬丹鄉":"913","潮州鎮":"920","泰武鄉":"921","來義鄉":"922","萬巒鄉":"923","崁頂鄉":"924","新埤鄉":"925","南州鄉":"926","林邊鄉":"927","東港鎮":"928","琉球鄉":"929","佳冬鄉":"931","新園鄉":"932","枋寮鄉":"940","枋山鄉":"941","春日鄉":"942","獅子鄉":"943","車城鄉":"944","牡丹鄉":"945","恆春鎮":"946","滿州鄉":"947"},
"臺東縣" : {"臺東市":"950","綠島鄉":"951","蘭嶼鄉":"952","延平鄉":"953","卑南鄉":"954","鹿野鄉":"955","關山鎮":"956","海端鄉":"957","池上鄉":"958","東河鄉":"959","成功鎮":"961","長濱鄉":"962","太麻里":"963","金峰鄉":"964","大武鄉":"965","達仁鄉":"966"},
"花蓮縣" : {"花蓮市":"970","新城鄉":"971","秀林鄉":"972","吉安鄉":"973","壽豐鄉":"974","鳳林鎮":"975","光復鄉":"976","豐濱鄉":"977","瑞穗鄉":"978","萬榮鄉":"979","玉里鎮":"981","卓溪鄉":"982","富里鄉":"983"},
"澎湖縣" : {"馬公市":"880","西嶼鄉":"881","望安鄉":"882","七美鄉":"883","白沙鄉":"884","湖西鄉":"885"},
"金門縣" : {"金沙鎮":"890","金湖鎮":"891","金寧鄉":"892","金城鎮":"893","烈嶼鄉":"894","烏坵鄉":"896"},
"連江縣" : {"南竿鄉":"209","北竿鄉":"210","莒光鄉":"211","東引鄉":"212"}}


idData={"臺北市" : {"中正區":"100","大同區":"103","中山區":"104","松山區":"105","大安區":"106","萬華區":"108","信義區":"110","士林區":"111","北投區":"112","內湖區":"114","南港區":"115","文山區":"116"},
"新北市" : {"萬里區":"207","金山區":"208","板橋區":"220","汐止區":"221","深坑區":"222","石碇區":"223","瑞芳區":"224","平溪區":"226","雙溪區":"227","貢寮區":"228","新店區":"231","坪林區":"232","烏來區":"233","永和區":"234","中和區":"235","土城區":"236","三峽區":"237","樹林區":"238","鶯歌區":"239","三重區":"241","新莊區":"242","泰山區":"243","林口區":"244","蘆洲區":"247","五股區":"248","八里區":"249","淡水區":"251","三芝區":"252","石門區":"253"},
"基隆市" : {"仁愛區":"200","信義區":"201","中正區":"202","中山區":"203","安樂區":"204","暖暖區":"205","七堵區":"206"},
"宜蘭縣" : {"宜蘭市":"260","頭城鎮":"261","礁溪鄉":"262","壯圍鄉":"263","員山鄉":"264","羅東鎮":"265","三星鄉":"266","大同鄉":"267","五結鄉":"268","冬山鄉":"269","蘇澳鎮":"270","南澳鄉":"272"},
"新竹市" : {"東區":"300", "北區":"300", "香山區":"300"},
"新竹縣": {"湖口鄉":"303","新豐鄉":"304","新埔鎮":"305","關西鎮":"306","芎林鄉":"307","寶山鄉":"308","竹東鎮":"310","五峰鄉":"311","橫山鄉":"312","尖石鄉":"313","北埔鄉":"314","峨眉鄉":"315"},
"桃園市" : {"中壢區":"320","平鎮區":"324","龍潭區":"325","楊梅區":"326","新屋區":"327","觀音區":"328","桃園區":"330","龜山區":"333","八德區":"334","大溪區":"335","復興區":"336","大園區":"337","蘆竹區":"338"},
"苗栗縣": {"竹南鎮":"350","頭份鎮":"351","三灣鄉":"352","南庄鄉":"353","獅潭鄉":"354","後龍鎮":"356","通霄鎮":"357","苑裡鎮":"358","苗栗市":"360","造橋鄉":"361","頭屋鄉":"362","公館鄉":"363","大湖鄉":"364","泰安鄉":"365","銅鑼鄉":"366","三義鄉":"367","西湖鄉":"368","卓蘭鎮":"369"},
"臺中市" : {"中區":"400","東區":"401","南區":"402","西區":"403","北區":"404","北屯區":"406","西屯區":"407","南屯區":"408","太平區":"411","大里區":"412","霧峰區":"413","烏日區":"414","豐原區":"420","后里區":"421","石岡區":"422","東勢區":"423","和平區":"424","新社區":"426","潭子區":"427","大雅區":"428","神岡區":"429","大肚區":"432","沙鹿區":"433","龍井區":"434","梧棲區":"435","清水區":"436","大甲區":"437","外埔區":"438","大安區":"439"},
"彰化縣" : {"彰化市":"500","芬園鄉":"502","花壇鄉":"503","秀水鄉":"504","鹿港鎮":"505","福興鄉":"506","線西鄉":"507","和美鎮":"508","伸港鄉":"509","員林鎮":"510","社頭鄉":"511","永靖鄉":"512","埔心鄉":"513","溪湖鎮":"514","大村鄉":"515","埔鹽鄉":"516","田中鎮":"520","北斗鎮":"521","田尾鄉":"522","埤頭鄉":"523","溪州鄉":"524","竹塘鄉":"525","二林鎮":"526","大城鄉":"527","芳苑鄉":"528","二水鄉":"530"},
"南投縣" : {"南投市":"540","中寮鄉":"541","草屯鎮":"542","國姓鄉":"544","埔里鎮":"545","仁愛鄉":"546","名間鄉":"551","集集鎮":"552","水里鄉":"553","魚池鄉":"555","信義鄉":"556","竹山鎮":"557","鹿谷鄉":"558"},
"雲林縣" : {"斗南鎮":"630","大埤鄉":"631","虎尾鎮":"632","土庫鎮":"633","褒忠鄉":"634","東勢鄉":"635","臺西鄉":"636","崙背鄉":"637","麥寮鄉":"638","斗六市":"640","林內鄉":"643","古坑鄉":"646","莿桐鄉":"647","西螺鎮":"648","二崙鄉":"649","北港鎮":"651","水林鄉":"652","口湖鄉":"653","四湖鄉":"654","元長鄉":"655"},
"嘉義市" : {"東區":"600", "西區":"600"},
"嘉義縣" : {"番路鄉":"602","梅山鄉":"603","竹崎鄉":"604","阿里山":"605","中埔鄉":"606","大埔鄉":"607","水上鄉":"608","鹿草鄉":"611","太保市":"612","朴子市":"613","東石鄉":"614","六腳鄉":"615","新港鄉":"616","民雄鄉":"621","大林鎮":"622","溪口鄉":"623","義竹鄉":"624","布袋鎮":"625"},
"臺南市" : {"永康區":"710","歸仁區":"711","新化區":"712","左鎮區":"713","玉井區":"714","楠西區":"715","南化區":"716","仁德區":"717","關廟區":"718","龍崎區":"719","官田區":"720","麻豆區":"721","佳里區":"722","西港區":"723","七股區":"724","將軍區":"725","學甲區":"726","北門區":"727","新營區":"730","後壁區":"731","白河區":"732","東山區":"733","六甲區":"734","下營區":"735","柳營區":"736","鹽水區":"737","善化區":"741","大內區":"742","山上區":"743","新市區":"744","安定區":"745"},
"高雄市" : {"新興區":"800","前金區":"801","苓雅區":"802","鹽埕區":"803","鼓山區":"804","旗津區":"805","前鎮區":"806","三民區":"807","楠梓區":"811","小港區":"812","左營區":"813","仁武區":"814","大社區":"815","岡山區":"820","路竹區":"821","阿蓮區":"822","田寮區":"823","燕巢區":"824","橋頭區":"825","梓官區":"826","彌陀區":"827","永安區":"828","湖內區":"829","鳳山區":"830","大寮區":"831","林園區":"832","鳥松區":"833","大樹區":"840","旗山區":"842","美濃區":"843","六龜區":"844","內門區":"845","杉林區":"846","甲仙區":"847","桃源區":"848","那瑪夏":"849","茂林區":"851","茄萣區":"852"},
"屏東縣" : {"屏東市":"900","三地門":"901","霧臺鄉":"902","瑪家鄉":"903","九如鄉":"904","里港鄉":"905","高樹鄉":"906","鹽埔鄉":"907","長治鄉":"908","麟洛鄉":"909","竹田鄉":"911","內埔鄉":"912","萬丹鄉":"913","潮州鎮":"920","泰武鄉":"921","來義鄉":"922","萬巒鄉":"923","崁頂鄉":"924","新埤鄉":"925","南州鄉":"926","林邊鄉":"927","東港鎮":"928","琉球鄉":"929","佳冬鄉":"931","新園鄉":"932","枋寮鄉":"940","枋山鄉":"941","春日鄉":"942","獅子鄉":"943","車城鄉":"944","牡丹鄉":"945","恆春鎮":"946","滿州鄉":"947"},
"臺東縣" : {"臺東市":"950","綠島鄉":"951","蘭嶼鄉":"952","延平鄉":"953","卑南鄉":"954","鹿野鄉":"955","關山鎮":"956","海端鄉":"957","池上鄉":"958","東河鄉":"959","成功鎮":"961","長濱鄉":"962","太麻里":"963","金峰鄉":"964","大武鄉":"965","達仁鄉":"966"},
"花蓮縣" : {"花蓮市":"970","新城鄉":"971","秀林鄉":"972","吉安鄉":"973","壽豐鄉":"974","鳳林鎮":"975","光復鄉":"976","豐濱鄉":"977","瑞穗鄉":"978","萬榮鄉":"979","玉里鎮":"981","卓溪鄉":"982","富里鄉":"983"},
"澎湖縣" : {"馬公市":"880","西嶼鄉":"881","望安鄉":"882","七美鄉":"883","白沙鄉":"884","湖西鄉":"885"},
"金門縣" : {"金沙鎮":"890","金湖鎮":"891","金寧鄉":"892","金城鎮":"893","烈嶼鄉":"894","烏坵鄉":"896"},
"連江縣" : {"南竿鄉":"209","北竿鄉":"210","莒光鄉":"211","東引鄉":"212"}}

# %%
import googlemaps
import json
gmaps = googlemaps.Client(key='AIzaSyAF9GKxqgmgDEW_h7M4TtM5CbkK03xnS0E')

for bigArea in cityData:
    for smallArea in cityData[bigArea]:
        cityData[bigArea][smallArea]={}
        cityData[bigArea][smallArea]["id"]=idData[bigArea][smallArea]
        try:
            cityData[bigArea][smallArea]["invoiceCost"]=invoiceDict[bigArea+smallArea]
        except:
            pass
        try:
            cityData[bigArea][smallArea]["humanDensity"]=humanDensityDict[bigArea+smallArea]
        except:
            pass
        
        try:
            cityData[bigArea][smallArea]["lat"]=areaDict[bigArea+smallArea][0]
            cityData[bigArea][smallArea]["lng"]=areaDict[bigArea+smallArea][1]
        except:
            geocode_result = gmaps.geocode(bigArea+smallArea)
            cityData[bigArea][smallArea]["lat"]=geocode_result[0]['geometry']['location']['lat']
            cityData[bigArea][smallArea]["lng"]=geocode_result[0]['geometry']['location']['lng']

# %%
cityData2=[{"bigArea":area,
  "smallArea":smallArea,
  'humanDensity':cityData[area][smallArea].get('humanDensity',0),
  'invoiceCost':cityData[area][smallArea].get('invoiceCost',0),
  'id':cityData[area][smallArea]['id'],
  'lat':cityData[area][smallArea]['lat'],
  'lng':cityData[area][smallArea]['lng']}  for area in cityData for smallArea in cityData[area]]

# %%
import json
with open("../data/cityData.json","w") as f:
    json.dump(cityData2,f)
