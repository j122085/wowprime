# %%
import pymongo
import re
import pprint
import json
import jieba
from collections import Counter
import time
import math
import logging
from gensim.models import word2vec
from sklearn.datasets import fetch_20newsgroups
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.neighbors.nearest_centroid import NearestCentroid
from sklearn.naive_bayes import MultinomialNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn import svm
# Out:
# D:\anaconda\lib\site-packages\gensim\utils.py:860: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")
# 2017-12-08 14:12:54,143 : INFO : 'pattern' package not found; tag filters are not available for English

# %%
with open ("../data/diendata.json") as f:
    ipeendata=json.load(f)

# %%
ipeendata[0]
# Out:
# {'Ncomment': 0,
#  'address': '台南市新營區健康路251號',
#  'averagecost': 0,
#  'bigstyle': '速食料理',
#  'collecount': 0,
#  'id': 100000,
#  'ipeenscore': 0,
#  'lat': 23.319379010490003,
#  'lng': 120.31197500804001,
#  'name': '麥當勞(新營家樂福店)',
#  'reviewdate': '2011/07/14',
#  'smallstyle': '漢堡、炸雞',
#  'status': '正常營業',
#  'tele': '066571158',
#  'viewcount': 2949}

# %%
for dien in ipeendata:
    if dien['Ncomment']!=0:
        try:
            comments=json.load(open("../data/diencomments/"+str(dien['id'])+".json"))
        except Exception as e:
            comments=[]
    else:
        comments=[]
    dien["comments"]=comments
print("讀取完畢")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-50-152db9f14750> in <module>()
#       1 for dien in ipeendata:
#       2     try:
# ----> 3         comments=json.load(open("../data/diencomments/"+str(dien['id'])+".json"))
#       4     except Exception as e:
#       5         comments=[]
#
# D:\anaconda\lib\_bootlocale.py in getpreferredencoding(do_setlocale)
#       9
#      10 if sys.platform.startswith("win"):
# ---> 11     def getpreferredencoding(do_setlocale=True):
#      12         return _locale._getdefaultlocale()[1]
#      13 else:
#
# KeyboardInterrupt:

# %%
ipeendata=[dien for dien in ipeendata if dien['Ncomment'] >0 and dien['address']!="" and dien['status']=='正常營業' and dien['comments']!=[]]
print(len(ipeendata))
# ipeendata[50]

# %%
jieba.set_dictionary('D:/dict/jieba_dict.txt.big')

# %%
#停止慈字典
stopwordset = set()
with open('D:/dict/stopwords.txt', 'r') as sw:
    for line in sw:
        stopwordset.add(line.strip('\n'))
        
#自製餐廳相關字字典pinlist
with open("D:/dict/FoodMoodDict.csv") as f:
    mydict=f.read()
#linewords pindict每個字的評分dict
linewords=[{myword:float(line.split(",")[0]) for myword in line.split(",")[1:]}\
           for line in mydict.split("\n") if line.split(",")[0]!=""]
pindict={}
for word in linewords:
    pindict.update(word)
pinlist=list(pindict.keys())

# %%
ipeendata[5]

# %%
#各種資料list
dienlist = [dien["name"] for dien in ipeendata]
bigstylelist = [dien["bigstyle"] for dien in ipeendata]
smallstylelist = [dien["smallstyle"] for dien in ipeendata]



#將以上字典都加入斷詞行列
for i in dienlist:
    jieba.add_word(i)
for i in bigstylelist:
    jieba.add_word(i)

for i in smallstylelist:
    jieba.add_word(i)
for i in pinlist:
    if i !="":
        jieba.add_word(i)
        
latlist = [dien['lat'] for dien in ipeendata]
lnglist = [dien['lng'] for dien in ipeendata]
Ncommentlist = [i["Ncomment"] for i in ipeendata]

# %%
diencommentlist=[[j["content"] for j in i["comments"]] for i in ipeendata]
diencommentlist[5]

# %%
dienmessagelist=[[''.join(j["message"]) for j in i["comments"] if j["message"]!=None and j["message"]!='null'] for i in ipeendata]
dienmessagelist[10]

# %%
#回覆數量
Nmessagelist=[len(dienmessage) for dienmessage in dienmessagelist]

# %%
#全部回覆+全部評論
dienallpinlist=[diencomment+dienmessage for diencomment,dienmessage in zip(diencommentlist,dienmessagelist)]
# dienallpinlist[10]

# %%
#把所有回覆合併
messagecombinlist=[" ".join(["".join(meg) for meg in megs if meg!=None and meg!='null'and meg!='']) for megs in dienmessagelist]
# messagecombinlist[10]

# %%
#把所有評論合併
commentcombinelist = [" ".join([j["content"] for j in i["comments"]]) for i in ipeendata]
# commentcombinelist[10]

# %%
#合併評論+回覆
pincombinelist=[comment+" "+message for comment,message in zip(commentcombinelist,messagecombinlist)]
# pincombinelist[10]

# %%
#清一下記憶體
import gc
gc.collect()

# %%
st=time.time()
#取得各店家的斷完詞評論pincutlist
pincutlist = []
cutcount=0
for pincombine in pincombinelist:
    if pincombine!="":
        cutcount+=1
        if cutcount%200==0:
            print("已切"+str(cutcount)+"篇文章的詞")
        words = jieba.cut(pincombine, cut_all=False)
        pincut=" ".join([word for word in words if word not in stopwordset and '\u4e00' <= word and word <= '\u9fff'])
        pincutlist.append(pincut)
    else:
        pincutlist.append("")
et=time.time()
print(et-st)

# %%
from myapi import TextMining
TM=TextMining.TextMining(pincutlist)
wordCountlist=TM.getWordCountList()
TF_IDFlist=TM.getTFIDF()

# %%
# #所有店家的用詞加總前三百wordCountlist300
# wordCountlist=[Counter(pincut.split(" ")).most_common(300) for pincut in pincutlist]

# st=time.time()
# #TF計算 (TF=這個字出現的次數/這篇文章的總字數)
# #(sum(dict(wordCount).values())=>一篇所有字的字數  wordkv[1]>>該文字字數  wordkv[0]>>該文字)
# #TFList每篇文章的詞 的詞頻
# # TFList=[[((wordkv[0],wordkv[1]/sum(dict(wordCount).values()))) for wordkv in wordCount] for wordCount in wordCountlist]
# n=0
# TFList=[]
# for wordCount in wordCountlist:
#     n+=1
#     if n%1000==0:
#         print(n)
#     TF={}
#     allwords=sum(dict(wordCount).values())
#     for wordkv in wordCount:
#         TF[wordkv[0]]=(wordkv[1]/allwords)
#     TFList.append(TF)
    

# #全文章共用了幾個詞(set可以去除重複，可迭代)
# wordlist=[]
# for wordCount in wordCountlist:
#     for word in wordCount:
#         wordlist.append(word[0])
# wordlist=set(wordlist)

# #nDien所有的文章(店家)數
# ndien=len(dienlist)

# et=time.time()
# print(et-st)

# %%
# a=set()

# %%
# len(wordlist)

# %%
#清一下記憶體
import gc
gc.collect()

# %%
# #計算各字出現次數
# st=time.time()
# wordappear={}
# k=0
# for wordCount in wordCountlist:
#     k+=1
#     if k%3000==0:
#         print(k)
#     for word in dict(wordCount).keys():
#         if word in wordappear:
#             wordappear[word]+=1
#         else:
#             wordappear[word]=1
            
# et=time.time()
# print(et-st)

# %%
# del wordappear[""]

# %%
# # #wordappear計算每個字出現於 (幾篇) 文章
# st=time.time()
# # wordappear={}
# # appearcount=0
# # for word in wordlist:
# #     appearcount+=1
# #     if appearcount%1000==0:
# #         print("以計算"+str(appearcount)+"個文字的出現篇數")
# #     n=0
# #     for pincut in pincutlist:
# #         if word in pincut:
# #             n+=1
# #     wordappear[word]=n
# #IDF(逆向檔案頻率)=某詞  所有文章數/在幾篇文章出現 開log10 >>次方數為所
# IDFlist={word:math.log(ndien/wordappear[word],10) for word in wordappear}


    
# et=time.time()
# print(et-st)

# %%
# len(IDFlist)

# %%
# TFList[2]

# %%
# #dienTF每家店的全字TF值 wordTF每個詞的TF   wordTF[0]詞 wordTF[1]詞的TF值  IDFlist[wordTF[0]]詞的IDF值
# # TF_IDFlist=[Counter({wordTF[0]:wordTF[1]*IDFlist[wordTF[0]]for wordTF in dienTF})for dienTF in TFList]
# # for name,TFIDF in zip(dienlist,TF_IDFlist):
# #     if name in TFIDF:
# #         del TFIDF[name]
# n=0
# TF_IDFlist=[]
# for dienTF in TFList:
#     n+=1
#     if n%3000==0:
#         print(n)
#     x=Counter()
#     for wordTF in dienTF:
#         x.update({wordTF:dienTF[wordTF]})
#     TF_IDFlist.append(x)

# %%
for name,TFIDF in zip(dienlist,TF_IDFlist):
    if name in TFIDF:
        del TFIDF[name]

# %%
gc.collect()

# %%
# st=time.time()
# pinCountMaxper5list = []
# countN=0
# for dienallpin in dienallpinlist:
#     dienWordcount={}
#     for allpin in  dienallpin:
#         countN+=1
#         if countN%100==0:
#             print("已算完"+str(countN)+"篇情緒字")
#         for pinword in pinlist:
#             if len(re.findall(pinword,allpin))>0:
#                 if len(re.findall(pinword,allpin))>5:
#                     npinword=5
#                 else:
#                     npinword=len(re.findall(pinword,allpin))
#                 if pinword not in dienWordcount:
#                     dienWordcount[pinword]=0
#                 dienWordcount[pinword]+=npinword
#     pinCountMaxper5list.append(dienWordcount)
# ed=time.time()
# print(ed-st)

# %%
st=time.time()
pinCountMaxper5list = []
countN=0
for dienallpin in dienallpinlist:
    dienWordcount={}
    for allpin in  dienallpin:
        countN+=1
        if countN%100==0:
            print("已算完"+str(countN)+"篇情緒字")
        for pinword in pinlist:
            nword=len(re.findall(pinword,allpin))
            if nword>0:
                if nword>5:
                    npinword=5
                else:
                    npinword=nword
                if pinword not in dienWordcount:
                    dienWordcount[pinword]=0
                dienWordcount[pinword]+=npinword
    pinCountMaxper5list.append(dienWordcount)
ed=time.time()
print(ed-st)

# %%
Npartpin=[int(Nmessage/6)+Ncomment for Nmessage,Ncomment in zip(Nmessagelist,Ncommentlist)]


#大致計算每家店的分數dienscorelist
dienscorelist=[]
for pinCount,N in zip(pinCountMaxper5list,Npartpin):
    dienscore=0
    for pin in pinCount:
        dienscore+=pinCount[pin]*pindict[pin]/N
    dienscorelist.append(dienscore)

# %%
synonyms=[{word:line.split(",")[1] for word in line.split(",")[1:]} for line in mydict.split("\n") if line.split(",")[0]!=""]

pinsynonymsdict={}
for synonym in synonyms:
    pinsynonymsdict.update(synonym)
del pinsynonymsdict[""]

# %%
featurescores=[]

#將評價詞加總及評論次數做iterate
for pinCountMaxper5,N in zip(pinCountMaxper5list,Npartpin):
    dienfeaturescore={}
    
    # 評價詞出現次數/評論次數 做為分數，其中否字開頭給負分
    for pin in pinCountMaxper5:
        if pin !="":
            if pinsynonymsdict[pin][0]=="否":
                if pinsynonymsdict[pin][1:] not in dienfeaturescore:
                    dienfeaturescore[pinsynonymsdict[pin][1:]]=0
                dienfeaturescore[pinsynonymsdict[pin][1:]]-=round(pinCountMaxper5[pin]/N,2)*1
            else:
                if pinsynonymsdict[pin] not in dienfeaturescore:
                    dienfeaturescore[pinsynonymsdict[pin]]=0
                dienfeaturescore[pinsynonymsdict[pin]]+=round(pinCountMaxper5[pin]/N,2)
    if len(dienfeaturescore)==0:
        dienfeaturescore["無評"]=1
    featurescores.append(dienfeaturescore)

# %%
BigAnalyzeTable=[]
for name,bigstyle,smallstyle,Ncomment,contentcut,wordCount,TFIDF,pinCountMax5,score,featurescore,introduction,lat,lng in zip(dienlist,bigstylelist,smallstylelist,Npartpin,pincutlist,wordCountlist,TF_IDFlist,pinCountMaxper5list,dienscorelist,featurescores,latlist,lnglist):
    dien={}
    dien['name']=name
    dien['bigstyle']=bigstyle
    dien['smallstyle']=smallstyle
    dien['Ncomment']=Ncomment
    dien['contentcut']=contentcut
    dien['wordCount']=wordCount
    dien['TF_IDF']=TFIDF
    dien['pinCountMaxper5']=pinCountMax5
    dien['score']=score
    dien['featurescores']=featurescore
    dien['tags']=[tag[0] for tag in Counter(TFIDF).most_common(5)]
    dien['lat']=lat
    dien['lng']=lng
    
    
    BigAnalyzeTable.append(dien)

# %%
gc.collect()

# %%
#算出每個評論的評論數N時的 最大值b 最小值g for正規化


#allpin=評論詞list
allpin=set([line.split(",")[1] for line in mydict.split("\n") if line.split(",")[0]!="" and line.split(",")[1][0]!="否"])
standard={}

#standard為正規化所需用的值
for pin in allpin:
    for rang in [(0,5),(5,10),(10,15),(15,100)]:
        get={}
        values=[dien['featurescores'][pin] for dien in BigAnalyzeTable if pin in dien['featurescores'] and dien["Ncomment"]>rang[0] and dien["Ncomment"]<=rang[1]]
        b=0
        g=0
        for value in values:
            if value <b:
                b=round(value,1)
            if value >g:
                g=round(value,1)
        get[pin+str(rang[0])]=((g+b)/2,g-(g+b)/2)
        standard.update(get)
        print(pin+"+"+str(rang[0])+"\t"+str(g)+"\t"+str(b))

# %%
#進行正規化的處理
for dien in BigAnalyzeTable:
    N=dien['Ncomment']
    for feature in dien['featurescores']:
        if feature !="無評":
            if N<6:
                dien['featurescores'][feature]=round((dien['featurescores'][feature])/standard[feature+str(0)][1],2)
            elif N<11 and N>=6:
                dien['featurescores'][feature]=round((dien['featurescores'][feature])/standard[feature+str(5)][1],2)
            elif N<16 and N>=11:
                dien['featurescores'][feature]=round((dien['featurescores'][feature])/standard[feature+str(10)][1],2)
            else:
                dien['featurescores'][feature]=round((dien['featurescores'][feature])/standard[feature+str(15)][1],2)

# %%
allpin=[line.split(",")[1] for line in mydict.split("\n") if line.split(",")[0]!="" and line.split(",")[1][0]!="否"]
standard={}

for pin in allpin:
    for rang in [(0,5),(5,10),(10,15),(15,100)]:
#         get={}
        values=[dien['featurescores'][pin] for dien in BigAnalyzeTable if pin in dien['featurescores'] and dien["Ncomment"]>rang[0] and dien["Ncomment"]<=rang[1]]
        b=0
        g=0
        for value in values:
            if value <b:
                b=round(value,1)
            if value >g:
                g=round(value,1)
#         get[pin+str(rang[0])]=((g+b)/2,g-(g+b)/2)
#         standard.update(get)
        print(pin+"+"+str(rang[0])+"\t"+str(g)+"\t"+str(b))

# %%
pipin=[('食物美味','食物不好吃',"非常好吃",'非常不好吃'),('划算','價格較高昂',"非常便宜",'非常貴')
       ,('環境好','環境比較不好',"環境超棒",'環境很差'),('服務好','服務較差',"服務一級棒",'服務很差')
       ,('其他正面情緒','評論有些負面情緒詞',"網路評論正面情緒非常多",'網路評論負面情緒很多')]
moods=[mood[0] for mood in pipin]
for dien in BigAnalyzeTable:
    newtag=[]
    for feature in dien["featurescores"]:
        if feature in moods:
            if dien["featurescores"][feature]>1:
                for pinpare in pipin:
                    if feature==pinpare[0]:
                        newtag.append(pinpare[2])
            elif dien["featurescores"][feature]>0.4:
                newtag.append(feature)
            elif dien["featurescores"][feature]<-0.5:
                for pinpare in pipin:
                    if feature==pinpare[0]:
                        newtag.append(pinpare[3])
            elif dien["featurescores"][feature]<0.0:
                for pinpare in pipin:
                    if feature==pinpare[0]:
                        newtag.append(pinpare[1])
        else:
            if dien["featurescores"][feature]>0.7:
                newtag.append(feature)
                    
                    
#用set去除重複標籤
    dien['tags']=list(set(dien['tags']+newtag))
    print(dien['name'])
#     print(newtag)
    dien['tags'].append(dien['bigstyle'])
    print(dien['tags'])

# %%
for i in BigAnalyzeTable:
    if i['score']>30 and i['Ncomment']>10:
        print(i['name']+' '+str(i['score']))
#         print(i['tags'])
        print(i['featurescores'])
        print('\n')
gooddien=[i for i in BigAnalyzeTable if i['score']>30 and i['Ncomment']>10]

# %%
with open('../data/bigtable.json','w') as f:
    json.dump(BigAnalyzeTable,f)
with open('../data/GoodDien.json','w') as f:
    json.dump(gooddien,f)

# %%
len(BigAnalyzeTable[3]['lng'])

# %% [markdown]
# # 試做word2vec

# %%
from gensim.models import word2vec
import logging
# Out:
# D:\anaconda\lib\site-packages\gensim\utils.py:860: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
import json
with open('../data/bigtable.json') as f:
    BigAnalyzeTable=json.load(f)

# %%
contentcutcombine=" ".join([i['contentcut'] for i in BigAnalyzeTable])
with open('../data/contentcutcombine.txt','w',encoding="utf-8") as w:
    w.write(contentcutcombine)

# %%
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)
sentences = word2vec.Text8Corpus('../data/contentcutcombine.txt')
model = word2vec.Word2Vec(sentences, size=250,window=6, min_count=4, workers=4,sg=1)

# Save our model.

model.save("../data/W2Vmodel/med250.model.bin")
# Out:
# 2017-12-06 09:06:42,382 : WARNING : consider setting layer size to a multiple of 4 for greater performance
# 2017-12-06 09:06:42,385 : INFO : collecting all words and their counts
# 2017-12-06 09:06:42,389 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2017-12-06 09:07:08,844 : INFO : collected 530156 word types from a corpus of 52193139 raw words and 5220 sentences
# 2017-12-06 09:07:08,845 : INFO : Loading a fresh vocabulary
# 2017-12-06 09:07:10,739 : INFO : min_count=4 retains 171455 unique words (32% of original 530156, drops 358701)
# 2017-12-06 09:07:10,740 : INFO : min_count=4 leaves 51700227 word corpus (99% of original 52193139, drops 492912)
# 2017-12-06 09:07:11,562 : INFO : deleting the raw counts dictionary of 530156 items
# 2017-12-06 09:07:11,592 : INFO : sample=0.001 downsamples 16 most-common words
# 2017-12-06 09:07:11,594 : INFO : downsampling leaves estimated 50740403 word corpus (98.1% of prior 51700227)
# 2017-12-06 09:07:11,596 : INFO : estimated required memory for 171455 words and 250 dimensions: 428637500 bytes
# 2017-12-06 09:07:12,349 : INFO : resetting layer weights
# 2017-12-06 09:07:16,313 : INFO : training model with 4 workers on 171455 vocabulary and 250 features, using sg=1 hs=0 sample=0.001 negative=5 window=6
# 2017-12-06 09:07:17,396 : INFO : PROGRESS: at 0.03% examples, 81078 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:07:18,418 : INFO : PROGRESS: at 0.08% examples, 97241 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:07:19,473 : INFO : PROGRESS: at 0.13% examples, 101576 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:07:20,503 : INFO : PROGRESS: at 0.17% examples, 104480 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:07:21,507 : INFO : PROGRESS: at 0.21% examples, 103052 words/s, in_qsize 6, out_qsize 1
# 2017-12-06 09:07:22,633 : INFO : PROGRESS: at 0.26% examples, 106218 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:07:23,714 : INFO : PROGRESS: at 0.31% examples, 106470 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:07:24,872 : INFO : PROGRESS: at 0.36% examples, 105734 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:07:25,982 : INFO : PROGRESS: at 0.40% examples, 105666 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:07:26,993 : INFO : PROGRESS: at 0.45% examples, 106590 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:07:28,018 : INFO : PROGRESS: at 0.49% examples, 106396 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:07:29,023 : INFO : PROGRESS: at 0.53% examples, 105635 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:07:30,086 : INFO : PROGRESS: at 0.58% examples, 106672 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:07:31,145 : INFO : PROGRESS: at 0.63% examples, 108230 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:07:32,259 : INFO : PROGRESS: at 0.69% examples, 109210 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:07:33,325 : INFO : PROGRESS: at 0.74% examples, 110364 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:07:34,426 : INFO : PROGRESS: at 0.79% examples, 110111 words/s, in_qsize 7, out_qsize 1
# 2017-12-06 09:07:35,505 : INFO : PROGRESS: at 0.84% examples, 111026 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:07:36,534 : INFO : PROGRESS: at 0.89% examples, 111629 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:07:37,659 : INFO : PROGRESS: at 0.93% examples, 111228 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:07:38,696 : INFO : PROGRESS: at 0.98% examples, 111735 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:07:39,744 : INFO : PROGRESS: at 1.03% examples, 112140 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:07:40,812 : INFO : PROGRESS: at 1.08% examples, 112016 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:07:41,846 : INFO : PROGRESS: at 1.13% examples, 112435 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:07:42,931 : INFO : PROGRESS: at 1.18% examples, 112612 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:07:43,997 : INFO : PROGRESS: at 1.23% examples, 113196 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:07:45,016 : INFO : PROGRESS: at 1.28% examples, 113584 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:07:46,036 : INFO : PROGRESS: at 1.33% examples, 113945 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:07:47,080 : INFO : PROGRESS: at 1.39% examples, 114505 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:07:48,144 : INFO : PROGRESS: at 1.44% examples, 114646 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:07:49,320 : INFO : PROGRESS: at 1.49% examples, 114398 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:07:50,352 : INFO : PROGRESS: at 1.54% examples, 114645 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:07:51,357 : INFO : PROGRESS: at 1.58% examples, 114697 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:07:52,552 : INFO : PROGRESS: at 1.64% examples, 114675 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:07:53,570 : INFO : PROGRESS: at 1.69% examples, 115199 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:07:54,756 : INFO : PROGRESS: at 1.74% examples, 115193 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:07:55,758 : INFO : PROGRESS: at 1.79% examples, 115472 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:07:56,790 : INFO : PROGRESS: at 1.84% examples, 115663 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:07:57,796 : INFO : PROGRESS: at 1.89% examples, 115905 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:07:58,921 : INFO : PROGRESS: at 1.95% examples, 116047 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:08:00,012 : INFO : PROGRESS: at 2.00% examples, 116266 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:08:01,038 : INFO : PROGRESS: at 2.05% examples, 116433 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:08:02,091 : INFO : PROGRESS: at 2.09% examples, 116092 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:08:03,096 : INFO : PROGRESS: at 2.15% examples, 116509 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:08:04,277 : INFO : PROGRESS: at 2.20% examples, 116485 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:08:05,291 : INFO : PROGRESS: at 2.25% examples, 116852 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:08:06,489 : INFO : PROGRESS: at 2.31% examples, 116776 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:08:07,729 : INFO : PROGRESS: at 2.37% examples, 116986 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:08:08,799 : INFO : PROGRESS: at 2.43% examples, 117383 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:08:09,862 : INFO : PROGRESS: at 2.48% examples, 117416 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:08:10,959 : INFO : PROGRESS: at 2.53% examples, 117556 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:08:12,012 : INFO : PROGRESS: at 2.58% examples, 117607 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:08:13,117 : INFO : PROGRESS: at 2.62% examples, 117377 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:08:14,129 : INFO : PROGRESS: at 2.66% examples, 117006 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:08:15,144 : INFO : PROGRESS: at 2.70% examples, 116638 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:08:16,224 : INFO : PROGRESS: at 2.75% examples, 116649 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:08:17,277 : INFO : PROGRESS: at 2.80% examples, 116549 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:08:18,335 : INFO : PROGRESS: at 2.84% examples, 116441 words/s, in_qsize 7, out_qsize 1
# 2017-12-06 09:08:19,347 : INFO : PROGRESS: at 2.89% examples, 116270 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:08:20,416 : INFO : PROGRESS: at 2.94% examples, 116607 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:08:21,420 : INFO : PROGRESS: at 2.98% examples, 116449 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:08:22,463 : INFO : PROGRESS: at 3.03% examples, 116526 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:08:23,621 : INFO : PROGRESS: at 3.08% examples, 116402 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:08:24,730 : INFO : PROGRESS: at 3.13% examples, 116367 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:08:25,763 : INFO : PROGRESS: at 3.18% examples, 116456 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:08:26,786 : INFO : PROGRESS: at 3.23% examples, 116282 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:08:27,842 : INFO : PROGRESS: at 3.28% examples, 116334 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:08:28,845 : INFO : PROGRESS: at 3.33% examples, 116469 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:08:29,862 : INFO : PROGRESS: at 3.36% examples, 116184 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:08:30,928 : INFO : PROGRESS: at 3.41% examples, 116088 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:08:31,961 : INFO : PROGRESS: at 3.46% examples, 116047 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:08:33,112 : INFO : PROGRESS: at 3.51% examples, 116207 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:08:34,120 : INFO : PROGRESS: at 3.56% examples, 116328 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:08:35,122 : INFO : PROGRESS: at 3.61% examples, 116453 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:08:36,293 : INFO : PROGRESS: at 3.67% examples, 116452 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:08:37,342 : INFO : PROGRESS: at 3.72% examples, 116502 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:08:38,399 : INFO : PROGRESS: at 3.77% examples, 116542 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:08:39,474 : INFO : PROGRESS: at 3.82% examples, 116554 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:08:40,585 : INFO : PROGRESS: at 3.87% examples, 116748 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:08:41,617 : INFO : PROGRESS: at 3.92% examples, 116706 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:08:42,650 : INFO : PROGRESS: at 3.97% examples, 116662 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:08:43,717 : INFO : PROGRESS: at 4.01% examples, 116575 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:08:44,729 : INFO : PROGRESS: at 4.06% examples, 116559 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:08:45,877 : INFO : PROGRESS: at 4.11% examples, 116470 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:08:46,979 : INFO : PROGRESS: at 4.15% examples, 116343 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:08:48,012 : INFO : PROGRESS: at 4.20% examples, 116409 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:08:49,025 : INFO : PROGRESS: at 4.25% examples, 116289 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:08:50,038 : INFO : PROGRESS: at 4.29% examples, 116276 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:08:51,154 : INFO : PROGRESS: at 4.34% examples, 116138 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:08:52,166 : INFO : PROGRESS: at 4.39% examples, 116329 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:08:53,172 : INFO : PROGRESS: at 4.43% examples, 116124 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:08:54,253 : INFO : PROGRESS: at 4.48% examples, 116034 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:08:55,270 : INFO : PROGRESS: at 4.52% examples, 116021 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:08:56,319 : INFO : PROGRESS: at 4.57% examples, 115971 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:08:57,459 : INFO : PROGRESS: at 4.62% examples, 115916 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:08:58,618 : INFO : PROGRESS: at 4.67% examples, 115935 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:08:59,808 : INFO : PROGRESS: at 4.72% examples, 115729 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:09:00,841 : INFO : PROGRESS: at 4.76% examples, 115698 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:09:01,900 : INFO : PROGRESS: at 4.82% examples, 115827 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:09:02,927 : INFO : PROGRESS: at 4.87% examples, 115895 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:09:04,072 : INFO : PROGRESS: at 4.92% examples, 115835 words/s, in_qsize 7, out_qsize 1
# 2017-12-06 09:09:05,109 : INFO : PROGRESS: at 4.97% examples, 116072 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:09:06,266 : INFO : PROGRESS: at 5.02% examples, 116002 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:09:07,281 : INFO : PROGRESS: at 5.07% examples, 116080 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:09:08,479 : INFO : PROGRESS: at 5.11% examples, 115795 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:09:09,539 : INFO : PROGRESS: at 5.16% examples, 115743 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:09:10,779 : INFO : PROGRESS: at 5.22% examples, 115846 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:09:11,780 : INFO : PROGRESS: at 5.28% examples, 116106 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:09:12,905 : INFO : PROGRESS: at 5.33% examples, 116070 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:09:13,913 : INFO : PROGRESS: at 5.38% examples, 116067 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:09:14,992 : INFO : PROGRESS: at 5.43% examples, 116158 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:09:16,126 : INFO : PROGRESS: at 5.48% examples, 116194 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:09:17,195 : INFO : PROGRESS: at 5.54% examples, 116373 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:09:18,288 : INFO : PROGRESS: at 5.59% examples, 116366 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:09:19,293 : INFO : PROGRESS: at 5.64% examples, 116524 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:09:20,455 : INFO : PROGRESS: at 5.70% examples, 116529 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:09:21,479 : INFO : PROGRESS: at 5.75% examples, 116586 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:09:22,538 : INFO : PROGRESS: at 5.80% examples, 116686 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:09:23,604 : INFO : PROGRESS: at 5.85% examples, 116701 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:09:24,651 : INFO : PROGRESS: at 5.90% examples, 116735 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:09:25,818 : INFO : PROGRESS: at 5.96% examples, 116808 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:09:26,906 : INFO : PROGRESS: at 6.01% examples, 116804 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:09:28,054 : INFO : PROGRESS: at 6.07% examples, 116893 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:09:29,092 : INFO : PROGRESS: at 6.12% examples, 117004 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:09:30,170 : INFO : PROGRESS: at 6.17% examples, 117080 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:09:31,172 : INFO : PROGRESS: at 6.22% examples, 117146 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:09:32,273 : INFO : PROGRESS: at 6.27% examples, 117122 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:09:33,365 : INFO : PROGRESS: at 6.33% examples, 117245 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:09:34,430 : INFO : PROGRESS: at 6.38% examples, 117250 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:09:35,439 : INFO : PROGRESS: at 6.43% examples, 117303 words/s, in_qsize 7, out_qsize 1
# 2017-12-06 09:09:36,469 : INFO : PROGRESS: at 6.47% examples, 117200 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:09:37,589 : INFO : PROGRESS: at 6.53% examples, 117299 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:09:38,677 : INFO : PROGRESS: at 6.58% examples, 117352 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:09:39,695 : INFO : PROGRESS: at 6.64% examples, 117465 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:09:40,880 : INFO : PROGRESS: at 6.69% examples, 117445 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:09:41,910 : INFO : PROGRESS: at 6.75% examples, 117617 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:09:43,001 : INFO : PROGRESS: at 6.80% examples, 117605 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:09:44,007 : INFO : PROGRESS: at 6.85% examples, 117657 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:09:45,134 : INFO : PROGRESS: at 6.90% examples, 117749 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:09:46,142 : INFO : PROGRESS: at 6.95% examples, 117801 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:09:47,146 : INFO : PROGRESS: at 7.00% examples, 117855 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:09:48,243 : INFO : PROGRESS: at 7.06% examples, 117900 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:09:49,261 : INFO : PROGRESS: at 7.10% examples, 117815 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:09:50,264 : INFO : PROGRESS: at 7.15% examples, 117870 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:09:51,454 : INFO : PROGRESS: at 7.20% examples, 117843 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:09:52,455 : INFO : PROGRESS: at 7.26% examples, 118023 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:09:53,593 : INFO : PROGRESS: at 7.31% examples, 117972 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:09:54,603 : INFO : PROGRESS: at 7.36% examples, 118015 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:09:55,618 : INFO : PROGRESS: at 7.41% examples, 118116 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:09:56,679 : INFO : PROGRESS: at 7.45% examples, 117881 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:09:57,709 : INFO : PROGRESS: at 7.49% examples, 117852 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:09:58,730 : INFO : PROGRESS: at 7.55% examples, 117952 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:09:59,921 : INFO : PROGRESS: at 7.60% examples, 117926 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:10:01,042 : INFO : PROGRESS: at 7.65% examples, 117832 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:10:02,086 : INFO : PROGRESS: at 7.69% examples, 117796 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:10:03,121 : INFO : PROGRESS: at 7.74% examples, 117764 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:10:04,183 : INFO : PROGRESS: at 7.79% examples, 117713 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:10:05,318 : INFO : PROGRESS: at 7.83% examples, 117613 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:10:06,494 : INFO : PROGRESS: at 7.88% examples, 117485 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:10:07,708 : INFO : PROGRESS: at 7.92% examples, 117335 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:10:08,714 : INFO : PROGRESS: at 7.96% examples, 117213 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:10:09,724 : INFO : PROGRESS: at 8.00% examples, 117089 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:10:10,736 : INFO : PROGRESS: at 8.05% examples, 117077 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:10:11,761 : INFO : PROGRESS: at 8.10% examples, 117168 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:10:12,999 : INFO : PROGRESS: at 8.15% examples, 117117 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:10:14,084 : INFO : PROGRESS: at 8.20% examples, 117058 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:10:15,117 : INFO : PROGRESS: at 8.25% examples, 117088 words/s, in_qsize 7, out_qsize 1
# 2017-12-06 09:10:16,309 : INFO : PROGRESS: at 8.31% examples, 117124 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:10:17,319 : INFO : PROGRESS: at 8.36% examples, 117221 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:10:18,336 : INFO : PROGRESS: at 8.41% examples, 117261 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:10:19,368 : INFO : PROGRESS: at 8.46% examples, 117289 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:10:20,405 : INFO : PROGRESS: at 8.51% examples, 117368 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:10:21,432 : INFO : PROGRESS: at 8.57% examples, 117453 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:10:22,470 : INFO : PROGRESS: at 8.62% examples, 117530 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:10:23,602 : INFO : PROGRESS: at 8.67% examples, 117547 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:10:24,636 : INFO : PROGRESS: at 8.72% examples, 117574 words/s, in_qsize 6, out_qsize 1
# 2017-12-06 09:10:25,781 : INFO : PROGRESS: at 8.78% examples, 117633 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:10:26,793 : INFO : PROGRESS: at 8.84% examples, 117722 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:10:27,966 : INFO : PROGRESS: at 8.89% examples, 117710 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:10:29,003 : INFO : PROGRESS: at 8.93% examples, 117682 words/s, in_qsize 7, out_qsize 1
# 2017-12-06 09:10:30,121 : INFO : PROGRESS: at 8.98% examples, 117604 words/s, in_qsize 5, out_qsize 2
# 2017-12-06 09:10:31,182 : INFO : PROGRESS: at 9.03% examples, 117663 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:10:32,326 : INFO : PROGRESS: at 9.09% examples, 117671 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:10:33,551 : INFO : PROGRESS: at 9.15% examples, 117730 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:10:34,737 : INFO : PROGRESS: at 9.21% examples, 117810 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:10:35,905 : INFO : PROGRESS: at 9.27% examples, 117900 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:10:36,908 : INFO : PROGRESS: at 9.33% examples, 118037 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:10:38,013 : INFO : PROGRESS: at 9.38% examples, 118018 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:10:39,190 : INFO : PROGRESS: at 9.44% examples, 118102 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:10:40,222 : INFO : PROGRESS: at 9.50% examples, 118219 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:10:41,265 : INFO : PROGRESS: at 9.55% examples, 118233 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:10:42,311 : INFO : PROGRESS: at 9.60% examples, 118293 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:10:43,389 : INFO : PROGRESS: at 9.65% examples, 118286 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:10:44,428 : INFO : PROGRESS: at 9.70% examples, 118350 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:10:45,548 : INFO : PROGRESS: at 9.76% examples, 118367 words/s, in_qsize 7, out_qsize 1
# 2017-12-06 09:10:46,581 : INFO : PROGRESS: at 9.81% examples, 118434 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:10:47,674 : INFO : PROGRESS: at 9.87% examples, 118465 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:10:48,681 : INFO : PROGRESS: at 9.92% examples, 118499 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:10:49,802 : INFO : PROGRESS: at 9.97% examples, 118560 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:10:50,813 : INFO : PROGRESS: at 10.02% examples, 118590 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:10:51,867 : INFO : PROGRESS: at 10.08% examples, 118641 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:10:52,907 : INFO : PROGRESS: at 10.13% examples, 118654 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:10:53,946 : INFO : PROGRESS: at 10.18% examples, 118714 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:10:55,012 : INFO : PROGRESS: at 10.23% examples, 118714 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:10:56,033 : INFO : PROGRESS: at 10.28% examples, 118782 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:10:57,038 : INFO : PROGRESS: at 10.33% examples, 118725 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:10:58,054 : INFO : PROGRESS: at 10.38% examples, 118752 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:10:59,162 : INFO : PROGRESS: at 10.43% examples, 118772 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:11:00,213 : INFO : PROGRESS: at 10.49% examples, 118865 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:11:01,299 : INFO : PROGRESS: at 10.54% examples, 118853 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:11:02,364 : INFO : PROGRESS: at 10.59% examples, 118938 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:11:03,444 : INFO : PROGRESS: at 10.64% examples, 118929 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:11:04,453 : INFO : PROGRESS: at 10.70% examples, 119042 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:11:05,542 : INFO : PROGRESS: at 10.75% examples, 119029 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:11:06,547 : INFO : PROGRESS: at 10.81% examples, 119143 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:11:07,658 : INFO : PROGRESS: at 10.86% examples, 119118 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:11:08,660 : INFO : PROGRESS: at 10.91% examples, 119191 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:11:09,847 : INFO : PROGRESS: at 10.97% examples, 119167 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:11:10,901 : INFO : PROGRESS: at 11.02% examples, 119171 words/s, in_qsize 7, out_qsize 1
# 2017-12-06 09:11:11,949 : INFO : PROGRESS: at 11.07% examples, 119178 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:11:13,008 : INFO : PROGRESS: at 11.11% examples, 119138 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:11:14,048 : INFO : PROGRESS: at 11.16% examples, 119108 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:11:15,127 : INFO : PROGRESS: at 11.21% examples, 119140 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:11:16,155 : INFO : PROGRESS: at 11.26% examples, 119156 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:11:17,170 : INFO : PROGRESS: at 11.31% examples, 119138 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:11:18,211 : INFO : PROGRESS: at 11.36% examples, 119188 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:11:19,242 : INFO : PROGRESS: at 11.41% examples, 119162 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:11:20,335 : INFO : PROGRESS: at 11.46% examples, 119147 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:11:21,368 : INFO : PROGRESS: at 11.51% examples, 119240 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:11:22,482 : INFO : PROGRESS: at 11.56% examples, 119214 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:11:23,496 : INFO : PROGRESS: at 11.62% examples, 119316 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:11:24,592 : INFO : PROGRESS: at 11.67% examples, 119299 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:11:25,612 : INFO : PROGRESS: at 11.73% examples, 119395 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:11:26,697 : INFO : PROGRESS: at 11.78% examples, 119383 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:11:27,725 : INFO : PROGRESS: at 11.83% examples, 119437 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:11:28,780 : INFO : PROGRESS: at 11.89% examples, 119476 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:11:29,885 : INFO : PROGRESS: at 11.93% examples, 119455 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:11:31,084 : INFO : PROGRESS: at 12.00% examples, 119505 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:11:32,102 : INFO : PROGRESS: at 12.05% examples, 119600 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:11:33,243 : INFO : PROGRESS: at 12.10% examples, 119561 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:11:34,278 : INFO : PROGRESS: at 12.15% examples, 119533 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:11:35,294 : INFO : PROGRESS: at 12.20% examples, 119590 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:11:36,432 : INFO : PROGRESS: at 12.26% examples, 119591 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:11:37,474 : INFO : PROGRESS: at 12.31% examples, 119672 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:11:38,494 : INFO : PROGRESS: at 12.36% examples, 119690 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:11:39,525 : INFO : PROGRESS: at 12.42% examples, 119738 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:11:40,560 : INFO : PROGRESS: at 12.47% examples, 119784 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:11:41,583 : INFO : PROGRESS: at 12.52% examples, 119800 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:11:42,601 : INFO : PROGRESS: at 12.57% examples, 119853 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:11:43,717 : INFO : PROGRESS: at 12.63% examples, 119863 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:11:44,753 : INFO : PROGRESS: at 12.69% examples, 119944 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:11:45,819 : INFO : PROGRESS: at 12.74% examples, 119939 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:11:46,891 : INFO : PROGRESS: at 12.79% examples, 120004 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:11:47,923 : INFO : PROGRESS: at 12.84% examples, 120014 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:11:48,935 : INFO : PROGRESS: at 12.90% examples, 120069 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:11:49,992 : INFO : PROGRESS: at 12.95% examples, 120067 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:11:51,060 : INFO : PROGRESS: at 13.00% examples, 120132 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:11:52,089 : INFO : PROGRESS: at 13.05% examples, 120142 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:11:53,138 : INFO : PROGRESS: at 13.10% examples, 120143 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:11:54,160 : INFO : PROGRESS: at 13.16% examples, 120193 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:11:55,351 : INFO : PROGRESS: at 13.21% examples, 120133 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:11:56,356 : INFO : PROGRESS: at 13.26% examples, 120189 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:11:57,503 : INFO : PROGRESS: at 13.31% examples, 120183 words/s, in_qsize 7, out_qsize 1
# 2017-12-06 09:11:58,515 : INFO : PROGRESS: at 13.37% examples, 120234 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:11:59,612 : INFO : PROGRESS: at 13.42% examples, 120248 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:12:00,671 : INFO : PROGRESS: at 13.48% examples, 120314 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:12:01,710 : INFO : PROGRESS: at 13.53% examples, 120320 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:12:02,827 : INFO : PROGRESS: at 13.59% examples, 120360 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:12:03,864 : INFO : PROGRESS: at 13.64% examples, 120366 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:12:04,879 : INFO : PROGRESS: at 13.69% examples, 120413 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:12:06,008 : INFO : PROGRESS: at 13.74% examples, 120380 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:12:07,012 : INFO : PROGRESS: at 13.79% examples, 120365 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:12:08,138 : INFO : PROGRESS: at 13.83% examples, 120301 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:12:09,312 : INFO : PROGRESS: at 13.88% examples, 120218 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:12:10,313 : INFO : PROGRESS: at 13.92% examples, 120139 words/s, in_qsize 7, out_qsize 1
# 2017-12-06 09:12:11,344 : INFO : PROGRESS: at 13.96% examples, 120114 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:12:12,412 : INFO : PROGRESS: at 14.01% examples, 120108 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:12:13,454 : INFO : PROGRESS: at 14.05% examples, 119981 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:12:14,465 : INFO : PROGRESS: at 14.08% examples, 119867 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:12:15,504 : INFO : PROGRESS: at 14.13% examples, 119840 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:12:16,525 : INFO : PROGRESS: at 14.18% examples, 119852 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:12:17,737 : INFO : PROGRESS: at 14.23% examples, 119853 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:12:18,775 : INFO : PROGRESS: at 14.29% examples, 119925 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:12:19,776 : INFO : PROGRESS: at 14.33% examples, 119849 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:12:20,928 : INFO : PROGRESS: at 14.37% examples, 119747 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:12:22,053 : INFO : PROGRESS: at 14.42% examples, 119688 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:12:23,061 : INFO : PROGRESS: at 14.47% examples, 119738 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:12:24,230 : INFO : PROGRESS: at 14.52% examples, 119726 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:12:25,238 : INFO : PROGRESS: at 14.58% examples, 119776 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:12:26,424 : INFO : PROGRESS: at 14.63% examples, 119758 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:12:27,452 : INFO : PROGRESS: at 14.69% examples, 119799 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:12:28,492 : INFO : PROGRESS: at 14.73% examples, 119773 words/s, in_qsize 6, out_qsize 1
# 2017-12-06 09:12:29,644 : INFO : PROGRESS: at 14.77% examples, 119643 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:12:30,666 : INFO : PROGRESS: at 14.80% examples, 119534 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:12:31,683 : INFO : PROGRESS: at 14.84% examples, 119426 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:12:32,748 : INFO : PROGRESS: at 14.88% examples, 119331 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:12:33,772 : INFO : PROGRESS: at 14.92% examples, 119253 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:12:34,802 : INFO : PROGRESS: at 14.96% examples, 119203 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:12:35,834 : INFO : PROGRESS: at 15.00% examples, 119123 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:12:36,983 : INFO : PROGRESS: at 15.04% examples, 119030 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:12:38,174 : INFO : PROGRESS: at 15.08% examples, 118953 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:12:39,398 : INFO : PROGRESS: at 15.13% examples, 118864 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:12:40,643 : INFO : PROGRESS: at 15.18% examples, 118767 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:12:41,878 : INFO : PROGRESS: at 15.22% examples, 118676 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:12:43,074 : INFO : PROGRESS: at 15.27% examples, 118598 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:12:44,192 : INFO : PROGRESS: at 15.31% examples, 118549 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:12:45,212 : INFO : PROGRESS: at 15.37% examples, 118624 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:12:46,269 : INFO : PROGRESS: at 15.41% examples, 118568 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:12:47,479 : INFO : PROGRESS: at 15.47% examples, 118546 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:12:48,679 : INFO : PROGRESS: at 15.51% examples, 118470 words/s, in_qsize 7, out_qsize 1
# 2017-12-06 09:12:49,706 : INFO : PROGRESS: at 15.56% examples, 118424 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:12:50,712 : INFO : PROGRESS: at 15.59% examples, 118359 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:12:51,801 : INFO : PROGRESS: at 15.64% examples, 118293 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:12:52,833 : INFO : PROGRESS: at 15.68% examples, 118248 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:12:53,877 : INFO : PROGRESS: at 15.72% examples, 118228 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:12:55,001 : INFO : PROGRESS: at 15.78% examples, 118265 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:12:56,001 : INFO : PROGRESS: at 15.84% examples, 118317 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:12:57,045 : INFO : PROGRESS: at 15.87% examples, 118240 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:12:58,149 : INFO : PROGRESS: at 15.92% examples, 118199 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:12:59,224 : INFO : PROGRESS: at 15.96% examples, 118140 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:13:00,249 : INFO : PROGRESS: at 16.00% examples, 118042 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:13:01,383 : INFO : PROGRESS: at 16.03% examples, 117907 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:13:02,504 : INFO : PROGRESS: at 16.08% examples, 117862 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:13:03,686 : INFO : PROGRESS: at 16.12% examples, 117796 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:13:04,713 : INFO : PROGRESS: at 16.17% examples, 117811 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:13:05,727 : INFO : PROGRESS: at 16.23% examples, 117857 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:13:06,737 : INFO : PROGRESS: at 16.27% examples, 117851 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:13:07,760 : INFO : PROGRESS: at 16.32% examples, 117838 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:13:08,800 : INFO : PROGRESS: at 16.36% examples, 117821 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:13:09,821 : INFO : PROGRESS: at 16.41% examples, 117839 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:13:10,850 : INFO : PROGRESS: at 16.46% examples, 117853 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:13:11,950 : INFO : PROGRESS: at 16.51% examples, 117845 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:13:12,964 : INFO : PROGRESS: at 16.56% examples, 117836 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:13:13,986 : INFO : PROGRESS: at 16.61% examples, 117852 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:13:15,021 : INFO : PROGRESS: at 16.65% examples, 117810 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:13:16,042 : INFO : PROGRESS: at 16.69% examples, 117773 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:13:17,113 : INFO : PROGRESS: at 16.73% examples, 117693 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:13:18,165 : INFO : PROGRESS: at 16.77% examples, 117646 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:13:19,197 : INFO : PROGRESS: at 16.82% examples, 117633 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:13:20,269 : INFO : PROGRESS: at 16.86% examples, 117554 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:13:21,309 : INFO : PROGRESS: at 16.90% examples, 117512 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:13:22,423 : INFO : PROGRESS: at 16.94% examples, 117446 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:13:23,549 : INFO : PROGRESS: at 16.99% examples, 117405 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:13:24,568 : INFO : PROGRESS: at 17.03% examples, 117396 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:13:25,576 : INFO : PROGRESS: at 17.08% examples, 117392 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:13:26,604 : INFO : PROGRESS: at 17.13% examples, 117380 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:13:27,726 : INFO : PROGRESS: at 17.17% examples, 117339 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:13:28,808 : INFO : PROGRESS: at 17.22% examples, 117312 words/s, in_qsize 6, out_qsize 1
# 2017-12-06 09:13:29,846 : INFO : PROGRESS: at 17.27% examples, 117349 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:13:30,940 : INFO : PROGRESS: at 17.31% examples, 117292 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:13:31,964 : INFO : PROGRESS: at 17.37% examples, 117332 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:13:32,966 : INFO : PROGRESS: at 17.42% examples, 117354 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:13:34,198 : INFO : PROGRESS: at 17.47% examples, 117304 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:13:35,303 : INFO : PROGRESS: at 17.51% examples, 117269 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:13:36,311 : INFO : PROGRESS: at 17.56% examples, 117289 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:13:37,334 : INFO : PROGRESS: at 17.61% examples, 117279 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:13:38,337 : INFO : PROGRESS: at 17.66% examples, 117326 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:13:39,364 : INFO : PROGRESS: at 17.71% examples, 117314 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:13:40,461 : INFO : PROGRESS: at 17.76% examples, 117306 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:13:41,471 : INFO : PROGRESS: at 17.80% examples, 117301 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:13:42,537 : INFO : PROGRESS: at 17.85% examples, 117254 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:13:43,551 : INFO : PROGRESS: at 17.90% examples, 117273 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:13:44,615 : INFO : PROGRESS: at 17.95% examples, 117301 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:13:45,672 : INFO : PROGRESS: at 18.00% examples, 117332 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:13:46,722 : INFO : PROGRESS: at 18.05% examples, 117315 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:13:47,815 : INFO : PROGRESS: at 18.10% examples, 117336 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:13:48,823 : INFO : PROGRESS: at 18.15% examples, 117356 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:13:49,885 : INFO : PROGRESS: at 18.20% examples, 117360 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:13:50,999 : INFO : PROGRESS: at 18.25% examples, 117324 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:13:52,029 : INFO : PROGRESS: at 18.30% examples, 117314 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:13:53,087 : INFO : PROGRESS: at 18.34% examples, 117294 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:13:54,147 : INFO : PROGRESS: at 18.39% examples, 117324 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:13:55,205 : INFO : PROGRESS: at 18.44% examples, 117282 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:13:56,241 : INFO : PROGRESS: at 18.49% examples, 117295 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:13:57,277 : INFO : PROGRESS: at 18.53% examples, 117259 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:13:58,286 : INFO : PROGRESS: at 18.57% examples, 117231 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:13:59,372 : INFO : PROGRESS: at 18.62% examples, 117205 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:14:00,488 : INFO : PROGRESS: at 18.66% examples, 117169 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:14:01,508 : INFO : PROGRESS: at 18.70% examples, 117138 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:14:02,558 : INFO : PROGRESS: at 18.74% examples, 117075 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:14:03,636 : INFO : PROGRESS: at 18.79% examples, 117027 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:14:04,693 : INFO : PROGRESS: at 18.84% examples, 117031 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:14:05,767 : INFO : PROGRESS: at 18.88% examples, 116986 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:14:06,867 : INFO : PROGRESS: at 18.92% examples, 116957 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:14:07,926 : INFO : PROGRESS: at 18.97% examples, 116916 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:14:08,952 : INFO : PROGRESS: at 19.01% examples, 116908 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:14:09,980 : INFO : PROGRESS: at 19.05% examples, 116851 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:14:11,035 : INFO : PROGRESS: at 19.09% examples, 116812 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:14:12,110 : INFO : PROGRESS: at 19.14% examples, 116791 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:14:13,200 : INFO : PROGRESS: at 19.18% examples, 116765 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:14:14,264 : INFO : PROGRESS: at 19.23% examples, 116746 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:14:15,285 : INFO : PROGRESS: at 19.28% examples, 116740 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:14:16,440 : INFO : PROGRESS: at 19.33% examples, 116744 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:14:17,455 : INFO : PROGRESS: at 19.38% examples, 116739 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:14:18,466 : INFO : PROGRESS: at 19.41% examples, 116689 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:14:19,547 : INFO : PROGRESS: at 19.46% examples, 116667 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:14:20,551 : INFO : PROGRESS: at 19.50% examples, 116620 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:14:21,552 : INFO : PROGRESS: at 19.55% examples, 116642 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:14:22,566 : INFO : PROGRESS: at 19.59% examples, 116638 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:14:23,583 : INFO : PROGRESS: at 19.64% examples, 116657 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:14:24,594 : INFO : PROGRESS: at 19.68% examples, 116585 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:14:25,598 : INFO : PROGRESS: at 19.72% examples, 116585 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:14:26,635 : INFO : PROGRESS: at 19.77% examples, 116598 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:14:27,650 : INFO : PROGRESS: at 19.83% examples, 116640 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:14:28,792 : INFO : PROGRESS: at 19.88% examples, 116624 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:14:29,804 : INFO : PROGRESS: at 19.93% examples, 116665 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:14:30,952 : INFO : PROGRESS: at 19.98% examples, 116669 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:14:31,962 : INFO : PROGRESS: at 20.04% examples, 116696 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:14:33,046 : INFO : PROGRESS: at 20.09% examples, 116718 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:14:34,213 : INFO : PROGRESS: at 20.14% examples, 116695 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:14:35,412 : INFO : PROGRESS: at 20.20% examples, 116686 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:14:36,416 : INFO : PROGRESS: at 20.25% examples, 116730 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:14:37,592 : INFO : PROGRESS: at 20.30% examples, 116727 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:14:38,599 : INFO : PROGRESS: at 20.36% examples, 116770 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:14:39,615 : INFO : PROGRESS: at 20.40% examples, 116744 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:14:40,657 : INFO : PROGRESS: at 20.44% examples, 116711 words/s, in_qsize 6, out_qsize 1
# 2017-12-06 09:14:41,819 : INFO : PROGRESS: at 20.48% examples, 116647 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:14:42,894 : INFO : PROGRESS: at 20.52% examples, 116562 words/s, in_qsize 7, out_qsize 1
# 2017-12-06 09:14:44,027 : INFO : PROGRESS: at 20.56% examples, 116527 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:14:45,258 : INFO : PROGRESS: at 20.61% examples, 116468 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:14:46,408 : INFO : PROGRESS: at 20.66% examples, 116430 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:14:47,461 : INFO : PROGRESS: at 20.70% examples, 116416 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:14:48,543 : INFO : PROGRESS: at 20.75% examples, 116396 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:14:49,587 : INFO : PROGRESS: at 20.79% examples, 116386 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:14:50,681 : INFO : PROGRESS: at 20.84% examples, 116363 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:14:51,791 : INFO : PROGRESS: at 20.89% examples, 116335 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:14:52,797 : INFO : PROGRESS: at 20.93% examples, 116335 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:14:53,813 : INFO : PROGRESS: at 20.98% examples, 116332 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:14:54,930 : INFO : PROGRESS: at 21.02% examples, 116304 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:14:56,128 : INFO : PROGRESS: at 21.07% examples, 116276 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:14:57,157 : INFO : PROGRESS: at 21.12% examples, 116270 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:14:58,289 : INFO : PROGRESS: at 21.16% examples, 116238 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:14:59,334 : INFO : PROGRESS: at 21.21% examples, 116228 words/s, in_qsize 7, out_qsize 1
# 2017-12-06 09:15:00,352 : INFO : PROGRESS: at 21.25% examples, 116183 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:15:01,377 : INFO : PROGRESS: at 21.29% examples, 116136 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:15:02,427 : INFO : PROGRESS: at 21.33% examples, 116104 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:15:03,488 : INFO : PROGRESS: at 21.38% examples, 116111 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:15:04,535 : INFO : PROGRESS: at 21.43% examples, 116100 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:15:05,639 : INFO : PROGRESS: at 21.47% examples, 116055 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:15:06,737 : INFO : PROGRESS: at 21.51% examples, 116033 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:15:07,846 : INFO : PROGRESS: at 21.56% examples, 116007 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:15:08,982 : INFO : PROGRESS: at 21.61% examples, 115976 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:15:10,126 : INFO : PROGRESS: at 21.65% examples, 115942 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:15:11,314 : INFO : PROGRESS: at 21.70% examples, 115898 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:15:12,365 : INFO : PROGRESS: at 21.74% examples, 115888 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:15:13,418 : INFO : PROGRESS: at 21.78% examples, 115836 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:15:14,446 : INFO : PROGRESS: at 21.82% examples, 115811 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:15:15,447 : INFO : PROGRESS: at 21.86% examples, 115752 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:15:16,551 : INFO : PROGRESS: at 21.90% examples, 115729 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:15:17,566 : INFO : PROGRESS: at 21.94% examples, 115667 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:15:18,606 : INFO : PROGRESS: at 21.97% examples, 115599 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:15:19,742 : INFO : PROGRESS: at 22.01% examples, 115529 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:15:20,779 : INFO : PROGRESS: at 22.05% examples, 115483 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:15:22,025 : INFO : PROGRESS: at 22.09% examples, 115387 words/s, in_qsize 6, out_qsize 1
# 2017-12-06 09:15:23,055 : INFO : PROGRESS: at 22.13% examples, 115343 words/s, in_qsize 7, out_qsize 0
# ...
# 2017-12-06 09:40:01,307 : INFO : PROGRESS: at 92.36% examples, 119249 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:40:02,410 : INFO : PROGRESS: at 92.41% examples, 119251 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:40:03,438 : INFO : PROGRESS: at 92.46% examples, 119258 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:40:04,447 : INFO : PROGRESS: at 92.51% examples, 119261 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:40:05,470 : INFO : PROGRESS: at 92.56% examples, 119264 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:40:06,536 : INFO : PROGRESS: at 92.61% examples, 119258 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:40:07,622 : INFO : PROGRESS: at 92.66% examples, 119262 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:40:08,687 : INFO : PROGRESS: at 92.72% examples, 119266 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:40:09,827 : INFO : PROGRESS: at 92.77% examples, 119267 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:40:10,830 : INFO : PROGRESS: at 92.82% examples, 119275 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:40:11,984 : INFO : PROGRESS: at 92.88% examples, 119274 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:40:13,010 : INFO : PROGRESS: at 92.93% examples, 119281 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:40:14,098 : INFO : PROGRESS: at 92.98% examples, 119285 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:40:15,170 : INFO : PROGRESS: at 93.04% examples, 119289 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:40:16,219 : INFO : PROGRESS: at 93.09% examples, 119294 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:40:17,419 : INFO : PROGRESS: at 93.15% examples, 119291 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:40:18,456 : INFO : PROGRESS: at 93.19% examples, 119288 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:40:19,469 : INFO : PROGRESS: at 93.25% examples, 119295 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:40:20,479 : INFO : PROGRESS: at 93.30% examples, 119298 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:40:21,506 : INFO : PROGRESS: at 93.34% examples, 119300 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:40:22,512 : INFO : PROGRESS: at 93.39% examples, 119304 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:40:23,608 : INFO : PROGRESS: at 93.45% examples, 119311 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:40:24,612 : INFO : PROGRESS: at 93.51% examples, 119319 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:40:25,748 : INFO : PROGRESS: at 93.56% examples, 119320 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:40:26,937 : INFO : PROGRESS: at 93.62% examples, 119327 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:40:27,970 : INFO : PROGRESS: at 93.68% examples, 119338 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:40:29,005 : INFO : PROGRESS: at 93.73% examples, 119339 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:40:30,030 : INFO : PROGRESS: at 93.79% examples, 119351 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:40:31,048 : INFO : PROGRESS: at 93.84% examples, 119353 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:40:32,123 : INFO : PROGRESS: at 93.89% examples, 119362 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:40:33,145 : INFO : PROGRESS: at 93.94% examples, 119364 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:40:34,227 : INFO : PROGRESS: at 94.00% examples, 119373 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:40:35,265 : INFO : PROGRESS: at 94.05% examples, 119379 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:40:36,272 : INFO : PROGRESS: at 94.11% examples, 119387 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:40:37,288 : INFO : PROGRESS: at 94.16% examples, 119389 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:40:38,380 : INFO : PROGRESS: at 94.21% examples, 119397 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:40:39,382 : INFO : PROGRESS: at 94.26% examples, 119400 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:40:40,389 : INFO : PROGRESS: at 94.32% examples, 119408 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:40:41,468 : INFO : PROGRESS: at 94.37% examples, 119412 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:40:42,487 : INFO : PROGRESS: at 94.43% examples, 119424 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:40:43,613 : INFO : PROGRESS: at 94.48% examples, 119420 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:40:44,894 : INFO : PROGRESS: at 94.54% examples, 119421 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:40:46,142 : INFO : PROGRESS: at 94.60% examples, 119424 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:40:47,419 : INFO : PROGRESS: at 94.66% examples, 119426 words/s, in_qsize 7, out_qsize 1
# 2017-12-06 09:40:48,653 : INFO : PROGRESS: at 94.72% examples, 119430 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:40:49,885 : INFO : PROGRESS: at 94.79% examples, 119434 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:40:51,101 : INFO : PROGRESS: at 94.85% examples, 119439 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:40:52,102 : INFO : PROGRESS: at 94.90% examples, 119452 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:40:53,249 : INFO : PROGRESS: at 94.95% examples, 119447 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:40:54,277 : INFO : PROGRESS: at 95.01% examples, 119459 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:40:55,367 : INFO : PROGRESS: at 95.06% examples, 119457 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:40:56,367 : INFO : PROGRESS: at 95.11% examples, 119465 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:40:57,535 : INFO : PROGRESS: at 95.17% examples, 119463 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:40:58,545 : INFO : PROGRESS: at 95.22% examples, 119471 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:40:59,674 : INFO : PROGRESS: at 95.27% examples, 119467 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:41:00,688 : INFO : PROGRESS: at 95.32% examples, 119465 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:41:01,711 : INFO : PROGRESS: at 95.37% examples, 119471 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:41:02,827 : INFO : PROGRESS: at 95.43% examples, 119473 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:41:03,866 : INFO : PROGRESS: at 95.48% examples, 119479 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:41:05,017 : INFO : PROGRESS: at 95.53% examples, 119478 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:41:06,051 : INFO : PROGRESS: at 95.59% examples, 119489 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:41:07,147 : INFO : PROGRESS: at 95.64% examples, 119487 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:41:08,239 : INFO : PROGRESS: at 95.69% examples, 119489 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:41:09,266 : INFO : PROGRESS: at 95.74% examples, 119491 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:41:10,309 : INFO : PROGRESS: at 95.80% examples, 119497 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:41:11,437 : INFO : PROGRESS: at 95.85% examples, 119497 words/s, in_qsize 7, out_qsize 1
# 2017-12-06 09:41:12,463 : INFO : PROGRESS: at 95.90% examples, 119504 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:41:13,564 : INFO : PROGRESS: at 95.96% examples, 119506 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:41:14,591 : INFO : PROGRESS: at 96.01% examples, 119508 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:41:15,740 : INFO : PROGRESS: at 96.06% examples, 119502 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:41:16,757 : INFO : PROGRESS: at 96.11% examples, 119509 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:41:17,903 : INFO : PROGRESS: at 96.16% examples, 119509 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:41:18,920 : INFO : PROGRESS: at 96.22% examples, 119516 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:41:19,936 : INFO : PROGRESS: at 96.27% examples, 119518 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:41:21,000 : INFO : PROGRESS: at 96.32% examples, 119518 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:41:22,101 : INFO : PROGRESS: at 96.38% examples, 119524 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:41:23,157 : INFO : PROGRESS: at 96.43% examples, 119525 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:41:24,158 : INFO : PROGRESS: at 96.48% examples, 119528 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:41:25,207 : INFO : PROGRESS: at 96.53% examples, 119533 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:41:26,247 : INFO : PROGRESS: at 96.57% examples, 119529 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:41:27,301 : INFO : PROGRESS: at 96.62% examples, 119530 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:41:28,303 : INFO : PROGRESS: at 96.67% examples, 119533 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:41:29,357 : INFO : PROGRESS: at 96.73% examples, 119538 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:41:30,400 : INFO : PROGRESS: at 96.78% examples, 119539 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:41:31,455 : INFO : PROGRESS: at 96.83% examples, 119543 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:41:32,462 : INFO : PROGRESS: at 96.88% examples, 119546 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:41:33,469 : INFO : PROGRESS: at 96.93% examples, 119554 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:41:34,530 : INFO : PROGRESS: at 96.99% examples, 119559 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:41:35,565 : INFO : PROGRESS: at 97.04% examples, 119565 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:41:36,619 : INFO : PROGRESS: at 97.10% examples, 119569 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:41:37,630 : INFO : PROGRESS: at 97.15% examples, 119577 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:41:38,690 : INFO : PROGRESS: at 97.20% examples, 119577 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:41:39,716 : INFO : PROGRESS: at 97.25% examples, 119578 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:41:40,828 : INFO : PROGRESS: at 97.31% examples, 119584 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:41:41,888 : INFO : PROGRESS: at 97.36% examples, 119588 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:41:42,963 : INFO : PROGRESS: at 97.41% examples, 119592 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:41:43,982 : INFO : PROGRESS: at 97.46% examples, 119594 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:41:44,988 : INFO : PROGRESS: at 97.51% examples, 119587 words/s, in_qsize 6, out_qsize 1
# 2017-12-06 09:41:46,017 : INFO : PROGRESS: at 97.56% examples, 119593 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:41:47,070 : INFO : PROGRESS: at 97.61% examples, 119598 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:41:48,140 : INFO : PROGRESS: at 97.67% examples, 119601 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:41:49,171 : INFO : PROGRESS: at 97.72% examples, 119602 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:41:50,216 : INFO : PROGRESS: at 97.77% examples, 119607 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:41:51,353 : INFO : PROGRESS: at 97.82% examples, 119607 words/s, in_qsize 7, out_qsize 1
# 2017-12-06 09:41:52,365 : INFO : PROGRESS: at 97.88% examples, 119619 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:41:53,469 : INFO : PROGRESS: at 97.93% examples, 119616 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:41:54,604 : INFO : PROGRESS: at 97.99% examples, 119621 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:41:55,624 : INFO : PROGRESS: at 98.04% examples, 119623 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:41:56,633 : INFO : PROGRESS: at 98.09% examples, 119631 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:41:57,738 : INFO : PROGRESS: at 98.14% examples, 119628 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:41:58,750 : INFO : PROGRESS: at 98.20% examples, 119640 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:41:59,789 : INFO : PROGRESS: at 98.25% examples, 119636 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:42:00,818 : INFO : PROGRESS: at 98.30% examples, 119642 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:42:01,901 : INFO : PROGRESS: at 98.35% examples, 119641 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:42:02,976 : INFO : PROGRESS: at 98.39% examples, 119635 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:42:04,015 : INFO : PROGRESS: at 98.45% examples, 119641 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:42:05,089 : INFO : PROGRESS: at 98.50% examples, 119644 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:42:06,149 : INFO : PROGRESS: at 98.56% examples, 119649 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:42:07,207 : INFO : PROGRESS: at 98.61% examples, 119654 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:42:08,366 : INFO : PROGRESS: at 98.66% examples, 119652 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:42:09,391 : INFO : PROGRESS: at 98.72% examples, 119663 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:42:10,472 : INFO : PROGRESS: at 98.77% examples, 119662 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:42:11,472 : INFO : PROGRESS: at 98.82% examples, 119665 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:42:12,519 : INFO : PROGRESS: at 98.87% examples, 119670 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:42:13,591 : INFO : PROGRESS: at 98.93% examples, 119674 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:42:14,610 : INFO : PROGRESS: at 98.98% examples, 119680 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:42:15,644 : INFO : PROGRESS: at 99.03% examples, 119681 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:42:16,661 : INFO : PROGRESS: at 99.08% examples, 119684 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:42:17,842 : INFO : PROGRESS: at 99.14% examples, 119686 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:42:18,916 : INFO : PROGRESS: at 99.18% examples, 119680 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:42:19,927 : INFO : PROGRESS: at 99.23% examples, 119683 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:42:20,968 : INFO : PROGRESS: at 99.29% examples, 119688 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:42:22,020 : INFO : PROGRESS: at 99.34% examples, 119688 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:42:23,076 : INFO : PROGRESS: at 99.39% examples, 119693 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:42:24,165 : INFO : PROGRESS: at 99.44% examples, 119696 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:42:25,198 : INFO : PROGRESS: at 99.50% examples, 119702 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:42:26,256 : INFO : PROGRESS: at 99.55% examples, 119706 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:42:27,309 : INFO : PROGRESS: at 99.60% examples, 119706 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:42:28,334 : INFO : PROGRESS: at 99.65% examples, 119708 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:42:29,451 : INFO : PROGRESS: at 99.70% examples, 119709 words/s, in_qsize 8, out_qsize 0
# 2017-12-06 09:42:30,482 : INFO : PROGRESS: at 99.76% examples, 119715 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:42:31,562 : INFO : PROGRESS: at 99.81% examples, 119718 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:42:32,576 : INFO : PROGRESS: at 99.86% examples, 119721 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:42:33,579 : INFO : PROGRESS: at 99.91% examples, 119724 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:42:34,608 : INFO : PROGRESS: at 99.96% examples, 119721 words/s, in_qsize 7, out_qsize 0
# 2017-12-06 09:42:35,246 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2017-12-06 09:42:35,261 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2017-12-06 09:42:35,278 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2017-12-06 09:42:35,302 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2017-12-06 09:42:35,304 : INFO : training on 260965695 raw words (253700968 effective words) took 2119.0s, 119728 effective words/s
# 2017-12-06 09:42:35,305 : INFO : saving Word2Vec object under ../data/W2Vmodel/med250.model.bin, separately None
# 2017-12-06 09:42:35,306 : INFO : storing np array 'syn0' to ../data/W2Vmodel/med250.model.bin.wv.syn0.npy
# 2017-12-06 09:42:37,392 : INFO : not storing attribute syn0norm
# 2017-12-06 09:42:37,395 : INFO : storing np array 'syn1neg' to ../data/W2Vmodel/med250.model.bin.syn1neg.npy
# 2017-12-06 09:42:39,683 : INFO : not storing attribute cum_table
# 2017-12-06 09:42:40,380 : INFO : saved ../data/W2Vmodel/med250.model.bin

# %%
from gensim.models import word2vec
from gensim import models
import logging

logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)
model = models.Word2Vec.load('../data/W2Vmodel/med250.model.bin')

print("提供 3 種測試模式\n")
print("輸入一個詞，則去尋找前一百個該詞的相似詞")
print("輸入兩個詞，則去計算兩個詞的餘弦相似度")
print("輸入三個詞，進行類比推理")

while True:
    try:
        query = input()
        q_list = query.split()

        if len(q_list) == 1:
            print("相似詞前 30 排序")
            res = model.most_similar(q_list[0],topn = 30)
            for item in res:
                print(item[0]+","+str(item[1]))

        elif len(q_list) == 2:
            print("計算 Cosine 相似度")
            res = model.similarity(q_list[0],q_list[1])
            print(res)
        else:
            print("%s之於%s，如%s之於" % (q_list[0],q_list[2],q_list[1]))
            res = model.most_similar([q_list[0],q_list[1]], [q_list[2]], topn= 20)
            for item in res:
                print(item[0]+","+str(item[1]))
        print("----------------------------")
    except Exception as e:
        print(repr(e))
# Out:
# D:\anaconda\lib\site-packages\gensim\utils.py:860: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")
# 2017-12-06 17:16:39,569 : INFO : loading Word2Vec object from ../data/W2Vmodel/med250.model.bin
# 2017-12-06 17:16:40,335 : INFO : loading wv recursively from ../data/W2Vmodel/med250.model.bin.wv.* with mmap=None
# 2017-12-06 17:16:40,336 : INFO : loading syn0 from ../data/W2Vmodel/med250.model.bin.wv.syn0.npy with mmap=None
# 2017-12-06 17:16:42,125 : INFO : setting ignored attribute syn0norm to None
# 2017-12-06 17:16:42,127 : INFO : loading syn1neg from ../data/W2Vmodel/med250.model.bin.syn1neg.npy with mmap=None
# 2017-12-06 17:16:43,804 : INFO : setting ignored attribute cum_table to None
# 2017-12-06 17:16:43,806 : INFO : loaded ../data/W2Vmodel/med250.model.bin
# 提供 3 種測試模式
#
# 輸入一個詞，則去尋找前一百個該詞的相似詞
# 輸入兩個詞，則去計算兩個詞的餘弦相似度
# 輸入三個詞，進行類比推理
# 王品
# 2017-12-06 17:16:50,973 : INFO : precomputing L2-norms of word weight vectors
# 相似詞前 30 排序
# 集團,0.697043240070343
# 西堤,0.6718290448188782
# 夏慕尼,0.6534008383750916
# 旗下,0.6320666670799255
# 舒果,0.6083923578262329
# 藝奇,0.5940302610397339
# 過夏,0.5909715890884399
# 板屋,0.5855164527893066
# 義塔,0.579062819480896
# 齊下,0.5716928243637085
# 欣業,0.5658509731292725
# 慕尼新,0.5655799508094788
# 瓦城泰統,0.5598896741867065
# 慕尼,0.5589690208435059
# 西提,0.5582025647163391
# 饗賓,0.5560311079025269
# 比王品,0.5553627014160156
# 夏慕尼是,0.5502938628196716
# 葛瑞夫,0.5493490695953369
# 石二鍋,0.5465500354766846
# 夏慕尼新,0.5435199737548828
# 喜達屋,0.5381762981414795
# 泰統,0.5364643931388855
# 期下,0.5311990976333618
# 連淘,0.5289168357849121
# 歐鄉,0.5279397964477539
# 店鼎王,0.5270134210586548
# 特價網,0.5268563032150269
# 麻業,0.5248816013336182
# 吃陶,0.5186080932617188
# ----------------------------
# 王品 牛排 華碩
# 王品之於華碩，如牛排之於
# 丁骨,0.5405569672584534
# 肋眼,0.5258134603500366
# 菲力,0.5239616632461548
# 西堤,0.5017823576927185
# 沙朗,0.4914287328720093
# 牛排肉,0.4471342861652374
# 大丁骨,0.44572222232818604
# 肩沙朗,0.44360101222991943
# 莎朗,0.44347110390663147
# 牛肋眼,0.4407462179660797
# 夏慕尼,0.4353127181529999
# 盎司,0.43324628472328186
# 原塊,0.4313947558403015
# 牛排館,0.428668349981308
# 超霸,0.42733490467071533
# 沃克,0.4220677614212036
# 香蒜炙燒,0.4204903841018677
# 台塑,0.42007526755332947
# 羅西尼,0.4116891622543335
# 半釉,0.4105113744735718
# ----------------------------
# 王品 華碩 牛排
# 王品之於牛排，如華碩之於
# 瓦城泰統,0.6861477494239807
# 欣業,0.6619128584861755
# 連淘,0.6502498984336853
# 旗號,0.6361071467399597
# 麻業,0.6254125833511353
# 中途站,0.6153238415718079
# 一份思念,0.6135019063949585
# 樓開,0.6132844686508179
# 區的民眾,0.6112716794013977
# 集團,0.6104284524917603
# 密集區,0.6096376180648804
# 象屋,0.6074917912483215
# 站共構,0.6047073602676392
# 敦南館,0.6040728092193604
# 有家開,0.6040401458740234
# 店鼎王,0.6033828854560852
# 內展,0.6021095514297485
# 滴愛店,0.6015883684158325
# 城在,0.6006792187690735
# 則開,0.5995215773582458
# ----------------------------
# 西堤 瓦城 牛排
# 西堤之於牛排，如瓦城之於
# 大心新泰式麵食,0.5031013488769531
# 瓦城泰國料理,0.4951327443122864
# 王品,0.4920329451560974
# 藝奇,0.489319384098053
# 舒果,0.47531455755233765
# 紅舍,0.4745795726776123
# 板屋,0.4650813639163971
# 瓦城泰統,0.46100717782974243
# 泰多,0.4575090706348419
# 泰是,0.4565042555332184
# 吃瓦城,0.4472392797470093
# 跟瓦城,0.43513455986976624
# 蘭那泰式餐廳,0.4348295032978058
# 老新台菜,0.429526150226593
# 集團,0.4285562336444855
# 旗下,0.4268867075443268
# 老四川,0.4250296354293823
# 有瓦城,0.4227837324142456
# 欣葉小聚,0.4151429533958435
# 百有,0.41504788398742676
# ----------------------------
# 王品 老四川 牛排
# 王品之於牛排，如老四川之於
# 鼎王,0.5405834913253784
# 老鍋,0.4907851219177246
# 無老,0.4810432195663452
# 無老鍋,0.47491228580474854
# 輕井澤,0.47209256887435913
# 過鼎王,0.4577925205230713
# 麻辣王朝,0.457233190536499
# 集團,0.45483753085136414
# 舞舞舞,0.45256149768829346
# 舒果,0.45055559277534485
# 不輸鼎王,0.4499026834964752
# 吃鼎王,0.44643256068229675
# 老四川巴蜀麻辣燙,0.4455208480358124
# 鮮友,0.44488775730133057
# 華川,0.4398583173751831
# 石二鍋,0.4355660080909729
# 椒房殿,0.43141308426856995
# 臥龍,0.4307042360305786
# 麻辣火鍋,0.4304099380970001
# 三媽,0.4279803931713104
# ----------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# D:\anaconda\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     729             try:
# --> 730                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     731             except Exception:
#
# D:\anaconda\lib\site-packages\jupyter_client\session.py in recv(self, socket, mode, content, copy)
#     795         try:
# --> 796             msg_list = socket.recv_multipart(mode, copy=copy)
#     797         except zmq.ZMQError as e:
#
# D:\anaconda\lib\site-packages\zmq\sugar\socket.py in recv_multipart(self, flags, copy, track)
#     394         """
# --> 395         parts = [self.recv(flags, copy=copy, track=track)]
#     396         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv (zmq\backend\cython\socket.c:7683)()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv (zmq\backend\cython\socket.c:7460)()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy (zmq\backend\cython\socket.c:2344)()
#
# D:\anaconda\lib\site-packages\zmq\backend\cython\checkrc.pxd in zmq.backend.cython.checkrc._check_rc (zmq\backend\cython\socket.c:9621)()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-9fe1ae750617> in <module>()
#      13 while True:
#      14     try:
# ---> 15         query = input()
#      16         q_list = query.split()
#      17
#
# D:\anaconda\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#     703             self._parent_ident,
#     704             self._parent_header,
# --> 705             password=False,
#     706         )
#     707
#
# D:\anaconda\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     733             except KeyboardInterrupt:
#     734                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 735                 raise KeyboardInterrupt
#     736             else:
#     737                 break
#
# KeyboardInterrupt:

# %%
# import json
# with open('../data/bigtable.json') as f:
#     BigAnalyzeTable=json.load(f)

# %%
# pincutlist=[dien["contentcut"] for dien in BigAnalyzeTable]

# %%
# from myapi import TextMining

# %%
# from myapi import TextMining
# TM=TextMining.TextMining(pincutlist)
# wordCountlist=TM.getWordCountList()
# TF_IDFlist=TM.getTFIDF()
# Out:
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 3000
# 6000
# 9000
# 12000
# 15000
# 18000
# 21000
# 24000
# 27000
# 30000
# 33000
