# %%
import requests
from bs4 import BeautifulSoup as bs
import re
import json

# %%
# url="http://www.ipeen.com.tw/shop/1122770"
# res=requests.get(url)
# soup=bs(res.text,"lxml")

filename="38783.html"
with open("../data/html2/"+filename,encoding="utf8") as f:
    data=f.read()
soup=bs(data,"lxml")
try:
    commentPage=int(int(re.findall("會員分享文 \(([0-9]+)\)",soup.text)[0])/5)+1
except:
    commentPage=0

# %%
url="http://www.ipeen.com.tw/shop/"+filename.split(".")[0]
url

# %%
peenlist=[]
for i in range(1,commentPage+1):
    url2=url+'/comments?p='+str(i)
    res2=requests.get(url2)
    if res2.status_code == 200:
        soup2=bs(res2.text,'lxml')
        pagepeenlist=['http://www.ipeen.com.tw'+i['href'] for i in soup2.select("p.summary > a") if "checkin" not in i['href']]
        peenlist+=pagepeenlist
peenlist

# %%
res3=requests.get("http://www.ipeen.com.tw/comment/571542")
soup=bs(res3.text,"lxml")
soup.select_one("div.description").text.replace("\n","").replace("\xa0","").replace("\t","")

# %%
def getcommentlist(diendata):
    commentlist = []
    n=0
    for url in diendata["comments"]:
        n+=1
        if n%50==0:
            time.sleep(3)
        res = requests.get(url)
        print(url)
        try:
            if res.status_code == 200:
                soup = bs(res.text, 'lxml')
                res.close()
                title = soup.select("#comment > header > div > div > h1")[0].text.replace("\n", "").strip().replace(" ", "")
                comment = "".join([i.text for i in soup.select('div.description')]).replace("\u200b", "").replace("\u3000", "").replace("\n", "").replace("\xa0", "").replace("\t", "").replace(" ", "")
                date = soup.select('p.inline.date > span')[0].text
                click = int(soup.select("#comment > header > div > div > div.actions > span")[1].text.split("共 ")[1].split(" 次瀏覽")[0].replace(",", ""))
                try:
                    replys = [re.findall('.[0-9]{4}-[0-9]{2}-[0-9]{2} [0-9]{2}:[0-9]{2}:[0-9]{2}([^檢舉]*)',
                    reply.text.replace("\n", "").replace("\xa0", ""))[0] for reply in soup.select("#reply > li")]
                except:
                    replys = None
            commentdict = {}
            commentdict["url"] = url
            commentdict["name"] = diendata['name']
            commentdict["date"] = date
            commentdict["title"] = title
            commentdict["content"] = comment
            commentdict["click"] = click
            commentdict["message"] = replys
            commentlist.append(commentdict)
        except exception as e:
            print(e)

    return commentlist

# %%
getcommentlist(13)

# %% [markdown]
# # 取得評論

# %%
import os
import json
import time
import requests
from bs4 import BeautifulSoup as bs
import re




def getcommentlist(diendata):
    user_agent = {'User-agent': '''Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/62.0.3202.94 Safari/537.36'''}
    commentlist = []
    n=0
    for url in diendata["comments"]:
        n+=1
        if n%50==0:
            time.sleep(3)
        res = requests.get(url, headers = user_agent)
        print(url)
        try:
            if res.status_code == 200:
                soup = bs(res.text, 'lxml')
                res.close()
                title = soup.select("#comment > header > div > div > h1")[0].text.replace("\n", "").strip().replace(" ", "")
                comment = "".join([i.text for i in soup.select('div.description')]).replace("\u200b", "").replace("\u3000", "").replace("\n", "").replace("\xa0", "").replace("\t", "").replace(" ", "")
                date = soup.select('p.inline.date > span')[0].text
                click = int(soup.select("#comment > header > div > div > div.actions > span")[1].text.split("共 ")[1].split(" 次瀏覽")[0].replace(",", ""))
                try:
                    replys = [re.findall('.[0-9]{4}-[0-9]{2}-[0-9]{2} [0-9]{2}:[0-9]{2}:[0-9]{2}([^檢舉]*)',
                    reply.text.replace("\n", "").replace("\xa0", ""))[0] for reply in soup.select("#reply > li")]
                except:
                    replys = None
            commentdict = {}
            commentdict["url"] = url
            commentdict["name"] = diendata['name']
            commentdict["date"] = date
            commentdict["title"] = title
            commentdict["content"] = comment
            commentdict["click"] = click
            commentdict["message"] = replys
            commentlist.append(commentdict)
        except Exception as e:
            print(e)
            time.sleep(1800)

    return commentlist


if not os.path.exists('../data/diencomments'):
    os.makedirs('../data/diencomments')
with open("../data/diendataAddCommentUrl.json",encoding="utf8") as f:
    data=json.load(f)
for diendata in data:
    
    #有json檔案代表抓過不需再抓
    if not os.path.exists("../data/diencomments/%s.json"%diendata["id"]):
        
        diencomments=getcommentlist(diendata)
        with open("../data/diencomments/%s.json"%diendata["id"],"w") as f:
            json.dump(diencomments,f)
            print("%s已完成"%diendata["id"])
#             b=time.time()
            time.sleep(len(diendata["comments"])*0.18)
#             e=time.time()
#             print(e-b)
    else:
        pass
# Out:
# http://www.ipeen.com.tw/comment/761136
# http://www.ipeen.com.tw/comment/725068
# http://www.ipeen.com.tw/comment/719634
# http://www.ipeen.com.tw/comment/638424
# http://www.ipeen.com.tw/comment/618626
# http://www.ipeen.com.tw/comment/603930
# http://www.ipeen.com.tw/comment/589698
# http://www.ipeen.com.tw/comment/586728
# http://www.ipeen.com.tw/comment/493854
# http://www.ipeen.com.tw/comment/489694
# http://www.ipeen.com.tw/comment/471698
# http://www.ipeen.com.tw/comment/460052
# http://www.ipeen.com.tw/comment/459716
# http://www.ipeen.com.tw/comment/443576
# http://www.ipeen.com.tw/comment/399160
# http://www.ipeen.com.tw/comment/863922
# http://www.ipeen.com.tw/comment/691434
# http://www.ipeen.com.tw/comment/668848
# http://www.ipeen.com.tw/comment/636716
# http://www.ipeen.com.tw/comment/612444
# http://www.ipeen.com.tw/comment/608106
# http://www.ipeen.com.tw/comment/602504
# http://www.ipeen.com.tw/comment/590262
# http://www.ipeen.com.tw/comment/531350
# http://www.ipeen.com.tw/comment/513974
# http://www.ipeen.com.tw/comment/504554
# http://www.ipeen.com.tw/comment/499818
# http://www.ipeen.com.tw/comment/443604
# 953148已完成
# http://www.ipeen.com.tw/comment/668806
# 968256已完成
# http://www.ipeen.com.tw/comment/668810
# 953152已完成
# http://www.ipeen.com.tw/comment/671572
# 953154已完成
# http://www.ipeen.com.tw/comment/668874
# 953158已完成
# http://www.ipeen.com.tw/comment/397264
# http://www.ipeen.com.tw/comment/169395
# 95316已完成
# http://www.ipeen.com.tw/comment/668966
# 953166已完成
# http://www.ipeen.com.tw/comment/668922
# 953168已完成
# http://www.ipeen.com.tw/comment/333293
# http://www.ipeen.com.tw/comment/169398
# 95317已完成
# http://www.ipeen.com.tw/comment/668926
# 953170已完成
# http://www.ipeen.com.tw/comment/670788
# http://www.ipeen.com.tw/comment/677352
# 953178已完成
# http://www.ipeen.com.tw/comment/421680
# http://www.ipeen.com.tw/comment/176131
# http://www.ipeen.com.tw/comment/175554
# http://www.ipeen.com.tw/comment/172253
# http://www.ipeen.com.tw/comment/169397
# http://www.ipeen.com.tw/comment/624508
# http://www.ipeen.com.tw/comment/545840
# http://www.ipeen.com.tw/comment/399326
# http://www.ipeen.com.tw/comment/174331
# http://www.ipeen.com.tw/comment/170199
# 95318已完成
# http://www.ipeen.com.tw/comment/671670
# 953186已完成
# http://www.ipeen.com.tw/comment/689738
# http://www.ipeen.com.tw/comment/421834
# http://www.ipeen.com.tw/comment/281871
# http://www.ipeen.com.tw/comment/276301
# http://www.ipeen.com.tw/comment/263371
# http://www.ipeen.com.tw/comment/261977
# http://www.ipeen.com.tw/comment/260504
# http://www.ipeen.com.tw/comment/259662
# http://www.ipeen.com.tw/comment/259004
# http://www.ipeen.com.tw/comment/258735
# http://www.ipeen.com.tw/comment/256601
# http://www.ipeen.com.tw/comment/114065
# http://www.ipeen.com.tw/comment/80694
# http://www.ipeen.com.tw/comment/31753
# http://www.ipeen.com.tw/comment/22450
# http://www.ipeen.com.tw/comment/10032
# http://www.ipeen.com.tw/comment/768574
# http://www.ipeen.com.tw/comment/623380
# http://www.ipeen.com.tw/comment/487604
# http://www.ipeen.com.tw/comment/481972
# http://www.ipeen.com.tw/comment/297917
# http://www.ipeen.com.tw/comment/166868
# http://www.ipeen.com.tw/comment/148380
# http://www.ipeen.com.tw/comment/108375
# http://www.ipeen.com.tw/comment/87001
# http://www.ipeen.com.tw/comment/74837
# http://www.ipeen.com.tw/comment/63826
# http://www.ipeen.com.tw/comment/58416
# http://www.ipeen.com.tw/comment/50318
# 9532已完成
# http://www.ipeen.com.tw/comment/309515
# http://www.ipeen.com.tw/comment/193092
# http://www.ipeen.com.tw/comment/169414
# 95320已完成
# 953202已完成
# http://www.ipeen.com.tw/comment/169410
# 95321已完成
# http://www.ipeen.com.tw/comment/789268
# 953210已完成
# http://www.ipeen.com.tw/comment/671896
# 953214已完成
# http://www.ipeen.com.tw/comment/1037440
# http://www.ipeen.com.tw/comment/799860
# http://www.ipeen.com.tw/comment/671660
# http://www.ipeen.com.tw/comment/669020
# 953218已完成
# http://www.ipeen.com.tw/comment/169413
# 95322已完成
# http://www.ipeen.com.tw/comment/669382
# 953220已完成
# 953222已完成
# http://www.ipeen.com.tw/comment/669108
# 953224已完成
# http://www.ipeen.com.tw/comment/669044
# 953226已完成
# 953230已完成
# http://www.ipeen.com.tw/comment/669086
# 953232已完成
# 953242已完成
# 953244已完成
# 953246已完成
# http://www.ipeen.com.tw/comment/1099757
# http://www.ipeen.com.tw/comment/484520
# http://www.ipeen.com.tw/comment/1060412
# http://www.ipeen.com.tw/comment/518478
# http://www.ipeen.com.tw/comment/497276
# 95325已完成
# http://www.ipeen.com.tw/comment/669142
# 953250已完成
# 953252已完成
# http://www.ipeen.com.tw/comment/169438
# 95326已完成
# http://www.ipeen.com.tw/comment/1040774
# http://www.ipeen.com.tw/comment/1014416
# http://www.ipeen.com.tw/comment/845878
# http://www.ipeen.com.tw/comment/818264
# http://www.ipeen.com.tw/comment/669182
# http://www.ipeen.com.tw/comment/942024
# http://www.ipeen.com.tw/comment/941556
# http://www.ipeen.com.tw/comment/941540
# http://www.ipeen.com.tw/comment/692096
# 953262已完成
# http://www.ipeen.com.tw/comment/669174
# 953264已完成
# http://www.ipeen.com.tw/comment/687854
# 953266已完成
# 953268已完成
# http://www.ipeen.com.tw/comment/176946
# http://www.ipeen.com.tw/comment/169439
# 95327已完成
# http://www.ipeen.com.tw/comment/726330
# http://www.ipeen.com.tw/comment/1190732
# http://www.ipeen.com.tw/comment/835774
# 953270已完成
# http://www.ipeen.com.tw/comment/169443
# 95328已完成
# http://www.ipeen.com.tw/comment/669220
# 953288已完成
# http://www.ipeen.com.tw/comment/169449
# 95329已完成
# http://www.ipeen.com.tw/comment/701602
# http://www.ipeen.com.tw/comment/701266
# http://www.ipeen.com.tw/comment/683806
# 953294已完成
# 953296已完成
# http://www.ipeen.com.tw/comment/195484
# 95330已完成
# http://www.ipeen.com.tw/comment/811132
# http://www.ipeen.com.tw/comment/669240
# 953304已完成
# http://www.ipeen.com.tw/comment/669326
# 953306已完成
# 953308已完成
# http://www.ipeen.com.tw/comment/169450
# 95331已完成
# http://www.ipeen.com.tw/comment/987820
# http://www.ipeen.com.tw/comment/952430
# http://www.ipeen.com.tw/comment/669270
# 953310已完成
# 953318已完成
# http://www.ipeen.com.tw/comment/398452
# http://www.ipeen.com.tw/comment/173269
# http://www.ipeen.com.tw/comment/367466
# 95332已完成
# http://www.ipeen.com.tw/comment/677404
# http://www.ipeen.com.tw/comment/669334
# 953328已完成
# http://www.ipeen.com.tw/comment/686928
# 953332已完成
# http://www.ipeen.com.tw/comment/933914
# http://www.ipeen.com.tw/comment/669360
# 953334已完成
# 953336已完成
# http://www.ipeen.com.tw/comment/1223993
# http://www.ipeen.com.tw/comment/669376
# 953340已完成
# http://www.ipeen.com.tw/comment/1379681
# http://www.ipeen.com.tw/comment/768312
# http://www.ipeen.com.tw/comment/674160
# 953342已完成
# http://www.ipeen.com.tw/comment/669682
# 953344已完成
# http://www.ipeen.com.tw/comment/934578
# 95335已完成
# 953354已完成
# 953358已完成
# http://www.ipeen.com.tw/comment/917496
# http://www.ipeen.com.tw/comment/671224
# http://www.ipeen.com.tw/comment/469872
# http://www.ipeen.com.tw/comment/169461
# 95336已完成
# http://www.ipeen.com.tw/comment/392124
# http://www.ipeen.com.tw/comment/641680
# http://www.ipeen.com.tw/comment/512782
# http://www.ipeen.com.tw/comment/169463
# 95337已完成
# 95338已完成
# http://www.ipeen.com.tw/comment/169498
# 95339已完成
# http://www.ipeen.com.tw/comment/669558
# 953392已完成
# http://www.ipeen.com.tw/comment/898264
# http://www.ipeen.com.tw/comment/781102
# http://www.ipeen.com.tw/comment/735752
# http://www.ipeen.com.tw/comment/689946
# http://www.ipeen.com.tw/comment/679842
# http://www.ipeen.com.tw/comment/801208
# 953398已完成
# http://www.ipeen.com.tw/comment/115917
# http://www.ipeen.com.tw/comment/57534
# http://www.ipeen.com.tw/comment/33054
# http://www.ipeen.com.tw/comment/32476
# http://www.ipeen.com.tw/comment/12742
# http://www.ipeen.com.tw/comment/3931
# http://www.ipeen.com.tw/comment/6678
# 9534已完成
# 953404已完成
# http://www.ipeen.com.tw/comment/1488158
# http://www.ipeen.com.tw/comment/1058064
# http://www.ipeen.com.tw/comment/1039030
# http://www.ipeen.com.tw/comment/753652
# http://www.ipeen.com.tw/comment/671102
# http://www.ipeen.com.tw/comment/186411
# http://www.ipeen.com.tw/comment/810372
# http://www.ipeen.com.tw/comment/566326
# http://www.ipeen.com.tw/comment/530852
# 95342已完成
# 95344已完成
# http://www.ipeen.com.tw/comment/928210
# http://www.ipeen.com.tw/comment/923004
# http://www.ipeen.com.tw/comment/921068
# http://www.ipeen.com.tw/comment/921028
# http://www.ipeen.com.tw/comment/920564
# http://www.ipeen.com.tw/comment/920546
# http://www.ipeen.com.tw/comment/920530
# http://www.ipeen.com.tw/comment/918882
# http://www.ipeen.com.tw/comment/918630
# http://www.ipeen.com.tw/comment/918250
# http://www.ipeen.com.tw/comment/918188
# http://www.ipeen.com.tw/comment/918120
# http://www.ipeen.com.tw/comment/917784
# http://www.ipeen.com.tw/comment/917554
# http://www.ipeen.com.tw/comment/917396
# http://www.ipeen.com.tw/comment/917312
# http://www.ipeen.com.tw/comment/917190
# http://www.ipeen.com.tw/comment/917170
# http://www.ipeen.com.tw/comment/917122
# http://www.ipeen.com.tw/comment/917042
# http://www.ipeen.com.tw/comment/789180
# http://www.ipeen.com.tw/comment/678134
# 953440已完成
# http://www.ipeen.com.tw/comment/669540
# 953444已完成
# http://www.ipeen.com.tw/comment/877078
# http://www.ipeen.com.tw/comment/834010
# http://www.ipeen.com.tw/comment/787526
# http://www.ipeen.com.tw/comment/1026746
# 953446已完成
# http://www.ipeen.com.tw/comment/676048
# 953448已完成
# 95345已完成
# http://www.ipeen.com.tw/comment/669566
# 953450已完成
# http://www.ipeen.com.tw/comment/826908
# http://www.ipeen.com.tw/comment/673120
# 953454已完成
# http://www.ipeen.com.tw/comment/673638
# http://www.ipeen.com.tw/comment/673436
# 953456已完成
# http://www.ipeen.com.tw/comment/838138
# http://www.ipeen.com.tw/comment/800134
# http://www.ipeen.com.tw/comment/656056
# http://www.ipeen.com.tw/comment/584082
# http://www.ipeen.com.tw/comment/576808
# 95346已完成
# 953460已完成
# http://www.ipeen.com.tw/comment/1264400
# http://www.ipeen.com.tw/comment/916266
# http://www.ipeen.com.tw/comment/795940
# http://www.ipeen.com.tw/comment/669588
# 953464已完成
# http://www.ipeen.com.tw/comment/199054
# 95347已完成
# 953470已完成
# http://www.ipeen.com.tw/comment/758380
# http://www.ipeen.com.tw/comment/669608
# 953472已完成
# 953474已完成
# http://www.ipeen.com.tw/comment/669634
# http://www.ipeen.com.tw/comment/898876
# http://www.ipeen.com.tw/comment/807412
# http://www.ipeen.com.tw/comment/757976
# 953476已完成
# http://www.ipeen.com.tw/comment/599460
# http://www.ipeen.com.tw/comment/401362
# 95348已完成
# http://www.ipeen.com.tw/comment/759792
# http://www.ipeen.com.tw/comment/669692
# 953480已完成
# http://www.ipeen.com.tw/comment/669658
# 953482已完成
# http://www.ipeen.com.tw/comment/669644
# 953484已完成
# http://www.ipeen.com.tw/comment/679418
# http://www.ipeen.com.tw/comment/674200
# http://www.ipeen.com.tw/comment/673800
# http://www.ipeen.com.tw/comment/669648
# 953486已完成
# http://www.ipeen.com.tw/comment/669654
# http://www.ipeen.com.tw/comment/839308
# 953488已完成
# http://www.ipeen.com.tw/comment/1139204
# http://www.ipeen.com.tw/comment/833716
# http://www.ipeen.com.tw/comment/818730
# http://www.ipeen.com.tw/comment/716566
# http://www.ipeen.com.tw/comment/688964
# http://www.ipeen.com.tw/comment/571976
# http://www.ipeen.com.tw/comment/528398
# http://www.ipeen.com.tw/comment/491380
# http://www.ipeen.com.tw/comment/480902
# http://www.ipeen.com.tw/comment/435912
# http://www.ipeen.com.tw/comment/429012
# http://www.ipeen.com.tw/comment/427802
# http://www.ipeen.com.tw/comment/421334
# http://www.ipeen.com.tw/comment/414478
# http://www.ipeen.com.tw/comment/345667
# http://www.ipeen.com.tw/comment/317053
# http://www.ipeen.com.tw/comment/188640
# http://www.ipeen.com.tw/comment/176065
# http://www.ipeen.com.tw/comment/171173
# http://www.ipeen.com.tw/comment/169721
# http://www.ipeen.com.tw/comment/724492
# http://www.ipeen.com.tw/comment/613768
# http://www.ipeen.com.tw/comment/541406
# http://www.ipeen.com.tw/comment/521828
# http://www.ipeen.com.tw/comment/424592
# http://www.ipeen.com.tw/comment/310535
# http://www.ipeen.com.tw/comment/173258
# 95350已完成
# http://www.ipeen.com.tw/comment/669684
# 953506已完成
# http://www.ipeen.com.tw/comment/1271606
# http://www.ipeen.com.tw/comment/952956
# http://www.ipeen.com.tw/comment/819082
# http://www.ipeen.com.tw/comment/501120
# http://www.ipeen.com.tw/comment/487814
# http://www.ipeen.com.tw/comment/431098
# http://www.ipeen.com.tw/comment/392162
# http://www.ipeen.com.tw/comment/370761
# http://www.ipeen.com.tw/comment/313893
# http://www.ipeen.com.tw/comment/124609
# http://www.ipeen.com.tw/comment/80004
# http://www.ipeen.com.tw/comment/18921
# http://www.ipeen.com.tw/comment/1528715
# http://www.ipeen.com.tw/comment/1526666
# http://www.ipeen.com.tw/comment/1525985
# http://www.ipeen.com.tw/comment/1019576
# http://www.ipeen.com.tw/comment/970822
# http://www.ipeen.com.tw/comment/757134
# http://www.ipeen.com.tw/comment/395466
# http://www.ipeen.com.tw/comment/383995
# 953522已完成
# 953526已完成
# 953528已完成
# http://www.ipeen.com.tw/comment/329467
# 95353已完成
# http://www.ipeen.com.tw/comment/1416281
# http://www.ipeen.com.tw/comment/971712
# http://www.ipeen.com.tw/comment/965438
# http://www.ipeen.com.tw/comment/817446
# http://www.ipeen.com.tw/comment/732352
# http://www.ipeen.com.tw/comment/710938
# http://www.ipeen.com.tw/comment/865600
# 953530已完成
# http://www.ipeen.com.tw/comment/741062
# 953534已完成
# http://www.ipeen.com.tw/comment/1439873
# http://www.ipeen.com.tw/comment/1365743
# http://www.ipeen.com.tw/comment/1080725
# http://www.ipeen.com.tw/comment/920188
# http://www.ipeen.com.tw/comment/772800
# http://www.ipeen.com.tw/comment/763218
# http://www.ipeen.com.tw/comment/742864
# http://www.ipeen.com.tw/comment/734312
# http://www.ipeen.com.tw/comment/700738
# http://www.ipeen.com.tw/comment/685364
# http://www.ipeen.com.tw/comment/671720
# http://www.ipeen.com.tw/comment/669700
# http://www.ipeen.com.tw/comment/1472786
# http://www.ipeen.com.tw/comment/1337564
# http://www.ipeen.com.tw/comment/1330154
# http://www.ipeen.com.tw/comment/1177673
# http://www.ipeen.com.tw/comment/1106078
# http://www.ipeen.com.tw/comment/910862
# http://www.ipeen.com.tw/comment/750709
# http://www.ipeen.com.tw/comment/743794
# 953536已完成
# http://www.ipeen.com.tw/comment/736280
# http://www.ipeen.com.tw/comment/674156
# 953540已完成
# http://www.ipeen.com.tw/comment/669740
# 953542已完成
# http://www.ipeen.com.tw/comment/669944
# 953550已完成
# http://www.ipeen.com.tw/comment/669744
# 953552已完成
# http://www.ipeen.com.tw/comment/669748
# 953554已完成
# http://www.ipeen.com.tw/comment/1057684
# http://www.ipeen.com.tw/comment/1052740
# http://www.ipeen.com.tw/comment/1002736
# http://www.ipeen.com.tw/comment/995212
# http://www.ipeen.com.tw/comment/988662
# http://www.ipeen.com.tw/comment/974740
# http://www.ipeen.com.tw/comment/913110
# http://www.ipeen.com.tw/comment/912214
# http://www.ipeen.com.tw/comment/906350
# http://www.ipeen.com.tw/comment/905716
# http://www.ipeen.com.tw/comment/810352
# http://www.ipeen.com.tw/comment/784222
# http://www.ipeen.com.tw/comment/768596
# http://www.ipeen.com.tw/comment/750100
# http://www.ipeen.com.tw/comment/738128
# http://www.ipeen.com.tw/comment/730428
# http://www.ipeen.com.tw/comment/729340
# http://www.ipeen.com.tw/comment/711652
# http://www.ipeen.com.tw/comment/706622
# http://www.ipeen.com.tw/comment/689640
# http://www.ipeen.com.tw/comment/684074
# http://www.ipeen.com.tw/comment/675446
# http://www.ipeen.com.tw/comment/670266
# http://www.ipeen.com.tw/comment/670260
# http://www.ipeen.com.tw/comment/670250
# http://www.ipeen.com.tw/comment/670112
# http://www.ipeen.com.tw/comment/670106
# http://www.ipeen.com.tw/comment/669766
# http://www.ipeen.com.tw/comment/1126241
# http://www.ipeen.com.tw/comment/819476
# http://www.ipeen.com.tw/comment/745634
# http://www.ipeen.com.tw/comment/732696
# http://www.ipeen.com.tw/comment/726944
# http://www.ipeen.com.tw/comment/725906
# http://www.ipeen.com.tw/comment/717602
# http://www.ipeen.com.tw/comment/713320
# http://www.ipeen.com.tw/comment/691308
# http://www.ipeen.com.tw/comment/671752
# 953556已完成
# http://www.ipeen.com.tw/comment/669774
# 953558已完成
# http://www.ipeen.com.tw/comment/169520
# 95356已完成
# http://www.ipeen.com.tw/comment/672468
# 953560已完成
# http://www.ipeen.com.tw/comment/669782
# 953562已完成
# http://www.ipeen.com.tw/comment/669790
# 953564已完成
# http://www.ipeen.com.tw/comment/669794
# 953566已完成
# http://www.ipeen.com.tw/comment/669808
# 953568已完成
# http://www.ipeen.com.tw/comment/169613
# 95357已完成
# http://www.ipeen.com.tw/comment/1042200
# http://www.ipeen.com.tw/comment/1031766
# http://www.ipeen.com.tw/comment/924326
# http://www.ipeen.com.tw/comment/924310
# http://www.ipeen.com.tw/comment/885240
# http://www.ipeen.com.tw/comment/881846
# http://www.ipeen.com.tw/comment/877612
# http://www.ipeen.com.tw/comment/870336
# http://www.ipeen.com.tw/comment/843336
# http://www.ipeen.com.tw/comment/839324
# http://www.ipeen.com.tw/comment/838966
# http://www.ipeen.com.tw/comment/834942
# http://www.ipeen.com.tw/comment/831934
# http://www.ipeen.com.tw/comment/829200
# http://www.ipeen.com.tw/comment/829068
# http://www.ipeen.com.tw/comment/826314
# http://www.ipeen.com.tw/comment/817922
# http://www.ipeen.com.tw/comment/798658
# http://www.ipeen.com.tw/comment/746946
# http://www.ipeen.com.tw/comment/713344
# http://www.ipeen.com.tw/comment/690858
# http://www.ipeen.com.tw/comment/669812
# http://www.ipeen.com.tw/comment/534710
# http://www.ipeen.com.tw/comment/1190852
# http://www.ipeen.com.tw/comment/841682
# http://www.ipeen.com.tw/comment/769058
# http://www.ipeen.com.tw/comment/494106
# 953572已完成
# 953574已完成
# http://www.ipeen.com.tw/comment/169969
# http://www.ipeen.com.tw/comment/416568
# 95358已完成
# http://www.ipeen.com.tw/comment/670172
# http://www.ipeen.com.tw/comment/658786
# 953580已完成
# http://www.ipeen.com.tw/comment/670766
# 953582已完成
# 953586已完成
# http://www.ipeen.com.tw/comment/669928
# 953588已完成
# 953590已完成
# http://www.ipeen.com.tw/comment/950052
# http://www.ipeen.com.tw/comment/942782
# http://www.ipeen.com.tw/comment/940402
# http://www.ipeen.com.tw/comment/701048
# http://www.ipeen.com.tw/comment/693198
# http://www.ipeen.com.tw/comment/684178
# http://www.ipeen.com.tw/comment/669956
# http://www.ipeen.com.tw/comment/1001694
# http://www.ipeen.com.tw/comment/937066
# http://www.ipeen.com.tw/comment/935106
# 953594已完成
# http://www.ipeen.com.tw/comment/673152
# 953596已完成
# http://www.ipeen.com.tw/comment/791270
# http://www.ipeen.com.tw/comment/787614
# http://www.ipeen.com.tw/comment/669968
# 953598已完成
# http://www.ipeen.com.tw/comment/255575
# http://www.ipeen.com.tw/comment/99828
# http://www.ipeen.com.tw/comment/27069
# http://www.ipeen.com.tw/comment/18147
# http://www.ipeen.com.tw/comment/14384
# http://www.ipeen.com.tw/comment/3560
# http://www.ipeen.com.tw/comment/1825
# http://www.ipeen.com.tw/comment/77102
# http://www.ipeen.com.tw/comment/12250
# http://www.ipeen.com.tw/comment/9249
# http://www.ipeen.com.tw/comment/3724
# 9536已完成
# http://www.ipeen.com.tw/comment/169533
# 95360已完成
# http://www.ipeen.com.tw/comment/694234
# http://www.ipeen.com.tw/comment/671968
# 953600已完成
# 953602已完成
# 953604已完成
# http://www.ipeen.com.tw/comment/685052
# 953616已完成
# http://www.ipeen.com.tw/comment/852408
# http://www.ipeen.com.tw/comment/322719
# http://www.ipeen.com.tw/comment/601048
# http://www.ipeen.com.tw/comment/201283
# http://www.ipeen.com.tw/comment/195559
# http://www.ipeen.com.tw/comment/183790
# 95362已完成
# http://www.ipeen.com.tw/comment/670026
# 953622已完成
# http://www.ipeen.com.tw/comment/670050
# 953624已完成
# http://www.ipeen.com.tw/comment/670372
# 953626已完成
# http://www.ipeen.com.tw/comment/740194
# http://www.ipeen.com.tw/comment/670082
# 953628已完成
# http://www.ipeen.com.tw/comment/297435
# http://www.ipeen.com.tw/comment/169586
# 95363已完成
# 953634已完成
# http://www.ipeen.com.tw/comment/670156
# 953636已完成
# http://www.ipeen.com.tw/comment/675482
# http://www.ipeen.com.tw/comment/670542
# 959574已完成
# http://www.ipeen.com.tw/comment/170239
# 95364已完成
# http://www.ipeen.com.tw/comment/670852
# 953640已完成
# http://www.ipeen.com.tw/comment/670150
# 953642已完成
# http://www.ipeen.com.tw/comment/1315421
# http://www.ipeen.com.tw/comment/659296
# http://www.ipeen.com.tw/comment/552298
# http://www.ipeen.com.tw/comment/58307
# http://www.ipeen.com.tw/comment/46882
# http://www.ipeen.com.tw/comment/46439
# http://www.ipeen.com.tw/comment/32078
# http://www.ipeen.com.tw/comment/1331915
# http://www.ipeen.com.tw/comment/667656
# http://www.ipeen.com.tw/comment/320705
# 953644已完成
# http://www.ipeen.com.tw/comment/823138
# http://www.ipeen.com.tw/comment/670110
# http://www.ipeen.com.tw/comment/1314482
# http://www.ipeen.com.tw/comment/969980
# http://www.ipeen.com.tw/comment/942784
# http://www.ipeen.com.tw/comment/699038
# 953646已完成
# http://www.ipeen.com.tw/comment/193496
# http://www.ipeen.com.tw/comment/173017
# http://www.ipeen.com.tw/comment/169545
# 95365已完成
# http://www.ipeen.com.tw/comment/1311605
# http://www.ipeen.com.tw/comment/1128080
# http://www.ipeen.com.tw/comment/1094888
# http://www.ipeen.com.tw/comment/1094609
# http://www.ipeen.com.tw/comment/852808
# 953650已完成
# http://www.ipeen.com.tw/comment/670176
# 953652已完成
# http://www.ipeen.com.tw/comment/942788
# 953654已完成
# http://www.ipeen.com.tw/comment/169544
# 95366已完成
# 953660已完成
# http://www.ipeen.com.tw/comment/670272
# 953664已完成
# http://www.ipeen.com.tw/comment/689556
# 953670已完成
# http://www.ipeen.com.tw/comment/169552
# 95368已完成
# http://www.ipeen.com.tw/comment/933248
# http://www.ipeen.com.tw/comment/1019298
# http://www.ipeen.com.tw/comment/964460
# http://www.ipeen.com.tw/comment/843578
# http://www.ipeen.com.tw/comment/608334
# 953696已完成
# 953700已完成
# http://www.ipeen.com.tw/comment/706150
# http://www.ipeen.com.tw/comment/670346
# http://www.ipeen.com.tw/comment/821670
# 953708已完成
# http://www.ipeen.com.tw/comment/169569
# 95371已完成
# 953726已完成
# http://www.ipeen.com.tw/comment/401216
# http://www.ipeen.com.tw/comment/169579
# 95374已完成
# http://www.ipeen.com.tw/comment/1153991
# http://www.ipeen.com.tw/comment/836910
# http://www.ipeen.com.tw/comment/514442
# http://www.ipeen.com.tw/comment/356748
# http://www.ipeen.com.tw/comment/342073
# http://www.ipeen.com.tw/comment/317815
# http://www.ipeen.com.tw/comment/169775
# http://www.ipeen.com.tw/comment/865704
# http://www.ipeen.com.tw/comment/626682
# http://www.ipeen.com.tw/comment/556470
# 95375已完成
# http://www.ipeen.com.tw/comment/671522
# 953764已完成
# http://www.ipeen.com.tw/comment/670322
# 953766已完成
# http://www.ipeen.com.tw/comment/670334
# 953768已完成
# http://www.ipeen.com.tw/comment/173174
# http://www.ipeen.com.tw/comment/172023
# http://www.ipeen.com.tw/comment/171906
# http://www.ipeen.com.tw/comment/171374
# http://www.ipeen.com.tw/comment/170825
# http://www.ipeen.com.tw/comment/170735
# http://www.ipeen.com.tw/comment/170340
# http://www.ipeen.com.tw/comment/169865
# http://www.ipeen.com.tw/comment/170504
# 95377已完成
# http://www.ipeen.com.tw/comment/1515602
# http://www.ipeen.com.tw/comment/1340321
# http://www.ipeen.com.tw/comment/1059014
# http://www.ipeen.com.tw/comment/1446395
# http://www.ipeen.com.tw/comment/670342
# 953776已完成
# http://www.ipeen.com.tw/comment/692356
# http://www.ipeen.com.tw/comment/678090
# http://www.ipeen.com.tw/comment/670348
# http://www.ipeen.com.tw/comment/1383938
# http://www.ipeen.com.tw/comment/670528
# 953778已完成
# http://www.ipeen.com.tw/comment/169596
# 95378已完成
# http://www.ipeen.com.tw/comment/670354
# 953780已完成
# http://www.ipeen.com.tw/comment/670392
# 953784已完成
# http://www.ipeen.com.tw/comment/169603
# http://www.ipeen.com.tw/comment/170507
# 95379已完成
# http://www.ipeen.com.tw/comment/670394
# 953792已完成
# http://www.ipeen.com.tw/comment/670418
# 953798已完成
# 9538已完成
# http://www.ipeen.com.tw/comment/351563
# http://www.ipeen.com.tw/comment/169602
# http://www.ipeen.com.tw/comment/712654
# 95380已完成
# http://www.ipeen.com.tw/comment/1149989
# http://www.ipeen.com.tw/comment/707640
# 953800已完成
# 953804已完成
# http://www.ipeen.com.tw/comment/971318
# http://www.ipeen.com.tw/comment/861698
# http://www.ipeen.com.tw/comment/837918
# http://www.ipeen.com.tw/comment/828120
# http://www.ipeen.com.tw/comment/818930
# http://www.ipeen.com.tw/comment/811594
# http://www.ipeen.com.tw/comment/688550
# http://www.ipeen.com.tw/comment/1056192
# http://www.ipeen.com.tw/comment/730788
# http://www.ipeen.com.tw/comment/708828
# 953806已完成
# 953808已完成
# http://www.ipeen.com.tw/comment/169745
# 95381已完成
# http://www.ipeen.com.tw/comment/767524
# http://www.ipeen.com.tw/comment/727398
# http://www.ipeen.com.tw/comment/726580
# http://www.ipeen.com.tw/comment/721660
# http://www.ipeen.com.tw/comment/721562
# http://www.ipeen.com.tw/comment/721094
# http://www.ipeen.com.tw/comment/719064
# http://www.ipeen.com.tw/comment/718328
# http://www.ipeen.com.tw/comment/717728
# http://www.ipeen.com.tw/comment/716876
# http://www.ipeen.com.tw/comment/714456
# http://www.ipeen.com.tw/comment/714104
# http://www.ipeen.com.tw/comment/712914
# http://www.ipeen.com.tw/comment/712908
# http://www.ipeen.com.tw/comment/711242
# http://www.ipeen.com.tw/comment/710274
# http://www.ipeen.com.tw/comment/710186
# http://www.ipeen.com.tw/comment/709976
# http://www.ipeen.com.tw/comment/729160
# http://www.ipeen.com.tw/comment/715152
# 953810已完成
# 953816已完成
# 95382已完成
# http://www.ipeen.com.tw/comment/713216
# http://www.ipeen.com.tw/comment/670546
# http://www.ipeen.com.tw/comment/947388
# http://www.ipeen.com.tw/comment/753246
# 953820已完成
# http://www.ipeen.com.tw/comment/985260
# http://www.ipeen.com.tw/comment/903742
# http://www.ipeen.com.tw/comment/809206
# http://www.ipeen.com.tw/comment/670524
# http://www.ipeen.com.tw/comment/1173272
# http://www.ipeen.com.tw/comment/706462
# http://www.ipeen.com.tw/comment/694434
# 953822已完成
# http://www.ipeen.com.tw/comment/804744
# http://www.ipeen.com.tw/comment/804350
# http://www.ipeen.com.tw/comment/801498
# http://www.ipeen.com.tw/comment/799506
# http://www.ipeen.com.tw/comment/796580
# http://www.ipeen.com.tw/comment/796354
# http://www.ipeen.com.tw/comment/795974
# http://www.ipeen.com.tw/comment/795778
# http://www.ipeen.com.tw/comment/795120
# http://www.ipeen.com.tw/comment/794086
# http://www.ipeen.com.tw/comment/793792
# http://www.ipeen.com.tw/comment/793754
# http://www.ipeen.com.tw/comment/793622
# http://www.ipeen.com.tw/comment/792188
# http://www.ipeen.com.tw/comment/791804
# http://www.ipeen.com.tw/comment/750206
# http://www.ipeen.com.tw/comment/748266
# http://www.ipeen.com.tw/comment/746296
# http://www.ipeen.com.tw/comment/744382
# http://www.ipeen.com.tw/comment/743510
# http://www.ipeen.com.tw/comment/742548
# http://www.ipeen.com.tw/comment/740038
# http://www.ipeen.com.tw/comment/739908
# http://www.ipeen.com.tw/comment/739898
# http://www.ipeen.com.tw/comment/739632
# http://www.ipeen.com.tw/comment/739358
# http://www.ipeen.com.tw/comment/739014
# http://www.ipeen.com.tw/comment/738650
# http://www.ipeen.com.tw/comment/738518
# http://www.ipeen.com.tw/comment/738412
# http://www.ipeen.com.tw/comment/738286
# http://www.ipeen.com.tw/comment/737974
# http://www.ipeen.com.tw/comment/737878
# http://www.ipeen.com.tw/comment/737500
# http://www.ipeen.com.tw/comment/737490
# http://www.ipeen.com.tw/comment/715208
# http://www.ipeen.com.tw/comment/706716
# http://www.ipeen.com.tw/comment/704050
# http://www.ipeen.com.tw/comment/703828
# http://www.ipeen.com.tw/comment/703454
# http://www.ipeen.com.tw/comment/702890
# http://www.ipeen.com.tw/comment/702556
# http://www.ipeen.com.tw/comment/702336
# http://www.ipeen.com.tw/comment/701704
# http://www.ipeen.com.tw/comment/701170
# http://www.ipeen.com.tw/comment/701146
# http://www.ipeen.com.tw/comment/699434
# http://www.ipeen.com.tw/comment/699270
# http://www.ipeen.com.tw/comment/698994
# http://www.ipeen.com.tw/comment/698840
# http://www.ipeen.com.tw/comment/698758
# http://www.ipeen.com.tw/comment/698490
# http://www.ipeen.com.tw/comment/698478
# http://www.ipeen.com.tw/comment/698362
# http://www.ipeen.com.tw/comment/698250
# http://www.ipeen.com.tw/comment/698230
# http://www.ipeen.com.tw/comment/693954
# http://www.ipeen.com.tw/comment/691784
# http://www.ipeen.com.tw/comment/690016
# http://www.ipeen.com.tw/comment/688502
# http://www.ipeen.com.tw/comment/688128
# http://www.ipeen.com.tw/comment/687650
# http://www.ipeen.com.tw/comment/687548
# http://www.ipeen.com.tw/comment/686674
# http://www.ipeen.com.tw/comment/686510
# http://www.ipeen.com.tw/comment/686210
# http://www.ipeen.com.tw/comment/685986
# http://www.ipeen.com.tw/comment/685856
# http://www.ipeen.com.tw/comment/683758
# http://www.ipeen.com.tw/comment/683724
# http://www.ipeen.com.tw/comment/683380
# http://www.ipeen.com.tw/comment/683168
# http://www.ipeen.com.tw/comment/683104
# http://www.ipeen.com.tw/comment/682610
# http://www.ipeen.com.tw/comment/681940
# 953824已完成
# http://www.ipeen.com.tw/comment/670568
# 953826已完成
# http://www.ipeen.com.tw/comment/1208807
# http://www.ipeen.com.tw/comment/1197623
# http://www.ipeen.com.tw/comment/1134071
# http://www.ipeen.com.tw/comment/1128437
# http://www.ipeen.com.tw/comment/1112549
# http://www.ipeen.com.tw/comment/1064774
# http://www.ipeen.com.tw/comment/907986
# http://www.ipeen.com.tw/comment/886656
# 953836已完成
# http://www.ipeen.com.tw/comment/670564
# 953838已完成
# http://www.ipeen.com.tw/comment/1050586
# http://www.ipeen.com.tw/comment/996606
# http://www.ipeen.com.tw/comment/670552
# 953840已完成
# http://www.ipeen.com.tw/comment/804892
# http://www.ipeen.com.tw/comment/795428
# http://www.ipeen.com.tw/comment/1016400
# 953844已完成
# 953846已完成
# http://www.ipeen.com.tw/comment/670592
# 953852已完成
# http://www.ipeen.com.tw/comment/909296
# http://www.ipeen.com.tw/comment/670680
# 953854已完成
# 953856已完成
# http://www.ipeen.com.tw/comment/670600
# 953858已完成
# http://www.ipeen.com.tw/comment/671586
# 953860已完成
# http://www.ipeen.com.tw/comment/706560
# http://www.ipeen.com.tw/comment/701964
# http://www.ipeen.com.tw/comment/701724
# http://www.ipeen.com.tw/comment/701274
# http://www.ipeen.com.tw/comment/701038
# http://www.ipeen.com.tw/comment/700436
# http://www.ipeen.com.tw/comment/700088
# http://www.ipeen.com.tw/comment/699274
# http://www.ipeen.com.tw/comment/699226
# http://www.ipeen.com.tw/comment/698884
# http://www.ipeen.com.tw/comment/676828
# http://www.ipeen.com.tw/comment/674920
# 953864已完成
# http://www.ipeen.com.tw/comment/1408007
# http://www.ipeen.com.tw/comment/1219106
# http://www.ipeen.com.tw/comment/1207328
# http://www.ipeen.com.tw/comment/1074311
# http://www.ipeen.com.tw/comment/1041220
# http://www.ipeen.com.tw/comment/1029424
# http://www.ipeen.com.tw/comment/1025332
# http://www.ipeen.com.tw/comment/1019014
# http://www.ipeen.com.tw/comment/967360
# http://www.ipeen.com.tw/comment/956538
# http://www.ipeen.com.tw/comment/949268
# http://www.ipeen.com.tw/comment/908006
# http://www.ipeen.com.tw/comment/877668
# http://www.ipeen.com.tw/comment/855512
# http://www.ipeen.com.tw/comment/847344
# http://www.ipeen.com.tw/comment/829856
# http://www.ipeen.com.tw/comment/826038
# http://www.ipeen.com.tw/comment/798678
# http://www.ipeen.com.tw/comment/795228
# http://www.ipeen.com.tw/comment/794714
# http://www.ipeen.com.tw/comment/791082
# http://www.ipeen.com.tw/comment/782456
# http://www.ipeen.com.tw/comment/779064
# http://www.ipeen.com.tw/comment/757056
# http://www.ipeen.com.tw/comment/754578
# http://www.ipeen.com.tw/comment/750691
# http://www.ipeen.com.tw/comment/750150
# http://www.ipeen.com.tw/comment/746894
# http://www.ipeen.com.tw/comment/746890
# http://www.ipeen.com.tw/comment/746468
# http://www.ipeen.com.tw/comment/743198
# http://www.ipeen.com.tw/comment/741454
# http://www.ipeen.com.tw/comment/738700
# http://www.ipeen.com.tw/comment/735894
# http://www.ipeen.com.tw/comment/732874
# http://www.ipeen.com.tw/comment/731538
# http://www.ipeen.com.tw/comment/725858
# http://www.ipeen.com.tw/comment/725604
# http://www.ipeen.com.tw/comment/724474
# http://www.ipeen.com.tw/comment/723838
# http://www.ipeen.com.tw/comment/718064
# http://www.ipeen.com.tw/comment/717188
# http://www.ipeen.com.tw/comment/1447286
# http://www.ipeen.com.tw/comment/1248605
# http://www.ipeen.com.tw/comment/1232801
# http://www.ipeen.com.tw/comment/1222634
# http://www.ipeen.com.tw/comment/1211483
# http://www.ipeen.com.tw/comment/1046970
# http://www.ipeen.com.tw/comment/1016694
# http://www.ipeen.com.tw/comment/867076
# http://www.ipeen.com.tw/comment/781022
# http://www.ipeen.com.tw/comment/722878
# http://www.ipeen.com.tw/comment/721034
# 953866已完成
# 95387已完成
# http://www.ipeen.com.tw/comment/679614
# 953878已完成
# http://www.ipeen.com.tw/comment/795544
# http://www.ipeen.com.tw/comment/794836
# http://www.ipeen.com.tw/comment/714676
# http://www.ipeen.com.tw/comment/713098
# http://www.ipeen.com.tw/comment/684168
# http://www.ipeen.com.tw/comment/677932
# http://www.ipeen.com.tw/comment/771184
# 953880已完成
# http://www.ipeen.com.tw/comment/702568
# http://www.ipeen.com.tw/comment/678588
# 953882已完成
# 953884已完成
# 953888已完成
# http://www.ipeen.com.tw/comment/520694
# http://www.ipeen.com.tw/comment/386225
# http://www.ipeen.com.tw/comment/383363
# http://www.ipeen.com.tw/comment/376047
# http://www.ipeen.com.tw/comment/332465
# http://www.ipeen.com.tw/comment/629314
# http://www.ipeen.com.tw/comment/388567
# 95389已完成
# http://www.ipeen.com.tw/comment/670684
# 953890已完成
# http://www.ipeen.com.tw/comment/671528
# 953892已完成
# http://www.ipeen.com.tw/comment/670690
# 953894已完成
# http://www.ipeen.com.tw/comment/1172315
# http://www.ipeen.com.tw/comment/950674
# http://www.ipeen.com.tw/comment/937794
# http://www.ipeen.com.tw/comment/821048
# http://www.ipeen.com.tw/comment/1281845
# http://www.ipeen.com.tw/comment/1055448
# http://www.ipeen.com.tw/comment/1028432
# http://www.ipeen.com.tw/comment/838908
# http://www.ipeen.com.tw/comment/697378
# http://www.ipeen.com.tw/comment/691874
# 953896已完成
# http://www.ipeen.com.tw/comment/670700
# 953898已完成
# http://www.ipeen.com.tw/comment/56558
# http://www.ipeen.com.tw/comment/412506
# http://www.ipeen.com.tw/comment/168156
# http://www.ipeen.com.tw/comment/146178
# http://www.ipeen.com.tw/comment/131481
# http://www.ipeen.com.tw/comment/93110
# 9539已完成
# 95390已完成
# http://www.ipeen.com.tw/comment/670702
# 953900已完成
# http://www.ipeen.com.tw/comment/670710
# 953908已完成
# http://www.ipeen.com.tw/comment/679648
# 953914已完成
# http://www.ipeen.com.tw/comment/670724
# 953916已完成
# http://www.ipeen.com.tw/comment/200278
# 95392已完成
# http://www.ipeen.com.tw/comment/670760
# 953920已完成
# http://www.ipeen.com.tw/comment/169656
# 95393已完成
# http://www.ipeen.com.tw/comment/670740
# 953932已完成
# http://www.ipeen.com.tw/comment/671144
# 953934已完成
# http://www.ipeen.com.tw/comment/1009960
# http://www.ipeen.com.tw/comment/974262
# http://www.ipeen.com.tw/comment/920670
# http://www.ipeen.com.tw/comment/742912
# http://www.ipeen.com.tw/comment/670774
# http://www.ipeen.com.tw/comment/952476
# http://www.ipeen.com.tw/comment/736694
# 953940已完成
# http://www.ipeen.com.tw/comment/169648
# 95395已完成
# http://www.ipeen.com.tw/comment/169660
# 95397已完成
# http://www.ipeen.com.tw/comment/895942
# 953974已完成
# http://www.ipeen.com.tw/comment/741462
# http://www.ipeen.com.tw/comment/697500
# http://www.ipeen.com.tw/comment/166730
# http://www.ipeen.com.tw/comment/75877
# http://www.ipeen.com.tw/comment/49538
# http://www.ipeen.com.tw/comment/40332
# http://www.ipeen.com.tw/comment/32480
# http://www.ipeen.com.tw/comment/1193192
# http://www.ipeen.com.tw/comment/38788
# 953976已完成
# http://www.ipeen.com.tw/comment/1097255
# http://www.ipeen.com.tw/comment/1006476
# http://www.ipeen.com.tw/comment/1000614
# http://www.ipeen.com.tw/comment/957360
# http://www.ipeen.com.tw/comment/834172
# http://www.ipeen.com.tw/comment/1165931
# http://www.ipeen.com.tw/comment/1077116
# 953978已完成
# http://www.ipeen.com.tw/comment/1516724
# http://www.ipeen.com.tw/comment/1006700
# http://www.ipeen.com.tw/comment/940916
# http://www.ipeen.com.tw/comment/937788
# http://www.ipeen.com.tw/comment/935542
# http://www.ipeen.com.tw/comment/869758
# http://www.ipeen.com.tw/comment/868606
# http://www.ipeen.com.tw/comment/864822
# http://www.ipeen.com.tw/comment/757938
# http://www.ipeen.com.tw/comment/757340
# http://www.ipeen.com.tw/comment/755810
# http://www.ipeen.com.tw/comment/748290
# http://www.ipeen.com.tw/comment/686646
# http://www.ipeen.com.tw/comment/670810
# http://www.ipeen.com.tw/comment/1428329
# http://www.ipeen.com.tw/comment/1425707
# http://www.ipeen.com.tw/comment/1291721
# http://www.ipeen.com.tw/comment/1044826
# http://www.ipeen.com.tw/comment/960054
# http://www.ipeen.com.tw/comment/940368
# http://www.ipeen.com.tw/comment/935792
# http://www.ipeen.com.tw/comment/865634
# http://www.ipeen.com.tw/comment/807368
# http://www.ipeen.com.tw/comment/767932
# 953980已完成
# http://www.ipeen.com.tw/comment/825522
# http://www.ipeen.com.tw/comment/670816
# 953990已完成
# http://www.ipeen.com.tw/comment/670826
# 953994已完成
# 953996已完成
# http://www.ipeen.com.tw/comment/1355789
# http://www.ipeen.com.tw/comment/1175387
# http://www.ipeen.com.tw/comment/977162
# http://www.ipeen.com.tw/comment/836360
# http://www.ipeen.com.tw/comment/835664
# http://www.ipeen.com.tw/comment/535484
# http://www.ipeen.com.tw/comment/490466
# http://www.ipeen.com.tw/comment/422412
# http://www.ipeen.com.tw/comment/342545
# http://www.ipeen.com.tw/comment/326495
# http://www.ipeen.com.tw/comment/996572
# http://www.ipeen.com.tw/comment/551096
# http://www.ipeen.com.tw/comment/454292
# http://www.ipeen.com.tw/comment/435294
# http://www.ipeen.com.tw/comment/396742
# http://www.ipeen.com.tw/comment/190122
# 95400已完成
# http://www.ipeen.com.tw/comment/676598
# 954000已完成
# http://www.ipeen.com.tw/comment/670884
# 954016已完成
# http://www.ipeen.com.tw/comment/169661
# 95402已完成
# http://www.ipeen.com.tw/comment/716284
# http://www.ipeen.com.tw/comment/670926
# 954022已完成
# 954024已完成
# http://www.ipeen.com.tw/comment/670940
# 954028已完成
# http://www.ipeen.com.tw/comment/171556
# http://www.ipeen.com.tw/comment/169716
# 95403已完成
# http://www.ipeen.com.tw/comment/670962
# 954030已完成
# http://www.ipeen.com.tw/comment/688352
# http://www.ipeen.com.tw/comment/671364
# 954034已完成
# http://www.ipeen.com.tw/comment/671524
# 954036已完成
# http://www.ipeen.com.tw/comment/671556
# 954040已完成
# http://www.ipeen.com.tw/comment/1017770
# http://www.ipeen.com.tw/comment/672182
# 954042已完成
# http://www.ipeen.com.tw/comment/1101341
# http://www.ipeen.com.tw/comment/740986
# http://www.ipeen.com.tw/comment/971064
# http://www.ipeen.com.tw/comment/801034
# http://www.ipeen.com.tw/comment/724472
# 954046已完成
# http://www.ipeen.com.tw/comment/782562
# http://www.ipeen.com.tw/comment/671062
# http://www.ipeen.com.tw/comment/751838
# 954062已完成
# http://www.ipeen.com.tw/comment/671066
# 954064已完成
# http://www.ipeen.com.tw/comment/1295198
# http://www.ipeen.com.tw/comment/671082
# 954066已完成
# http://www.ipeen.com.tw/comment/671360
# 954070已完成
# http://www.ipeen.com.tw/comment/1122698
# http://www.ipeen.com.tw/comment/972958
# http://www.ipeen.com.tw/comment/936634
# http://www.ipeen.com.tw/comment/1541468
# http://www.ipeen.com.tw/comment/1536065
# http://www.ipeen.com.tw/comment/1018868
# http://www.ipeen.com.tw/comment/926218
# http://www.ipeen.com.tw/comment/924086
# http://www.ipeen.com.tw/comment/915624
# http://www.ipeen.com.tw/comment/840266
# 954074已完成
# http://www.ipeen.com.tw/comment/945300
# http://www.ipeen.com.tw/comment/710756
# http://www.ipeen.com.tw/comment/709814
# http://www.ipeen.com.tw/comment/699294
# http://www.ipeen.com.tw/comment/698972
# http://www.ipeen.com.tw/comment/697814
# http://www.ipeen.com.tw/comment/696428
# http://www.ipeen.com.tw/comment/695198
# http://www.ipeen.com.tw/comment/695184
# http://www.ipeen.com.tw/comment/694894
# http://www.ipeen.com.tw/comment/692580
# http://www.ipeen.com.tw/comment/691870
# http://www.ipeen.com.tw/comment/690754
# http://www.ipeen.com.tw/comment/690336
# http://www.ipeen.com.tw/comment/688338
# http://www.ipeen.com.tw/comment/688300
# http://www.ipeen.com.tw/comment/687004
# http://www.ipeen.com.tw/comment/686652
# http://www.ipeen.com.tw/comment/686376
# http://www.ipeen.com.tw/comment/686222
# http://www.ipeen.com.tw/comment/685050
# http://www.ipeen.com.tw/comment/684386
# http://www.ipeen.com.tw/comment/683822
# http://www.ipeen.com.tw/comment/683488
# http://www.ipeen.com.tw/comment/683290
# http://www.ipeen.com.tw/comment/683006
# http://www.ipeen.com.tw/comment/682690
# http://www.ipeen.com.tw/comment/681978
# http://www.ipeen.com.tw/comment/681620
# 954076已完成
# http://www.ipeen.com.tw/comment/818588
# http://www.ipeen.com.tw/comment/680550
# http://www.ipeen.com.tw/comment/870200
# http://www.ipeen.com.tw/comment/812558
# http://www.ipeen.com.tw/comment/671180
# 954084已完成
# http://www.ipeen.com.tw/comment/774452
# http://www.ipeen.com.tw/comment/756770
# http://www.ipeen.com.tw/comment/671176
# http://www.ipeen.com.tw/comment/1067801
# 954086已完成
# http://www.ipeen.com.tw/comment/671184
# 954088已完成
# http://www.ipeen.com.tw/comment/1004816
# http://www.ipeen.com.tw/comment/850094
# http://www.ipeen.com.tw/comment/671220
# 954098已完成
# http://www.ipeen.com.tw/comment/1271045
# http://www.ipeen.com.tw/comment/871274
# http://www.ipeen.com.tw/comment/538438
# http://www.ipeen.com.tw/comment/452660
# http://www.ipeen.com.tw/comment/323633
# http://www.ipeen.com.tw/comment/297707
# http://www.ipeen.com.tw/comment/97413
# http://www.ipeen.com.tw/comment/89771
# http://www.ipeen.com.tw/comment/36189
# http://www.ipeen.com.tw/comment/19763
# http://www.ipeen.com.tw/comment/13662
# http://www.ipeen.com.tw/comment/1327775
# http://www.ipeen.com.tw/comment/558568
# http://www.ipeen.com.tw/comment/551088
# http://www.ipeen.com.tw/comment/428766
# http://www.ipeen.com.tw/comment/86432
# http://www.ipeen.com.tw/comment/50210
# http://www.ipeen.com.tw/comment/33317
# http://www.ipeen.com.tw/comment/19254
# http://www.ipeen.com.tw/comment/13355
# 9541已完成
# http://www.ipeen.com.tw/comment/169678
# 95410已完成
# http://www.ipeen.com.tw/comment/1040838
# http://www.ipeen.com.tw/comment/748148
# http://www.ipeen.com.tw/comment/743638
# http://www.ipeen.com.tw/comment/742906
# http://www.ipeen.com.tw/comment/742152
# http://www.ipeen.com.tw/comment/737616
# http://www.ipeen.com.tw/comment/737170
# http://www.ipeen.com.tw/comment/736042
# http://www.ipeen.com.tw/comment/733916
# http://www.ipeen.com.tw/comment/732988
# http://www.ipeen.com.tw/comment/730704
# http://www.ipeen.com.tw/comment/724556
# http://www.ipeen.com.tw/comment/723770
# http://www.ipeen.com.tw/comment/723516
# http://www.ipeen.com.tw/comment/714102
# http://www.ipeen.com.tw/comment/713296
# http://www.ipeen.com.tw/comment/696718
# http://www.ipeen.com.tw/comment/732842
# 954100已完成
# 954106已完成
# http://www.ipeen.com.tw/comment/671270
# 954108已完成
# http://www.ipeen.com.tw/comment/254713
# 95411已完成
# http://www.ipeen.com.tw/comment/671300
# 954112已完成
# http://www.ipeen.com.tw/comment/1469402
# 954116已完成
# http://www.ipeen.com.tw/comment/1433207
# http://www.ipeen.com.tw/comment/1399274
# http://www.ipeen.com.tw/comment/1315514
# http://www.ipeen.com.tw/comment/1315067
# http://www.ipeen.com.tw/comment/1164278
# http://www.ipeen.com.tw/comment/1163804
# http://www.ipeen.com.tw/comment/1045398
# http://www.ipeen.com.tw/comment/1041890
# http://www.ipeen.com.tw/comment/1026726
# http://www.ipeen.com.tw/comment/1024092
# http://www.ipeen.com.tw/comment/1023854
# http://www.ipeen.com.tw/comment/1021108
# http://www.ipeen.com.tw/comment/1017662
# http://www.ipeen.com.tw/comment/1007814
# http://www.ipeen.com.tw/comment/1006768
# http://www.ipeen.com.tw/comment/988658
# http://www.ipeen.com.tw/comment/973790
# http://www.ipeen.com.tw/comment/973018
# http://www.ipeen.com.tw/comment/965630
# http://www.ipeen.com.tw/comment/949894
# http://www.ipeen.com.tw/comment/947572
# http://www.ipeen.com.tw/comment/940268
# http://www.ipeen.com.tw/comment/938808
# http://www.ipeen.com.tw/comment/938290
# http://www.ipeen.com.tw/comment/936568
# http://www.ipeen.com.tw/comment/919170
# http://www.ipeen.com.tw/comment/909574
# http://www.ipeen.com.tw/comment/903048
# http://www.ipeen.com.tw/comment/853972
# http://www.ipeen.com.tw/comment/808532
# http://www.ipeen.com.tw/comment/761704
# http://www.ipeen.com.tw/comment/727760
# http://www.ipeen.com.tw/comment/684948
# http://www.ipeen.com.tw/comment/684128
# http://www.ipeen.com.tw/comment/633034
# http://www.ipeen.com.tw/comment/625552
# http://www.ipeen.com.tw/comment/611814
# http://www.ipeen.com.tw/comment/556378
# http://www.ipeen.com.tw/comment/438904
# http://www.ipeen.com.tw/comment/433890
# http://www.ipeen.com.tw/comment/188380
# http://www.ipeen.com.tw/comment/1377764
# http://www.ipeen.com.tw/comment/1330211
# http://www.ipeen.com.tw/comment/1313177
# http://www.ipeen.com.tw/comment/1209245
# http://www.ipeen.com.tw/comment/1026606
# http://www.ipeen.com.tw/comment/1022486
# http://www.ipeen.com.tw/comment/996906
# http://www.ipeen.com.tw/comment/968372
# http://www.ipeen.com.tw/comment/935194
# http://www.ipeen.com.tw/comment/811742
# http://www.ipeen.com.tw/comment/590476
# http://www.ipeen.com.tw/comment/431430
# 95412已完成
# http://www.ipeen.com.tw/comment/811918
# http://www.ipeen.com.tw/comment/768232
# http://www.ipeen.com.tw/comment/763670
# http://www.ipeen.com.tw/comment/758330
# http://www.ipeen.com.tw/comment/723012
# http://www.ipeen.com.tw/comment/693158
# http://www.ipeen.com.tw/comment/671320
# http://www.ipeen.com.tw/comment/692922
# http://www.ipeen.com.tw/comment/687606
# http://www.ipeen.com.tw/comment/680626
# 954120已完成
# 954122已完成
# http://www.ipeen.com.tw/comment/865498
# http://www.ipeen.com.tw/comment/861826
# http://www.ipeen.com.tw/comment/727070
# http://www.ipeen.com.tw/comment/844374
# http://www.ipeen.com.tw/comment/801114
# 954124已完成
# http://www.ipeen.com.tw/comment/728602
# 954126已完成
# http://www.ipeen.com.tw/comment/1448441
# http://www.ipeen.com.tw/comment/1130009
# 954128已完成
# 954130已完成
# http://www.ipeen.com.tw/comment/684228
# 954136已完成
# http://www.ipeen.com.tw/comment/508432
# http://www.ipeen.com.tw/comment/415824
# http://www.ipeen.com.tw/comment/335119
# http://www.ipeen.com.tw/comment/191067
# http://www.ipeen.com.tw/comment/185043
# http://www.ipeen.com.tw/comment/156553
# http://www.ipeen.com.tw/comment/373883
# http://www.ipeen.com.tw/comment/354448
# http://www.ipeen.com.tw/comment/263576
# http://www.ipeen.com.tw/comment/192163
# 954138已完成
# http://www.ipeen.com.tw/comment/671326
# 954140已完成
# http://www.ipeen.com.tw/comment/810306
# 954142已完成
# http://www.ipeen.com.tw/comment/1424246
# http://www.ipeen.com.tw/comment/1026312
# http://www.ipeen.com.tw/comment/940622
# http://www.ipeen.com.tw/comment/656146
# http://www.ipeen.com.tw/comment/292713
# http://www.ipeen.com.tw/comment/59053
# http://www.ipeen.com.tw/comment/8571
# http://www.ipeen.com.tw/comment/627766
# 954154已完成
# 954156已完成
# http://www.ipeen.com.tw/comment/169700
# 95416已完成
# 954166已完成
# http://www.ipeen.com.tw/comment/1476566
# http://www.ipeen.com.tw/comment/1192631
# http://www.ipeen.com.tw/comment/1132895
# http://www.ipeen.com.tw/comment/1130621
# http://www.ipeen.com.tw/comment/1116431
# http://www.ipeen.com.tw/comment/1053272
# http://www.ipeen.com.tw/comment/1013322
# http://www.ipeen.com.tw/comment/962424
# http://www.ipeen.com.tw/comment/948850
# http://www.ipeen.com.tw/comment/940228
# http://www.ipeen.com.tw/comment/936116
# http://www.ipeen.com.tw/comment/928148
# http://www.ipeen.com.tw/comment/905366
# http://www.ipeen.com.tw/comment/895580
# http://www.ipeen.com.tw/comment/886150
# http://www.ipeen.com.tw/comment/875934
# http://www.ipeen.com.tw/comment/863716
# http://www.ipeen.com.tw/comment/740572
# http://www.ipeen.com.tw/comment/736234
# http://www.ipeen.com.tw/comment/716348
# http://www.ipeen.com.tw/comment/702510
# http://www.ipeen.com.tw/comment/697034
# http://www.ipeen.com.tw/comment/1536680
# http://www.ipeen.com.tw/comment/1495238
# http://www.ipeen.com.tw/comment/1382711
# http://www.ipeen.com.tw/comment/1193771
# http://www.ipeen.com.tw/comment/1173317
# http://www.ipeen.com.tw/comment/1056872
# http://www.ipeen.com.tw/comment/1042148
# http://www.ipeen.com.tw/comment/961428
# http://www.ipeen.com.tw/comment/957676
# http://www.ipeen.com.tw/comment/912436
# http://www.ipeen.com.tw/comment/885810
# http://www.ipeen.com.tw/comment/880916
# http://www.ipeen.com.tw/comment/740812
# 954168已完成
# http://www.ipeen.com.tw/comment/795768
# http://www.ipeen.com.tw/comment/785494
# http://www.ipeen.com.tw/comment/777348
# http://www.ipeen.com.tw/comment/776694
# http://www.ipeen.com.tw/comment/776056
# http://www.ipeen.com.tw/comment/773882
# http://www.ipeen.com.tw/comment/758246
# http://www.ipeen.com.tw/comment/764146
# 954170已完成
# http://www.ipeen.com.tw/comment/784824
# http://www.ipeen.com.tw/comment/753258
# http://www.ipeen.com.tw/comment/739596
# http://www.ipeen.com.tw/comment/738568
# http://www.ipeen.com.tw/comment/734624
# http://www.ipeen.com.tw/comment/729456
# http://www.ipeen.com.tw/comment/729346
# http://www.ipeen.com.tw/comment/727802
# http://www.ipeen.com.tw/comment/727606
# http://www.ipeen.com.tw/comment/727040
# http://www.ipeen.com.tw/comment/726190
# http://www.ipeen.com.tw/comment/725956
# http://www.ipeen.com.tw/comment/725242
# http://www.ipeen.com.tw/comment/724836
# http://www.ipeen.com.tw/comment/724402
# http://www.ipeen.com.tw/comment/723674
# http://www.ipeen.com.tw/comment/722762
# http://www.ipeen.com.tw/comment/722366
# http://www.ipeen.com.tw/comment/722332
# http://www.ipeen.com.tw/comment/722136
# http://www.ipeen.com.tw/comment/721958
# http://www.ipeen.com.tw/comment/721900
# http://www.ipeen.com.tw/comment/721508
# http://www.ipeen.com.tw/comment/719404
# http://www.ipeen.com.tw/comment/775146
# 954172已完成
# http://www.ipeen.com.tw/comment/759852
# 954174已完成
# http://www.ipeen.com.tw/comment/169707
# 95418已完成
# 9542已完成
# http://www.ipeen.com.tw/comment/479872
# http://www.ipeen.com.tw/comment/169706
# 95420已完成
# 95421已完成
# http://www.ipeen.com.tw/comment/671422
# 954216已完成
# 954224已完成
# http://www.ipeen.com.tw/comment/169719
# 95425已完成
# http://www.ipeen.com.tw/comment/760870
# http://www.ipeen.com.tw/comment/759350
# http://www.ipeen.com.tw/comment/758294
# http://www.ipeen.com.tw/comment/756530
# http://www.ipeen.com.tw/comment/747688
# http://www.ipeen.com.tw/comment/731788
# http://www.ipeen.com.tw/comment/730462
# http://www.ipeen.com.tw/comment/729884
# http://www.ipeen.com.tw/comment/726350
# http://www.ipeen.com.tw/comment/704448
# http://www.ipeen.com.tw/comment/698942
# http://www.ipeen.com.tw/comment/691472
# ...
# http://www.ipeen.com.tw/comment/759342
# http://www.ipeen.com.tw/comment/728662
# http://www.ipeen.com.tw/comment/721778
# http://www.ipeen.com.tw/comment/793038
# 972062已完成
# http://www.ipeen.com.tw/comment/320125
# 97207已完成
# http://www.ipeen.com.tw/comment/175024
# 97209已完成
# 9721已完成
# http://www.ipeen.com.tw/comment/175028
# 97210已完成
# 972100已完成
# http://www.ipeen.com.tw/comment/721808
# 972108已完成
# http://www.ipeen.com.tw/comment/197021
# http://www.ipeen.com.tw/comment/188447
# http://www.ipeen.com.tw/comment/180301
# http://www.ipeen.com.tw/comment/188577
# http://www.ipeen.com.tw/comment/175030
# 97211已完成
# http://www.ipeen.com.tw/comment/734484
# http://www.ipeen.com.tw/comment/723554
# 972120已完成
# http://www.ipeen.com.tw/comment/1062018
# http://www.ipeen.com.tw/comment/925926
# http://www.ipeen.com.tw/comment/906160
# http://www.ipeen.com.tw/comment/899426
# http://www.ipeen.com.tw/comment/897584
# http://www.ipeen.com.tw/comment/894798
# http://www.ipeen.com.tw/comment/826248
# http://www.ipeen.com.tw/comment/795090
# http://www.ipeen.com.tw/comment/734672
# http://www.ipeen.com.tw/comment/734490
# http://www.ipeen.com.tw/comment/721848
# http://www.ipeen.com.tw/comment/824804
# http://www.ipeen.com.tw/comment/783338
# http://www.ipeen.com.tw/comment/738918
# 972122已完成
# http://www.ipeen.com.tw/comment/721832
# 972124已完成
# http://www.ipeen.com.tw/comment/721860
# 972128已完成
# http://www.ipeen.com.tw/comment/555538
# http://www.ipeen.com.tw/comment/476304
# http://www.ipeen.com.tw/comment/592708
# http://www.ipeen.com.tw/comment/519166
# http://www.ipeen.com.tw/comment/517426
# http://www.ipeen.com.tw/comment/393558
# http://www.ipeen.com.tw/comment/175040
# 97213已完成
# http://www.ipeen.com.tw/comment/883402
# http://www.ipeen.com.tw/comment/901522
# http://www.ipeen.com.tw/comment/721842
# 972130已完成
# http://www.ipeen.com.tw/comment/1052314
# 972132已完成
# 972136已完成
# http://www.ipeen.com.tw/comment/1002804
# http://www.ipeen.com.tw/comment/974816
# http://www.ipeen.com.tw/comment/974228
# http://www.ipeen.com.tw/comment/938818
# http://www.ipeen.com.tw/comment/934686
# http://www.ipeen.com.tw/comment/926478
# http://www.ipeen.com.tw/comment/917448
# http://www.ipeen.com.tw/comment/905874
# http://www.ipeen.com.tw/comment/899086
# http://www.ipeen.com.tw/comment/886620
# http://www.ipeen.com.tw/comment/880338
# http://www.ipeen.com.tw/comment/875978
# http://www.ipeen.com.tw/comment/870472
# http://www.ipeen.com.tw/comment/860208
# http://www.ipeen.com.tw/comment/842134
# http://www.ipeen.com.tw/comment/827272
# http://www.ipeen.com.tw/comment/815814
# http://www.ipeen.com.tw/comment/814706
# http://www.ipeen.com.tw/comment/807222
# http://www.ipeen.com.tw/comment/773622
# http://www.ipeen.com.tw/comment/755938
# http://www.ipeen.com.tw/comment/743412
# http://www.ipeen.com.tw/comment/741574
# http://www.ipeen.com.tw/comment/726442
# http://www.ipeen.com.tw/comment/1402421
# http://www.ipeen.com.tw/comment/1225196
# http://www.ipeen.com.tw/comment/1047938
# http://www.ipeen.com.tw/comment/1011116
# http://www.ipeen.com.tw/comment/1005356
# http://www.ipeen.com.tw/comment/985594
# http://www.ipeen.com.tw/comment/980048
# http://www.ipeen.com.tw/comment/915656
# http://www.ipeen.com.tw/comment/915222
# http://www.ipeen.com.tw/comment/910968
# http://www.ipeen.com.tw/comment/895788
# http://www.ipeen.com.tw/comment/866334
# http://www.ipeen.com.tw/comment/865670
# http://www.ipeen.com.tw/comment/864476
# http://www.ipeen.com.tw/comment/848468
# http://www.ipeen.com.tw/comment/820698
# http://www.ipeen.com.tw/comment/747382
# http://www.ipeen.com.tw/comment/733728
# http://www.ipeen.com.tw/comment/721880
# 972138已完成
# http://www.ipeen.com.tw/comment/176529
# 97214已完成
# http://www.ipeen.com.tw/comment/721876
# 972140已完成
# 972142已完成
# 972144已完成
# http://www.ipeen.com.tw/comment/721894
# 972146已完成
# 972148已完成
# http://www.ipeen.com.tw/comment/299429
# http://www.ipeen.com.tw/comment/175041
# 97215已完成
# http://www.ipeen.com.tw/comment/721902
# 972152已完成
# 972154已完成
# http://www.ipeen.com.tw/comment/1064464
# http://www.ipeen.com.tw/comment/1063600
# http://www.ipeen.com.tw/comment/1063000
# http://www.ipeen.com.tw/comment/258207
# 97216已完成
# 972162已完成
# http://www.ipeen.com.tw/comment/949728
# http://www.ipeen.com.tw/comment/767790
# http://www.ipeen.com.tw/comment/766600
# http://www.ipeen.com.tw/comment/766024
# http://www.ipeen.com.tw/comment/766004
# http://www.ipeen.com.tw/comment/764734
# http://www.ipeen.com.tw/comment/763022
# http://www.ipeen.com.tw/comment/761400
# http://www.ipeen.com.tw/comment/758134
# http://www.ipeen.com.tw/comment/756576
# http://www.ipeen.com.tw/comment/753492
# http://www.ipeen.com.tw/comment/751860
# http://www.ipeen.com.tw/comment/749914
# http://www.ipeen.com.tw/comment/749478
# http://www.ipeen.com.tw/comment/749122
# http://www.ipeen.com.tw/comment/747870
# 972164已完成
# 972166已完成
# http://www.ipeen.com.tw/comment/1541522
# http://www.ipeen.com.tw/comment/751858
# http://www.ipeen.com.tw/comment/721932
# 972168已完成
# 972170已完成
# http://www.ipeen.com.tw/comment/897106
# http://www.ipeen.com.tw/comment/776504
# http://www.ipeen.com.tw/comment/895460
# http://www.ipeen.com.tw/comment/772974
# http://www.ipeen.com.tw/comment/721934
# 972172已完成
# http://www.ipeen.com.tw/comment/927806
# http://www.ipeen.com.tw/comment/821606
# http://www.ipeen.com.tw/comment/721948
# 972178已完成
# http://www.ipeen.com.tw/comment/762910
# http://www.ipeen.com.tw/comment/737122
# http://www.ipeen.com.tw/comment/721962
# 972180已完成
# http://www.ipeen.com.tw/comment/874802
# http://www.ipeen.com.tw/comment/722258
# 972182已完成
# http://www.ipeen.com.tw/comment/1091759
# http://www.ipeen.com.tw/comment/1060840
# http://www.ipeen.com.tw/comment/721956
# 972184已完成
# http://www.ipeen.com.tw/comment/743492
# 972186已完成
# http://www.ipeen.com.tw/comment/838796
# http://www.ipeen.com.tw/comment/721972
# 972188已完成
# http://www.ipeen.com.tw/comment/175070
# 97219已完成
# 972196已完成
# http://www.ipeen.com.tw/comment/896374
# 972198已完成
# 9722已完成
# 972200已完成
# http://www.ipeen.com.tw/comment/734576
# http://www.ipeen.com.tw/comment/714566
# 972202已完成
# http://www.ipeen.com.tw/comment/722008
# 972206已完成
# http://www.ipeen.com.tw/comment/175077
# 97221已完成
# http://www.ipeen.com.tw/comment/755528
# http://www.ipeen.com.tw/comment/724984
# http://www.ipeen.com.tw/comment/722012
# 972210已完成
# http://www.ipeen.com.tw/comment/773802
# 972212已完成
# http://www.ipeen.com.tw/comment/754678
# http://www.ipeen.com.tw/comment/722022
# 972214已完成
# http://www.ipeen.com.tw/comment/760812
# http://www.ipeen.com.tw/comment/722040
# 972216已完成
# http://www.ipeen.com.tw/comment/722054
# 972218已完成
# 97222已完成
# 972222已完成
# 972224已完成
# 97223已完成
# http://www.ipeen.com.tw/comment/722096
# 972230已完成
# http://www.ipeen.com.tw/comment/1419239
# http://www.ipeen.com.tw/comment/722274
# 972232已完成
# 972236已完成
# 972238已完成
# 97224已完成
# 972242已完成
# 97225已完成
# http://www.ipeen.com.tw/comment/878894
# http://www.ipeen.com.tw/comment/722154
# 972250已完成
# http://www.ipeen.com.tw/comment/1043746
# http://www.ipeen.com.tw/comment/1037414
# http://www.ipeen.com.tw/comment/1422464
# http://www.ipeen.com.tw/comment/1005960
# http://www.ipeen.com.tw/comment/995244
# http://www.ipeen.com.tw/comment/824236
# http://www.ipeen.com.tw/comment/722168
# 972254已完成
# http://www.ipeen.com.tw/comment/722170
# 972258已完成
# http://www.ipeen.com.tw/comment/471024
# http://www.ipeen.com.tw/comment/175090
# http://www.ipeen.com.tw/comment/659350
# http://www.ipeen.com.tw/comment/185507
# 97226已完成
# 972260已完成
# http://www.ipeen.com.tw/comment/722196
# 972262已完成
# 972264已完成
# http://www.ipeen.com.tw/comment/1239536
# http://www.ipeen.com.tw/comment/606696
# 97227已完成
# http://www.ipeen.com.tw/comment/938972
# http://www.ipeen.com.tw/comment/722242
# http://www.ipeen.com.tw/comment/1100285
# 972270已完成
# http://www.ipeen.com.tw/comment/722294
# http://www.ipeen.com.tw/comment/722238
# 972272已完成
# 972274已完成
# 972282已完成
# http://www.ipeen.com.tw/comment/722252
# 972284已完成
# http://www.ipeen.com.tw/comment/722290
# 972288已完成
# http://www.ipeen.com.tw/comment/502410
# 97229已完成
# http://www.ipeen.com.tw/comment/1296260
# http://www.ipeen.com.tw/comment/940936
# http://www.ipeen.com.tw/comment/875208
# http://www.ipeen.com.tw/comment/806544
# http://www.ipeen.com.tw/comment/722382
# 972292已完成
# 972296已完成
# 9723已完成
# http://www.ipeen.com.tw/comment/1188695
# http://www.ipeen.com.tw/comment/811592
# http://www.ipeen.com.tw/comment/254695
# http://www.ipeen.com.tw/comment/475794
# http://www.ipeen.com.tw/comment/266285
# 97230已完成
# http://www.ipeen.com.tw/comment/722352
# 972300已完成
# http://www.ipeen.com.tw/comment/1296731
# 972302已完成
# http://www.ipeen.com.tw/comment/530090
# http://www.ipeen.com.tw/comment/485752
# http://www.ipeen.com.tw/comment/370004
# http://www.ipeen.com.tw/comment/193732
# http://www.ipeen.com.tw/comment/508146
# http://www.ipeen.com.tw/comment/468288
# http://www.ipeen.com.tw/comment/456704
# http://www.ipeen.com.tw/comment/402860
# http://www.ipeen.com.tw/comment/397644
# http://www.ipeen.com.tw/comment/360006
# http://www.ipeen.com.tw/comment/197758
# http://www.ipeen.com.tw/comment/175096
# 97231已完成
# http://www.ipeen.com.tw/comment/777988
# http://www.ipeen.com.tw/comment/724650
# 972312已完成
# http://www.ipeen.com.tw/comment/811538
# http://www.ipeen.com.tw/comment/780034
# http://www.ipeen.com.tw/comment/775934
# http://www.ipeen.com.tw/comment/795878
# 972320已完成
# 972326已完成
# http://www.ipeen.com.tw/comment/723260
# 972332已完成
# http://www.ipeen.com.tw/comment/722408
# 972334已完成
# http://www.ipeen.com.tw/comment/904038
# http://www.ipeen.com.tw/comment/461676
# http://www.ipeen.com.tw/comment/175097
# 97234已完成
# http://www.ipeen.com.tw/comment/722428
# 972342已完成
# http://www.ipeen.com.tw/comment/722476
# 972348已完成
# http://www.ipeen.com.tw/comment/853510
# 972356已完成
# http://www.ipeen.com.tw/comment/722516
# 972360已完成
# http://www.ipeen.com.tw/comment/725704
# 972362已完成
# http://www.ipeen.com.tw/comment/722474
# 972364已完成
# http://www.ipeen.com.tw/comment/1058960
# http://www.ipeen.com.tw/comment/962016
# http://www.ipeen.com.tw/comment/821998
# 972366已完成
# http://www.ipeen.com.tw/comment/722524
# http://www.ipeen.com.tw/comment/722520
# 972370已完成
# http://www.ipeen.com.tw/comment/842320
# http://www.ipeen.com.tw/comment/722526
# 972372已完成
# http://www.ipeen.com.tw/comment/722544
# 972376已完成
# http://www.ipeen.com.tw/comment/732858
# http://www.ipeen.com.tw/comment/722566
# http://www.ipeen.com.tw/comment/20705
# http://www.ipeen.com.tw/comment/20660
# http://www.ipeen.com.tw/comment/758600
# 972378已完成
# http://www.ipeen.com.tw/comment/1051318
# http://www.ipeen.com.tw/comment/473904
# http://www.ipeen.com.tw/comment/473342
# http://www.ipeen.com.tw/comment/492768
# http://www.ipeen.com.tw/comment/175175
# 97238已完成
# http://www.ipeen.com.tw/comment/1407098
# http://www.ipeen.com.tw/comment/1089254
# http://www.ipeen.com.tw/comment/1022692
# http://www.ipeen.com.tw/comment/990620
# http://www.ipeen.com.tw/comment/733352
# http://www.ipeen.com.tw/comment/728300
# http://www.ipeen.com.tw/comment/974266
# http://www.ipeen.com.tw/comment/944008
# http://www.ipeen.com.tw/comment/847262
# http://www.ipeen.com.tw/comment/838774
# http://www.ipeen.com.tw/comment/767918
# http://www.ipeen.com.tw/comment/742388
# http://www.ipeen.com.tw/comment/722556
# 972380已完成
# http://www.ipeen.com.tw/comment/722564
# http://www.ipeen.com.tw/comment/846366
# http://www.ipeen.com.tw/comment/773530
# 972382已完成
# http://www.ipeen.com.tw/comment/175111
# 97239已完成
# http://www.ipeen.com.tw/comment/1045168
# http://www.ipeen.com.tw/comment/722608
# 972392已完成
# http://www.ipeen.com.tw/comment/722622
# 972396已完成
# http://www.ipeen.com.tw/comment/722666
# 972398已完成
# 9724已完成
# http://www.ipeen.com.tw/comment/726322
# 972400已完成
# http://www.ipeen.com.tw/comment/732548
# 972402已完成
# 972404已完成
# http://www.ipeen.com.tw/comment/908944
# http://www.ipeen.com.tw/comment/799852
# http://www.ipeen.com.tw/comment/750665
# http://www.ipeen.com.tw/comment/746846
# http://www.ipeen.com.tw/comment/722664
# http://www.ipeen.com.tw/comment/862534
# 972410已完成
# http://www.ipeen.com.tw/comment/755190
# local variable 'date' referenced before assignment
# http://www.ipeen.com.tw/comment/722686
# 972414已完成
# 972416已完成
# http://www.ipeen.com.tw/comment/902924
# local variable 'date' referenced before assignment
# http://www.ipeen.com.tw/comment/722808
# 972420已完成
# http://www.ipeen.com.tw/comment/723172
# 972428已完成
# 97243已完成
# http://www.ipeen.com.tw/comment/722748
# 972434已完成
# http://www.ipeen.com.tw/comment/1399553
# local variable 'date' referenced before assignment
# http://www.ipeen.com.tw/comment/722846
# http://www.ipeen.com.tw/comment/1437596
# http://www.ipeen.com.tw/comment/1361591
# 972438已完成
# 97244已完成
# 972440已完成
# http://www.ipeen.com.tw/comment/729352
# local variable 'date' referenced before assignment
# 972442已完成
# http://www.ipeen.com.tw/comment/722830
# local variable 'date' referenced before assignment
# 972444已完成
# http://www.ipeen.com.tw/comment/722782
# local variable 'date' referenced before assignment
# 972446已完成
# 972448已完成
# http://www.ipeen.com.tw/comment/175127
# local variable 'date' referenced before assignment
# http://www.ipeen.com.tw/comment/29936
# local variable 'date' referenced before assignment
# 97245已完成
# http://www.ipeen.com.tw/comment/722838
# local variable 'date' referenced before assignment
# 972450已完成
# http://www.ipeen.com.tw/comment/722828
# 972454已完成
# http://www.ipeen.com.tw/comment/722840
# local variable 'date' referenced before assignment
# 972456已完成
# 972460已完成
# http://www.ipeen.com.tw/comment/722850
# local variable 'date' referenced before assignment
# 972462已完成
# http://www.ipeen.com.tw/comment/722882
# 972464已完成
# http://www.ipeen.com.tw/comment/722904
# local variable 'date' referenced before assignment
# 972466已完成
# http://www.ipeen.com.tw/comment/1216055
# http://www.ipeen.com.tw/comment/722984
# 972468已完成
# http://www.ipeen.com.tw/comment/948964
# local variable 'date' referenced before assignment
# http://www.ipeen.com.tw/comment/921644
# local variable 'date' referenced before assignment
# http://www.ipeen.com.tw/comment/913890
# local variable 'date' referenced before assignment
# http://www.ipeen.com.tw/comment/679406
# local variable 'date' referenced before assignment
# http://www.ipeen.com.tw/comment/619376
# local variable 'date' referenced before assignment
# http://www.ipeen.com.tw/comment/253645
# local variable 'date' referenced before assignment
# http://www.ipeen.com.tw/comment/253095
# local variable 'date' referenced before assignment
# http://www.ipeen.com.tw/comment/1117343
# http://www.ipeen.com.tw/comment/447352
# 97247已完成
# http://www.ipeen.com.tw/comment/761442
# local variable 'date' referenced before assignment
# http://www.ipeen.com.tw/comment/747068
# local variable 'date' referenced before assignment
# 972470已完成
# http://www.ipeen.com.tw/comment/808932
# local variable 'date' referenced before assignment
# http://www.ipeen.com.tw/comment/527412
# local variable 'date' referenced before assignment
# http://www.ipeen.com.tw/comment/195771
# local variable 'date' referenced before assignment
# 97248已完成
# http://www.ipeen.com.tw/comment/722976
# local variable 'date' referenced before assignment
# 972480已完成
# http://www.ipeen.com.tw/comment/753324
# local variable 'date' referenced before assignment
# http://www.ipeen.com.tw/comment/723716
# 972482已完成
# 972484已完成
# http://www.ipeen.com.tw/comment/1252064
# local variable 'date' referenced before assignment
# http://www.ipeen.com.tw/comment/1225370
# local variable 'date' referenced before assignment
# http://www.ipeen.com.tw/comment/533094
# local variable 'date' referenced before assignment
# http://www.ipeen.com.tw/comment/998644
# 972488已完成
# http://www.ipeen.com.tw/comment/175164
# local variable 'date' referenced before assignment
# http://www.ipeen.com.tw/comment/372483
# 97249已完成
# http://www.ipeen.com.tw/comment/723036
# 972494已完成
# http://www.ipeen.com.tw/comment/1073207
# local variable 'date' referenced before assignment
# 972498已完成
# 9725已完成
# http://www.ipeen.com.tw/comment/180115
# local variable 'date' referenced before assignment
# http://www.ipeen.com.tw/comment/187667
# local variable 'date' referenced before assignment
# http://www.ipeen.com.tw/comment/175160
# local variable 'date' referenced before assignment
# 97250已完成
# http://www.ipeen.com.tw/comment/723138
# 972500已完成
# http://www.ipeen.com.tw/comment/867382
# http://www.ipeen.com.tw/comment/723076
# 972502已完成
# 972506已完成
# http://www.ipeen.com.tw/comment/988666
# http://www.ipeen.com.tw/comment/839866
# http://www.ipeen.com.tw/comment/766034
# http://www.ipeen.com.tw/comment/764104
# http://www.ipeen.com.tw/comment/755762
# http://www.ipeen.com.tw/comment/754890
# http://www.ipeen.com.tw/comment/748928
# http://www.ipeen.com.tw/comment/747508
# http://www.ipeen.com.tw/comment/732236

# %%
with open("../data/diencomments/1000080.json",encoding="utf8") as f:
    data=json.load(f)

# %%
import json
# x=[json.load(open("../data/diencomments/"+file)) for file in os.listdir("../data/diencomments")]
x=[{"id":file.split(".")[0],"comments":json.load(open("../data/diencomments/"+file))} for file in os.listdir("../data/diencomments")]
print("讀取完畢")


def flat_list_v_1(the_list):
    is_nested = True
    before = the_list[:]
    while is_nested:
        is_nested = False
        now = []
        for item in before:
            if isinstance(item, list):
                now.extend(item)
                is_nested = True
            else:
                now.append(item)
        before = now
    return before

# a=flat_list_v_1(x)

# print("list解開完畢")

# len(a)

# %%
x=[dien['comments'] for dien in a]
a=flat_list_v_1(x)
len(a)

# %%
a[:100]
