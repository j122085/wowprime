# %%
import json
with open(r"C:\Users\andy.yuan\Downloads\table_2016.geojson",encoding="utf8") as f:
    x=json.load(f)

# %%
x
# Out:
# {'features': [{'geometry': {'coordinates': [[[[121.238262, 25.079399],
#        [121.235839, 25.079587],
#        [121.235154, 25.081295],
#        [121.235553, 25.082677],
#        [121.237353, 25.083588],
#        [121.239218, 25.0827],
#        [121.239785, 25.081288],
#        [121.239256, 25.080213],
#        [121.2384, 25.079544],
#        [121.238262, 25.079399]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'cartodb_id': 233, 'gridcode': 4, 'id': 234},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[121.41732, 24.999375],
#        [121.415836, 24.999626],
#        [121.41422, 25.002283],
#        [121.415085, 25.003027],
#        [121.417139, 25.001443],
#        [121.417752, 25.000435],
#        [121.41732, 24.999375]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'cartodb_id': 592, 'gridcode': 4, 'id': 617},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[121.020239, 24.886742],
#        [121.018061, 24.886874],
# ...
